# %% [markdown]
# <img align="right" src="images/tf.png" width="128"/>
# <img align="right" src="images/logo.png" width="128"/>
# <img align="right" src="images/etcbc.png" width="128"/>
# <img align="right" src="images/dans.png" width="128"/>
#
# ---
#
# To get started: consult [start](start.ipynb)
#
# ---
#
# # Display
#
# We show the ins and outs of displaying Dead Sea Scroll material.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os, collections
from tf.app import use
from tf.applib.helpers import dm, dh

# %% [markdown]
# If you want to use a version of the DSS ahead of a release, use the incantation with `hot` in it.
# That will take time, not only for the download itself, but also for the one-time preprocessing of the data.
#
# If you are content with the latest stable release, use the line without the `hot`.
#
# I have the data locally in my github clone of the DSS, so I use the variant with `clone`.
#
# If you do a `git clone https://github.com/ETCBC/dss` from your directory
# `~/github/etcbc` you can use this as well.

# %%
#A = use('dss:hot', checkout='hot', hoist=globals())
#A = use('dss:clone', checkout='clone', hoist=globals())
A = use('dss', hoist=globals())
# Out:
# 	connecting to online GitHub repo annotation/app-dss ... connected
# Using TF-app in /Users/dirk/text-fabric-data/annotation/app-dss/code:
# 	rv0.4=#6f0198838fa9339fc85e23551bd83d61e4bbaaa7 (latest release)
# 	connecting to online GitHub repo etcbc/dss ... connected
# Using data in /Users/dirk/text-fabric-data/etcbc/dss/tf/0.4:
# 	rv0.4=#dbdfeb914b510aa5bed5425b5b3096521e8b35c2 (latest release)
# 	connecting to online GitHub repo etcbc/dss ... connected
# Using data in /Users/dirk/text-fabric-data/etcbc/dss/parallels/tf/0.4:
# 	rv0.4=#dbdfeb914b510aa5bed5425b5b3096521e8b35c2 (latest release)
# <b>Documentation:</b> <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/" title="provenance of Dead Sea Scrolls">DSS</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Writing/Hebrew.html" title="Hebrew characters and transcriptions">Character table</a> <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="DSS feature documentation">Feature docs</a> <a target="_blank" href="https://github.com/annotation/app-dss" title="dss API documentation">dss API</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/" title="text-fabric-api">Text-Fabric API 7.7.0</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Use/Search/" title="Search Templates Introduction and Reference">Search Reference</a><details open><summary><b>Loaded features</b>:</summary>
# <p><b>Dead Sea Scrolls</b>: <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/after.tf">after</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/alt.tf">alt</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/biblical.tf">biblical</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/book.tf">book</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/chapter.tf">chapter</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/cl.tf">cl</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/cl2.tf">cl2</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/cor.tf">cor</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/fragment.tf">fragment</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/full.tf">full</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/fulle.tf">fulle</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/fullo.tf">fullo</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/glex.tf">glex</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/glexe.tf">glexe</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/glexo.tf">glexo</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/glyph.tf">glyph</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/glyphe.tf">glyphe</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/glypho.tf">glypho</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/gn.tf">gn</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/gn2.tf">gn2</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/gn3.tf">gn3</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/halfverse.tf">halfverse</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/intl.tf">intl</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.4/lang.tf">lang</a>  <a target="_blank" href="https://github.com/etcbc/ ...
# <style>
# @font-face {
#   font-family: "Ezra SIL";
#   src:
#     local("SILEOT.ttf"),
#     url("https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true");
# }
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: normal;
#     text-decoration: none;
#     direction: ltr;
# }
# .txte,.txte a:visited,.txte a:link {
#     font-family: monospace;
#     font-size: normal;
#     text-decoration: none;
#     direction: ltr;
# }
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: large;
#     text-decoration: none;
#     direction: ltr;
# }
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: x-large;
#     text-decoration: none;
#     direction: rtl;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .meta {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: row nowrap;
# }
# .features {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .children {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     border: 0;
#     background-color: #ffffff;
# }
# .children.scroll {
#     flex-flow: column nowrap;
# }
# .children.fragment {
#     flex-flow: column nowrap;
# }
# .children.line {
#     align-items: stretch;
#     flex-flow: row wrap;
# }
# .children.cluster {
#     flex-flow: row wrap;
# }
# .children.word {
#     align-items: stretch;
#     flex-flow: row nowrap;
# }
# .children.sign {
#     flex-flow: column nowrap;
# }
# .contnr {
#     width: fit-content;
#     direction: rtl;
# }
# .contnr.scroll,.contnr.fragment,
# .contnr.line,
# .contnr.cluster,
# .contnr.word,
# .contnr.sign {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5em 0.1em 0.1em 0.1em;
#     margin: 0.8em 0.1em 0.1em 0.1em;
#     border-radius: 0.2em;
#     border-style: solid;
#     border-width: 0.2em;
#     font-size: small;
# }
# .contnr.scroll,.contnr.fragment {
#     border-color: #bb8800;
# }
# .contnr.line {
#     border-color: #0088bb;
# }
# .contnr.cluster {
#     flex-flow: row wrap;
#     border: 0;
# }
# .contnr.word {
#     border-color: #44bbff;
# }
# .contnr.sign {
#     border-color: #bbbbbb;
# }
# .contnr.hl {
#     background-color: #ffee66;
# }
# .lbl.scroll,.lbl.fragment,
# .lbl.line,
# .lbl.cluster,
# .lbl.sign,.lbl.word {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     font-size: small;
#     display: block;
# }
# .lbl.scroll,.lbl.fragment {
#     border-color: #bb8800;
#     border-width: 0.3em;
#     border-radius: 0.3em;
#     color: #bb8800;
# }
# .lbl.line {
#     border-color: #0088bb;
#     border-width: 0.3em;
#     border-radius: 0.3em;
#     color: #0088bb;
# }
# .lbl.cluster {
#     border-color: #dddddd;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     color: #0000cc;
# }
# .lbl.word {
#     border-color: #44bbff;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     font-size: medium;
#     color: #000000;
# }
# .lbl.sign {
#     border-color: #bbbbbb;
#     border-width: 0.1em;
#     border-radius: 0.1em;
#     font-size: small;
#     color: #000000;
# }
# .name {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .text {
#     font-family: sans-serif;
#     font-size: x-small;
#     color: #000000;
# }
# .srcln {
#     font-family: monospace;
#     font-size: x-small;
#     color: #0000bb;
# }
# .scriptpaleohebrew {
#     border: 1px dashed navy;
# }
# .scriptgreekcapital {
#     border: 1px dashed brown;
# }
# .langa {
#     text-decoration: underline;
# }
# .intl1 {
#     vertical-align: -0.25em;
# }
# .intl2 {
#     vertical-align: -0.5em;
# }
# .langg {
#     font-family: serif;
#     text-decoration: underline;
# }
# .vac1 {
#     background-color: #aaaaaa;
#     border 2pt solid #dd3333;
#     border-radius: 4pt;
# }
# .rem1 {
#     font-weight: bold;
#     color: red;
#     text-decoration: line-through;
# }
# .rem2 {
#     font-weight: bold;
#     color: maroon;
#     text-decoration: line-through;
# }
# .rec1 {
#     color: teal;
#     font-size: 80%;
# }
# .cor1 {
#     font-weight: bold;
#     color: dodgerblue;
#     text-decoration: overline;
# }
# .cor2 {
#     font-weight: bold;
#     color: navy;
#     text-decoration: overline;
# }
# .cor3 {
#     font-weight: bold;
#     color: navy;
#     text-decoration: overline;
#     vertical-align: super;
# }
# .alt1 {
#     text-decoration: overline;
# }
#
# /* UNSURE: italic*/
#
# .unc1 {
#     font-weight: bold;
#     color: #888888;
# }
# .unc2 {
#     font-weight: bold;
#     color: #bbbbbb;
# }
# .unc3 {
#     font-weight: bold;
#     color: #bbbbbb;
#     text-shadow: #cccccc 1px 1px;
# }
# .unc4 {
#     font-weight: bold;
#     color: #dddddd;
#     text-shadow: #eeeeee 2px 2px;
# }
#
# /* cluster */
# .empty {
#   color: #ff0000;
# }
#
#
# tr.tf, td.tf, th.tf {
#   text-align: left;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlup {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>
# <details open><summary><b>API members</b>:</summary>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">C Computed</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Call AllComputeds</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Cs ComputedString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">E Edge</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Eall AllEdges</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Es EdgeString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ensureLoaded</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">TF</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ignored</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">loadLog</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Locality/#locality" title="doc">L Locality</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">cache</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">error</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">indent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">info</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">reset</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">N Nodes</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKey</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKeyTuple</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">otypeRank</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortNodes</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">F Feature</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fall AllFeatures</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fs FeatureString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Search/#search" title="doc">S Search</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Text/#text" title="doc">T Text</a></details>

# %% [markdown]
# We pick an example fragment with which we illustrate many ways to represent the DSS material.

# %%
examplefragment = ('1Q1', 'f1')
f = T.nodeFromSection(examplefragment)
lines = L.d(f, otype='line')
words = L.d(f, otype='word')
signs = L.d(f, otype='sign')

# %% [markdown]
# # Text formats
#
# The TF API supports *text formats*. Text formats make selections and apply templates and styles based
# on the analysed features of the text. For example: a text-format may ignore flags or clusters, or
# format numerals in special ways.
#
# Text formats are not baked into TF, but they are defined in the feature `otext` of the corpus.
#
# Moreover, for this corpus a TF app has been build that defines additional text-formats.
#
# Whereas the formats defined in `otext` are strictly plain text formats, the formats
# defined in the app are able to use typographic styles to shape the text, such as bold, italic, colors, etc.
#
# Here is the list of all formats.

# %%
T.formats
# Out:
# {'lex-default': 'word',
#  'lex-orig-full': 'word',
#  'lex-source-full': 'word',
#  'lex-trans-full': 'word',
#  'morph-source-full': 'word',
#  'text-orig-extra': 'word',
#  'text-orig-full': 'sign',
#  'text-source-extra': 'word',
#  'text-source-full': 'sign',
#  'text-trans-extra': 'word',
#  'text-trans-full': 'sign',
#  'layout-orig-full': 'sign',
#  'layout-trans-full': 'sign',
#  'layout-source-full': 'sign'}

# %% [markdown]
# ## Plain text formats
#
# The formats whose names start with `text-` are the plain text formats.
#
# ### `text-orig-full`
#
# This is the plain Hebrew text of the transcriptions, without text-critical signs and brackets.
#
# This is the default format. We do not have to specify it.

# %%
for l in lines:
  A.plain(l)
# Out:
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f1:1" sec="1Q1 f1:1">1Q1 f1:1&nbsp;</a><span class="txtu">וירא אלהים כי טוב ׃ ויהי ערב ויהי בקר יום רביעי ׃ ויאמר </span>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f1:2" sec="1Q1 f1:2">1Q1 f1:2&nbsp;</a><span class="txtu">אלהים ישׁרוצו המים שׁרץ נפשׁ חיה ועוף יעופף על הארץ על פני רקיע השׁמים ׃ </span>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f1:3" sec="1Q1 f1:3">1Q1 f1:3&nbsp;</a><span class="txtu">ויברא אלהים את התנינם הגדלים ואת כל נפשׁ החיה הרמשׁת אשׁר שׁרצו המים ׃ </span>

# %% [markdown]
# The `plain()` function focuses on the *contents*, and instead of the line number, it gives a full specification
# of the location,
# linked to the [Leon Levy digital library](https://www.deadseascrolls.org.il/home).
#
# But we can omit the locations:

# %%
for l in lines:
  A.plain(l, withPassage=False)
# Out:
# <span class="txtu">וירא אלהים כי טוב ׃ ויהי ערב ויהי בקר יום רביעי ׃ ויאמר </span>
# <span class="txtu">אלהים ישׁרוצו המים שׁרץ נפשׁ חיה ועוף יעופף על הארץ על פני רקיע השׁמים ׃ </span>
# <span class="txtu">ויברא אלהים את התנינם הגדלים ואת כל נפשׁ החיה הרמשׁת אשׁר שׁרצו המים ׃ </span>

# %% [markdown]
# ### `text-source-extra`
#
# This format is really close to the Abegg transcription. It contains all original information.

# %%
for l in lines:
  A.plain(l, fmt='text-source-extra')
# Out:
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f1:1" sec="1Q1 f1:1">1Q1 f1:1&nbsp;</a><span class="txto">]wyra al[hyM ky ]fwb . wyhy orb wyhy bqr ywM rbyoy . wyamr[ </span>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f1:2" sec="1Q1 f1:2">1Q1 f1:2&nbsp;</a><span class="txto">]alhyM yC[rwxw hmyM Cr«]X npC jyh wowP yowpP ol harX ol pny rqyo hCmyM . </span>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f1:3" sec="1Q1 f1:3">1Q1 f1:3&nbsp;</a><span class="txto">]wybra a[l]hyM at htnynM hgdlyM wat kl npC hjyh hrmCt aCr Crxw hmyM[ . </span>

# %% [markdown]
# ### `text-trans-extra`
#
# This format gives the ETCBC transcription:

# %%
for l in lines:
  A.plain(l, fmt='text-trans-extra')
# Out:
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f1:1" sec="1Q1 f1:1">1Q1 f1:1&nbsp;</a><span class="txte">[ WJR> >L ]HJm KJ [ VWB 00 WJHJ &lt;RB WJHJ BQR JWm RBJ&lt;J 00 WJ>MR ] </span>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f1:2" sec="1Q1 f1:2">1Q1 f1:2&nbsp;</a><span class="txte">[ >LHJm JC ]RWYW HMJm CR#[ y NPC XJH W&lt;Wp J&lt;WPp &lt;L H>Ry &lt;L PNJ RQJ&lt; HCMJm 00 </span>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f1:3" sec="1Q1 f1:3">1Q1 f1:3&nbsp;</a><span class="txte">[ WJBR> > ]L[ HJm >T HTNJNm HGDLJm W>T KL NPC HXJH HRMCT >CR CRYW HMJm ] 00 </span>

# %% [markdown]
# ## Styled text formats
#
# The formats whose names start with `layout-` are the styled text formats.
#
# ### `layout-orig-full`
#
# This format looks like `text-orig-full`, but now we re-introduce the flags and clusters by specific
# layout devices.

# %%
for l in lines:
  A.plain(l, fmt='layout-orig-full')
# Out:
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f1:1" sec="1Q1 f1:1">1Q1 f1:1&nbsp;</a><span class="txtu"><span class="rec1">ו</span><span class="rec1">י</span><span class="rec1">ר</span><span class="rec1">א</span> <span class="rec1">א</span><span class="rec1">ל</span>הים כי <span class="rec1">ט</span><span class="rec1">ו</span><span class="rec1">ב</span> <span class="rec1"></span><span class="rec1">׃</span> <span class="rec1">ו</span><span class="rec1">י</span><span class="rec1">ה</span><span class="rec1">י</span> <span class="rec1">ע</span><span class="rec1">ר</span><span class="rec1">ב</span> <span class="rec1">ו</span><span class="rec1">י</span><span class="rec1">ה</span><span class="rec1">י</span> <span class="rec1">ב</span><span class="rec1">ק</span><span class="rec1">ר</span> <span class="rec1">י</span><span class="rec1">ו</span><span class="rec1">ם</span> <span class="rec1">ר</span><span class="rec1">ב</span><span class="rec1">י</span><span class="rec1">ע</span><span class="rec1">י</span> <span class="rec1"></span><span class="rec1">׃</span> <span class="rec1">ו</span><span class="rec1">י</span><span class="rec1">א</span><span class="rec1">מ</span><span class="rec1">ר</span> </span>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f1:2" sec="1Q1 f1:2">1Q1 f1:2&nbsp;</a><span class="txtu"><span class="rec1">א</span><span class="rec1">ל</span><span class="rec1">ה</span><span class="rec1">י</span><span class="rec1">ם</span> <span class="rec1">י</span><span class="rec1">שׁ</span>רוצו המים שׁ<span class="unc2">ר</span><span class="rec1">ץ</span> <span class="rec1">נ</span><span class="rec1">פ</span><span class="rec1">שׁ</span> <span class="rec1">ח</span><span class="rec1">י</span><span class="rec1">ה</span> <span class="rec1">ו</span><span class="rec1">ע</span><span class="rec1">ו</span><span class="rec1">ף</span> <span class="rec1">י</span><span class="rec1">ע</span><span class="rec1">ו</span><span class="rec1">פ</span><span class="rec1">ף</span> <span class="rec1">ע</span><span class="rec1">ל</span> <span class="rec1">ה</span><span class="rec1">א</span><span class="rec1">ר</span><span class="rec1">ץ</span> <span class="rec1">ע</span><span class="rec1">ל</span> <span class="rec1">פ</span><span class="rec1">נ</span><span class="rec1">י</span> <span class="rec1">ר</span><span class="rec1">ק</span><span class="rec1">י</span><span class="rec1">ע</span> <span class="rec1">ה</span><span class="rec1">שׁ</span><span class="rec1">מ</span><span class="rec1">י</span><span class="rec1">ם</span> <span class="rec1"></span><span class="rec1">׃</span> </span>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f1:3" sec="1Q1 f1:3">1Q1 f1:3&nbsp;</a><span class="txtu"><span class="rec1">ו</span><span class="rec1">י</span><span class="rec1">ב</span><span class="rec1">ר</span><span class="rec1">א</span> <span class="rec1">א</span>ל<span class="rec1">ה</span><span class="rec1">י</span><span class="rec1">ם</span> <span class="rec1">א</span><span class="rec1">ת</span> <span class="rec1">ה</span><span class="rec1">ת</span><span class="rec1">נ</span><span class="rec1">י</span><span class="rec1">נ</span><span class="rec1">ם</span> <span class="rec1">ה</span><span class="rec1">ג</span><span class="rec1">ד</span><span class="rec1">ל</span><span class="rec1">י</span><span class="rec1">ם</span> <span class="rec1">ו</span><span class="rec1">א</span><span class="rec1">ת</span> <span class="rec1">כ</span><span class="rec1">ל</span> <span class="rec1">נ</span><span class="rec1">פ</span><span class="rec1">שׁ</span> <span class="rec1">ה</span><span class="rec1">ח</span><span class="rec1">י</span><span class="rec1">ה</span> <span class="rec1">ה</span><span class="rec1">ר</span><span class="rec1">מ</span><span class="rec1">שׁ</span><span class="rec1">ת</span> <span class="rec1">א</span><span class="rec1">שׁ</span><span class="rec1">ר</span> <span class="rec1">שׁ</span><span class="rec1">ר</span><span class="rec1">צ</span><span class="rec1">ו</span> <span class="rec1">ה</span><span class="rec1">מ</span><span class="rec1">י</span><span class="rec1">ם</span> ׃ </span>

# %% [markdown]
# The teal font color indicates that the material is a *reconstruction*.
# In the source, it is between `[ ]` brackets.
#
# See below for a detailed list of examples.

# %% [markdown]
# ### `layout-trans-full`
#
# The same layout, but now using ETCBC transcriptions.

# %%
for l in lines:
  A.plain(l, fmt='layout-trans-full')
# Out:
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f1:1" sec="1Q1 f1:1">1Q1 f1:1&nbsp;</a><span class="txte"><span class="rec1">W</span><span class="rec1">J</span><span class="rec1">R</span><span class="rec1">></span> <span class="rec1">></span><span class="rec1">L</span>HJm KJ <span class="rec1">V</span><span class="rec1">W</span><span class="rec1">B</span> <span class="rec1"></span><span class="rec1">00</span> <span class="rec1">W</span><span class="rec1">J</span><span class="rec1">H</span><span class="rec1">J</span> <span class="rec1"><</span><span class="rec1">R</span><span class="rec1">B</span> <span class="rec1">W</span><span class="rec1">J</span><span class="rec1">H</span><span class="rec1">J</span> <span class="rec1">B</span><span class="rec1">Q</span><span class="rec1">R</span> <span class="rec1">J</span><span class="rec1">W</span><span class="rec1">m</span> <span class="rec1">R</span><span class="rec1">B</span><span class="rec1">J</span><span class="rec1"><</span><span class="rec1">J</span> <span class="rec1"></span><span class="rec1">00</span> <span class="rec1">W</span><span class="rec1">J</span><span class="rec1">></span><span class="rec1">M</span><span class="rec1">R</span> </span>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f1:2" sec="1Q1 f1:2">1Q1 f1:2&nbsp;</a><span class="txte"><span class="rec1">></span><span class="rec1">L</span><span class="rec1">H</span><span class="rec1">J</span><span class="rec1">m</span> <span class="rec1">J</span><span class="rec1">C</span>RWYW HMJm C<span class="unc2">R</span><span class="rec1">y</span> <span class="rec1">N</span><span class="rec1">P</span><span class="rec1">C</span> <span class="rec1">X</span><span class="rec1">J</span><span class="rec1">H</span> <span class="rec1">W</span><span class="rec1"><</span><span class="rec1">W</span><span class="rec1">p</span> <span class="rec1">J</span><span class="rec1"><</span><span class="rec1">W</span><span class="rec1">P</span><span class="rec1">p</span> <span class="rec1"><</span><span class="rec1">L</span> <span class="rec1">H</span><span class="rec1">></span><span class="rec1">R</span><span class="rec1">y</span> <span class="rec1"><</span><span class="rec1">L</span> <span class="rec1">P</span><span class="rec1">N</span><span class="rec1">J</span> <span class="rec1">R</span><span class="rec1">Q</span><span class="rec1">J</span><span class="rec1"><</span> <span class="rec1">H</span><span class="rec1">C</span><span class="rec1">M</span><span class="rec1">J</span><span class="rec1">m</span> <span class="rec1"></span><span class="rec1">00</span> </span>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f1:3" sec="1Q1 f1:3">1Q1 f1:3&nbsp;</a><span class="txte"><span class="rec1">W</span><span class="rec1">J</span><span class="rec1">B</span><span class="rec1">R</span><span class="rec1">></span> <span class="rec1">></span>L<span class="rec1">H</span><span class="rec1">J</span><span class="rec1">m</span> <span class="rec1">></span><span class="rec1">T</span> <span class="rec1">H</span><span class="rec1">T</span><span class="rec1">N</span><span class="rec1">J</span><span class="rec1">N</span><span class="rec1">m</span> <span class="rec1">H</span><span class="rec1">G</span><span class="rec1">D</span><span class="rec1">L</span><span class="rec1">J</span><span class="rec1">m</span> <span class="rec1">W</span><span class="rec1">></span><span class="rec1">T</span> <span class="rec1">K</span><span class="rec1">L</span> <span class="rec1">N</span><span class="rec1">P</span><span class="rec1">C</span> <span class="rec1">H</span><span class="rec1">X</span><span class="rec1">J</span><span class="rec1">H</span> <span class="rec1">H</span><span class="rec1">R</span><span class="rec1">M</span><span class="rec1">C</span><span class="rec1">T</span> <span class="rec1">></span><span class="rec1">C</span><span class="rec1">R</span> <span class="rec1">C</span><span class="rec1">R</span><span class="rec1">Y</span><span class="rec1">W</span> <span class="rec1">H</span><span class="rec1">M</span><span class="rec1">J</span><span class="rec1">m</span> 00 </span>

# %% [markdown]
# ### `layout-source-full`
#
# The same layout, but now using Abegg's transcriptions.

# %%
for l in lines:
  A.plain(l, fmt='layout-source-full')
# Out:
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f1:1" sec="1Q1 f1:1">1Q1 f1:1&nbsp;</a><span class="txto"><span class="rec1">w</span><span class="rec1">y</span><span class="rec1">r</span><span class="rec1">a</span> <span class="rec1">a</span><span class="rec1">l</span>hyM ky <span class="rec1">f</span><span class="rec1">w</span><span class="rec1">b</span> <span class="rec1"></span><span class="rec1">.</span> <span class="rec1">w</span><span class="rec1">y</span><span class="rec1">h</span><span class="rec1">y</span> <span class="rec1">o</span><span class="rec1">r</span><span class="rec1">b</span> <span class="rec1">w</span><span class="rec1">y</span><span class="rec1">h</span><span class="rec1">y</span> <span class="rec1">b</span><span class="rec1">q</span><span class="rec1">r</span> <span class="rec1">y</span><span class="rec1">w</span><span class="rec1">M</span> <span class="rec1">r</span><span class="rec1">b</span><span class="rec1">y</span><span class="rec1">o</span><span class="rec1">y</span> <span class="rec1"></span><span class="rec1">.</span> <span class="rec1">w</span><span class="rec1">y</span><span class="rec1">a</span><span class="rec1">m</span><span class="rec1">r</span> </span>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f1:2" sec="1Q1 f1:2">1Q1 f1:2&nbsp;</a><span class="txto"><span class="rec1">a</span><span class="rec1">l</span><span class="rec1">h</span><span class="rec1">y</span><span class="rec1">M</span> <span class="rec1">y</span><span class="rec1">C</span>rwxw hmyM C<span class="unc2">r</span><span class="rec1">X</span> <span class="rec1">n</span><span class="rec1">p</span><span class="rec1">C</span> <span class="rec1">j</span><span class="rec1">y</span><span class="rec1">h</span> <span class="rec1">w</span><span class="rec1">o</span><span class="rec1">w</span><span class="rec1">P</span> <span class="rec1">y</span><span class="rec1">o</span><span class="rec1">w</span><span class="rec1">p</span><span class="rec1">P</span> <span class="rec1">o</span><span class="rec1">l</span> <span class="rec1">h</span><span class="rec1">a</span><span class="rec1">r</span><span class="rec1">X</span> <span class="rec1">o</span><span class="rec1">l</span> <span class="rec1">p</span><span class="rec1">n</span><span class="rec1">y</span> <span class="rec1">r</span><span class="rec1">q</span><span class="rec1">y</span><span class="rec1">o</span> <span class="rec1">h</span><span class="rec1">C</span><span class="rec1">m</span><span class="rec1">y</span><span class="rec1">M</span> <span class="rec1"></span><span class="rec1">.</span> </span>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f1:3" sec="1Q1 f1:3">1Q1 f1:3&nbsp;</a><span class="txto"><span class="rec1">w</span><span class="rec1">y</span><span class="rec1">b</span><span class="rec1">r</span><span class="rec1">a</span> <span class="rec1">a</span>l<span class="rec1">h</span><span class="rec1">y</span><span class="rec1">M</span> <span class="rec1">a</span><span class="rec1">t</span> <span class="rec1">h</span><span class="rec1">t</span><span class="rec1">n</span><span class="rec1">y</span><span class="rec1">n</span><span class="rec1">M</span> <span class="rec1">h</span><span class="rec1">g</span><span class="rec1">d</span><span class="rec1">l</span><span class="rec1">y</span><span class="rec1">M</span> <span class="rec1">w</span><span class="rec1">a</span><span class="rec1">t</span> <span class="rec1">k</span><span class="rec1">l</span> <span class="rec1">n</span><span class="rec1">p</span><span class="rec1">C</span> <span class="rec1">h</span><span class="rec1">j</span><span class="rec1">y</span><span class="rec1">h</span> <span class="rec1">h</span><span class="rec1">r</span><span class="rec1">m</span><span class="rec1">C</span><span class="rec1">t</span> <span class="rec1">a</span><span class="rec1">C</span><span class="rec1">r</span> <span class="rec1">C</span><span class="rec1">r</span><span class="rec1">x</span><span class="rec1">w</span> <span class="rec1">h</span><span class="rec1">m</span><span class="rec1">y</span><span class="rec1">M</span> . </span>

# %% [markdown]
# Or, if you want to see all the marks:

# %% [markdown]
# # Pretty
#
# The ultimate of graphical display is by means of the `pretty()` function.
#
# This display is less useful for reading, but instead optimized for showing all information that you might
# wish for.
#
# It shows a base representation according to a text format of your choice
# (here we choose `layout-orig-full`), and it shows the values
# of a standard set of features.

# %%
A.pretty(lines[0], fmt='layout-orig-full', withNodes=False, lineNumbers=False)
# Out:
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f1:1" sec="1Q1 f1:1">line <span class="txtn">1</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">1</span> <span class="line">1</span></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="rec1">ו</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">1</span> <span class="lex">וְ</span> <span class="sp">ptcl</span> <span class="cl">conj</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ו</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="rec1">י</span><span class="rec1">ר</span><span class="rec1">א</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">ראה</span> <span class="sp">verb</span> <span class="ps">3</span> <span class="gn">m</span> <span class="nu">s</span> <span class="vs">qal</span> <span class="vt">wayy</span> <span class="md">juss</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">י</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ר</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">א</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="rec1">א</span><span class="rec1">ל</span>הים </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">אֱלֹהִים</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">m</span> <span class="nu">p</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">א</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ל</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ם </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">כי </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">כִּי_2</span> <span class="sp">ptcl</span> <span class="cl">conj</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">כ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="rec1">ט</span><span class="rec1">ו</span><span class="rec1">ב</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">טֹוב_1</span> <span class="sp">adjv</span> <span class="gn">m</span> <span class="nu">s</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ט</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ו</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ב</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="rec1"></span><span class="rec1">׃</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">׃</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="rec1">ו</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">וְ</span> <span class="sp">ptcl</span> <span class="cl">conj</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ו</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="rec1">י</span><span class="rec1">ה</span><span class="rec1">י</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">היה</span> <span class="sp">verb</span> <span class="ps">3</span> <span class="gn">m</span> <span class="nu">s</span> <span class="vs">qal</span> <span class="vt">wayy</span> <span class="md">juss</span></div>

# %% [markdown]
# Later on, in the [search](search.ipynb) tutorial we see that `pretty()` can also display other features,
# even features that you or other people have created and added later.
#
# Here we call for the feature `fullo`, defined word words, not signs, which shows the original source code for the word in question
# including the bracketing characters.
#
# Consult the
# [feature documentation](https://github.com/etcbc/dss/blob/master/docs//transcription.md)
# to see what information is stored in all the features.
#
# We show it with node numbers, but you could leave them out in an obvious way.

# %%
A.pretty(lines[0], extraFeatures='fullo', fmt='layout-orig-full', withNodes=True)
# Out:
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f1:1" sec="1Q1 f1:1">line <span class="txtn">1</span></a>
#         <a href="#" class="nd">1589600</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">1</span> <span class="line">1</span></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="rec1">ו</span></span>
#         <a href="#" class="nd">1893326</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">1</span> <span class="lex">וְ</span> <span class="sp">ptcl</span> <span class="cl">conj</span> <span class="fullo xft"><span class="f">fullo=</span>]w</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ו</span></span>
#         <a href="#" class="nd">770999</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="rec1">י</span><span class="rec1">ר</span><span class="rec1">א</span> </span>
#         <a href="#" class="nd">1893327</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">ראה</span> <span class="sp">verb</span> <span class="ps">3</span> <span class="gn">m</span> <span class="nu">s</span> <span class="vs">qal</span> <span class="vt">wayy</span> <span class="md">juss</span> <span class="fullo xft"><span class="f">fullo=</span>yra</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">י</span></span>
#         <a href="#" class="nd">771000</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ר</span></span>
#         <a href="#" class="nd">771001</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">א</span> </span>
#         <a href="#" class="nd">771002</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="rec1">א</span><span class="rec1">ל</span>הים </span>
#         <a href="#" class="nd">1893328</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">אֱלֹהִים</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">m</span> <span class="nu">p</span> <span class="fullo xft"><span class="f">fullo=</span>al[hyM</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">א</span></span>
#         <a href="#" class="nd">771003</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ל</span></span>
#         <a href="#" class="nd">771004</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה</span>
#         <a href="#" class="nd">771005</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#         <a href="#" class="nd">771006</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ם </span>
#         <a href="#" class="nd">771007</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">כי </span>
#         <a href="#" class="nd">1893329</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">כִּי_2</span> <span class="sp">ptcl</span> <span class="cl">conj</span> <span class="fullo xft"><span class="f">fullo=</span>ky</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">כ</span>
#         <a href="#" class="nd">771008</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י </span>
#         <a href="#" class="nd">771009</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="rec1">ט</span><span class="rec1">ו</span><span class="rec1">ב</span> </span>
#         <a href="#" class="nd">1893330</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">טֹוב_1</span> <span class="sp">adjv</span> <span class="gn">m</span> <span class="nu">s</span> <span class="fullo xft"><span class="f">fullo=</span>]fwb</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ט</span></span>
#         <a href="#" class="nd">771010</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ו</span></span>
#         <a href="#" class="nd">771011</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ב</span> </span>
#         <a href="#" class="nd">771012</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="rec1"></span><span class="rec1">׃</span> </span>
#         <a href="#" class="nd">1893331</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="fullo xft"><span class="f">fullo=</span>.</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">׃</span> </span>
#         <a href="#" class="nd">771014</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">

# %% [markdown]
# We can even do it for a whole fragment:

# %%
A.pretty(f, extraFeatures='fullo', fmt='layout-orig-rich', withNodes=True)
# Out:
# <div class="contnr fragment " >
#
#     <div class="lbl fragment">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f1" sec="1Q1 f1">fragment <span class="txtn">f1</span></a>
#         <a href="#" class="nd">1540219</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">1</span> <span class="fragment">f1</span></div>
#     </div>
#
#
# </div>

# %% [markdown]
# We do not see much, because the default condense type is `line`, and a `fragment` is bigger than that.
# Objects bigger than de condense type will be abbreviated to a label that indicates their identity,
# not their contents.
#
# But we can override this by adding `full=True`.
#
# See also the documentation on [`pretty`](https://annotation.github.io/text-fabric/Api/App/#display).

# %%
A.pretty(f, extraFeatures='full', fmt='layout-orig-full', withNodes=False, full=True)
# Out:
# <div class="contnr fragment " >
#
#     <div class="lbl fragment">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f1" sec="1Q1 f1">fragment <span class="txtn">f1</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">1</span> <span class="fragment">f1</span></div>
#     </div>
#
#
#     <div class="children fragment">
#
#
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <span class="txtn">1</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">1</span> <span class="line">1</span></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="rec1">ו</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">1</span> <span class="lex">וְ</span> <span class="sp">ptcl</span> <span class="cl">conj</span> <span class="full xft"><span class="f">full=</span>[ ו</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ו</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="rec1">י</span><span class="rec1">ר</span><span class="rec1">א</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">ראה</span> <span class="sp">verb</span> <span class="ps">3</span> <span class="gn">m</span> <span class="nu">s</span> <span class="vs">qal</span> <span class="vt">wayy</span> <span class="md">juss</span> <span class="full xft"><span class="f">full=</span>ירא</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">י</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ר</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">א</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="rec1">א</span><span class="rec1">ל</span>הים </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">אֱלֹהִים</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">m</span> <span class="nu">p</span> <span class="full xft"><span class="f">full=</span>אל ]הים</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">א</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ל</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ם </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">כי </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">כִּי_2</span> <span class="sp">ptcl</span> <span class="cl">conj</span> <span class="full xft"><span class="f">full=</span>כי</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">כ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="rec1">ט</span><span class="rec1">ו</span><span class="rec1">ב</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">טֹוב_1</span> <span class="sp">adjv</span> <span class="gn">m</span> <span class="nu">s</span> <span class="full xft"><span class="f">full=</span>[ טוב</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ט</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ו</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ב</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="rec1"></span><span class="rec1">׃</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="full xft"><span class="f">full=</span>׃</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">׃</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="rec1">ו</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">וְ</span> <span class="sp">ptcl</span> <span class="cl">conj</span> <span class="full xft"><span class="f">full=</span>ו</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span clas

# %% [markdown]
# # Layout formats: the details
#
# We give detailed examples of how the material is styled in the `layout-` formats.
#
# We show the representation of all kinds of signs and also what the influence of
# clustering and flags are.
#
# Here are the design principles:
#
# * when the color changes as per one the cases below, the font will be bolded, except
#   for reconstructions
# * uncertain text `? # (# #) #? ##`
#   cause the signs in their scope to be in italics, grey and blurry,
#   increasingly so as the degree of uncertainty goes up from 1 to 4
# * alternate text `( )` is overlined
# * vacats `(- -)` have a red border
# * reconstructions `[ ]` are in color teal and in a smaller font
# * removed text is striked through, if by an ancient editor `{{ }}` it is set in color maroon
#   if by a modern editor, the color is red
# * corrected text is overlined, if by an ancient editor `<< >>` the color is navy,
#   if supralinear (also ancient editor) `^ ^` the color is also navy
#   and the text is superscripted, if by a modern editor `< >` the color is dodgerblue
# * interlinear text is subscripted or extra subscripted (depending on the interlinear value 1 or 2)
# * non-Hebrew text (Aramaic or Greek) is underlined
# * text that is marked by script (paleo Hebrew or Greek Capital) gets a straight border around it

# %% [markdown]
# Just a quick overview of the cluster types:

# %%
clusterFreqs = F.type.freqList(nodeTypes={'cluster'})
clusterFreqs
# Out:
# (('rec', 93733),
#  ('vac', 3522),
#  ('cor3', 1582),
#  ('unc2', 906),
#  ('rem2', 706),
#  ('alt', 333),
#  ('cor2', 147),
#  ('cor', 95),
#  ('rem', 75))

# %%
clusterTypes = [x[0] for x in clusterFreqs]
clusterNodes = F.otype.s('cluster')
clusterByType = {typ: [n for n in clusterNodes if F.type.v(n) == typ] for typ in clusterTypes}
clusterExamples = {typ: clusterByType[typ][0:2] for typ in clusterTypes}

# %% [markdown]
# We have now example nodes for each type of cluster.
#
# Likewise, we want examples of the uncertain flag, the languages, the scripts, the interlinears.
#
# We write a generic function to provide example nodes for each value that a `feature` of interest can have.
# Of all those nodes, we select a sub list, from `start` to `end`.

# %%
def compileExamples(feature, start, end):
  print(f'Examples for feature "{feature}"')
  fObj = Fs(feature)
  f = fObj.v
  freqs = fObj.freqList()
  for (c, amount) in freqs:
    print(f'\t{c} occurs {amount:>6} x')
  values = [x[0] for x in freqs]
  nodes = [n for n in F.otype.s('sign') if f(n)]
  nodesByValue = {v: [n for n in nodes if f(n) == v] for v in values}
  print(f'\t{len(nodes)} nodes have the feature "{feature}"')
  examples = {f'{feature}{"" if v == 0 else v}': nodesByValue[v][start - 1:end] for v in values}
  for (v, ns) in examples.items():
    print(f'\t{v:<10} {", ".join(str(n) for n in ns)}')
  return examples

# %% [markdown]
# We collect the examples in a dictionary `allExamples`, keyed by a string that combines the feature name with
# a value.
#
# **For the technically inclined:**
# In the TF-app for DSS, we use that key as a CSS class name to trigger special formatting.
#
# The following link takes you directly to where that happens.
# [display.css](https://github.com/annotation/app-dss/blob/d430bfe1601ff961bbed425e1c6a7a3934a81ba8/code/static/display.css#L209-L280).

# %%
allExamples = {}
allExamples.update(clusterExamples)

for (feature, start, end) in (
  ('unc', 1, 2),
  ('lang', 2, 10),
  ('script', 2, 10),
  ('intl', 1, 2),
):
  allExamples.update(compileExamples(feature, start, end))
# Out:
# Examples for feature "unc"
# 	4 occurs  40167 x
# 	2 occurs  27146 x
# 	3 occurs  14629 x
# 	1 occurs  10324 x
# 	92266 nodes have the feature "unc"
# 	unc4       1790, 4126
# 	unc2       1550, 1570
# 	unc3       1791, 4981
# 	unc1       113, 1344
# Examples for feature "lang"
# 	a occurs 185116 x
# 	g occurs     23 x
# 	135728 nodes have the feature "lang"
# 	langa      105433, 105434, 105435, 105436, 105437, 105438, 105439, 105440, 105441
# 	langg      140918, 140919, 141116, 141117, 141118, 141207, 141208, 141254, 141255
# Examples for feature "script"
# 	paleohebrew occurs   4087 x
# 	greekcapital occurs     23 x
# 	3314 nodes have the feature "script"
# 	scriptpaleohebrew 39204, 39205, 39206, 41066, 41067, 41068, 41069, 41090, 41091
# 	scriptgreekcapital 140918, 140919, 141116, 141117, 141118, 141207, 141208, 141254, 141255
# Examples for feature "intl"
# 	1 occurs   1573 x
# 	2 occurs     59 x
# 	1189 nodes have the feature "intl"
# 	intl1      103664, 103665
# 	intl2      196270, 196271

# %%
allExamples
# Out:
# {'rec': [1430278, 1430321],
#  'vac': [1430239, 1430240],
#  'cor3': [1430264, 1430283],
#  'unc2': [1550, 1570],
#  'rem2': [1430263, 1430311],
#  'alt': [1443186, 1443788],
#  'cor2': [1430294, 1430548],
#  'cor': [1430243, 1430246],
#  'rem': [1430245, 1430247],
#  'unc4': [1790, 4126],
#  'unc3': [1791, 4981],
#  'unc1': [113, 1344],
#  'langa': [105433,
#   105434,
#   105435,
#   105436,
#   105437,
#   105438,
#   105439,
#   105440,
#   105441],
#  'langg': [140918,
#   140919,
#   141116,
#   141117,
#   141118,
#   141207,
#   141208,
#   141254,
#   141255],
#  'scriptpaleohebrew': [39204,
#   39205,
#   39206,
#   41066,
#   41067,
#   41068,
#   41069,
#   41090,
#   41091],
#  'scriptgreekcapital': [140918,
#   140919,
#   141116,
#   141117,
#   141118,
#   141207,
#   141208,
#   141254,
#   141255],
#  'intl1': [103664, 103665],
#  'intl2': [196270, 196271]}

# %%
for (typ, examples) in sorted(allExamples.items()):
  dm('---\n')
  print(f'Examples of "{typ}"')
  words = set()
  for n in examples:
    isCluster = F.otype.v(n) == 'cluster'
    ref = L.d(n, otype='sign')[0] if isCluster else n
    w = L.u(ref, otype='word')[0]
    words.add(w)
  for w in words:
    A.pretty(w, fmt='layout-orig-full', withNodes=True)
# Out:
# ---
# Examples of "alt"
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q214a'" title="show this scroll in the Leon Levy library" sec="4Q214a f1:1">4Q214a f1:1</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q214a'" title="4Q214a f1:1" sec="4Q214a f1:1">word <span class="txtu"><span class="langa rec1 alt1">ת</span><span class="langa rec1 alt1">ח</span><span class="langa rec1">ו</span><span class="langa rec1">ת</span> </span></a>
#         <a href="#" class="nd">1686765</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">תְּחֹות</span> <span class="sp">ptcl</span> <span class="cl">prep</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langa rec1 alt1">ת</span></span>
#         <a href="#" class="nd">225472</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="alt"><span class="f">alt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langa rec1 alt1">ח</span></span>
#         <a href="#" class="nd">225473</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="alt"><span class="f">alt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langa rec1">ו</span></span>
#         <a href="#" class="nd">225474</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langa rec1">ת</span> </span>
#         <a href="#" class="nd">225475</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q221'" title="show this scroll in the Leon Levy library" sec="4Q221 f3:3">4Q221 f3:3</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q221'" title="4Q221 f3:3" sec="4Q221 f3:3">word <span class="txtu"><span class="rec1 alt1"> </span><span class="rec1 alt1"> </span> </span></a>
#         <a href="#" class="nd">1690246</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1 alt1"> </span></span>
#         <a href="#" class="nd">234749</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span> <span class="alt"><span class="f">alt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1 alt1"> </span> </span>
#         <a href="#" class="nd">234750</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span> <span class="alt"><span class="f">alt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# ---
# Examples of "cor"
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 2:12">CD 2:12</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 2:12" sec="CD 2:12">word <span class="txtu">משׁיח<span class="rem1">ו</span><span class="cor1">י</span> </span></a>
#         <a href="#" class="nd">1607316</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">מָשִׁיחַ</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">m</span> <span class="nu">p</span> <span class="st">c</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">מ</span>
#         <a href="#" class="nd">1327</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">שׁ</span>
#         <a href="#" class="nd">1328</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#         <a href="#" class="nd">1329</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ח</span>
#         <a href="#" class="nd">1330</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rem1">ו</span></span>
#         <a href="#" class="nd">1331</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rem"><span class="f">rem=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="cor1">י</span> </span>
#         <a href="#" class="nd">1332</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="cor"><span class="f">cor=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 2:6">CD 2:6</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 2:6" sec="CD 2:6">word <span class="txtu">י<span class="cor1">ד</span><span class="cor1">י</span> </span></a>
#         <a href="#" class="nd">1607215</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">יָד</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">f</span> <span class="nu">d</span> <span class="st">c</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#         <a href="#" class="nd">1043</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="cor1">ד</span></span>
#         <a href="#" class="nd">1044</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="cor"><span class="f">cor=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="cor1">י</span> </span>
#         <a href="#" class="nd">1045</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="cor"><span class="f">cor=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# ---
# Examples of "cor2"
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 8:15">CD 8:15</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 8:15" sec="CD 8:15">word <span class="txtu">אבות<span class="cor2">י</span>׳ך </span></a>
#         <a href="#" class="nd">1609192</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">אָב</span> <span class="sp">suff</span> <span class="cl">cmn</span> <span class="gn">m</span> <span class="nu">p</span> <span class="st">c</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">א</span>
#         <a href="#" class="nd">6655</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ב</span>
#         <a href="#" class="nd">6656</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#         <a href="#" class="nd">6657</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ת</span>
#         <a href="#" class="nd">6658</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="cor2">י</span></span>
#         <a href="#" class="nd">6659</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="cor"><span class="f">cor=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">׳</span>
#         <a href="#" class="nd">6660</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ך </span>
#         <a href="#" class="nd">6661</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QS'" title="show this scroll in the Leon Levy library" sec="1QS 1:16">1QS 1:16</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QS'" title="1QS 1:16" sec="1QS 1:16">word <span class="txtu">י<span class="rem2">א</span><span class="cor2">ע</span>בורו </span></a>
#         <a href="#" class="nd">1613348</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">עבר_1</span> <span class="sp">verb</span> <span class="ps">3</span> <span class="gn">m</span> <span class="nu">p</span> <span class="vs">qal</span> <span class="vt">impf</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#         <a href="#" class="nd">17766</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rem2">א</span></span>
#         <a href="#" class="nd">17767</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rem"><span class="f">rem=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="cor2">ע</span></span>
#         <a href="#" class="nd">17768</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="cor"><span class="f">cor=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ב</span>
#         <a href="#" class="nd">17769</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#         <a href="#" class="nd">17770</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ר</span>
#         <a href="#" class="nd">17771</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו </span>
#         <a href="#" class="nd">17772</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# ---
# Examples of "cor3"
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 5:4">CD 5:4</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 5:4" sec="CD 5:4">word <span class="txtu">יושׁ<span class="cor3">ו</span>ע </span></a>
#         <a href="#" class="nd">1608104</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">יְהֹושֻׁעַ</span> <span class="sp">subs</span> <span class="cl">prp</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#         <a href="#" class="nd">3629</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#         <a href="#" class="nd">3630</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">שׁ</span>
#         <a href="#" class="nd">3631</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="cor3">ו</span></span>
#         <a href="#" class="nd">3632</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="cor"><span class="f">cor=</span>3</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ע </span>
#         <a href="#" class="nd">3633</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 7:13">CD 7:13</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 7:13" sec="CD 7:13">word <span class="txtu">ה<span class="unc1 cor3">ו</span>סגרו </span></a>
#         <a href="#" class="nd">1608850</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">סגר</span> <span class="sp">verb</span> <span class="ps">3</span> <span class="gn">c</span> <span class="nu">p</span> <span class="vs">hofal</span> <span class="vt">perf</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה</span>
#         <a href="#" class="nd">5705</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc1 cor3">ו</span></span>
#         <a href="#" class="nd">5706</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>1</span> <span class="cor"><span class="f">cor=</span>3</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ס</span>
#         <a href="#" class="nd">5707</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ג</span>
#         <a href="#" class="nd">5708</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ר</span>
#         <a href="#" class="nd">5709</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו </span>
#         <a href="#" class="nd">5710</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# ---
# Examples of "intl1"
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q15'" title="show this scroll in the Leon Levy library" sec="1Q15 f1:2">1Q15 f1:2</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q15'" title="1Q15 f1:2" sec="1Q15 f1:2">word <span class="txtu"><span class="intl1 rec1"></span><span class="intl1 rec1">ε</span> </span></a>
#         <a href="#" class="nd">1642390</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex"> # </span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="intl1 rec1">ε</span> </span>
#         <a href="#" class="nd">103665</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="intl"><span class="f">intl=</span>1</span> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# ---
# Examples of "intl2"
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q202'" title="show this scroll in the Leon Levy library" sec="4Q202 f1ii:25">4Q202 f1ii:25</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q202'" title="4Q202 f1ii:25" sec="4Q202 f1ii:25">word <span class="txtu"><span class="langa intl2 rec1">א</span><span class="langa intl2 rec1">ד</span><span class="langa intl2 rec1">י</span><span class="langa intl2 rec1">ן</span> </span></a>
#         <a href="#" class="nd">1675844</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">אֱדַיִן</span> <span class="sp">ptcl</span> <span class="cl">advb</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langa intl2 rec1">א</span></span>
#         <a href="#" class="nd">196270</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="intl"><span class="f">intl=</span>2</span> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langa intl2 rec1">ד</span></span>
#         <a href="#" class="nd">196271</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="intl"><span class="f">intl=</span>2</span> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langa intl2 rec1">י</span></span>
#         <a href="#" class="nd">196272</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="intl"><span class="f">intl=</span>2</span> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langa intl2 rec1">ן</span> </span>
#         <a href="#" class="nd">196273</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="intl"><span class="f">intl=</span>2</span> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# ---
# Examples of "langa"
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q20'" title="show this scroll in the Leon Levy library" sec="1Q20 a0:1">1Q20 a0:1</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q20'" title="1Q20 a0:1" sec="1Q20 a0:1">word <span class="txtu"><span class="langa rec1"></span><span class="langa rec1">ε</span> </span></a>
#         <a href="#" class="nd">1643080</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex"> # </span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langa rec1">ε</span> </span>
#         <a href="#" class="nd">105433</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q20'" title="show this scroll in the Leon Levy library" sec="1Q20 a0:1">1Q20 a0:1</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q20'" title="1Q20 a0:1" sec="1Q20 a0:1">word <span class="txtu"><span class="langa"> # </span><span class="langa">כ</span><span class="langa">א</span><span class="langa"> # </span><span class="langa"> # </span><span class="langa">ל</span><span class="langa"> # </span><span class="langa"> # </span><span class="langa"> # </span> </span></a>
#         <a href="#" class="nd">1643081</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex"> # כא #  # ל #  #  # </span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langa"> # </span></span>
#         <a href="#" class="nd">105434</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langa">כ</span></span>
#         <a href="#" class="nd">105435</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langa">א</span></span>
#         <a href="#" class="nd">105436</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langa"> # </span></span>
#         <a href="#" class="nd">105437</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langa"> # </span></span>
#         <a href="#" class="nd">105438</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langa">ל</span></span>
#         <a href="#" class="nd">105439</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langa"> # </span></span>
#         <a href="#" class="nd">105440</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langa"> # </span></span>
#         <a href="#" class="nd">105441</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langa"> # </span> </span>
#         <a href="#" class="nd">105442</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# ---
# Examples of "langg"
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='3Q15'" title="show this scroll in the Leon Levy library" sec="3Q15 2:2">3Q15 2:2</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='3Q15'" title="3Q15 2:2" sec="3Q15 2:2">word <span class="txtu"><span class="langg scriptgreekcapital">Η</span><span class="langg scriptgreekcapital">Ν</span> </span></a>
#         <a href="#" class="nd">1656114</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">g</span> <span class="lex">ε</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langg scriptgreekcapital">Η</span></span>
#         <a href="#" class="nd">141207</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>g</span> <span class="script"><span class="f">script=</span>greekcapital</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langg scriptgreekcapital">Ν</span> </span>
#         <a href="#" class="nd">141208</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>g</span> <span class="script"><span class="f">script=</span>greekcapital</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='3Q15'" title="show this scroll in the Leon Levy library" sec="3Q15 1:4">3Q15 1:4</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='3Q15'" title="3Q15 1:4" sec="3Q15 1:4">word <span class="txtu"><span class="langg scriptgreekcapital">Κ</span><span class="langg scriptgreekcapital">Ε</span><span class="langg scriptgreekcapital">Ν</span> </span></a>
#         <a href="#" class="nd">1656004</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">g</span> <span class="lex">ε</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langg scriptgreekcapital">Κ</span></span>
#         <a href="#" class="nd">140917</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>g</span> <span class="script"><span class="f">script=</span>greekcapital</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langg scriptgreekcapital">Ε</span></span>
#         <a href="#" class="nd">140918</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>g</span> <span class="script"><span class="f">script=</span>greekcapital</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langg scriptgreekcapital">Ν</span> </span>
#         <a href="#" class="nd">140919</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>g</span> <span class="script"><span class="f">script=</span>greekcapital</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='3Q15'" title="show this scroll in the Leon Levy library" sec="3Q15 1:12">3Q15 1:12</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='3Q15'" title="3Q15 1:12" sec="3Q15 1:12">word <span class="txtu"><span class="langg scriptgreekcapital">Χ</span><span class="langg scriptgreekcapital">Α</span><span class="langg scriptgreekcapital">Γ</span> </span></a>
#         <a href="#" class="nd">1656078</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">g</span> <span class="lex">ε</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langg scriptgreekcapital">Χ</span></span>
#         <a href="#" class="nd">141116</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>g</span> <span class="script"><span class="f">script=</span>greekcapital</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langg scriptgreekcapital">Α</span></span>
#         <a href="#" class="nd">141117</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>g</span> <span class="script"><span class="f">script=</span>greekcapital</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langg scriptgreekcapital">Γ</span> </span>
#         <a href="#" class="nd">141118</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>g</span> <span class="script"><span class="f">script=</span>greekcapital</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='3Q15'" title="show this scroll in the Leon Levy library" sec="3Q15 2:4">3Q15 2:4</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='3Q15'" title="3Q15 2:4" sec="3Q15 2:4">word <span class="txtu"><span class="langg scriptgreekcapital">Θ</span><span class="langg scriptgreekcapital">Ε</span> </span></a>
#         <a href="#" class="nd">1656132</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">g</span> <span class="lex">ε</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langg scriptgreekcapital">Θ</span></span>
#         <a href="#" class="nd">141254</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>g</span> <span class="script"><span class="f">script=</span>greekcapital</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langg scriptgreekcapital">Ε</span> </span>
#         <a href="#" class="nd">141255</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>g</span> <span class="script"><span class="f">script=</span>greekcapital</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# ---
# Examples of "rec"
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 6:16">CD 6:16</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 6:16" sec="CD 6:16">word <span class="txtu">אלמ<span class="unc3">נ</span><span class="rec1">ו</span>ת </span></a>
#         <a href="#" class="nd">1608584</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">אַלְמָנָה</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">f</span> <span class="nu">p</span> <span class="st">a</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">א</span>
#         <a href="#" class="nd">4978</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ל</span>
#         <a href="#" class="nd">4979</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">מ</span>
#         <a href="#" class="nd">4980</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc3">נ</span></span>
#         <a href="#" class="nd">4981</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>3</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ו</span></span>
#         <a href="#" class="nd">4982</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ת </span>
#         <a href="#" class="nd">4983</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 10:14">CD 10:14</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 10:14" sec="CD 10:14">word <span class="txtu">שׁ<span class="rec1">ב</span>ת </span></a>
#         <a href="#" class="nd">1609832</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">שַׁבָּת</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">b</span> <span class="nu">s</span> <span class="st">a</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">שׁ</span>
#         <a href="#" class="nd">8385</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ב</span></span>
#         <a href="#" class="nd">8386</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ת </span>
#         <a href="#" class="nd">8387</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# ---
# Examples of "rem"
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 2:12">CD 2:12</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 2:12" sec="CD 2:12">word <span class="txtu">משׁיח<span class="rem1">ו</span><span class="cor1">י</span> </span></a>
#         <a href="#" class="nd">1607316</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">מָשִׁיחַ</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">m</span> <span class="nu">p</span> <span class="st">c</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">מ</span>
#         <a href="#" class="nd">1327</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">שׁ</span>
#         <a href="#" class="nd">1328</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#         <a href="#" class="nd">1329</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ח</span>
#         <a href="#" class="nd">1330</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rem1">ו</span></span>
#         <a href="#" class="nd">1331</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rem"><span class="f">rem=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="cor1">י</span> </span>
#         <a href="#" class="nd">1332</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="cor"><span class="f">cor=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 2:13">CD 2:13</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 2:13" sec="CD 2:13">word <span class="txtu"><span class="rem1">שׁ</span><span class="rem1">מ</span><span class="rem1">ו</span> </span></a>
#         <a href="#" class="nd">1607325</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">שֵׁם_1</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">m</span> <span class="nu">p</span> <span class="st">c</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rem1">שׁ</span></span>
#         <a href="#" class="nd">1355</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rem"><span class="f">rem=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rem1">מ</span></span>
#         <a href="#" class="nd">1356</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rem"><span class="f">rem=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rem1">ו</span> </span>
#         <a href="#" class="nd">1357</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rem"><span class="f">rem=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# ---
# Examples of "rem2"
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 9:14">CD 9:14</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 9:14" sec="CD 9:14">word <span class="txtu"><span class="rem2">ו</span></span></a>
#         <a href="#" class="nd">1609509</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">וְ</span> <span class="sp">ptcl</span> <span class="cl">conj</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rem2">ו</span></span>
#         <a href="#" class="nd">7518</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rem"><span class="f">rem=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 5:3">CD 5:3</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 5:3" sec="CD 5:3">word <span class="txtu"><span class="rem2">נ</span><span class="rem2">פ</span><span class="rem2"> # </span><span class="rem2"> # </span> </span></a>
#         <a href="#" class="nd">1608093</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">פ #  # </span> <span class="sp">verb</span> <span class="gn">m</span> <span class="nu">s</span> <span class="st">a</span> <span class="vs">nifal</span> <span class="vt">ptca</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rem2">נ</span></span>
#         <a href="#" class="nd">3596</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rem"><span class="f">rem=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rem2">פ</span></span>
#         <a href="#" class="nd">3597</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rem"><span class="f">rem=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rem2"> # </span></span>
#         <a href="#" class="nd">3598</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rem"><span class="f">rem=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rem2"> # </span> </span>
#         <a href="#" class="nd">3599</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rem"><span class="f">rem=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# ---
# Examples of "scriptgreekcapital"
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='3Q15'" title="show this scroll in the Leon Levy library" sec="3Q15 2:2">3Q15 2:2</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='3Q15'" title="3Q15 2:2" sec="3Q15 2:2">word <span class="txtu"><span class="langg scriptgreekcapital">Η</span><span class="langg scriptgreekcapital">Ν</span> </span></a>
#         <a href="#" class="nd">1656114</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">g</span> <span class="lex">ε</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langg scriptgreekcapital">Η</span></span>
#         <a href="#" class="nd">141207</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>g</span> <span class="script"><span class="f">script=</span>greekcapital</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langg scriptgreekcapital">Ν</span> </span>
#         <a href="#" class="nd">141208</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>g</span> <span class="script"><span class="f">script=</span>greekcapital</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='3Q15'" title="show this scroll in the Leon Levy library" sec="3Q15 1:4">3Q15 1:4</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='3Q15'" title="3Q15 1:4" sec="3Q15 1:4">word <span class="txtu"><span class="langg scriptgreekcapital">Κ</span><span class="langg scriptgreekcapital">Ε</span><span class="langg scriptgreekcapital">Ν</span> </span></a>
#         <a href="#" class="nd">1656004</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">g</span> <span class="lex">ε</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langg scriptgreekcapital">Κ</span></span>
#         <a href="#" class="nd">140917</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>g</span> <span class="script"><span class="f">script=</span>greekcapital</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langg scriptgreekcapital">Ε</span></span>
#         <a href="#" class="nd">140918</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>g</span> <span class="script"><span class="f">script=</span>greekcapital</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="langg scriptgreekcapital">Ν</span> </span>
#         <a href="#" class="nd">140919</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>g</span> <span class="script"><span class="f">script=</span>greekcapital</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='3Q15'" title="show this scroll in the Leon Levy library" sec="3Q15 1:12">3Q15 1:12</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='3Q15'" title="3Q15 1:12" sec="3Q15 1:12">word <span class="txtu"><span class="langg scriptgreekcapital">Χ</span><span class="langg scriptgreekcapital">Α</span><span class="langg scriptgreekcapital">Γ</span> </span></a>
#         <a href="#" class="nd">1656078</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">g</span> <span class="lex">ε</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
# ...
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ח</span>
#         <a href="#" class="nd">1342</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#         <a href="#" class="nd">1343</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc1">ז</span></span>
#         <a href="#" class="nd">1344</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc1">י</span> </span>
#         <a href="#" class="nd">1345</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 1:4">CD 1:4</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 1:4" sec="CD 1:4">word <span class="txtu"><span class="unc1">ו</span></span></a>
#         <a href="#" class="nd">1606903</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">וְ</span> <span class="sp">ptcl</span> <span class="cl">conj</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc1">ו</span></span>
#         <a href="#" class="nd">113</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# ---
# Examples of "unc2"
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 2:18">CD 2:18</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 2:18" sec="CD 2:18">word <span class="txtu"><span class="rem1">ע</span><span class="rem1">י</span><span class="unc2 rem1">ד</span><span class="rem1">י</span> </span></a>
#         <a href="#" class="nd">1607402</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">עֵד</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">m</span> <span class="nu">p</span> <span class="st">c</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rem1">ע</span></span>
#         <a href="#" class="nd">1568</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rem"><span class="f">rem=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rem1">י</span></span>
#         <a href="#" class="nd">1569</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rem"><span class="f">rem=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc2 rem1">ד</span></span>
#         <a href="#" class="nd">1570</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>2</span> <span class="rem"><span class="f">rem=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rem1">י</span> </span>
#         <a href="#" class="nd">1571</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rem"><span class="f">rem=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 2:17">CD 2:17</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 2:17" sec="CD 2:17">word <span class="txtu">לכ<span class="unc2">ת</span>׳ם </span></a>
#         <a href="#" class="nd">1607397</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">הלך</span> <span class="sp">suff</span> <span class="vs">qal</span> <span class="vt">infc</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ל</span>
#         <a href="#" class="nd">1548</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">כ</span>
#         <a href="#" class="nd">1549</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc2">ת</span></span>
#         <a href="#" class="nd">1550</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">׳</span>
#         <a href="#" class="nd">1551</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ם </span>
#         <a href="#" class="nd">1552</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# ---
# Examples of "unc3"
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 6:16">CD 6:16</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 6:16" sec="CD 6:16">word <span class="txtu">אלמ<span class="unc3">נ</span><span class="rec1">ו</span>ת </span></a>
#         <a href="#" class="nd">1608584</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">אַלְמָנָה</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">f</span> <span class="nu">p</span> <span class="st">a</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">א</span>
#         <a href="#" class="nd">4978</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ל</span>
#         <a href="#" class="nd">4979</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">מ</span>
#         <a href="#" class="nd">4980</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc3">נ</span></span>
#         <a href="#" class="nd">4981</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>3</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ו</span></span>
#         <a href="#" class="nd">4982</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ת </span>
#         <a href="#" class="nd">4983</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 3:2">CD 3:2</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 3:2" sec="CD 3:2">word <span class="txtu"><span class="unc4">א</span><span class="unc3">ו</span>הב </span></a>
#         <a href="#" class="nd">1607474</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">אהב</span> <span class="sp">verb</span> <span class="gn">m</span> <span class="nu">s</span> <span class="st">a</span> <span class="vs">qal</span> <span class="vt">ptca</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc4">א</span></span>
#         <a href="#" class="nd">1790</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>4</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc3">ו</span></span>
#         <a href="#" class="nd">1791</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>3</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה</span>
#         <a href="#" class="nd">1792</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ב </span>
#         <a href="#" class="nd">1793</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# ---
# Examples of "unc4"
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 3:2">CD 3:2</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 3:2" sec="CD 3:2">word <span class="txtu"><span class="unc4">א</span><span class="unc3">ו</span>הב </span></a>
#         <a href="#" class="nd">1607474</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">אהב</span> <span class="sp">verb</span> <span class="gn">m</span> <span class="nu">s</span> <span class="st">a</span> <span class="vs">qal</span> <span class="vt">ptca</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc4">א</span></span>
#         <a href="#" class="nd">1790</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>4</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc3">ו</span></span>
#         <a href="#" class="nd">1791</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>3</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה</span>
#         <a href="#" class="nd">1792</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ב </span>
#         <a href="#" class="nd">1793</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 5:16">CD 5:16</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 5:16" sec="CD 5:16">word <span class="txtu">מ<span class="unc4">ע</span>שׁי׳הם </span></a>
#         <a href="#" class="nd">1608274</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">מַעֲשֶׂה</span> <span class="sp">suff</span> <span class="cl">cmn</span> <span class="gn">m</span> <span class="nu">p</span> <span class="st">c</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">מ</span>
#         <a href="#" class="nd">4125</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc4">ע</span></span>
#         <a href="#" class="nd">4126</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>4</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">שׁ</span>
#         <a href="#" class="nd">4127</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#         <a href="#" class="nd">4128</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">׳</span>
#         <a href="#" class="nd">4129</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה</span>
#         <a href="#" class="nd">4130</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ם </span>
#         <a href="#" class="nd">4131</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# ---
# Examples of "vac"
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 1:1">CD 1:1</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 1:1" sec="CD 1:1">word <span class="txtu"><span class="vac1"> </span> </span></a>
#         <a href="#" class="nd">1606865</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
#     </div>
#
#
# </div>
# <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 1:11">CD 1:11</a>
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 1:11" sec="CD 1:11">word <span class="txtu"><span class="vac1"> </span> </span></a>
#         <a href="#" class="nd">1607005</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# ---
#
# All chapters:
#
# * **[start](start.ipynb)** introduction to computing with your corpus
# * **display** become an expert in creating pretty displays of your text structures
# * **[search](search.ipynb)** turbo charge your hand-coding with search templates
# * **[exportExcel](exportExcel.ipynb)** make tailor-made spreadsheets out of your results
# * **[share](share.ipynb)** draw in other people's data and let them use yours
# * **[similarLines](similarLines.ipynb)** spot the similarities between lines
#
# ---
#
# See the [cookbook](cookbook) for recipes for small, concrete tasks.
