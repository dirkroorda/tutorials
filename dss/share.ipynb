# %% [markdown]
# <img align="right" src="images/tf.png" width="128"/>
# <img align="right" src="images/logo.png" width="128"/>
# <img align="right" src="images/etcbc.png" width="128"/>
# <img align="right" src="images/dans.png" width="128"/>
#
# ---
#
# To get started: consult [start](start.ipynb)
#
# ---
#
# # Sharing data features
#
# ## Explore additional data
#
# Once you analyse a corpus, it is likely that you produce data that others can reuse.
# Maybe you have defined a set of proper name occurrences, or special numerals, or you have computed part-of-speech assignments.
#
# It is possible to turn these insights into *new features*, i.e. new `.tf` files with values assigned to specific nodes.
#
# ## Make your own data
#
# New data is a product of your own methods and computations in the first place.
# But how do you turn that data into new TF features?
# It turns out that the last step is not that difficult.
#
# If you can shape your data as a mapping (dictionary) from node numbers (integers) to values
# (strings or integers), then TF can turn that data into a feature file for you with one command.
#
# ## Share your new data
# You can then easily share your new features on GitHub, so that your colleagues everywhere
# can try it out for themselves.
#
# You can add such data on the fly, by passing a `mod={org}/{repo}/{path}` parameter,
# or a bunch of them separated by commas.
#
# If the data is there, it will be auto-downloaded and stored on your machine.
#
# Let's do it.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import collections

from tf.app import use

# %%
A = use('dss', hoist=globals())
# Out:
# 	connecting to online GitHub repo annotation/app-dss ... connected
# Using TF-app in /Users/dirk/text-fabric-data/annotation/app-dss/code:
# 	rv0.5=#97e1e3066c4e7a4319b1a34d1f858440c4369461 (latest release)
# 	connecting to online GitHub repo etcbc/dss ... connected
# Using data in /Users/dirk/text-fabric-data/etcbc/dss/tf/0.5:
# 	rv0.5=#c22b7d84ef48b7fbe13333c35cee2428228b3411 (latest release)
# 	connecting to online GitHub repo etcbc/dss ... connected
# Using data in /Users/dirk/text-fabric-data/etcbc/dss/parallels/tf/0.5:
# 	rv0.5=#c22b7d84ef48b7fbe13333c35cee2428228b3411 (latest release)
# <b>Documentation:</b> <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/" title="provenance of Dead Sea Scrolls">DSS</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Writing/Hebrew.html" title="Hebrew characters and transcriptions">Character table</a> <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="DSS feature documentation">Feature docs</a> <a target="_blank" href="https://github.com/annotation/app-dss" title="dss API documentation">dss API</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/" title="text-fabric-api">Text-Fabric API 7.7.5</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Use/Search/" title="Search Templates Introduction and Reference">Search Reference</a><details open><summary><b>Loaded features</b>:</summary>
# <p><b>Dead Sea Scrolls</b>: <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/after.tf">after</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/alt.tf">alt</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/biblical.tf">biblical</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/book.tf">book</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/chapter.tf">chapter</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/cl.tf">cl</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/cl2.tf">cl2</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/cor.tf">cor</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/fragment.tf">fragment</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/full.tf">full</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/fulle.tf">fulle</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/fullo.tf">fullo</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/glex.tf">glex</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/glexe.tf">glexe</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/glexo.tf">glexo</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/glyph.tf">glyph</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/glyphe.tf">glyphe</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/glypho.tf">glypho</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/gn.tf">gn</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/gn2.tf">gn2</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/gn3.tf">gn3</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/halfverse.tf">halfverse</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/intl.tf">intl</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/lang.tf">lang</a>  <a target="_blank" href="https://github.com/etcbc/ ...
# <style>
# @font-face {
#   font-family: "Ezra SIL";
#   src:
#     local("SILEOT.ttf"),
#     url("https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true");
# }
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: normal;
#     text-decoration: none;
#     direction: ltr;
# }
# .txte,.txte a:visited,.txte a:link {
#     font-family: monospace;
#     font-size: normal;
#     text-decoration: none;
#     direction: ltr;
# }
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: large;
#     text-decoration: none;
#     direction: ltr;
# }
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: x-large;
#     text-decoration: none;
#     direction: rtl;
# }
# .full,.glyph,.lex,.punc {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
# }
# .lex {
#   color: mediumblue;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .meta {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: row nowrap;
# }
# .features {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .children {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     border: 0;
#     background-color: #ffffff;
# }
# .children.scroll {
#     flex-flow: column nowrap;
# }
# .children.fragment {
#     flex-flow: column nowrap;
# }
# .children.line {
#     align-items: stretch;
#     flex-flow: row wrap;
# }
# .children.cluster {
#     flex-flow: row wrap;
# }
# .children.word {
#     align-items: stretch;
#     flex-flow: row nowrap;
# }
# .children.sign {
#     flex-flow: column nowrap;
# }
# .contnr {
#     width: fit-content;
#     direction: rtl;
# }
# .contnr.scroll,.contnr.fragment,
# .contnr.line,
# .contnr.cluster,
# .contnr.word,
# .contnr.sign {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5em 0.1em 0.1em 0.1em;
#     margin: 0.8em 0.1em 0.1em 0.1em;
#     border-radius: 0.2em;
#     border-style: solid;
#     border-width: 0.2em;
#     font-size: small;
# }
# .contnr.scroll,.contnr.fragment {
#     border-color: #bb8800;
# }
# .contnr.line {
#     border-color: #0088bb;
# }
# .contnr.cluster {
#     flex-flow: row wrap;
#     border: 0;
# }
# .contnr.word {
#     border-color: #44bbff;
# }
# .contnr.sign {
#     border-color: #bbbbbb;
# }
# .contnr.hl {
#     background-color: #ffee66;
# }
# .lbl.scroll,.lbl.fragment,
# .lbl.line,
# .lbl.cluster,
# .lbl.sign,.lbl.word {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     font-size: small;
#     display: block;
# }
# .lbl.scroll,.lbl.fragment {
#     border-color: #bb8800;
#     border-width: 0.3em;
#     border-radius: 0.3em;
#     color: #bb8800;
# }
# .lbl.line {
#     border-color: #0088bb;
#     border-width: 0.3em;
#     border-radius: 0.3em;
#     color: #0088bb;
# }
# .lbl.cluster {
#     border-color: #dddddd;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     color: #0000cc;
# }
# .lbl.word {
#     border-color: #44bbff;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     font-size: medium;
#     color: #000000;
# }
# .lbl.sign {
#     border-color: #bbbbbb;
#     border-width: 0.1em;
#     border-radius: 0.1em;
#     font-size: small;
#     color: #000000;
# }
# .name {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .text {
#     font-family: sans-serif;
#     font-size: x-small;
#     color: #000000;
# }
# .srcln {
#     font-family: monospace;
#     font-size: x-small;
#     color: #0000bb;
# }
# .scriptpaleohebrew {
#     border: 1px dashed navy;
# }
# .scriptgreekcapital {
#     border: 1px dashed brown;
# }
# .langa {
#     text-decoration: underline;
# }
# .intl1 {
#     vertical-align: -0.25em;
# }
# .intl2 {
#     vertical-align: -0.5em;
# }
# .langg {
#     font-family: serif;
#     text-decoration: underline;
# }
# .vac1 {
#     background-color: #aaaaaa;
#     border 2pt solid #dd3333;
#     border-radius: 4pt;
# }
# .rem1 {
#     font-weight: bold;
#     color: red;
#     text-decoration: line-through;
# }
# .rem2 {
#     font-weight: bold;
#     color: maroon;
#     text-decoration: line-through;
# }
# .rec1 {
#     color: teal;
#     font-size: 80%;
# }
# .cor1 {
#     font-weight: bold;
#     color: dodgerblue;
#     text-decoration: overline;
# }
# .cor2 {
#     font-weight: bold;
#     color: navy;
#     text-decoration: overline;
# }
# .cor3 {
#     font-weight: bold;
#     color: navy;
#     text-decoration: overline;
#     vertical-align: super;
# }
# .alt1 {
#     text-decoration: overline;
# }
#
# /* UNSURE: italic*/
#
# .unc1 {
#     font-weight: bold;
#     color: #888888;
# }
# .unc2 {
#     font-weight: bold;
#     color: #bbbbbb;
# }
# .unc3 {
#     font-weight: bold;
#     color: #bbbbbb;
#     text-shadow: #cccccc 1px 1px;
# }
# .unc4 {
#     font-weight: bold;
#     color: #dddddd;
#     text-shadow: #eeeeee 2px 2px;
# }
#
# .empty {
#   color: #ff0000;
# }
#
#
# tr.tf, td.tf, th.tf {
#   text-align: left;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlup {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>
# <details open><summary><b>API members</b>:</summary>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">C Computed</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Call AllComputeds</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Cs ComputedString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">E Edge</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Eall AllEdges</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Es EdgeString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ensureLoaded</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">TF</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ignored</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">loadLog</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Locality/#locality" title="doc">L Locality</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">cache</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">error</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">indent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">info</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">reset</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">N Nodes</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKey</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKeyTuple</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">otypeRank</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortNodes</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">F Feature</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fall AllFeatures</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fs FeatureString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Search/#search" title="doc">S Search</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Text/#text" title="doc">T Text</a></details>

# %% [markdown]
# # Making data
#
# We illustrate the data creation part by creating a new feature, `cert`.
# The idea is that we mark every consonant sign voor certainty.
#
# A certain consonant gets `cert=100`.
#
# If the consonant has the uncertain feature `unc`, then 10 times its value is subtracted from 100.
#
# If the consonant has the feature `rec`, it loses 45 points.
#
# Ancient removal `rem2` leads to minus 20, modern removal `rem` to minus 40.
#
# Ancient correction `cor2` leads to minus 12, modern correction `cor` to minus 18.
#
# Alternate marking `alt` leads to minus 25.
#
# The minimum is `1`.
#
# We extend the `cert` measure to words, fragments and scrolls by averaging over signs that
# have received a `cert` measure.

# %%
def measure(s):
  c = 100
  d = F.unc.v(s)
  if d:
    c -= 10 * d
  d = F.rec.v(s)
  if d:
    c -= 45
  d = F.rem.v(s)
  if d == 1:
    c -= 40
  elif d == 2:
    c -= 20
  d = F.cor.v(s)
  if d == 2 or d == 3:
    c -= 12
  elif d == 1:
    c -= 18
  d = F.alt.v(s)
  if d:
    c -= 25
  if c < 1:
    c = 1
  return c

# %%
CONS = 'cons'
cert = {}

indent(reset=True)

for sc in F.otype.s('scroll'):
  fN = 0
  fSum = 0
  for f in L.d(sc, otype='fragment'):
    lN = 0
    lSum = 0
    for l in L.d(f, otype='line'):
      wN = 0
      wSum = 0
      for w in L.d(l, otype='word'):
        sN = 0
        sSum = 0
        for s in L.d(w, otype='sign'):
          if F.type.v(s) != CONS:
            continue
          sCert = measure(s)
          cert[s] = sCert
          sN += 1
          sSum += sCert
        if sN:
          wCert = int(round(sSum / sN))
          cert[w] = wCert
          wN += 1
          wSum += wCert
      if wN:
        lCert = int(round(wSum / wN))
        cert[l] = lCert
        lN += 1
        lSum += lCert
    if lN:
      fCert = int(round(lSum / lN))
      cert[f] = fCert
      fN += 1
      fSum += fCert
  if fN:
    scCert = int(round(fSum / fN))
    cert[sc] = scCert
    
info(f'{len(cert)} certainties determined')
# Out:
#   5.11s 1625373 certainties determined

# %% [markdown]
# # Saving data
#
# The [documentation](https://annotation.github.io/text-fabric/Api/Fabric/#saving-features) explains how to save this data into a text-fabric
# data file.
#
# We choose a location where to save it, the `exercises` folder in the `dss` repository in the `dss` organization.
#
# In order to do this, we restart the TF api, but now with the desired output location in the `locations` parameter.

# %%
import os

# %%
GITHUB = os.path.expanduser('~/github')
ORG = 'etcbc'
REPO = 'dss'
PATH = 'exercises'
VERSION = A.version

# %% [markdown]
# Note the version: we have built the version against a specific version of the data:

# %%
A.version
# Out:
# '0.5'

# %% [markdown]
# Later on, we pass this version on, so that users of our data will get the shared data in exactly the same version as their core data.

# %% [markdown]
# We have to specify a bit of metadata for this feature:

# %%
metaData = {
  'cert': dict(
    valueType='int',
    description='measure of certainty of material, between 1 and 100 (most certain)',
    creator='Dirk Roorda',
  ),
}

# %% [markdown]
# Now we can give the save command:

# %%
TF.save(nodeFeatures=dict(cert=cert), metaData=metaData, location=f'{GITHUB}/{ORG}/{REPO}/{PATH}/tf', module=VERSION)
# Out:
#    |     1.97s T cert                 to /Users/dirk/github/etcbc/dss/exercises/tf/0.5
# True

# %% [markdown]
# # Sharing data
#
# How to share your own data is explained in the
# [documentation](https://annotation.github.io/text-fabric/Api/Data/).
#
# Here we show it step by step for the `ummama` feature.
#
# If you commit your changes to the exercises repo, and have done a `git push origin master`,
# you already have shared your data!
#
# If you want to make a stable release, so that you can keep developing, while your users fall back
# on the stable data, you can make a new release.
#
# Go to the GitHub website for that, go to your repo, and click *Releases* and follow the nudges.
#
# If you want to make it even smoother for your users, you can zip the data and attach it as a binary to the release just created.
#
# We need to zip the data in exactly the right directory structure. Text-Fabric can do that for us:

# %%
# %%sh
#
# text-fabric-zip etcbc/dss/exercises/tf
# Out:
# True
# Create release data for etcbc/dss/exercises/tf
# Found 3 versions
# zip files end up in /Users/dirk/Downloads/etcbc-release/dss
# zipping etcbc/dss                  0.3 with   1 features ==> exercises-tf-0.3.zip
# zipping etcbc/dss                  0.4 with   1 features ==> exercises-tf-0.4.zip
# zipping etcbc/dss                  0.5 with   1 features ==> exercises-tf-0.5.zip

# %% [markdown]
# All versions have been zipped, but it works OK if you only attach the newest version to the newest release.
#
# If a user asks for an older version in this release, the system can still find it.

# %% [markdown]
# # Use the data
#
# We can use the data by calling it up when we say `use('dss', ...)`.
#
# Here is how:
#
# (use the line without `clone` if the data is really published,
# use the line with `clone` if you want to test your local copy of the feature).

# %%
#A = use('dss', hoist=globals(), mod='etcbc/dss/exercises/tf')
A = use('dss', hoist=globals(), mod='etcbc/dss/exercises/tf:clone')
# Out:
# 	connecting to online GitHub repo annotation/app-dss ... connected
# Using TF-app in /Users/dirk/text-fabric-data/annotation/app-dss/code:
# 	rv0.5=#97e1e3066c4e7a4319b1a34d1f858440c4369461 (latest release)
# 	connecting to online GitHub repo etcbc/dss ... connected
# Using data in /Users/dirk/text-fabric-data/etcbc/dss/tf/0.5:
# 	rv0.5=#c22b7d84ef48b7fbe13333c35cee2428228b3411 (latest release)
# 	connecting to online GitHub repo etcbc/dss ... connected
# Using data in /Users/dirk/text-fabric-data/etcbc/dss/parallels/tf/0.5:
# 	rv0.5=#c22b7d84ef48b7fbe13333c35cee2428228b3411 (latest release)
# Using data in /Users/dirk/github/etcbc/dss/exercises/tf/0.5:
# 	repo clone offline under ~/github (local github)
# <b>Documentation:</b> <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/" title="provenance of Dead Sea Scrolls">DSS</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Writing/Hebrew.html" title="Hebrew characters and transcriptions">Character table</a> <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="DSS feature documentation">Feature docs</a> <a target="_blank" href="https://github.com/annotation/app-dss" title="dss API documentation">dss API</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/" title="text-fabric-api">Text-Fabric API 7.7.5</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Use/Search/" title="Search Templates Introduction and Reference">Search Reference</a><details open><summary><b>Loaded features</b>:</summary>
# <p><b>Dead Sea Scrolls</b>: <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/after.tf">after</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/alt.tf">alt</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/biblical.tf">biblical</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/book.tf">book</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/chapter.tf">chapter</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/cl.tf">cl</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/cl2.tf">cl2</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/cor.tf">cor</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/fragment.tf">fragment</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/full.tf">full</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/fulle.tf">fulle</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/fullo.tf">fullo</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/glex.tf">glex</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/glexe.tf">glexe</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/glexo.tf">glexo</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/glyph.tf">glyph</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/glyphe.tf">glyphe</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/glypho.tf">glypho</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/gn.tf">gn</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/gn2.tf">gn2</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/gn3.tf">gn3</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/halfverse.tf">halfverse</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/intl.tf">intl</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.5/lang.tf">lang</a>  <a target="_blank" href="https://github.com/etcbc/ ...
# <style>
# @font-face {
#   font-family: "Ezra SIL";
#   src:
#     local("SILEOT.ttf"),
#     url("https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true");
# }
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: normal;
#     text-decoration: none;
#     direction: ltr;
# }
# .txte,.txte a:visited,.txte a:link {
#     font-family: monospace;
#     font-size: normal;
#     text-decoration: none;
#     direction: ltr;
# }
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: large;
#     text-decoration: none;
#     direction: ltr;
# }
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: x-large;
#     text-decoration: none;
#     direction: rtl;
# }
# .full,.glyph,.lex,.punc {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
# }
# .lex {
#   color: mediumblue;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .meta {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: row nowrap;
# }
# .features {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .children {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     border: 0;
#     background-color: #ffffff;
# }
# .children.scroll {
#     flex-flow: column nowrap;
# }
# .children.fragment {
#     flex-flow: column nowrap;
# }
# .children.line {
#     align-items: stretch;
#     flex-flow: row wrap;
# }
# .children.cluster {
#     flex-flow: row wrap;
# }
# .children.word {
#     align-items: stretch;
#     flex-flow: row nowrap;
# }
# .children.sign {
#     flex-flow: column nowrap;
# }
# .contnr {
#     width: fit-content;
#     direction: rtl;
# }
# .contnr.scroll,.contnr.fragment,
# .contnr.line,
# .contnr.cluster,
# .contnr.word,
# .contnr.sign {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5em 0.1em 0.1em 0.1em;
#     margin: 0.8em 0.1em 0.1em 0.1em;
#     border-radius: 0.2em;
#     border-style: solid;
#     border-width: 0.2em;
#     font-size: small;
# }
# .contnr.scroll,.contnr.fragment {
#     border-color: #bb8800;
# }
# .contnr.line {
#     border-color: #0088bb;
# }
# .contnr.cluster {
#     flex-flow: row wrap;
#     border: 0;
# }
# .contnr.word {
#     border-color: #44bbff;
# }
# .contnr.sign {
#     border-color: #bbbbbb;
# }
# .contnr.hl {
#     background-color: #ffee66;
# }
# .lbl.scroll,.lbl.fragment,
# .lbl.line,
# .lbl.cluster,
# .lbl.sign,.lbl.word {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     font-size: small;
#     display: block;
# }
# .lbl.scroll,.lbl.fragment {
#     border-color: #bb8800;
#     border-width: 0.3em;
#     border-radius: 0.3em;
#     color: #bb8800;
# }
# .lbl.line {
#     border-color: #0088bb;
#     border-width: 0.3em;
#     border-radius: 0.3em;
#     color: #0088bb;
# }
# .lbl.cluster {
#     border-color: #dddddd;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     color: #0000cc;
# }
# .lbl.word {
#     border-color: #44bbff;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     font-size: medium;
#     color: #000000;
# }
# .lbl.sign {
#     border-color: #bbbbbb;
#     border-width: 0.1em;
#     border-radius: 0.1em;
#     font-size: small;
#     color: #000000;
# }
# .name {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .text {
#     font-family: sans-serif;
#     font-size: x-small;
#     color: #000000;
# }
# .srcln {
#     font-family: monospace;
#     font-size: x-small;
#     color: #0000bb;
# }
# .scriptpaleohebrew {
#     border: 1px dashed navy;
# }
# .scriptgreekcapital {
#     border: 1px dashed brown;
# }
# .langa {
#     text-decoration: underline;
# }
# .intl1 {
#     vertical-align: -0.25em;
# }
# .intl2 {
#     vertical-align: -0.5em;
# }
# .langg {
#     font-family: serif;
#     text-decoration: underline;
# }
# .vac1 {
#     background-color: #aaaaaa;
#     border 2pt solid #dd3333;
#     border-radius: 4pt;
# }
# .rem1 {
#     font-weight: bold;
#     color: red;
#     text-decoration: line-through;
# }
# .rem2 {
#     font-weight: bold;
#     color: maroon;
#     text-decoration: line-through;
# }
# .rec1 {
#     color: teal;
#     font-size: 80%;
# }
# .cor1 {
#     font-weight: bold;
#     color: dodgerblue;
#     text-decoration: overline;
# }
# .cor2 {
#     font-weight: bold;
#     color: navy;
#     text-decoration: overline;
# }
# .cor3 {
#     font-weight: bold;
#     color: navy;
#     text-decoration: overline;
#     vertical-align: super;
# }
# .alt1 {
#     text-decoration: overline;
# }
#
# /* UNSURE: italic*/
#
# .unc1 {
#     font-weight: bold;
#     color: #888888;
# }
# .unc2 {
#     font-weight: bold;
#     color: #bbbbbb;
# }
# .unc3 {
#     font-weight: bold;
#     color: #bbbbbb;
#     text-shadow: #cccccc 1px 1px;
# }
# .unc4 {
#     font-weight: bold;
#     color: #dddddd;
#     text-shadow: #eeeeee 2px 2px;
# }
#
# .empty {
#   color: #ff0000;
# }
#
#
# tr.tf, td.tf, th.tf {
#   text-align: left;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlup {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>
# <details open><summary><b>API members</b>:</summary>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">C Computed</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Call AllComputeds</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Cs ComputedString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">E Edge</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Eall AllEdges</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Es EdgeString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ensureLoaded</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">TF</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ignored</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">loadLog</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Locality/#locality" title="doc">L Locality</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">cache</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">error</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">indent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">info</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">reset</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">N Nodes</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKey</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKeyTuple</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">otypeRank</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortNodes</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">F Feature</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fall AllFeatures</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fs FeatureString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Search/#search" title="doc">S Search</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Text/#text" title="doc">T Text</a></details>

# %% [markdown]
# Above you see a new section in the feature list: **etcbc/dss/exercises/tf** with our foreign feature in it: `cert`.
#
# Now, suppose did not know much about this feature, then we would like to do a few basic checks:

# %%
F.cert.freqList()
# Out:
# ((100, 730507),
#  (55, 667515),
#  (60, 50110),
#  (80, 38107),
#  (70, 20927),
#  (90, 18767),
#  (88, 6423),
#  (85, 4794),
#  (78, 4499),
#  (87, 4226),
#  (95, 4070),
#  (93, 3997),
#  (92, 3529),
#  (58, 3017),
#  (82, 2839),
#  (98, 2833),
#  (72, 2655),
#  (68, 2628),
#  (89, 2562),
#  (56, 2510),
#  (65, 2496),
#  (96, 2436),
#  (57, 2358),
#  (97, 2275),
#  (62, 2117),
#  (63, 2089),
#  (66, 2076),
#  (75, 2011),
#  (73, 1943),
#  (94, 1904),
#  (83, 1818),
#  (84, 1796),
#  (91, 1766),
#  (79, 1762),
#  (61, 1759),
#  (64, 1754),
#  (86, 1694),
#  (74, 1549),
#  (59, 1479),
#  (77, 1402),
#  (43, 1401),
#  (67, 1284),
#  (81, 1272),
#  (76, 1234),
#  (69, 1193),
#  (71, 1118),
#  (99, 1068),
#  (30, 566),
#  (35, 352),
#  (48, 230),
#  (40, 133),
#  (50, 106),
#  (15, 100),
#  (37, 67),
#  (45, 49),
#  (51, 29),
#  (53, 23),
#  (49, 22),
#  (47, 18),
#  (25, 17),
#  (54, 14),
#  (52, 12),
#  (28, 11),
#  (42, 11),
#  (44, 9),
#  (38, 8),
#  (46, 7),
#  (20, 6),
#  (23, 3),
#  (36, 3),
#  (1, 1),
#  (18, 1),
#  (21, 1),
#  (22, 1),
#  (29, 1),
#  (31, 1),
#  (34, 1),
#  (39, 1))

# %% [markdown]
# Which nodes have the lowest uncertainty?

# %%
{F.otype.v(n) for n in N() if F.cert.v(n) and F.cert.v(n) < 10}
# Out:
# {'sign'}

# %% [markdown]
# Only signs are this uncertain.
#
# Let's look for pretty uncertain fragments:

# %%
results = A.search('''
fragment cert<50
''')
# Out:
#   0.01s 0 results

# %%
results = A.search('''
fragment cert<60
''')
# Out:
#   0.01s 380 results

# %%
A.table(results, start=1, end=20)
# Out:
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">fragment</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QSb'" title="show this scroll in the Leon Levy library" sec="1QSb f12">1QSb f12</a></td><td class="tf">fragment f12</td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q21'" title="show this scroll in the Leon Levy library" sec="1Q21 f3">1Q21 f3</a></td><td class="tf">fragment f3</td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='2Q18'" title="show this scroll in the Leon Levy library" sec="2Q18 f1">2Q18 f1</a></td><td class="tf">fragment f1</td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='2Q18'" title="show this scroll in the Leon Levy library" sec="2Q18 f2">2Q18 f2</a></td><td class="tf">fragment f2</td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='2Q29'" title="show this scroll in the Leon Levy library" sec="2Q29 f1">2Q29 f1</a></td><td class="tf">fragment f1</td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q163'" title="show this scroll in the Leon Levy library" sec="4Q163 f26">4Q163 f26</a></td><td class="tf">fragment f26</td></tr>
# <tr class="tf"><td class="tf">7</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q201'" title="show this scroll in the Leon Levy library" sec="4Q201 f1vi">4Q201 f1vi</a></td><td class="tf">fragment f1vi</td></tr>
# <tr class="tf"><td class="tf">8</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q202'" title="show this scroll in the Leon Levy library" sec="4Q202 f1vi">4Q202 f1vi</a></td><td class="tf">fragment f1vi</td></tr>
# <tr class="tf"><td class="tf">9</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q204'" title="show this scroll in the Leon Levy library" sec="4Q204 f1vii">4Q204 f1vii</a></td><td class="tf">fragment f1vii</td></tr>
# <tr class="tf"><td class="tf">10</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q204'" title="show this scroll in the Leon Levy library" sec="4Q204 f5i">4Q204 f5i</a></td><td class="tf">fragment f5i</td></tr>
# <tr class="tf"><td class="tf">11</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q205'" title="show this scroll in the Leon Levy library" sec="4Q205 f1xii">4Q205 f1xii</a></td><td class="tf">fragment f1xii</td></tr>
# <tr class="tf"><td class="tf">12</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q221'" title="show this scroll in the Leon Levy library" sec="4Q221 f3">4Q221 f3</a></td><td class="tf">fragment f3</td></tr>
# <tr class="tf"><td class="tf">13</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q249b'" title="show this scroll in the Leon Levy library" sec="4Q249b f1">4Q249b f1</a></td><td class="tf">fragment f1</td></tr>
# <tr class="tf"><td class="tf">14</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q249c'" title="show this scroll in the Leon Levy library" sec="4Q249c f1">4Q249c f1</a></td><td class="tf">fragment f1</td></tr>
# <tr class="tf"><td class="tf">15</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q249d'" title="show this scroll in the Leon Levy library" sec="4Q249d f1">4Q249d f1</a></td><td class="tf">fragment f1</td></tr>
# <tr class="tf"><td class="tf">16</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q249f'" title="show this scroll in the Leon Levy library" sec="4Q249f f1_3">4Q249f f1_3</a></td><td class="tf">fragment f1_3</td></tr>
# <tr class="tf"><td class="tf">17</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q249g'" title="show this scroll in the Leon Levy library" sec="4Q249g f1_2">4Q249g f1_2</a></td><td class="tf">fragment f1_2</td></tr>
# <tr class="tf"><td class="tf">18</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q249g'" title="show this scroll in the Leon Levy library" sec="4Q249g f3_7">4Q249g f3_7</a></td><td class="tf">fragment f3_7</td></tr>
# <tr class="tf"><td class="tf">19</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q249h'" title="show this scroll in the Leon Levy library" sec="4Q249h f1_2">4Q249h f1_2</a></td><td class="tf">fragment f1_2</td></tr>
# <tr class="tf"><td class="tf">20</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q249i'" title="show this scroll in the Leon Levy library" sec="4Q249i f1">4Q249i f1</a></td><td class="tf">fragment f1</td></tr></table>

# %% [markdown]
# Same for scrolls:

# %%
results = A.search('''
scroll cert<50
''')
# Out:
#   0.00s 0 results

# %%
results = A.search('''
scroll cert<60
''')
# Out:
#   0.00s 27 results

# %%
A.show(results)
# Out:
# <p><b>result</b> <i>1</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='2Q18'" title="2Q18" sec="2Q18">scroll <span class="txtn">2Q18  <span class="scroll">2Q18</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>58</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>2</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q249b'" title="4Q249b" sec="4Q249b">scroll <span class="txtn">4Q249b  <span class="scroll">4Q249b</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>59</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>3</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q249c'" title="4Q249c" sec="4Q249c">scroll <span class="txtn">4Q249c  <span class="scroll">4Q249c</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>57</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>4</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q249d'" title="4Q249d" sec="4Q249d">scroll <span class="txtn">4Q249d  <span class="scroll">4Q249d</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>57</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>5</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q249f'" title="4Q249f" sec="4Q249f">scroll <span class="txtn">4Q249f  <span class="scroll">4Q249f</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>58</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>6</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q249g'" title="4Q249g" sec="4Q249g">scroll <span class="txtn">4Q249g  <span class="scroll">4Q249g</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>58</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>7</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q249h'" title="4Q249h" sec="4Q249h">scroll <span class="txtn">4Q249h  <span class="scroll">4Q249h</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>59</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>8</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q249j'" title="4Q249j" sec="4Q249j">scroll <span class="txtn">4Q249j  <span class="biblical">1</span> <span class="scroll">4Q249j</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>58</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>9</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q483'" title="4Q483" sec="4Q483">scroll <span class="txtn">4Q483  <span class="biblical">1</span> <span class="scroll">4Q483</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>58</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>10</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='2Q4'" title="2Q4" sec="2Q4">scroll <span class="txtn">2Q4  <span class="biblical">1</span> <span class="scroll">2Q4</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>58</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>11</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='2Q9'" title="2Q9" sec="2Q9">scroll <span class="txtn">2Q9  <span class="biblical">1</span> <span class="scroll">2Q9</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>59</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>12</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='2Q10'" title="2Q10" sec="2Q10">scroll <span class="txtn">2Q10  <span class="biblical">1</span> <span class="scroll">2Q10</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>59</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>13</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='2Q11'" title="2Q11" sec="2Q11">scroll <span class="txtn">2Q11  <span class="biblical">1</span> <span class="scroll">2Q11</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>58</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>14</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='3Q1'" title="3Q1" sec="3Q1">scroll <span class="txtn">3Q1  <span class="biblical">1</span> <span class="scroll">3Q1</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>59</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>15</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='3Q3'" title="3Q3" sec="3Q3">scroll <span class="txtn">3Q3  <span class="biblical">1</span> <span class="scroll">3Q3</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>58</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>16</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q8b'" title="4Q8b" sec="4Q8b">scroll <span class="txtn">4Q8b  <span class="biblical">1</span> <span class="scroll">4Q8b</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>59</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>17</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q69a'" title="4Q69a" sec="4Q69a">scroll <span class="txtn">4Q69a  <span class="biblical">1</span> <span class="scroll">4Q69a</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>59</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>18</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q71'" title="4Q71" sec="4Q71">scroll <span class="txtn">4Q71  <span class="biblical">1</span> <span class="scroll">4Q71</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>59</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>19</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q103a'" title="4Q103a" sec="4Q103a">scroll <span class="txtn">4Q103a  <span class="biblical">1</span> <span class="scroll">4Q103a</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>58</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>20</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q116'" title="4Q116" sec="4Q116">scroll <span class="txtn">4Q116  <span class="biblical">1</span> <span class="scroll">4Q116</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>58</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>21</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q151'" title="4Q151" sec="4Q151">scroll <span class="txtn">4Q151  <span class="biblical">1</span> <span class="scroll">4Q151</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>57</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>22</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q153'" title="4Q153" sec="4Q153">scroll <span class="txtn">4Q153  <span class="biblical">1</span> <span class="scroll">4Q153</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>57</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>23</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q483'" title="4Q483" sec="4Q483">scroll <span class="txtn">4Q483  <span class="biblical">1</span> <span class="scroll">4Q483</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>57</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>24</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q576'" title="4Q576" sec="4Q576">scroll <span class="txtn">4Q576  <span class="biblical">1</span> <span class="scroll">4Q576</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>56</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>25</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='5Q7'" title="5Q7" sec="5Q7">scroll <span class="txtn">5Q7  <span class="biblical">1</span> <span class="scroll">5Q7</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>58</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>26</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='8Q1'" title="8Q1" sec="8Q1">scroll <span class="txtn">8Q1  <span class="biblical">1</span> <span class="scroll">8Q1</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>58</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>27</i></p>
# <div class="contnr scroll " >
#
#     <div class="lbl scroll">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='11Q9'" title="11Q9" sec="11Q9">scroll <span class="txtn">11Q9  <span class="biblical">1</span> <span class="scroll">11Q9</span><div class="features"> <span class="cert xft"><span class="f">cert=</span>58</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>

# %% [markdown]
# Lines with certainty of 50:

# %%
results = A.search('''
line cert<57
''')
# Out:
#   0.06s 2061 results

# %%
A.show(results, start=100, end=102)
# Out:
# <p><b>result</b> <i>100</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q204'" title="4Q204 f5i:29" sec="4Q204 f5i:29">line <span class="txtn">29</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="line">29</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">מן </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">מִן</span> <span class="sp">ptcl</span> <span class="cl">prep</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">מ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ן </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ורד</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">וְרַד</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">m</span> <span class="nu">s</span> <span class="st">d</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ר</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ד</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">א </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">ָא</span> <span class="sp">ptcl</span> <span class="cl">art</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">א </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">וְ</span> <span class="sp">ptcl</span> <span class="cl">conj</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">כול </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">כֹּל</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">m</span> <span class="nu">s</span> <span class="st">c</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">כ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ל </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">שׁער׳ה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">שְׂעַר</span> <span class="sp">suff</span> <span class="cl">cmn</span> <span class="gn">m</span> <span class="nu">s</span> <span class="st">c</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">שׁ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ע</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ר</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
# <p><b>result</b> <i>101</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q204'" title="4Q204 f5i:30" sec="4Q204 f5i:30">line <span class="txtn">30</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="line">30</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">בית</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">בַּי</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">m</span> <span class="nu">s</span> <span class="st">d</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ב</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ת</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">א </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">ָא</span> <span class="sp">ptcl</span> <span class="cl">art</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">א </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">כ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">כְּ</span> <span class="sp">ptcl</span> <span class="cl">prep</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">כ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">שׁמשׁ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">שְׁמַשׁ</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">b</span> <span class="nu">s</span> <span class="st">d</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">שׁ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">מ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">שׁ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">א </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">ָא</span> <span class="sp">ptcl</span> <span class="cl">art</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">א </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ε </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex"> # </span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ε </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">׃ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">׃ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>102</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q204'" title="4Q204 f5ii:16" sec="4Q204 f5ii:16">line <span class="txtn">16</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="line">16</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ε </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex"> # </span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ε </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ב</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">בְּ</span> <span class="sp">ptcl</span> <span class="cl">prep</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ב</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">אדין </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">אֱדַיִן</span> <span class="sp">ptcl</span> <span class="cl">advb</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">א</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ד</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ן </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ענית </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">ענה</span> <span class="sp">verb</span> <span class="ps">1</span> <span class="gn">c</span> <span class="nu">s</span> <span class="vs">peal</span> <span class="vt">perf</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ע</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">נ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ת </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">אנה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">אֲנָה</span> <span class="sp">pron</span> <span class="cl">indp</span> <span class="ps">1</span> <span class="gn">c</span> <span class="nu">s</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">א</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">נ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">חנוך </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">חֲנֹוךְ</span> <span class="sp">subs</span> <span class="cl">prp</span> <spa

# %% [markdown]
# With highlights:

# %%
highlights = {}

for s in F.otype.s('sign'):
  if not F.cert.v(s):
    continue
  color = 'lightsalmon' if F.cert.v(s) < 56 else 'mediumaquamarine'
  highlights[s] = color

# %%
A.show(results, start=100, end=102, condensed=True, highlights=highlights)
# Out:
# <p><b>line</b> <i>100</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q204'" title="4Q204 f5i:29" sec="4Q204 f5i:29">line <span class="txtn">29</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="line">29</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">מן </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">מִן</span> <span class="sp">ptcl</span> <span class="cl">prep</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">מ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">ן </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ורד</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">וְרַד</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">m</span> <span class="nu">s</span> <span class="st">d</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">ר</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">ד</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">א </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">ָא</span> <span class="sp">ptcl</span> <span class="cl">art</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">א </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">וְ</span> <span class="sp">ptcl</span> <span class="cl">conj</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">כול </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">כֹּל</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">m</span> <span class="nu">s</span> <span class="st">c</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">כ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">ל </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">שׁער׳ה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">שְׂעַר</span> <span class="sp">suff</span> <span class="cl">cmn</span> <span class="gn">m</span> <span class="nu">s</span> <span class="st">c</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">שׁ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">ע</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>
# <p><b>line</b> <i>101</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q204'" title="4Q204 f5i:30" sec="4Q204 f5i:30">line <span class="txtn">30</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="line">30</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">בית</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">בַּי</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">m</span> <span class="nu">s</span> <span class="st">d</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">ב</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">ת</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">א </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">ָא</span> <span class="sp">ptcl</span> <span class="cl">art</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">א </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">כ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">כְּ</span> <span class="sp">ptcl</span> <span class="cl">prep</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">כ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">שׁמשׁ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">שְׁמַשׁ</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">b</span> <span class="nu">s</span> <span class="st">d</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">שׁ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">מ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">שׁ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">א </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">ָא</span> <span class="sp">ptcl</span> <span class="cl">art</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">א </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ε </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex"> # </span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ε </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">׃ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">׃ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>line</b> <i>102</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q204'" title="4Q204 f5ii:16" sec="4Q204 f5ii:16">line <span class="txtn">16</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="line">16</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ε </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex"> # </span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ε </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ב</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">בְּ</span> <span class="sp">ptcl</span> <span class="cl">prep</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">ב</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">אדין </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">אֱדַיִן</span> <span class="sp">ptcl</span> <span class="cl">advb</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">א</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">ד</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">ן </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ענית </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">ענה</span> <span class="sp">verb</span> <span class="ps">1</span> <span class="gn">c</span> <span class="nu">s</span> <span class="vs">peal</span> <span class="vt">perf</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">ע</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">נ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">ת </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">אנה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang">a</span> <span class="lex">אֲנָה</span> <span class="sp">pron</span> <span class="cl">indp</span> <span class="ps">1</span> <span class="gn">c</span> <span class="nu">s</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">א</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">נ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lang"><span class="f">lang=</span>a</span> <span class="rec"><span class="f">rec=</span>1</span> <span class="cert xft"><span class="f">cert=</span>55</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtu">ה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="l

# %% [markdown]
# # All together!
#
# If more researchers have shared data modules, you can draw them all in.
#
# Then you can design queries that use features from all these different sources.
#
# In that way, you build your own research on top of the work of others.

# %% [markdown]
# Hover over the features to see where they come from, and you'll see they come from your local github repo.

# %% [markdown]
# ---
#
# All chapters:
#
# * **[start](start.ipynb)** become an expert in creating pretty displays of your text structures
# * **[display](display.ipynb)** become an expert in creating pretty displays of your text structures
# * **[search](search.ipynb)** turbo charge your hand-coding with search templates
# * **[exportExcel](exportExcel.ipynb)** make tailor-made spreadsheets out of your results
# * **share** draw in other people's data and let them use yours
# * **[similarLines](similarLines.ipynb)** spot the similarities between lines
#
# ---
#
# See the [cookbook](cookbook) for recipes for small, concrete tasks.
