# %% [markdown]
# <img align="right" src="images/tf.png" width="128"/>
# <img align="right" src="images/logo.png" width="128"/>
# <img align="right" src="images/etcbc.png" width="128"/>
# <img align="right" src="images/dans.png" width="128"/>
#
# ---
#
# To get started: consult [start](start.ipynb)
#
# ---
#
# # Search Introduction
#
# *Search* in Text-Fabric is a template based way of looking for structural patterns in your dataset.
#
# It is inspired by the idea of
# [topographic query](http://books.google.nl/books?id=9ggOBRz1dO4C).
#
# Within Text-Fabric we have the unique possibility to combine the ease of formulating search templates for
# complicated patterns with the power of programmatically processing the results.
#
# This notebook will show you how to get up and running.
#
# ## Alternative for hand-coding
#
# Search is a powerful feature for a wide range of purposes.
#
# Quite a bit of the implementation work has been dedicated to optimize performance.
# Yet I do not pretend to have found optimal strategies for all
# possible search templates.
# Some search tasks may turn out to be somewhat costly or even very costly.
#
# That being said, I think search might turn out helpful in many cases,
# especially by reducing the amount of hand-coding needed to work with special subsets of your data.
#
# ## Easy command
#
# Search is as simple as saying (just an example)
#
# ```python
# results = A.search(template)
# A.show(results)
# ```
#
# See all ins and outs in the
# [search template docs](https://annotation.github.io/text-fabric/Use/Search/#search-templates).

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use

# %%
A = use('dss:hot', hoist=globals())
# Out:
# 	connecting to online GitHub repo annotation/app-dss ... connected
# 	code/app.py...downloaded
# 	code/config.py...downloaded
# 	code/static...directory
# 		code/static/display.css...downloaded
# 		code/static/logo.png...downloaded
# 	OK
# Using TF-app in /Users/dirk/text-fabric-data/annotation/app-dss/code:
# 	#fa0361f04d87c2314095bdefc4a66645d6e008e8 (latest commit)
# 	connecting to online GitHub repo etcbc/dss ... connected
# Using data in /Users/dirk/text-fabric-data/etcbc/dss/tf/0.3:
# 	#62c1b150a7265916e48727b2286f192443d968fc (latest commit)
# <b>Documentation:</b> <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs/" title="provenance of Dead Sea Scrolls">DSS</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Writing/Hebrew.html" title="Hebrew characters and transcriptions">Character table</a> <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="DSS feature documentation">Feature docs</a> <a target="_blank" href="https://github.com/annotation/app-dss" title="dss API documentation">dss API</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/" title="text-fabric-api">Text-Fabric API 7.7.0</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Use/Search/" title="Search Templates Introduction and Reference">Search Reference</a><details open><summary><b>Loaded features</b>:</summary>
# <p><b>Dead Sea Scrolls</b>: <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/after.tf">after</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/alt.tf">alt</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/biblical.tf">biblical</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/book.tf">book</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/chapter.tf">chapter</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/cl.tf">cl</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/cl2.tf">cl2</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/cor.tf">cor</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/fragment.tf">fragment</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/full.tf">full</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/fulle.tf">fulle</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/fullo.tf">fullo</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/glex.tf">glex</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/glexe.tf">glexe</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/glexo.tf">glexo</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/glyph.tf">glyph</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/glyphe.tf">glyphe</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/glypho.tf">glypho</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/gn.tf">gn</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/gn2.tf">gn2</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/gn3.tf">gn3</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/halfverse.tf">halfverse</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/intl.tf">intl</a>  <a target="_blank" href="https://github.com/etcbc/dss/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/etcbc/dss/tf/0.3/lang.tf">lang</a>  <a target="_blank" href="https://github.com/etcbc/ ...
# <style>
# @font-face {
#   font-family: "Ezra SIL";
#   src:
#     local("SILEOT.ttf"),
#     url("https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true");
# }
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: normal;
#     text-decoration: none;
#     direction: ltr;
# }
# .txte,.txte a:visited,.txte a:link {
#     font-family: monospace;
#     font-size: normal;
#     text-decoration: none;
#     direction: ltr;
# }
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: large;
#     text-decoration: none;
#     direction: ltr;
# }
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: x-large;
#     text-decoration: none;
#     direction: rtl;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .meta {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: row nowrap;
# }
# .features {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .children {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     border: 0;
#     background-color: #ffffff;
# }
# .children.scroll {
#     flex-flow: column nowrap;
# }
# .children.fragment {
#     flex-flow: column nowrap;
# }
# .children.line {
#     align-items: stretch;
#     flex-flow: row wrap;
# }
# .children.cluster {
#     flex-flow: row wrap;
# }
# .children.word {
#     align-items: stretch;
#     flex-flow: row nowrap;
# }
# .children.sign {
#     flex-flow: column nowrap;
# }
# .contnr {
#     width: fit-content;
#     direction: rtl;
# }
# .contnr.scroll,.contnr.fragment,
# .contnr.line,
# .contnr.cluster,
# .contnr.word,
# .contnr.sign {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5em 0.1em 0.1em 0.1em;
#     margin: 0.8em 0.1em 0.1em 0.1em;
#     border-radius: 0.2em;
#     border-style: solid;
#     border-width: 0.2em;
#     font-size: small;
# }
# .contnr.scroll,.contnr.fragment {
#     border-color: #bb8800;
# }
# .contnr.line {
#     border-color: #0088bb;
# }
# .contnr.cluster {
#     flex-flow: row wrap;
#     border: 0;
# }
# .contnr.word {
#     border-color: #44bbff;
# }
# .contnr.sign {
#     border-color: #bbbbbb;
# }
# .contnr.hl {
#     background-color: #ffee66;
# }
# .lbl.scroll,.lbl.fragment,
# .lbl.line,
# .lbl.cluster,
# .lbl.sign,.lbl.word {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     font-size: small;
#     display: block;
# }
# .lbl.scroll,.lbl.fragment {
#     border-color: #bb8800;
#     border-width: 0.3em;
#     border-radius: 0.3em;
#     color: #bb8800;
# }
# .lbl.line {
#     border-color: #0088bb;
#     border-width: 0.3em;
#     border-radius: 0.3em;
#     color: #0088bb;
# }
# .lbl.cluster {
#     border-color: #dddddd;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     color: #0000cc;
# }
# .lbl.word {
#     border-color: #44bbff;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     font-size: medium;
#     color: #000000;
# }
# .lbl.sign {
#     border-color: #bbbbbb;
#     border-width: 0.1em;
#     border-radius: 0.1em;
#     font-size: small;
#     color: #000000;
# }
# .name {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .text {
#     font-family: sans-serif;
#     font-size: x-small;
#     color: #000000;
# }
# .srcln {
#     font-family: monospace;
#     font-size: x-small;
#     color: #0000bb;
# }
# .scriptpaleohebrew {
#     border: 1px dashed navy;
# }
# .scriptgreekcapital {
#     border: 1px dashed brown;
# }
# .langa {
#     text-decoration: underline;
# }
# .intl1 {
#     vertical-align: -0.25em;
# }
# .intl2 {
#     vertical-align: -0.5em;
# }
# .langg {
#     font-family: serif;
#     text-decoration: underline;
# }
# .vac1 {
#     background-color: #aaaaaa;
#     border 2pt solid #dd3333;
#     border-radius: 4pt;
# }
# .rem1 {
#     font-weight: bold;
#     color: red;
#     text-decoration: line-through;
# }
# .rem2 {
#     font-weight: bold;
#     color: maroon;
#     text-decoration: line-through;
# }
# .rec1 {
#     color: teal;
#     font-size: 80%;
# }
# .cor1 {
#     font-weight: bold;
#     color: dodgerblue;
#     text-decoration: overline;
# }
# .cor2 {
#     font-weight: bold;
#     color: navy;
#     text-decoration: overline;
# }
# .cor3 {
#     font-weight: bold;
#     color: navy;
#     text-decoration: overline;
#     vertical-align: super;
# }
# .alt1 {
#     text-decoration: overline;
# }
#
# /* UNSURE: italic*/
#
# .unc1 {
#     font-weight: bold;
#     color: #888888;
# }
# .unc2 {
#     font-weight: bold;
#     color: #bbbbbb;
# }
# .unc3 {
#     font-weight: bold;
#     color: #bbbbbb;
#     text-shadow: #cccccc 1px 1px;
# }
# .unc4 {
#     font-weight: bold;
#     color: #dddddd;
#     text-shadow: #eeeeee 2px 2px;
# }
#
# /* cluster */
# .empty {
#   color: #ff0000;
# }
#
#
# tr.tf, td.tf, th.tf {
#   text-align: left;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlup {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>
# <details open><summary><b>API members</b>:</summary>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">C Computed</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Call AllComputeds</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Cs ComputedString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">E Edge</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Eall AllEdges</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Es EdgeString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ensureLoaded</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">TF</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ignored</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">loadLog</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Locality/#locality" title="doc">L Locality</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">cache</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">error</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">indent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">info</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">reset</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">N Nodes</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKey</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKeyTuple</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">otypeRank</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortNodes</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">F Feature</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fall AllFeatures</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fs FeatureString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Search/#search" title="doc">S Search</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Text/#text" title="doc">T Text</a></details>

# %% [markdown]
# # Basic search command
#
# We start with the most simple form of issuing a query.
#
# Let's look for the verbs in the `hitpael` with an uncertain character in it.
#
# All work involved in searching takes place under the hood.

# %%
query = '''
word vs=hitpael
  sign unc
'''
results = A.search(query)
A.table(results, end=10)
# Out:
#   1.39s 399 results
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">word</th><th>sign</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 12:23">CD 12:23</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 12:23" sec="CD 12:23"><span class="txtu"><span  class="hl hlup" >מ</span><span  class="hlup" >ת</span><span  class="hlup" >ה</span><span  class="hlup" >ל</span><span  class="hlup" >כ</span><span  class="hlup" >י</span><span  class="hlup" >ם </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl hlup" >מ</span></span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 12:23">CD 12:23</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 12:23" sec="CD 12:23"><span class="txtu"><span  class="hlup" >מ</span><span  class="hlup" >ת</span><span  class="hlup" >ה</span><span  class="hlup" >ל</span><span  class="hl hlup" >כ</span><span  class="hlup" >י</span><span  class="hlup" >ם </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl hlup" >כ</span></span></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 12:23">CD 12:23</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 12:23" sec="CD 12:23"><span class="txtu"><span  class="hlup" >מ</span><span  class="hlup" >ת</span><span  class="hlup" >ה</span><span  class="hlup" >ל</span><span  class="hlup" >כ</span><span  class="hl hlup" >י</span><span  class="hlup" >ם </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl hlup" >י</span></span></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 12:23">CD 12:23</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 12:23" sec="CD 12:23"><span class="txtu"><span  class="hlup" >מ</span><span  class="hlup" >ת</span><span  class="hlup" >ה</span><span  class="hlup" >ל</span><span  class="hlup" >כ</span><span  class="hlup" >י</span><span  class="hl hlup" >ם </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl hlup" >ם </span></span></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 15:11">CD 15:11</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 15:11" sec="CD 15:11"><span class="txtu"><span  class="hlup" >י</span><span  class="hlup" >ת</span><span  class="hlup" >פ</span><span  class="hl hlup" >ת</span><span  class="hlup" >ה </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl hlup" >ת</span></span></td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 19:4">CD 19:4</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 19:4" sec="CD 19:4"><span class="txtu"><span  class="hl hlup" >י</span><span  class="hlup" >ת</span><span  class="hlup" >ה</span><span  class="hlup" >ל</span><span  class="hlup" >כ</span><span  class="hlup" >ו </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl hlup" >י</span></span></td></tr>
# <tr class="tf"><td class="tf">7</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QS'" title="show this scroll in the Leon Levy library" sec="1QS 7:24">1QS 7:24</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QS'" title="1QS 7:24" sec="1QS 7:24"><span class="txtu"><span  class="hl hlup" >י</span><span  class="hlup" >ת</span><span  class="hlup" >ע</span><span  class="hlup" >ר</span><span  class="hlup" >ב </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl hlup" >י</span></span></td></tr>
# <tr class="tf"><td class="tf">8</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QS'" title="show this scroll in the Leon Levy library" sec="1QS 7:24">1QS 7:24</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QS'" title="1QS 7:24" sec="1QS 7:24"><span class="txtu"><span  class="hlup" >י</span><span  class="hl hlup" >ת</span><span  class="hlup" >ע</span><span  class="hlup" >ר</span><span  class="hlup" >ב </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl hlup" >ת</span></span></td></tr>
# <tr class="tf"><td class="tf">9</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QSa'" title="show this scroll in the Leon Levy library" sec="1QSa 1:11">1QSa 1:11</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QSa'" title="1QSa 1:11" sec="1QSa 1:11"><span class="txtu"><span  class="hlup" >ה</span><span  class="hl hlup" >ת</span><span  class="hlup" >י</span><span  class="hlup" >צ</span><span  class="hlup" >ב </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl hlup" >ת</span></span></td></tr>
# <tr class="tf"><td class="tf">10</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QSb'" title="show this scroll in the Leon Levy library" sec="1QSb 4:2">1QSb 4:2</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QSb'" title="1QSb 4:2" sec="1QSb 4:2"><span class="txtu"><span  class="hl hlup" >ה</span><span  class="hlup" >ת</span><span  class="hlup" >ע</span><span  class="hlup" >ר</span><span  class="hlup" >ב </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl hlup" >ה</span></span></td></tr></table>

# %% [markdown]
# We have multiple uncertain signs per word,
# and for each sign we see the whole word repeated.
#
# We can condense our results to words:

# %%
A.table(results, end=10, condensed=True, condenseType='word')
# Out:
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">word</th><th>sign</th><th>sign</th><th>sign</th><th>sign</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 12:23">CD 12:23</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 12:23" sec="CD 12:23"><span class="txtu"><span  class="hl" >מ</span>תהל<span  class="hl" >כ</span><span  class="hl" >י</span><span  class="hl" >ם </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl" >כ</span></span></td><td class="tf"><span class="txtu"><span  class="hl" >י</span></span></td><td class="tf"><span class="txtu"><span  class="hl" >ם </span></span></td><td class="tf"><span class="txtu"><span  class="hl" >מ</span></span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 15:11">CD 15:11</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 15:11" sec="CD 15:11"><span class="txtu">יתפ<span  class="hl" >ת</span>ה </span></a></td><td class="tf"><span class="txtu"><span  class="hl" >ת</span></span></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 19:4">CD 19:4</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 19:4" sec="CD 19:4"><span class="txtu"><span  class="hl" >י</span>תהלכו </span></a></td><td class="tf"><span class="txtu"><span  class="hl" >י</span></span></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QS'" title="show this scroll in the Leon Levy library" sec="1QS 7:24">1QS 7:24</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QS'" title="1QS 7:24" sec="1QS 7:24"><span class="txtu"><span  class="hl" >י</span><span  class="hl" >ת</span>ערב </span></a></td><td class="tf"><span class="txtu"><span  class="hl" >י</span></span></td><td class="tf"><span class="txtu"><span  class="hl" >ת</span></span></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QSa'" title="show this scroll in the Leon Levy library" sec="1QSa 1:11">1QSa 1:11</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QSa'" title="1QSa 1:11" sec="1QSa 1:11"><span class="txtu">ה<span  class="hl" >ת</span>יצב </span></a></td><td class="tf"><span class="txtu"><span  class="hl" >ת</span></span></td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QSb'" title="show this scroll in the Leon Levy library" sec="1QSb 4:2">1QSb 4:2</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QSb'" title="1QSb 4:2" sec="1QSb 4:2"><span class="txtu"><span  class="hl" >ה</span>תערב </span></a></td><td class="tf"><span class="txtu"><span  class="hl" >ה</span></span></td></tr>
# <tr class="tf"><td class="tf">7</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QM'" title="show this scroll in the Leon Levy library" sec="1QM 13:12">1QM 13:12</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QM'" title="1QM 13:12" sec="1QM 13:12"><span class="txtu">יתהלכ<span  class="hl" >ו </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl" >ו </span></span></td></tr>
# <tr class="tf"><td class="tf">8</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QM'" title="show this scroll in the Leon Levy library" sec="1QM 15:15">1QM 15:15</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QM'" title="1QM 15:15" sec="1QM 15:15"><span class="txtu">מתע<span  class="hl" >ת</span>דים </span></a></td><td class="tf"><span class="txtu"><span  class="hl" >ת</span></span></td></tr>
# <tr class="tf"><td class="tf">9</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QM'" title="show this scroll in the Leon Levy library" sec="1QM 16:6">1QM 16:6</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QM'" title="1QM 16:6" sec="1QM 16:6"><span class="txtu">התק<span  class="hl" >ר</span>ב </span></a></td><td class="tf"><span class="txtu"><span  class="hl" >ר</span></span></td></tr>
# <tr class="tf"><td class="tf">10</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QM'" title="show this scroll in the Leon Levy library" sec="1QM 16:13">1QM 16:13</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QM'" title="1QM 16:13" sec="1QM 16:13"><span class="txtu">מתקרב<span  class="hl" >י</span>ם </span></a></td><td class="tf"><span class="txtu"><span  class="hl" >י</span></span></td></tr></table>

# %% [markdown]
# We can show them in rich layout as well:

# %%
A.table(results, end=10, condensed=True, condenseType='word', fmt='layout-orig-full')
# Out:
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">word</th><th>sign</th><th>sign</th><th>sign</th><th>sign</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 12:23">CD 12:23</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 12:23" sec="CD 12:23"><span class="txtu"><span  class="hl" ><span class="unc2">מ</span></span>תהל<span  class="hl" ><span class="unc2">כ</span></span><span  class="hl" ><span class="unc1">י</span></span><span  class="hl" ><span class="unc2">ם</span> </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc2">כ</span></span></span></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc1">י</span></span></span></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc2">ם</span> </span></span></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc2">מ</span></span></span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 15:11">CD 15:11</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 15:11" sec="CD 15:11"><span class="txtu">יתפ<span  class="hl" ><span class="unc2">ת</span></span>ה </span></a></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc2">ת</span></span></span></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="show this scroll in the Leon Levy library" sec="CD 19:4">CD 19:4</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 19:4" sec="CD 19:4"><span class="txtu"><span  class="hl" ><span class="unc1">י</span></span>תהלכו </span></a></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc1">י</span></span></span></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QS'" title="show this scroll in the Leon Levy library" sec="1QS 7:24">1QS 7:24</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QS'" title="1QS 7:24" sec="1QS 7:24"><span class="txtu"><span  class="hl" ><span class="unc1">י</span></span><span  class="hl" ><span class="unc2">ת</span></span>ערב </span></a></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc1">י</span></span></span></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc2">ת</span></span></span></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QSa'" title="show this scroll in the Leon Levy library" sec="1QSa 1:11">1QSa 1:11</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QSa'" title="1QSa 1:11" sec="1QSa 1:11"><span class="txtu">ה<span  class="hl" ><span class="unc2">ת</span></span><span class="rec1">י</span>צב </span></a></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc2">ת</span></span></span></td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QSb'" title="show this scroll in the Leon Levy library" sec="1QSb 4:2">1QSb 4:2</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QSb'" title="1QSb 4:2" sec="1QSb 4:2"><span class="txtu"><span  class="hl" ><span class="unc4">ה</span></span>תערב </span></a></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc4">ה</span></span></span></td></tr>
# <tr class="tf"><td class="tf">7</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QM'" title="show this scroll in the Leon Levy library" sec="1QM 13:12">1QM 13:12</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QM'" title="1QM 13:12" sec="1QM 13:12"><span class="txtu">יתהלכ<span  class="hl" ><span class="unc1">ו</span> </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc1">ו</span> </span></span></td></tr>
# <tr class="tf"><td class="tf">8</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QM'" title="show this scroll in the Leon Levy library" sec="1QM 15:15">1QM 15:15</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QM'" title="1QM 15:15" sec="1QM 15:15"><span class="txtu"><span class="rec1">מ</span><span class="rec1">ת</span><span class="rec1">ע</span><span  class="hl" ><span class="unc4">ת</span></span>דים </span></a></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc4">ת</span></span></span></td></tr>
# <tr class="tf"><td class="tf">9</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QM'" title="show this scroll in the Leon Levy library" sec="1QM 16:6">1QM 16:6</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QM'" title="1QM 16:6" sec="1QM 16:6"><span class="txtu"><span class="rec1">ה</span><span class="rec1">ת</span><span class="rec1">ק</span><span  class="hl" ><span class="unc4">ר</span></span>ב </span></a></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc4">ר</span></span></span></td></tr>
# <tr class="tf"><td class="tf">10</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QM'" title="show this scroll in the Leon Levy library" sec="1QM 16:13">1QM 16:13</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1QM'" title="1QM 16:13" sec="1QM 16:13"><span class="txtu">מתקרב<span  class="hl" ><span class="unc3">י</span></span><span class="rec1">ם</span> </span></a></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc3">י</span></span></span></td></tr></table>

# %% [markdown]
# Note that we can choose start and/or end points in the results list.

# %%
A.table(results, start=100, end=110, condensed=True, condenseType='word', fmt='layout-orig-full')
# Out:
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">word</th><th>sign</th><th>sign</th>
# </tr>
#
# <tr class="tf"><td class="tf">100</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q405'" title="show this scroll in the Leon Levy library" sec="4Q405 f23i:11">4Q405 f23i:11</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q405'" title="4Q405 f23i:11" sec="4Q405 f23i:11"><span class="txtu"><span  class="hl" ><span class="unc3">י</span></span>תכ<span  class="hl" ><span class="unc1">ו</span></span>נו </span></a></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc1">ו</span></span></span></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc3">י</span></span></span></td></tr>
# <tr class="tf"><td class="tf">101</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q405'" title="show this scroll in the Leon Levy library" sec="4Q405 f25:3">4Q405 f25:3</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q405'" title="4Q405 f25:3" sec="4Q405 f25:3"><span class="txtu"><span  class="hl" ><span class="unc4">מ</span></span><span  class="hl" ><span class="unc4">ת</span></span><span  class="hl" ><span class="unc4">ה</span></span>ל<span  class="hl" ><span class="unc4">כ</span></span>י<span  class="hl" ><span class="unc2">ם</span> </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc4">מ</span></span></span></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc4">ת</span></span></span></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc4">ה</span></span></span></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc4">כ</span></span></span></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc2">ם</span> </span></span></td></tr>
# <tr class="tf"><td class="tf">102</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q415'" title="show this scroll in the Leon Levy library" sec="4Q415 f12:4">4Q415 f12:4</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q415'" title="4Q415 f12:4" sec="4Q415 f12:4"><span class="txtu">הת<span  class="hl" ><span class="unc4">שׁ</span></span><span class="cor3">שׁ</span><span  class="hl" ><span class="unc1">ו</span></span> #  </span></a></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc4">שׁ</span></span></span></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc1">ו</span></span></span></td></tr>
# <tr class="tf"><td class="tf">103</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q417'" title="show this scroll in the Leon Levy library" sec="4Q417 f1i:12">4Q417 f1i:12</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q417'" title="4Q417 f1i:12" sec="4Q417 f1i:12"><span class="txtu">התהלכ׳<span  class="hl" ><span class="unc1">ו</span> </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc1">ו</span> </span></span></td></tr>
# <tr class="tf"><td class="tf">104</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q417'" title="show this scroll in the Leon Levy library" sec="4Q417 f1i:23">4Q417 f1i:23</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q417'" title="4Q417 f1i:23" sec="4Q417 f1i:23"><span class="txtu"><span  class="hl" ><span class="unc4">ת</span></span><span class="rec1">ת</span><span  class="hl" ><span class="unc4">ח</span></span><span  class="hl" ><span class="unc3">ז</span></span>ק </span></a></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc4">ח</span></span></span></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc3">ז</span></span></span></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc4">ת</span></span></span></td></tr>
# <tr class="tf"><td class="tf">105</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q417'" title="show this scroll in the Leon Levy library" sec="4Q417 f2i:8">4Q417 f2i:8</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q417'" title="4Q417 f2i:8" sec="4Q417 f2i:8"><span class="txtu">ת<span  class="hl" ><span class="unc4">ת</span></span><span  class="hl" ><span class="unc4">ה</span></span>לך </span></a></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc4">ת</span></span></span></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc4">ה</span></span></span></td></tr>
# <tr class="tf"><td class="tf">106</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q417'" title="show this scroll in the Leon Levy library" sec="4Q417 f19:4">4Q417 f19:4</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q417'" title="4Q417 f19:4" sec="4Q417 f19:4"><span class="txtu"><span  class="hl" ><span class="unc1">י</span></span><span  class="hl" ><span class="unc2">ת</span></span><span  class="hl" ><span class="unc2">ה</span></span>ל<span  class="hl" ><span class="unc4">ך</span> </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc4">ך</span> </span></span></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc1">י</span></span></span></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc2">ת</span></span></span></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc2">ה</span></span></span></td></tr>
# <tr class="tf"><td class="tf">107</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q418'" title="show this scroll in the Leon Levy library" sec="4Q418 f2+2a_c:4">4Q418 f2+2a_c:4</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q418'" title="4Q418 f2+2a_c:4" sec="4Q418 f2+2a_c:4"><span class="txtu">ית<span  class="hl" ><span class="unc4">ר</span> </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc4">ר</span> </span></span></td></tr>
# <tr class="tf"><td class="tf">108</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q418'" title="show this scroll in the Leon Levy library" sec="4Q418 f9+9a_c:9">4Q418 f9+9a_c:9</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q418'" title="4Q418 f9+9a_c:9" sec="4Q418 f9+9a_c:9"><span class="txtu"><span  class="hl" ><span class="unc2">ת</span></span><span  class="hl" ><span class="unc2">ת</span></span>ה<span  class="hl" ><span class="unc2">ל</span></span><span  class="hl" ><span class="unc2">ך</span> </span></span></a></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc2">ת</span></span></span></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc2">ל</span></span></span></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc2">ך</span> </span></span></td><td class="tf"><span class="txtu"><span  class="hl" ><span class="unc2">ת</span></span></span></td></tr>
# <tr class="tf"><td class="tf">109</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q418'" title="show this scroll in the Leon Levy library" sec="4Q418 f9+9a_c:10">4Q418 f9+9a_c:10</a></td><td class="tf"><a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='4Q418'" title="4Q418 f9+9a_c:10" sec="4Q418 f9+9a_c:10"><span class="txtu"><span  class="hl" ><span class="unc4 rem2">ת</span></span><span  class="hl" ><span class="unc4 rem2">

# %% [markdown]
# We can show the results more fully with `show()`.

# %%
A.show(results, fmt='layout-orig-full', start=1, end=3)
# Out:
# <p><b>result</b> <i>1</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 12:23" sec="CD 12:23">line <span class="txtn">23</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="line">23</span></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="unc4">ה</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">הַ</span> <span class="sp">ptcl</span> <span class="cl">art</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc4">ה</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>4</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">מ<span class="unc4">ח</span><span class="rec1">נ</span><span class="rec1">ו</span><span class="unc4">ת</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">מַחֲנֶה</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">b</span> <span class="nu">p</span> <span class="st">a</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">מ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc4">ח</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>4</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">נ</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ו</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc4">ת</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>4</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="unc4">ה</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">הַ</span> <span class="sp">ptcl</span> <span class="cl">art</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc4">ה</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>4</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word hl" >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="unc2">מ</span>תהל<span class="unc2">כ</span><span class="unc1">י</span><span class="unc2">ם</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">הלך</span> <span class="sp">verb</span> <span class="gn">m</span> <span class="nu">p</span> <span class="st">a</span> <span class="vs">hitpael</span> <span class="vt">ptca</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl" >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc2">מ</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ת</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ל</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc2">כ</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc1">י</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc2">ם</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="unc2">ב</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">בְּ</span> <span class="sp">ptcl</span> <span class="cl">prep</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc2">ב</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="unc2">א</span>לה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">אֵלֶּה</span> <span class="sp">adjv</span> <span class="gn">b</span> <span class="nu">p</span> <span class="st">a</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc2">א</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ל</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ב</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">בְּ</span> <span class="sp">ptcl</span> <span class="cl">prep</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ב</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
# <p><b>result</b> <i>2</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 12:23" sec="CD 12:23">line <span class="txtn">23</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="line">23</span></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="unc4">ה</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">הַ</span> <span class="sp">ptcl</span> <span class="cl">art</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc4">ה</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>4</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">מ<span class="unc4">ח</span><span class="rec1">נ</span><span class="rec1">ו</span><span class="unc4">ת</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">מַחֲנֶה</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">b</span> <span class="nu">p</span> <span class="st">a</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">מ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc4">ח</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>4</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">נ</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ו</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc4">ת</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>4</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="unc4">ה</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">הַ</span> <span class="sp">ptcl</span> <span class="cl">art</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc4">ה</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>4</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word hl" >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="unc2">מ</span>תהל<span class="unc2">כ</span><span class="unc1">י</span><span class="unc2">ם</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">הלך</span> <span class="sp">verb</span> <span class="gn">m</span> <span class="nu">p</span> <span class="st">a</span> <span class="vs">hitpael</span> <span class="vt">ptca</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc2">מ</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ת</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ל</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl" >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc2">כ</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc1">י</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc2">ם</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="unc2">ב</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">בְּ</span> <span class="sp">ptcl</span> <span class="cl">prep</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc2">ב</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="unc2">א</span>לה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">אֵלֶּה</span> <span class="sp">adjv</span> <span class="gn">b</span> <span class="nu">p</span> <span class="st">a</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc2">א</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ל</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ב</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">בְּ</span> <span class="sp">ptcl</span> <span class="cl">prep</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ב</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
# <p><b>result</b> <i>3</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="CD 12:23" sec="CD 12:23">line <span class="txtn">23</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="line">23</span></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="unc4">ה</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">הַ</span> <span class="sp">ptcl</span> <span class="cl">art</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc4">ה</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>4</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">מ<span class="unc4">ח</span><span class="rec1">נ</span><span class="rec1">ו</span><span class="unc4">ת</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">מַחֲנֶה</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">b</span> <span class="nu">p</span> <span class="st">a</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">מ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc4">ח</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>4</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">נ</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="rec1">ו</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc4">ת</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>4</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="unc4">ה</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">הַ</span> <span class="sp">ptcl</span> <span class="cl">art</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc4">ה</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>4</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word hl" >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="unc2">מ</span>תהל<span class="unc2">כ</span><span class="unc1">י</span><span class="unc2">ם</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">הלך</span> <span class="sp">verb</span> <span class="gn">m</span> <span class="nu">p</span> <span class="st">a</span> <span class="vs">hitpael</span> <span class="vt">ptca</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc2">מ</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ת</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ל</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc2">כ</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl" >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc1">י</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc2">ם</span> </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="unc2">ב</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">בְּ</span> <span class="sp">ptcl</span> <span class="cl">prep</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc2">ב</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu"><span class="unc2">א</span>לה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">אֵלֶּה</span> <span class="sp">adjv</span> <span class="gn">b</span> <span class="nu">p</span> <span class="st">a</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu"><span class="unc2">א</span></span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ל</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ב</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="lex">בְּ</span> <span class="sp">ptcl</span> <span class="cl">prep</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ב</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>

# %% [markdown]
# # Condense results
#
# There are two fundamentally different ways of presenting the results: condensed and uncondensed.
#
# In **uncondensed** view, all results are listed individually.
# You can keep track of which parts belong to which results.
# The display can become unwieldy.
#
# This is the default view, because it is the straightest, most logical, answer to your query.
#
# In **condensed** view all nodes of all results are grouped in containers first (e.g. lines), and then presented
# container by container.
# You loose the information of what parts belong to what result.
#
# As an example of the difference, we look for all proper nouns.

# %%
query = '''
line scroll=1Q1
  word sp=subs cl=prp
'''

# %% [markdown]
# Note that you can have comments in a search template. Comment lines start with a `%`.

# %%
results = A.search(query)
A.table(results, end=100)
# Out:
#   0.55s 20 results
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">line</th><th>word</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="show this scroll in the Leon Levy library" sec="1Q1 f2:3">1Q1 f2:3</a></td><td class="tf"><span class="txtu"><span  class="hl" >יהוה </span>אלהים לאשׁה מה זאת עשׁית ותאמר האשׁה הנחשׁ השׁיא׳ני ואכל ׃ ויאמר יהוה </span></td><td class="tf"><span class="txtu"><span  class="hlup" >י</span><span  class="hlup" >ה</span><span  class="hlup" >ו</span><span  class="hlup" >ה </span></span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="show this scroll in the Leon Levy library" sec="1Q1 f2:3">1Q1 f2:3</a></td><td class="tf"><span class="txtu">יהוה אלהים לאשׁה מה זאת עשׁית ותאמר האשׁה הנחשׁ השׁיא׳ני ואכל ׃ ויאמר <span  class="hl" >יהוה </span></span></td><td class="tf"><span class="txtu"><span  class="hlup" >י</span><span  class="hlup" >ה</span><span  class="hlup" >ו</span><span  class="hlup" >ה </span></span></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="show this scroll in the Leon Levy library" sec="1Q1 f3:1">1Q1 f3:1</a></td><td class="tf"><span class="txtu">בקרני׳ו וילך <span  class="hl" >אברהם </span>ויקח את האיל ויעל׳הו לעלה תחת בנ׳ו ׃ </span></td><td class="tf"><span class="txtu"><span  class="hlup" >א</span><span  class="hlup" >ב</span><span  class="hlup" >ר</span><span  class="hlup" >ה</span><span  class="hlup" >ם </span></span></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="show this scroll in the Leon Levy library" sec="1Q1 f3:2">1Q1 f3:2</a></td><td class="tf"><span class="txtu">ויקרא <span  class="hl" >אברהם </span>את שׁם המקום ההוא יהוה יראה אשׁר יאמר היום בהר </span></td><td class="tf"><span class="txtu"><span  class="hlup" >א</span><span  class="hlup" >ב</span><span  class="hlup" >ר</span><span  class="hlup" >ה</span><span  class="hlup" >ם </span></span></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="show this scroll in the Leon Levy library" sec="1Q1 f3:2">1Q1 f3:2</a></td><td class="tf"><span class="txtu">ויקרא אברהם את שׁם המקום ההוא <span  class="hl" >יהוה </span>יראה אשׁר יאמר היום בהר </span></td><td class="tf"><span class="txtu"><span  class="hlup" >י</span><span  class="hlup" >ה</span><span  class="hlup" >ו</span><span  class="hlup" >ה </span></span></td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="show this scroll in the Leon Levy library" sec="1Q1 f3:3">1Q1 f3:3</a></td><td class="tf"><span class="txtu"><span  class="hl" >יהוה </span>יראה ׃ ויקרא מלאך יהוה אל אברהם שׁנית מן השׁמים ׃ </span></td><td class="tf"><span class="txtu"><span  class="hlup" >י</span><span  class="hlup" >ה</span><span  class="hlup" >ו</span><span  class="hlup" >ה </span></span></td></tr>
# <tr class="tf"><td class="tf">7</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="show this scroll in the Leon Levy library" sec="1Q1 f3:3">1Q1 f3:3</a></td><td class="tf"><span class="txtu">יהוה יראה ׃ ויקרא מלאך <span  class="hl" >יהוה </span>אל אברהם שׁנית מן השׁמים ׃ </span></td><td class="tf"><span class="txtu"><span  class="hlup" >י</span><span  class="hlup" >ה</span><span  class="hlup" >ו</span><span  class="hlup" >ה </span></span></td></tr>
# <tr class="tf"><td class="tf">8</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="show this scroll in the Leon Levy library" sec="1Q1 f3:3">1Q1 f3:3</a></td><td class="tf"><span class="txtu">יהוה יראה ׃ ויקרא מלאך יהוה אל <span  class="hl" >אברהם </span>שׁנית מן השׁמים ׃ </span></td><td class="tf"><span class="txtu"><span  class="hlup" >א</span><span  class="hlup" >ב</span><span  class="hlup" >ר</span><span  class="hlup" >ה</span><span  class="hlup" >ם </span></span></td></tr>
# <tr class="tf"><td class="tf">9</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="show this scroll in the Leon Levy library" sec="1Q1 f4:1">1Q1 f4:1</a></td><td class="tf"><span class="txtu">ε ויקם שׁדה <span  class="hl" >עפרון </span>אשׁר </span></td><td class="tf"><span class="txtu"><span  class="hlup" >ע</span><span  class="hlup" >פ</span><span  class="hlup" >ר</span><span  class="hlup" >ו</span><span  class="hlup" >ן </span></span></td></tr>
# <tr class="tf"><td class="tf">10</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="show this scroll in the Leon Levy library" sec="1Q1 f4:2">1Q1 f4:2</a></td><td class="tf"><span class="txtu">ב<span  class="hl" >מכפלה </span>אשׁר לפני ממרא השׁדה והמערה אשׁר ב׳ו וכול העץ </span></td><td class="tf"><span class="txtu"><span  class="hlup" >מ</span><span  class="hlup" >כ</span><span  class="hlup" >פ</span><span  class="hlup" >ל</span><span  class="hlup" >ה </span></span></td></tr>
# <tr class="tf"><td class="tf">11</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="show this scroll in the Leon Levy library" sec="1Q1 f4:2">1Q1 f4:2</a></td><td class="tf"><span class="txtu">במכפלה אשׁר לפני <span  class="hl" >ממרא </span>השׁדה והמערה אשׁר ב׳ו וכול העץ </span></td><td class="tf"><span class="txtu"><span  class="hlup" >מ</span><span  class="hlup" >מ</span><span  class="hlup" >ר</span><span  class="hlup" >א </span></span></td></tr>
# <tr class="tf"><td class="tf">12</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="show this scroll in the Leon Levy library" sec="1Q1 f4:3">1Q1 f4:3</a></td><td class="tf"><span class="txtu">אשׁר בשׁדה אשׁר בכול גבל׳ו סביב ׃ ל<span  class="hl" >אברהם </span>למקנה לעיני בני חת </span></td><td class="tf"><span class="txtu"><span  class="hlup" >א</span><span  class="hlup" >ב</span><span  class="hlup" >ר</span><span  class="hlup" >ה</span><span  class="hlup" >ם </span></span></td></tr>
# <tr class="tf"><td class="tf">13</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="show this scroll in the Leon Levy library" sec="1Q1 f4:3">1Q1 f4:3</a></td><td class="tf"><span class="txtu">אשׁר בשׁדה אשׁר בכול גבל׳ו סביב ׃ לאברהם למקנה לעיני בני <span  class="hl" >חת </span></span></td><td class="tf"><span class="txtu"><span  class="hlup" >ח</span><span  class="hlup" >ת </span></span></td></tr>
# <tr class="tf"><td class="tf">14</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="show this scroll in the Leon Levy library" sec="1Q1 f4:4">1Q1 f4:4</a></td><td class="tf"><span class="txtu">בכול באי שׁער עיר׳ו ׃ ואחרי כן קבר <span  class="hl" >אברהם </span>את שׁרה אשׁת׳ו </span></td><td class="tf"><span class="txtu"><span  class="hlup" >א</span><span  class="hlup" >ב</span><span  class="hlup" >ר</span><span  class="hlup" >ה</span><span  class="hlup" >ם </span></span></td></tr>
# <tr class="tf"><td class="tf">15</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="show this scroll in the Leon Levy library" sec="1Q1 f4:4">1Q1 f4:4</a></td><td class="tf"><span class="txtu">בכול באי שׁער עיר׳ו ׃ ואחרי כן קבר אברהם את <span  class="hl" >שׁרה </span>אשׁת׳ו </span></td><td class="tf"><span class="txtu"><span  class="hlup" >שׁ</span><span  class="hlup" >ר</span><span  class="hlup" >ה </span></span></td></tr>
# <tr class="tf"><td class="tf">16</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explo

# %% [markdown]
# We zoom in on line 3 of fragment `f3`:

# %%
query = '''
line scroll=1Q1 fragment=f3 line=3
  word sp=subs cl=prp
'''

# %% [markdown]
# Note that you can have comments in a search template. Comment lines start with a `%`.

# %%
results = A.search(query)
A.table(results)
# Out:
#   0.56s 3 results
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">line</th><th>word</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="show this scroll in the Leon Levy library" sec="1Q1 f3:3">1Q1 f3:3</a></td><td class="tf"><span class="txtu"><span  class="hl" >יהוה </span>יראה ׃ ויקרא מלאך יהוה אל אברהם שׁנית מן השׁמים ׃ </span></td><td class="tf"><span class="txtu"><span  class="hlup" >י</span><span  class="hlup" >ה</span><span  class="hlup" >ו</span><span  class="hlup" >ה </span></span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="show this scroll in the Leon Levy library" sec="1Q1 f3:3">1Q1 f3:3</a></td><td class="tf"><span class="txtu">יהוה יראה ׃ ויקרא מלאך <span  class="hl" >יהוה </span>אל אברהם שׁנית מן השׁמים ׃ </span></td><td class="tf"><span class="txtu"><span  class="hlup" >י</span><span  class="hlup" >ה</span><span  class="hlup" >ו</span><span  class="hlup" >ה </span></span></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="show this scroll in the Leon Levy library" sec="1Q1 f3:3">1Q1 f3:3</a></td><td class="tf"><span class="txtu">יהוה יראה ׃ ויקרא מלאך יהוה אל <span  class="hl" >אברהם </span>שׁנית מן השׁמים ׃ </span></td><td class="tf"><span class="txtu"><span  class="hlup" >א</span><span  class="hlup" >ב</span><span  class="hlup" >ר</span><span  class="hlup" >ה</span><span  class="hlup" >ם </span></span></td></tr></table>

# %% [markdown]
# Let's expand the results display:

# %%
A.show(results)
# Out:
# <p><b>result</b> <i>1</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f3:3" sec="1Q1 f3:3">line <span class="txtn">3</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">1</span> <span class="line">3</span> <span class="fragment xft"><span class="f">fragment=</span>f3</span> <span class="scroll xft"><span class="f">scroll=</span>1Q1</span></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word hl" >
#
#     <div class="lbl word">
#         <span class="txtu">יהוה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">1</span> <span class="lex">יהוה</span> <span class="sp">subs</span> <span class="cl">prp</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">יראה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">ראה</span> <span class="sp">verb</span> <span class="ps">3</span> <span class="gn">m</span> <span class="nu">s</span> <span class="vs">nifal</span> <span class="vt">impf</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ר</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">א</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">׃ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">׃ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">וְ</span> <span class="sp">ptcl</span> <span class="cl">conj</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">יקרא </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">קרא_1</span> <span class="sp">verb</span> <span class="ps">3</span> <span class="gn">m</span> <span class="nu">s</span> <span class="vs">qal</span> <span class="vt">wayy</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ק</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ר</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">א </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">מלאך </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">מַלְאָךְ</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">m</span> <span class="nu">s</span> <span class="st">c</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">מ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ל</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">א</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ך </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">יהוה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">יהוה</span> <span class="sp">subs</span> <span class="cl">prp</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#
#     </div>
# <p><b>result</b> <i>2</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f3:3" sec="1Q1 f3:3">line <span class="txtn">3</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">1</span> <span class="line">3</span> <span class="fragment xft"><span class="f">fragment=</span>f3</span> <span class="scroll xft"><span class="f">scroll=</span>1Q1</span></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">יהוה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">1</span> <span class="lex">יהוה</span> <span class="sp">subs</span> <span class="cl">prp</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">יראה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">ראה</span> <span class="sp">verb</span> <span class="ps">3</span> <span class="gn">m</span> <span class="nu">s</span> <span class="vs">nifal</span> <span class="vt">impf</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ר</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">א</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">׃ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">׃ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">וְ</span> <span class="sp">ptcl</span> <span class="cl">conj</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">יקרא </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">קרא_1</span> <span class="sp">verb</span> <span class="ps">3</span> <span class="gn">m</span> <span class="nu">s</span> <span class="vs">qal</span> <span class="vt">wayy</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ק</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ר</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">א </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">מלאך </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">מַלְאָךְ</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">m</span> <span class="nu">s</span> <span class="st">c</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">מ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ל</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">א</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ך </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word hl" >
#
#     <div class="lbl word">
#         <span class="txtu">יהוה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">יהוה</span> <span class="sp">subs</span> <span class="cl">prp</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#
#     </div>
# <p><b>result</b> <i>3</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f3:3" sec="1Q1 f3:3">line <span class="txtn">3</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">1</span> <span class="line">3</span> <span class="fragment xft"><span class="f">fragment=</span>f3</span> <span class="scroll xft"><span class="f">scroll=</span>1Q1</span></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">יהוה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">1</span> <span class="lex">יהוה</span> <span class="sp">subs</span> <span class="cl">prp</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">יראה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">ראה</span> <span class="sp">verb</span> <span class="ps">3</span> <span class="gn">m</span> <span class="nu">s</span> <span class="vs">nifal</span> <span class="vt">impf</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ר</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">א</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">׃ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">׃ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">וְ</span> <span class="sp">ptcl</span> <span class="cl">conj</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">יקרא </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">קרא_1</span> <span class="sp">verb</span> <span class="ps">3</span> <span class="gn">m</span> <span class="nu">s</span> <span class="vs">qal</span> <span class="vt">wayy</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ק</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ר</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">א </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">מלאך </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">מַלְאָךְ</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">m</span> <span class="nu">s</span> <span class="st">c</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">מ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ל</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">א</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ך </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">יהוה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">יהוה</span> <span class="sp">subs</span> <span class="cl">prp</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#
#     </div>

# %% [markdown]
# As you see, the results are listed per result tuple, even if they occur all in the same line.
# This way you can keep track of what exactly belongs to each result.
#
# Now in condensed mode:

# %%
A.show(results, condensed=True)
# Out:
# <p><b>line</b> <i>1</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f3:3" sec="1Q1 f3:3">line <span class="txtn">3</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">1</span> <span class="line">3</span> <span class="fragment xft"><span class="f">fragment=</span>f3</span> <span class="scroll xft"><span class="f">scroll=</span>1Q1</span></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word hl" >
#
#     <div class="lbl word">
#         <span class="txtu">יהוה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">1</span> <span class="lex">יהוה</span> <span class="sp">subs</span> <span class="cl">prp</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">יראה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">ראה</span> <span class="sp">verb</span> <span class="ps">3</span> <span class="gn">m</span> <span class="nu">s</span> <span class="vs">nifal</span> <span class="vt">impf</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ר</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">א</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">׃ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">׃ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">וְ</span> <span class="sp">ptcl</span> <span class="cl">conj</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">יקרא </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">קרא_1</span> <span class="sp">verb</span> <span class="ps">3</span> <span class="gn">m</span> <span class="nu">s</span> <span class="vs">qal</span> <span class="vt">wayy</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ק</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ר</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">א </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">מלאך </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">מַלְאָךְ</span> <span class="sp">subs</span> <span class="cl">cmn</span> <span class="gn">m</span> <span class="nu">s</span> <span class="st">c</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">מ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ל</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">א</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ך </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word hl" >
#
#     <div class="lbl word">
#         <span class="txtu">יהוה </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">יהוה</span> <span class="sp">subs</span> <span class="cl">prp</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#
#     </di

# %% [markdown]
# This line has 3 results, and all of them are highlighted in the same line display.
#
# We can modify the container in which we see our results.
#
# By default, it is `line`, but we can make it `fragment` as well:

# %%
A.show(results, condensed=True, condenseType='fragment')
# Out:
# <p><b>fragment</b> <i>1</i></p>
# <div class="contnr fragment " >
#
#     <div class="lbl fragment">
#         <a href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='1Q1'" title="1Q1 f3" sec="1Q1 f3">fragment <span class="txtn">f3</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">1</span> <span class="fragment">f3</span> <span class="scroll xft"><span class="f">scroll=</span>1Q1</span></div>
#     </div>
#
#
#     <div class="children fragment">
#
#
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <span class="txtn">1</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">1</span> <span class="line">1</span> <span class="fragment xft"><span class="f">fragment=</span>f3</span> <span class="scroll xft"><span class="f">scroll=</span>1Q1</span></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ב</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">1</span> <span class="lex">בְּ</span> <span class="sp">ptcl</span> <span class="cl">prep</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ב</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">קרני׳ו </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">קֶרֶן</span> <span class="sp">suff</span> <span class="cl">cmn</span> <span class="gn">f</span> <span class="nu">d</span> <span class="st">c</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ק</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ר</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">נ</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">׳</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">וְ</span> <span class="sp">ptcl</span> <span class="cl">conj</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ילך </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">הלך</span> <span class="sp">verb</span> <span class="ps">3</span> <span class="gn">m</span> <span class="nu">s</span> <span class="vs">qal</span> <span class="vt">wayy</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ל</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ך </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">אברהם </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">אַבְרָהָם</span> <span class="sp">subs</span> <span class="cl">prp</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">א</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ב</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="rec"><span class="f">rec=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ר</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="unc"><span class="f">unc=</span>2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ה</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ם </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">וְ</span> <span class="sp">ptcl</span> <span class="cl">conj</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">ו</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtu">יקח </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="biblical">0</span> <span class="lex">לקח</span> <span class="sp">verb</span> <span class="ps">3</span> <span class="gn">m</span> <span class="nu">s</span> <span class="vs">qal</span> <span class="vt">wayy</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtu">י</span>

# %% [markdown]
# We now see the the displays of the whole fragment, with the line with the proper names in it highlighted and the proper names
# themselves highlighted as well.

# %% [markdown]
# # Custom highlighting
#
# Let us make a new search where we look for two different things in the same line.
#
# We can apply different highlight colors to different parts of the result.
# The signs in the pair are member 0 and 1 of the result tuples.
# The members that we do not map, will not be highlighted.
# The members that we map to the empty string will be highlighted with the default color.
#
# **NB:** Choose your colors from the
# [CSS specification](https://developer.mozilla.org/en-US/docs/Web/CSS/color_value).

# %%
query = '''
line
  sign missing=1
  sign question=1
  sign damage=1
'''

# %%
results = A.search(query)
A.table(results, end=10)
# Out:
#   0.56s 776 results
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">line</th><th>sign</th><th>sign</th><th>sign</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 obverse:5">P510530 obverse:5</a></td><td class="tf"><span class="txtp">{disz}<span  class="hl" >[{d}</span>x]-<span  class="hl" >ra#?-</span>bi il-qe2-a-am-ma</span></td><td class="tf"><span class="txtp"><span  class="hl" >[{d}</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >ra#?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >ra#?-</span></span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 obverse:5">P510530 obverse:5</a></td><td class="tf"><span class="txtp">{disz}[{d}<span  class="hl" >x]-</span><span  class="hl" >ra#?-</span>bi il-qe2-a-am-ma</span></td><td class="tf"><span class="txtp"><span  class="hl" >x]-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >ra#?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >ra#?-</span></span></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:11">P510530 reverse:11</a></td><td class="tf"><span class="txtp"><span  class="hl" >[szu-</span>bu-<span  class="hl" >lim?] </span><span  class="hl" >sza# </span>ta-asz-pu-ra-am</span></td><td class="tf"><span class="txtp"><span  class="hl" >[szu-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >lim?] </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >sza# </span></span></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:11">P510530 reverse:11</a></td><td class="tf"><span class="txtp">[szu-<span  class="hl" >bu-</span><span  class="hl" >lim?] </span><span  class="hl" >sza# </span>ta-asz-pu-ra-am</span></td><td class="tf"><span class="txtp"><span  class="hl" >bu-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >lim?] </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >sza# </span></span></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:11">P510530 reverse:11</a></td><td class="tf"><span class="txtp">[szu-bu-<span  class="hl" >lim?] </span><span  class="hl" >sza# </span>ta-asz-pu-ra-am</span></td><td class="tf"><span class="txtp"><span  class="hl" >lim?] </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >lim?] </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >sza# </span></span></td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:15'">P510534 reverse:15'</a></td><td class="tf"><span class="txtp"><span  class="hl" >li#-</span>iq#-bi-ma da-ba-ab#-szu <span  class="hl" >li#?-</span>in-na-me-<span  class="hl" >[er]</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >[er]</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >li#?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >li#-</span></span></td></tr>
# <tr class="tf"><td class="tf">7</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:15'">P510534 reverse:15'</a></td><td class="tf"><span class="txtp">li#-<span  class="hl" >iq#-</span>bi-ma da-ba-ab#-szu <span  class="hl" >li#?-</span>in-na-me-<span  class="hl" >[er]</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >[er]</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >li#?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >iq#-</span></span></td></tr>
# <tr class="tf"><td class="tf">8</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:15'">P510534 reverse:15'</a></td><td class="tf"><span class="txtp">li#-iq#-bi-ma da-ba-<span  class="hl" >ab#-</span>szu <span  class="hl" >li#?-</span>in-na-me-<span  class="hl" >[er]</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >[er]</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >li#?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >ab#-</span></span></td></tr>
# <tr class="tf"><td class="tf">9</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:15'">P510534 reverse:15'</a></td><td class="tf"><span class="txtp">li#-iq#-bi-ma da-ba-ab#-szu <span  class="hl" >li#?-</span>in-na-me-<span  class="hl" >[er]</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >[er]</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >li#?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >li#?-</span></span></td></tr>
# <tr class="tf"><td class="tf">10</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:20'">P510534 reverse:20'</a></td><td class="tf"><span class="txtp"><span  class="hl" >li#-</span>il#-<span  class="hl" >qe2#?-</span><span  class="hl" >[szu-</span>ma?]</span></td><td class="tf"><span class="txtp"><span  class="hl" >[szu-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >qe2#?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >li#-</span></span></td></tr></table>

# %%
A.table(results, end=10, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">line</th><th>sign</th><th>sign</th><th>sign</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 obverse:5">P510530 obverse:5</a></td><td class="tf"><span class="txtp">{disz}<span  class="hl"  style="background-color: cyan;" >[{d}</span>x]-<span  class="hl"  style="background-color: lightsalmon;" >ra#?-</span>bi il-qe2-a-am-ma</span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: cyan;" >[{d}</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >ra#?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >ra#?-</span></span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 obverse:5">P510530 obverse:5</a></td><td class="tf"><span class="txtp">{disz}[{d}<span  class="hl"  style="background-color: cyan;" >x]-</span><span  class="hl"  style="background-color: lightsalmon;" >ra#?-</span>bi il-qe2-a-am-ma</span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: cyan;" >x]-</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >ra#?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >ra#?-</span></span></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:11">P510530 reverse:11</a></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: cyan;" >[szu-</span>bu-<span  class="hl"  style="background-color: magenta;" >lim?] </span><span  class="hl"  style="background-color: lightsalmon;" >sza# </span>ta-asz-pu-ra-am</span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: cyan;" >[szu-</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: magenta;" >lim?] </span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >sza# </span></span></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:11">P510530 reverse:11</a></td><td class="tf"><span class="txtp">[szu-<span  class="hl"  style="background-color: cyan;" >bu-</span><span  class="hl"  style="background-color: magenta;" >lim?] </span><span  class="hl"  style="background-color: lightsalmon;" >sza# </span>ta-asz-pu-ra-am</span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: cyan;" >bu-</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: magenta;" >lim?] </span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >sza# </span></span></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:11">P510530 reverse:11</a></td><td class="tf"><span class="txtp">[szu-bu-<span  class="hl"  style="background-color: magenta;" >lim?] </span><span  class="hl"  style="background-color: lightsalmon;" >sza# </span>ta-asz-pu-ra-am</span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: magenta;" >lim?] </span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: magenta;" >lim?] </span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >sza# </span></span></td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:15'">P510534 reverse:15'</a></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >li#-</span>iq#-bi-ma da-ba-ab#-szu <span  class="hl"  style="background-color: magenta;" >li#?-</span>in-na-me-<span  class="hl"  style="background-color: cyan;" >[er]</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: cyan;" >[er]</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: magenta;" >li#?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >li#-</span></span></td></tr>
# <tr class="tf"><td class="tf">7</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:15'">P510534 reverse:15'</a></td><td class="tf"><span class="txtp">li#-<span  class="hl"  style="background-color: lightsalmon;" >iq#-</span>bi-ma da-ba-ab#-szu <span  class="hl"  style="background-color: magenta;" >li#?-</span>in-na-me-<span  class="hl"  style="background-color: cyan;" >[er]</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: cyan;" >[er]</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: magenta;" >li#?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >iq#-</span></span></td></tr>
# <tr class="tf"><td class="tf">8</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:15'">P510534 reverse:15'</a></td><td class="tf"><span class="txtp">li#-iq#-bi-ma da-ba-<span  class="hl"  style="background-color: lightsalmon;" >ab#-</span>szu <span  class="hl"  style="background-color: magenta;" >li#?-</span>in-na-me-<span  class="hl"  style="background-color: cyan;" >[er]</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: cyan;" >[er]</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: magenta;" >li#?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >ab#-</span></span></td></tr>
# <tr class="tf"><td class="tf">9</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:15'">P510534 reverse:15'</a></td><td class="tf"><span class="txtp">li#-iq#-bi-ma da-ba-ab#-szu <span  class="hl"  style="background-color: lightsalmon;" >li#?-</span>in-na-me-<span  class="hl"  style="background-color: cyan;" >[er]</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: cyan;" >[er]</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >li#?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >li#?-</span></span></td></tr>
# <tr class="tf"><td class="tf">10</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:20'">P510534 reverse:20'</a></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >li#-</span>il#-<span  class="hl"  style="background-color: magenta;" >qe2#?-</span><span

# %%
A.show(results, end=10, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
# <p><b>result</b> <i>1</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 obverse:5" sec="P510530 obverse:5">line <span class="txtn">5</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{disz}[{d}x]-ra#?-bi </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{disz}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[{d}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">x]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ra#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">il-qe2-a-am-ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">il-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">qe2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">am-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>2</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 obverse:5" sec="P510530 obverse:5">line <span class="txtn">5</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{disz}[{d}x]-ra#?-bi </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{disz}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[{d}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">x]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ra#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">il-qe2-a-am-ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">il-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">qe2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">am-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>3</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 reverse:11" sec="P510530 reverse:11">line <span class="txtn">11</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[szu-bu-lim?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">lim?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ta-asz-pu-ra-am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ta-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">asz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">pu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ra-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>4</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 reverse:11" sec="P510530 reverse:11">line <span class="txtn">11</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[szu-bu-lim?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">lim?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ta-asz-pu-ra-am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ta-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">asz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">pu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ra-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>5</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 reverse:11" sec="P510530 reverse:11">line <span class="txtn">11</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[szu-bu-lim?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">lim?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ta-asz-pu-ra-am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ta-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">asz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">pu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ra-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>6</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="P510534 reverse:15'" sec="P510534 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#-iq#-bi-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">li#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">iq#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">da-ba-ab#-szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">da-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ba-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ab#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#?-in-na-me-[er]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">li#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">in-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">me-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[er]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>7</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="P510534 reverse:15'" sec="P510534 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#-iq#-bi-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">li#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">iq#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">da-ba-ab#-szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">da-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ba-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ab#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#?-in-na-me-[er]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">li#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">in-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">me-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[er]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>8</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="P510534 reverse:15'" sec="P510534 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#-iq#-bi-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">li#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">iq#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">da-ba-ab#-szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">da-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ba-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ab#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#?-in-na-me-[er]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">li#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">in-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">me-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[er]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>9</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="P510534 reverse:15'" sec="P510534 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#-iq#-bi-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">li#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">iq#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">da-ba-ab#-szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">da-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ba-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ab#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#?-in-na-me-[er]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">li#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">in-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">me-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[er]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>10</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="P510534 reverse:20'" sec="P510534 reverse:20'">line <span class="txtn">20'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#-il#-qe2#?-[szu-ma?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">li#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">il#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">qe2#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# Color mapping works best for uncondensed results. If you condense results, some nodes may occupy
# different positions in different results. It is unpredictable which color will be used
# for such nodes:

# %%
A.show(results, condensed=True, end=10, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
# <p><b>line</b> <i>1</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 obverse:5" sec="P510530 obverse:5">line <span class="txtn">5</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{disz}[{d}x]-ra#?-bi </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{disz}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[{d}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">x]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ra#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">il-qe2-a-am-ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">il-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">qe2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">am-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>line</b> <i>2</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 reverse:11" sec="P510530 reverse:11">line <span class="txtn">11</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[szu-bu-lim?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">lim?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ta-asz-pu-ra-am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ta-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">asz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">pu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ra-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>line</b> <i>3</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="P510534 reverse:15'" sec="P510534 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#-iq#-bi-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">li#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">iq#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">da-ba-ab#-szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">da-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ba-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ab#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#?-in-na-me-[er]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">li#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">in-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">me-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[er]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>line</b> <i>4</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="P510534 reverse:20'" sec="P510534 reverse:20'">line <span class="txtn">20'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#-il#-qe2#?-[szu-ma?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">li#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">il#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">qe2#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ma?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>line</b> <i>5</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510546" title="P510546 obverse:1" sec="P510546 obverse:1">line <span class="txtn">1</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">a-na </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{d}na#-[bi-um-at-pa-lam?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{d}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">na#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[bi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">um-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">at-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">pa-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">lam?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>line</b> <i>6</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510550" title="P510550 obverse:9" sec="P510550 obverse:9">line <span class="txtn">9</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_ha-za-nu-um{sar}_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_ha-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">za-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">nu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">um</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{sar}_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">i-ka-am#? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">i-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ka-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">am#? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[x] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[x] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">x-al#-la-x-ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">x-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">al#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">la-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">x-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>line</b> <i>7</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510554" title="P510554 reverse:10" sec="P510554 reverse:10">line <span class="txtn">10</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_1(disz) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_1(disz) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sila3 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sila3 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sze_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sze_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">la# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">la# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[i-ka-al-la?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[i-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ka-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">al-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">la?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>line</b> <i>8</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510560" title="P510560 obverse:9" sec="P510560 obverse:9">line <span class="txtn">9</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">isz-ti-isz#-[szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">isz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ti-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">isz#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">szi-ni-szu?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">szi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ni-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">szu?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">x </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">x </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_hi-a_</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_hi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a_</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>line</b> <i>9</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510562" title="P510562 reverse:15" sec="P510562 reverse:15">line <span class="txtn">15</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">i-ri-isz-ka </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">i-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ri-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">isz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ka </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">um-ma# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">um-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ma# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[at-ta]-a-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[at-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ta]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">i-na </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">i-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_{gesz}ma2?_-[ma?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_{gesz}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ma2?_-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[ma?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>line</b> <i>10</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510565" title="P510565 reverse:4" sec="P510565 reverse:4">line <span class="txtn">4</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[a-na?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">na?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_e2_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_e2_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{d}utu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{d}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">utu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">szu-ri-ba-am#</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ri-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ba-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">am#</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# You can specify to what container you want to condense. By default, everything is condensed to lines.
#
# Let's change that to faces.
# Note that the `end` parameter counts the number of faces now.

# %%
A.show(results, end=2, condensed=True, condenseType='face', colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
# <p><b>face</b> <i>1</i></p>
# <div class="contnr face " >
#
#     <div class="lbl face">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 obverse" sec="P510530 obverse">face <span class="txtn">obverse</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="object">tablet</span></div>
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <span class="txtn">1</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[a-na] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">dingir-szu-ib-ni</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">dingir-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ib-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ni</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <span class="txtn">2</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[qi2]-bi2#-ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[qi2]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi2#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <span class="txtn">3</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[um-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[um-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{d}na-bi]-um#-na-s,i-ir-ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{d}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">um#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">s,i-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ir-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <span class="txtn">4</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[sze-a-am] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[sze-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
# <p><b>face</b> <i>2</i></p>
# <div class="contnr face " >
#
#     <div class="lbl face">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 reverse" sec="P510530 reverse">face <span class="txtn">reverse</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="object">tablet</span></div>
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <span class="txtn">1</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">u3 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u3 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ka-ni-ik </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ka-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ni-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ik </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">szi-ma-tim </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">tim </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ta-ad-di-in</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ta-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ad-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">di-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">in</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <span class="txtn">2</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">mi-nu-u2 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">mi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">nu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u2 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">a-wa-tum-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">wa-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">tum-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">da-ba-ba-am </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">da-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ba-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ba-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">am </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">tu-sze-er-szi</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">tu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sze-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">er-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <

# %% [markdown]
# # Constraining order
# You can stipulate an order on the things in your template.
# You only have to put a relational operator between them.
# Say we want only results where the damage follows the missing.

# %%
query = '''
line
  sign question=1
  sign missing=1
  < sign damage=1
'''

# %%
results = A.search(query)
A.table(results, end=10)
# Out:
#   0.56s 372 results
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">line</th><th>sign</th><th>sign</th><th>sign</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 obverse:5">P510530 obverse:5</a></td><td class="tf"><span class="txtp">{disz}<span  class="hl" >[{d}</span>x]-<span  class="hl" >ra#?-</span>bi il-qe2-a-am-ma</span></td><td class="tf"><span class="txtp"><span  class="hl" >ra#?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >[{d}</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >ra#?-</span></span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 obverse:5">P510530 obverse:5</a></td><td class="tf"><span class="txtp">{disz}[{d}<span  class="hl" >x]-</span><span  class="hl" >ra#?-</span>bi il-qe2-a-am-ma</span></td><td class="tf"><span class="txtp"><span  class="hl" >ra#?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >x]-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >ra#?-</span></span></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:11">P510530 reverse:11</a></td><td class="tf"><span class="txtp"><span  class="hl" >[szu-</span>bu-<span  class="hl" >lim?] </span><span  class="hl" >sza# </span>ta-asz-pu-ra-am</span></td><td class="tf"><span class="txtp"><span  class="hl" >lim?] </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >[szu-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >sza# </span></span></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:11">P510530 reverse:11</a></td><td class="tf"><span class="txtp">[szu-<span  class="hl" >bu-</span><span  class="hl" >lim?] </span><span  class="hl" >sza# </span>ta-asz-pu-ra-am</span></td><td class="tf"><span class="txtp"><span  class="hl" >lim?] </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >bu-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >sza# </span></span></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:11">P510530 reverse:11</a></td><td class="tf"><span class="txtp">[szu-bu-<span  class="hl" >lim?] </span><span  class="hl" >sza# </span>ta-asz-pu-ra-am</span></td><td class="tf"><span class="txtp"><span  class="hl" >lim?] </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >lim?] </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >sza# </span></span></td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510550" title="show this document on CDLI" sec="P510550 obverse:9">P510550 obverse:9</a></td><td class="tf"><span class="txtp">_ha-za-nu-um{sar}_ i-ka-<span  class="hl" >am#? </span><span  class="hl" >[x] </span>x-<span  class="hl" >al#-</span>la-x-ma</span></td><td class="tf"><span class="txtp"><span  class="hl" >am#? </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >[x] </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >al#-</span></span></td></tr>
# <tr class="tf"><td class="tf">7</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510565" title="show this document on CDLI" sec="P510565 reverse:4">P510565 reverse:4</a></td><td class="tf"><span class="txtp"><span  class="hl" >[a-</span><span  class="hl" >na?] </span>_e2_ {d}utu szu-ri-ba-<span  class="hl" >am#</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >na?] </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >[a-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >am#</span></span></td></tr>
# <tr class="tf"><td class="tf">8</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510565" title="show this document on CDLI" sec="P510565 reverse:4">P510565 reverse:4</a></td><td class="tf"><span class="txtp">[a-<span  class="hl" >na?] </span>_e2_ {d}utu szu-ri-ba-<span  class="hl" >am#</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >na?] </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >na?] </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >am#</span></span></td></tr>
# <tr class="tf"><td class="tf">9</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510567" title="show this document on CDLI" sec="P510567 reverse:2">P510567 reverse:2</a></td><td class="tf"><span class="txtp"><span  class="hl" >[...] </span><span  class="hl" >ia#? </span>_sag-us2_</span></td><td class="tf"><span class="txtp"><span  class="hl" >ia#? </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >[...] </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >ia#? </span></span></td></tr>
# <tr class="tf"><td class="tf">10</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510586" title="show this document on CDLI" sec="P510586 obverse:11">P510586 obverse:11</a></td><td class="tf"><span class="txtp"><span  class="hl" >[{disz}]</span>i-na-e2-ul-masz-<span  class="hl" >numun# </span>a-<span  class="hl" >na#? </span>[ma-ah-ri-ka?]</span></td><td class="tf"><span class="txtp"><span  class="hl" >na#? </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >[{disz}]</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >numun# </span></span></td></tr></table>

# %% [markdown]
# We can also require the things to be adjacent.

# %%
query = '''
line
  sign question=1
  sign missing=1
  <: sign damage=1
'''

# %%
results = A.search(query)
A.table(results, end=10)
A.show(results, end=10, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
#   0.55s 84 results
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">line</th><th>sign</th><th>sign</th><th>sign</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 obverse:5">P510530 obverse:5</a></td><td class="tf"><span class="txtp">{disz}[{d}<span  class="hl" >x]-</span><span  class="hl" >ra#?-</span>bi il-qe2-a-am-ma</span></td><td class="tf"><span class="txtp"><span  class="hl" >ra#?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >x]-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >ra#?-</span></span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:11">P510530 reverse:11</a></td><td class="tf"><span class="txtp">[szu-bu-<span  class="hl" >lim?] </span><span  class="hl" >sza# </span>ta-asz-pu-ra-am</span></td><td class="tf"><span class="txtp"><span  class="hl" >lim?] </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >lim?] </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >sza# </span></span></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510567" title="show this document on CDLI" sec="P510567 reverse:2">P510567 reverse:2</a></td><td class="tf"><span class="txtp"><span  class="hl" >[...] </span><span  class="hl" >ia#? </span>_sag-us2_</span></td><td class="tf"><span class="txtp"><span  class="hl" >ia#? </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >[...] </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >ia#? </span></span></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510586" title="show this document on CDLI" sec="P510586 obverse:27">P510586 obverse:27</a></td><td class="tf"><span class="txtp">[asz-szum <span  class="hl" >ha]-</span><span  class="hl" >bil2#?-</span>we?-du-um sza asz-pu-ra#-[ak-kum]</span></td><td class="tf"><span class="txtp"><span  class="hl" >bil2#?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >ha]-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >bil2#?-</span></span></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510586" title="show this document on CDLI" sec="P510586 obverse:27">P510586 obverse:27</a></td><td class="tf"><span class="txtp">[asz-szum <span  class="hl" >ha]-</span><span  class="hl" >bil2#?-</span><span  class="hl" >we?-</span>du-um sza asz-pu-ra#-[ak-kum]</span></td><td class="tf"><span class="txtp"><span  class="hl" >we?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >ha]-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >bil2#?-</span></span></td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510588" title="show this document on CDLI" sec="P510588 left:1':2">P510588 left:1':2</a></td><td class="tf"><span class="txtp"><span  class="hl" >[i?]-</span><span  class="hl" >na# </span>zimbir{ki#}</span></td><td class="tf"><span class="txtp"><span  class="hl" >[i?]-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >[i?]-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >na# </span></span></td></tr>
# <tr class="tf"><td class="tf">7</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510597" title="show this document on CDLI" sec="P510597 obverse:12">P510597 obverse:12</a></td><td class="tf"><span class="txtp"><span  class="hl" >[a?-</span><span  class="hl" >na] </span><span  class="hl" >babila2#</span>[{ki}]</span></td><td class="tf"><span class="txtp"><span  class="hl" >[a?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >na] </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >babila2#</span></span></td></tr>
# <tr class="tf"><td class="tf">8</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510657" title="show this document on CDLI" sec="P510657 envelope - obverse:1">P510657 envelope - obverse:1</a></td><td class="tf"><span class="txtp"><span  class="hl" >[tup]-</span><span  class="hl" >pi#? </span>a-hi-i3-li2-ia</span></td><td class="tf"><span class="txtp"><span  class="hl" >pi#? </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >[tup]-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >pi#? </span></span></td></tr>
# <tr class="tf"><td class="tf">9</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510660" title="show this document on CDLI" sec="P510660 reverse:7">P510660 reverse:7</a></td><td class="tf"><span class="txtp"><span  class="hl" >[t,e4?]-</span><span  class="hl" >em# </span>_a-sza3_ ma-la a-di i-na-an-na</span></td><td class="tf"><span class="txtp"><span  class="hl" >[t,e4?]-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >[t,e4?]-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >em# </span></span></td></tr>
# <tr class="tf"><td class="tf">10</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510662" title="show this document on CDLI" sec="P510662 reverse:1">P510662 reverse:1</a></td><td class="tf"><span class="txtp"><span  class="hl" >[1(disz)?] </span><span  class="hl" >_tug2#?_ </span>a-la-qe2-am</span></td><td class="tf"><span class="txtp"><span  class="hl" >[1(disz)?] </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >[1(disz)?] </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >_tug2#?_ </span></span></td></tr></table>
# <p><b>result</b> <i>1</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 obverse:5" sec="P510530 obverse:5">line <span class="txtn">5</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{disz}[{d}x]-ra#?-bi </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{disz}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[{d}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">x]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ra#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">il-qe2-a-am-ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">il-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">qe2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">am-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>2</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 reverse:11" sec="P510530 reverse:11">line <span class="txtn">11</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[szu-bu-lim?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">lim?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ta-asz-pu-ra-am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ta-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">asz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">pu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ra-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>3</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510567" title="P510567 reverse:2" sec="P510567 reverse:2">line <span class="txtn">2</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[...] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[...] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="grapheme"><span class="f">grapheme=</span>...</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ia#? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ia#? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_sag-us2_</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_sag-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">us2_</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>4</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510586" title="P510586 obverse:27" sec="P510586 obverse:27">line <span class="txtn">27</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[asz-szum </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[asz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szum </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ha]-bil2#?-we?-du-um </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ha]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">bil2#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">we?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">du-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">um </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sza </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sza </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">asz-pu-ra#-[ak-kum]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">asz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">pu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ra#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[ak-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">kum]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>5</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510586" title="P510586 obverse:27" sec="P510586 obverse:27">line <span class="txtn">27</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[asz-szum </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[asz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szum </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ha]-bil2#?-we?-du-um </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ha]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">bil2#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">we?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">du-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">um </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sza </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sza </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">asz-pu-ra#-[ak-kum]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">asz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">pu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ra#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[ak-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">kum]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>6</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510588" title="P510588 left:1':2" sec="P510588 left:1':2">line <span class="txtn">1':2</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[i?]-na# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[i?]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">na# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">zimbir{ki#}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">zimbir</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{ki#}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="det"><span class="f">det=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>7</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510597" title="P510597 obverse:12" sec="P510597 obverse:12">line <span class="txtn">12</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[a?-na] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[a?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">na] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">babila2#[{ki}]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">babila2#</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[{ki}]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>8</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510657" title="P510657 envelope - obverse:1" sec="P510657 envelope - obverse:1">line <span class="txtn">1</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[tup]-pi#? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[tup]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">pi#? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">a-hi-i3-li2-ia</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">hi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">i3-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">li2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ia</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>9</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510660" title="P510660 reverse:7" sec="P510660 reverse:7">line <span class="txtn">7</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[t,e4?]-em# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[t,e4?]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">em# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_a-sza3_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sza3_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ma-la </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">la </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">a-di </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">di </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">i-na-an-na</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">i-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">an-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>10</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510662" title="P510662 reverse:1" sec="P510662 reverse:1">line <span class="txtn">1</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[1(disz)?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[1(disz)?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span> <span class="repeat"><span class="f">repeat=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_tug2#?_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">_tug2#?_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">a-la-qe2-am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">la-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">qe2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# Finally, we make the three things fully adjacent in fixed order:

# %%
query = '''
line
  sign question=1
  <: sign missing=1
  <: sign damage=1
'''

# %%
results = A.search(query)
A.table(results, end=10)
A.show(results, end=10, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
#   0.55s 7 results
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">line</th><th>sign</th><th>sign</th><th>sign</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510597" title="show this document on CDLI" sec="P510597 obverse:12">P510597 obverse:12</a></td><td class="tf"><span class="txtp"><span  class="hl" >[a?-</span><span  class="hl" >na] </span><span  class="hl" >babila2#</span>[{ki}]</span></td><td class="tf"><span class="txtp"><span  class="hl" >[a?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >na] </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >babila2#</span></span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P292756" title="show this document on CDLI" sec="P292756 obverse:21">P292756 obverse:21</a></td><td class="tf"><span class="txtp"><span  class="hl" >[sza? </span><span  class="hl" >(...)] </span><span  class="hl" >it#-</span>ti-ia u2-ul in-nam-ru-ma</span></td><td class="tf"><span class="txtp"><span  class="hl" >[sza? </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >(...)] </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >it#-</span></span></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P313393" title="show this document on CDLI" sec="P313393 obverse:3">P313393 obverse:3</a></td><td class="tf"><span class="txtp">um-ma <span  class="hl" >ni?-</span><span  class="hl" >[...]-</span><span  class="hl" >ma#</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >ni?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >[...]-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >ma#</span></span></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P386470" title="show this document on CDLI" sec="P386470 reverse:15'">P386470 reverse:15'</a></td><td class="tf"><span class="txtp"><span  class="hl" >[u2?-</span><span  class="hl" >sze]-</span><span  class="hl" >et#-</span>bu-u2-[szu?]</span></td><td class="tf"><span class="txtp"><span  class="hl" >[u2?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >sze]-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >et#-</span></span></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305755" title="show this document on CDLI" sec="P305755 reverse:3">P305755 reverse:3</a></td><td class="tf"><span class="txtp">u3 <span  class="hl" >KA#?-</span><span  class="hl" >[x]-</span><span  class="hl" >UM#? </span>a-hu-u2-szu qa2-ta-ti-szu-ma</span></td><td class="tf"><span class="txtp"><span  class="hl" >KA#?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >[x]-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >UM#? </span></span></td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P307155" title="show this document on CDLI" sec="P307155 obverse:11">P307155 obverse:11</a></td><td class="tf"><span class="txtp">mi-im#-ma# sza ta#-<span  class="hl" >GA?-</span><span  class="hl" >[x]-</span><span  class="hl" >BU#? </span>[x]</span></td><td class="tf"><span class="txtp"><span  class="hl" >GA?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >[x]-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >BU#? </span></span></td></tr>
# <tr class="tf"><td class="tf">7</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P308015" title="show this document on CDLI" sec="P308015 reverse:2">P308015 reverse:2</a></td><td class="tf"><span class="txtp">{disz}<span  class="hl" >UD?-</span><span  class="hl" >[x] </span><span  class="hl" >{ki#}-</span>li-ib-lu-ut,</span></td><td class="tf"><span class="txtp"><span  class="hl" >UD?-</span></span></td><td class="tf"><span class="txtp"><span  class="hl" >[x] </span></span></td><td class="tf"><span class="txtp"><span  class="hl" >{ki#}-</span></span></td></tr></table>
# <p><b>result</b> <i>1</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510597" title="P510597 obverse:12" sec="P510597 obverse:12">line <span class="txtn">12</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[a?-na] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[a?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">na] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">babila2#[{ki}]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">babila2#</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[{ki}]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>2</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P292756" title="P292756 obverse:21" sec="P292756 obverse:21">line <span class="txtn">21</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[sza? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[sza? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">(...)] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">(...)] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="uncertain"><span class="f">uncertain=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span> <span class="grapheme"><span class="f">grapheme=</span>...</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">it#-ti-ia </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">it#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ti-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ia </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">u2-ul </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ul </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">in-nam-ru-ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">in-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">nam-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ru-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>3</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P313393" title="P313393 obverse:3" sec="P313393 obverse:3">line <span class="txtn">3</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">um-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">um-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ni?-[...]-ma#</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ni?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[...]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="grapheme"><span class="f">grapheme=</span>...</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ma#</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>4</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P386470" title="P386470 reverse:15'" sec="P386470 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[u2?-sze]-et#-bu-u2-[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[u2?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sze]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">et#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>5</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305755" title="P305755 reverse:3" sec="P305755 reverse:3">line <span class="txtn">3</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">u3 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u3 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">KA#?-[x]-UM#? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">KA#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span> <span class="grapheme"><span class="f">grapheme=</span>KA</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[x]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">UM#? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span> <span class="grapheme"><span class="f">grapheme=</span>UM</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">a-hu-u2-szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">hu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">qa2-ta-ti-szu-ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">qa2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ta-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ti-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>6</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P307155" title="P307155 obverse:11" sec="P307155 obverse:11">line <span class="txtn">11</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">mi-im#-ma# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">mi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">im#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sza </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sza </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ta#-GA?-[x]-BU#? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ta#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">GA?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="grapheme"><span class="f">grapheme=</span>GA</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[x]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">BU#? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span> <span class="grapheme"><span class="f">grapheme=</span>BU</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[x]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[x]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>7</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P308015" title="P308015 reverse:2" sec="P308015 reverse:2">line <span class="txtn">2</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{disz}UD?-[x] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{disz}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">UD?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="grapheme"><span class="f">grapheme=</span>UD</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[x] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{ki#}-li-ib-lu-ut,</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">{ki#}-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="det"><span class="f">det=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">li-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ib-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">lu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ut,</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# # Custom feature display
#
# We would like to see the original atf and the flags for signs.
# The way to do that, is to perform a `A.prettySetup(features)` first.
#
# We concentrate on one specific result.

# %%
A.displaySetup(extraFeatures='atf flags')

# %%
A.show(results, start=4, end=4, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
# <p><b>result</b> <i>4</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P386470" title="P386470 reverse:15'" sec="P386470 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[u2?-sze]-et#-bu-u2-[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>[u2?-sze]-et#-bu-u2-[szu?]</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[u2?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span> <span class="atf xft"><span class="f">atf=</span>u2?</span> <span class="flags xft"><span class="f">flags=</span>?</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sze]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="atf xft"><span class="f">atf=</span>sze</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">et#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="atf xft"><span class="f">atf=</span>et#</span> <span class="flags xft"><span class="f">flags=</span>#</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>bu</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>u2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span> <span class="atf xft"><span class="f">atf=</span>szu?</span> <span class="flags xft"><span class="f">flags=</span>?</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# The features without meaningful values have been left out. We can also change that by passing a set of values
# we think are not meaningful. The default set is
#
# ```python
# {None, 'NA', 'none', 'unknown'}
# ```

# %%
A.displaySetup(noneValues=set())
A.show(results, start=4, end=4, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
# <p><b>result</b> <i>4</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P386470" title="P386470 reverse:15'" sec="P386470 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="remarks"></span> <span class="translation@en"></span> <span class="atf xft"><span class="f">atf=</span></span> <span class="damage xft"><span class="f">damage=</span></span> <span class="flags xft"><span class="f">flags=</span></span> <span class="missing xft"><span class="f">missing=</span></span> <span class="question xft"><span class="f">question=</span></span></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[u2?-sze]-et#-bu-u2-[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>[u2?-sze]-et#-bu-u2-[szu?]</span> <span class="damage xft"><span class="f">damage=</span></span> <span class="flags xft"><span class="f">flags=</span></span> <span class="missing xft"><span class="f">missing=</span></span> <span class="question xft"><span class="f">question=</span></span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[u2?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="collated"><span class="f">collated=</span></span> <span class="remarkable"><span class="f">remarkable=</span></span> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span></span> <span class="det"><span class="f">det=</span></span> <span class="uncertain"><span class="f">uncertain=</span></span> <span class="missing"><span class="f">missing=</span>1</span> <span class="excised"><span class="f">excised=</span></span> <span class="supplied"><span class="f">supplied=</span></span> <span class="langalt"><span class="f">langalt=</span></span> <span class="comment"><span class="f">comment=</span></span> <span class="remarks"><span class="f">remarks=</span></span> <span class="repeat"><span class="f">repeat=</span></span> <span class="fraction"><span class="f">fraction=</span></span> <span class="operator"><span class="f">operator=</span></span> <span class="grapheme"><span class="f">grapheme=</span></span> <span class="atf xft"><span class="f">atf=</span>u2?</span> <span class="flags xft"><span class="f">flags=</span>?</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sze]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="collated"><span class="f">collated=</span></span> <span class="remarkable"><span class="f">remarkable=</span></span> <span class="question"><span class="f">question=</span></span> <span class="damage"><span class="f">damage=</span></span> <span class="det"><span class="f">det=</span></span> <span class="uncertain"><span class="f">uncertain=</span></span> <span class="missing"><span class="f">missing=</span>1</span> <span class="excised"><span class="f">excised=</span></span> <span class="supplied"><span class="f">supplied=</span></span> <span class="langalt"><span class="f">langalt=</span></span> <span class="comment"><span class="f">comment=</span></span> <span class="remarks"><span class="f">remarks=</span></span> <span class="repeat"><span class="f">repeat=</span></span> <span class="fraction"><span class="f">fraction=</span></span> <span class="operator"><span class="f">operator=</span></span> <span class="grapheme"><span class="f">grapheme=</span></span> <span class="atf xft"><span class="f">atf=</span>sze</span> <span class="flags xft"><span class="f">flags=</span></span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">et#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="collated"><span class="f">collated=</span></span> <span class="remarkable"><span class="f">remarkable=</span></span> <span class="question"><span class="f">question=</span></span> <span class="damage"><span class="f">damage=</span>1</span> <span class="det"><span class="f">det=</span></span> <span class="uncertain"><span class="f">uncertain=</span></span> <span class="missing"><span class="f">missing=</span></span> <span class="excised"><span class="f">excised=</span></span> <span class="supplied"><span class="f">supplied=</span></span> <span class="langalt"><span class="f">langalt=</span></span> <span class="comment"><span class="f">comment=</span></span> <span class="remarks"><span class="f">remarks=</span></span> <span class="repeat"><span class="f">repeat=</span></span> <span class="fraction"><span class="f">fraction=</span></span> <span class="operator"><span class="f">operator=</span></span> <span class="grapheme"><span class="f">grapheme=</span></span> <span class="atf xft"><span class="f">atf=</span>et#</span> <span class="flags xft"><span class="f">flags=</span>#</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="collated"><span class="f">collated=</span></span> <span class="remarkable"><span class="f">remarkable=</span></span> <span class="question"><span class="f">question=</span></span> <span class="damage"><span class="f">damage=</span></span> <span class="det"><span class="f">det=</span></span> <span class="uncertain"><span class="f">uncertain=</span></span> <span class="missing"><span class="f">missing=</span></span> <span class="excised"><span class="f">excised=</span></span> <span class="supplied"><span class="f">supplied=</span></span> <span class="langalt"><span class="f">langalt=</span></span> <span class="comment"><span class="f">comment=</span></span> <span class="remarks"><span class="f">remarks=</span></span> <span class="repeat"><span class="f">repeat=</span></span> <span class="fraction"><span class="f">fraction=</span></span> <span class="operator"><span class="f">operator=</span></span> <span class="grapheme"><span class="f">grapheme=</span></span> <span class="atf xft"><span class="f">atf=</span>bu</span> <span class="flags xft"><span class="f">flags=</span></span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="collated"><span class="f">collated=</span></span> <span class="remarkable"><span class="f">remarkable=</span></span> <span class="question"><span class="f">question=</span></span> <span class="damage"><span class="f">damage=</span></span> <span class="det"><span class="f">det=</span></span> <span class="uncertain"><span class="f">uncertain=</span></span> <span class="missing"><span class="f">missing=</span></span> <span class="excised"><span class="f">excised=</span></span> <span class="supplied"><span class="f">supplied=</span></span> <span class="langalt"><span class="f">langalt=</span></span> <span class="comment"><span class="f">comment=</span></span> <span class="remarks"><span class="f">remarks=</span></span> <span class="repeat"><span class="f">repeat=</span></span> <span class="fraction"><span class="f">fraction=</span></span> <span class="operator"><span class="f">operator=</span></span> <span class="grapheme"><span class="f">grapheme=</span></span> <span class="atf xft"><span class="f">atf=</span>u2</span> <span class="flags xft"><span class="f">flags=</span></span></div>
#     <

# %% [markdown]
# This makes clear that it is convenient to keep `None` in the `noneValues`:

# %%
A.displaySetup(noneValues={None})
A.show(results, start=4, end=4, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
# <p><b>result</b> <i>4</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P386470" title="P386470 reverse:15'" sec="P386470 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[u2?-sze]-et#-bu-u2-[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>[u2?-sze]-et#-bu-u2-[szu?]</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[u2?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span> <span class="atf xft"><span class="f">atf=</span>u2?</span> <span class="flags xft"><span class="f">flags=</span>?</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sze]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="atf xft"><span class="f">atf=</span>sze</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">et#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="atf xft"><span class="f">atf=</span>et#</span> <span class="flags xft"><span class="f">flags=</span>#</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>bu</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>u2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span> <span class="atf xft"><span class="f">atf=</span>szu?</span> <span class="flags xft"><span class="f">flags=</span>?</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# We can even choose to suppress other values, e.g. the value 1.
#
# That will remove all the features such as `question`, `missing`.

# %%
A.displaySetup(noneValues={None, 'NA', 'unknown', 1})
A.show(results, start=4, end=4, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
# <p><b>result</b> <i>4</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P386470" title="P386470 reverse:15'" sec="P386470 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[u2?-sze]-et#-bu-u2-[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>[u2?-sze]-et#-bu-u2-[szu?]</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[u2?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>u2?</span> <span class="flags xft"><span class="f">flags=</span>?</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sze]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>sze</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">et#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>et#</span> <span class="flags xft"><span class="f">flags=</span>#</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>bu</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>u2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>szu?</span> <span class="flags xft"><span class="f">flags=</span>?</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# In the rest of the notebook we stick to our normal setup, so we reset the extra features.

# %%
A.displayReset()
A.show(results, start=4, end=4, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
# <p><b>result</b> <i>4</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P386470" title="P386470 reverse:15'" sec="P386470 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[u2?-sze]-et#-bu-u2-[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[u2?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sze]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">et#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# # Features from queries
#
# In earlier displays we saw the *types* of signs, because the query mentioned it.
#
# Suppose we want to display the type also here, then we can modify the query by mentioning the feature `type`.
#
# But we do not want to impose extra limitations, so we say `type*`, meaning: no conditions on type whatsoever.

# %%
query = '''
line
  sign question=1 type*
  <: sign missing=1
  <: sign damage=1
'''

# %%
results = A.search(query)
A.show(results, start=4, end=4, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
#   0.56s 7 results
# <p><b>result</b> <i>4</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P386470" title="P386470 reverse:15'" sec="P386470 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[u2?-sze]-et#-bu-u2-[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[u2?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sze]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">et#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# # Show your own tuples
#
# So far we have `show()`n the results of searches.
# But you can also construct your own tuples and show them.
#
# Whereas you can use search to get a pretty good approximation of what you want, most of the times
# you do not arrive precisely at your destination.
#
# Here is an example where we use search to come close, and then work our way to produce the end result.
#
# ## More missing than damaged
#
# We look for lines that have more missing signs than damaged signs.
#
# In our search templates we cannot formulate that a feature has different values on two nodes in the template.
# We could spell out all possible combinations of values and make a search template for each of them,
# but that is needlessly complex.
#
# Let's first use search to find all clauses containing missing and damaged signs.

# %%
query = '''
line
  sign missing
  sign damage
'''
results = A.search(query)
# Out:
#   0.32s 9900 results

# %% [markdown]
# Now the hand coding begins. We are going to extract the tuples we want.

# %%
lines = {}
for (l, m, d) in results:
  lines.setdefault(l, (set(), set()))
  lines[l][0].add(m)
  lines[l][1].add(d)
print(f'{len(lines)} lines')
# Out:
# 3031 lines

# %% [markdown]
# Now we have all lines with both missing and damaged signs, without duplicates.
#
# For each line we have a set with its missing signs and one with its damaged signs.
#
# We filter in order to retain the lines with more missing than damaged signs.
# We put all missing signs in one big set and all damaged signs in one big set.

# %%
answer = []
missing = set()
damage = set()

for (l, (m, d)) in lines.items():
  if len(m) > len(d):
    answer.append((l, *m, *d))
    missing |= m
    damage |= d
len(answer)
# Out:
# 1345

# %%
answer[0]
# Out:
# (230894, 955, 956, 954)

# %% [markdown]
# We are going to make a dictionary of highligts: one color for the missing signs and one for the damaged.

# %%
highlights = {}
colorM = 'lightsalmon'
colorD = 'mediumaquamarine'
for s in missing:
  highlights[s] = colorM
for s in damage:
  highlights[s] = colorD

# %% [markdown]
# And now we can show them:

# %%
A.table(answer, start=1, end=10, highlights=highlights)
# Out:
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">line</th><th>sign</th><th>sign</th><th>sign</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509377" title="show this document on CDLI" sec="P509377 reverse:2">P509377 reverse:2</a></td><td class="tf"><span class="txtp">_sze_ u3 _ku3-babbar_ ad-di-na-<span  class="hl"  style="background-color: mediumaquamarine;" >ak#-</span><span  class="hl"  style="background-color: lightsalmon;" >[kum-</span><span  class="hl"  style="background-color: lightsalmon;" >ma]</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[kum-</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >ma]</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >ak#-</span></span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P481192" title="show this document on CDLI" sec="P481192 obverse:10'">P481192 obverse:10'</a></td><td class="tf"><span class="txtp">_a-sza3_ u2-ul e-<span  class="hl"  style="background-color: mediumaquamarine;" >ri#-</span><span  class="hl"  style="background-color: lightsalmon;" >[isz </span><span  class="hl"  style="background-color: lightsalmon;" >...]</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[isz </span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >...]</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >ri#-</span></span></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P481192" title="show this document on CDLI" sec="P481192 obverse:13'">P481192 obverse:13'</a></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[x </span><span  class="hl"  style="background-color: lightsalmon;" >(x)] </span>x-a-tum it-<span  class="hl"  style="background-color: mediumaquamarine;" >ta#-</span>za-az-za i-mu-ut-ta</span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[x </span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >(x)] </span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >ta#-</span></span></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P481192" title="show this document on CDLI" sec="P481192 obverse:14'">P481192 obverse:14'</a></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[...] </span>x tup-<span  class="hl"  style="background-color: mediumaquamarine;" >pu# </span><span  class="hl"  style="background-color: lightsalmon;" >[x </span><span  class="hl"  style="background-color: lightsalmon;" >x] </span>a-<span  class="hl"  style="background-color: mediumaquamarine;" >na# </span><span  class="hl"  style="background-color: mediumaquamarine;" >ma#-</span>har a-<span  class="hl"  style="background-color: lightsalmon;" >[wi-</span><span  class="hl"  style="background-color: lightsalmon;" >le-</span><span  class="hl"  style="background-color: lightsalmon;" >e]</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[...] </span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[x </span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >x] </span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[wi-</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >le-</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >e]</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >na# </span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >ma#-</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >pu# </span></span></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P481192" title="show this document on CDLI" sec="P481192 reverse:13'">P481192 reverse:13'</a></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[x </span><span  class="hl"  style="background-color: lightsalmon;" >(x)] </span>x-ma a-na ma-ah-<span  class="hl"  style="background-color: mediumaquamarine;" >ri#-</span><span  class="hl"  style="background-color: mediumaquamarine;" >ka# </span>il-li-kam x x <span  class="hl"  style="background-color: lightsalmon;" >[(x) </span><span  class="hl"  style="background-color: lightsalmon;" >(x)]</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >(x)]</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[(x) </span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[x </span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >(x)] </span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >ri#-</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >ka# </span></span></td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P389256" title="show this document on CDLI" sec="P389256 obverse:4'">P389256 obverse:4'</a></td><td class="tf"><span class="txtp">uz-ni-ia <span  class="hl"  style="background-color: mediumaquamarine;" >li#-</span><span  class="hl"  style="background-color: lightsalmon;" >[x </span><span  class="hl"  style="background-color: lightsalmon;" >...]</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[x </span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >...]</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >li#-</span></span></td></tr>
# <tr class="tf"><td class="tf">7</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P389256" title="show this document on CDLI" sec="P389256 left:2">P389256 left:2</a></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[...] </span>i-di-<span  class="hl"  style="background-color: mediumaquamarine;" >in# </span><span  class="hl"  style="background-color: lightsalmon;" >[...]</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[...] </span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[...]</span></span></td><td class="tf"><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >in# </span></span></td></tr>
# <tr class="tf"><td class="tf">8</td><td

# %% [markdown]
# As you see, you have total control.

# %% [markdown]
# ---
#
# All chapters:
#
# * **[start](start.ipynb)** become an expert in creating pretty displays of your text structures
# * **[display](display.ipynb)** become an expert in creating pretty displays of your text structures
# * **search** turbo charge your hand-coding with search templates
# * **[exportExcel](exportExcel.ipynb)** make tailor-made spreadsheets out of your results
# * **[share](share.ipynb)** draw in other people's data and let them use yours
# * **[similarLines](similarLines.ipynb)** spot the similarities between lines
#
# ---
#
# See the [cookbook](cookbook) for recipes for small, concrete tasks.
