# %% [markdown]
# <img align="right" src="images/tf.png" width="128"/>
# <img align="right" src="images/ninologo.png" width="128"/>
# <img align="right" src="images/dans.png" width="128"/>
#
# ---
#
# To get started: consult [start](start.ipynb)
#
# ---
#
# # Sharing data features
#
# ## Explore additional data
#
# Once you analyse a corpus, it is likely that you produce data that others can reuse.
# Maybe you have defined a set of proper name occurrences, or special numerals, or you have computed part-of-speech assignments.
#
# It is possible to turn these insights into *new features*, i.e. new `.tf` files with values assigned to specific nodes.
#
# ## Make your own data
#
# New data is a product of your own methods and computations in the first place.
# But how do you turn that data into new TF features?
# It turns out that the last step is not that difficult.
#
# If you can shape your data as a mapping (dictionary) from node numbers (integers) to values
# (strings or integers), then TF can turn that data into a feature file for you with one command.
#
# ## Share your new data
# You can then easily share your new features on GitHub, so that your colleagues everywhere
# can try it out for themselves.
#
# You can add such data on the fly, by passing a `mod={org}/{repo}/{path}` parameter,
# or a bunch of them separated by commas.
#
# If the data is there, it will be auto-downloaded and stored on your machine.
#
# Let's do it.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import collections

from tf.app import use

# %%
A = use('oldbabylonian', hoist=globals(), check=True)
# Out:
# TF app is up-to-date.
# Using annotation/app-oldbabylonian commit 1f12c687368dec8eabefe35264a30f4d5eac3fb4 (=latest)
#   in /Users/dirk/text-fabric-data/__apps__/oldbabylonian.
# No new data release available online.
# Using Nino-cunei/oldbabylonian/tf - 1.0.1 rv1.0.1 (=latest) in /Users/dirk/text-fabric-data.
# <b>Documentation:</b> <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs/" title="provenance of Old Babylonian Letters 1900-1600: Cuneiform tablets ">OLDBABYLONIAN</a> <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs/transcription.md" title="How TF features represent ATF">Character table</a> <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="OLDBABYLONIAN feature documentation">Feature docs</a> <a target="_blank" href="https://github.com/annotation/app-oldbabylonian" title="oldbabylonian API documentation">oldbabylonian API</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/" title="text-fabric-api">Text-Fabric API 7.4.10</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Use/Search/" title="Search Templates Introduction and Reference">Search Reference</a><details open><summary><b>Loaded features</b>:</summary>
# <p><b>Old Babylonian Letters 1900-1600: Cuneiform tablets </b>: <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/after.tf">after</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/afterr.tf">afterr</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/afteru.tf">afteru</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/atf.tf">atf</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/atfpost.tf">atfpost</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/atfpre.tf">atfpre</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/col.tf">col</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/collated.tf">collated</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/collection.tf">collection</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/comment.tf">comment</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/damage.tf">damage</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/det.tf">det</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/docnote.tf">docnote</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/docnumber.tf">docnumber</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/excised.tf">excised</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/face.tf">face</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/flags.tf">flags</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/fraction.tf">fraction</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/grapheme.tf">grapheme</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/ ...
# <style>
# @font-face {
#   font-family: "Santakku";
#   src:
#     local("Santakku.ttf"),
#     url("https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true");
# }
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: normal;
#     text-decoration: none;
# }
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: monospace;
#     font-size: normal;
#     text-decoration: none;
# }
# .txtr,.txtr a:visited,.txtr a:link {
#     font-family: serif;
#     font-size: large;
#     text-decoration: none;
# }
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Santakku;
#     font-size: x-large;
#     text-decoration: none;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .pnum {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .meta {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: row nowrap;
# }
# .features,.comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .children {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     border: 0;
#     background-color: #ffffff;
# }
# .children.document {
#     flex-flow: column nowrap;
# }
# .children.face {
#     flex-flow: column nowrap;
# }
# .children.line {
#     align-items: stretch;
#     flex-flow: row nowrap;
# }
# .children.cluster {
#     flex-flow: row wrap;
# }
# .children.line {
#     align-items: stretch;
#     flex-flow: row nowrap;
# }
# .children.sign {
#     flex-flow: column nowrap;
# }
# .contnr {
#     width: fit-content;
# }
# .contnr.document,.contnr.face,
# .contnr.line,
# .contnr.cluster,
# .contnr.word,
# .contnr.sign {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5em 0.1em 0.1em 0.1em;
#     margin: 0.8em 0.1em 0.1em 0.1em;
#     border-radius: 0.2em;
#     border-style: solid;
#     border-width: 0.2em;
#     font-size: small;
# }
# .contnr.document,.contnr.face {
#     border-color: #bb8800;
# }
# .contnr.line {
#     border-color: #0088bb;
# }
# .contnr.cluster {
#     flex-flow: row wrap;
#     border: 0;
# }
# .contnr.word {
#     border-color: #44bbff;
# }
# .contnr.sign {
#     border-color: #bbbbbb;
# }
# .contnr.hl {
#     background-color: #ffee66;
# }
# .lbl.document,.lbl.face,
# .lbl.line,
# .lbl.cluster,
# .lbl.sign,.lbl.word {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     font-size: small;
#     display: block;
# }
# .lbl.document,.lbl.face {
#     border-color: #bb8800;
#     border-width: 0.3em;
#     border-radius: 0.3em;
#     color: #bb8800;
# }
# .lbl.line {
#     border-color: #0088bb;
#     border-width: 0.3em;
#     border-radius: 0.3em;
#     color: #0088bb;
# }
# .lbl.cluster {
#     border-color: #dddddd;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     color: #0000cc;
# }
# .lbl.word {
#     border-color: #44bbff;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     font-size: medium;
#     color: #000000;
# }
# .lbl.sign {
#     border-color: #bbbbbb;
#     border-width: 0.1em;
#     border-radius: 0.1em;
#     font-size: small;
#     color: #000000;
# }
# .op {
#     padding:  0.5em 0.1em 0.1em 0.1em;
#     margin: 0.8em 0.1em 0.1em 0.1em;
#     font-family: monospace;
#     font-size: x-large;
#     font-weight: bold;
# }
# .name {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .period {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .text {
#     font-family: sans-serif;
#     font-size: x-small;
#     color: #000000;
# }
# .srcln {
#     font-family: monospace;
#     font-size: medium;
#     color: #000000;
# }
# .srclnnum {
#     font-family: monospace;
#     font-size: x-small;
#     color: #0000bb;
# }
# .comment {
#     color: #7777dd;
#     font-family: monospace;
#     font-size: small;
# }
# .operator {
#     color: #ff77ff;
#     font-size: large;
# }
# /* LANGUAGE: superscript and subscript */
#
# /* cluster */
# .det {
#     vertical-align: super;
# }
# /* cluster */
# .langalt {
#     vertical-align: sub;
# }
# /* REDACTIONAL: line over or under  */
#
# /* flag */
# .collated {
#     font-weight: bold;
#     text-decoration: underline;
# }
# /* cluster */
# .excised {
#     color: #dd0000;
#     text-decoration: line-through;
# }
# /* cluster */
# .supplied {
#     color: #0000ff;
#     text-decoration: overline;
# }
# /* flag */
# .remarkable {
#     font-weight: bold;
#     text-decoration: overline;
# }
#
# /* UNSURE: italic*/
#
# /* cluster */
# .uncertain {
#     font-style: italic
# }
# /* flag */
# .question {
#     font-weight: bold;
#     font-style: italic
# }
#
# /* BROKEN: text-shadow */
#
# /* cluster */
# .missing {
#     color: #999999;
#     text-shadow: #bbbbbb 1px 1px;
# }
# /* flag */
# .damage {
#     font-weight: bold;
#     color: #999999;
#     text-shadow: #bbbbbb 1px 1px;
# }
# .empty {
#   color: #ff0000;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlup {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>
# <details open><summary><b>API members</b>:</summary>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">C Computed</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Call AllComputeds</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Cs ComputedString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">E Edge</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Eall AllEdges</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Es EdgeString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ensureLoaded</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">TF</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ignored</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">loadLog</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Locality/#locality" title="doc">L Locality</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">cache</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">error</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">indent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">info</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">reset</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">N Nodes</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKey</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKeyTuple</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">otypeRank</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortNodes</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">F Feature</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fall AllFeatures</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fs FeatureString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Search/#search" title="doc">S Search</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Text/#text" title="doc">T Text</a></details>

# %% [markdown]
# # Making data
#
# We illustrate the data creation part by creating a new feature, `ummama`.
# The idea is that we mark every sign reading that occurs between `um-ma` and `ma` some where in the first 3 lines of a face.
# We want to mark every occurrence of such signs elsewhere in the corpus with `ummama=1`.
#
# We only do it if the sign between the `um-ma` and `ma` (which must be on the same line) is not missing, damaged, or questionable.
#
# The easiest way to get started is to run a query:

# %%
query = '''
line ln<4
  =: sign reading=um missing# damage# question#
  <: sign reading=ma missing# damage# question#
% the next sign is the one that we are after
  < sign missing# damage# question#
  < sign reading=ma missing# damage# question#
'''

# %%
results = A.search(query)
# Out:
#   1.89s 3466 results

# %%
A.table(results, end=10)
# Out:
# <table><tr><th>n</th><th>p</th><th>line</th><th>sign</th><th>sign</th><th>sign</th><th>sign</th></tr>
# <tr><td>1</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:3">P509373 obverse:3</a></td><td><span class="txtp"><span  class="hl" >um-</span><span  class="hl" >ma </span><span  class="hl" >_{d}</span>en-lil2_-sza-du-u2-ni-<span  class="hl" >ma</span></span></td><td><span class="txtp"><span  class="hl" >um-</span></span></td><td><span class="txtp"><span  class="hl" >ma </span></span></td><td><span class="txtp"><span  class="hl" >_{d}</span></span></td><td><span class="txtp"><span  class="hl" >ma</span></span></td></tr>
# <tr><td>2</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:3">P509373 obverse:3</a></td><td><span class="txtp"><span  class="hl" >um-</span><span  class="hl" >ma </span>_{d}<span  class="hl" >en-</span>lil2_-sza-du-u2-ni-<span  class="hl" >ma</span></span></td><td><span class="txtp"><span  class="hl" >um-</span></span></td><td><span class="txtp"><span  class="hl" >ma </span></span></td><td><span class="txtp"><span  class="hl" >en-</span></span></td><td><span class="txtp"><span  class="hl" >ma</span></span></td></tr>
# <tr><td>3</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:3">P509373 obverse:3</a></td><td><span class="txtp"><span  class="hl" >um-</span><span  class="hl" >ma </span>_{d}en-<span  class="hl" >lil2_-</span>sza-du-u2-ni-<span  class="hl" >ma</span></span></td><td><span class="txtp"><span  class="hl" >um-</span></span></td><td><span class="txtp"><span  class="hl" >ma </span></span></td><td><span class="txtp"><span  class="hl" >lil2_-</span></span></td><td><span class="txtp"><span  class="hl" >ma</span></span></td></tr>
# <tr><td>4</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:3">P509373 obverse:3</a></td><td><span class="txtp"><span  class="hl" >um-</span><span  class="hl" >ma </span>_{d}en-lil2_-<span  class="hl" >sza-</span>du-u2-ni-<span  class="hl" >ma</span></span></td><td><span class="txtp"><span  class="hl" >um-</span></span></td><td><span class="txtp"><span  class="hl" >ma </span></span></td><td><span class="txtp"><span  class="hl" >sza-</span></span></td><td><span class="txtp"><span  class="hl" >ma</span></span></td></tr>
# <tr><td>5</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:3">P509373 obverse:3</a></td><td><span class="txtp"><span  class="hl" >um-</span><span  class="hl" >ma </span>_{d}en-lil2_-sza-<span  class="hl" >du-</span>u2-ni-<span  class="hl" >ma</span></span></td><td><span class="txtp"><span  class="hl" >um-</span></span></td><td><span class="txtp"><span  class="hl" >ma </span></span></td><td><span class="txtp"><span  class="hl" >du-</span></span></td><td><span class="txtp"><span  class="hl" >ma</span></span></td></tr>
# <tr><td>6</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:3">P509373 obverse:3</a></td><td><span class="txtp"><span  class="hl" >um-</span><span  class="hl" >ma </span>_{d}en-lil2_-sza-du-<span  class="hl" >u2-</span>ni-<span  class="hl" >ma</span></span></td><td><span class="txtp"><span  class="hl" >um-</span></span></td><td><span class="txtp"><span  class="hl" >ma </span></span></td><td><span class="txtp"><span  class="hl" >u2-</span></span></td><td><span class="txtp"><span  class="hl" >ma</span></span></td></tr>
# <tr><td>7</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:3">P509373 obverse:3</a></td><td><span class="txtp"><span  class="hl" >um-</span><span  class="hl" >ma </span>_{d}en-lil2_-sza-du-u2-<span  class="hl" >ni-</span><span  class="hl" >ma</span></span></td><td><span class="txtp"><span  class="hl" >um-</span></span></td><td><span class="txtp"><span  class="hl" >ma </span></span></td><td><span class="txtp"><span  class="hl" >ni-</span></span></td><td><span class="txtp"><span  class="hl" >ma</span></span></td></tr>
# <tr><td>8</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P481190" title="show this document on CDLI" sec="P481190 obverse:3">P481190 obverse:3</a></td><td><span class="txtp"><span  class="hl" >um-</span><span  class="hl" >ma </span>nu#-ur2#-<span  class="hl" >i3-</span>li2-szu-<span  class="hl" >ma</span></span></td><td><span class="txtp"><span  class="hl" >um-</span></span></td><td><span class="txtp"><span  class="hl" >ma </span></span></td><td><span class="txtp"><span  class="hl" >i3-</span></span></td><td><span class="txtp"><span  class="hl" >ma</span></span></td></tr>
# <tr><td>9</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P481190" title="show this document on CDLI" sec="P481190 obverse:3">P481190 obverse:3</a></td><td><span class="txtp"><span  class="hl" >um-</span><span  class="hl" >ma </span>nu#-ur2#-i3-<span  class="hl" >li2-</span>szu-<span  class="hl" >ma</span></span></td><td><span class="txtp"><span  class="hl" >um-</span></span></td><td><span class="txtp"><span  class="hl" >ma </span></span></td><td><span class="txtp"><span  class="hl" >li2-</span></span></td><td><span class="txtp"><span  class="hl" >ma</span></span></td></tr>
# <tr><td>10</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P481190" title="show this document on CDLI" sec="P481190 obverse:3">P481190 obverse:3</a></td><td><span class="txtp"><span  class="hl" >um-</span><span  class="hl" >ma </span>nu#-ur2#-i3-li2-<span  class="hl" >szu-</span><span  class="hl" >ma</span></span></td><td><span class="txtp"><span  class="hl" >um-</span></span></td><td><span class="txtp"><span  class="hl" >ma </span></span></td><td><span class="txtp"><span  class="hl" >szu-</span></span></td><td><span class="txtp"><span  class="hl" >ma</span></span></td></tr></table>

# %% [markdown]
# Observe how the signs between `um-ma` and `ma` are picked up, except the damaged `nu` and `ur2`.
#
# First we are collect these readings, and survey the frequencies in the result.
#
# Some signs do not have a reading, but then they have a grapheme.
# If they do not have a grapheme, they might be comment signs, and we skip them.

# %%
umaReadings = collections.Counter()

# collect

for (line, um, ma1, sign, ma2) in results:
  reading = F.reading.v(sign) or F.grapheme.v(sign)
  if not reading:
    continue
  umaReadings[reading] += 1
  
# show

print(f'Found {len(umaReadings)} distinct readings')
limit = 20

for (reading, amount) in sorted(
  umaReadings.items(),
  key=lambda x: (-x[1], x[0]),
)[0:limit]:
  print(f'{reading:<6} {amount:>4} x')
print(f' ... and {len(umaReadings) - limit} more ...')
# Out:
# Found 249 distinct readings
# d       324 x
# a       133 x
# ra      128 x
# mu      123 x
# bi      121 x
# am      112 x
# ha       99 x
# na       95 x
# suen     78 x
# i        66 x
# ni       66 x
# szu      66 x
# utu      61 x
# um       59 x
# li2      55 x
# tum      55 x
# ma       50 x
# marduk   50 x
# nu       43 x
# sza      41 x
#  ... and 229 more ...

# %% [markdown]
# Now we visit all signs in the whole corpus and check whether their reading or grapheme is in this set.
# If so, we give that sign a value 1 in the dictionary `ummama`.

# %%
ummama = {}

allSigns = F.otype.s('sign')

for s in allSigns:
  reading = F.reading.v(s) or F.grapheme.v(s)
  if not reading:
    continue
  if reading in umaReadings:
    ummama[s] = 1
    
print(f'Assigned `ummama=1` to {len(ummama)} sign occurrences out of {len(allSigns)}')
# Out:
# Assigned `ummama=1` to 182222 sign occurrences out of 203219

# %% [markdown]
# Note that the majority of all signs also occurs between `um-ma` and `ma` at the start of a document.
#
# Maybe this is an indication that we are not capturing the idea of selecting specific signs,
# we may have to strengthen our search criterion.
#
# But that is beyond this tutorial. We suppose these ummama words form a valueable set that we want to share.

# %% [markdown]
# # Saving data
#
# The [documentation](https://annotation.github.io/text-fabric/Api/Fabric/#saving-features) explains how to save this data into a text-fabric
# data file.
#
# We choose a location where to save it, the `exercises` repository in the `Nino-cunei` organization, in the folder `analysis`.
#
# In order to do this, we restart the TF api, but now with the desired output location in the `locations` parameter.

# %%
import os

# %%
GITHUB = os.path.expanduser('~/github')
ORG = 'Nino-cunei'
REPO = 'exercises'
PATH = 'analysis'
VERSION = A.version

# %% [markdown]
# Note the version: we have built the version against a specific version of the data:

# %%
A.version
# Out:
# '1.0.1'

# %% [markdown]
# Later on, we pass this version on, so that users of our data will get the shared data in exactly the same version as their core data.

# %% [markdown]
# We have to specify a bit of metadata for this feature:

# %%
metaData = {
  'ummama': dict(
    valueType='int',
    description='reading occurs somewhere between um-ma and ma',
    creator='Dirk Roorda',
  ),
}

# %% [markdown]
# Now we can give the save command:

# %%
TF.save(nodeFeatures=dict(ummama=ummama), metaData=metaData, location=f'{GITHUB}/{ORG}/{REPO}/{PATH}/tf', module=VERSION)
# Out:
#    |     0.22s T ummama               to /Users/dirk/github/Nino-cunei/exercises/analysis/tf/1.0.1
# True

# %% [markdown]
# # Sharing data
#
# How to share your own data is explained in the
# [documentation](https://annotation.github.io/text-fabric/Api/Data/).
#
# Here we show it step by step for the `ummama` feature.

# %% [markdown]
# ## Zip the data
#
# We need to zip the data in exactly the right directory structure. Text-Fabric can do that for us:

# %%
# %%sh
#
# text-fabric-zip Nino-cunei/exercises/analysis/tf
# Out:
# True
# Create release data for Nino-cunei/exercises/analysis/tf
# zip files end up in /Users/dirk/Downloads/Nino-cunei-release/exercises
# zipping Nino-cunei/exercises      1.0.1 with   1 features ==> analysis-tf-1.0.1.zip

# %% [markdown]
# Now you have the file in the desired structure in your Downloads folder.
#
# ## Put the data on Github
#
# The next thing is: make a new release in your Github directory, in this case Nino-cunei/exercises, and attach
# the zip file as a binary.
#
# You have to do this in your web browser, on the Github website.
#
# Here is the result for our case
#
# ![ummama](images/ummama.png)

# %% [markdown]
# # Use the data
#
# We can use the data by calling it up when we say `use('oldbabylonian', ...)`.
#
# Here is how:

# %%
A = use('oldbabylonian', hoist=globals(), check=True, mod='Nino-cunei/exercises/analysis/tf')
# Out:
# TF app is up-to-date.
# Using annotation/app-oldbabylonian commit 1f12c687368dec8eabefe35264a30f4d5eac3fb4 (=latest)
#   in /Users/dirk/text-fabric-data/__apps__/oldbabylonian.
# No new data release available online.
# Using Nino-cunei/oldbabylonian/tf - 1.0.1 rv1.0.1 (=latest) in /Users/dirk/text-fabric-data.
# 	downloading Nino-cunei/exercises - 1.0.1 rv0.1
# 	from https://github.com/Nino-cunei/exercises/releases/download/v0.1/analysis-tf-1.0.1.zip ...
# 	unzipping ...
# 	saving Nino-cunei/exercises - 1.0.1 rv0.1
# 	saved Nino-cunei/exercises - 1.0.1 rv0.1
# Using Nino-cunei/exercises/analysis/tf - 1.0.1 rv0.1 (=latest) in /Users/dirk/text-fabric-data
# <b>Documentation:</b> <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs/" title="provenance of Old Babylonian Letters 1900-1600: Cuneiform tablets ">OLDBABYLONIAN</a> <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs/transcription.md" title="How TF features represent ATF">Character table</a> <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="OLDBABYLONIAN feature documentation">Feature docs</a> <a target="_blank" href="https://github.com/annotation/app-oldbabylonian" title="oldbabylonian API documentation">oldbabylonian API</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/" title="text-fabric-api">Text-Fabric API 7.4.10</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Use/Search/" title="Search Templates Introduction and Reference">Search Reference</a><details open><summary><b>Loaded features</b>:</summary>
# <p><b>Old Babylonian Letters 1900-1600: Cuneiform tablets </b>: <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/after.tf">after</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/afterr.tf">afterr</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/afteru.tf">afteru</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/atf.tf">atf</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/atfpost.tf">atfpost</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/atfpre.tf">atfpre</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/col.tf">col</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/collated.tf">collated</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/collection.tf">collection</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/comment.tf">comment</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/damage.tf">damage</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/det.tf">det</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/docnote.tf">docnote</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/docnumber.tf">docnumber</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/excised.tf">excised</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/face.tf">face</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/flags.tf">flags</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/fraction.tf">fraction</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/grapheme.tf">grapheme</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/ ...
# <style>
# @font-face {
#   font-family: "Santakku";
#   src:
#     local("Santakku.ttf"),
#     url("https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true");
# }
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: normal;
#     text-decoration: none;
# }
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: monospace;
#     font-size: normal;
#     text-decoration: none;
# }
# .txtr,.txtr a:visited,.txtr a:link {
#     font-family: serif;
#     font-size: large;
#     text-decoration: none;
# }
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Santakku;
#     font-size: x-large;
#     text-decoration: none;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .pnum {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .meta {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: row nowrap;
# }
# .features,.comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .children {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     border: 0;
#     background-color: #ffffff;
# }
# .children.document {
#     flex-flow: column nowrap;
# }
# .children.face {
#     flex-flow: column nowrap;
# }
# .children.line {
#     align-items: stretch;
#     flex-flow: row nowrap;
# }
# .children.cluster {
#     flex-flow: row wrap;
# }
# .children.line {
#     align-items: stretch;
#     flex-flow: row nowrap;
# }
# .children.sign {
#     flex-flow: column nowrap;
# }
# .contnr {
#     width: fit-content;
# }
# .contnr.document,.contnr.face,
# .contnr.line,
# .contnr.cluster,
# .contnr.word,
# .contnr.sign {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5em 0.1em 0.1em 0.1em;
#     margin: 0.8em 0.1em 0.1em 0.1em;
#     border-radius: 0.2em;
#     border-style: solid;
#     border-width: 0.2em;
#     font-size: small;
# }
# .contnr.document,.contnr.face {
#     border-color: #bb8800;
# }
# .contnr.line {
#     border-color: #0088bb;
# }
# .contnr.cluster {
#     flex-flow: row wrap;
#     border: 0;
# }
# .contnr.word {
#     border-color: #44bbff;
# }
# .contnr.sign {
#     border-color: #bbbbbb;
# }
# .contnr.hl {
#     background-color: #ffee66;
# }
# .lbl.document,.lbl.face,
# .lbl.line,
# .lbl.cluster,
# .lbl.sign,.lbl.word {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     font-size: small;
#     display: block;
# }
# .lbl.document,.lbl.face {
#     border-color: #bb8800;
#     border-width: 0.3em;
#     border-radius: 0.3em;
#     color: #bb8800;
# }
# .lbl.line {
#     border-color: #0088bb;
#     border-width: 0.3em;
#     border-radius: 0.3em;
#     color: #0088bb;
# }
# .lbl.cluster {
#     border-color: #dddddd;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     color: #0000cc;
# }
# .lbl.word {
#     border-color: #44bbff;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     font-size: medium;
#     color: #000000;
# }
# .lbl.sign {
#     border-color: #bbbbbb;
#     border-width: 0.1em;
#     border-radius: 0.1em;
#     font-size: small;
#     color: #000000;
# }
# .op {
#     padding:  0.5em 0.1em 0.1em 0.1em;
#     margin: 0.8em 0.1em 0.1em 0.1em;
#     font-family: monospace;
#     font-size: x-large;
#     font-weight: bold;
# }
# .name {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .period {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .text {
#     font-family: sans-serif;
#     font-size: x-small;
#     color: #000000;
# }
# .srcln {
#     font-family: monospace;
#     font-size: medium;
#     color: #000000;
# }
# .srclnnum {
#     font-family: monospace;
#     font-size: x-small;
#     color: #0000bb;
# }
# .comment {
#     color: #7777dd;
#     font-family: monospace;
#     font-size: small;
# }
# .operator {
#     color: #ff77ff;
#     font-size: large;
# }
# /* LANGUAGE: superscript and subscript */
#
# /* cluster */
# .det {
#     vertical-align: super;
# }
# /* cluster */
# .langalt {
#     vertical-align: sub;
# }
# /* REDACTIONAL: line over or under  */
#
# /* flag */
# .collated {
#     font-weight: bold;
#     text-decoration: underline;
# }
# /* cluster */
# .excised {
#     color: #dd0000;
#     text-decoration: line-through;
# }
# /* cluster */
# .supplied {
#     color: #0000ff;
#     text-decoration: overline;
# }
# /* flag */
# .remarkable {
#     font-weight: bold;
#     text-decoration: overline;
# }
#
# /* UNSURE: italic*/
#
# /* cluster */
# .uncertain {
#     font-style: italic
# }
# /* flag */
# .question {
#     font-weight: bold;
#     font-style: italic
# }
#
# /* BROKEN: text-shadow */
#
# /* cluster */
# .missing {
#     color: #999999;
#     text-shadow: #bbbbbb 1px 1px;
# }
# /* flag */
# .damage {
#     font-weight: bold;
#     color: #999999;
#     text-shadow: #bbbbbb 1px 1px;
# }
# .empty {
#   color: #ff0000;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlup {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>
# <details open><summary><b>API members</b>:</summary>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">C Computed</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Call AllComputeds</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Cs ComputedString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">E Edge</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Eall AllEdges</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Es EdgeString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ensureLoaded</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">TF</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ignored</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">loadLog</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Locality/#locality" title="doc">L Locality</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">cache</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">error</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">indent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">info</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">reset</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">N Nodes</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKey</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKeyTuple</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">otypeRank</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortNodes</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">F Feature</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fall AllFeatures</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fs FeatureString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Search/#search" title="doc">S Search</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Text/#text" title="doc">T Text</a></details>

# %% [markdown]
# Above you see a new section in the feature list: **Nino-cunei/exercises/analysis/tf** with our foreign feature in it: `ummama`.
#
# Now, suppose did not know much about this feature, then we would like to do a few basic checks:

# %%
F.ummama.freqList()
# Out:
# ((1, 182222),)

# %% [markdown]
# We see that the feature has only one value, `1`, and that 182222 nodes have it.

# %% [markdown]
# Which nodes have a ummmama feature?

# %%
{F.otype.v(n) for n in N() if F.ummama.v(n)}
# Out:
# {'sign'}

# %% [markdown]
# Only signs have the feature.
#
# Let's have a look at a table of some ummama signs.

# %%
results = A.search('''
sign ummama
''')
# Out:
#   0.32s 182222 results

# %%
A.table(results, start=1, end=20)
# Out:
# <table><tr><th>n</th><th>p</th><th>sign</th></tr>
# <tr><td>1</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:1">P509373 obverse:1</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:1" sec="P509373 obverse:1"><span class="txtp"><span  class="hl" >[a-</span></span></a></td></tr>
# <tr><td>2</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:1">P509373 obverse:1</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:1" sec="P509373 obverse:1"><span class="txtp"><span  class="hl" >na] </span></span></a></td></tr>
# <tr><td>3</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:1">P509373 obverse:1</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:1" sec="P509373 obverse:1"><span class="txtp"><span  class="hl" >_{d}</span></span></a></td></tr>
# <tr><td>4</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:1">P509373 obverse:1</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:1" sec="P509373 obverse:1"><span class="txtp"><span  class="hl" >suen_-</span></span></a></td></tr>
# <tr><td>5</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:1">P509373 obverse:1</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:1" sec="P509373 obverse:1"><span class="txtp"><span  class="hl" >i-</span></span></a></td></tr>
# <tr><td>6</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:1">P509373 obverse:1</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:1" sec="P509373 obverse:1"><span class="txtp"><span  class="hl" >[din-</span></span></a></td></tr>
# <tr><td>7</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:1">P509373 obverse:1</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:1" sec="P509373 obverse:1"><span class="txtp"><span  class="hl" >nam]</span></span></a></td></tr>
# <tr><td>8</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:2">P509373 obverse:2</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:2" sec="P509373 obverse:2"><span class="txtp"><span  class="hl" >qi2-</span></span></a></td></tr>
# <tr><td>9</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:2">P509373 obverse:2</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:2" sec="P509373 obverse:2"><span class="txtp"><span  class="hl" >[ma]</span></span></a></td></tr>
# <tr><td>10</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:3">P509373 obverse:3</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:3" sec="P509373 obverse:3"><span class="txtp"><span  class="hl" >um-</span></span></a></td></tr>
# <tr><td>11</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:3">P509373 obverse:3</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:3" sec="P509373 obverse:3"><span class="txtp"><span  class="hl" >ma </span></span></a></td></tr>
# <tr><td>12</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:3">P509373 obverse:3</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:3" sec="P509373 obverse:3"><span class="txtp"><span  class="hl" >_{d}</span></span></a></td></tr>
# <tr><td>13</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:3">P509373 obverse:3</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:3" sec="P509373 obverse:3"><span class="txtp"><span  class="hl" >en-</span></span></a></td></tr>
# <tr><td>14</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:3">P509373 obverse:3</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:3" sec="P509373 obverse:3"><span class="txtp"><span  class="hl" >lil2_-</span></span></a></td></tr>
# <tr><td>15</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:3">P509373 obverse:3</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:3" sec="P509373 obverse:3"><span class="txtp"><span  class="hl" >sza-</span></span></a></td></tr>
# <tr><td>16</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:3">P509373 obverse:3</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:3" sec="P509373 obverse:3"><span class="txtp"><span  class="hl" >du-</span></span></a></td></tr>
# <tr><td>17</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:3">P509373 obverse:3</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:3" sec="P509373 obverse:3"><span class="txtp"><span  class="hl" >u2-</span></span></a></td></tr>
# <tr><td>18</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:3">P509373 obverse:3</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:3" sec="P509373 obverse:3"><span class="txtp"><span  class="hl" >ni-</span></span></a></td></tr>
# <tr><td>19</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:3">P509373 obverse:3</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:3" sec="P509373 obverse:3"><span class="txtp"><span  class="hl" >ma</span></span>

# %% [markdown]
# Now let's get some non-ummama signs:

# %%
results = A.search('''
sign ummama#
''')
# Out:
#   0.17s 20997 results

# %%
A.table(results, start=1, end=20)
# Out:
# <table><tr><th>n</th><th>p</th><th>sign</th></tr>
# <tr><td>1</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:2">P509373 obverse:2</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:2" sec="P509373 obverse:2"><span class="txtp"><span  class="hl" >bi2-</span></span></a></td></tr>
# <tr><td>2</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:5">P509373 obverse:5</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:5" sec="P509373 obverse:5"><span class="txtp"><span  class="hl" >t,u2-</span></span></a></td></tr>
# <tr><td>3</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:6">P509373 obverse:6</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:6" sec="P509373 obverse:6"><span class="txtp"><span  class="hl" >a2-</span></span></a></td></tr>
# <tr><td>4</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:6">P509373 obverse:6</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:6" sec="P509373 obverse:6"><span class="txtp"><span  class="hl" >gal2 </span></span></a></td></tr>
# <tr><td>5</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:9">P509373 obverse:9</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:9" sec="P509373 obverse:9"><span class="txtp"><span  class="hl" >2(esze3) </span></span></a></td></tr>
# <tr><td>6</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:9">P509373 obverse:9</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:9" sec="P509373 obverse:9"><span class="txtp"><span  class="hl" >gud_</span></span></a></td></tr>
# <tr><td>7</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:10">P509373 obverse:10</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:10" sec="P509373 obverse:10"><span class="txtp"><span  class="hl" >gar3_ </span></span></a></td></tr>
# <tr><td>8</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:10">P509373 obverse:10</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:10" sec="P509373 obverse:10"><span class="txtp"><span  class="hl" >ag-</span></span></a></td></tr>
# <tr><td>9</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:10">P509373 obverse:10</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:10" sec="P509373 obverse:10"><span class="txtp"><span  class="hl" >_uru_ </span></span></a></td></tr>
# <tr><td>10</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:11">P509373 obverse:11</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:11" sec="P509373 obverse:11"><span class="txtp"><span  class="hl" >kam_ </span></span></a></td></tr>
# <tr><td>11</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:12">P509373 obverse:12</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:12" sec="P509373 obverse:12"><span class="txtp"><span  class="hl" >_uru_ </span></span></a></td></tr>
# <tr><td>12</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:12">P509373 obverse:12</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:12" sec="P509373 obverse:12"><span class="txtp"><span  class="hl" >ak-</span></span></a></td></tr>
# <tr><td>13</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:13">P509373 obverse:13</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:13" sec="P509373 obverse:13"><span class="txtp"><span  class="hl" >2(esze3) </span></span></a></td></tr>
# <tr><td>14</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:13">P509373 obverse:13</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:13" sec="P509373 obverse:13"><span class="txtp"><span  class="hl" >szuku_ </span></span></a></td></tr>
# <tr><td>15</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:13">P509373 obverse:13</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:13" sec="P509373 obverse:13"><span class="txtp"><span  class="hl" >_nagar-</span></span></a></td></tr>
# <tr><td>16</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:14">P509373 obverse:14</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:14" sec="P509373 obverse:14"><span class="txtp"><span  class="hl" >gar3 </span></span></a></td></tr>
# <tr><td>17</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:14">P509373 obverse:14</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:14" sec="P509373 obverse:14"><span class="txtp"><span  class="hl" >uru_ </span></span></a></td></tr>
# <tr><td>18</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:14">P509373 obverse:14</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:14" sec="P509373 obverse:14"><span class="txtp"><span  class="hl" >[...]</span></span></a></td></tr>
# <tr><td>19</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:15">P509373 obverse:15</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:15

# %% [markdown]
# Let's get lines with both ummama and non-ummama signs:

# %%
results = A.search('''
line
  sign ummama
  sign ummama#
''')
# Out:
#   0.70s 133412 results

# %%
A.table(results, start=1, end=2, condensed=True)
# Out:
# <table><tr><th>n</th><th>p</th><th>line</th><th>sign</th><th>sign</th><th>sign</th></tr>
# <tr><td>1</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:2">P509373 obverse:2</a></td><td><span class="txtp"><span  class="hl" >qi2-</span><span  class="hl" >bi2-</span><span  class="hl" >[ma]</span></span></td><td><span class="txtp"><span  class="hl" >qi2-</span></span></td><td><span class="txtp"><span  class="hl" >bi2-</span></span></td><td><span class="txtp"><span  class="hl" >[ma]</span></span></td></tr>
# <tr><td>2</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:5">P509373 obverse:5</a></td><td><span class="txtp"><span  class="hl" >li-</span><span  class="hl" >ba-</span><span  class="hl" >al-</span><span  class="hl" >li-</span><span  class="hl" >t,u2-</span><span  class="hl" >u2-</span><span  class="hl" >ka</span></span></td><td><span class="txtp"><span  class="hl" >li-</span></span></td><td><span class="txtp"><span  class="hl" >ba-</span></span></td><td><span class="txtp"><span  class="hl" >al-</span></span></td><td><span class="txtp"><span  class="hl" >li-</span></span></td><td><span class="txtp"><span  class="hl" >t,u2-</span></span></td><td><span class="txtp"><span  class="hl" >u2-</span></span></td><td><span class="txtp"><span  class="hl" >ka</span></span></td></tr></table>

# %% [markdown]
# With highlights:

# %%
highlights = {}

for s in F.otype.s('sign'):
  color = 'lightsalmon' if F.ummama.v(s) else 'mediumaquamarine'
  highlights[s] = color

# %%
A.table(results, start=1, end=10, condensed=True, highlights=highlights)
# Out:
# <table><tr><th>n</th><th>p</th><th>line</th><th>sign</th><th>sign</th><th>sign</th></tr>
# <tr><td>1</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:2">P509373 obverse:2</a></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >qi2-</span><span  class="hl"  style="background-color: mediumaquamarine;" >bi2-</span><span  class="hl"  style="background-color: lightsalmon;" >[ma]</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >qi2-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >bi2-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[ma]</span></span></td></tr>
# <tr><td>2</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:5">P509373 obverse:5</a></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >li-</span><span  class="hl"  style="background-color: lightsalmon;" >ba-</span><span  class="hl"  style="background-color: lightsalmon;" >al-</span><span  class="hl"  style="background-color: lightsalmon;" >li-</span><span  class="hl"  style="background-color: mediumaquamarine;" >t,u2-</span><span  class="hl"  style="background-color: lightsalmon;" >u2-</span><span  class="hl"  style="background-color: lightsalmon;" >ka</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >li-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >ba-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >al-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >li-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >t,u2-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >u2-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >ka</span></span></td></tr>
# <tr><td>3</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:6">P509373 obverse:6</a></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >{disz}</span><span  class="hl"  style="background-color: lightsalmon;" >sze-</span><span  class="hl"  style="background-color: lightsalmon;" >ep-</span><span  class="hl"  style="background-color: lightsalmon;" >_{d}</span><span  class="hl"  style="background-color: lightsalmon;" >suen </span><span  class="hl"  style="background-color: mediumaquamarine;" >a2-</span><span  class="hl"  style="background-color: mediumaquamarine;" >gal2 </span><span  class="hl"  style="background-color: lightsalmon;" >[dumu] </span><span  class="hl"  style="background-color: lightsalmon;" >um-</span><span  class="hl"  style="background-color: lightsalmon;" >mi-</span><span  class="hl"  style="background-color: lightsalmon;" >a-</span><span  class="hl"  style="background-color: lightsalmon;" >mesz_</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >{disz}</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >sze-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >ep-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >_{d}</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >suen </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >a2-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >gal2 </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[dumu] </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >um-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >mi-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >a-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >mesz_</span></span></td></tr>
# <tr><td>4</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:9">P509373 obverse:9</a></td><td><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >2(esze3) </span><span  class="hl"  style="background-color: lightsalmon;" >_a-</span><span  class="hl"  style="background-color: lightsalmon;" >sza3_ </span><span  class="hl"  style="background-color: lightsalmon;" >s,i-</span><span  class="hl"  style="background-color: lightsalmon;" >[bi]-</span><span  class="hl"  style="background-color: lightsalmon;" >it </span><span  class="hl"  style="background-color: lightsalmon;" >{disz}</span><span  class="hl"  style="background-color: lightsalmon;" >[ku]-</span><span  class="hl"  style="background-color: lightsalmon;" >un-</span><span  class="hl"  style="background-color: lightsalmon;" >zu-</span><span  class="hl"  style="background-color: lightsalmon;" >lum </span><span  class="hl"  style="background-color: lightsalmon;" >_sza3-</span><span  class="hl"  style="background-color: mediumaquamarine;" >gud_</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >2(esze3) </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >_a-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >sza3_ </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >s,i-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[bi]-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >it </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >{disz}</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[ku]-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >un-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >zu-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >lum </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >_sza3-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >gud_</span></span></td></tr>
# <tr><td>5</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:10">P509373 obverse:10</a></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >_a-</span><span  class="hl"  style="background-color: lightsalmon;" >sza3 </span><span  class="hl"  style="background-color: lightsalmon;" >a-</span><span  class="hl"  style="background-color: mediumaquamarine;" >gar3_ </span><span  class="hl"  style="background-color: lightsalmon;" >na-</span><span  class="hl"  style="background-color: mediumaquamarine;" >ag-</span><span  class="hl"  style="background-color: lightsalmon;" >[ma-</span><span  class="hl"  style="backgrou

# %% [markdown]
# If we do a pretty display, the `ummama` feature shows up.

# %%
A.show(results, start=1, end=3, condensed=True, withNodes=True, highlights=highlights)
# Out:
# <p><b>line</b> <i>1</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:2" sec="P509373 obverse:2">line <span class="txtn">2</span></a>
#         <a href="#" class="nd">230788</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">qi2-bi2-[ma]</span>
#         <a href="#" class="nd">258163</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">qi2-</span>
#         <a href="#" class="nd">8</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: mediumaquamarine;" >
#
#     <div class="lbl sign">
#         <span class="txtp">bi2-</span>
#         <a href="#" class="nd">9</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[ma]</span>
#         <a href="#" class="nd">10</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>line</b> <i>2</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:5" sec="P509373 obverse:5">line <span class="txtn">5</span></a>
#         <a href="#" class="nd">230791</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li-ba-al-li-t,u2-u2-ka</span>
#         <a href="#" class="nd">258171</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">li-</span>
#         <a href="#" class="nd">32</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ba-</span>
#         <a href="#" class="nd">33</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">al-</span>
#         <a href="#" class="nd">34</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">li-</span>
#         <a href="#" class="nd">35</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: mediumaquamarine;" >
#
#     <div class="lbl sign">
#         <span class="txtp">t,u2-</span>
#         <a href="#" class="nd">36</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">u2-</span>
#         <a href="#" class="nd">37</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ka</span>
#         <a href="#" class="nd">38</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>line</b> <i>3</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:6" sec="P509373 obverse:6">line <span class="txtn">6</span></a>
#         <a href="#" class="nd">230792</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{disz}sze-ep-_{d}suen </span>
#         <a href="#" class="nd">258172</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">{disz}</span>
#         <a href="#" class="nd">39</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sze-</span>
#         <a href="#" class="nd">40</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ep-</span>
#         <a href="#" class="nd">41</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">_{d}</span>
#         <a href="#" class="nd">42</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">suen </span>
#         <a href="#" class="nd">43</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">a2-gal2 </span>
#         <a href="#" class="nd">258173</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: mediumaquamarine;" >
#
#     <div class="lbl sign">
#         <span class="txtp">a2-</span>
#         <a href="#" class="nd">44</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: mediumaquamarine;" >
#
#     <div class="lbl sign">
#         <span class="txtp">gal2 </span>
#         <a href="#" class="nd">45</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[dumu] </span>
#         <a href="#" class="nd">258174</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[dumu] </span>
#         <a href="#" class="nd">46</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">um-mi-a-mesz_</span>
#         <a href="#" class="nd">258175</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">um-</span>
#         <a href="#" class="nd">47</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">mi-</span>
#         <a href="#" class="nd">48</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#         <a href="#" class="nd">49</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">mesz_</span>
#         <a href="#" class="nd">50</a>
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# Or in the context of a whole face:

# %%
A.show(results, start=1, end=1, condensed=True, condenseType='face', withNodes=False, highlights=highlights)
# Out:
# <p><b>face</b> <i>1</i></p>
# <div class="contnr face " >
#
#     <div class="lbl face">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse" sec="P509373 obverse">face <span class="txtn">obverse</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="object">tablet</span></div>
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <span class="txtn">1</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[a-na] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">na] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_{d}suen_-i-[din-nam]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">_{d}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">suen_-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">i-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[din-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">nam]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <span class="txtn">2</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">qi2-bi2-[ma]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">qi2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: mediumaquamarine;" >
#
#     <div class="lbl sign">
#         <span class="txtp">bi2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[ma]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <span class="txtn">3</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">um-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">um-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_{d}en-lil2_-sza-du-u2-ni-ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">_{d}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">en-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">lil2_-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sza-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="ummama xft"><span class="f">ummama=</span>1</span></div>
#     </div>
#
#
# </di

# %% [markdown]
# Note how the words that are **_heads_** of their phrases are highlighted within their phrases.

# %% [markdown]
# # All together!
#
# If more researchers have shared data modules, you can draw them all in.
#
# Then you can design queries that use features from all these different sources.
#
# In that way, you build your own research on top of the work of others.

# %% [markdown]
# # Features from custom locations

# %% [markdown]
# If you want to load your features from your own local github repositories, instead of from the data
# that TF has downloaded for you into `~/text-fabric-data`, you can do so by passing the flag `lgc=True`.

# %%
A = use('oldbabylonian', lgc=True, hoist=globals())
# Out:
# Using TF app oldbabylonian in /Users/dirk/github/annotation/app-oldbabylonian/code
# Using Nino-cunei/oldbabylonian/tf - 1.0.1 in /Users/dirk/github
# <b>Documentation:</b> <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs/" title="provenance of Old Babylonian Letters 1900-1600: Cuneiform tablets ">OLDBABYLONIAN</a> <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs/transcription.md" title="How TF features represent ATF">Character table</a> <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="OLDBABYLONIAN feature documentation">Feature docs</a> <a target="_blank" href="https://github.com/annotation/app-oldbabylonian" title="oldbabylonian API documentation">oldbabylonian API</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/" title="text-fabric-api">Text-Fabric API 7.4.10</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Use/Search/" title="Search Templates Introduction and Reference">Search Reference</a><details open><summary><b>Loaded features</b>:</summary>
# <p><b>Old Babylonian Letters 1900-1600: Cuneiform tablets </b>: <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/oldbabylonian/tf/1.0.1/after.tf">after</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/oldbabylonian/tf/1.0.1/afterr.tf">afterr</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/oldbabylonian/tf/1.0.1/afteru.tf">afteru</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/oldbabylonian/tf/1.0.1/atf.tf">atf</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/oldbabylonian/tf/1.0.1/atfpost.tf">atfpost</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/oldbabylonian/tf/1.0.1/atfpre.tf">atfpre</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/oldbabylonian/tf/1.0.1/col.tf">col</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/oldbabylonian/tf/1.0.1/collated.tf">collated</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/oldbabylonian/tf/1.0.1/collection.tf">collection</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/oldbabylonian/tf/1.0.1/comment.tf">comment</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/oldbabylonian/tf/1.0.1/damage.tf">damage</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/oldbabylonian/tf/1.0.1/det.tf">det</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/oldbabylonian/tf/1.0.1/docnote.tf">docnote</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/oldbabylonian/tf/1.0.1/docnumber.tf">docnumber</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/oldbabylonian/tf/1.0.1/excised.tf">excised</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/oldbabylonian/tf/1.0.1/face.tf">face</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/oldbabylonian/tf/1.0.1/flags.tf">flags</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/oldbabylonian/tf/1.0.1/fraction.tf">fraction</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/oldbabylonian/tf/1.0.1/grapheme.tf">grapheme</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/oldbabylonian/tf/1.0.1/graphemer.tf">graphemer</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/oldbabylonian/tf/1.0 ...
# <style>
# @font-face {
#   font-family: "Santakku";
#   src:
#     local("Santakku.ttf"),
#     url("https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true");
# }
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: normal;
#     text-decoration: none;
# }
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: monospace;
#     font-size: normal;
#     text-decoration: none;
# }
# .txtr,.txtr a:visited,.txtr a:link {
#     font-family: serif;
#     font-size: large;
#     text-decoration: none;
# }
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Santakku;
#     font-size: x-large;
#     text-decoration: none;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .pnum {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .meta {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: row nowrap;
# }
# .features,.comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .children {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     border: 0;
#     background-color: #ffffff;
# }
# .children.document {
#     flex-flow: column nowrap;
# }
# .children.face {
#     flex-flow: column nowrap;
# }
# .children.line {
#     align-items: stretch;
#     flex-flow: row nowrap;
# }
# .children.cluster {
#     flex-flow: row wrap;
# }
# .children.line {
#     align-items: stretch;
#     flex-flow: row nowrap;
# }
# .children.sign {
#     flex-flow: column nowrap;
# }
# .contnr {
#     width: fit-content;
# }
# .contnr.document,.contnr.face,
# .contnr.line,
# .contnr.cluster,
# .contnr.word,
# .contnr.sign {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5em 0.1em 0.1em 0.1em;
#     margin: 0.8em 0.1em 0.1em 0.1em;
#     border-radius: 0.2em;
#     border-style: solid;
#     border-width: 0.2em;
#     font-size: small;
# }
# .contnr.document,.contnr.face {
#     border-color: #bb8800;
# }
# .contnr.line {
#     border-color: #0088bb;
# }
# .contnr.cluster {
#     flex-flow: row wrap;
#     border: 0;
# }
# .contnr.word {
#     border-color: #44bbff;
# }
# .contnr.sign {
#     border-color: #bbbbbb;
# }
# .contnr.hl {
#     background-color: #ffee66;
# }
# .lbl.document,.lbl.face,
# .lbl.line,
# .lbl.cluster,
# .lbl.sign,.lbl.word {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     font-size: small;
#     display: block;
# }
# .lbl.document,.lbl.face {
#     border-color: #bb8800;
#     border-width: 0.3em;
#     border-radius: 0.3em;
#     color: #bb8800;
# }
# .lbl.line {
#     border-color: #0088bb;
#     border-width: 0.3em;
#     border-radius: 0.3em;
#     color: #0088bb;
# }
# .lbl.cluster {
#     border-color: #dddddd;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     color: #0000cc;
# }
# .lbl.word {
#     border-color: #44bbff;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     font-size: medium;
#     color: #000000;
# }
# .lbl.sign {
#     border-color: #bbbbbb;
#     border-width: 0.1em;
#     border-radius: 0.1em;
#     font-size: small;
#     color: #000000;
# }
# .op {
#     padding:  0.5em 0.1em 0.1em 0.1em;
#     margin: 0.8em 0.1em 0.1em 0.1em;
#     font-family: monospace;
#     font-size: x-large;
#     font-weight: bold;
# }
# .name {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .period {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .text {
#     font-family: sans-serif;
#     font-size: x-small;
#     color: #000000;
# }
# .srcln {
#     font-family: monospace;
#     font-size: medium;
#     color: #000000;
# }
# .srclnnum {
#     font-family: monospace;
#     font-size: x-small;
#     color: #0000bb;
# }
# .comment {
#     color: #7777dd;
#     font-family: monospace;
#     font-size: small;
# }
# .operator {
#     color: #ff77ff;
#     font-size: large;
# }
# /* LANGUAGE: superscript and subscript */
#
# /* cluster */
# .det {
#     vertical-align: super;
# }
# /* cluster */
# .langalt {
#     vertical-align: sub;
# }
# /* REDACTIONAL: line over or under  */
#
# /* flag */
# .collated {
#     font-weight: bold;
#     text-decoration: underline;
# }
# /* cluster */
# .excised {
#     color: #dd0000;
#     text-decoration: line-through;
# }
# /* cluster */
# .supplied {
#     color: #0000ff;
#     text-decoration: overline;
# }
# /* flag */
# .remarkable {
#     font-weight: bold;
#     text-decoration: overline;
# }
#
# /* UNSURE: italic*/
#
# /* cluster */
# .uncertain {
#     font-style: italic
# }
# /* flag */
# .question {
#     font-weight: bold;
#     font-style: italic
# }
#
# /* BROKEN: text-shadow */
#
# /* cluster */
# .missing {
#     color: #999999;
#     text-shadow: #bbbbbb 1px 1px;
# }
# /* flag */
# .damage {
#     font-weight: bold;
#     color: #999999;
#     text-shadow: #bbbbbb 1px 1px;
# }
# .empty {
#   color: #ff0000;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlup {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>
# <details open><summary><b>API members</b>:</summary>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">C Computed</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Call AllComputeds</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Cs ComputedString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">E Edge</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Eall AllEdges</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Es EdgeString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ensureLoaded</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">TF</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ignored</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">loadLog</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Locality/#locality" title="doc">L Locality</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">cache</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">error</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">indent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">info</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">reset</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">N Nodes</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKey</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKeyTuple</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">otypeRank</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortNodes</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">F Feature</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fall AllFeatures</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fs FeatureString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Search/#search" title="doc">S Search</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Text/#text" title="doc">T Text</a></details>

# %% [markdown]
# Hover over the features to see where they come from, and you'll see they come from your local github repo.

# %% [markdown]
# ---
#
# All chapters:
#
# * **[start](start.ipynb)** become an expert in creating pretty displays of your text structures
# * **[display](display.ipynb)** become an expert in creating pretty displays of your text structures
# * **[search](search.ipynb)** turbo charge your hand-coding with search templates
# * **[exportExcel](exportExcel.ipynb)** make tailor-made spreadsheets out of your results
# * **share** draw in other people's data and let them use yours
# * **[similarLines](similarLines.ipynb)** spot the similarities between lines
#
# ---
#
# See the [cookbook](cookbook) for recipes for small, concrete tasks.
