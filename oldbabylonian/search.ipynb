# %% [markdown]
# <img align="right" src="images/tf.png" width="128"/>
# <img align="right" src="images/ninologo.png" width="128"/>
# <img align="right" src="images/dans.png" width="128"/>
#
# ---
#
# To get started: consult [start](start.ipynb)
#
# ---
#
# # Search Introduction
#
# *Search* in Text-Fabric is a template based way of looking for structural patterns in your dataset.
#
# It is inspired by the idea of
# [topographic query](http://books.google.nl/books?id=9ggOBRz1dO4C).
#
# Within Text-Fabric we have the unique possibility to combine the ease of formulating search templates for
# complicated patterns with the power of programmatically processing the results.
#
# This notebook will show you how to get up and running.
#
# ## Alternative for hand-coding
#
# Search is a powerful feature for a wide range of purposes.
#
# Quite a bit of the implementation work has been dedicated to optimize performance.
# Yet I do not pretend to have found optimal strategies for all
# possible search templates.
# Some search tasks may turn out to be somewhat costly or even very costly.
#
# That being said, I think search might turn out helpful in many cases,
# especially by reducing the amount of hand-coding needed to work with special subsets of your data.
#
# ## Easy command
#
# Search is as simple as saying (just an example)
#
# ```python
# results = A.search(template)
# A.show(results)
# ```
#
# See all ins and outs in the
# [search template docs](https://annotation.github.io/text-fabric/Use/Search/#search-templates).

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use

# %%
A = use('oldbabylonian', hoist=globals(), check=True)
# Out:
# 	downloading latest annotation/app-oldbabylonian
# 	from https://api.github.com/repos/annotation/app-oldbabylonian/zipball ...
# 	unzipping ...
# 	saving annotation/app-oldbabylonian commit 8f7c6eb2b1731abb1f54b6029c46f29fbb66da41
# 	saved annotation/app-oldbabylonian commit 8f7c6eb2b1731abb1f54b6029c46f29fbb66da41
# Using annotation/app-oldbabylonian commit 8f7c6eb2b1731abb1f54b6029c46f29fbb66da41 (=latest)
#   in /Users/dirk/text-fabric-data/__apps__/oldbabylonian
# No new data release available online.
# Using Nino-cunei/oldbabylonian/tf - 1.0.1 rv1.0.1 (=latest) in /Users/dirk/text-fabric-data.
# <b>Documentation:</b> <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs/" title="provenance of Old Babylonian Letters 1900-1600: Cuneiform tablets ">OLDBABYLONIAN</a> <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs/transcription.md" title="How TF features represent ATF">Character table</a> <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="OLDBABYLONIAN feature documentation">Feature docs</a> <a target="_blank" href="https://github.com/annotation/app-oldbabylonian" title="oldbabylonian API documentation">oldbabylonian API</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/" title="text-fabric-api">Text-Fabric API 7.4.9</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Use/Search/" title="Search Templates Introduction and Reference">Search Reference</a><details open><summary><b>Loaded features</b>:</summary>
# <p><b>Old Babylonian Letters 1900-1600: Cuneiform tablets </b>: <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/after.tf">after</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/afterr.tf">afterr</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/afteru.tf">afteru</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/atf.tf">atf</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/atfpost.tf">atfpost</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/atfpre.tf">atfpre</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/col.tf">col</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/collated.tf">collated</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/collection.tf">collection</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/comment.tf">comment</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/damage.tf">damage</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/det.tf">det</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/docnote.tf">docnote</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/docnumber.tf">docnumber</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/excised.tf">excised</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/face.tf">face</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/flags.tf">flags</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/fraction.tf">fraction</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/tf/1.0.1/grapheme.tf">grapheme</a>  <a target="_blank" href="https://github.com/Nino-cunei/oldbabylonian/blob/master/docs//transcription.md" title="/Users/dirk/text-fabric-data/Nino-cunei/oldbabylonian/ ...
# <style>
# @font-face {
#   font-family: "Santakku";
#   src:
#     local("Santakku.ttf"),
#     url("https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true");
# }
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: normal;
#     text-decoration: none;
# }
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: monospace;
#     font-size: normal;
#     text-decoration: none;
# }
# .txtr,.txtr a:visited,.txtr a:link {
#     font-family: serif;
#     font-size: large;
#     text-decoration: none;
# }
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Santakku;
#     font-size: x-large;
#     text-decoration: none;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .pnum {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .meta {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: row nowrap;
# }
# .features,.comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .children {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     border: 0;
#     background-color: #ffffff;
# }
# .children.document {
#     flex-flow: column nowrap;
# }
# .children.face {
#     flex-flow: column nowrap;
# }
# .children.line {
#     align-items: stretch;
#     flex-flow: row nowrap;
# }
# .children.cluster {
#     flex-flow: row wrap;
# }
# .children.line {
#     align-items: stretch;
#     flex-flow: row nowrap;
# }
# .children.sign {
#     flex-flow: column nowrap;
# }
# .contnr {
#     width: fit-content;
# }
# .contnr.document,.contnr.face,
# .contnr.line,
# .contnr.cluster,
# .contnr.word,
# .contnr.sign {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5em 0.1em 0.1em 0.1em;
#     margin: 0.8em 0.1em 0.1em 0.1em;
#     border-radius: 0.2em;
#     border-style: solid;
#     border-width: 0.2em;
#     font-size: small;
# }
# .contnr.document,.contnr.face {
#     border-color: #bb8800;
# }
# .contnr.line {
#     border-color: #0088bb;
# }
# .contnr.cluster {
#     flex-flow: row wrap;
#     border: 0;
# }
# .contnr.word {
#     border-color: #44bbff;
# }
# .contnr.sign {
#     border-color: #bbbbbb;
# }
# .contnr.hl {
#     background-color: #ffee66;
# }
# .lbl.document,.lbl.face,
# .lbl.line,
# .lbl.cluster,
# .lbl.sign,.lbl.word {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     font-size: small;
#     display: block;
# }
# .lbl.document,.lbl.face {
#     border-color: #bb8800;
#     border-width: 0.3em;
#     border-radius: 0.3em;
#     color: #bb8800;
# }
# .lbl.line {
#     border-color: #0088bb;
#     border-width: 0.3em;
#     border-radius: 0.3em;
#     color: #0088bb;
# }
# .lbl.cluster {
#     border-color: #dddddd;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     color: #0000cc;
# }
# .lbl.word {
#     border-color: #44bbff;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     font-size: medium;
#     color: #000000;
# }
# .lbl.sign {
#     border-color: #bbbbbb;
#     border-width: 0.1em;
#     border-radius: 0.1em;
#     font-size: small;
#     color: #aaaaaa;
# }
# .op {
#     padding:  0.5em 0.1em 0.1em 0.1em;
#     margin: 0.8em 0.1em 0.1em 0.1em;
#     font-family: monospace;
#     font-size: x-large;
#     font-weight: bold;
# }
# .name {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .period {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .text {
#     font-family: sans-serif;
#     font-size: x-small;
#     color: #000000;
# }
# .srcln {
#     font-family: monospace;
#     font-size: medium;
#     color: #000000;
# }
# .srclnnum {
#     font-family: monospace;
#     font-size: x-small;
#     color: #0000bb;
# }
# .comment {
#     color: #7777dd;
#     font-family: monospace;
#     font-size: small;
# }
# .operator {
#     color: #ff77ff;
#     font-size: large;
# }
# /* LANGUAGE: superscript and subscript */
#
# /* cluster */
# .det {
#     vertical-align: super;
# }
# /* cluster */
# .langalt {
#     vertical-align: sub;
# }
# /* REDACTIONAL: line over or under  */
#
# /* flag */
# .collated {
#     font-weight: bold;
#     text-decoration: underline;
# }
# /* cluster */
# .excised {
#     color: #dd0000;
#     text-decoration: line-through;
# }
# /* cluster */
# .supplied {
#     color: #0000ff;
#     text-decoration: overline;
# }
# /* flag */
# .remarkable {
#     font-weight: bold;
#     text-decoration: overline;
# }
#
# /* UNSURE: italic*/
#
# /* cluster */
# .uncertain {
#     font-style: italic
# }
# /* flag */
# .question {
#     font-weight: bold;
#     font-style: italic
# }
#
# /* BROKEN: text-shadow */
#
# /* cluster */
# .missing {
#     color: #999999;
#     text-shadow: #bbbbbb 1px 1px;
# }
# /* flag */
# .damage {
#     font-weight: bold;
#     color: #999999;
#     text-shadow: #bbbbbb 1px 1px;
# }
# .empty {
#   color: #ff0000;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlup {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>
# <details open><summary><b>API members</b>:</summary>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">C Computed</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Call AllComputeds</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Cs ComputedString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">E Edge</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Eall AllEdges</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Es EdgeString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ensureLoaded</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">TF</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ignored</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">loadLog</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Locality/#locality" title="doc">L Locality</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">cache</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">error</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">indent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">info</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">reset</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">N Nodes</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKey</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKeyTuple</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">otypeRank</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortNodes</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">F Feature</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fall AllFeatures</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fs FeatureString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Search/#search" title="doc">S Search</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Text/#text" title="doc">T Text</a></details>

# %% [markdown]
# # Basic search command
#
# We start with the most simple form of issuing a query.
# Let's look for the numerals with a repeat greater than 3.
# We also want to show the words in which they occur.
#
# All work involved in searching takes place under the hood.

# %%
query = '''
word
  sign type=numeral repeat>3
'''
results = A.search(query)
A.table(results, end=10)
# Out:
#   0.19s 547 results
# <table><tr><th>n</th><th>p</th><th>word</th><th>sign</th></tr>
# <tr><td>1</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:11">P509373 obverse:11</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:11" sec="P509373 obverse:11"><span class="txtp"><span  class="hl hlup" >7(disz) </span></span></a></td><td><span class="txtp"><span  class="hl hlup" >7(disz) </span></span></td></tr>
# <tr><td>2</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509376" title="show this document on CDLI" sec="P509376 obverse:4">P509376 obverse:4</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509376" title="P509376 obverse:4" sec="P509376 obverse:4"><span class="txtp"><span  class="hl hlup" >4(disz)-</span><span  class="hlup" >kam_ </span></span></a></td><td><span class="txtp"><span  class="hl hlup" >4(disz)-</span></span></td></tr>
# <tr><td>3</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509377" title="show this document on CDLI" sec="P509377 reverse:10">P509377 reverse:10</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509377" title="P509377 reverse:10" sec="P509377 reverse:10"><span class="txtp"><span  class="hl hlup" >6(disz) </span></span></a></td><td><span class="txtp"><span  class="hl hlup" >6(disz) </span></span></td></tr>
# <tr><td>4</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P389958" title="show this document on CDLI" sec="P389958 obverse:7'">P389958 obverse:7'</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P389958" title="P389958 obverse:7'" sec="P389958 obverse:7'"><span class="txtp"><span  class="hl hlup" >_5(disz) </span></span></a></td><td><span class="txtp"><span  class="hl hlup" >_5(disz) </span></span></td></tr>
# <tr><td>5</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510527" title="show this document on CDLI" sec="P510527 reverse:11">P510527 reverse:11</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510527" title="P510527 reverse:11" sec="P510527 reverse:11"><span class="txtp"><span  class="hlup" >_igi-</span><span  class="hl hlup" >6(disz)-</span><span  class="hlup" >gal2 </span></span></a></td><td><span class="txtp"><span  class="hl hlup" >6(disz)-</span></span></td></tr>
# <tr><td>6</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:17">P510530 reverse:17</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 reverse:17" sec="P510530 reverse:17"><span class="txtp"><span  class="hl hlup" >4(disz)-</span><span  class="hlup" >kam_</span></span></a></td><td><span class="txtp"><span  class="hl hlup" >4(disz)-</span></span></td></tr>
# <tr><td>7</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:5'">P510534 reverse:5'</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="P510534 reverse:5'" sec="P510534 reverse:5'"><span class="txtp"><span  class="hl hlup" >4(disz) </span></span></a></td><td><span class="txtp"><span  class="hl hlup" >4(disz) </span></span></td></tr>
# <tr><td>8</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:10'">P510534 reverse:10'</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="P510534 reverse:10'" sec="P510534 reverse:10'"><span class="txtp"><span  class="hl hlup" >_5(disz)-</span><span  class="hlup" >ta-</span><span  class="hlup" >am3_ </span></span></a></td><td><span class="txtp"><span  class="hl hlup" >_5(disz)-</span></span></td></tr>
# <tr><td>9</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510536" title="show this document on CDLI" sec="P510536 obverse:5">P510536 obverse:5</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510536" title="P510536 obverse:5" sec="P510536 obverse:5"><span class="txtp"><span  class="hl hlup" >6(disz) </span></span></a></td><td><span class="txtp"><span  class="hl hlup" >6(disz) </span></span></td></tr>
# <tr><td>10</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510539" title="show this document on CDLI" sec="P510539 obverse:7">P510539 obverse:7</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510539" title="P510539 obverse:7" sec="P510539 obverse:7"><span class="txtp"><span  class="hl hlup" >4(disz) </span></span></a></td><td><span class="txtp"><span  class="hl hlup" >4(disz) </span></span></td></tr></table>

# %% [markdown]
# We can show them in unicode representation as well:

# %%
A.table(results, end=10, fmt='text-orig-unicode')
# Out:
# <table><tr><th>n</th><th>p</th><th>word</th><th>sign</th></tr>
# <tr><td>1</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="show this document on CDLI" sec="P509373 obverse:11">P509373 obverse:11</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:11" sec="P509373 obverse:11"><span class="txtu"><span  class="hl hlup" >𒁹𒁹𒁹𒁹𒁹𒁹𒁹 </span></span></a></td><td><span class="txtu"><span  class="hl hlup" >𒁹𒁹𒁹𒁹𒁹𒁹𒁹 </span></span></td></tr>
# <tr><td>2</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509376" title="show this document on CDLI" sec="P509376 obverse:4">P509376 obverse:4</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509376" title="P509376 obverse:4" sec="P509376 obverse:4"><span class="txtu"><span  class="hl hlup" >𒁹𒁹𒁹𒁹</span><span  class="hlup" >𒄰&#124;𒄭𒁁 </span></span></a></td><td><span class="txtu"><span  class="hl hlup" >𒁹𒁹𒁹𒁹</span></span></td></tr>
# <tr><td>3</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509377" title="show this document on CDLI" sec="P509377 reverse:10">P509377 reverse:10</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509377" title="P509377 reverse:10" sec="P509377 reverse:10"><span class="txtu"><span  class="hl hlup" >𒁹𒁹𒁹𒁹𒁹𒁹 </span></span></a></td><td><span class="txtu"><span  class="hl hlup" >𒁹𒁹𒁹𒁹𒁹𒁹 </span></span></td></tr>
# <tr><td>4</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P389958" title="show this document on CDLI" sec="P389958 obverse:7'">P389958 obverse:7'</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P389958" title="P389958 obverse:7'" sec="P389958 obverse:7'"><span class="txtu"><span  class="hl hlup" >𒁹𒁹𒁹𒁹𒁹 </span></span></a></td><td><span class="txtu"><span  class="hl hlup" >𒁹𒁹𒁹𒁹𒁹 </span></span></td></tr>
# <tr><td>5</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510527" title="show this document on CDLI" sec="P510527 reverse:11">P510527 reverse:11</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510527" title="P510527 reverse:11" sec="P510527 reverse:11"><span class="txtu"><span  class="hlup" >𒅆</span><span  class="hl hlup" >𒁹𒁹𒁹𒁹𒁹𒁹</span><span  class="hlup" >𒅅 </span></span></a></td><td><span class="txtu"><span  class="hl hlup" >𒁹𒁹𒁹𒁹𒁹𒁹</span></span></td></tr>
# <tr><td>6</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:17">P510530 reverse:17</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 reverse:17" sec="P510530 reverse:17"><span class="txtu"><span  class="hl hlup" >𒁹𒁹𒁹𒁹</span><span  class="hlup" >𒄰&#124;𒄭𒁁</span></span></a></td><td><span class="txtu"><span  class="hl hlup" >𒁹𒁹𒁹𒁹</span></span></td></tr>
# <tr><td>7</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:5'">P510534 reverse:5'</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="P510534 reverse:5'" sec="P510534 reverse:5'"><span class="txtu"><span  class="hl hlup" >𒁹𒁹𒁹𒁹 </span></span></a></td><td><span class="txtu"><span  class="hl hlup" >𒁹𒁹𒁹𒁹 </span></span></td></tr>
# <tr><td>8</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:10'">P510534 reverse:10'</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="P510534 reverse:10'" sec="P510534 reverse:10'"><span class="txtu"><span  class="hl hlup" >𒁹𒁹𒁹𒁹𒁹</span><span  class="hlup" >𒋫</span><span  class="hlup" >𒀀𒀭 </span></span></a></td><td><span class="txtu"><span  class="hl hlup" >𒁹𒁹𒁹𒁹𒁹</span></span></td></tr>
# <tr><td>9</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510536" title="show this document on CDLI" sec="P510536 obverse:5">P510536 obverse:5</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510536" title="P510536 obverse:5" sec="P510536 obverse:5"><span class="txtu"><span  class="hl hlup" >𒁹𒁹𒁹𒁹𒁹𒁹 </span></span></a></td><td><span class="txtu"><span  class="hl hlup" >𒁹𒁹𒁹𒁹𒁹𒁹 </span></span></td></tr>
# <tr><td>10</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510539" title="show this document on CDLI" sec="P510539 obverse:7">P510539 obverse:7</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510539" title="P510539 obverse:7" sec="P510539 obverse:7"><span class="txtu"><span  class="hl hlup" >𒁹𒁹𒁹𒁹 </span></span></a></td><td><span class="txtu"><span  class="hl hlup" >𒁹𒁹𒁹𒁹 </span></span></td></tr></table>

# %% [markdown]
# The hyperlinks take us all to the CDLI archival page of the document (tablet) in question.
#
# Note that we can choose start and/or end points in the results list.

# %%
A.table(results, start=500, end=510, fmt='text-orig-rich')
# Out:
# <table><tr><th>n</th><th>p</th><th>word</th><th>sign</th></tr>
# <tr><td>500</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P306530" title="show this document on CDLI" sec="P306530 obverse:10">P306530 obverse:10</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P306530" title="P306530 obverse:10" sec="P306530 obverse:10"><span class="txtr"><span  class="hl hlup" >5(diš)-</span><span  class="hlup" >kam</span></span></a></td><td><span class="txtr"><span  class="hl hlup" >5(diš)-</span></span></td></tr>
# <tr><td>501</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305753" title="show this document on CDLI" sec="P305753 case - obverse:10">P305753 case - obverse:10</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305753" title="P305753 case - obverse:10" sec="P305753 case - obverse:10"><span class="txtr"><span  class="hl hlup" >5(diš) </span></span></a></td><td><span class="txtr"><span  class="hl hlup" >5(diš) </span></span></td></tr>
# <tr><td>502</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305753" title="show this document on CDLI" sec="P305753 case - reverse:10">P305753 case - reverse:10</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305753" title="P305753 case - reverse:10" sec="P305753 case - reverse:10"><span class="txtr"><span  class="hl hlup" >5(diš) </span></span></a></td><td><span class="txtr"><span  class="hl hlup" >5(diš) </span></span></td></tr>
# <tr><td>503</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305753" title="show this document on CDLI" sec="P305753 case - reverse:14">P305753 case - reverse:14</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305753" title="P305753 case - reverse:14" sec="P305753 case - reverse:14"><span class="txtr"><span  class="hl hlup" >4(u) </span></span></a></td><td><span class="txtr"><span  class="hl hlup" >4(u) </span></span></td></tr>
# <tr><td>504</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305753" title="show this document on CDLI" sec="P305753 case - lower edge:1">P305753 case - lower edge:1</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305753" title="P305753 case - lower edge:1" sec="P305753 case - lower edge:1"><span class="txtr"><span  class="hlup" >igi-</span><span  class="hl hlup" >6(diš)-</span><span  class="hlup" >gal₂ </span></span></a></td><td><span class="txtr"><span  class="hl hlup" >6(diš)-</span></span></td></tr>
# <tr><td>505</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305791" title="show this document on CDLI" sec="P305791 obverse:5">P305791 obverse:5</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305791" title="P305791 obverse:5" sec="P305791 obverse:5"><span class="txtr"><span  class="hl hlup" >5(diš) </span></span></a></td><td><span class="txtr"><span  class="hl hlup" >5(diš) </span></span></td></tr>
# <tr><td>506</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305805" title="show this document on CDLI" sec="P305805 obverse:11">P305805 obverse:11</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305805" title="P305805 obverse:11" sec="P305805 obverse:11"><span class="txtr"><span  class="hl hlup" >5(aš) </span></span></a></td><td><span class="txtr"><span  class="hl hlup" >5(aš) </span></span></td></tr>
# <tr><td>507</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305755" title="show this document on CDLI" sec="P305755 reverse:16">P305755 reverse:16</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305755" title="P305755 reverse:16" sec="P305755 reverse:16"><span class="txtr"><span  class="hl hlup" >5(aš) </span></span></a></td><td><span class="txtr"><span  class="hl hlup" >5(aš) </span></span></td></tr>
# <tr><td>508</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305745" title="show this document on CDLI" sec="P305745 obverse:9">P305745 obverse:9</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305745" title="P305745 obverse:9" sec="P305745 obverse:9"><span class="txtr"><span  class="hl hlup" >4(barig) </span></span></a></td><td><span class="txtr"><span  class="hl hlup" >4(barig) </span></span></td></tr>
# <tr><td>509</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305745" title="show this document on CDLI" sec="P305745 obverse:10">P305745 obverse:10</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305745" title="P305745 obverse:10" sec="P305745 obverse:10"><span class="txtr"><span  class="hl hlup" >4(barig) </span></span></a></td><td><span class="txtr"><span  class="hl hlup" >4(barig) </span></span></td></tr>
# <tr><td>510</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305745" title="show this document on CDLI" sec="P305745 reverse:5">P305745 reverse:5</a></td><td><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305745" title="P305745 reverse:5" sec="P305745 reverse:5"><span class="txtr"><span  class="hl hlup" >4(u) </span></span></a></td><td><span class="txtr"><span  class="hl hlup" >4(u) </span></span></td></tr></table>

# %% [markdown]
# We can show the results more fully with `show()`.
#
# That gives us pretty displays of tablet faces with the results highlighted.
#
# But faces are a bit

# %%
A.show(results, start=1, end=3)
# Out:
# <p><b>result</b> <i>1</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509373" title="P509373 obverse:11" sec="P509373 obverse:11">line <span class="txtn">11</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sza </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sza </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_{d}utu_-ha-zi-[ir] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_{d}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">utu_-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ha-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">zi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[ir] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">isz-tu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">isz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">tu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_mu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_mu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word hl" >
#
#     <div class="lbl word">
#         <span class="txtp">7(disz) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl" >
#
#     <div class="lbl sign">
#         <span class="txtp">7(disz) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>7</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">kam_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">kam_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">id-di-nu-szum</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">id-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">di-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">nu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szum</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>2</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509376" title="P509376 obverse:4" sec="P509376 obverse:4">line <span class="txtn">4</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_u4 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_u4 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word hl" >
#
#     <div class="lbl word">
#         <span class="txtp">4(disz)-kam_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl" >
#
#     <div class="lbl sign">
#         <span class="txtp">4(disz)-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>4</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">kam_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">a-di </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">di </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">i-na-an-na</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">i-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">an-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>3</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509377" title="P509377 reverse:10" sec="P509377 reverse:10">line <span class="txtn">10</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">szum-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szum-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word hl" >
#
#     <div class="lbl word">
#         <span class="txtp">6(disz) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl" >
#
#     <div class="lbl sign">
#         <span class="txtp">6(disz) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="repeat"><span class="f">repeat=</span>6</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_gin2 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_gin2 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ku3-babbar_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ku3-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">babbar_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">i-di-in-szum</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">i-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">di-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">in-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szum</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# # Condense results
#
# There are two fundamentally different ways of presenting the results: condensed and uncondensed.
#
# In **uncondensed** view, all results are listed individually.
# You can keep track of which parts belong to which results.
# The display can become unwieldy.
#
# This is the default view, because it is the straightest, most logical, answer to your query.
#
# In **condensed** view all nodes of all results are grouped in containers first (e.g. verses), and then presented
# container by container.
# You loose the information of what parts belong to what result.
#
# As an example of is the difference, we look for all numerals.

# %%
query = '''
% we choose a tablet with several numerals
document pnumber=P510556
  sign type=numeral repeat>3
'''

# %% [markdown]
# Note that you can have comments in a search template. Comment lines start with a `%`.

# %%
results = A.search(query)
A.table(results, end=100)
# Out:
#   0.17s 5 results
# <table><tr><th>n</th><th>p</th><th>document</th><th>sign</th></tr>
# <tr><td>1</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510556" title="show this document on CDLI" sec="P510556 obverse:6">P510556 obverse:6</a></td><td>document P510556</td><td><span class="txtp"><span  class="hl" >4(disz)-</span></span></td></tr>
# <tr><td>2</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510556" title="show this document on CDLI" sec="P510556 obverse:12">P510556 obverse:12</a></td><td>document P510556</td><td><span class="txtp"><span  class="hl" >5(disz) </span></span></td></tr>
# <tr><td>3</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510556" title="show this document on CDLI" sec="P510556 reverse:4">P510556 reverse:4</a></td><td>document P510556</td><td><span class="txtp"><span  class="hl" >_5(gesz2) </span></span></td></tr>
# <tr><td>4</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510556" title="show this document on CDLI" sec="P510556 reverse:8">P510556 reverse:8</a></td><td>document P510556</td><td><span class="txtp"><span  class="hl" >6(gesz2) </span></span></td></tr>
# <tr><td>5</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510556" title="show this document on CDLI" sec="P510556 reverse:8">P510556 reverse:8</a></td><td>document P510556</td><td><span class="txtp"><span  class="hl" >5(ban2) </span></span></td></tr></table>

# %% [markdown]
# Let's expand the results display:

# %%
A.show(results)
# Out:
# <p><b>result</b> <i>1</i></p>
# <div class="contnr document " >
#
#     <div class="lbl document">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510556" title="P510556" sec="P510556">document <span class="txtn">P510556  <span class="collection">AbB</span> <span class="volume">12</span> <span class="docnumber">031</span><div class="features"> <span class="pnumber xft"><span class="f">pnumber=</span>P510556</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510556" title="P510556 obverse:6" sec="P510556 obverse:6">line <span class="txtn">6</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">i-na </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">i-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_u4 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_u4 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">1(u) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">1(u) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>1</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">4(disz)-kam_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl" >
#
#     <div class="lbl sign">
#         <span class="txtp">4(disz)-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>4</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">kam_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sza </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sza </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_iti </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_iti </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">NE-NE-gar_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">NE-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="grapheme"><span class="f">grapheme=</span>NE</span> <span class="type xft"><span class="f">type=</span>grapheme</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">NE-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="grapheme"><span class="f">grapheme=</span>NE</span> <span class="type xft"><span class="f">type=</span>grapheme</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">gar_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">a-na </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sze-e </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sze-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">e </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">szu-ut-_sipa-mesz_{ki}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span cla
# <p><b>result</b> <i>2</i></p>
# <div class="contnr document " >
#
#     <div class="lbl document">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510556" title="P510556" sec="P510556">document <span class="txtn">P510556  <span class="collection">AbB</span> <span class="volume">12</span> <span class="docnumber">031</span><div class="features"> <span class="pnumber xft"><span class="f">pnumber=</span>P510556</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510556" title="P510556 obverse:12" sec="P510556 obverse:12">line <span class="txtn">12</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_dumu_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_dumu_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">hi-IZ-BI-SZI </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">hi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">IZ-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="grapheme"><span class="f">grapheme=</span>IZ</span> <span class="type xft"><span class="f">type=</span>grapheme</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">BI-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="grapheme"><span class="f">grapheme=</span>BI</span> <span class="type xft"><span class="f">type=</span>grapheme</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">SZI </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="grapheme"><span class="f">grapheme=</span>SZI</span> <span class="type xft"><span class="f">type=</span>grapheme</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">5(disz) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl" >
#
#     <div class="lbl sign">
#         <span class="txtp">5(disz) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="repeat"><span class="f">repeat=</span>5</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">szu-szi </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szi </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_sze </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_sze </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">gur_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">gur_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">a-na# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">x </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">x </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>unknown</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[x </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[x </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="type xft"><span class="f">type=</span>unknown</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">(x)]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">(x)]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="uncertain"><span class="f">uncertain=</sp
# <p><b>result</b> <i>3</i></p>
# <div class="contnr document " >
#
#     <div class="lbl document">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510556" title="P510556" sec="P510556">document <span class="txtn">P510556  <span class="collection">AbB</span> <span class="volume">12</span> <span class="docnumber">031</span><div class="features"> <span class="pnumber xft"><span class="f">pnumber=</span>P510556</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510556" title="P510556 reverse:4" sec="P510556 reverse:4">line <span class="txtn">4</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ib-ba-szu-u2 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ib-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ba-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u2 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_5(gesz2) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl" >
#
#     <div class="lbl sign">
#         <span class="txtp">_5(gesz2) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>5</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">3(u) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">3(u) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>3</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sze </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sze </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">gur </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">gur </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{gesz#}ban2#_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{gesz#}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="det"><span class="f">det=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ban2#_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{gesz#}me-sze-qum#</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{gesz#}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="det"><span class="f">det=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">me-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sze-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">qum#</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>4</i></p>
# <div class="contnr document " >
#
#     <div class="lbl document">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510556" title="P510556" sec="P510556">document <span class="txtn">P510556  <span class="collection">AbB</span> <span class="volume">12</span> <span class="docnumber">031</span><div class="features"> <span class="pnumber xft"><span class="f">pnumber=</span>P510556</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510556" title="P510556 reverse:8" sec="P510556 reverse:8">line <span class="txtn">8</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_szunigin </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_szunigin </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">6(gesz2) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl" >
#
#     <div class="lbl sign">
#         <span class="txtp">6(gesz2) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>6</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">2(u) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">2(u) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>2</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">1(asz) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">1(asz) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>1</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">5(ban2) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">5(ban2) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>5</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sze </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sze </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">gur </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">gur </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{gesz}ban2#_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{gesz}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ban2#_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[{gesz}me]-sze#-qum</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[{gesz}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">me]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sze#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">qum</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>5</i></p>
# <div class="contnr document " >
#
#     <div class="lbl document">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510556" title="P510556" sec="P510556">document <span class="txtn">P510556  <span class="collection">AbB</span> <span class="volume">12</span> <span class="docnumber">031</span><div class="features"> <span class="pnumber xft"><span class="f">pnumber=</span>P510556</span></div></span></a>
#
#     </div>
#
#     <div class="meta">
#
#     </div>
#
#
# </div>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510556" title="P510556 reverse:8" sec="P510556 reverse:8">line <span class="txtn">8</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_szunigin </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_szunigin </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">6(gesz2) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">6(gesz2) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>6</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">2(u) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">2(u) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>2</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">1(asz) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">1(asz) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>1</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">5(ban2) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl" >
#
#     <div class="lbl sign">
#         <span class="txtp">5(ban2) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>5</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sze </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sze </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">gur </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">gur </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{gesz}ban2#_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{gesz}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ban2#_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[{gesz}me]-sze#-qum</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[{gesz}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">me]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sze#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">qum</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# As you see, the results are listed per result tuple, even if they occur all in the same verse.
# This way you can keep track of what exactly belongs to each result.
#
# Now in condensed mode:

# %%
A.show(results, condensed=True)
# Out:
# <p><b>line</b> <i>1</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510556" title="P510556 obverse:6" sec="P510556 obverse:6">line <span class="txtn">6</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">i-na </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">i-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_u4 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_u4 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">1(u) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">1(u) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>1</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">4(disz)-kam_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl" >
#
#     <div class="lbl sign">
#         <span class="txtp">4(disz)-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>4</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">kam_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sza </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sza </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_iti </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_iti </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">NE-NE-gar_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">NE-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="grapheme"><span class="f">grapheme=</span>NE</span> <span class="type xft"><span class="f">type=</span>grapheme</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">NE-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="grapheme"><span class="f">grapheme=</span>NE</span> <span class="type xft"><span class="f">type=</span>grapheme</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">gar_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">a-na </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sze-e </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sze-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">e </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">szu-ut-_sipa-mesz_{ki}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span cla
# <p><b>line</b> <i>2</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510556" title="P510556 obverse:12" sec="P510556 obverse:12">line <span class="txtn">12</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_dumu_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_dumu_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">hi-IZ-BI-SZI </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">hi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">IZ-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="grapheme"><span class="f">grapheme=</span>IZ</span> <span class="type xft"><span class="f">type=</span>grapheme</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">BI-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="grapheme"><span class="f">grapheme=</span>BI</span> <span class="type xft"><span class="f">type=</span>grapheme</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">SZI </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="grapheme"><span class="f">grapheme=</span>SZI</span> <span class="type xft"><span class="f">type=</span>grapheme</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">5(disz) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl" >
#
#     <div class="lbl sign">
#         <span class="txtp">5(disz) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="repeat"><span class="f">repeat=</span>5</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">szu-szi </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szi </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_sze </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_sze </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">gur_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">gur_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">a-na# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">x </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">x </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>unknown</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[x </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[x </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="type xft"><span class="f">type=</span>unknown</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">(x)]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">(x)]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="uncertain"><span class="f">uncertain=</sp
# <p><b>line</b> <i>3</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510556" title="P510556 reverse:4" sec="P510556 reverse:4">line <span class="txtn">4</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ib-ba-szu-u2 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ib-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ba-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u2 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_5(gesz2) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl" >
#
#     <div class="lbl sign">
#         <span class="txtp">_5(gesz2) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>5</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">3(u) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">3(u) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>3</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sze </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sze </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">gur </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">gur </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{gesz#}ban2#_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{gesz#}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="det"><span class="f">det=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ban2#_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{gesz#}me-sze-qum#</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{gesz#}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="det"><span class="f">det=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">me-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sze-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">qum#</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>line</b> <i>4</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510556" title="P510556 reverse:8" sec="P510556 reverse:8">line <span class="txtn">8</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_szunigin </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_szunigin </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">6(gesz2) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl" >
#
#     <div class="lbl sign">
#         <span class="txtp">6(gesz2) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>6</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">2(u) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">2(u) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>2</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">1(asz) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">1(asz) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>1</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">5(ban2) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl" >
#
#     <div class="lbl sign">
#         <span class="txtp">5(ban2) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>5</span> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sze </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sze </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">gur </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">gur </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{gesz}ban2#_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{gesz}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ban2#_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[{gesz}me]-sze#-qum</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[{gesz}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">me]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sze#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">qum</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# The last line has two results, and both results are highlighted in the same line display.
#
# We can modify the container in which we see our results.
#
# By default, it is `line`, but we can make it `face` as well:

# %%
A.show(results, condensed=True, condenseType='face')
# Out:
# <p><b>face</b> <i>1</i></p>
# <div class="contnr face " >
#
#     <div class="lbl face">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510556" title="P510556 obverse" sec="P510556 obverse">face <span class="txtn">obverse</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="object">tablet</span></div>
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <span class="txtn">1</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">a-na </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">be-li2-ia </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">be-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">li2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ia </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">qi2-bi2-ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">qi2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <span class="txtn">2</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">um-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">um-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{d}na-bi-um-at-pa-lam </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{d}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">um-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">at-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">pa-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">lam </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ARAD-ka-ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ARAD-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="grapheme"><span class="f">grapheme=</span>ARAD</span> <span class="type xft"><span class="f">type=</span>grapheme</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ka-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <span class="txtn">3</span
# <p><b>face</b> <i>2</i></p>
# <div class="contnr face " >
#
#     <div class="lbl face">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510556" title="P510556 reverse" sec="P510556 reverse">face <span class="txtn">reverse</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="object">tablet</span></div>
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <span class="txtn">1</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">a-di# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">di# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">i-na#-an#-na# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">i-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">an#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">x </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">x </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>unknown</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[...]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[...]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="grapheme"><span class="f">grapheme=</span>...</span> <span class="type xft"><span class="f">type=</span>ellipsis</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <span class="txtn">2</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sze-e </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sze-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">e </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">be-li2-ia </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">be-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">li2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ia </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ki-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ki-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">x </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">x </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>unknown</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[...]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[...]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</

# %% [markdown]
# We now see the the displays of two faces, one with two numerals in it and one with three.

# %% [markdown]
# # Custom highlighting
#
# Let us make a new search where we look for two different things in the same line.
#
# We can apply different highlight colors to different parts of the result.
# The signs in the pair are member 0 and 1 of the result tuples.
# The members that we do not map, will not be highlighted.
# The members that we map to the empty string will be highlighted with the default color.
#
# **NB:** Choose your colors from the
# [CSS specification](https://developer.mozilla.org/en-US/docs/Web/CSS/color_value).

# %%
query = '''
line
  sign missing=1
  sign question=1
  sign damage=1
'''

# %%
results = A.search(query)
A.table(results, end=10)
# Out:
#   0.54s 776 results
# <table><tr><th>n</th><th>p</th><th>line</th><th>sign</th><th>sign</th><th>sign</th></tr>
# <tr><td>1</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 obverse:5">P510530 obverse:5</a></td><td><span class="txtp">{disz}<span  class="hl" >[{d}</span>x]-<span  class="hl" >ra#?-</span>bi il-qe2-a-am-ma</span></td><td><span class="txtp"><span  class="hl" >[{d}</span></span></td><td><span class="txtp"><span  class="hl" >ra#?-</span></span></td><td><span class="txtp"><span  class="hl" >ra#?-</span></span></td></tr>
# <tr><td>2</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 obverse:5">P510530 obverse:5</a></td><td><span class="txtp">{disz}[{d}<span  class="hl" >x]-</span><span  class="hl" >ra#?-</span>bi il-qe2-a-am-ma</span></td><td><span class="txtp"><span  class="hl" >x]-</span></span></td><td><span class="txtp"><span  class="hl" >ra#?-</span></span></td><td><span class="txtp"><span  class="hl" >ra#?-</span></span></td></tr>
# <tr><td>3</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:11">P510530 reverse:11</a></td><td><span class="txtp"><span  class="hl" >[szu-</span>bu-<span  class="hl" >lim?] </span><span  class="hl" >sza# </span>ta-asz-pu-ra-am</span></td><td><span class="txtp"><span  class="hl" >[szu-</span></span></td><td><span class="txtp"><span  class="hl" >lim?] </span></span></td><td><span class="txtp"><span  class="hl" >sza# </span></span></td></tr>
# <tr><td>4</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:11">P510530 reverse:11</a></td><td><span class="txtp">[szu-<span  class="hl" >bu-</span><span  class="hl" >lim?] </span><span  class="hl" >sza# </span>ta-asz-pu-ra-am</span></td><td><span class="txtp"><span  class="hl" >bu-</span></span></td><td><span class="txtp"><span  class="hl" >lim?] </span></span></td><td><span class="txtp"><span  class="hl" >sza# </span></span></td></tr>
# <tr><td>5</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:11">P510530 reverse:11</a></td><td><span class="txtp">[szu-bu-<span  class="hl" >lim?] </span><span  class="hl" >sza# </span>ta-asz-pu-ra-am</span></td><td><span class="txtp"><span  class="hl" >lim?] </span></span></td><td><span class="txtp"><span  class="hl" >lim?] </span></span></td><td><span class="txtp"><span  class="hl" >sza# </span></span></td></tr>
# <tr><td>6</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:15'">P510534 reverse:15'</a></td><td><span class="txtp"><span  class="hl" >li#-</span>iq#-bi-ma da-ba-ab#-szu <span  class="hl" >li#?-</span>in-na-me-<span  class="hl" >[er]</span></span></td><td><span class="txtp"><span  class="hl" >[er]</span></span></td><td><span class="txtp"><span  class="hl" >li#?-</span></span></td><td><span class="txtp"><span  class="hl" >li#-</span></span></td></tr>
# <tr><td>7</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:15'">P510534 reverse:15'</a></td><td><span class="txtp">li#-<span  class="hl" >iq#-</span>bi-ma da-ba-ab#-szu <span  class="hl" >li#?-</span>in-na-me-<span  class="hl" >[er]</span></span></td><td><span class="txtp"><span  class="hl" >[er]</span></span></td><td><span class="txtp"><span  class="hl" >li#?-</span></span></td><td><span class="txtp"><span  class="hl" >iq#-</span></span></td></tr>
# <tr><td>8</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:15'">P510534 reverse:15'</a></td><td><span class="txtp">li#-iq#-bi-ma da-ba-<span  class="hl" >ab#-</span>szu <span  class="hl" >li#?-</span>in-na-me-<span  class="hl" >[er]</span></span></td><td><span class="txtp"><span  class="hl" >[er]</span></span></td><td><span class="txtp"><span  class="hl" >li#?-</span></span></td><td><span class="txtp"><span  class="hl" >ab#-</span></span></td></tr>
# <tr><td>9</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:15'">P510534 reverse:15'</a></td><td><span class="txtp">li#-iq#-bi-ma da-ba-ab#-szu <span  class="hl" >li#?-</span>in-na-me-<span  class="hl" >[er]</span></span></td><td><span class="txtp"><span  class="hl" >[er]</span></span></td><td><span class="txtp"><span  class="hl" >li#?-</span></span></td><td><span class="txtp"><span  class="hl" >li#?-</span></span></td></tr>
# <tr><td>10</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:20'">P510534 reverse:20'</a></td><td><span class="txtp"><span  class="hl" >li#-</span>il#-<span  class="hl" >qe2#?-</span><span  class="hl" >[szu-</span>ma?]</span></td><td><span class="txtp"><span  class="hl" >[szu-</span></span></td><td><span class="txtp"><span  class="hl" >qe2#?-</span></span></td><td><span class="txtp"><span  class="hl" >li#-</span></span></td></tr></table>

# %%
A.table(results, end=10, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
# <table><tr><th>n</th><th>p</th><th>line</th><th>sign</th><th>sign</th><th>sign</th></tr>
# <tr><td>1</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 obverse:5">P510530 obverse:5</a></td><td><span class="txtp">{disz}<span  class="hl"  style="background-color: cyan;" >[{d}</span>x]-<span  class="hl"  style="background-color: lightsalmon;" >ra#?-</span>bi il-qe2-a-am-ma</span></td><td><span class="txtp"><span  class="hl"  style="background-color: cyan;" >[{d}</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >ra#?-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >ra#?-</span></span></td></tr>
# <tr><td>2</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 obverse:5">P510530 obverse:5</a></td><td><span class="txtp">{disz}[{d}<span  class="hl"  style="background-color: cyan;" >x]-</span><span  class="hl"  style="background-color: lightsalmon;" >ra#?-</span>bi il-qe2-a-am-ma</span></td><td><span class="txtp"><span  class="hl"  style="background-color: cyan;" >x]-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >ra#?-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >ra#?-</span></span></td></tr>
# <tr><td>3</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:11">P510530 reverse:11</a></td><td><span class="txtp"><span  class="hl"  style="background-color: cyan;" >[szu-</span>bu-<span  class="hl"  style="background-color: magenta;" >lim?] </span><span  class="hl"  style="background-color: lightsalmon;" >sza# </span>ta-asz-pu-ra-am</span></td><td><span class="txtp"><span  class="hl"  style="background-color: cyan;" >[szu-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: magenta;" >lim?] </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >sza# </span></span></td></tr>
# <tr><td>4</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:11">P510530 reverse:11</a></td><td><span class="txtp">[szu-<span  class="hl"  style="background-color: cyan;" >bu-</span><span  class="hl"  style="background-color: magenta;" >lim?] </span><span  class="hl"  style="background-color: lightsalmon;" >sza# </span>ta-asz-pu-ra-am</span></td><td><span class="txtp"><span  class="hl"  style="background-color: cyan;" >bu-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: magenta;" >lim?] </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >sza# </span></span></td></tr>
# <tr><td>5</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:11">P510530 reverse:11</a></td><td><span class="txtp">[szu-bu-<span  class="hl"  style="background-color: magenta;" >lim?] </span><span  class="hl"  style="background-color: lightsalmon;" >sza# </span>ta-asz-pu-ra-am</span></td><td><span class="txtp"><span  class="hl"  style="background-color: magenta;" >lim?] </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: magenta;" >lim?] </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >sza# </span></span></td></tr>
# <tr><td>6</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:15'">P510534 reverse:15'</a></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >li#-</span>iq#-bi-ma da-ba-ab#-szu <span  class="hl"  style="background-color: magenta;" >li#?-</span>in-na-me-<span  class="hl"  style="background-color: cyan;" >[er]</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: cyan;" >[er]</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: magenta;" >li#?-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >li#-</span></span></td></tr>
# <tr><td>7</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:15'">P510534 reverse:15'</a></td><td><span class="txtp">li#-<span  class="hl"  style="background-color: lightsalmon;" >iq#-</span>bi-ma da-ba-ab#-szu <span  class="hl"  style="background-color: magenta;" >li#?-</span>in-na-me-<span  class="hl"  style="background-color: cyan;" >[er]</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: cyan;" >[er]</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: magenta;" >li#?-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >iq#-</span></span></td></tr>
# <tr><td>8</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:15'">P510534 reverse:15'</a></td><td><span class="txtp">li#-iq#-bi-ma da-ba-<span  class="hl"  style="background-color: lightsalmon;" >ab#-</span>szu <span  class="hl"  style="background-color: magenta;" >li#?-</span>in-na-me-<span  class="hl"  style="background-color: cyan;" >[er]</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: cyan;" >[er]</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: magenta;" >li#?-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >ab#-</span></span></td></tr>
# <tr><td>9</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:15'">P510534 reverse:15'</a></td><td><span class="txtp">li#-iq#-bi-ma da-ba-ab#-szu <span  class="hl"  style="background-color: lightsalmon;" >li#?-</span>in-na-me-<span  class="hl"  style="background-color: cyan;" >[er]</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: cyan;" >[er]</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >li#?-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >li#?-</span></span></td></tr>
# <tr><td>10</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="show this document on CDLI" sec="P510534 reverse:20'">P510534 reverse:20'</a></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >li#-</span>il#-<span  class="hl"  style="background-color: magenta;" >qe2#?-</span><span  class="hl"  style="background-color: cyan;" >[szu-</span>ma?]</span></td><td><span class="txtp"><span  class="hl"  style="background-color: cyan;" >[szu-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: magenta;" >qe2#?-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >li#-</span></span></td></tr></table>

# %%
A.show(results, end=10, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
# <p><b>result</b> <i>1</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 obverse:5" sec="P510530 obverse:5">line <span class="txtn">5</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{disz}[{d}x]-ra#?-bi </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{disz}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[{d}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">x]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ra#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">il-qe2-a-am-ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">il-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">qe2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">am-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>2</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 obverse:5" sec="P510530 obverse:5">line <span class="txtn">5</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{disz}[{d}x]-ra#?-bi </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{disz}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[{d}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">x]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ra#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">il-qe2-a-am-ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">il-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">qe2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">am-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>3</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 reverse:11" sec="P510530 reverse:11">line <span class="txtn">11</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[szu-bu-lim?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">lim?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ta-asz-pu-ra-am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ta-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">asz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">pu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ra-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>4</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 reverse:11" sec="P510530 reverse:11">line <span class="txtn">11</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[szu-bu-lim?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">lim?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ta-asz-pu-ra-am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ta-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">asz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">pu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ra-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>5</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 reverse:11" sec="P510530 reverse:11">line <span class="txtn">11</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[szu-bu-lim?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">lim?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ta-asz-pu-ra-am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ta-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">asz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">pu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ra-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>6</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="P510534 reverse:15'" sec="P510534 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#-iq#-bi-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">li#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">iq#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">da-ba-ab#-szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">da-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ba-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ab#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#?-in-na-me-[er]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">li#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">in-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">me-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[er]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>7</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="P510534 reverse:15'" sec="P510534 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#-iq#-bi-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">li#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">iq#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">da-ba-ab#-szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">da-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ba-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ab#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#?-in-na-me-[er]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">li#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">in-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">me-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[er]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>8</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="P510534 reverse:15'" sec="P510534 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#-iq#-bi-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">li#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">iq#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">da-ba-ab#-szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">da-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ba-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ab#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#?-in-na-me-[er]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">li#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">in-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">me-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[er]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>9</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="P510534 reverse:15'" sec="P510534 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#-iq#-bi-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">li#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">iq#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">da-ba-ab#-szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">da-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ba-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ab#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#?-in-na-me-[er]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">li#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">in-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">me-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[er]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>10</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="P510534 reverse:20'" sec="P510534 reverse:20'">line <span class="txtn">20'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#-il#-qe2#?-[szu-ma?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">li#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">il#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">qe2#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# Color mapping works best for uncondensed results. If you condense results, some nodes may occupy
# different positions in different results. It is unpredictable which color will be used
# for such nodes:

# %%
A.show(results, condensed=True, end=10, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
# <p><b>line</b> <i>1</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 obverse:5" sec="P510530 obverse:5">line <span class="txtn">5</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{disz}[{d}x]-ra#?-bi </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{disz}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[{d}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">x]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ra#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">il-qe2-a-am-ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">il-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">qe2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">am-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>line</b> <i>2</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 reverse:11" sec="P510530 reverse:11">line <span class="txtn">11</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[szu-bu-lim?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">lim?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ta-asz-pu-ra-am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ta-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">asz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">pu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ra-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>line</b> <i>3</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="P510534 reverse:15'" sec="P510534 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#-iq#-bi-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">li#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">iq#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">da-ba-ab#-szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">da-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ba-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ab#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#?-in-na-me-[er]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">li#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">in-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">me-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[er]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>line</b> <i>4</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510534" title="P510534 reverse:20'" sec="P510534 reverse:20'">line <span class="txtn">20'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">li#-il#-qe2#?-[szu-ma?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">li#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">il#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">qe2#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ma?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>line</b> <i>5</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510546" title="P510546 obverse:1" sec="P510546 obverse:1">line <span class="txtn">1</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">a-na </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{d}na#-[bi-um-at-pa-lam?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{d}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">na#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[bi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">um-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">at-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">pa-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">lam?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>line</b> <i>6</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510550" title="P510550 obverse:9" sec="P510550 obverse:9">line <span class="txtn">9</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_ha-za-nu-um{sar}_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_ha-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">za-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">nu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">um</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{sar}_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">i-ka-am#? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">i-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ka-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">am#? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[x] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[x] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">x-al#-la-x-ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">x-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">al#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">la-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">x-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>line</b> <i>7</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510554" title="P510554 reverse:10" sec="P510554 reverse:10">line <span class="txtn">10</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_1(disz) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_1(disz) </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span> <span class="repeat"><span class="f">repeat=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sila3 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sila3 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sze_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sze_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">la# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">la# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[i-ka-al-la?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[i-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ka-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">al-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">la?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>line</b> <i>8</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510560" title="P510560 obverse:9" sec="P510560 obverse:9">line <span class="txtn">9</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">isz-ti-isz#-[szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">isz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ti-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">isz#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">szi-ni-szu?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">szi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ni-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">szu?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">x </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">x </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_hi-a_</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_hi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a_</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>line</b> <i>9</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510562" title="P510562 reverse:15" sec="P510562 reverse:15">line <span class="txtn">15</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">i-ri-isz-ka </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">i-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ri-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">isz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ka </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">um-ma# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">um-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ma# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[at-ta]-a-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[at-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ta]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">i-na </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">i-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_{gesz}ma2?_-[ma?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_{gesz}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ma2?_-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[ma?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>line</b> <i>10</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510565" title="P510565 reverse:4" sec="P510565 reverse:4">line <span class="txtn">4</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[a-na?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">na?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_e2_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_e2_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{d}utu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{d}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">utu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">szu-ri-ba-am#</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ri-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ba-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">am#</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# You can specify to what container you want to condense. By default, everything is condensed to lines.
#
# Let's change that to faces.
# Note that the `end` parameter counts the number of faces now.

# %%
A.show(results, end=2, condensed=True, condenseType='face', colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
# <p><b>face</b> <i>1</i></p>
# <div class="contnr face " >
#
#     <div class="lbl face">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 obverse" sec="P510530 obverse">face <span class="txtn">obverse</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="object">tablet</span></div>
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <span class="txtn">1</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[a-na] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">dingir-szu-ib-ni</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">dingir-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ib-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ni</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <span class="txtn">2</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[qi2]-bi2#-ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[qi2]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi2#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <span class="txtn">3</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[um-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[um-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{d}na-bi]-um#-na-s,i-ir-ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{d}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">um#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">s,i-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ir-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <span class="txtn">4</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[sze-a-am] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[sze-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
# <p><b>face</b> <i>2</i></p>
# <div class="contnr face " >
#
#     <div class="lbl face">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 reverse" sec="P510530 reverse">face <span class="txtn">reverse</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="object">tablet</span></div>
#     </div>
#
#
#     <div class="children face">
#
#
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <span class="txtn">1</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">u3 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u3 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ka-ni-ik </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ka-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ni-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ik </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">szi-ma-tim </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">tim </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ta-ad-di-in</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ta-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ad-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">di-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">in</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <span class="txtn">2</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">mi-nu-u2 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">mi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">nu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u2 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">a-wa-tum-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">wa-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">tum-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">da-ba-ba-am </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">da-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ba-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ba-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">am </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">tu-sze-er-szi</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">tu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sze-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">er-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <

# %% [markdown]
# # Constraining order
# You can stipulate an order on the things in your template.
# You only have to put a relational operator between them.
# Say we want only results where the damage follows the missing.

# %%
query = '''
line
  sign question=1
  sign missing=1
  < sign damage=1
'''

# %%
results = A.search(query)
A.table(results, end=10)
# Out:
#   0.55s 372 results
# <table><tr><th>n</th><th>p</th><th>line</th><th>sign</th><th>sign</th><th>sign</th></tr>
# <tr><td>1</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 obverse:5">P510530 obverse:5</a></td><td><span class="txtp">{disz}<span  class="hl" >[{d}</span>x]-<span  class="hl" >ra#?-</span>bi il-qe2-a-am-ma</span></td><td><span class="txtp"><span  class="hl" >ra#?-</span></span></td><td><span class="txtp"><span  class="hl" >[{d}</span></span></td><td><span class="txtp"><span  class="hl" >ra#?-</span></span></td></tr>
# <tr><td>2</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 obverse:5">P510530 obverse:5</a></td><td><span class="txtp">{disz}[{d}<span  class="hl" >x]-</span><span  class="hl" >ra#?-</span>bi il-qe2-a-am-ma</span></td><td><span class="txtp"><span  class="hl" >ra#?-</span></span></td><td><span class="txtp"><span  class="hl" >x]-</span></span></td><td><span class="txtp"><span  class="hl" >ra#?-</span></span></td></tr>
# <tr><td>3</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:11">P510530 reverse:11</a></td><td><span class="txtp"><span  class="hl" >[szu-</span>bu-<span  class="hl" >lim?] </span><span  class="hl" >sza# </span>ta-asz-pu-ra-am</span></td><td><span class="txtp"><span  class="hl" >lim?] </span></span></td><td><span class="txtp"><span  class="hl" >[szu-</span></span></td><td><span class="txtp"><span  class="hl" >sza# </span></span></td></tr>
# <tr><td>4</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:11">P510530 reverse:11</a></td><td><span class="txtp">[szu-<span  class="hl" >bu-</span><span  class="hl" >lim?] </span><span  class="hl" >sza# </span>ta-asz-pu-ra-am</span></td><td><span class="txtp"><span  class="hl" >lim?] </span></span></td><td><span class="txtp"><span  class="hl" >bu-</span></span></td><td><span class="txtp"><span  class="hl" >sza# </span></span></td></tr>
# <tr><td>5</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:11">P510530 reverse:11</a></td><td><span class="txtp">[szu-bu-<span  class="hl" >lim?] </span><span  class="hl" >sza# </span>ta-asz-pu-ra-am</span></td><td><span class="txtp"><span  class="hl" >lim?] </span></span></td><td><span class="txtp"><span  class="hl" >lim?] </span></span></td><td><span class="txtp"><span  class="hl" >sza# </span></span></td></tr>
# <tr><td>6</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510550" title="show this document on CDLI" sec="P510550 obverse:9">P510550 obverse:9</a></td><td><span class="txtp">_ha-za-nu-um{sar}_ i-ka-<span  class="hl" >am#? </span><span  class="hl" >[x] </span>x-<span  class="hl" >al#-</span>la-x-ma</span></td><td><span class="txtp"><span  class="hl" >am#? </span></span></td><td><span class="txtp"><span  class="hl" >[x] </span></span></td><td><span class="txtp"><span  class="hl" >al#-</span></span></td></tr>
# <tr><td>7</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510565" title="show this document on CDLI" sec="P510565 reverse:4">P510565 reverse:4</a></td><td><span class="txtp"><span  class="hl" >[a-</span><span  class="hl" >na?] </span>_e2_ {d}utu szu-ri-ba-<span  class="hl" >am#</span></span></td><td><span class="txtp"><span  class="hl" >na?] </span></span></td><td><span class="txtp"><span  class="hl" >[a-</span></span></td><td><span class="txtp"><span  class="hl" >am#</span></span></td></tr>
# <tr><td>8</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510565" title="show this document on CDLI" sec="P510565 reverse:4">P510565 reverse:4</a></td><td><span class="txtp">[a-<span  class="hl" >na?] </span>_e2_ {d}utu szu-ri-ba-<span  class="hl" >am#</span></span></td><td><span class="txtp"><span  class="hl" >na?] </span></span></td><td><span class="txtp"><span  class="hl" >na?] </span></span></td><td><span class="txtp"><span  class="hl" >am#</span></span></td></tr>
# <tr><td>9</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510567" title="show this document on CDLI" sec="P510567 reverse:2">P510567 reverse:2</a></td><td><span class="txtp"><span  class="hl" >[...] </span><span  class="hl" >ia#? </span>_sag-us2_</span></td><td><span class="txtp"><span  class="hl" >ia#? </span></span></td><td><span class="txtp"><span  class="hl" >[...] </span></span></td><td><span class="txtp"><span  class="hl" >ia#? </span></span></td></tr>
# <tr><td>10</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510586" title="show this document on CDLI" sec="P510586 obverse:11">P510586 obverse:11</a></td><td><span class="txtp"><span  class="hl" >[{disz}]</span>i-na-e2-ul-masz-<span  class="hl" >numun# </span>a-<span  class="hl" >na#? </span>[ma-ah-ri-ka?]</span></td><td><span class="txtp"><span  class="hl" >na#? </span></span></td><td><span class="txtp"><span  class="hl" >[{disz}]</span></span></td><td><span class="txtp"><span  class="hl" >numun# </span></span></td></tr></table>

# %% [markdown]
# We can also require the things to be adjacent.

# %%
query = '''
line
  sign question=1
  sign missing=1
  <: sign damage=1
'''

# %%
results = A.search(query)
A.table(results, end=10)
A.show(results, end=10, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
#   0.55s 84 results
# <table><tr><th>n</th><th>p</th><th>line</th><th>sign</th><th>sign</th><th>sign</th></tr>
# <tr><td>1</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 obverse:5">P510530 obverse:5</a></td><td><span class="txtp">{disz}[{d}<span  class="hl" >x]-</span><span  class="hl" >ra#?-</span>bi il-qe2-a-am-ma</span></td><td><span class="txtp"><span  class="hl" >ra#?-</span></span></td><td><span class="txtp"><span  class="hl" >x]-</span></span></td><td><span class="txtp"><span  class="hl" >ra#?-</span></span></td></tr>
# <tr><td>2</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="show this document on CDLI" sec="P510530 reverse:11">P510530 reverse:11</a></td><td><span class="txtp">[szu-bu-<span  class="hl" >lim?] </span><span  class="hl" >sza# </span>ta-asz-pu-ra-am</span></td><td><span class="txtp"><span  class="hl" >lim?] </span></span></td><td><span class="txtp"><span  class="hl" >lim?] </span></span></td><td><span class="txtp"><span  class="hl" >sza# </span></span></td></tr>
# <tr><td>3</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510567" title="show this document on CDLI" sec="P510567 reverse:2">P510567 reverse:2</a></td><td><span class="txtp"><span  class="hl" >[...] </span><span  class="hl" >ia#? </span>_sag-us2_</span></td><td><span class="txtp"><span  class="hl" >ia#? </span></span></td><td><span class="txtp"><span  class="hl" >[...] </span></span></td><td><span class="txtp"><span  class="hl" >ia#? </span></span></td></tr>
# <tr><td>4</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510586" title="show this document on CDLI" sec="P510586 obverse:27">P510586 obverse:27</a></td><td><span class="txtp">[asz-szum <span  class="hl" >ha]-</span><span  class="hl" >bil2#?-</span>we?-du-um sza asz-pu-ra#-[ak-kum]</span></td><td><span class="txtp"><span  class="hl" >bil2#?-</span></span></td><td><span class="txtp"><span  class="hl" >ha]-</span></span></td><td><span class="txtp"><span  class="hl" >bil2#?-</span></span></td></tr>
# <tr><td>5</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510586" title="show this document on CDLI" sec="P510586 obverse:27">P510586 obverse:27</a></td><td><span class="txtp">[asz-szum <span  class="hl" >ha]-</span><span  class="hl" >bil2#?-</span><span  class="hl" >we?-</span>du-um sza asz-pu-ra#-[ak-kum]</span></td><td><span class="txtp"><span  class="hl" >we?-</span></span></td><td><span class="txtp"><span  class="hl" >ha]-</span></span></td><td><span class="txtp"><span  class="hl" >bil2#?-</span></span></td></tr>
# <tr><td>6</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510588" title="show this document on CDLI" sec="P510588 left:1':2">P510588 left:1':2</a></td><td><span class="txtp"><span  class="hl" >[i?]-</span><span  class="hl" >na# </span>zimbir{ki#}</span></td><td><span class="txtp"><span  class="hl" >[i?]-</span></span></td><td><span class="txtp"><span  class="hl" >[i?]-</span></span></td><td><span class="txtp"><span  class="hl" >na# </span></span></td></tr>
# <tr><td>7</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510597" title="show this document on CDLI" sec="P510597 obverse:12">P510597 obverse:12</a></td><td><span class="txtp"><span  class="hl" >[a?-</span><span  class="hl" >na] </span><span  class="hl" >babila2#</span>[{ki}]</span></td><td><span class="txtp"><span  class="hl" >[a?-</span></span></td><td><span class="txtp"><span  class="hl" >na] </span></span></td><td><span class="txtp"><span  class="hl" >babila2#</span></span></td></tr>
# <tr><td>8</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510657" title="show this document on CDLI" sec="P510657 envelope - obverse:1">P510657 envelope - obverse:1</a></td><td><span class="txtp"><span  class="hl" >[tup]-</span><span  class="hl" >pi#? </span>a-hi-i3-li2-ia</span></td><td><span class="txtp"><span  class="hl" >pi#? </span></span></td><td><span class="txtp"><span  class="hl" >[tup]-</span></span></td><td><span class="txtp"><span  class="hl" >pi#? </span></span></td></tr>
# <tr><td>9</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510660" title="show this document on CDLI" sec="P510660 reverse:7">P510660 reverse:7</a></td><td><span class="txtp"><span  class="hl" >[t,e4?]-</span><span  class="hl" >em# </span>_a-sza3_ ma-la a-di i-na-an-na</span></td><td><span class="txtp"><span  class="hl" >[t,e4?]-</span></span></td><td><span class="txtp"><span  class="hl" >[t,e4?]-</span></span></td><td><span class="txtp"><span  class="hl" >em# </span></span></td></tr>
# <tr><td>10</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510662" title="show this document on CDLI" sec="P510662 reverse:1">P510662 reverse:1</a></td><td><span class="txtp"><span  class="hl" >[1(disz)?] </span><span  class="hl" >_tug2#?_ </span>a-la-qe2-am</span></td><td><span class="txtp"><span  class="hl" >[1(disz)?] </span></span></td><td><span class="txtp"><span  class="hl" >[1(disz)?] </span></span></td><td><span class="txtp"><span  class="hl" >_tug2#?_ </span></span></td></tr></table>
# <p><b>result</b> <i>1</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 obverse:5" sec="P510530 obverse:5">line <span class="txtn">5</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{disz}[{d}x]-ra#?-bi </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{disz}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[{d}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">x]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ra#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bi </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">il-qe2-a-am-ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">il-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">qe2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">am-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>2</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510530" title="P510530 reverse:11" sec="P510530 reverse:11">line <span class="txtn">11</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[szu-bu-lim?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">lim?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sza# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ta-asz-pu-ra-am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ta-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">asz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">pu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ra-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>3</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510567" title="P510567 reverse:2" sec="P510567 reverse:2">line <span class="txtn">2</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[...] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[...] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="grapheme"><span class="f">grapheme=</span>...</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ia#? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ia#? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_sag-us2_</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_sag-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">us2_</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>4</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510586" title="P510586 obverse:27" sec="P510586 obverse:27">line <span class="txtn">27</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[asz-szum </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[asz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szum </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ha]-bil2#?-we?-du-um </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ha]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">bil2#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">we?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">du-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">um </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sza </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sza </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">asz-pu-ra#-[ak-kum]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">asz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">pu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ra#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[ak-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">kum]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>5</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510586" title="P510586 obverse:27" sec="P510586 obverse:27">line <span class="txtn">27</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[asz-szum </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[asz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szum </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ha]-bil2#?-we?-du-um </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ha]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">bil2#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">we?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">du-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">um </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sza </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sza </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">asz-pu-ra#-[ak-kum]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">asz-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">pu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ra#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[ak-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">kum]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>6</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510588" title="P510588 left:1':2" sec="P510588 left:1':2">line <span class="txtn">1':2</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[i?]-na# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[i?]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">na# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">zimbir{ki#}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">zimbir</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{ki#}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="det"><span class="f">det=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>7</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510597" title="P510597 obverse:12" sec="P510597 obverse:12">line <span class="txtn">12</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[a?-na] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[a?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">na] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">babila2#[{ki}]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">babila2#</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[{ki}]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>8</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510657" title="P510657 envelope - obverse:1" sec="P510657 envelope - obverse:1">line <span class="txtn">1</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[tup]-pi#? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[tup]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">pi#? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">a-hi-i3-li2-ia</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">hi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">i3-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">li2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ia</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>9</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510660" title="P510660 reverse:7" sec="P510660 reverse:7">line <span class="txtn">7</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[t,e4?]-em# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[t,e4?]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">em# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_a-sza3_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">_a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sza3_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ma-la </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">la </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">a-di </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">di </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">i-na-an-na</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">i-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">an-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">na</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>10</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510662" title="P510662 reverse:1" sec="P510662 reverse:1">line <span class="txtn">1</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[1(disz)?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[1(disz)?] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span> <span class="repeat"><span class="f">repeat=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">_tug2#?_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">_tug2#?_ </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span> <span class="langalt"><span class="f">langalt=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">a-la-qe2-am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">la-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">qe2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">am</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# Finally, we make the three things fully adjacent in fixed order:

# %%
query = '''
line
  sign question=1
  <: sign missing=1
  <: sign damage=1
'''

# %%
results = A.search(query)
A.table(results, end=10)
A.show(results, end=10, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
#   0.55s 7 results
# <table><tr><th>n</th><th>p</th><th>line</th><th>sign</th><th>sign</th><th>sign</th></tr>
# <tr><td>1</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510597" title="show this document on CDLI" sec="P510597 obverse:12">P510597 obverse:12</a></td><td><span class="txtp"><span  class="hl" >[a?-</span><span  class="hl" >na] </span><span  class="hl" >babila2#</span>[{ki}]</span></td><td><span class="txtp"><span  class="hl" >[a?-</span></span></td><td><span class="txtp"><span  class="hl" >na] </span></span></td><td><span class="txtp"><span  class="hl" >babila2#</span></span></td></tr>
# <tr><td>2</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P292756" title="show this document on CDLI" sec="P292756 obverse:21">P292756 obverse:21</a></td><td><span class="txtp"><span  class="hl" >[sza? </span><span  class="hl" >(...)] </span><span  class="hl" >it#-</span>ti-ia u2-ul in-nam-ru-ma</span></td><td><span class="txtp"><span  class="hl" >[sza? </span></span></td><td><span class="txtp"><span  class="hl" >(...)] </span></span></td><td><span class="txtp"><span  class="hl" >it#-</span></span></td></tr>
# <tr><td>3</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P313393" title="show this document on CDLI" sec="P313393 obverse:3">P313393 obverse:3</a></td><td><span class="txtp">um-ma <span  class="hl" >ni?-</span><span  class="hl" >[...]-</span><span  class="hl" >ma#</span></span></td><td><span class="txtp"><span  class="hl" >ni?-</span></span></td><td><span class="txtp"><span  class="hl" >[...]-</span></span></td><td><span class="txtp"><span  class="hl" >ma#</span></span></td></tr>
# <tr><td>4</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P386470" title="show this document on CDLI" sec="P386470 reverse:15'">P386470 reverse:15'</a></td><td><span class="txtp"><span  class="hl" >[u2?-</span><span  class="hl" >sze]-</span><span  class="hl" >et#-</span>bu-u2-[szu?]</span></td><td><span class="txtp"><span  class="hl" >[u2?-</span></span></td><td><span class="txtp"><span  class="hl" >sze]-</span></span></td><td><span class="txtp"><span  class="hl" >et#-</span></span></td></tr>
# <tr><td>5</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305755" title="show this document on CDLI" sec="P305755 reverse:3">P305755 reverse:3</a></td><td><span class="txtp">u3 <span  class="hl" >KA#?-</span><span  class="hl" >[x]-</span><span  class="hl" >UM#? </span>a-hu-u2-szu qa2-ta-ti-szu-ma</span></td><td><span class="txtp"><span  class="hl" >KA#?-</span></span></td><td><span class="txtp"><span  class="hl" >[x]-</span></span></td><td><span class="txtp"><span  class="hl" >UM#? </span></span></td></tr>
# <tr><td>6</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P307155" title="show this document on CDLI" sec="P307155 obverse:11">P307155 obverse:11</a></td><td><span class="txtp">mi-im#-ma# sza ta#-<span  class="hl" >GA?-</span><span  class="hl" >[x]-</span><span  class="hl" >BU#? </span>[x]</span></td><td><span class="txtp"><span  class="hl" >GA?-</span></span></td><td><span class="txtp"><span  class="hl" >[x]-</span></span></td><td><span class="txtp"><span  class="hl" >BU#? </span></span></td></tr>
# <tr><td>7</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P308015" title="show this document on CDLI" sec="P308015 reverse:2">P308015 reverse:2</a></td><td><span class="txtp">{disz}<span  class="hl" >UD?-</span><span  class="hl" >[x] </span><span  class="hl" >{ki#}-</span>li-ib-lu-ut,</span></td><td><span class="txtp"><span  class="hl" >UD?-</span></span></td><td><span class="txtp"><span  class="hl" >[x] </span></span></td><td><span class="txtp"><span  class="hl" >{ki#}-</span></span></td></tr></table>
# <p><b>result</b> <i>1</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510597" title="P510597 obverse:12" sec="P510597 obverse:12">line <span class="txtn">12</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[a?-na] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[a?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">na] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">babila2#[{ki}]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">babila2#</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[{ki}]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>2</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P292756" title="P292756 obverse:21" sec="P292756 obverse:21">line <span class="txtn">21</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[sza? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[sza? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">(...)] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">(...)] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="uncertain"><span class="f">uncertain=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span> <span class="grapheme"><span class="f">grapheme=</span>...</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">it#-ti-ia </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">it#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ti-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ia </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">u2-ul </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ul </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">in-nam-ru-ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">in-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">nam-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ru-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>3</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P313393" title="P313393 obverse:3" sec="P313393 obverse:3">line <span class="txtn">3</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">um-ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">um-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ni?-[...]-ma#</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ni?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[...]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="grapheme"><span class="f">grapheme=</span>...</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">ma#</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>4</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P386470" title="P386470 reverse:15'" sec="P386470 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[u2?-sze]-et#-bu-u2-[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[u2?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sze]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">et#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>5</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P305755" title="P305755 reverse:3" sec="P305755 reverse:3">line <span class="txtn">3</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">u3 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u3 </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">KA#?-[x]-UM#? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">KA#?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span> <span class="grapheme"><span class="f">grapheme=</span>KA</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[x]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">UM#? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span> <span class="grapheme"><span class="f">grapheme=</span>UM</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">a-hu-u2-szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">a-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">hu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">qa2-ta-ti-szu-ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">qa2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ta-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ti-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">szu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>6</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P307155" title="P307155 obverse:11" sec="P307155 obverse:11">line <span class="txtn">11</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">mi-im#-ma# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">mi-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">im#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ma# </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">sza </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">sza </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">ta#-GA?-[x]-BU#? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ta#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">GA?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="grapheme"><span class="f">grapheme=</span>GA</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[x]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">BU#? </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span>1</span> <span class="grapheme"><span class="f">grapheme=</span>BU</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[x]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[x]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
# <p><b>result</b> <i>7</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P308015" title="P308015 reverse:2" sec="P308015 reverse:2">line <span class="txtn">2</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{disz}UD?-[x] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">{disz}</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="det"><span class="f">det=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">UD?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="grapheme"><span class="f">grapheme=</span>UD</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[x] </span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">{ki#}-li-ib-lu-ut,</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">{ki#}-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="det"><span class="f">det=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">li-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ib-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">lu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">ut,</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# # Custom feature display
#
# We would like to see the original atf and the flags for signs.
# The way to do that, is to perform a `A.prettySetup(features)` first.
#
# We concentrate on one specific result.

# %%
A.displaySetup(extraFeatures='atf flags')

# %%
A.show(results, start=4, end=4, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
# <p><b>result</b> <i>4</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P386470" title="P386470 reverse:15'" sec="P386470 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[u2?-sze]-et#-bu-u2-[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>[u2?-sze]-et#-bu-u2-[szu?]</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[u2?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span> <span class="atf xft"><span class="f">atf=</span>u2?</span> <span class="flags xft"><span class="f">flags=</span>?</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sze]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="atf xft"><span class="f">atf=</span>sze</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">et#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="atf xft"><span class="f">atf=</span>et#</span> <span class="flags xft"><span class="f">flags=</span>#</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>bu</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>u2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span> <span class="atf xft"><span class="f">atf=</span>szu?</span> <span class="flags xft"><span class="f">flags=</span>?</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# The features without meaningful values have been left out. We can also change that by passing a set of values
# we think are not meaningful. The default set is
#
# ```python
# {None, 'NA', 'none', 'unknown'}
# ```

# %%
A.displaySetup(noneValues=set())
A.show(results, start=4, end=4, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
# <p><b>result</b> <i>4</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P386470" title="P386470 reverse:15'" sec="P386470 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="remarks"></span> <span class="translation@en"></span> <span class="atf xft"><span class="f">atf=</span></span> <span class="damage xft"><span class="f">damage=</span></span> <span class="flags xft"><span class="f">flags=</span></span> <span class="missing xft"><span class="f">missing=</span></span> <span class="question xft"><span class="f">question=</span></span></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[u2?-sze]-et#-bu-u2-[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>[u2?-sze]-et#-bu-u2-[szu?]</span> <span class="damage xft"><span class="f">damage=</span></span> <span class="flags xft"><span class="f">flags=</span></span> <span class="missing xft"><span class="f">missing=</span></span> <span class="question xft"><span class="f">question=</span></span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[u2?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="collated"><span class="f">collated=</span></span> <span class="remarkable"><span class="f">remarkable=</span></span> <span class="question"><span class="f">question=</span>1</span> <span class="damage"><span class="f">damage=</span></span> <span class="det"><span class="f">det=</span></span> <span class="uncertain"><span class="f">uncertain=</span></span> <span class="missing"><span class="f">missing=</span>1</span> <span class="excised"><span class="f">excised=</span></span> <span class="supplied"><span class="f">supplied=</span></span> <span class="langalt"><span class="f">langalt=</span></span> <span class="comment"><span class="f">comment=</span></span> <span class="remarks"><span class="f">remarks=</span></span> <span class="repeat"><span class="f">repeat=</span></span> <span class="fraction"><span class="f">fraction=</span></span> <span class="operator"><span class="f">operator=</span></span> <span class="grapheme"><span class="f">grapheme=</span></span> <span class="atf xft"><span class="f">atf=</span>u2?</span> <span class="flags xft"><span class="f">flags=</span>?</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sze]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="collated"><span class="f">collated=</span></span> <span class="remarkable"><span class="f">remarkable=</span></span> <span class="question"><span class="f">question=</span></span> <span class="damage"><span class="f">damage=</span></span> <span class="det"><span class="f">det=</span></span> <span class="uncertain"><span class="f">uncertain=</span></span> <span class="missing"><span class="f">missing=</span>1</span> <span class="excised"><span class="f">excised=</span></span> <span class="supplied"><span class="f">supplied=</span></span> <span class="langalt"><span class="f">langalt=</span></span> <span class="comment"><span class="f">comment=</span></span> <span class="remarks"><span class="f">remarks=</span></span> <span class="repeat"><span class="f">repeat=</span></span> <span class="fraction"><span class="f">fraction=</span></span> <span class="operator"><span class="f">operator=</span></span> <span class="grapheme"><span class="f">grapheme=</span></span> <span class="atf xft"><span class="f">atf=</span>sze</span> <span class="flags xft"><span class="f">flags=</span></span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">et#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="collated"><span class="f">collated=</span></span> <span class="remarkable"><span class="f">remarkable=</span></span> <span class="question"><span class="f">question=</span></span> <span class="damage"><span class="f">damage=</span>1</span> <span class="det"><span class="f">det=</span></span> <span class="uncertain"><span class="f">uncertain=</span></span> <span class="missing"><span class="f">missing=</span></span> <span class="excised"><span class="f">excised=</span></span> <span class="supplied"><span class="f">supplied=</span></span> <span class="langalt"><span class="f">langalt=</span></span> <span class="comment"><span class="f">comment=</span></span> <span class="remarks"><span class="f">remarks=</span></span> <span class="repeat"><span class="f">repeat=</span></span> <span class="fraction"><span class="f">fraction=</span></span> <span class="operator"><span class="f">operator=</span></span> <span class="grapheme"><span class="f">grapheme=</span></span> <span class="atf xft"><span class="f">atf=</span>et#</span> <span class="flags xft"><span class="f">flags=</span>#</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="collated"><span class="f">collated=</span></span> <span class="remarkable"><span class="f">remarkable=</span></span> <span class="question"><span class="f">question=</span></span> <span class="damage"><span class="f">damage=</span></span> <span class="det"><span class="f">det=</span></span> <span class="uncertain"><span class="f">uncertain=</span></span> <span class="missing"><span class="f">missing=</span></span> <span class="excised"><span class="f">excised=</span></span> <span class="supplied"><span class="f">supplied=</span></span> <span class="langalt"><span class="f">langalt=</span></span> <span class="comment"><span class="f">comment=</span></span> <span class="remarks"><span class="f">remarks=</span></span> <span class="repeat"><span class="f">repeat=</span></span> <span class="fraction"><span class="f">fraction=</span></span> <span class="operator"><span class="f">operator=</span></span> <span class="grapheme"><span class="f">grapheme=</span></span> <span class="atf xft"><span class="f">atf=</span>bu</span> <span class="flags xft"><span class="f">flags=</span></span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="collated"><span class="f">collated=</span></span> <span class="remarkable"><span class="f">remarkable=</span></span> <span class="question"><span class="f">question=</span></span> <span class="damage"><span class="f">damage=</span></span> <span class="det"><span class="f">det=</span></span> <span class="uncertain"><span class="f">uncertain=</span></span> <span class="missing"><span class="f">missing=</span></span> <span class="excised"><span class="f">excised=</span></span> <span class="supplied"><span class="f">supplied=</span></span> <span class="langalt"><span class="f">langalt=</span></span> <span class="comment"><span class="f">comment=</span></span> <span class="remarks"><span class="f">remarks=</span></span> <span class="repeat"><span class="f">repeat=</span></span> <span class="fraction"><span class="f">fraction=</span></span> <span class="operator"><span class="f">operator=</span></span> <span class="grapheme"><span class="f">grapheme=</span></span> <span class="atf xft"><span class="f">atf=</span>u2</span> <span class="flags xft"><span class="f">flags=</span></span></div>
#     <

# %% [markdown]
# This makes clear that it is convenient to keep `None` in the `noneValues`:

# %%
A.displaySetup(noneValues={None})
A.show(results, start=4, end=4, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
# <p><b>result</b> <i>4</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P386470" title="P386470 reverse:15'" sec="P386470 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[u2?-sze]-et#-bu-u2-[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>[u2?-sze]-et#-bu-u2-[szu?]</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[u2?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span> <span class="atf xft"><span class="f">atf=</span>u2?</span> <span class="flags xft"><span class="f">flags=</span>?</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sze]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="atf xft"><span class="f">atf=</span>sze</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">et#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="atf xft"><span class="f">atf=</span>et#</span> <span class="flags xft"><span class="f">flags=</span>#</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>bu</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>u2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span> <span class="atf xft"><span class="f">atf=</span>szu?</span> <span class="flags xft"><span class="f">flags=</span>?</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# We can even choose to suppress other values, e.g. the value 1.
#
# That will remove all the features such as `question`, `missing`.

# %%
A.displaySetup(noneValues={None, 'NA', 'unknown', 1})
A.show(results, start=4, end=4, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
# <p><b>result</b> <i>4</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P386470" title="P386470 reverse:15'" sec="P386470 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[u2?-sze]-et#-bu-u2-[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>[u2?-sze]-et#-bu-u2-[szu?]</span></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[u2?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>u2?</span> <span class="flags xft"><span class="f">flags=</span>?</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sze]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>sze</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">et#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>et#</span> <span class="flags xft"><span class="f">flags=</span>#</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>bu</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>u2</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="atf xft"><span class="f">atf=</span>szu?</span> <span class="flags xft"><span class="f">flags=</span>?</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# In the rest of the notebook we stick to our normal setup, so we reset the extra features.

# %%
A.displayReset()
A.show(results, start=4, end=4, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
# <p><b>result</b> <i>4</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P386470" title="P386470 reverse:15'" sec="P386470 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[u2?-sze]-et#-bu-u2-[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[u2?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sze]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">et#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# # Features from queries
#
# In earlier displays we saw the *types* of signs, because the query mentioned it.
#
# Suppose we want to display the type also here, then we can modify the query by mentioning the feature `type`.
#
# But we do not want to impose extra limitations, so we say `type*`, meaning: no conditions on type whatsoever.

# %%
query = '''
line
  sign question=1 type*
  <: sign missing=1
  <: sign damage=1
'''

# %%
results = A.search(query)
A.show(results, start=4, end=4, colorMap={0: '', 2: 'cyan', 3: 'magenta', 4: 'lightsalmon'})
# Out:
#   0.54s 7 results
# <p><b>result</b> <i>4</i></p>
# <div class="contnr line " >
#
#     <div class="lbl line">
#         <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P386470" title="P386470 reverse:15'" sec="P386470 reverse:15'">line <span class="txtn">15'</span></a>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children line">
#
#
# <div class="contnr word " >
#
#     <div class="lbl word">
#         <span class="txtp">[u2?-sze]-et#-bu-u2-[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"></div>
#     </div>
#
#
#     <div class="children word">
#
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="lbl sign">
#         <span class="txtp">[u2?-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="lbl sign">
#         <span class="txtp">sze]-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="missing"><span class="f">missing=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign hl"  style="background-color: lightsalmon;" >
#
#     <div class="lbl sign">
#         <span class="txtp">et#-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="damage"><span class="f">damage=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">bu-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">u2-</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
# <div class="contnr sign " >
#
#     <div class="lbl sign">
#         <span class="txtp">[szu?]</span>
#
#     </div>
#
#     <div class="meta">
#         <div class="features"> <span class="question"><span class="f">question=</span>1</span> <span class="missing"><span class="f">missing=</span>1</span> <span class="type xft"><span class="f">type=</span>reading</span></div>
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %% [markdown]
# # Show your own tuples
#
# So far we have `show()`n the results of searches.
# But you can also construct your own tuples and show them.
#
# Whereas you can use search to get a pretty good approximation of what you want, most of the times
# you do not arrive precisely at your destination.
#
# Here is an example where we use search to come close, and then work our way to produce the end result.
#
# ## More missing than damaged
#
# We look for lines that have more missing signs than damaged signs.
#
# In our search templates we cannot formulate that a feature has different values on two nodes in the template.
# We could spell out all possible combinations of values and make a search template for each of them,
# but that is needlessly complex.
#
# Let's first use search to find all clauses containing missing and damaged signs.

# %%
query = '''
line
  sign missing
  sign damage
'''
results = A.search(query)
# Out:
#   0.31s 9900 results

# %% [markdown]
# Now the hand coding begins. We are going to extract the tuples we want.

# %%
lines = {}
for (l, m, d) in results:
  lines.setdefault(l, (set(), set()))
  lines[l][0].add(m)
  lines[l][1].add(d)
print(f'{len(lines)} lines')
# Out:
# 3031 lines

# %% [markdown]
# Now we have all lines with both missing and damaged signs, without duplicates.
#
# For each line we have a set with its missing signs and one with its damaged signs.
#
# We filter in order to retain the lines with more missing than damaged signs.
# We put all missing signs in one big set and all damaged signs in one big set.

# %%
answer = []
missing = set()
damage = set()

for (l, (m, d)) in lines.items():
  if len(m) > len(d):
    answer.append((l, *m, *d))
    missing |= m
    damage |= d
len(answer)
# Out:
# 1345

# %%
answer[0]
# Out:
# (230893, 955, 956, 954)

# %% [markdown]
# We are going to make a dictionary of highligts: one color for the missing signs and one for the damaged.

# %%
highlights = {}
colorM = 'lightsalmon'
colorD = 'mediumaquamarine'
for s in missing:
  highlights[s] = colorM
for s in damage:
  highlights[s] = colorD

# %% [markdown]
# And now we can show them:

# %%
A.table(answer, start=1, end=10, highlights=highlights)
# Out:
# <table><tr><th>n</th><th>p</th><th>line</th><th>sign</th><th>sign</th><th>sign</th></tr>
# <tr><td>1</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P509377" title="show this document on CDLI" sec="P509377 reverse:2">P509377 reverse:2</a></td><td><span class="txtp">_sze_ u3 _ku3-babbar_ ad-di-na-<span  class="hl"  style="background-color: mediumaquamarine;" >ak#-</span><span  class="hl"  style="background-color: lightsalmon;" >[kum-</span><span  class="hl"  style="background-color: lightsalmon;" >ma]</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[kum-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >ma]</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >ak#-</span></span></td></tr>
# <tr><td>2</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P481192" title="show this document on CDLI" sec="P481192 obverse:10'">P481192 obverse:10'</a></td><td><span class="txtp">_a-sza3_ u2-ul e-<span  class="hl"  style="background-color: mediumaquamarine;" >ri#-</span><span  class="hl"  style="background-color: lightsalmon;" >[isz </span><span  class="hl"  style="background-color: lightsalmon;" >...]</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[isz </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >...]</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >ri#-</span></span></td></tr>
# <tr><td>3</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P481192" title="show this document on CDLI" sec="P481192 obverse:13'">P481192 obverse:13'</a></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[x </span><span  class="hl"  style="background-color: lightsalmon;" >(x)] </span>x-a-tum it-<span  class="hl"  style="background-color: mediumaquamarine;" >ta#-</span>za-az-za i-mu-ut-ta</span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[x </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >(x)] </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >ta#-</span></span></td></tr>
# <tr><td>4</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P481192" title="show this document on CDLI" sec="P481192 obverse:14'">P481192 obverse:14'</a></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[...] </span>x tup-<span  class="hl"  style="background-color: mediumaquamarine;" >pu# </span><span  class="hl"  style="background-color: lightsalmon;" >[x </span><span  class="hl"  style="background-color: lightsalmon;" >x] </span>a-<span  class="hl"  style="background-color: mediumaquamarine;" >na# </span><span  class="hl"  style="background-color: mediumaquamarine;" >ma#-</span>har a-<span  class="hl"  style="background-color: lightsalmon;" >[wi-</span><span  class="hl"  style="background-color: lightsalmon;" >le-</span><span  class="hl"  style="background-color: lightsalmon;" >e]</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[...] </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[x </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >x] </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[wi-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >le-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >e]</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >na# </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >ma#-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >pu# </span></span></td></tr>
# <tr><td>5</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P481192" title="show this document on CDLI" sec="P481192 reverse:13'">P481192 reverse:13'</a></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[x </span><span  class="hl"  style="background-color: lightsalmon;" >(x)] </span>x-ma a-na ma-ah-<span  class="hl"  style="background-color: mediumaquamarine;" >ri#-</span><span  class="hl"  style="background-color: mediumaquamarine;" >ka# </span>il-li-kam x x <span  class="hl"  style="background-color: lightsalmon;" >[(x) </span><span  class="hl"  style="background-color: lightsalmon;" >(x)]</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >(x)]</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[(x) </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[x </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >(x)] </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >ri#-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >ka# </span></span></td></tr>
# <tr><td>6</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P389256" title="show this document on CDLI" sec="P389256 obverse:4'">P389256 obverse:4'</a></td><td><span class="txtp">uz-ni-ia <span  class="hl"  style="background-color: mediumaquamarine;" >li#-</span><span  class="hl"  style="background-color: lightsalmon;" >[x </span><span  class="hl"  style="background-color: lightsalmon;" >...]</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[x </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >...]</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >li#-</span></span></td></tr>
# <tr><td>7</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P389256" title="show this document on CDLI" sec="P389256 left:2">P389256 left:2</a></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[...] </span>i-di-<span  class="hl"  style="background-color: mediumaquamarine;" >in# </span><span  class="hl"  style="background-color: lightsalmon;" >[...]</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[...] </span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[...]</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: mediumaquamarine;" >in# </span></span></td></tr>
# <tr><td>8</td><td> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P510527" title="show this document on CDLI" sec="P510527 reverse:1">P510527 reverse:1</a></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[a-</span><span  class="hl"  style="background-color: lightsalmon;" >wi]-</span><span  class="hl"  style="background-color: mediumaquamarine;" >lu#-</span>u2 i-na mu-uh2-hi ip-qu2-i3-li2-szu _di-ku5_</span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >[a-</span></span></td><td><span class="txtp"><span  class="hl"  style="background-color: lightsalmon;" >wi]-</span></span></td><td><span class="txtp"><span

# %% [markdown]
# As you see, you have total control.

# %% [markdown]
# ---
#
# All chapters:
#
# * **[start](start.ipynb)** become an expert in creating pretty displays of your text structures
# * **[display](display.ipynb)** become an expert in creating pretty displays of your text structures
# * **search** turbo charge your hand-coding with search templates
# * **[exportExcel](exportExcel.ipynb)** make tailor-made spreadsheets out of your results
# * **[share](share.ipynb)** draw in other people's data and let them use yours
