# %% [markdown]
# <img align="right" src="images/tf-small.png"/>
# <img align="right" src="images/uu-small.png"/>
# <img align="right" src="images/logo.png"/>
#
# # Search Introduction
#
# *Search* in Text-Fabric is a template based way of looking for structural patterns in your dataset.
#
# Within Text-Fabric we have the unique possibility to combine the ease of formulating search templates for
# complicated syntactical patterns with the power of programmatically processing the results.
#
# This notebook will show you how to get up and running.
#
# ## Easy command
#
# Search is as simple as saying (just an example)
#
# ```python
# results = A.search(template)
# A.show(results)
# ```
#
# See all ins and outs in the
# [search template docs](https://annotation.github.io/text-fabric/Use/Search/#search-templates).

# %% [markdown]
# # Incantation
#
# The ins and outs of installing Text-Fabric, getting the corpus, and initializing a notebook are
# explained in the [start tutorial](start.ipynb).

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use

# %%
A = use('quran', hoist=globals())
# Out:
# Using quran commit 2a86beb3f768265578d137052ca7f2b314f06ea1
#   in /Users/dirk/text-fabric-data/__apps__/quran
# Using q-ran/quran/tf - 0.2 rv0.3 in /Users/dirk/text-fabric-data
# **Documentation:** <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs" title="provenance of Quran">QURAN</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Writing/Arabic" title="('Arabic characters and transcriptions',)">Character table</a> <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#features.md" title="QURAN feature documentation">Feature docs</a> <a target="_blank" href="https://github.com/annotation/app-quran" title="quran API documentation">quran API</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/" title="text-fabric-api">Text-Fabric API 7.3.8</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Use/Search/" title="Search Templates Introduction and Reference">Search Reference</a>
# <details open><summary><b>Loaded features</b>:</summary>
# <p><b>Quran</b>: <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#a" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/a.tf">a</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#ascii" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/ascii.tf">ascii</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#ax" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/ax.tf">ax</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#case" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/case.tf">case</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#component" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/component.tf">component</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#definite" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/definite.tf">definite</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#f" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/f.tf">f</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#formation" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/formation.tf">formation</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#fx" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/fx.tf">fx</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#gn" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/gn.tf">gn</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#interjection" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/interjection.tf">interjection</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#l" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/l.tf">l</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#lemma" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/lemma.tf">lemma</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#lx" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/lx.tf">lx</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#mood" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/mood.tf">mood</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#n" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/n.tf">n</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#name" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/name.tf">name</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#name@ll" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/name@en.tf">name@ll</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#nameAscii" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/nameAscii.tf">nameAscii</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#nameTrans" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/nameTrans.tf">nameTrans</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#nu" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/nu.tf">nu</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#number" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/number.tf">number</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#order" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/order.tf">order</a>  <a target="_blank" href="https://github.co ...
# <style>
# @font-face {
#   font-family: "AmiriQuran";
#   src: url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.ttf?raw=true');
#   src: url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff2?raw=true') format('woff');
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .aya {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-end;
#     align-items: flex-end;
#     direction: ltr;
#     width: 100%;
# }
# .outeritem {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .word {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 1px solid #cccccc;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .lextp {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 2px solid #888888;
#     width: fit-content;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .occs {
#     font-size: x-small;
# }
# .tr,.tr a:visited,.tr a:link {
#     font-family: sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: ltr;
#     text-decoration: none;
# }
# .trb,.trb a:visited,.trb a:link {
#     font-family: sans-serif;
#     font-size: normal;
#     direction: ltr;
#     text-decoration: none;
# }
# .ar,.ar a:visited,.ar a:link {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: rtl;
#     text-decoration: none;
# }
# .arb,.arb a:visited,.arb a:link {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     line-height: 3;
#     direction: rtl;
#     text-decoration: none;
# }
# .vn {
#   font-size: small !important;
#   padding-right: 1em;
# }
# .sp,.sp a:visited,.sp a:link {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
#     text-decoration: none;
# }
# .lexeme {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .vs {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .vt {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .hl {
#     background-color: #ffee66;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlup {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>
# <details open><summary><b>API members</b>:</summary>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">C Computed</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Call AllComputeds</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Cs ComputedString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">E Edge</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Eall AllEdges</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Es EdgeString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ensureLoaded</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">TF</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ignored</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">loadLog</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Locality/#locality" title="doc">L Locality</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">cache</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">error</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">indent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">info</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">reset</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">N Nodes</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKey</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKeyTuple</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">otypeRank</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortNodes</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">F Feature</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fall AllFeatures</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fs FeatureString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Search/#search" title="doc">S Search</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Text/#text" title="doc">T Text</a></details>

# %% [markdown]
# # Basic search command
#
# We start with the most simple form of issuing a query.
# Let's look for the words in sura 1.
#
# All work involved in searching takes place under the hood.

# %%
query = '''
sura number=1|2|3
  aya number<4
    word
'''
results = A.search(query)
A.table(results, end=10)
# Out:
#   0.13s 80 results
# n | p | sura | aya | word
# --- | --- | --- | --- | ---
# 1| <a href="http://tanzil.net/#1:1" title="show this passage on Tanzil" sec="1:1">1:1</a>|<span class="trb"><a href="http://tanzil.net/#1:1" title="1" sec="1">1</a></span>|<span class="arb"><span class="vn">1:1</span><span  class="hl" >بِ</span>سْمِ ٱللَّهِ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ</span>|<span class="arb"><span  class="hl" >بِ</span></span>
# 2| <a href="http://tanzil.net/#1:1" title="show this passage on Tanzil" sec="1:1">1:1</a>|<span class="trb"><a href="http://tanzil.net/#1:1" title="1" sec="1">1</a></span>|<span class="arb"><span class="vn">1:1</span>بِ<span  class="hl" >سْمِ </span>ٱللَّهِ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ</span>|<span class="arb"><span  class="hl" >سْمِ </span></span>
# 3| <a href="http://tanzil.net/#1:1" title="show this passage on Tanzil" sec="1:1">1:1</a>|<span class="trb"><a href="http://tanzil.net/#1:1" title="1" sec="1">1</a></span>|<span class="arb"><span class="vn">1:1</span>بِسْمِ <span  class="hl" >ٱللَّهِ </span>ٱلرَّحْمَٰنِ ٱلرَّحِيمِ</span>|<span class="arb"><span  class="hl" >ٱللَّهِ </span></span>
# 4| <a href="http://tanzil.net/#1:1" title="show this passage on Tanzil" sec="1:1">1:1</a>|<span class="trb"><a href="http://tanzil.net/#1:1" title="1" sec="1">1</a></span>|<span class="arb"><span class="vn">1:1</span>بِسْمِ ٱللَّهِ <span  class="hl" >ٱل</span>رَّحْمَٰنِ ٱلرَّحِيمِ</span>|<span class="arb"><span  class="hl" >ٱل</span></span>
# 5| <a href="http://tanzil.net/#1:1" title="show this passage on Tanzil" sec="1:1">1:1</a>|<span class="trb"><a href="http://tanzil.net/#1:1" title="1" sec="1">1</a></span>|<span class="arb"><span class="vn">1:1</span>بِسْمِ ٱللَّهِ ٱل<span  class="hl" >رَّحْمَٰنِ </span>ٱلرَّحِيمِ</span>|<span class="arb"><span  class="hl" >رَّحْمَٰنِ </span></span>
# 6| <a href="http://tanzil.net/#1:1" title="show this passage on Tanzil" sec="1:1">1:1</a>|<span class="trb"><a href="http://tanzil.net/#1:1" title="1" sec="1">1</a></span>|<span class="arb"><span class="vn">1:1</span>بِسْمِ ٱللَّهِ ٱلرَّحْمَٰنِ <span  class="hl" >ٱل</span>رَّحِيمِ</span>|<span class="arb"><span  class="hl" >ٱل</span></span>
# 7| <a href="http://tanzil.net/#1:1" title="show this passage on Tanzil" sec="1:1">1:1</a>|<span class="trb"><a href="http://tanzil.net/#1:1" title="1" sec="1">1</a></span>|<span class="arb"><span class="vn">1:1</span>بِسْمِ ٱللَّهِ ٱلرَّحْمَٰنِ ٱل<span  class="hl" >رَّحِيمِ</span></span>|<span class="arb"><span  class="hl" >رَّحِيمِ</span></span>
# 8| <a href="http://tanzil.net/#1:2" title="show this passage on Tanzil" sec="1:2">1:2</a>|<span class="trb"><a href="http://tanzil.net/#1:1" title="1" sec="1">1</a></span>|<span class="arb"><span class="vn">1:2</span><span  class="hl" >ٱلْ</span>حَمْدُ لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ</span>|<span class="arb"><span  class="hl" >ٱلْ</span></span>
# 9| <a href="http://tanzil.net/#1:2" title="show this passage on Tanzil" sec="1:2">1:2</a>|<span class="trb"><a href="http://tanzil.net/#1:1" title="1" sec="1">1</a></span>|<span class="arb"><span class="vn">1:2</span>ٱلْ<span  class="hl" >حَمْدُ </span>لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ</span>|<span class="arb"><span  class="hl" >حَمْدُ </span></span>
# 10| <a href="http://tanzil.net/#1:2" title="show this passage on Tanzil" sec="1:2">1:2</a>|<span class="trb"><a href="http://tanzil.net/#1:1" title="1" sec="1">1</a></span>|<span class="arb"><span class="vn">1:2</span>ٱلْحَمْدُ <span  class="hl" >لِ</span>لَّهِ رَبِّ ٱلْعَٰلَمِينَ</span>|<span class="arb"><span  class="hl" >لِ</span></span>

# %% [markdown]
# The hyperlinks take us to aya on Tanzil.
#
# Note that we can choose start and/or end points in the results list.

# %%
A.table(results, start=8, end=13, linked=3)
# Out:
# n | p | sura | aya | word
# --- | --- | --- | --- | ---
# 8| <a href="http://tanzil.net/#1:2" title="show this passage on Tanzil" sec="1:2">1:2</a>|<span class="trb">1</span>|<span class="arb"><span class="vn">1:2</span><span  class="hl" >ٱلْ</span>حَمْدُ لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ</span>|<span class="arb"><a href="http://tanzil.net/#1:2" title="1:2" sec="1:2"><span  class="hl" >ٱلْ</span></a></span>
# 9| <a href="http://tanzil.net/#1:2" title="show this passage on Tanzil" sec="1:2">1:2</a>|<span class="trb">1</span>|<span class="arb"><span class="vn">1:2</span>ٱلْ<span  class="hl" >حَمْدُ </span>لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ</span>|<span class="arb"><a href="http://tanzil.net/#1:2" title="1:2" sec="1:2"><span  class="hl" >حَمْدُ </span></a></span>
# 10| <a href="http://tanzil.net/#1:2" title="show this passage on Tanzil" sec="1:2">1:2</a>|<span class="trb">1</span>|<span class="arb"><span class="vn">1:2</span>ٱلْحَمْدُ <span  class="hl" >لِ</span>لَّهِ رَبِّ ٱلْعَٰلَمِينَ</span>|<span class="arb"><a href="http://tanzil.net/#1:2" title="1:2" sec="1:2"><span  class="hl" >لِ</span></a></span>
# 11| <a href="http://tanzil.net/#1:2" title="show this passage on Tanzil" sec="1:2">1:2</a>|<span class="trb">1</span>|<span class="arb"><span class="vn">1:2</span>ٱلْحَمْدُ لِ<span  class="hl" >لَّهِ </span>رَبِّ ٱلْعَٰلَمِينَ</span>|<span class="arb"><a href="http://tanzil.net/#1:2" title="1:2" sec="1:2"><span  class="hl" >لَّهِ </span></a></span>
# 12| <a href="http://tanzil.net/#1:2" title="show this passage on Tanzil" sec="1:2">1:2</a>|<span class="trb">1</span>|<span class="arb"><span class="vn">1:2</span>ٱلْحَمْدُ لِلَّهِ <span  class="hl" >رَبِّ </span>ٱلْعَٰلَمِينَ</span>|<span class="arb"><a href="http://tanzil.net/#1:2" title="1:2" sec="1:2"><span  class="hl" >رَبِّ </span></a></span>
# 13| <a href="http://tanzil.net/#1:2" title="show this passage on Tanzil" sec="1:2">1:2</a>|<span class="trb">1</span>|<span class="arb"><span class="vn">1:2</span>ٱلْحَمْدُ لِلَّهِ رَبِّ <span  class="hl" >ٱلْ</span>عَٰلَمِينَ</span>|<span class="arb"><a href="http://tanzil.net/#1:2" title="1:2" sec="1:2"><span  class="hl" >ٱلْ</span></a></span>

# %% [markdown]
# We can show the results more fully with `show()`.

# %%
A.show(results, start=1, end=3)
# Out:
# **result** *1*
# <div class="None  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:1" title="show this passage on Tanzil" sec="1">1</a></div>
#
#     </div>
#
#
# </div>
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:1" title="show this passage on Tanzil" sec="1:1">1:1</a></div>
#
#     </div>
#
# <div class="word  hl" >
# <div class="ar">بِ</div>
# <div class="features"> <span class="pos">preposition</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">سْمِ </div>
# <div class="features"> <span class="lemma">{som</span> <span class="root">smw</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱللَّهِ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">رَّحْمَٰنِ </div>
# <div class="features"> <span class="lemma">r~aHoma`n</span> <span class="root">rHm</span> <span class="pos">adjective</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">رَّحِيمِ</div>
# <div class="features"> <span class="lemma">r~aHiym</span> <span class="root">rHm</span> <span class="pos">adjective</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
#
# </div>
# **result** *2*
# <div class="None  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:1" title="show this passage on Tanzil" sec="1">1</a></div>
#
#     </div>
#
#
# </div>
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:1" title="show this passage on Tanzil" sec="1:1">1:1</a></div>
#
#     </div>
#
# <div class="word  " >
# <div class="ar">بِ</div>
# <div class="features"> <span class="pos">preposition</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">سْمِ </div>
# <div class="features"> <span class="lemma">{som</span> <span class="root">smw</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱللَّهِ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">رَّحْمَٰنِ </div>
# <div class="features"> <span class="lemma">r~aHoma`n</span> <span class="root">rHm</span> <span class="pos">adjective</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">رَّحِيمِ</div>
# <div class="features"> <span class="lemma">r~aHiym</span> <span class="root">rHm</span> <span class="pos">adjective</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
#
# </div>
# **result** *3*
# <div class="None  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:1" title="show this passage on Tanzil" sec="1">1</a></div>
#
#     </div>
#
#
# </div>
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:1" title="show this passage on Tanzil" sec="1:1">1:1</a></div>
#
#     </div>
#
# <div class="word  " >
# <div class="ar">بِ</div>
# <div class="features"> <span class="pos">preposition</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">سْمِ </div>
# <div class="features"> <span class="lemma">{som</span> <span class="root">smw</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ٱللَّهِ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">رَّحْمَٰنِ </div>
# <div class="features"> <span class="lemma">r~aHoma`n</span> <span class="root">rHm</span> <span class="pos">adjective</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">رَّحِيمِ</div>
# <div class="features"> <span class="lemma">r~aHiym</span> <span class="root">rHm</span> <span class="pos">adjective</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# We can show all results condensed by *aya*:

# %%
A.show(results, condensed=True)
# Out:
# **aya** *1*
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:1" title="show this passage on Tanzil" sec="1:1">1:1</a></div>
#
#     </div>
#
# <div class="word  hl" >
# <div class="ar">بِ</div>
# <div class="features"> <span class="pos">preposition</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">سْمِ </div>
# <div class="features"> <span class="lemma">{som</span> <span class="root">smw</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ٱللَّهِ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">رَّحْمَٰنِ </div>
# <div class="features"> <span class="lemma">r~aHoma`n</span> <span class="root">rHm</span> <span class="pos">adjective</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">رَّحِيمِ</div>
# <div class="features"> <span class="lemma">r~aHiym</span> <span class="root">rHm</span> <span class="pos">adjective</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
#
# </div>
# **aya** *2*
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:2" title="show this passage on Tanzil" sec="1:2">1:2</a></div>
#
#     </div>
#
# <div class="word  hl" >
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">حَمْدُ </div>
# <div class="features"> <span class="lemma">Hamod</span> <span class="root">Hmd</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">لِ</div>
# <div class="features"> <span class="pos">preposition</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">لَّهِ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">رَبِّ </div>
# <div class="features"> <span class="lemma">rab~</span> <span class="root">rbb</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">عَٰلَمِينَ</div>
# <div class="features"> <span class="lemma">Ea`lamiyn</span> <span class="root">Elm</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
#
# </div>
# **aya** *3*
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:3" title="show this passage on Tanzil" sec="1:3">1:3</a></div>
#
#     </div>
#
# <div class="word  hl" >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">رَّحْمَٰنِ </div>
# <div class="features"> <span class="lemma">r~aHoma`n</span> <span class="root">rHm</span> <span class="pos">adjective</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">رَّحِيمِ</div>
# <div class="features"> <span class="lemma">r~aHiym</span> <span class="root">rHm</span> <span class="pos">adjective</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
#
# </div>
# **aya** *4*
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:1" title="show this passage on Tanzil" sec="2:1">2:1</a></div>
#
#     </div>
#
# <div class="word  hl" >
# <div class="ar">الٓمٓ</div>
# <div class="features"> <span class="pos">initials</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
#
# </div>
# **aya** *5*
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:2" title="show this passage on Tanzil" sec="2:2">2:2</a></div>
#
#     </div>
#
# <div class="word  hl" >
# <div class="ar">ذَٰلِكَ </div>
# <div class="features"> <span class="lemma">*a`lik</span> <span class="pos">pronoun</span> <span class="posx">demonstrative</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">كِتَٰبُ </div>
# <div class="features"> <span class="lemma">kita`b</span> <span class="root">ktb</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">لَا </div>
# <div class="features"> <span class="lemma">laA</span> <span class="pos">particle</span> <span class="posx">negative</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">رَيْبَ </div>
# <div class="features"> <span class="lemma">rayob</span> <span class="root">ryb</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">فِي</div>
# <div class="features"> <span class="lemma">fiY</span> <span class="pos">preposition</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">هِ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">هُدًى </div>
# <div class="features"> <span class="lemma">hudFY</span> <span class="root">hdy</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">لِّ</div>
# <div class="features"> <span class="pos">preposition</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">لْ</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">مُتَّقِينَ</div>
# <div class="features"> <span class="lemma">mut~aqiyn</span> <span class="root">wqy</span> <span class="pos">noun</span> <span class="formation">VIII</span> <span class="tense">participle</span> <span class="number xft"><span class="f">number=</span>3</span></div>
#
#
# </div>
#
#
# </div>
# **aya** *6*
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:3" title="show this passage on Tanzil" sec="2:3">2:3</a></div>
#
#     </div>
#
# <div class="word  hl" >
# <div class="ar">ٱلَّذِينَ </div>
# <div class="features"> <span class="lemma">{l~a*iY</span> <span class="pos">pronoun</span> <span class="posx">relative</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">يُؤْمِنُ</div>
# <div class="features"> <span class="lemma">'aAmana</span> <span class="root">Amn</span> <span class="pos">verb</span> <span class="formation">IV</span> <span class="tense">imperfect</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ونَ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">بِ</div>
# <div class="features"> <span class="pos">preposition</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">غَيْبِ </div>
# <div class="features"> <span class="lemma">gayob</span> <span class="root">gyb</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>3</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">يُقِيمُ</div>
# <div class="features"> <span class="lemma">>aqaAma</span> <span class="root">qwm</span> <span class="pos">verb</span> <span class="formation">IV</span> <span class="tense">imperfect</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ونَ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span> <span class="number xft"><span class="f">number=</span>3</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">صَّلَوٰةَ </div>
# <div class="features"> <span class="lemma">Salaw`p</span> <span class="root">Slw</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">مِ</div>
# <div class="features"> <span class="lemma">min</span> <span class="pos">preposition</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">مَّا </div>
# <div class="features"> <span class="lemma">maA</span> <span class="pos">pronoun</span> <span class="posx">relative</span> <span class="number xft"><span class="f">number=</span>3</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">رَزَقْ</div>
# <div class="features"> <span class="lemma">razaqa</span> <span class="root">rzq</span> <span class="pos">verb</span> <span class="tense">perfect</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">نَٰ</div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">هُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span> <span class="number xft"><span class="f">number=</span>3</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">يُنفِقُ</div>
# <div class="features"> <span class="lemma">>anfaqa</span> <span class="root">nfq</span> <span class="pos">verb</span> <span class="formation">IV</span> <span class="tense">imperfect</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ونَ</div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
#
# </div>
# **aya** *7*
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#3:1" title="show this passage on Tanzil" sec="3:1">3:1</a></div>
#
#     </div>
#
# <div class="word  hl" >
# <div class="ar">الٓمٓ</div>
# <div class="features"> <span class="pos">initials</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
#
# </div>
# **aya** *8*
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#3:2" title="show this passage on Tanzil" sec="3:2">3:2</a></div>
#
#     </div>
#
# <div class="word  hl" >
# <div class="ar">ٱللَّهُ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">لَآ </div>
# <div class="features"> <span class="lemma">laA</span> <span class="pos">particle</span> <span class="posx">negative</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">إِلَٰهَ </div>
# <div class="features"> <span class="lemma">&lt;ila`h</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">إِلَّا </div>
# <div class="features"> <span class="lemma">&lt;il~aA</span> <span class="pos">particle</span> <span class="posx">exceptive</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">هُوَ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">حَىُّ </div>
# <div class="features"> <span class="lemma">Hay~</span> <span class="root">Hyy</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">قَيُّومُ</div>
# <div class="features"> <span class="lemma">qay~uwm</span> <span class="root">qwm</span> <span class="pos">adjective</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
#
# </div>
# **aya** *9*
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#3:3" title="show this passage on Tanzil" sec="3:3">3:3</a></div>
#
#     </div>
#
# <div class="word  hl" >
# <div class="ar">نَزَّلَ </div>
# <div class="features"> <span class="lemma">naz~ala</span> <span class="root">nzl</span> <span class="pos">verb</span> <span class="formation">II</span> <span class="tense">perfect</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">عَلَيْ</div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">كَ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">كِتَٰبَ </div>
# <div class="features"> <span class="lemma">kita`b</span> <span class="root">ktb</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">بِ</div>
# <div class="features"> <span class="pos">preposition</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">حَقِّ </div>
# <div class="features"> <span class="lemma">Haq~</span> <span class="root">Hqq</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>3</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">مُصَدِّقًا </div>
# <div class="features"> <span class="lemma">muSad~iq</span> <span class="root">Sdq</span> <span class="pos">noun</span> <span class="formation">II</span> <span class="tense">participle</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">لِّ</div>
# <div class="features"> <span class="pos">preposition</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">مَا </div>
# <div class="features"> <span class="lemma">maA</span> <span class="pos">pronoun</span> <span class="posx">relative</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">بَيْنَ </div>
# <div class="features"> <span class="lemma">bayon</span> <span class="root">byn</span> <span class="pos">adverb</span> <span class="posx">location</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">يَدَيْ</div>
# <div class="features"> <span class="lemma">yad</span> <span class="root">ydy</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">هِ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">أَنزَلَ </div>
# <div class="features"> <span class="lemma">>anzala</span> <span class="root">nzl</span> <span class="pos">verb</span> <span class="formation">IV</span> <span class="tense">perfect</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">تَّوْرَىٰةَ </div>
# <div class="features"> <span class="lemma">t~aworaY`p</span> <span class="pos">noun</span> <span class="posx">proper</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">إِنجِيلَ</div>
# <div class="features"> <span class="lemma">&lt;injiyl</span> <span class="pos">noun</span> <span class="posx">proper</span> <span class="number xft"><span class="f">number=</span>3</span></div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# or by *hizb*

# %%
A.show(results, condensed=True, condenseType='hizb')
# Out:
# **hizb** *1*
# <a href="http://tanzil.net/#1:1" title="show this passage on Tanzil" sec="1:1">1:1</a>
# <div class="None  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:1" title="1:1" sec="1:1"><span class="vn">hizb 1</span></a></div>
#
#     </div>
#
# <div class="aya  hl" >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:1" title="show this passage on Tanzil" sec="1:1">1:1</a></div>
#
#     </div>
#
# <div class="word  hl" >
# <div class="ar">بِ</div>
# <div class="features"> <span class="pos">preposition</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">سْمِ </div>
# <div class="features"> <span class="lemma">{som</span> <span class="root">smw</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ٱللَّهِ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">رَّحْمَٰنِ </div>
# <div class="features"> <span class="lemma">r~aHoma`n</span> <span class="root">rHm</span> <span class="pos">adjective</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">رَّحِيمِ</div>
# <div class="features"> <span class="lemma">r~aHiym</span> <span class="root">rHm</span> <span class="pos">adjective</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
#
# </div>
#
# <div class="aya  hl" >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:2" title="show this passage on Tanzil" sec="1:2">1:2</a></div>
#
#     </div>
#
# <div class="word  hl" >
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">حَمْدُ </div>
# <div class="features"> <span class="lemma">Hamod</span> <span class="root">Hmd</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">لِ</div>
# <div class="features"> <span class="pos">preposition</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">لَّهِ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">رَبِّ </div>
# <div class="features"> <span class="lemma">rab~</span> <span class="root">rbb</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">عَٰلَمِينَ</div>
# <div class="features"> <span class="lemma">Ea`lamiyn</span> <span class="root">Elm</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
#
# </div>
#
# <div class="aya  hl" >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:3" title="show this passage on Tanzil" sec="1:3">1:3</a></div>
#
#     </div>
#
# <div class="word  hl" >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">رَّحْمَٰنِ </div>
# <div class="features"> <span class="lemma">r~aHoma`n</span> <span class="root">rHm</span> <span class="pos">adjective</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="ar">رَّحِيمِ</div>
# <div class="features"> <span class="lemma">r~aHiym</span> <span class="root">rHm</span> <span class="pos">adjective</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
#
# </div>
#
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:4" title="show this passage on Tanzil" sec="1:4">1:4</a></div>
#
#     </div>
#
# <div class="word  " >
# <div class="ar">مَٰلِكِ </div>
# <div class="features"> <span class="lemma">ma`lik</span> <span class="root">mlk</span> <span class="pos">noun</span> <span class="tense">participle</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">يَوْمِ </div>
# <div class="features"> <span class="lemma">yawom</span> <span class="root">ywm</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">دِّينِ</div>
# <div class="features"> <span class="lemma">diyn</span> <span class="root">dyn</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
#
# </div>
#
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:5" title="show this passage on Tanzil" sec="1:5">1:5</a></div>
#
#     </div>
#
# <div class="word  " >
# <div class="ar">إِيَّاكَ </div>
# <div class="features"> <span class="lemma">&lt;iy~aA</span> <span class="pos">pronoun</span> <span class="posx">personal</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">نَعْبُدُ </div>
# <div class="features"> <span class="lemma">Eabada</span> <span class="root">Ebd</span> <span class="pos">verb</span> <span class="tense">imperfect</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">إِيَّاكَ </div>
# <div class="features"> <span class="lemma">&lt;iy~aA</span> <span class="pos">pronoun</span> <span class="posx">personal</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">نَسْتَعِينُ</div>
# <div class="features"> <span class="lemma">{sotaEiynu</span> <span class="root">Ewn</span> <span class="pos">verb</span> <span class="formation">X</span> <span class="tense">imperfect</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
#
# </div>
#
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:6" title="show this passage on Tanzil" sec="1:6">1:6</a></div>
#
#     </div>
#
# <div class="word  " >
# <div class="ar">ٱهْدِ</div>
# <div class="features"> <span class="lemma">hadaY</span> <span class="root">hdy</s
# **hizb** *2*
# <a href="http://tanzil.net/#2:283" title="show this passage on Tanzil" sec="2:283">2:283</a>
# <div class="None  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:283" title="2:283" sec="2:283"><span class="vn">hizb 20</span></a></div>
#
#     </div>
#
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:283" title="show this passage on Tanzil" sec="2:283">2:283</a></div>
#
#     </div>
#
# <div class="word  " >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">إِن </div>
# <div class="features"> <span class="lemma">&lt;in</span> <span class="pos">particle</span> <span class="posx">conditional</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">كُن</div>
# <div class="features"> <span class="lemma">kaAna</span> <span class="root">kwn</span> <span class="pos">verb</span> <span class="tense">perfect</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">تُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">عَلَىٰ </div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">سَفَرٍ </div>
# <div class="features"> <span class="lemma">safar</span> <span class="root">sfr</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">circumstantial</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">لَمْ </div>
# <div class="features"> <span class="lemma">lam</span> <span class="pos">particle</span> <span class="posx">negative</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">تَجِدُ</div>
# <div class="features"> <span class="lemma">wajada</span> <span class="root">wjd</span> <span class="pos">verb</span> <span class="tense">imperfect</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">وا۟ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">كَاتِبًا </div>
# <div class="features"> <span class="lemma">kaAtib</span> <span class="root">ktb</span> <span class="pos">noun</span> <span class="tense">participle</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">فَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">result</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">رِهَٰنٌ </div>
# <div class="features"> <span class="lemma">riha`n</span> <span class="root">rhn</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">مَّقْبُوضَةٌ </div>
# <div class="features"> <span class="lemma">m~aqobuwDap</span> <span class="root">qbD</span> <span class="pos">adjective</span> <span class="tense">participle</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">فَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">إِنْ </div>
# <div class="features"> <span class="lemma">&lt;in</span> <span class="pos">particle</span> <span class="posx">conditional</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">أَمِنَ </div>
# <div class="features"> <span class="lemma">>amina</span> <span class="root">Amn</span> <span class="pos">verb</span> <span class="tense">perfect</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">بَعْضُ</div>
# <div class="features"> <span class="lemma">baEoD</span> <span class="root">bED</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">كُم </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">بَعْضًا </div>
# <div class="features"> <span class="lemma">baEoD</span> <span class="root">bED</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">فَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">result</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">لْ</div>
# <div class="features"> <span class="pos">prefix</span> <span class="posx">imperative</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">يُؤَدِّ </div>
# <div class="features"> <span class="lemma">yu&amp;ad~i</span> <span class="root">Ady</span> <span class="pos">verb</span> <span class="formation">II</span> <span class="tense">imperfect</span> <span class="number xft"><span class="f">number=</span>3</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱلَّذِى </div>
# <div class="features"> <span class="lemma">{l~a*iY</span> <span class="pos">pronoun</span> <span class="posx">relative</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱؤْتُمِنَ </div>
# <div class="features"> <span class="lemma">{&amp;otumina</span> <span class="root">Amn</span> <span class="pos">verb</span> <span class="formation">VIII</span> <span class="tense">perfect</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">أَمَٰنَتَ</div>
# <div class="features"> <span class="lemma">>ama`nat</span> <span class="root">Amn</span> <span class="pos">noun</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">هُۥ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span> <span class="number xft"><span class="f">number=</span>1</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">لْ</div>
# <div class="features"> <span class="pos">prefix</span> <span class="posx">imperative</span> <span class="number xft"><span class="f">number=</span>2</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">يَتَّقِ </div>
# <div class="features"> <span class="lemma">{t~aqaY`</span> <span class="root">wqy</span> <span class="pos">verb</span> <span class="formation">VIII</span> <span class="tense">imperfect</span> <span class="number xft"><span class=

# %% [markdown]
# # Meaningful queries
#
# Let's turn to a bit more meaningful query:
#
# all ayas with a verb immediately followed by the word for Allah.

# %%
query = '''
aya
  word pos=verb
  <: word pos=noun posx=proper root=Alh
'''

# %% [markdown]
# We run it with `A.search()`:

# %%
results = A.search(query)
# Out:
#   0.31s 529 results

# %%
A.table(results, start=10, end=20)
# Out:
# n | p | aya | word | word
# --- | --- | --- | --- | ---
# 10| <a href="http://tanzil.net/#2:80" title="show this passage on Tanzil" sec="2:80">2:80</a>|<span class="arb"><a class="vn" href="http://tanzil.net/#2:80" title="2:80" sec="2:80">2:80</a>وَقَالُوا۟ لَن تَمَسَّنَا ٱلنَّارُ إِلَّآ أَيَّامًا مَّعْدُودَةً قُلْ أَتَّخَذْتُمْ عِندَ ٱللَّهِ عَهْدًا فَلَن <span  class="hl" >يُخْلِفَ </span><span  class="hl" >ٱللَّهُ </span>عَهْدَهُۥٓ أَمْ تَقُولُونَ عَلَى ٱللَّهِ مَا لَا تَعْلَمُونَ</span>|<span class="arb"><span  class="hl" >يُخْلِفَ </span></span>|<span class="arb"><span  class="hl" >ٱللَّهُ </span></span>
# 11| <a href="http://tanzil.net/#2:90" title="show this passage on Tanzil" sec="2:90">2:90</a>|<span class="arb"><a class="vn" href="http://tanzil.net/#2:90" title="2:90" sec="2:90">2:90</a>بِئْسَمَا ٱشْتَرَوْا۟ بِهِۦٓ أَنفُسَهُمْ أَن يَكْفُرُوا۟ بِمَآ <span  class="hl" >أَنزَلَ </span><span  class="hl" >ٱللَّهُ </span>بَغْيًا أَن يُنَزِّلَ ٱللَّهُ مِن فَضْلِهِۦ عَلَىٰ مَن يَشَآءُ مِنْ عِبَادِهِۦ فَبَآءُو بِغَضَبٍ عَلَىٰ غَضَبٍ وَلِلْكَٰفِرِينَ عَذَابٌ مُّهِينٌ</span>|<span class="arb"><span  class="hl" >أَنزَلَ </span></span>|<span class="arb"><span  class="hl" >ٱللَّهُ </span></span>
# 12| <a href="http://tanzil.net/#2:90" title="show this passage on Tanzil" sec="2:90">2:90</a>|<span class="arb"><a class="vn" href="http://tanzil.net/#2:90" title="2:90" sec="2:90">2:90</a>بِئْسَمَا ٱشْتَرَوْا۟ بِهِۦٓ أَنفُسَهُمْ أَن يَكْفُرُوا۟ بِمَآ أَنزَلَ ٱللَّهُ بَغْيًا أَن <span  class="hl" >يُنَزِّلَ </span><span  class="hl" >ٱللَّهُ </span>مِن فَضْلِهِۦ عَلَىٰ مَن يَشَآءُ مِنْ عِبَادِهِۦ فَبَآءُو بِغَضَبٍ عَلَىٰ غَضَبٍ وَلِلْكَٰفِرِينَ عَذَابٌ مُّهِينٌ</span>|<span class="arb"><span  class="hl" >يُنَزِّلَ </span></span>|<span class="arb"><span  class="hl" >ٱللَّهُ </span></span>
# 13| <a href="http://tanzil.net/#2:91" title="show this passage on Tanzil" sec="2:91">2:91</a>|<span class="arb"><a class="vn" href="http://tanzil.net/#2:91" title="2:91" sec="2:91">2:91</a>وَإِذَا قِيلَ لَهُمْ ءَامِنُوا۟ بِمَآ <span  class="hl" >أَنزَلَ </span><span  class="hl" >ٱللَّهُ </span>قَالُوا۟ نُؤْمِنُ بِمَآ أُنزِلَ عَلَيْنَا وَيَكْفُرُونَ بِمَا وَرَآءَهُۥ وَهُوَ ٱلْحَقُّ مُصَدِّقًا لِّمَا مَعَهُمْ قُلْ فَلِمَ تَقْتُلُونَ أَنۢبِيَآءَ ٱللَّهِ مِن قَبْلُ إِن كُنتُم مُّؤْمِنِينَ</span>|<span class="arb"><span  class="hl" >أَنزَلَ </span></span>|<span class="arb"><span  class="hl" >ٱللَّهُ </span></span>
# 14| <a href="http://tanzil.net/#2:109" title="show this passage on Tanzil" sec="2:109">2:109</a>|<span class="arb"><a class="vn" href="http://tanzil.net/#2:109" title="2:109" sec="2:109">2:109</a>وَدَّ كَثِيرٌ مِّنْ أَهْلِ ٱلْكِتَٰبِ لَوْ يَرُدُّونَكُم مِّنۢ بَعْدِ إِيمَٰنِكُمْ كُفَّارًا حَسَدًا مِّنْ عِندِ أَنفُسِهِم مِّنۢ بَعْدِ مَا تَبَيَّنَ لَهُمُ ٱلْحَقُّ فَٱعْفُوا۟ وَٱصْفَحُوا۟ حَتَّىٰ <span  class="hl" >يَأْتِىَ </span><span  class="hl" >ٱللَّهُ </span>بِأَمْرِهِۦٓ إِنَّ ٱللَّهَ عَلَىٰ كُلِّ شَىْءٍ قَدِيرٌ</span>|<span class="arb"><span  class="hl" >يَأْتِىَ </span></span>|<span class="arb"><span  class="hl" >ٱللَّهُ </span></span>
# 15| <a href="http://tanzil.net/#2:116" title="show this passage on Tanzil" sec="2:116">2:116</a>|<span class="arb"><a class="vn" href="http://tanzil.net/#2:116" title="2:116" sec="2:116">2:116</a>وَقَالُوا۟ <span  class="hl" >ٱتَّخَذَ </span><span  class="hl" >ٱللَّهُ </span>وَلَدًا سُبْحَٰنَهُۥ بَل لَّهُۥ مَا فِى ٱلسَّمَٰوَٰتِ وَٱلْأَرْضِ كُلٌّ لَّهُۥ قَٰنِتُونَ</span>|<span class="arb"><span  class="hl" >ٱتَّخَذَ </span></span>|<span class="arb"><span  class="hl" >ٱللَّهُ </span></span>
# 16| <a href="http://tanzil.net/#2:143" title="show this passage on Tanzil" sec="2:143">2:143</a>|<span class="arb"><a class="vn" href="http://tanzil.net/#2:143" title="2:143" sec="2:143">2:143</a>وَكَذَٰلِكَ جَعَلْنَٰكُمْ أُمَّةً وَسَطًا لِّتَكُونُوا۟ شُهَدَآءَ عَلَى ٱلنَّاسِ وَيَكُونَ ٱلرَّسُولُ عَلَيْكُمْ شَهِيدًا وَمَا جَعَلْنَا ٱلْقِبْلَةَ ٱلَّتِى كُنتَ عَلَيْهَآ إِلَّا لِنَعْلَمَ مَن يَتَّبِعُ ٱلرَّسُولَ مِمَّن يَنقَلِبُ عَلَىٰ عَقِبَيْهِ وَإِن كَانَتْ لَكَبِيرَةً إِلَّا عَلَى ٱلَّذِينَ <span  class="hl" >هَدَى </span><span  class="hl" >ٱللَّهُ </span>وَمَا كَانَ ٱللَّهُ لِيُضِيعَ إِيمَٰنَكُمْ إِنَّ ٱللَّهَ بِٱلنَّاسِ لَرَءُوفٌ رَّحِيمٌ</span>|<span class="arb"><span  class="hl" >هَدَى </span></span>|<span class="arb"><span  class="hl" >ٱللَّهُ </span></span>
# 17| <a href="http://tanzil.net/#2:143" title="show this passage on Tanzil" sec="2:143">2:143</a>|<span class="arb"><a class="vn" href="http://tanzil.net/#2:143" title="2:143" sec="2:143">2:143</a>وَكَذَٰلِكَ جَعَلْنَٰكُمْ أُمَّةً وَسَطًا لِّتَكُونُوا۟ شُهَدَآءَ عَلَى ٱلنَّاسِ وَيَكُونَ ٱلرَّسُولُ عَلَيْكُمْ شَهِيدًا وَمَا جَعَلْنَا ٱلْقِبْلَةَ ٱلَّتِى كُنتَ عَلَيْهَآ إِلَّا لِنَعْلَمَ مَن يَتَّبِعُ ٱلرَّسُولَ مِمَّن يَنقَلِبُ عَلَىٰ عَقِبَيْهِ وَإِن كَانَتْ لَكَبِيرَةً إِلَّا عَلَى ٱلَّذِينَ هَدَى ٱللَّهُ وَمَا <span  class="hl" >كَانَ </span><span  class="hl" >ٱللَّهُ </span>لِيُضِيعَ إِيمَٰنَكُمْ إِنَّ ٱللَّهَ بِٱلنَّاسِ لَرَءُوفٌ رَّحِيمٌ</span>|<span class="arb"><span  class="hl" >كَانَ </span></span>|<span class="arb"><span  class="hl" >ٱللَّهُ </span></span>
# 18| <a href="http://tanzil.net/#2:164" title="show this passage on Tanzil" sec="2:164">2:164</a>|<span class="arb"><a class="vn" href="http://tanzil.net/#2:164" title="2:164" sec="2:164">2:164</a>إِنَّ فِى خَلْقِ ٱلسَّمَٰوَٰتِ وَٱلْأَرْضِ وَٱخْتِلَٰفِ ٱلَّيْلِ وَٱلنَّهَارِ وَٱلْفُلْكِ ٱلَّتِى تَجْرِى فِى ٱلْبَحْرِ بِمَا يَنفَعُ ٱلنَّاسَ وَمَآ <span  class="hl" >أَنزَلَ </span><span  class="hl" >ٱللَّهُ </span>مِنَ ٱلسَّمَآءِ مِن مَّآءٍ فَأَحْيَا بِهِ ٱلْأَرْضَ بَعْدَ مَوْتِهَا وَبَثَّ فِيهَا مِن كُلِّ دَآبَّةٍ وَتَصْرِيفِ ٱلرِّيَٰحِ وَٱلسَّحَابِ ٱلْمُسَخَّرِ بَيْنَ ٱلسَّمَآءِ وَٱلْأَرْضِ لَءَايَٰتٍ لِّقَوْمٍ يَعْقِلُونَ</span>|<span class="arb"><span  class="hl" >أَنزَلَ </span></span>|<span class="arb"><span  class="hl" >ٱللَّهُ </span></span>
# 19| <a href="http://tanzil.net/#2:170" title="show this passage on Tanzil" sec="2:170">2:170</a>|<span class="arb"><a class="vn" href="http://tanzil.net/#2:170" title="2:170" sec="2:170">2:170</a>وَإِذَا قِيلَ لَهُمُ ٱتَّبِعُوا۟ مَآ <span  class="hl" >أَنزَلَ </span><span  class="hl" >ٱللَّهُ </span>قَالُوا۟ بَلْ نَتَّبِعُ مَآ أَلْفَيْنَا عَلَيْهِ ءَابَآءَنَآ أَوَلَوْ كَانَ ءَابَآؤُهُمْ لَا يَعْقِلُونَ شَيْـًٔا وَلَا يَهْتَدُونَ</span>|<span class="arb"><span  class="hl" >أَنزَلَ </span></span>|<span class="arb"><span  class="hl" >ٱللَّهُ </span></span>
# 20| <a href="http://tanzil.net/#2:174" title="show this passage on Tanzil" sec="2:174">2:174</a>|<span class="arb"><a class="vn" href="http://tanzil.net/#2:174" title="2:174" sec="2:174">2:174</a>إِنَّ ٱلَّذِينَ يَكْتُمُونَ مَآ <span  class="hl" >أَنزَلَ </span><span  class="hl" >ٱللَّهُ </span>مِنَ ٱلْكِتَٰبِ وَيَشْتَرُونَ بِهِۦ ثَمَنًا قَلِيلًا أُو۟لَٰٓئِكَ مَا يَأْكُلُونَ فِى بُطُونِهِمْ إِلَّا ٱلنَّارَ وَلَا يُكَلِّمُهُمُ ٱللَّهُ يَوْمَ ٱلْقِيَٰمَةِ وَلَا يُزَكِّيهِمْ وَلَهُمْ عَذَابٌ أَلِيمٌ</span>|<span class="arb"><span  class="hl" >أَنزَلَ </span></span>|<span class="arb"><span  class="hl" >ٱللَّهُ </span></span>

# %% [markdown]
# Here it comes: the `A.show()` function asks you for some limits (it will not show more than 100 at a time), and then it displays them.
#
# It lists the results as follows:
#
# * a heading showing which result in the sequence of all results this is
# * an overview of the nodes in the tuple of this result
# * a display of all verses that have result material, with the places highlighted that
#   correspond to a node in the result tuple

# %%
A.show(results, start=10, end=14, withNodes=True)
# Out:
# **result** *10*
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:80" title="show this passage on Tanzil" sec="2:80">2:80</a></div>
#         <a href="#" class="nd">205735</a>
#     </div>
#
# <div class="word  " >
# <a href="#" class="nd">2219</a>
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2220</a>
# <div class="ar">قَالُ</div>
# <div class="features"> <span class="lemma">qaAla</span> <span class="root">qwl</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2221</a>
# <div class="ar">وا۟ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2222</a>
# <div class="ar">لَن </div>
# <div class="features"> <span class="lemma">lan</span> <span class="pos">particle</span> <span class="posx">negative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2223</a>
# <div class="ar">تَمَسَّ</div>
# <div class="features"> <span class="lemma">mas~a</span> <span class="root">mss</span> <span class="pos">verb</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2224</a>
# <div class="ar">نَا </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2225</a>
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2226</a>
# <div class="ar">نَّارُ </div>
# <div class="features"> <span class="lemma">naAr</span> <span class="root">nwr</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2227</a>
# <div class="ar">إِلَّآ </div>
# <div class="features"> <span class="lemma">&lt;il~aA</span> <span class="pos">particle</span> <span class="posx">exceptive</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2228</a>
# <div class="ar">أَيَّامًا </div>
# <div class="features"> <span class="lemma">yawom</span> <span class="root">ywm</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2229</a>
# <div class="ar">مَّعْدُودَةً </div>
# <div class="features"> <span class="lemma">m~aEoduwdap</span> <span class="root">Edd</span> <span class="pos">adjective</span> <span class="tense">participle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2230</a>
# <div class="ar">قُلْ </div>
# <div class="features"> <span class="lemma">qaAla</span> <span class="root">qwl</span> <span class="pos">verb</span> <span class="tense">imperative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2231</a>
# <div class="ar">أَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">interrogative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2232</a>
# <div class="ar">تَّخَذْ</div>
# <div class="features"> <span class="lemma">{t~axa*a</span> <span class="root">Ax*</span> <span class="pos">verb</span> <span class="formation">VIII</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2233</a>
# <div class="ar">تُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2234</a>
# <div class="ar">عِندَ </div>
# <div class="features"> <span class="lemma">Eind</span> <span class="root">End</span> <span class="pos">adverb</span> <span class="posx">location</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2235</a>
# <div class="ar">ٱللَّهِ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2236</a>
# <div class="ar">عَهْدًا </div>
# <div class="features"> <span class="lemma">Eahod</span> <span class="root">Ehd</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2237</a>
# <div class="ar">فَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2238</a>
# <div class="ar">لَن </div>
# <div class="features"> <span class="lemma">lan</span> <span class="pos">particle</span> <span class="posx">negative</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <a href="#" class="nd">2239</a>
# <div class="ar">يُخْلِفَ </div>
# <div class="features"> <span class="lemma">>axolafu</span> <span class="root">xlf</span> <span class="pos">verb</span> <span class="formation">IV</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <a href="#" class="nd">2240</a>
# <div class="ar">ٱللَّهُ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2241</a>
# <div class="ar">عَهْدَ</div>
# <div class="features"> <span class="lemma">Eahod</span> <span class="root">Ehd</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2242</a>
# <div class="ar">هُۥٓ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2243</a>
# <div class="ar">أَمْ </div>
# <div class="features"> <span class="lemma">>am</span> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2244</a>
# <div class="ar">تَقُولُ</div>
# <div class="features"> <span class="lemma">qaAla</span> <span class="root">qwl</span> <span class="pos">verb</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2245</a>
# <div class="ar">ونَ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2246</a>
# <div class="ar">عَلَى </div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2247</a>
# <div class="ar">ٱللَّهِ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2248</a>
# <div class="ar">مَا </div>
# <div class="features"> <span class="lemma">maA</span> <span class="pos">pronoun</span> <span class="posx">relative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2249</a>
# <div class="ar">لَا </div>
# <div class="features"> <span class="lemma">laA</span> <span class="pos">particle</span> <span class="posx">negative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2250</a>
# <div class="ar">تَعْلَمُ</div>
# <div class="features"> <span class="lemma">Ealima</span> <span class="root">Elm</span> <span class="pos">verb</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2251</a>
# <div class="ar">ونَ</div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
#
# </div>
# **result** *11*
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:90" title="show this passage on Tanzil" sec="2:90">2:90</a></div>
#         <a href="#" class="nd">205745</a>
#     </div>
#
# <div class="word  " >
# <a href="#" class="nd">2595</a>
# <div class="ar">بِئْسَ</div>
# <div class="features"> <span class="lemma">bi}osa</span> <span class="root">bAs</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2596</a>
# <div class="ar">مَا </div>
# <div class="features"> <span class="lemma">maA</span> <span class="pos">pronoun</span> <span class="posx">relative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2597</a>
# <div class="ar">ٱشْتَرَ</div>
# <div class="features"> <span class="lemma">{$otaraY`</span> <span class="root">$ry</span> <span class="pos">verb</span> <span class="formation">VIII</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2598</a>
# <div class="ar">وْا۟ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2599</a>
# <div class="ar">بِ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2600</a>
# <div class="ar">هِۦٓ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2601</a>
# <div class="ar">أَنفُسَ</div>
# <div class="features"> <span class="lemma">nafos</span> <span class="root">nfs</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2602</a>
# <div class="ar">هُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2603</a>
# <div class="ar">أَن </div>
# <div class="features"> <span class="lemma">>an</span> <span class="pos">conjunction</span> <span class="posx">subordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2604</a>
# <div class="ar">يَكْفُرُ</div>
# <div class="features"> <span class="lemma">kafara</span> <span class="root">kfr</span> <span class="pos">verb</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2605</a>
# <div class="ar">وا۟ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2606</a>
# <div class="ar">بِ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2607</a>
# <div class="ar">مَآ </div>
# <div class="features"> <span class="lemma">maA</span> <span class="pos">pronoun</span> <span class="posx">relative</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <a href="#" class="nd">2608</a>
# <div class="ar">أَنزَلَ </div>
# <div class="features"> <span class="lemma">>anzala</span> <span class="root">nzl</span> <span class="pos">verb</span> <span class="formation">IV</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <a href="#" class="nd">2609</a>
# <div class="ar">ٱللَّهُ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2610</a>
# <div class="ar">بَغْيًا </div>
# <div class="features"> <span class="lemma">bagoy</span> <span class="root">bgy</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2611</a>
# <div class="ar">أَن </div>
# <div class="features"> <span class="lemma">>an</span> <span class="pos">conjunction</span> <span class="posx">subordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2612</a>
# <div class="ar">يُنَزِّلَ </div>
# <div class="features"> <span class="lemma">naz~ala</span> <span class="root">nzl</span> <span class="pos">verb</span> <span class="formation">II</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2613</a>
# <div class="ar">ٱللَّهُ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2614</a>
# <div class="ar">مِن </div>
# <div class="features"> <span class="lemma">min</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2615</a>
# <div class="ar">فَضْلِ</div>
# <div class="features"> <span class="lemma">faDol</span> <span class="root">fDl</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2616</a>
# <div class="ar">هِۦ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2617</a>
# <div class="ar">عَلَىٰ </div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2618</a>
# <div class="ar">مَن </div>
# <div class="features"> <span class="lemma">man</span> <span class="pos">pronoun</span> <span class="posx">relative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2619</a>
# <div class="ar">يَشَآءُ </div>
# <div class="features"> <span class="lemma">$aA^'a</span> <span class="root">$yA</span> <span class="pos">verb</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2620</a>
# <div class="ar">مِنْ </div>
# <div class="features"> <span class="lemma">min</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2621</a>
# <div class="ar">عِبَادِ</div>
# <div class="features"> <span class="lemma">Eabod</span> <span class="root">Ebd</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2622</a>
# <div class="ar">هِۦ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2623</a>
# <div class="ar">فَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2624</a>
# <div class="ar">بَآءُ</div>
# <div class="features"> <span class="lemma">baA^'a</span> <span class="root">bwA</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2625</a>
# <div class="ar">و </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2626</a>
# <div class="ar">بِ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2627</a>
# <div class="ar">غَضَبٍ </div>
# <div class="features"> <span class="lemma">gaDab</span> <span class="root">gDb</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2628</a>
# <div class="ar">عَلَىٰ </div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2629</a>
# <div class="ar">غَضَبٍ </div>
# <div class="features"> <span class="lemma">gaDab</span> <span class="root">gDb</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2630</a>
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2631</a>
# <
# **result** *12*
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:90" title="show this passage on Tanzil" sec="2:90">2:90</a></div>
#         <a href="#" class="nd">205745</a>
#     </div>
#
# <div class="word  " >
# <a href="#" class="nd">2595</a>
# <div class="ar">بِئْسَ</div>
# <div class="features"> <span class="lemma">bi}osa</span> <span class="root">bAs</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2596</a>
# <div class="ar">مَا </div>
# <div class="features"> <span class="lemma">maA</span> <span class="pos">pronoun</span> <span class="posx">relative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2597</a>
# <div class="ar">ٱشْتَرَ</div>
# <div class="features"> <span class="lemma">{$otaraY`</span> <span class="root">$ry</span> <span class="pos">verb</span> <span class="formation">VIII</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2598</a>
# <div class="ar">وْا۟ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2599</a>
# <div class="ar">بِ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2600</a>
# <div class="ar">هِۦٓ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2601</a>
# <div class="ar">أَنفُسَ</div>
# <div class="features"> <span class="lemma">nafos</span> <span class="root">nfs</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2602</a>
# <div class="ar">هُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2603</a>
# <div class="ar">أَن </div>
# <div class="features"> <span class="lemma">>an</span> <span class="pos">conjunction</span> <span class="posx">subordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2604</a>
# <div class="ar">يَكْفُرُ</div>
# <div class="features"> <span class="lemma">kafara</span> <span class="root">kfr</span> <span class="pos">verb</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2605</a>
# <div class="ar">وا۟ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2606</a>
# <div class="ar">بِ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2607</a>
# <div class="ar">مَآ </div>
# <div class="features"> <span class="lemma">maA</span> <span class="pos">pronoun</span> <span class="posx">relative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2608</a>
# <div class="ar">أَنزَلَ </div>
# <div class="features"> <span class="lemma">>anzala</span> <span class="root">nzl</span> <span class="pos">verb</span> <span class="formation">IV</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2609</a>
# <div class="ar">ٱللَّهُ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2610</a>
# <div class="ar">بَغْيًا </div>
# <div class="features"> <span class="lemma">bagoy</span> <span class="root">bgy</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2611</a>
# <div class="ar">أَن </div>
# <div class="features"> <span class="lemma">>an</span> <span class="pos">conjunction</span> <span class="posx">subordinating</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <a href="#" class="nd">2612</a>
# <div class="ar">يُنَزِّلَ </div>
# <div class="features"> <span class="lemma">naz~ala</span> <span class="root">nzl</span> <span class="pos">verb</span> <span class="formation">II</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <a href="#" class="nd">2613</a>
# <div class="ar">ٱللَّهُ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2614</a>
# <div class="ar">مِن </div>
# <div class="features"> <span class="lemma">min</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2615</a>
# <div class="ar">فَضْلِ</div>
# <div class="features"> <span class="lemma">faDol</span> <span class="root">fDl</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2616</a>
# <div class="ar">هِۦ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2617</a>
# <div class="ar">عَلَىٰ </div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2618</a>
# <div class="ar">مَن </div>
# <div class="features"> <span class="lemma">man</span> <span class="pos">pronoun</span> <span class="posx">relative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2619</a>
# <div class="ar">يَشَآءُ </div>
# <div class="features"> <span class="lemma">$aA^'a</span> <span class="root">$yA</span> <span class="pos">verb</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2620</a>
# <div class="ar">مِنْ </div>
# <div class="features"> <span class="lemma">min</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2621</a>
# <div class="ar">عِبَادِ</div>
# <div class="features"> <span class="lemma">Eabod</span> <span class="root">Ebd</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2622</a>
# <div class="ar">هِۦ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2623</a>
# <div class="ar">فَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2624</a>
# <div class="ar">بَآءُ</div>
# <div class="features"> <span class="lemma">baA^'a</span> <span class="root">bwA</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2625</a>
# <div class="ar">و </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2626</a>
# <div class="ar">بِ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2627</a>
# <div class="ar">غَضَبٍ </div>
# <div class="features"> <span class="lemma">gaDab</span> <span class="root">gDb</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2628</a>
# <div class="ar">عَلَىٰ </div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2629</a>
# <div class="ar">غَضَبٍ </div>
# <div class="features"> <span class="lemma">gaDab</span> <span class="root">gDb</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2630</a>
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2631</a>
# <
# **result** *13*
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:91" title="show this passage on Tanzil" sec="2:91">2:91</a></div>
#         <a href="#" class="nd">205746</a>
#     </div>
#
# <div class="word  " >
# <a href="#" class="nd">2636</a>
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2637</a>
# <div class="ar">إِذَا </div>
# <div class="features"> <span class="lemma">&lt;i*aA</span> <span class="pos">adverb</span> <span class="posx">time</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2638</a>
# <div class="ar">قِيلَ </div>
# <div class="features"> <span class="lemma">qaAla</span> <span class="root">qwl</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2639</a>
# <div class="ar">لَ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2640</a>
# <div class="ar">هُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2641</a>
# <div class="ar">ءَامِنُ</div>
# <div class="features"> <span class="lemma">'aAmana</span> <span class="root">Amn</span> <span class="pos">verb</span> <span class="formation">IV</span> <span class="tense">imperative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2642</a>
# <div class="ar">وا۟ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2643</a>
# <div class="ar">بِ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2644</a>
# <div class="ar">مَآ </div>
# <div class="features"> <span class="lemma">maA</span> <span class="pos">pronoun</span> <span class="posx">relative</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <a href="#" class="nd">2645</a>
# <div class="ar">أَنزَلَ </div>
# <div class="features"> <span class="lemma">>anzala</span> <span class="root">nzl</span> <span class="pos">verb</span> <span class="formation">IV</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <a href="#" class="nd">2646</a>
# <div class="ar">ٱللَّهُ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2647</a>
# <div class="ar">قَالُ</div>
# <div class="features"> <span class="lemma">qaAla</span> <span class="root">qwl</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2648</a>
# <div class="ar">وا۟ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2649</a>
# <div class="ar">نُؤْمِنُ </div>
# <div class="features"> <span class="lemma">'aAmana</span> <span class="root">Amn</span> <span class="pos">verb</span> <span class="formation">IV</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2650</a>
# <div class="ar">بِ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2651</a>
# <div class="ar">مَآ </div>
# <div class="features"> <span class="lemma">maA</span> <span class="pos">pronoun</span> <span class="posx">relative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2652</a>
# <div class="ar">أُنزِلَ </div>
# <div class="features"> <span class="lemma">>anzala</span> <span class="root">nzl</span> <span class="pos">verb</span> <span class="formation">IV</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2653</a>
# <div class="ar">عَلَيْ</div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2654</a>
# <div class="ar">نَا </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2655</a>
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2656</a>
# <div class="ar">يَكْفُرُ</div>
# <div class="features"> <span class="lemma">kafara</span> <span class="root">kfr</span> <span class="pos">verb</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2657</a>
# <div class="ar">ونَ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2658</a>
# <div class="ar">بِ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2659</a>
# <div class="ar">مَا </div>
# <div class="features"> <span class="lemma">maA</span> <span class="pos">pronoun</span> <span class="posx">relative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2660</a>
# <div class="ar">وَرَآءَ</div>
# <div class="features"> <span class="lemma">waraA^'</span> <span class="root">wry</span> <span class="pos">adverb</span> <span class="posx">location</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2661</a>
# <div class="ar">هُۥ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2662</a>
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2663</a>
# <div class="ar">هُوَ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2664</a>
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2665</a>
# <div class="ar">حَقُّ </div>
# <div class="features"> <span class="lemma">Haq~</span> <span class="root">Hqq</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2666</a>
# <div class="ar">مُصَدِّقًا </div>
# <div class="features"> <span class="lemma">muSad~iq</span> <span class="root">Sdq</span> <span class="pos">noun</span> <span class="formation">II</span> <span class="tense">participle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2667</a>
# <div class="ar">لِّ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2668</a>
# <div class="ar">مَا </div>
# <div class="features"> <span class="lemma">maA</span> <span class="pos">pronoun</span> <span class="posx">relative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2669</a>
# <div class="ar">مَعَ</div>
# <div class="features"> <span class="lemma">maE2</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2670</a>
# <div class="ar">هُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2671</a>
# <div class="ar">قُلْ </div>
# <div class="features"> <span class="lemma">qaAla</span> <span class="root">qwl</span> <span class="pos">verb</span> <span class="tense">imperative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">2672</a>
# <div class="ar">فَ</div>
# <div class="features"> <span class="p
# **result** *14*
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:109" title="show this passage on Tanzil" sec="2:109">2:109</a></div>
#         <a href="#" class="nd">205764</a>
#     </div>
#
# <div class="word  " >
# <a href="#" class="nd">3241</a>
# <div class="ar">وَدَّ </div>
# <div class="features"> <span class="lemma">wad~a</span> <span class="root">wdd</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3242</a>
# <div class="ar">كَثِيرٌ </div>
# <div class="features"> <span class="lemma">kaviyr</span> <span class="root">kvr</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3243</a>
# <div class="ar">مِّنْ </div>
# <div class="features"> <span class="lemma">min</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3244</a>
# <div class="ar">أَهْلِ </div>
# <div class="features"> <span class="lemma">>ahol</span> <span class="root">Ahl</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3245</a>
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3246</a>
# <div class="ar">كِتَٰبِ </div>
# <div class="features"> <span class="lemma">kita`b</span> <span class="root">ktb</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3247</a>
# <div class="ar">لَوْ </div>
# <div class="features"> <span class="lemma">law</span> <span class="pos">conjunction</span> <span class="posx">subordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3248</a>
# <div class="ar">يَرُدُّ</div>
# <div class="features"> <span class="lemma">rad~a</span> <span class="root">rdd</span> <span class="pos">verb</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3249</a>
# <div class="ar">ونَ</div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3250</a>
# <div class="ar">كُم </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3251</a>
# <div class="ar">مِّنۢ </div>
# <div class="features"> <span class="lemma">min</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3252</a>
# <div class="ar">بَعْدِ </div>
# <div class="features"> <span class="lemma">baEod</span> <span class="root">bEd</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3253</a>
# <div class="ar">إِيمَٰنِ</div>
# <div class="features"> <span class="lemma">&lt;iyma`n</span> <span class="root">Amn</span> <span class="pos">noun</span> <span class="formation">IV</span> <span class="tense">verbalNoun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3254</a>
# <div class="ar">كُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3255</a>
# <div class="ar">كُفَّارًا </div>
# <div class="features"> <span class="lemma">kaAfir</span> <span class="root">kfr</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3256</a>
# <div class="ar">حَسَدًا </div>
# <div class="features"> <span class="lemma">Hasad</span> <span class="root">Hsd</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3257</a>
# <div class="ar">مِّنْ </div>
# <div class="features"> <span class="lemma">min</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3258</a>
# <div class="ar">عِندِ </div>
# <div class="features"> <span class="lemma">Eind</span> <span class="root">End</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3259</a>
# <div class="ar">أَنفُسِ</div>
# <div class="features"> <span class="lemma">nafos</span> <span class="root">nfs</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3260</a>
# <div class="ar">هِم </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3261</a>
# <div class="ar">مِّنۢ </div>
# <div class="features"> <span class="lemma">min</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3262</a>
# <div class="ar">بَعْدِ </div>
# <div class="features"> <span class="lemma">baEod</span> <span class="root">bEd</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3263</a>
# <div class="ar">مَا </div>
# <div class="features"> <span class="lemma">maA</span> <span class="pos">pronoun</span> <span class="posx">relative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3264</a>
# <div class="ar">تَبَيَّنَ </div>
# <div class="features"> <span class="lemma">tabay~ana</span> <span class="root">byn</span> <span class="pos">verb</span> <span class="formation">V</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3265</a>
# <div class="ar">لَ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3266</a>
# <div class="ar">هُمُ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3267</a>
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3268</a>
# <div class="ar">حَقُّ </div>
# <div class="features"> <span class="lemma">Haq~</span> <span class="root">Hqq</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3269</a>
# <div class="ar">فَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3270</a>
# <div class="ar">ٱعْفُ</div>
# <div class="features"> <span class="lemma">EafaA</span> <span class="root">Efw</span> <span class="pos">verb</span> <span class="tense">imperative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3271</a>
# <div class="ar">وا۟ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3272</a>
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3273</a>
# <div class="ar">ٱصْفَحُ</div>
# <div class="features"> <span class="lemma">yaSofaHu</span> <span class="root">SfH</span> <span class="pos">verb</span> <span class="tense">imperative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3274</a>
# <div class="ar">وا۟ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3275</a>
# <div class="ar">حَتَّىٰ </div>
# <div class="features"> <span class="lemma">Hat~aY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <a href="#" class="nd">3276</a>
# <div class="ar">يَأْتِىَ </div>
# <div class="features"> <span class="lemma">>ataY</span> <span class="root">Aty</span> <span class="pos">verb</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <a href="#" class="nd">3277</a>
# <div class="ar">ٱللَّهُ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos"

# %% [markdown]
# We can also package the results tuples in other things than ayas, e.g. pages:

# %%
A.show(results, start=10, end=14, withNodes=True, condensed=True, condenseType='page')
# Out:
# **page** *10*
# <a href="http://tanzil.net/#2:142" title="show this passage on Tanzil" sec="2:142">2:142</a>
# <div class="None  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:142" title="2:142" sec="2:142"><span class="vn">page 22</span></a></div>
#         <a href="#" class="nd">217685</a>
#     </div>
#
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:142" title="show this passage on Tanzil" sec="2:142">2:142</a></div>
#         <a href="#" class="nd">205797</a>
#     </div>
#
# <div class="word  " >
# <a href="#" class="nd">4263</a>
# <div class="ar">سَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">future</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4264</a>
# <div class="ar">يَقُولُ </div>
# <div class="features"> <span class="lemma">qaAla</span> <span class="root">qwl</span> <span class="pos">verb</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4265</a>
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4266</a>
# <div class="ar">سُّفَهَآءُ </div>
# <div class="features"> <span class="lemma">safiyh</span> <span class="root">sfh</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4267</a>
# <div class="ar">مِنَ </div>
# <div class="features"> <span class="lemma">min</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4268</a>
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4269</a>
# <div class="ar">نَّاسِ </div>
# <div class="features"> <span class="lemma">n~aAs</span> <span class="root">nws</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4270</a>
# <div class="ar">مَا </div>
# <div class="features"> <span class="lemma">maA</span> <span class="pos">particle</span> <span class="posx">interrogative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4271</a>
# <div class="ar">وَلَّىٰ</div>
# <div class="features"> <span class="lemma">wal~aY`</span> <span class="root">wly</span> <span class="pos">verb</span> <span class="formation">II</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4272</a>
# <div class="ar">هُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4273</a>
# <div class="ar">عَن </div>
# <div class="features"> <span class="lemma">Ean</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4274</a>
# <div class="ar">قِبْلَتِ</div>
# <div class="features"> <span class="lemma">qibolap</span> <span class="root">qbl</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4275</a>
# <div class="ar">هِمُ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4276</a>
# <div class="ar">ٱلَّتِى </div>
# <div class="features"> <span class="lemma">{l~a*iY</span> <span class="pos">pronoun</span> <span class="posx">relative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4277</a>
# <div class="ar">كَانُ</div>
# <div class="features"> <span class="lemma">kaAna</span> <span class="root">kwn</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4278</a>
# <div class="ar">وا۟ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4279</a>
# <div class="ar">عَلَيْ</div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4280</a>
# <div class="ar">هَا </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4281</a>
# <div class="ar">قُل </div>
# <div class="features"> <span class="lemma">qaAla</span> <span class="root">qwl</span> <span class="pos">verb</span> <span class="tense">imperative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4282</a>
# <div class="ar">لِّ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4283</a>
# <div class="ar">لَّهِ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4284</a>
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4285</a>
# <div class="ar">مَشْرِقُ </div>
# <div class="features"> <span class="lemma">ma$oriq</span> <span class="root">$rq</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4286</a>
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4287</a>
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4288</a>
# <div class="ar">مَغْرِبُ </div>
# <div class="features"> <span class="lemma">magorib</span> <span class="root">grb</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4289</a>
# <div class="ar">يَهْدِى </div>
# <div class="features"> <span class="lemma">hadaY</span> <span class="root">hdy</span> <span class="pos">verb</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4290</a>
# <div class="ar">مَن </div>
# <div class="features"> <span class="lemma">man</span> <span class="pos">pronoun</span> <span class="posx">relative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4291</a>
# <div class="ar">يَشَآءُ </div>
# <div class="features"> <span class="lemma">$aA^'a</span> <span class="root">$yA</span> <span class="pos">verb</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4292</a>
# <div class="ar">إِلَىٰ </div>
# <div class="features"> <span class="lemma">&lt;ilaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4293</a>
# <div class="ar">صِرَٰطٍ </div>
# <div class="features"> <span class="lemma">Sira`T</span> <span class="root">SrT</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4294</a>
# <div class="ar">مُّسْتَقِيمٍ</div>
# <div class="features"> <span class="lemma">m~usotaqiym</span> <span class="root">qwm</span> <span class="pos">adjective</span> <span class="formation">X</span> <span class="tense">participle</span></div>
#
#
# </div>
#
#
# </div>
#
# <div class="aya  hl" >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:143" title="show this passage on Tanzil" sec="2:143">2:143</a></div>
#         <a href="#" class="nd">205798</a>
#     </div>
#
# <div class="word  " >
# <a href="#" class="nd">4295</a>
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4296</a>
# <div class="ar">كَ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4297</a>
# <div class="ar">ذَٰلِكَ </div>
# <div class="features"> <span class="le
# **page** *11*
# <a href="http://tanzil.net/#2:164" title="show this passage on Tanzil" sec="2:164">2:164</a>
# <div class="None  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:164" title="2:164" sec="2:164"><span class="vn">page 25</span></a></div>
#         <a href="#" class="nd">217688</a>
#     </div>
#
# <div class="aya  hl" >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:164" title="show this passage on Tanzil" sec="2:164">2:164</a></div>
#         <a href="#" class="nd">205819</a>
#     </div>
#
# <div class="word  " >
# <a href="#" class="nd">4931</a>
# <div class="ar">إِنَّ </div>
# <div class="features"> <span class="lemma">&lt;in~</span> <span class="pos">particle</span> <span class="posx">accusative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4932</a>
# <div class="ar">فِى </div>
# <div class="features"> <span class="lemma">fiY</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4933</a>
# <div class="ar">خَلْقِ </div>
# <div class="features"> <span class="lemma">xaloq</span> <span class="root">xlq</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4934</a>
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4935</a>
# <div class="ar">سَّمَٰوَٰتِ </div>
# <div class="features"> <span class="lemma">samaA^'</span> <span class="root">smw</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4936</a>
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4937</a>
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4938</a>
# <div class="ar">أَرْضِ </div>
# <div class="features"> <span class="lemma">>aroD</span> <span class="root">ArD</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4939</a>
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4940</a>
# <div class="ar">ٱخْتِلَٰفِ </div>
# <div class="features"> <span class="lemma">{xotila`f</span> <span class="root">xlf</span> <span class="pos">noun</span> <span class="formation">VIII</span> <span class="tense">verbalNoun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4941</a>
# <div class="ar">ٱلَّ</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4942</a>
# <div class="ar">يْلِ </div>
# <div class="features"> <span class="lemma">layol</span> <span class="root">lyl</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4943</a>
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4944</a>
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4945</a>
# <div class="ar">نَّهَارِ </div>
# <div class="features"> <span class="lemma">nahaAr</span> <span class="root">nhr</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4946</a>
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4947</a>
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4948</a>
# <div class="ar">فُلْكِ </div>
# <div class="features"> <span class="lemma">fulok</span> <span class="root">flk</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4949</a>
# <div class="ar">ٱلَّتِى </div>
# <div class="features"> <span class="lemma">{l~a*iY</span> <span class="pos">pronoun</span> <span class="posx">relative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4950</a>
# <div class="ar">تَجْرِى </div>
# <div class="features"> <span class="lemma">jarayo</span> <span class="root">jry</span> <span class="pos">verb</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4951</a>
# <div class="ar">فِى </div>
# <div class="features"> <span class="lemma">fiY</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4952</a>
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4953</a>
# <div class="ar">بَحْرِ </div>
# <div class="features"> <span class="lemma">baHor</span> <span class="root">bHr</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4954</a>
# <div class="ar">بِ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4955</a>
# <div class="ar">مَا </div>
# <div class="features"> <span class="lemma">maA</span> <span class="pos">pronoun</span> <span class="posx">relative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4956</a>
# <div class="ar">يَنفَعُ </div>
# <div class="features"> <span class="lemma">nafaEa</span> <span class="root">nfE</span> <span class="pos">verb</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4957</a>
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4958</a>
# <div class="ar">نَّاسَ </div>
# <div class="features"> <span class="lemma">n~aAs</span> <span class="root">nws</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4959</a>
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4960</a>
# <div class="ar">مَآ </div>
# <div class="features"> <span class="lemma">maA</span> <span class="pos">pronoun</span> <span class="posx">relative</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <a href="#" class="nd">4961</a>
# <div class="ar">أَنزَلَ </div>
# <div class="features"> <span class="lemma">>anzala</span> <span class="root">nzl</span> <span class="pos">verb</span> <span class="formation">IV</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <a href="#" class="nd">4962</a>
# <div class="ar">ٱللَّهُ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4963</a>
# <div class="ar">مِنَ </div>
# <div class="features"> <span class="lemma">min</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4964</a>
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4965</a>
# <div class="ar">سَّمَآءِ </div>
# <div class="features"> <span class="lemma">samaA^'</span> <span class="root">smw</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4966</a>
# <div class="ar">مِن </div>
# <div class="features"> <span class="lemma">min</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">4967</a>
# <div class="ar">مَّآءٍ </div>
# <div class="features"> <span class="lemma">maA^'</span> <sp
# **page** *12*
# <a href="http://tanzil.net/#2:170" title="show this passage on Tanzil" sec="2:170">2:170</a>
# <div class="None  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:170" title="2:170" sec="2:170"><span class="vn">page 26</span></a></div>
#         <a href="#" class="nd">217689</a>
#     </div>
#
# <div class="aya  hl" >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:170" title="show this passage on Tanzil" sec="2:170">2:170</a></div>
#         <a href="#" class="nd">205825</a>
#     </div>
#
# <div class="word  " >
# <a href="#" class="nd">5156</a>
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5157</a>
# <div class="ar">إِذَا </div>
# <div class="features"> <span class="lemma">&lt;i*aA</span> <span class="pos">adverb</span> <span class="posx">time</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5158</a>
# <div class="ar">قِيلَ </div>
# <div class="features"> <span class="lemma">qaAla</span> <span class="root">qwl</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5159</a>
# <div class="ar">لَ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5160</a>
# <div class="ar">هُمُ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5161</a>
# <div class="ar">ٱتَّبِعُ</div>
# <div class="features"> <span class="lemma">{t~abaEa</span> <span class="root">tbE</span> <span class="pos">verb</span> <span class="formation">VIII</span> <span class="tense">imperative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5162</a>
# <div class="ar">وا۟ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5163</a>
# <div class="ar">مَآ </div>
# <div class="features"> <span class="lemma">maA</span> <span class="pos">pronoun</span> <span class="posx">relative</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <a href="#" class="nd">5164</a>
# <div class="ar">أَنزَلَ </div>
# <div class="features"> <span class="lemma">>anzala</span> <span class="root">nzl</span> <span class="pos">verb</span> <span class="formation">IV</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <a href="#" class="nd">5165</a>
# <div class="ar">ٱللَّهُ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5166</a>
# <div class="ar">قَالُ</div>
# <div class="features"> <span class="lemma">qaAla</span> <span class="root">qwl</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5167</a>
# <div class="ar">وا۟ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5168</a>
# <div class="ar">بَلْ </div>
# <div class="features"> <span class="lemma">bal</span> <span class="pos">particle</span> <span class="posx">retraction</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5169</a>
# <div class="ar">نَتَّبِعُ </div>
# <div class="features"> <span class="lemma">{t~abaEa</span> <span class="root">tbE</span> <span class="pos">verb</span> <span class="formation">VIII</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5170</a>
# <div class="ar">مَآ </div>
# <div class="features"> <span class="lemma">maA</span> <span class="pos">pronoun</span> <span class="posx">relative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5171</a>
# <div class="ar">أَلْفَيْ</div>
# <div class="features"> <span class="lemma">>alofa</span> <span class="root">lfw</span> <span class="pos">verb</span> <span class="formation">IV</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5172</a>
# <div class="ar">نَا </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5173</a>
# <div class="ar">عَلَيْ</div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5174</a>
# <div class="ar">هِ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5175</a>
# <div class="ar">ءَابَآءَ</div>
# <div class="features"> <span class="lemma">A^baA'</span> <span class="root">Abw</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5176</a>
# <div class="ar">نَآ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5177</a>
# <div class="ar">أَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">interrogative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5178</a>
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">supplemental</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5179</a>
# <div class="ar">لَوْ </div>
# <div class="features"> <span class="lemma">law</span> <span class="pos">conjunction</span> <span class="posx">subordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5180</a>
# <div class="ar">كَانَ </div>
# <div class="features"> <span class="lemma">kaAna</span> <span class="root">kwn</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5181</a>
# <div class="ar">ءَابَآؤُ</div>
# <div class="features"> <span class="lemma">A^baA'</span> <span class="root">Abw</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5182</a>
# <div class="ar">هُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5183</a>
# <div class="ar">لَا </div>
# <div class="features"> <span class="lemma">laA</span> <span class="pos">particle</span> <span class="posx">negative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5184</a>
# <div class="ar">يَعْقِلُ</div>
# <div class="features"> <span class="lemma">Eaqalu</span> <span class="root">Eql</span> <span class="pos">verb</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5185</a>
# <div class="ar">ونَ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5186</a>
# <div class="ar">شَيْـًٔا </div>
# <div class="features"> <span class="lemma">$aYo'</span> <span class="root">$yA</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5187</a>
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5188</a>
# <div class="ar">لَا </div>
# <div class="features"> <span class="lemma">laA</span> <span class="pos">particle</span> <span class="posx">negative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5189</a>
# <div class="ar">يَهْتَدُ</div>
# <div class="features"> <span class="lemma">{hotadaY`</span> <span class="root">hdy</span> <span class="pos">verb</span> <span
# **page** *13*
# <a href="http://tanzil.net/#2:182" title="show this passage on Tanzil" sec="2:182">2:182</a>
# <div class="None  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:182" title="2:182" sec="2:182"><span class="vn">page 28</span></a></div>
#         <a href="#" class="nd">217691</a>
#     </div>
#
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:182" title="show this passage on Tanzil" sec="2:182">2:182</a></div>
#         <a href="#" class="nd">205837</a>
#     </div>
#
# <div class="word  " >
# <a href="#" class="nd">5600</a>
# <div class="ar">فَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5601</a>
# <div class="ar">مَنْ </div>
# <div class="features"> <span class="lemma">man</span> <span class="pos">particle</span> <span class="posx">conditional</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5602</a>
# <div class="ar">خَافَ </div>
# <div class="features"> <span class="lemma">xaAfa</span> <span class="root">xwf</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5603</a>
# <div class="ar">مِن </div>
# <div class="features"> <span class="lemma">min</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5604</a>
# <div class="ar">مُّوصٍ </div>
# <div class="features"> <span class="lemma">m~uwS</span> <span class="root">wSy</span> <span class="pos">noun</span> <span class="formation">IV</span> <span class="tense">participle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5605</a>
# <div class="ar">جَنَفًا </div>
# <div class="features"> <span class="lemma">janaf</span> <span class="root">jnf</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5606</a>
# <div class="ar">أَوْ </div>
# <div class="features"> <span class="lemma">>aw</span> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5607</a>
# <div class="ar">إِثْمًا </div>
# <div class="features"> <span class="lemma">&lt;ivom</span> <span class="root">Avm</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5608</a>
# <div class="ar">فَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5609</a>
# <div class="ar">أَصْلَحَ </div>
# <div class="features"> <span class="lemma">>aSolaHa</span> <span class="root">SlH</span> <span class="pos">verb</span> <span class="formation">IV</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5610</a>
# <div class="ar">بَيْنَ</div>
# <div class="features"> <span class="lemma">bayon</span> <span class="root">byn</span> <span class="pos">adverb</span> <span class="posx">location</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5611</a>
# <div class="ar">هُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5612</a>
# <div class="ar">فَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">result</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5613</a>
# <div class="ar">لَآ </div>
# <div class="features"> <span class="lemma">laA</span> <span class="pos">particle</span> <span class="posx">negative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5614</a>
# <div class="ar">إِثْمَ </div>
# <div class="features"> <span class="lemma">&lt;ivom</span> <span class="root">Avm</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5615</a>
# <div class="ar">عَلَيْ</div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5616</a>
# <div class="ar">هِ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5617</a>
# <div class="ar">إِنَّ </div>
# <div class="features"> <span class="lemma">&lt;in~</span> <span class="pos">particle</span> <span class="posx">accusative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5618</a>
# <div class="ar">ٱللَّهَ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5619</a>
# <div class="ar">غَفُورٌ </div>
# <div class="features"> <span class="lemma">gafuwr</span> <span class="root">gfr</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5620</a>
# <div class="ar">رَّحِيمٌ</div>
# <div class="features"> <span class="lemma">r~aHiym</span> <span class="root">rHm</span> <span class="pos">adjective</span></div>
#
#
# </div>
#
#
# </div>
#
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:183" title="show this passage on Tanzil" sec="2:183">2:183</a></div>
#         <a href="#" class="nd">205838</a>
#     </div>
#
# <div class="word  " >
# <a href="#" class="nd">5621</a>
# <div class="ar">يَٰٓ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">vocative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5622</a>
# <div class="ar">أَيُّهَا </div>
# <div class="features"> <span class="lemma">>ay~uhaA</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5623</a>
# <div class="ar">ٱلَّذِينَ </div>
# <div class="features"> <span class="lemma">{l~a*iY</span> <span class="pos">pronoun</span> <span class="posx">relative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5624</a>
# <div class="ar">ءَامَنُ</div>
# <div class="features"> <span class="lemma">'aAmana</span> <span class="root">Amn</span> <span class="pos">verb</span> <span class="formation">IV</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5625</a>
# <div class="ar">وا۟ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5626</a>
# <div class="ar">كُتِبَ </div>
# <div class="features"> <span class="lemma">kataba</span> <span class="root">ktb</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5627</a>
# <div class="ar">عَلَيْ</div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5628</a>
# <div class="ar">كُمُ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5629</a>
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5630</a>
# <div class="ar">صِّيَامُ </div>
# <div class="features"> <span class="lemma">SiyaAm</span> <span class="root">Swm</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5631</a>
# <div class="ar">كَ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5632</a>
# <div class="ar">مَا </div>
# <div class="features"> <span class="lemma">maA</span> <span class="pos">conjunction</span> <span class="posx">subordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5633</a>
# <div class="ar">كُتِبَ </div>
# <div class="featur
# **page** *14*
# <a href="http://tanzil.net/#2:187" title="show this passage on Tanzil" sec="2:187">2:187</a>
# <div class="None  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:187" title="2:187" sec="2:187"><span class="vn">page 29</span></a></div>
#         <a href="#" class="nd">217692</a>
#     </div>
#
# <div class="aya  hl" >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:187" title="show this passage on Tanzil" sec="2:187">2:187</a></div>
#         <a href="#" class="nd">205842</a>
#     </div>
#
# <div class="word  " >
# <a href="#" class="nd">5801</a>
# <div class="ar">أُحِلَّ </div>
# <div class="features"> <span class="lemma">>aHal~a</span> <span class="root">Hll</span> <span class="pos">verb</span> <span class="formation">IV</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5802</a>
# <div class="ar">لَ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5803</a>
# <div class="ar">كُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5804</a>
# <div class="ar">لَيْلَةَ </div>
# <div class="features"> <span class="lemma">layolap</span> <span class="root">lyl</span> <span class="pos">adverb</span> <span class="posx">time</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5805</a>
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5806</a>
# <div class="ar">صِّيَامِ </div>
# <div class="features"> <span class="lemma">SiyaAm</span> <span class="root">Swm</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5807</a>
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5808</a>
# <div class="ar">رَّفَثُ </div>
# <div class="features"> <span class="lemma">rafav</span> <span class="root">rfv</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5809</a>
# <div class="ar">إِلَىٰ </div>
# <div class="features"> <span class="lemma">&lt;ilaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5810</a>
# <div class="ar">نِسَآئِ</div>
# <div class="features"> <span class="lemma">nisaA^'</span> <span class="root">nsw</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5811</a>
# <div class="ar">كُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5812</a>
# <div class="ar">هُنَّ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5813</a>
# <div class="ar">لِبَاسٌ </div>
# <div class="features"> <span class="lemma">libaAs</span> <span class="root">lbs</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5814</a>
# <div class="ar">لَّ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5815</a>
# <div class="ar">كُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5816</a>
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5817</a>
# <div class="ar">أَنتُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5818</a>
# <div class="ar">لِبَاسٌ </div>
# <div class="features"> <span class="lemma">libaAs</span> <span class="root">lbs</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5819</a>
# <div class="ar">لَّ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5820</a>
# <div class="ar">هُنَّ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <a href="#" class="nd">5821</a>
# <div class="ar">عَلِمَ </div>
# <div class="features"> <span class="lemma">Ealima</span> <span class="root">Elm</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <a href="#" class="nd">5822</a>
# <div class="ar">ٱللَّهُ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5823</a>
# <div class="ar">أَنَّ</div>
# <div class="features"> <span class="lemma">>an~</span> <span class="pos">particle</span> <span class="posx">accusative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5824</a>
# <div class="ar">كُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5825</a>
# <div class="ar">كُن</div>
# <div class="features"> <span class="lemma">kaAna</span> <span class="root">kwn</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5826</a>
# <div class="ar">تُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5827</a>
# <div class="ar">تَخْتَانُ</div>
# <div class="features"> <span class="lemma">yaxotaAnu</span> <span class="root">xwn</span> <span class="pos">verb</span> <span class="formation">VIII</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5828</a>
# <div class="ar">ونَ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5829</a>
# <div class="ar">أَنفُسَ</div>
# <div class="features"> <span class="lemma">nafos</span> <span class="root">nfs</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5830</a>
# <div class="ar">كُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5831</a>
# <div class="ar">فَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5832</a>
# <div class="ar">تَابَ </div>
# <div class="features"> <span class="lemma">taAba</span> <span class="root">twb</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5833</a>
# <div class="ar">عَلَيْ</div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5834</a>
# <div class="ar">كُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5835</a>
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">5836</a>
# <div class="ar">عَفَا </div>
# <div class="features"> <span class="lemma">EafaA</span> <span class="root">Efw</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div cla

# %% [markdown]
# # Next steps
#
# * **[display](display.ipynb)** become an expert in creating pretty displays of your text structures
# * **[exportExcel](exportExcel.ipynb)** make tailor-made spreadsheets out of your results
# * (to come) **[share](share.ipynb)** draw in other people's data and let them use yours
#
# Back to [start](start.ipynb)
