# %% [markdown]
# <img align="right" src="images/tf.png" width="128"/>
# <img align="right" src="images/uu-small.png" width="128"/>
# <img align="right" src="images/dans.png" width="128"/>
#
# ---
#
# To get started: consult [start](start.ipynb)
#
# ---
#
# # Rich display
#
# The apps of Text-Fabric know more about a corpus than vanilla TF.
# That knowledge is used by the apps to define pretty and plain displays of textual objects.
#
# A **plain** display of an object is a simple reference to that object if it is big, or the text of that object if it is small.
#
# A **pretty** display of an object is a representation of the structure of that object. It contains text and features of sub objects.
# Provided the object is not too big.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use

# %%
A = use('quran', hoist=globals(), check=True)
# Out:
# 	downloading latest annotation/app-quran
# 	from https://api.github.com/repos/annotation/app-quran/zipball ...
# 	unzipping ...
# 	saving annotation/app-quran commit 7de4898c6776a20c8b6a19668ca33077d2a9cbb2
# 	saved annotation/app-quran commit 7de4898c6776a20c8b6a19668ca33077d2a9cbb2
# Using annotation/app-quran commit 7de4898c6776a20c8b6a19668ca33077d2a9cbb2 (=latest)
#   in /Users/dirk/text-fabric-data/__apps__/quran
# No new data release available online.
# Using q-ran/quran/tf - 0.2 rv0.3 (=latest) in /Users/dirk/text-fabric-data.
# **Documentation:** <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs" title="provenance of Quran">QURAN</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Writing/Arabic" title="('Arabic characters and transcriptions',)">Character table</a> <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#features.md" title="QURAN feature documentation">Feature docs</a> <a target="_blank" href="https://github.com/annotation/app-quran" title="quran API documentation">quran API</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/" title="text-fabric-api">Text-Fabric API 7.3.8</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Use/Search/" title="Search Templates Introduction and Reference">Search Reference</a>
# <details open><summary><b>Loaded features</b>:</summary>
# <p><b>Quran</b>: <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#a" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/a.tf">a</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#ascii" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/ascii.tf">ascii</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#ax" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/ax.tf">ax</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#case" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/case.tf">case</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#component" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/component.tf">component</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#definite" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/definite.tf">definite</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#f" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/f.tf">f</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#formation" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/formation.tf">formation</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#fx" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/fx.tf">fx</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#gn" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/gn.tf">gn</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#interjection" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/interjection.tf">interjection</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#l" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/l.tf">l</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#lemma" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/lemma.tf">lemma</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#lx" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/lx.tf">lx</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#mood" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/mood.tf">mood</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#n" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/n.tf">n</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#name" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/name.tf">name</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#name@ll" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/name@en.tf">name@ll</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#nameAscii" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/nameAscii.tf">nameAscii</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#nameTrans" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/nameTrans.tf">nameTrans</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#nu" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/nu.tf">nu</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#number" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/number.tf">number</a>  <a target="_blank" href="https://github.com/q-ran/quran/blob/master/docs/features-0.2.md#order" title="/Users/dirk/text-fabric-data/q-ran/quran/tf/0.2/order.tf">order</a>  <a target="_blank" href="https://github.co ...
# <style>
# @font-face {
#   font-family: "AmiriQuran";
#   src: url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.ttf?raw=true');
#   src: url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff2?raw=true') format('woff');
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .aya {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-end;
#     align-items: flex-end;
#     direction: ltr;
#     width: 100%;
# }
# .outeritem {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .word {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 1px solid #cccccc;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .lextp {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 2px solid #888888;
#     width: fit-content;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .occs {
#     font-size: x-small;
# }
# .tr,.tr a:visited,.tr a:link {
#     font-family: sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: ltr;
#     text-decoration: none;
# }
# .trb,.trb a:visited,.trb a:link {
#     font-family: sans-serif;
#     font-size: normal;
#     direction: ltr;
#     text-decoration: none;
# }
# .ar,.ar a:visited,.ar a:link {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: rtl;
#     text-decoration: none;
# }
# .arb,.arb a:visited,.arb a:link {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     line-height: 3;
#     direction: rtl;
#     text-decoration: none;
# }
# .vn {
#   font-size: small !important;
#   padding-right: 1em;
# }
# .sp,.sp a:visited,.sp a:link {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
#     text-decoration: none;
# }
# .lexeme {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .vs {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .vt {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .hl {
#     background-color: #ffee66;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlup {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>
# <details open><summary><b>API members</b>:</summary>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">C Computed</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Call AllComputeds</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Cs ComputedString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">E Edge</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Eall AllEdges</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Es EdgeString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ensureLoaded</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">TF</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ignored</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">loadLog</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Locality/#locality" title="doc">L Locality</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">cache</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">error</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">indent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">info</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">reset</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">N Nodes</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKey</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKeyTuple</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">otypeRank</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortNodes</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">F Feature</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fall AllFeatures</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fs FeatureString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Search/#search" title="doc">S Search</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Text/#text" title="doc">T Text</a></details>

# %% [markdown]
# # Arbitrary nodes
# We pretty-print an arbitrary node.

# %%
aya = F.otype.s('aya')[1000]
A.pretty(aya)
# Out:
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#7:47" title="show this passage on Tanzil" sec="7:47">7:47</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">إِذَا </div>
# <div class="features"> <span class="lemma">&lt;i*aA</span> <span class="pos">adverb</span> <span class="posx">time</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">صُرِفَتْ </div>
# <div class="features"> <span class="lemma">Sarafa</span> <span class="root">Srf</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">أَبْصَٰرُ</div>
# <div class="features"> <span class="lemma">baSar</span> <span class="root">bSr</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">هُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">تِلْقَآءَ </div>
# <div class="features"> <span class="lemma">tiloqaA^'</span> <span class="root">lqy</span> <span class="pos">adverb</span> <span class="posx">location</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">أَصْحَٰبِ </div>
# <div class="features"> <span class="lemma">>aSoHa`b</span> <span class="root">SHb</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">نَّارِ </div>
# <div class="features"> <span class="lemma">naAr</span> <span class="root">nwr</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">قَالُ</div>
# <div class="features"> <span class="lemma">qaAla</span> <span class="root">qwl</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">وا۟ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">رَبَّ</div>
# <div class="features"> <span class="lemma">rab~</span> <span class="root">rbb</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">نَا </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">لَا </div>
# <div class="features"> <span class="lemma">laA</span> <span class="pos">particle</span> <span class="posx">prohibition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">تَجْعَلْ</div>
# <div class="features"> <span class="lemma">jaEala</span> <span class="root">jEl</span> <span class="pos">verb</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">نَا </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">مَعَ </div>
# <div class="features"> <span class="lemma">maE</span> <span class="pos">adverb</span> <span class="posx">location</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">قَوْمِ </div>
# <div class="features"> <span class="lemma">qawom</span> <span class="root">qwm</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ظَّٰلِمِينَ</div>
# <div class="features"> <span class="lemma">ZaAlim</span> <span class="root">Zlm</span> <span class="pos">adjective</span> <span class="tense">participle</span></div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# Where is this phrase on Tanzil?
# You can click on the passage reference.
#
# You can generate this link as follows:

# %%
A.webLink(aya)
# Out:
# <a href="http://tanzil.net/#7:47" title="show this passage on Tanzil" sec="7:47">7:47</a>

# %% [markdown]
# A link to another passage:

# %%
z = A.nodeFromSectionStr('3:4')

# %%
A.webLink(z)
# Out:
# <a href="http://tanzil.net/#3:4" title="show this passage on Tanzil" sec="3:4">3:4</a>

# %% [markdown]
# # Plain
#
# We can represent a node in plain representation and highlight specific portions.

# %%
aya = F.otype.s('aya')[1000]
groups = L.d(aya, otype='group')
words = L.d(aya, otype='word')

# %% [markdown]
# First we highlight some words:

# %%
wordHighlights = set(words[i] for i in {1, 3, 5, 7, 9})
A.plain(aya, highlights=wordHighlights)
# Out:
# <span class="arb"><a class="vn" href="http://tanzil.net/#7:47" title="7:47" sec="7:47">7:47</a>وَ<span  class="hl" >إِذَا </span>صُرِفَتْ <span  class="hl" >أَبْصَٰرُ</span>هُمْ <span  class="hl" >تِلْقَآءَ </span>أَصْحَٰبِ <span  class="hl" >ٱل</span>نَّارِ <span  class="hl" >قَالُ</span>وا۟ رَبَّنَا لَا تَجْعَلْنَا مَعَ ٱلْقَوْمِ ٱلظَّٰلِمِينَ</span>

# %% [markdown]
# Now some wordgroups:

# %%
groupHighlights = set(groups[i] for i in {7, 12})
A.plain(aya, highlights=groupHighlights)
# Out:
# <span class="arb"><a class="vn" href="http://tanzil.net/#7:47" title="7:47" sec="7:47">7:47</a>وَإِذَا صُرِفَتْ أَبْصَٰرُهُمْ تِلْقَآءَ أَصْحَٰبِ ٱلنَّارِ قَالُوا۟ <span  class="hlup" >رَبَّ</span><span  class="hlup" >نَا </span>لَا تَجْعَلْنَا مَعَ ٱلْقَوْمِ <span  class="hlup" >ٱل</span><span  class="hlup" >ظَّٰلِمِينَ</span></span>

# %% [markdown]
# As you see, when we highlight bigger things than words, we put a
# highlighted border around the words in those things.

# %% [markdown]
# We can do both:

# %%
highlights = set(wordHighlights) | set(groupHighlights)
A.plain(aya, highlights=highlights)
# Out:
# <span class="arb"><a class="vn" href="http://tanzil.net/#7:47" title="7:47" sec="7:47">7:47</a>وَ<span  class="hl" >إِذَا </span>صُرِفَتْ <span  class="hl" >أَبْصَٰرُ</span>هُمْ <span  class="hl" >تِلْقَآءَ </span>أَصْحَٰبِ <span  class="hl" >ٱل</span>نَّارِ <span  class="hl" >قَالُ</span>وا۟ <span  class="hlup" >رَبَّ</span><span  class="hlup" >نَا </span>لَا تَجْعَلْنَا مَعَ ٱلْقَوْمِ <span  class="hlup" >ٱل</span><span  class="hlup" >ظَّٰلِمِينَ</span></span>

# %% [markdown]
# We can also highlight the aya itself.

# %%
highlights = {aya}
A.plain(aya, highlights=highlights)
# Out:
# <span class="arb"><a class="vn" href="http://tanzil.net/#7:47" title="7:47" sec="7:47"><span  class="hldot" >7:47</span></a>وَإِذَا صُرِفَتْ أَبْصَٰرُهُمْ تِلْقَآءَ أَصْحَٰبِ ٱلنَّارِ قَالُوا۟ رَبَّنَا لَا تَجْعَلْنَا مَعَ ٱلْقَوْمِ ٱلظَّٰلِمِينَ</span>

# %% [markdown]
# As you see, only the aya label is highlighted, not the contents.
# The same policy is followed for suras and other sectional units.

# %%
juz = F.otype.s('juz')[20]
A.plain(juz, highlights={juz})
# Out:
# <a href="http://tanzil.net/#29:46" title="show this passage on Tanzil" sec="29:46">29:46</a>&nbsp;<span class="arb"><a href="http://tanzil.net/#29:46" title="29:46" sec="29:46"><span  class="hl" ><span class="vn">juz 21</span></span><br/></a></span>

# %%
ruku = F.otype.s('ruku')[20]
A.plain(ruku, highlights={ruku})
# Out:
# <a href="http://tanzil.net/#2:164" title="show this passage on Tanzil" sec="2:164">2:164</a>&nbsp;<span class="arb"><a href="http://tanzil.net/#2:164" title="2:164" sec="2:164"><span  class="hl" ><span class="vn">ruku 21</span></span><br/></a></span>

# %% [markdown]
# But if we pass a condense type that is bigger than the section type, we get the material of the section.
#
# Remember that we can see the types and their bigness as follows:

# %%
C.levels.data
# Out:
# (('manzil', 18317.0, 217101, 217107),
#  ('sajda', 6043.066666666667, 218268, 218282),
#  ('juz', 4273.966666666666, 216831, 216860),
#  ('sura', 1124.7280701754387, 211885, 211998),
#  ('hizb', 534.2458333333333, 216861, 217100),
#  ('ruku', 230.60971223021582, 217108, 217663),
#  ('page', 212.28311258278146, 217664, 218267),
#  ('aya', 20.56109685695959, 205649, 211884),
#  ('lex', 15.440397350993377, 211999, 216830),
#  ('group', 1.6559557788425525, 128220, 205648),
#  ('word', 1, 1, 128219))

# %% [markdown]
# So the *hizb* is bigger than the *page*.
#
# Let's print a plain *page* with condense type *hizb*:

# %%
page = F.otype.s('page')[20]
A.plain(page, condenseType='hizb')
# Out:
# <a href="http://tanzil.net/#2:135" title="show this passage on Tanzil" sec="2:135">2:135</a>&nbsp;<span class="arb"><a href="http://tanzil.net/#2:135" title="2:135" sec="2:135"><span class="vn">page 21</span><br/><span class="arb"><span class="arb"><a class="vn" href="http://tanzil.net/#2:135" title="2:135" sec="2:135">2:135</a>وَقَالُوا۟ كُونُوا۟ هُودًا أَوْ نَصَٰرَىٰ تَهْتَدُوا۟ قُلْ بَلْ مِلَّةَ إِبْرَٰهِۦمَ حَنِيفًا وَمَا كَانَ مِنَ ٱلْمُشْرِكِينَ</span></span><br/><span class="arb"><span class="arb"><a class="vn" href="http://tanzil.net/#2:136" title="2:136" sec="2:136">2:136</a>قُولُوٓا۟ ءَامَنَّا بِٱللَّهِ وَمَآ أُنزِلَ إِلَيْنَا وَمَآ أُنزِلَ إِلَىٰٓ إِبْرَٰهِۦمَ وَإِسْمَٰعِيلَ وَإِسْحَٰقَ وَيَعْقُوبَ وَٱلْأَسْبَاطِ وَمَآ أُوتِىَ مُوسَىٰ وَعِيسَىٰ وَمَآ أُوتِىَ ٱلنَّبِيُّونَ مِن رَّبِّهِمْ لَا نُفَرِّقُ بَيْنَ أَحَدٍ مِّنْهُمْ وَنَحْنُ لَهُۥ مُسْلِمُونَ</span></span><br/><span class="arb"><span class="arb"><a class="vn" href="http://tanzil.net/#2:137" title="2:137" sec="2:137">2:137</a>فَإِنْ ءَامَنُوا۟ بِمِثْلِ مَآ ءَامَنتُم بِهِۦ فَقَدِ ٱهْتَدَوا۟ وَّإِن تَوَلَّوْا۟ فَإِنَّمَا هُمْ فِى شِقَاقٍ فَسَيَكْفِيكَهُمُ ٱللَّهُ وَهُوَ ٱلسَّمِيعُ ٱلْعَلِيمُ</span></span><br/><span class="arb"><span class="arb"><a class="vn" href="http://tanzil.net/#2:138" title="2:138" sec="2:138">2:138</a>صِبْغَةَ ٱللَّهِ وَمَنْ أَحْسَنُ مِنَ ٱللَّهِ صِبْغَةً وَنَحْنُ لَهُۥ عَٰبِدُونَ</span></span><br/><span class="arb"><span class="arb"><a class="vn" href="http://tanzil.net/#2:139" title="2:139" sec="2:139">2:139</a>قُلْ أَتُحَآجُّونَنَا فِى ٱللَّهِ وَهُوَ رَبُّنَا وَرَبُّكُمْ وَلَنَآ أَعْمَٰلُنَا وَلَكُمْ أَعْمَٰلُكُمْ وَنَحْنُ لَهُۥ مُخْلِصُونَ</span></span><br/><span class="arb"><span class="arb"><a class="vn" href="http://tanzil.net/#2:140" title="2:140" sec="2:140">2:140</a>أَمْ تَقُولُونَ إِنَّ إِبْرَٰهِۦمَ وَإِسْمَٰعِيلَ وَإِسْحَٰقَ وَيَعْقُوبَ وَٱلْأَسْبَاطَ كَانُوا۟ هُودًا أَوْ نَصَٰرَىٰ قُلْ ءَأَنتُمْ أَعْلَمُ أَمِ ٱللَّهُ وَمَنْ أَظْلَمُ مِمَّن كَتَمَ شَهَٰدَةً عِندَهُۥ مِنَ ٱللَّهِ وَمَا ٱللَّهُ بِغَٰفِلٍ عَمَّا تَعْمَلُونَ</span></span><br/><span class="arb"><span class="arb"><a class="vn" href="http://tanzil.net/#2:141" title="2:141" sec="2:141">2:141</a>تِلْكَ أُمَّةٌ قَدْ خَلَتْ لَهَا مَا كَسَبَتْ وَلَكُم مَّا كَسَبْتُمْ وَلَا تُسْـَٔلُونَ عَمَّا كَانُوا۟ يَعْمَلُونَ</span></span><br/></a></span>

# %% [markdown]
# We can use different colors for highlighting.
# Lets color even words differently from uneven words, and ayas in yet another color.

# %%
highlights = {i: 'lightsalmon' for i in words if i % 2 == 0}
highlights.update({i: 'mediumaquamarine' for i in words if i % 2 == 1})
highlights.update({i: 'blue' for i in groups if i % 5 == 1})
highlights[aya] = '#eeeeff'
A.plain(aya, highlights=highlights)
# Out:
# <span class="arb"><a class="vn" href="http://tanzil.net/#7:47" title="7:47" sec="7:47"><span  class="hldot"  style="background-color: #eeeeff;border-color: #eeeeff;" >7:47</span></a><span  class="hl"  style="background-color: mediumaquamarine;" >وَ</span><span  class="hl"  style="background-color: lightsalmon;" >إِذَا </span><span  class="hl"  style="background-color: mediumaquamarine;" >صُرِفَتْ </span><span  class="hl"  style="background-color: lightsalmon;" >أَبْصَٰرُ</span><span  class="hl"  style="background-color: mediumaquamarine;" >هُمْ </span><span  class="hl hlup"  style="background-color: lightsalmon;border-color: blue;" >تِلْقَآءَ </span><span  class="hl"  style="background-color: mediumaquamarine;" >أَصْحَٰبِ </span><span  class="hl"  style="background-color: lightsalmon;" >ٱل</span><span  class="hl"  style="background-color: mediumaquamarine;" >نَّارِ </span><span  class="hl"  style="background-color: lightsalmon;" >قَالُ</span><span  class="hl"  style="background-color: mediumaquamarine;" >وا۟ </span><span  class="hl"  style="background-color: lightsalmon;" >رَبَّ</span><span  class="hl"  style="background-color: mediumaquamarine;" >نَا </span><span  class="hl hlup"  style="background-color: lightsalmon;border-color: blue;" >لَا </span><span  class="hl"  style="background-color: mediumaquamarine;" >تَجْعَلْ</span><span  class="hl"  style="background-color: lightsalmon;" >نَا </span><span  class="hl"  style="background-color: mediumaquamarine;" >مَعَ </span><span  class="hl"  style="background-color: lightsalmon;" >ٱلْ</span><span  class="hl"  style="background-color: mediumaquamarine;" >قَوْمِ </span><span  class="hl"  style="background-color: lightsalmon;" >ٱل</span><span  class="hl"  style="background-color: mediumaquamarine;" >ظَّٰلِمِينَ</span></span>

# %% [markdown]
# # Ayas
#
# Now a couple of ayas:

# %%
aya1 = A.nodeFromSectionStr('2:7')
aya2 = A.nodeFromSectionStr('3:17')

# %%
A.pretty(aya2)
# Out:
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#3:17" title="show this passage on Tanzil" sec="3:17">3:17</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">صَّٰبِرِينَ </div>
# <div class="features"> <span class="lemma">SaAbir</span> <span class="root">Sbr</span> <span class="pos">noun</span> <span class="tense">participle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">صَّٰدِقِينَ </div>
# <div class="features"> <span class="lemma">SaAdiq</span> <span class="root">Sdq</span> <span class="pos">noun</span> <span class="tense">participle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">قَٰنِتِينَ </div>
# <div class="features"> <span class="lemma">qaAnit</span> <span class="root">qnt</span> <span class="pos">noun</span> <span class="tense">participle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">مُنفِقِينَ </div>
# <div class="features"> <span class="lemma">munfiqiyn</span> <span class="root">nfq</span> <span class="pos">noun</span> <span class="formation">IV</span> <span class="tense">participle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">مُسْتَغْفِرِينَ </div>
# <div class="features"> <span class="lemma">musotagofiriyn</span> <span class="root">gfr</span> <span class="pos">noun</span> <span class="formation">X</span> <span class="tense">participle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">بِ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">أَسْحَارِ</div>
# <div class="features"> <span class="lemma">saHar</span> <span class="root">sHr</span> <span class="pos">noun</span></div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# The other aya with node numbers.

# %%
A.pretty(aya1, withNodes=True)
# Out:
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:7" title="show this passage on Tanzil" sec="2:7">2:7</a></div>
#         <a href="#" class="nd">205662</a>
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <a href="#" class="nd">131</a>
# <div class="ar">خَتَمَ </div>
# <div class="features"> <span class="lemma">xatama</span> <span class="root">xtm</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">132</a>
# <div class="ar">ٱللَّهُ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">133</a>
# <div class="ar">عَلَىٰ </div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">134</a>
# <div class="ar">قُلُوبِ</div>
# <div class="features"> <span class="lemma">qalob</span> <span class="root">qlb</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">135</a>
# <div class="ar">هِمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">136</a>
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">137</a>
# <div class="ar">عَلَىٰ </div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">138</a>
# <div class="ar">سَمْعِ</div>
# <div class="features"> <span class="lemma">samoE</span> <span class="root">smE</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">139</a>
# <div class="ar">هِمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">140</a>
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">141</a>
# <div class="ar">عَلَىٰٓ </div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">142</a>
# <div class="ar">أَبْصَٰرِ</div>
# <div class="features"> <span class="lemma">baSar</span> <span class="root">bSr</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">143</a>
# <div class="ar">هِمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">144</a>
# <div class="ar">غِشَٰوَةٌ </div>
# <div class="features"> <span class="lemma">gi$a`wap</span> <span class="root">g$w</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">145</a>
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">146</a>
# <div class="ar">لَ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">147</a>
# <div class="ar">هُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">148</a>
# <div class="ar">عَذَابٌ </div>
# <div class="features"> <span class="lemma">Ea*aAb</span> <span class="root">E*b</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">149</a>
# <div class="ar">عَظِيمٌ</div>
# <div class="features"> <span class="lemma">EaZiym</span> <span class="root">EZm</span> <span class="pos">adjective</span></div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# Now we selectively remove a few features from the display:

# %%
A.pretty(aya1, suppress={'posx', 'tense'})
# Out:
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:7" title="show this passage on Tanzil" sec="2:7">2:7</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="ar">خَتَمَ </div>
# <div class="features"> <span class="lemma">xatama</span> <span class="root">xtm</span> <span class="pos">verb</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱللَّهُ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">عَلَىٰ </div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">قُلُوبِ</div>
# <div class="features"> <span class="lemma">qalob</span> <span class="root">qlb</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">هِمْ </div>
# <div class="features"> <span class="pos">pronoun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">عَلَىٰ </div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">سَمْعِ</div>
# <div class="features"> <span class="lemma">samoE</span> <span class="root">smE</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">هِمْ </div>
# <div class="features"> <span class="pos">pronoun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">عَلَىٰٓ </div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">أَبْصَٰرِ</div>
# <div class="features"> <span class="lemma">baSar</span> <span class="root">bSr</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">هِمْ </div>
# <div class="features"> <span class="pos">pronoun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">غِشَٰوَةٌ </div>
# <div class="features"> <span class="lemma">gi$a`wap</span> <span class="root">g$w</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">لَ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">هُمْ </div>
# <div class="features"> <span class="pos">pronoun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">عَذَابٌ </div>
# <div class="features"> <span class="lemma">Ea*aAb</span> <span class="root">E*b</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">عَظِيمٌ</div>
# <div class="features"> <span class="lemma">EaZiym</span> <span class="root">EZm</span> <span class="pos">adjective</span></div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# Now we add features to the display:

# %%
A.displaySetup(extraFeatures=['ps', 'nu', 'gn'])

# %%
A.pretty(aya1)
# Out:
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:7" title="show this passage on Tanzil" sec="2:7">2:7</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="ar">خَتَمَ </div>
# <div class="features"> <span class="lemma">xatama</span> <span class="root">xtm</span> <span class="pos">verb</span> <span class="tense">perfect</span> <span class="gn xft"><span class="f">gn=</span>m</span> <span class="nu xft"><span class="f">nu=</span>s</span> <span class="ps xft"><span class="f">ps=</span>3</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱللَّهُ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">عَلَىٰ </div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">قُلُوبِ</div>
# <div class="features"> <span class="lemma">qalob</span> <span class="root">qlb</span> <span class="pos">noun</span> <span class="gn xft"><span class="f">gn=</span>f</span> <span class="nu xft"><span class="f">nu=</span>p</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">هِمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span> <span class="gn xft"><span class="f">gn=</span>m</span> <span class="nu xft"><span class="f">nu=</span>p</span> <span class="ps xft"><span class="f">ps=</span>3</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">عَلَىٰ </div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">سَمْعِ</div>
# <div class="features"> <span class="lemma">samoE</span> <span class="root">smE</span> <span class="pos">noun</span> <span class="gn xft"><span class="f">gn=</span>m</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">هِمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span> <span class="gn xft"><span class="f">gn=</span>m</span> <span class="nu xft"><span class="f">nu=</span>p</span> <span class="ps xft"><span class="f">ps=</span>3</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">عَلَىٰٓ </div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">أَبْصَٰرِ</div>
# <div class="features"> <span class="lemma">baSar</span> <span class="root">bSr</span> <span class="pos">noun</span> <span class="gn xft"><span class="f">gn=</span>m</span> <span class="nu xft"><span class="f">nu=</span>p</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">هِمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span> <span class="gn xft"><span class="f">gn=</span>m</span> <span class="nu xft"><span class="f">nu=</span>p</span> <span class="ps xft"><span class="f">ps=</span>3</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">غِشَٰوَةٌ </div>
# <div class="features"> <span class="lemma">gi$a`wap</span> <span class="root">g$w</span> <span class="pos">noun</span> <span class="gn xft"><span class="f">gn=</span>f</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">لَ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">هُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span> <span class="gn xft"><span class="f">gn=</span>m</span> <span class="nu xft"><span class="f">nu=</span>p</span> <span class="ps xft"><span class="f">ps=</span>3</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">عَذَابٌ </div>
# <div class="features"> <span class="lemma">Ea*aAb</span> <span class="root">E*b</span> <span class="pos">noun</span> <span class="gn xft"><span class="f">gn=</span>m</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">عَظِيمٌ</div>
# <div class="features"> <span class="lemma">EaZiym</span> <span class="root">EZm</span> <span class="pos">adjective</span> <span class="gn xft"><span class="f">gn=</span>m</span> <span class="nu xft"><span class="f">nu=</span>s</span></div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# and we reset the pretty features to the default values:

# %%
A.displayReset('extraFeatures')

# %%
A.pretty(aya1)
# Out:
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:7" title="show this passage on Tanzil" sec="2:7">2:7</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="ar">خَتَمَ </div>
# <div class="features"> <span class="lemma">xatama</span> <span class="root">xtm</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱللَّهُ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">عَلَىٰ </div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">قُلُوبِ</div>
# <div class="features"> <span class="lemma">qalob</span> <span class="root">qlb</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">هِمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">عَلَىٰ </div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">سَمْعِ</div>
# <div class="features"> <span class="lemma">samoE</span> <span class="root">smE</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">هِمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">عَلَىٰٓ </div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">أَبْصَٰرِ</div>
# <div class="features"> <span class="lemma">baSar</span> <span class="root">bSr</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">هِمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">غِشَٰوَةٌ </div>
# <div class="features"> <span class="lemma">gi$a`wap</span> <span class="root">g$w</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">لَ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">هُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">عَذَابٌ </div>
# <div class="features"> <span class="lemma">Ea*aAb</span> <span class="root">E*b</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">عَظِيمٌ</div>
# <div class="features"> <span class="lemma">EaZiym</span> <span class="root">EZm</span> <span class="pos">adjective</span></div>
#
#
# </div>
#
#
# </div>

# %%
A.displaySetup(extraFeatures=['translation@en', 'translation@nl'])

# %%
A.pretty(aya1)
# Out:
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#2:7" title="show this passage on Tanzil" sec="2:7">2:7</a></div>
#
#         <div class="features"> <span class="translation@en xft"><span class="f">translation@en=</span>God has set a seal on their hearts and on their hearing, and on their eyes is a covering, and there awaits them a mighty chastisement.</span> <span class="translation@nl xft"><span class="f">translation@nl=</span>God heeft hun harten en hun gehoor verzegeld en over hun ogen is een sluier; voor hen is er een geweldige bestraffing.</span></div>
#     </div>
#
# <div class="word  " >
# <div class="ar">خَتَمَ </div>
# <div class="features"> <span class="lemma">xatama</span> <span class="root">xtm</span> <span class="pos">verb</span> <span class="tense">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱللَّهُ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">عَلَىٰ </div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">قُلُوبِ</div>
# <div class="features"> <span class="lemma">qalob</span> <span class="root">qlb</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">هِمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">عَلَىٰ </div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">سَمْعِ</div>
# <div class="features"> <span class="lemma">samoE</span> <span class="root">smE</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">هِمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">عَلَىٰٓ </div>
# <div class="features"> <span class="lemma">EalaY`</span> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">أَبْصَٰرِ</div>
# <div class="features"> <span class="lemma">baSar</span> <span class="root">bSr</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">هِمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">غِشَٰوَةٌ </div>
# <div class="features"> <span class="lemma">gi$a`wap</span> <span class="root">g$w</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">particle</span> <span class="posx">resumption</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">لَ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">هُمْ </div>
# <div class="features"> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">عَذَابٌ </div>
# <div class="features"> <span class="lemma">Ea*aAb</span> <span class="root">E*b</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">عَظِيمٌ</div>
# <div class="features"> <span class="lemma">EaZiym</span> <span class="root">EZm</span> <span class="pos">adjective</span></div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# # Translations in pretty display
#
# We can add the translation features `translation@ll` for `ll = en` or `nl` to the extra features for pretty display.
# Let's pretty display the first sura with both translations.

# %%
sura1 = F.otype.s('sura')[0]

# %%
A.pretty(sura1)
# Out:
# <div class="None  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:1" title="show this passage on Tanzil" sec="1">1</a></div>
#
#         <div class="features"></div>
#     </div>
#
#
# </div>

# %% [markdown]
# That is a bit meager. The reason is that the *sura* is a **big** type, i.e. bigger than the default *condenseType*, which is the *aya*.
#
# If we want a complete display of a sura, we have to pass a big enough `condenseType` to `pretty()`:

# %%
A.pretty(sura1, condenseType='sura')
# Out:
# <div class="None  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:1" title="show this passage on Tanzil" sec="1">1</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:1" title="show this passage on Tanzil" sec="1:1">1:1</a></div>
#
#         <div class="features"> <span class="translation@en xft"><span class="f">translation@en=</span>In the Name of God, the Merciful, the Compassionate</span> <span class="translation@nl xft"><span class="f">translation@nl=</span>In de naam van God, de erbarmer, de barmhartige.</span></div>
#     </div>
#
# <div class="word  " >
# <div class="ar">بِ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">سْمِ </div>
# <div class="features"> <span class="lemma">{som</span> <span class="root">smw</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱللَّهِ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">رَّحْمَٰنِ </div>
# <div class="features"> <span class="lemma">r~aHoma`n</span> <span class="root">rHm</span> <span class="pos">adjective</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">رَّحِيمِ</div>
# <div class="features"> <span class="lemma">r~aHiym</span> <span class="root">rHm</span> <span class="pos">adjective</span></div>
#
#
# </div>
#
#
# </div>
#
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:2" title="show this passage on Tanzil" sec="1:2">1:2</a></div>
#
#         <div class="features"> <span class="translation@en xft"><span class="f">translation@en=</span>Praise belongs to God, the Lord of all Being,</span> <span class="translation@nl xft"><span class="f">translation@nl=</span>Lof zij God, de Heer van de wereldbewoners,</span></div>
#     </div>
#
# <div class="word  " >
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">حَمْدُ </div>
# <div class="features"> <span class="lemma">Hamod</span> <span class="root">Hmd</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">لِ</div>
# <div class="features"> <span class="pos">preposition</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">لَّهِ </div>
# <div class="features"> <span class="lemma">{ll~ah</span> <span class="root">Alh</span> <span class="pos">noun</span> <span class="posx">proper</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">رَبِّ </div>
# <div class="features"> <span class="lemma">rab~</span> <span class="root">rbb</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱلْ</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">عَٰلَمِينَ</div>
# <div class="features"> <span class="lemma">Ea`lamiyn</span> <span class="root">Elm</span> <span class="pos">noun</span></div>
#
#
# </div>
#
#
# </div>
#
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:3" title="show this passage on Tanzil" sec="1:3">1:3</a></div>
#
#         <div class="features"> <span class="translation@en xft"><span class="f">translation@en=</span>the All-merciful, the All-compassionate,</span> <span class="translation@nl xft"><span class="f">translation@nl=</span>de erbarmer, de barmhartige,</span></div>
#     </div>
#
# <div class="word  " >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">رَّحْمَٰنِ </div>
# <div class="features"> <span class="lemma">r~aHoma`n</span> <span class="root">rHm</span> <span class="pos">adjective</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">رَّحِيمِ</div>
# <div class="features"> <span class="lemma">r~aHiym</span> <span class="root">rHm</span> <span class="pos">adjective</span></div>
#
#
# </div>
#
#
# </div>
#
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:4" title="show this passage on Tanzil" sec="1:4">1:4</a></div>
#
#         <div class="features"> <span class="translation@en xft"><span class="f">translation@en=</span>the Master of the Day of Doom.</span> <span class="translation@nl xft"><span class="f">translation@nl=</span>de heerser op de oordeelsdag.</span></div>
#     </div>
#
# <div class="word  " >
# <div class="ar">مَٰلِكِ </div>
# <div class="features"> <span class="lemma">ma`lik</span> <span class="root">mlk</span> <span class="pos">noun</span> <span class="tense">participle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">يَوْمِ </div>
# <div class="features"> <span class="lemma">yawom</span> <span class="root">ywm</span> <span class="pos">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">ٱل</div>
# <div class="features"> <span class="pos">determiner</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">دِّينِ</div>
# <div class="features"> <span class="lemma">diyn</span> <span class="root">dyn</span> <span class="pos">noun</span></div>
#
#
# </div>
#
#
# </div>
#
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:5" title="show this passage on Tanzil" sec="1:5">1:5</a></div>
#
#         <div class="features"> <span class="translation@en xft"><span class="f">translation@en=</span>Thee only we serve; to Thee alone we pray for succour.</span> <span class="translation@nl xft"><span class="f">translation@nl=</span>U dienen wij en U vragen wij om hulp.</span></div>
#     </div>
#
# <div class="word  " >
# <div class="ar">إِيَّاكَ </div>
# <div class="features"> <span class="lemma">&lt;iy~aA</span> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">نَعْبُدُ </div>
# <div class="features"> <span class="lemma">Eabada</span> <span class="root">Ebd</span> <span class="pos">verb</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">وَ</div>
# <div class="features"> <span class="pos">conjunction</span> <span class="posx">coordinating</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">إِيَّاكَ </div>
# <div class="features"> <span class="lemma">&lt;iy~aA</span> <span class="pos">pronoun</span> <span class="posx">personal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">نَسْتَعِينُ</div>
# <div class="features"> <span class="lemma">{sotaEiynu</span> <span class="root">Ewn</span> <span class="pos">verb</span> <span class="formation">X</span> <span class="tense">imperfect</span></div>
#
#
# </div>
#
#
# </div>
#
# <div class="aya  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="http://tanzil.net/#1:6" title="show this passage on Tanzil" sec="1:6">1:6</a></div>
#
#         <div class="features"> <span class="translation@en xft"><span class="f">translation@en=</span>Guide us in the straight path,</span> <span class="translation@nl xft"><span class="f">translation@nl=</span>Leid ons op de juiste weg,</span></div>
#     </div>
#
# <div class="word  " >
# <div class="ar">ٱهْدِ</div>
# <div class="features"> <span class="lemma">hadaY</span> <span class="root">hdy</span> <span class="pos">verb</span> <span class="tense">imperative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="ar">نَا </div>
# <div class="features"> <span class="pos">pronoun</span> <s

# %% [markdown]
# ---
#
# All chapters:
#
# * **[start](start.ipynb)** introduction to computing with your corpus
# * **display** become an expert in creating pretty displays of your text structures
# * **[search](search.ipynb)** turbo charge your hand-coding with search templates
# * **[exportExcel](exportExcel.ipynb)** make tailor-made spreadsheets out of your results
# * (to come) **[share](share.ipynb)** draw in other people's data and let them use yours
# * **[similarAyas](similarAyas.ipynb)** spot the similarities between lines
#
# Back to [start](start.ipynb)
