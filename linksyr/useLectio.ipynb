# %% [markdown]
# <img align="right" src="images/tf.png" width="128"/>
# <img align="right" src="images/etcbc.png" width="128"/>
# <img align="right" src="images/syrnt.png" width="128"/>
# <img align="right" src="images/peshitta.png" width="128"/>
#
# # Use lectionaries in the Peshitta (OT and NT)
#
# This notebook shows just one way to use the Syriac Lectionary data by Geert Jan Veldman
# together with the Peshitta texts, OT and NT.
#
# It has been used in the Syriac Bootcamp at the ETCBC, VU Amsterdam, on 2019-01-18.
#
# ## Provenance
#
# The lectionary data can be downloaded from the
# [DANS archive](https://dans.knaw.nl/en/front-page?set_language=en)
# through this DOI:
# [10.17026/dans-26t-hhv7](https://doi.org/10.17026/dans-26t-hhv7).
#
# The Peshitta (OT) and (NT) text sources in text-fabric format are on GitHub:
#
# * OT: [etcbc/peshitta](https://github.com/ETCBC/peshitta)
# * NT: [etcbc/syrnt](https://github.com/ETCBC/syrnt)
#
# The program that generated the text-fabric features linking the lectionaries with the text is in
# a Jupyter notebook:
#
# * [makeLectio](https://nbviewer.jupyter.org/github/etcbc/linksyr/blob/master/programs/lectionaries/makeLectio.ipynb)
#
# ## Run it yourself!
#
# Make sure you have installed
#
# * Python (3.6.3 or higher)
# * Jupyter
#
#   ```pip3 install jupyter```
# * Text-Fabric
#
#   ```pip3 install text-fabric```
#
# If you have already installed text-fabric before, make sure to do
#
# ```pip3 install --upgrade text-fabric```
#
# because Text-Fabric is in active development every now and then.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import re
from tf.app import use

# %% [markdown]
# # Context
#
# We will be working with two TF data sources,
#
# * the `peshitta`, (OT Peshitta) which name we store in variable `P`
# * the `syrnt`, (NT Peshitta) which name we store in variable `S`
#
# They both contain Syriac text and transcriptions, but the SyrNT has linguistic annotations and lexemes, while the
# Peshitta (OT) lacks them.

# %%
P = 'peshitta'
S = 'syrnt'
A = {P: None, S: None}

# %% [markdown]
# # Text-Fabric browser
#
# Let's first look at the data in your own browser.
#
# What you need to do is to open a command prompt.
# If you do not know what that is: on Windows it is the program `cmd.exe`, on the Mac it is the app called `Terminal`,
# and on Linux you know what it is.
#
# You can use it from any directory.
#
# If one of the commands below do not work, you have installed things differently than I assume here, or the installation was not succesful.
# For more information, consult
# [Install](https://annotation.github.io/text-fabric/About/Install/) and/or
# [FAQ](https://annotation.github.io/text-fabric/About/Faq/)

# %% [markdown]
# Start the TF browser as follows:
#
# ### Old Testament
#
# ```
# text-fabric peshitta -c --mod=etcbc/linksyr/data/tf/lectio/peshitta
# ```
#
# ### New Testament
#
# Open a new command prompt and say there:
#
# ```
# text-fabric syrnt -c --mod=etcbc/linksyr/data/tf/lectio/syrnt
# ```
#
# ### Example queries
#
# In both cases, issue a query such as
#
# ```
# verse taksa link
# ```
#
# or a more refined one:
#
# ```
# verse taksa link
#   word word_etcbc=LLJ>
# ```
#
#
# You will see all verses that are associated with a lectionary that has a `taksa` and a `link` value.

# %% [markdown]
# After playing around with the browsing interface on both testaments, return to this notebook.

# %% [markdown]
# We are going to load both texts here in our program:

# %%
for volume in A:
  A[volume] = use(volume+':clone', mod=f'etcbc/linksyr/data/tf/lectio/{volume}')
# Out:
# Using TF-app in /Users/dirk/github/annotation/app-peshitta/code:
# 	repo clone offline under ~/github (local github)
# 	connecting to online GitHub repo etcbc/peshitta ... connected
# Using data in /Users/dirk/text-fabric-data/etcbc/peshitta/tf/0.1:
# 	r0.4 (latest release)
# 	connecting to online GitHub repo etcbc/linksyr ... connected
# Using data in /Users/dirk/text-fabric-data/etcbc/linksyr/data/tf/lectio/peshitta/0.1:
# 	rv0.1 (latest release)
# <b>Documentation:</b> <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs" title="provenance of Peshitta (Old Testament)">PESHITTA</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Writing/Syriac" title="('Syriac characters and transcriptions',)">Character table</a> <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#transcription.md" title="PESHITTA feature documentation">Feature docs</a> <a target="_blank" href="https://github.com/annotation/app-peshitta" title="peshitta API documentation">peshitta API</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/" title="text-fabric-api">Text-Fabric API 7.5.4</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Use/Search/" title="Search Templates Introduction and Reference">Search Reference</a><details open><summary><b>Loaded features</b>:</summary>
# <p><b>Peshitta (Old Testament)</b>: <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#book" title="/Users/dirk/text-fabric-data/etcbc/peshitta/tf/0.1/book.tf">book</a>  <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#book@ll" title="/Users/dirk/text-fabric-data/etcbc/peshitta/tf/0.1/book@en.tf">book@ll</a>  <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#chapter" title="/Users/dirk/text-fabric-data/etcbc/peshitta/tf/0.1/chapter.tf">chapter</a>  <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#otype" title="/Users/dirk/text-fabric-data/etcbc/peshitta/tf/0.1/otype.tf">otype</a>  <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#trailer" title="/Users/dirk/text-fabric-data/etcbc/peshitta/tf/0.1/trailer.tf">trailer</a>  <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#trailer_etcbc" title="/Users/dirk/text-fabric-data/etcbc/peshitta/tf/0.1/trailer_etcbc.tf">trailer_etcbc</a>  <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#verse" title="/Users/dirk/text-fabric-data/etcbc/peshitta/tf/0.1/verse.tf">verse</a>  <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#witness" title="/Users/dirk/text-fabric-data/etcbc/peshitta/tf/0.1/witness.tf">witness</a>  <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#word" title="/Users/dirk/text-fabric-data/etcbc/peshitta/tf/0.1/word.tf">word</a>  <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#word_etcbc" title="/Users/dirk/text-fabric-data/etcbc/peshitta/tf/0.1/word_etcbc.tf">word_etcbc</a>  <b><i><a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#oslots" title="/Users/dirk/text-fabric-data/etcbc/peshitta/tf/0.1/oslots.tf">oslots</a></i></b> </p><p><b>etcbc/linksyr/data/tf/lectio/peshitta</b>: <a target="_blank" href="https://github.com/etcbc/linksyr/tree/master/data/tf/lectio/peshitta" title="/Users/dirk/text-fabric-data/etcbc/linksyr/data/tf/lectio/peshitta/0.1/lectio.tf">lectio</a>  <a target="_blank" href="https://github.com/etcbc/linksyr/tree/master/data/tf/lectio/peshitta" title="/Users/dirk/text-fabric-data/etcbc/linksyr/data/tf/lectio/peshitta/0.1/link.tf">link</a>  <a target="_blank" href="https://github.com/etcbc/linksyr/tree/master/data/tf/lectio/peshitta" title="/Users/dirk/text-fabric-data/etcbc/linksyr/data/tf/lectio/peshitta/0.1/mark1.tf">mark1</a>  <a target="_blank" href="https://github.com/etcbc/linksyr/tree/master/data/tf/lectio/peshitta" title="/Users/dirk/text-fabric-data/etcbc/linksyr/data/tf/lectio/peshitta/0.1/mark2.tf">mark2</a>  <a target="_blank" href="https://github.com/etcbc/linksyr/tree/master/data/tf/lectio/peshitta" title="/Users/dirk/text-fabric-data/etcbc/linksyr/data/tf/lectio/peshitta/0.1/siglum.tf">siglum</a>  <a target="_blank" href="https://github.com/etcbc/linksyr/tree/master/data/tf/lectio/peshitta" title="/Users/dirk/text-fabric-data/etcbc/linksyr/data/tf/lectio/peshitta/0.1/taksa.tf">taksa</a>  <a target="_blank" href="https://github.com/etcbc/linksyr/tree/master/data/tf/lectio/peshitta" title="/Users/dirk/text-fabric-data/etcbc/linksyr/data/tf/lectio/peshitta/0.1/taksaTr.tf">taksaTr</a> </p></details>
# <style>
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src:
#     local("SyrCOMEdessa.otf"),
#     url("https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true");
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .verse {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-end;
#     align-items: flex-end;
#     direction: ltr;
#     width: 100%;
# }
# .outeritem {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .word {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 1px solid #cccccc;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .occs {
#     font-size: x-small;
# }
# .tr,.tr a:visited,.tr a:link {
#     font-family: sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: ltr;
#     text-decoration: none;
# }
# .trb,.trb a:visited,.trb a:link {
#     font-family: sans-serif;
#     font-size: normal;
#     direction: ltr;
#     text-decoration: none;
# }
# .sy,.sy a:visited,.sy a:link {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: rtl;
#     text-decoration: none;
# }
# .syb,.syb a:visited,.syb a:link {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: large;
#     line-height: 2;
#     direction: rtl;
#     text-decoration: none;
# }
# .vn {
#   font-size: small !important;
#   padding-right: 1em;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .hl {
#     background-color: #ffee66;
# }
#
# tr.tf, td.tf, th.tf {
#   text-align: left;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlup {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>
# Using TF-app in /Users/dirk/github/annotation/app-syrnt/code:
# 	repo clone offline under ~/github (local github)
# 	connecting to online GitHub repo etcbc/syrnt ... connected
# Using data in /Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1:
# 	r0.3 (latest release)
# 	connecting to online GitHub repo etcbc/linksyr ... connected
# Using data in /Users/dirk/text-fabric-data/etcbc/linksyr/data/tf/lectio/syrnt/0.1:
# 	rv0.1 (latest release)
# <b>Documentation:</b> <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs" title="provenance of SyrNT">SYRNT</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Writing/Syriac" title="('Syriac characters and transcriptions',)">Character table</a> <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#transcription.md" title="SYRNT feature documentation">Feature docs</a> <a target="_blank" href="https://github.com/annotation/app-syrnt" title="syrnt API documentation">syrnt API</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/" title="text-fabric-api">Text-Fabric API 7.5.4</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Use/Search/" title="Search Templates Introduction and Reference">Search Reference</a><details open><summary><b>Loaded features</b>:</summary>
# <p><b>SyrNT</b>: <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#book" title="/Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1/book.tf">book</a>  <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#book@ll" title="/Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1/book@en.tf">book@ll</a>  <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#chapter" title="/Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1/chapter.tf">chapter</a>  <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#demcat" title="/Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1/demcat.tf">demcat</a>  <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#fmhdot" title="/Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1/fmhdot.tf">fmhdot</a>  <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#gn" title="/Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1/gn.tf">gn</a>  <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#lexeme" title="/Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1/lexeme.tf">lexeme</a>  <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#lexeme_etcbc" title="/Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1/lexeme_etcbc.tf">lexeme_etcbc</a>  <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#lexeme_sedra" title="/Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1/lexeme_sedra.tf">lexeme_sedra</a>  <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#nmtyp" title="/Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1/nmtyp.tf">nmtyp</a>  <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#ntyp" title="/Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1/ntyp.tf">ntyp</a>  <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#nu" title="/Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1/nu.tf">nu</a>  <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#otype" title="/Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1/otype.tf">otype</a>  <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#prefix" title="/Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1/prefix.tf">prefix</a>  <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#prefix_etcbc" title="/Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1/prefix_etcbc.tf">prefix_etcbc</a>  <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#prefix_sedra" title="/Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1/prefix_sedra.tf">prefix_sedra</a>  <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#prtyp" title="/Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1/prtyp.tf">prtyp</a>  <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#ps" title="/Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1/ps.tf">ps</a>  <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#ptctyp" title="/Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1/ptctyp.tf">ptctyp</a>  <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#root" title="/Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1/root.tf">root</a>  <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#root_etcbc" title="/Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1/root_etcbc.tf">root_etcbc</a>  <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/docs/transcription-0.1.md#root_sedra" title="/Users/dirk/text-fabric-data/etcbc/syrnt/tf/0.1/root_sedra.tf"> ...
# <style>
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src:
#     local("SyrCOMEdessa.otf"),
#     url("https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true");
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .verse {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-end;
#     align-items: flex-end;
#     direction: ltr;
#     width: 100%;
# }
# .outeritem {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .word {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 1px solid #cccccc;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .lextp {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 2px solid #888888;
#     width: fit-content;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .occs {
#     font-size: x-small;
# }
# .tr,.tr a:visited,.tr a:link {
#     font-family: sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: ltr;
#     text-decoration: none;
# }
# .trb,.trb a:visited,.trb a:link {
#     font-family: sans-serif;
#     font-size: normal;
#     direction: ltr;
#     text-decoration: none;
# }
# .sy,.sy a:visited,.sy a:link {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: rtl;
#     text-decoration: none;
# }
# .syb,.syb a:visited,.syb a:link {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: large;
#     line-height: 2;
#     direction: rtl;
#     text-decoration: none;
# }
# .vn {
#   font-size: small !important;
#   padding-right: 1em;
# }
# .sp,.sp a:visited,.sp a:link {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
#     text-decoration: none;
# }
# .lexeme {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .vs {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .vt {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .hl {
#     background-color: #ffee66;
# }
#
#
# tr.tf, td.tf, th.tf {
#   text-align: left;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlup {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>

# %% [markdown]
# Above you can see that we have loaded the `peshitta` and `syrnt` data sources but also additional data from
#
# * **etcbc/linksyr/data/tf/lectio/peshitta**
# * **etcbc/linksyr/data/tf/lectio/syrnt**

# %% [markdown]
# From both additional sources we have loaded several features: `lectio`, `mark1`, `mark2`, `siglum`, `taksa`, `taksaTr`.
#
# Every lectionary has a number. A lectionary is linked to several verses.
#
# Here is what kind of information the features contain:
#
# feature | description
# --- | ---
# **lectio** | comma separated list of numbers of lectionaries associated with this verse
# **mark1** | comma separated list of words which mark the precise location of where the lectionaries start
# **taksa** | newline separated list of liturgical events associated with the lectionaries (in Syriac)
# **taksaTr** | same as **taksa**, but now in English
# **siglum** | newline separated list of document references that mention specify the lectionary
# **link** | newline separated list of links to the *sigla*
# **mark2** | same as **mark2**, but the word is in a different language

# %% [markdown]
# When you work with TF, you usually have handy variables called `F`, `L`, `T` ready with which you access all data in the text.
#
# Since we use two TF resources in this program, we make a double set of these variables, and instead of just `F`, we'll say
# `F[P]` for accessing the Peshitta (OT) and `F[S]` for accessing the SyrNT. Same pattern for `L` and `T`.
#
# For the meaning of these variables, consult
#
# * [F Features](https://annotation.github.io/text-fabric/Api/Features/)
# * [L Locality](https://annotation.github.io/text-fabric/Api/Locality/)
# * [T Text](https://annotation.github.io/text-fabric/Api/Text/)

# %%
Fs = {}
F = {}
T = {}
L = {}

for volume in A:
  thisApi = A[volume].api
  F[volume] = thisApi.F
  Fs[volume] = thisApi.Fs
  T[volume] = thisApi.T
  L[volume] = thisApi.L

# %%
extraFeatures = '''
  lectio
  mark1 mark2
'''.strip().split()

# %% [markdown]
# # Liturgicalness
#
# We measure the *liturgicalness* of a word by counting the number of lectionaries it is involved in.
#
# As a first step, we collect for each words the set of lectionaries it is involved in.
#
# In the Peshitta OT we use the word form, since we do not have lemmas.
# The word form is in the feature `word`.
#
# In the SyrNT we use the word lemma, which is in the feature `lexeme`.
#
# We collect the information in the dictionary `liturgical`, which maps each word form unto the set of lectionaries it is involved in.

# %%
# this function can do the collection in either Testament

def getLiturgical(volume):
  wordRep = 'word' if volume == P else 'lexeme'
  mapping = {}

  # we traverse all verse nodes
  for verseNode in F[volume].otype.s('verse'):
    # we retrieve the value of feature 'lectio' for that verse node
    lectioStr = F[volume].lectio.v(verseNode)
    if lectioStr:
      # we split the lectio string into a set of individual lectio numbers
      lectios = lectioStr.split(',')
      
      # we descend into the words of the verse
      for wordNode in L[volume].d(verseNode, otype='word'):
        # we use either the feature 'word' or 'lexeme', depending on the volume
        word = Fs[volume](wordRep).v(wordNode)
        
        # if this is the first time we encounter the word,
        # we add it to the mapping and give it a start value: the empty set 
        if word not in mapping:
          mapping[word] = set()
        # in any case, we add the new found lectio numbers to the existing set for this word
        mapping[word] |= set(lectios)
        
  # we report how many words we have collected
  print(f'Found {len(mapping)} words in {volume}')
  
  # we return the mapping as result
  return mapping

# %% [markdown]
# Before we call the function above for Peshitta and SyrNT, we make a place where the results can land:

# %%
liturgical = {}

# %%
for volume in A:
  liturgical[volume] = getLiturgical(volume)
# Out:
# Found 30235 words in peshitta
# Found 2521 words in syrnt

# %% [markdown]
# Remember that we count word occurrences in the Peshitta, and lemmas in the SyrNT, so we get much smaller numbers for the NT.

# %% [markdown]
# Let's show some mapping members for each volume:

# %%
for volume in liturgical:
  print(f'IN {volume}:')
  for (word, lectios) in list(liturgical[volume].items())[0:10]:
    print(f'\t{word}')
    print(f'\t\t{",".join(sorted(lectios)[0:5])} ...')
# Out:
# IN peshitta:
# 	ܒܪܫܝܬ
# 		1151,1333,1550,1574,1578 ...
# 	ܒܪܐ
# 		1000,1002,1005,1016,1024 ...
# 	ܐܠܗܐ
# 		10,100,1002,1003,1007 ...
# 	ܝܬ
# 		1151,1333,1550,1574,1578 ...
# 	ܫܡܝܐ
# 		1039,1085,1088,1111,1121 ...
# 	ܘܝܬ
# 		1151,1333,1550,1574,1578 ...
# 	ܐܪܥܐ
# 		10,1000,1003,1005,1007 ...
# 	ܗܘܬ
# 		1000,1003,1005,1017,1020 ...
# 	ܬܘܗ
# 		1151,1333,1550,1563,1574 ...
# 	ܘܒܘܗ̇
# 		1151,1333,1550,1574,1578 ...
# IN syrnt:
# 	ܝܥܩܘܒ
# 		1004,1186,1243,1294,1329 ...
# 	ܝܠܕ
# 		1004,1059,1116,1157,1243 ...
# 	ܝܘܣܦ
# 		1004,1243,1254,1261,1273 ...
# 	ܓܒܪܐ
# 		0,1112,1161,1193,1196 ...
# 	ܡܪܝܡ
# 		1243,1268,1273,1305,1313 ...
# 	ܡܢ
# 		0,1001,1004,1008,1012 ...
# 	ܝܫܘܥ
# 		0,1008,1012,1018,1023 ...
# 	ܩܪܐ
# 		1001,1004,1012,1032,1096 ...
# 	ܡܫܝܚܐ
# 		0,1012,1018,1023,1032 ...
# 	ܟܠ
# 		0,1001,1004,1012,1023 ...

# %% [markdown]
# We are not done yet, because we are not interested in the actual lectionaries, but in their number.
# So we make a new mapping `liturgicalNess`, which maps each word to the number of lectionaries it is associated with.

# %%
liturgicalNess = {}

for volume in liturgical:
  for word in liturgical[volume]:
    nLectio = len(liturgical[volume][word])
    liturgicalNess.setdefault(volume, {})[word] = nLectio

# %% [markdown]
# Lets print the top twenty of each volume

# %%
for volume in liturgicalNess:
  print(f'IN {volume}:')
  for (word, lNess) in sorted(
    liturgicalNess[volume].items(),
    key=lambda x: (-x[1], x[0]),
  )[0:20]:
    print(f'\t{lNess:>5} {word}')
# Out:
# IN peshitta:
# 	 5487 ܡܢ
# 	 4508 ܡܪܝܐ
# 	 4470 ܥܠ
# 	 4228 ܡܛܠ
# 	 4123 ܠܐ
# 	 3510 ܐܝܟ
# 	 3500 ܘܠܐ
# 	 2925 ܕܡܪܝܐ
# 	 2886 ܠܗ
# 	 2836 ܐܢܐ
# 	 2541 ܐܢܘܢ
# 	 2488 ܐܪܥܐ
# 	 2364 ܕܠܐ
# 	 2267 ܗܘ
# 	 2148 ܗܢܐ
# 	 2079 ܐܠܗܐ
# 	 2072 ܩܕܡ
# 	 2050 ܠܗܘܢ
# 	 2047 ܗܐ
# 	 1940 ܘܐܡܪ
# IN syrnt:
# 	 1508 ܗܘ
# 	 1502 ܗܘܐ
# 	 1477 ܡܢ
# 	 1474 ܠ
# 	 1414 ܠܐ
# 	 1376 ܐܠܗܐ
# 	 1304 ܗܢܐ
# 	 1271 ܟܠ
# 	 1256 ܥܠ
# 	 1247 ܕܝܢ
# 	 1145 ܐܝܬ
# 	 1144 ܓܝܪ
# 	 1065 ܐܝܢܐ
# 	 1048 ܒ
# 	 1035 ܐܡܪ
# 	 1024 ܟܕ
# 	 1009 ܐܢܐ
# 	  976 ܡܪܝܐ
# 	  972 ܐܦ
# 	  953 ܐܝܟ

# %% [markdown]
# # Frequency lists
#
# Here is how to get a frequency list of a volume.
#
# We can produce the frequency of any feature, but let us do it here for words in the Peshitta (OT) and
# lexemes in the SyrNY.
#
# There is a hidden snag: in the SyrNT we do not have only word nodes, but also lexeme nodes.
# When we count frequencies, we have to take care to count word nodes only.
#
# The function [freqList](https://annotation.github.io/text-fabric/Api/Features/)
# can do that.
#
# Lets use it and produce the top twenty list of frequent words in both sources, and also the number of hapaxes.

# %%
# first we define a function to generate the table per volume

def showFreqList(volume):
  print(f'IN {volume}:')
  wordRep = 'word' if volume == P else 'lexeme'
  freqs = Fs[volume](wordRep).freqList(nodeTypes={'word'})
  
  # now the members of freqs are pairs (word, freqency)
  
  # we print the top frequent words
  for (word, freq) in freqs[0:10]:
    print(f'\t{freq:>5} x {word}')
    
  # we collect all hapaxes: the items with frequency 1
  hapaxes = [word for (word, freq) in freqs if freq == 1]
  print(f'{len(hapaxes)} hapaxes')
  for hapax in hapaxes[100:105]:
    print(f'\t{hapax}')

# %%
# then we execute it on both volumes

for volume in A:
  showFreqList(volume)
# Out:
# IN peshitta:
# 	 8932 x ܡܢ
# 	 5330 x ܥܠ
# 	 4586 x ܡܪܝܐ
# 	 4453 x ܠܐ
# 	 3972 x ܡܛܠ
# 	 3217 x ܘܠܐ
# 	 3206 x ܐܝܟ
# 	 3132 x ܠܗ
# 	 2625 x ܐܢܘܢ
# 	 2488 x ܗܘܐ
# 32755 hapaxes
# 	ܐ̈ܒܝܕܝ
# 	ܐ̈ܒܢܝ
# 	ܐ̈ܓܡܐ
# 	ܐ̈ܕܢܝܗ̇
# 	ܐ̈ܕܢܝܟ
# IN syrnt:
# 	 4234 x ܠ
# 	 4006 x ܗܘܐ
# 	 3397 x ܗܘ
# 	 3335 x ܡܢ
# 	 3140 x ܠܐ
# 	 2553 x ܐܡܪ
# 	 1828 x ܕܝܢ
# 	 1813 x ܥܠ
# 	 1728 x ܐܢܐ
# 	 1584 x ܗܢܐ
# 835 hapaxes
# 	ܒܠܩ
# 	ܒܢܝ-ܪܓܫܝ
# 	ܒܣܕܝܐ
# 	ܒܥܕ
# 	ܒܥܘܪ

# %% [markdown]
# # Queries
#
# First a simple query with all verses with a lectionary (with taksa and link)

# %%
query = '''
verse taksa link
'''

# %% [markdown]
# We run them in both the Old and the New Testament

# %%
results = {}
for volume in A:
  results[volume] = A[volume].search(query)
# Out:
#   0.03s 4571 results
#   0.01s 1991 results

# %% [markdown]
# Let's show some results from the New Testament:

# %%
A[S].show(results[S], start=1, end=1)
# Out:
# <p><b>result</b> <i>1</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/syrnt/blob/master/plain/0.1/Mark.txt" title="show this passage in the SyrNT source" sec="Mark 14:27">Mark 14:27</a></div>
#
#         <div class="features"> <span class="link xft"><span class="f">link=</span>https://gallica.bnf.fr/ark:/12148/btv1b10527102b/f498.item</span> <span class="taksa xft"><span class="f">taksa=</span>ܕܠܠܝܐ ܕܥܪܘܒܬܐ ܕܨܠܝܒܘܬܐ</span></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܘܐܡܪ </div>
# <div class="features"> <span class="word_etcbc">W>MR</span> <span class="lexeme_etcbc">>MR</span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܗܘܢ </div>
# <div class="features"> <span class="word_etcbc">LHWN</span> <span class="lexeme_etcbc">L</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܝܫܘܥ </div>
# <div class="features"> <span class="word_etcbc">JCW&lt;</span> <span class="lexeme_etcbc">JCW&lt;</span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܟܠܟܘܢ </div>
# <div class="features"> <span class="word_etcbc">DKLKWN</span> <span class="lexeme_etcbc">KL</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܬܬܟܫܠܘܢ </div>
# <div class="features"> <span class="word_etcbc">TTKCLWN</span> <span class="lexeme_etcbc">KCL</span> <span class="sp">verb</span> <span class="vs">ethpeal</span> <span class="vt">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܝ </div>
# <div class="features"> <span class="word_etcbc">BJ</span> <span class="lexeme_etcbc">B</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܗܢܐ </div>
# <div class="features"> <span class="word_etcbc">BHN></span> <span class="lexeme_etcbc">HN></span> <span class="sp">pronoun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܠܝܐ </div>
# <div class="features"> <span class="word_etcbc">LLJ></span> <span class="lexeme_etcbc">LLJ></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܟܬܝܒ </div>
# <div class="features"> <span class="word_etcbc">KTJB</span> <span class="lexeme_etcbc">KTB</span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">participle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܓܝܪ </div>
# <div class="features"> <span class="word_etcbc">GJR</span> <span class="lexeme_etcbc">GJR</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܐܡܚܐ </div>
# <div class="features"> <span class="word_etcbc">D>MX></span> <span class="lexeme_etcbc">MX></span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܪܥܝܐ </div>
# <div class="features"> <span class="word_etcbc">LR&lt;J></span> <span class="lexeme_etcbc">R&lt;J></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܢܬܒܕܪܘܢ </div>
# <div class="features"> <span class="word_etcbc">WNTBDRWN</span> <span class="lexeme_etcbc">BDR</span> <span class="sp">verb</span> <span class="vs">ethpael</span> <span class="vt">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܡܪܘܗܝ </div>
# <div class="features"> <span class="word_etcbc">>MRWHJ</span> <span class="lexeme_etcbc">>MR></span> <span class="sp">noun</span></div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# Let's show some results from the New Testament:

# %%
A[P].show(results[P], start=1, end=1)
# Out:
# <p><b>result</b> <i>1</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Genesis" title="show this passage in the Peshitta source" sec="Genesis 1:1">Genesis 1:1</a></div>
#
#         <div class="features"> <span class="link xft"><span class="f">link=</span>http://beta.nli.org.il/he/manuscripts/NNL_ALEPH003891722/NLI<br/>http://web.nli.org.il/sites/NLI/Hebrew/digitallibrary/pages/viewer.aspx?presentorid=MANUSCRIPTS&amp;docid=PNX_MANUSCRIPTS003891732-1#|FL53564525<br/>http://web.nli.org.il/sites/NLI/Hebrew/digitallibrary/pages/viewer.aspx?presentorid=MANUSCRIPTS&amp;docid=PNX_MANUSCRIPTS003891737-1#|FL53566312<br/>https://archive.org/stream/SMC1.1/SMC%201.1#page/n64/mode/1up<br/>https://digi.vatlib.it/view/MSS_Vat.sir.24/0108<br/>https://digi.vatlib.it/view/MSS_Vat.sir.278/0009<br/>https://digi.vatlib.it/view/MSS_Vat.sir.278/0017<br/>https://digi.vatlib.it/view/MSS_Vat.sir.278/0042<br/>https://digi.vatlib.it/view/MSS_Vat.sir.278/0241<br/>https://www.loc.gov/resource/amedmonastery.00279386243-ms/?sp=119<br/>https://www.loc.gov/resource/amedmonastery.00279386243-ms/?sp=20<br/>https://www.loc.gov/resource/amedmonastery.00279386243-ms/?sp=7<br/>https://www.loc.gov/resource/amedmonastery.00279386577-ms/?sp=15<br/>https://www.loc.gov/resource/amedmonastery.00279386577-ms/?sp=181<br/>https://www.loc.gov/resource/amedmonastery.00279386577-ms/?sp=36<br/>https://www.loc.gov/resource/amedmonastery.00279386577-ms/?sp=4<br/>https://www.loc.gov/resource/amedmonastery.00279387648-ms/?sp=10<br/>https://www.loc.gov/resource/amedmonastery.00279387648-ms/?sp=108<br/>https://www.loc.gov/resource/amedmonastery.00279387648-ms/?sp=16<br/>https://www.loc.gov/resource/amedmonastery.00279387648-ms/?sp=9<br/>https://www.loc.gov/resource/amedmonastery.00279387697-ms/?sp=12<br/>https://www.loc.gov/resource/amedmonastery.00279387697-ms/?sp=153<br/>https://www.loc.gov/resource/amedmonastery.00279388124-ms/?sp=106<br/>https://www.loc.gov/resource/amedmonastery.00279388124-ms/?sp=17<br/>https://www.loc.gov/resource/amedmonastery.00279388124-ms/?sp=5<br/>https://www.loc.gov/resource/amedmonastery.00279388768-ms/?sp=17<br/>https://www.loc.gov/resource/amedmonastery.00279388768-ms/?sp=7<br/>https://www.loc.gov/resource/amedmonastery.00279388768-ms/?sp=94<br/>https://www.vhmml.org/readingRoom/view/132198</span> <span class="taksa xft"><span class="f">taksa=</span>N.A.<br/>[...]<br/>ܒܪܡܫܐ ܕܝܘܡ ܀ ܏ܒ ܏ܒܫ ܀܏ܐ ܀ ܕܨܘܡܐ<br/>ܒܪܡܫܐ ܕܝܘܡ ܏ܒ ܏ܒܫ ܏ܐ ܕܨܘܡܐ<br/>ܒܪܡܫܐ ܕܝܘܡ ܏ܒ ܕܫܒ ܐ<br/>ܒܪܡܫܐ ܕܝܠܗ ܕܝܘ܏ܡ ܏ܒ ܏ܒܫ ܕ܏ܫܒ ܏ܐ ܕܨܘܡܐ<br/>ܒܪܡܫܐ ܕܝܠܗ ܕܝܘܡ ܬܪ̈ܝܢ ܒܫܒܐ ܕܫܒܬܐ ܩܕܡܝܬܐ ܕܨܘܡܐ<br/>ܒܪܡܫܐ ܕܝܠܗ ܕܝܘܡ. ܏ܒ ܒܫܒܐ ܕܫܒܬܐ ܏ܐ. ܕܨܘܡܐ<br/>ܒܪܡܫܐ ܕܝܠܗ ܕܝܘܡ. ܏ܒ: ܒܫܒܐ ܕܫܒܬܐ: ܐ: ܕܨܘܡܐ<br/>ܒܪܡܫܐ ܕܝܠܗ ܕܝܘܡ: ܏ܒ ܒܫܒܐ: ܕ܏ܫܒ :ܐ: ܕܨܘܡܐ<br/>ܒܪܡܫܐ ܕܝܠܗ ܕܝܘܡܐ ܏ܕܒ ܒܫܒܐ ܕܫܒܬܐ : ܏ܐ :<br/>ܒܪܡܫܐ ܕܝܠܗ: ܝܘܡ ܒ ܒܫܒܐ ܕ܏ܫܒ: ܏ܐ ܕܨܘܡܐ<br/>ܒܬܪܝܢ ܒܫܒܐ : ܒܪܡܫܐ: ܢܦܩܝܢ ܡܢ ܒܝܬ ܕܓܙܐ ܟܕ ܛܥܢܝܢ ܐܘܢܓܠܝܘܢ ܘܐܡܪܝܢ ܥܢܝܬܐ ܗܕܐ܀<br/>ܕܚܕܒܫܒܐ ܩܕܡܝܐ ܕܨܘܡܐ ܪܒܐ<br/>ܕܝܘܡ ܬܪ̈ܝܢ ܒܫܒܐ ܕܩܘ̣ܒܠ ܨܘܡܐ<br/>ܕܝܘܡ ܬܪ̈ܝܢ ܒܫܒܐ ܕܩܘܒܠ ܨܘܡܐ ܩܪ̈ܝܢܐ<br/>ܕܬܪܝܢ ܒܫܒܐ ܕܨܘܡܐ<br/>ܕܬܪܝܢ ܒܫܒܐ ܕܫܒܬܐ ܩܕܡܝܬܐ ܕܨܘܡܐ<br/>ܕܬܪܝܢ ܒܫܒܐ ܕܫܒܬܐ ܩܕܡܝܬܐ ܕܨܘܡܐ ܪܒܐ<br/>ܕܬܪܝܢ ܒܫܒܐ ܩܕܡܝܐ ܕܨܘܡܐ ܪܒܐ<br/>ܕܬܪܝܢܒܫ ܩܕܡܝܐ ܕܨܘܡܐ ܪܒܐ<br/>ܕܬܪܝܢܒܫܒܐ ܕܨܘܡܐ ܪܒܐ.<br/>ܕܬܪܝܢܒܫܒܐ ܕܫܒܬܐ ܩܕܡܝܬܐ ܕܨܘܡܐ<br/>ܘ ܟܢܘܢ ܒ ܥܐܕܐ ܕܕܢܚܐ ܩܕܝܫܐ ܕܡܪܢ<br/>ܝܘܡ ܏ܫܒ ܪܒܬܐ. ܒܪܡܫܐ<br/>ܝܘܡ ܫܒܬܐ ܪܒ̇ܬܐ ܒܪܡܫܐ.<br/>ܝܘܡ ܫܒܬܐ ܪܒܬܐ ܒܪܡܫܐ<br/>ܟܗ ܟܢܘܢ ܐ ܡܘܠܕܗ ܕܡܪܢ ܝܫܘܥ ܡܫܝܚܐ<br/>ܩܕܡ[ܐܝܬ] ܕܥܐܕܐ ܕܒܝܬ ܝ̇ܠܕܗ<br/>ܩܕܡܐܝܬ ܕܢܓܗ ܥܐܕܐ ܩܕܝܫܐ ܕܝܠܕܗ ܕܡܪܢ ܝܫܘܥ ܡܫܝܚܐ<br/>ܩܕܡܐܝܬ ܕܥܐܕܐ ܕܒܝܬ ܝܠܕܗ ܕܡܪܢ ܘܐܠܗܢ ܘܦܪܘܩܢ ܝܫܘܥ ܡܫܝܚܐ<br/>ܩܕܡܐܝܬ ܥܐܕܐ ܕܒܝܬ ܝܠܕܗ̇ ܕ[...] ܘܦܪܘܩܢ ܝܫܘܥ ܡܫܝܚܐ ܒܦܓܪ[.]<br/>ܩܕܡܐܝܬ ܥܐܕܐ ܩܕܝܫܐ ܕܝܠܕܗ ܕܡܪܢ ܒܦܓܪ<br/>ܩܕܡܐܝܬ ܥܐܕܐ ܩܕܝܫܐ ܕܝܠܕܗ ܕܡܪܢ ܘܐܠܗܢ܀. ܝܫܘܥ ܡܫܝܚܐ<br/>ܩܪ̈ܝܢܐ ܕܚܕܒܫܒܐ ܚ̣ܕܬܐ܀<br/>ܩܪ̈ܝܢܐ ܕܝܘܡ ܬܪ̈ܝܢ ܒܫܒܐ ܕܫܒܬܐ ܩܕ܏ܡܝ ܕܨܘܡܐ.<br/>ܩܪ̈ܝܢܐ ܕܬܪ̈ܝܢ ܒܫܒܐ ܕܨܘܡܐ ܕܫܒܬܐ ܩܕܡܝܬܐ<br/>ܩܪܝܢܐ ܕܬܪܝܢܒܫܒܐ ܕܫܒܬܐ ܩܕܡܝܬܐ ܕܨܘܡܐ.<br/>ܬܘܒ ܛܟܣܐ ܕ܏ܩܪ̈ ܕܥܐܕܐ ܩܕܝܫܐ ܕܕܢܚܐ<br/>ܬܘܒ ܛܟܣܐ ܕܩܪ̈ܝܢܐ ܕܢܓܗ ܥܐܕܐ ܩܕܝܫܐ ܕܕܢܚܐ<br/>ܬܘܒ ܛܟܣܐ ܕܩܪ̈ܝܢܐ ܕܥܐܕܐ ܕܕܢܚܐ ܒܪܡܫܐ ܕܢܓܗ ܥܐܕܐ<br/>ܬܘܒ ܛܟܣܐ ܕܩܪ̈ܝܢܐ ܕܥܐܕܐ ܩܕܝܫܐ ܕܕܢܚܐ<br/>ܬܘܒ ܛܟܣܐ ܕܩܪܝܢܐ ܕܥܐܕܐ ܏ܩܕ ܕܕܢܚܐ ܒܪܡܫܐ<br/>ܬܘܒ ܛܟܣܐ ܕܩܪܝܢܐ ܕܥܐܕܐ ܕܕܢܚܐ ܩܕܡܐܝܬ.<br/>ܬܘܒ ܛܟܣܐ ܕܩܪܝܢܐ ܕܥܕܐ(!) ܩܕܝܫܐ ܕܒܝܬ ܕܢܚܐ<br/>ܬܘܒ ܛܟܣܐ ܕܬܪ̈ܝܢ ܒܫܒܫܐ(!) ܕܨܘܡܐ<br/>ܬܘܒ ܛܣܐ(!) ܕܩܪܝܢܐ ܕܥܐܕܐ ܩܕܝܫܐ ܕܕܢܚܐ</span></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܒܪܫܝܬ </div>
# <div class="features"> <span class="word_etcbc">BRCJT</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܪܐ </div>
# <div class="features"> <span class="word_etcbc">BR></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܠܗܐ. </div>
# <div class="features"> <span class="word_etcbc">>LH></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܝܬ </div>
# <div class="features"> <span class="word_etcbc">JT</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܫܡܝܐ </div>
# <div class="features"> <span class="word_etcbc">CMJ></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܝܬ </div>
# <div class="features"> <span class="word_etcbc">WJT</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܪܥܐ. </div>
# <div class="features"> <span class="word_etcbc">>R&lt;></span></div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# # Word study: CJN>
#
# We want to study a word, in both volumes.
# First we show a verse where the word occurs: James 3:18.
#
# It is in the New Testament.
#
# The
# [`T.nodeFromSection()`](https://annotation.github.io/text-fabric/Api/Text/)
# function can find the node (bar code) for a verse specified by a passage reference.

# %%
# we have to pass the section reference as a triple:
section = ('James', 3, 18)

# we retrieve the verse node
verseNode = T[S].nodeFromSection(('James', 3, 18))

# in case you're curious: here is the node, but it should not be meaningful to you,
# only to the program

print(verseNode)
# Out:
# 120158

# %% [markdown]
# Finally we show the corresponding verse by means of the function
# [pretty()](https://annotation.github.io/text-fabric/Api/App/#display)

# %%
A[S].pretty(verseNode)
# Out:
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/syrnt/blob/master/plain/0.1/James.txt" title="show this passage in the SyrNT source" sec="James 3:18">James 3:18</a></div>
#
#         <div class="features"> <span class="taksa xft"><span class="f">taksa=</span>[...]<br/>ܕܝܘܡ ܥܪܘܒܬܐ ܩ܏ܕܡ ܕܨܘܡܐ<br/>ܩܪ̈ܝܢܐ ܕܚܕܒܫܒܐ ܕܚܡܫܐ ܕܒ̇ܬܪ ܩܝ̣ܡܬܐ.<br/>ܬܘܒ ܛܟܣܐ ܕܚ̈ܡܫܐ ܒܫܒܐ ܕܨܘܡܐ</span></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܦܐܪܐ </div>
# <div class="features"> <span class="word_etcbc">P>R></span> <span class="lexeme_etcbc">P>R></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܝܢ </div>
# <div class="features"> <span class="word_etcbc">DJN</span> <span class="lexeme_etcbc">DJN</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܙܕܝܩܘܬܐ </div>
# <div class="features"> <span class="word_etcbc">DZDJQWT></span> <span class="lexeme_etcbc">ZDJQWT></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">BCJN></span> <span class="lexeme_etcbc">CJN></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܙܕܪܥܝܢ </div>
# <div class="features"> <span class="word_etcbc">MZDR&lt;JN</span> <span class="lexeme_etcbc">ZR&lt;</span> <span class="sp">verb</span> <span class="vs">ethpeal</span> <span class="vt">participle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܐܝܠܝܢ </div>
# <div class="features"> <span class="word_etcbc">L>JLJN</span> <span class="lexeme_etcbc">>JN></span> <span class="sp">pronoun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܥܒܕܝܢ </div>
# <div class="features"> <span class="word_etcbc">D&lt;BDJN</span> <span class="lexeme_etcbc">&lt;BD</span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">participle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܫܠܡܐ </div>
# <div class="features"> <span class="word_etcbc">CLM></span> <span class="lexeme_etcbc">CLM></span> <span class="sp">noun</span></div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# Now we use a query to find this word in the New Testament

# %%
queryS = '''
word lexeme_etcbc=CJN>
'''

# %%
resultsS = A[S].search(queryS)
# Out:
#   0.12s 14 results

# %% [markdown]
# We show them all:

# %%
A[S].show(resultsS)
# Out:
# <p><b>result</b> <i>1</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/syrnt/blob/master/plain/0.1/Matthew.txt" title="show this passage in the SyrNT source" sec="Matthew 10:34">Matthew 10:34</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܠܐ </div>
# <div class="features"> <span class="word_etcbc">L></span> <span class="lexeme_etcbc">L></span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܬܣܒܪܘܢ </div>
# <div class="features"> <span class="word_etcbc">TSBRWN</span> <span class="lexeme_etcbc">SBR</span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܐܬܝܬ </div>
# <div class="features"> <span class="word_etcbc">D>TJT</span> <span class="lexeme_etcbc">>T></span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܐܪܡܐ </div>
# <div class="features"> <span class="word_etcbc">D>RM></span> <span class="lexeme_etcbc">RM></span> <span class="sp">verb</span> <span class="vs">aphel</span> <span class="vt">imperfect</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">CJN></span> <span class="lexeme_etcbc">CJN></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܐܪܥܐ </div>
# <div class="features"> <span class="word_etcbc">B>R&lt;></span> <span class="lexeme_etcbc">>R&lt;></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܐ </div>
# <div class="features"> <span class="word_etcbc">L></span> <span class="lexeme_etcbc">L></span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܬܝܬ </div>
# <div class="features"> <span class="word_etcbc">>TJT</span> <span class="lexeme_etcbc">>T></span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܐܪܡܐ </div>
# <div class="features"> <span class="word_etcbc">D>RM></span> <span class="lexeme_etcbc">RM></span> <span class="sp">verb</span> <span class="vs">aphel</span> <span class="vt">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">CJN></span> <span class="lexeme_etcbc">CJN></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܠܐ </div>
# <div class="features"> <span class="word_etcbc">>L></span> <span class="lexeme_etcbc">>L></span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܚܪܒܐ </div>
# <div class="features"> <span class="word_etcbc">XRB></span> <span class="lexeme_etcbc">XRB></span> <span class="sp">noun</span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>2</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/syrnt/blob/master/plain/0.1/Matthew.txt" title="show this passage in the SyrNT source" sec="Matthew 10:34">Matthew 10:34</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܠܐ </div>
# <div class="features"> <span class="word_etcbc">L></span> <span class="lexeme_etcbc">L></span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܬܣܒܪܘܢ </div>
# <div class="features"> <span class="word_etcbc">TSBRWN</span> <span class="lexeme_etcbc">SBR</span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܐܬܝܬ </div>
# <div class="features"> <span class="word_etcbc">D>TJT</span> <span class="lexeme_etcbc">>T></span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܐܪܡܐ </div>
# <div class="features"> <span class="word_etcbc">D>RM></span> <span class="lexeme_etcbc">RM></span> <span class="sp">verb</span> <span class="vs">aphel</span> <span class="vt">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">CJN></span> <span class="lexeme_etcbc">CJN></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܐܪܥܐ </div>
# <div class="features"> <span class="word_etcbc">B>R&lt;></span> <span class="lexeme_etcbc">>R&lt;></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܐ </div>
# <div class="features"> <span class="word_etcbc">L></span> <span class="lexeme_etcbc">L></span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܬܝܬ </div>
# <div class="features"> <span class="word_etcbc">>TJT</span> <span class="lexeme_etcbc">>T></span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܐܪܡܐ </div>
# <div class="features"> <span class="word_etcbc">D>RM></span> <span class="lexeme_etcbc">RM></span> <span class="sp">verb</span> <span class="vs">aphel</span> <span class="vt">imperfect</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">CJN></span> <span class="lexeme_etcbc">CJN></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܠܐ </div>
# <div class="features"> <span class="word_etcbc">>L></span> <span class="lexeme_etcbc">>L></span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܚܪܒܐ </div>
# <div class="features"> <span class="word_etcbc">XRB></span> <span class="lexeme_etcbc">XRB></span> <span class="sp">noun</span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>3</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/syrnt/blob/master/plain/0.1/Mark.txt" title="show this passage in the SyrNT source" sec="Mark 9:50">Mark 9:50</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܫܦܝܪܐ </div>
# <div class="features"> <span class="word_etcbc">CPJR></span> <span class="lexeme_etcbc">CPJR></span> <span class="sp">adjective</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܗܝ </div>
# <div class="features"> <span class="word_etcbc">HJ</span> <span class="lexeme_etcbc">HW</span> <span class="sp">pronoun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܠܚܐ </div>
# <div class="features"> <span class="word_etcbc">MLX></span> <span class="lexeme_etcbc">MLX></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܢ </div>
# <div class="features"> <span class="word_etcbc">>N</span> <span class="lexeme_etcbc">>N</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܝܢ </div>
# <div class="features"> <span class="word_etcbc">DJN</span> <span class="lexeme_etcbc">DJN</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܠܚܐ </div>
# <div class="features"> <span class="word_etcbc">MLX></span> <span class="lexeme_etcbc">MLX></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܬܦܟܗ </div>
# <div class="features"> <span class="word_etcbc">TPKH</span> <span class="lexeme_etcbc">PKH</span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܡܢܐ </div>
# <div class="features"> <span class="word_etcbc">BMN></span> <span class="lexeme_etcbc">MN></span> <span class="sp">pronoun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܬܬܡܠܚ </div>
# <div class="features"> <span class="word_etcbc">TTMLX</span> <span class="lexeme_etcbc">MLX</span> <span class="sp">verb</span> <span class="vs">ethpeal</span> <span class="vt">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܬܗܘܐ </div>
# <div class="features"> <span class="word_etcbc">THW></span> <span class="lexeme_etcbc">HW></span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܟܘܢ </div>
# <div class="features"> <span class="word_etcbc">BKWN</span> <span class="lexeme_etcbc">B</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܠܚܐ </div>
# <div class="features"> <span class="word_etcbc">MLX></span> <span class="lexeme_etcbc">MLX></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܘܒܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">WBCJN></span> <span class="lexeme_etcbc">CJN></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܗܘܘ </div>
# <div class="features"> <span class="word_etcbc">HWW</span> <span class="lexeme_etcbc">HW></span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܚܕ </div>
# <div class="features"> <span class="word_etcbc">XD</span> <span class="lexeme_etcbc">XD</span> <span class="sp">numeral</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܥܡ </div>
# <div class="features"> <span class="word_etcbc">&lt;M</span> <span class="lexeme_etcbc">&lt;M</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܚܕ </div>
# <div class="features"> <span class="word_etcbc">XD</span> <span class="lexeme_etcbc">XD</span> <span class="sp">numeral</span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>4</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/syrnt/blob/master/plain/0.1/Luke.txt" title="show this passage in the SyrNT source" sec="Luke 11:21">Luke 11:21</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܐܡܬܝ </div>
# <div class="features"> <span class="word_etcbc">>MTJ</span> <span class="lexeme_etcbc">>MTJ</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܚܣܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">DXSJN></span> <span class="lexeme_etcbc">XSJN></span> <span class="sp">adjective</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܟܕ </div>
# <div class="features"> <span class="word_etcbc">KD</span> <span class="lexeme_etcbc">KD</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܙܝܢ </div>
# <div class="features"> <span class="word_etcbc">MZJN</span> <span class="lexeme_etcbc">ZN</span> <span class="sp">verb</span> <span class="vs">pael</span> <span class="vt">participle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܢܛܪ </div>
# <div class="features"> <span class="word_etcbc">NVR</span> <span class="lexeme_etcbc">NVR</span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܪܬܗ </div>
# <div class="features"> <span class="word_etcbc">DRTH</span> <span class="lexeme_etcbc">DRT></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܒܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">BCJN></span> <span class="lexeme_etcbc">CJN></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܗܘ </div>
# <div class="features"> <span class="word_etcbc">HW</span> <span class="lexeme_etcbc">HW</span> <span class="sp">pronoun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܩܢܝܢܗ </div>
# <div class="features"> <span class="word_etcbc">QNJNH</span> <span class="lexeme_etcbc">QNJN></span> <span class="sp">noun</span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>5</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/syrnt/blob/master/plain/0.1/Luke.txt" title="show this passage in the SyrNT source" sec="Luke 12:51">Luke 12:51</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܣܒܪܝܢ </div>
# <div class="features"> <span class="word_etcbc">SBRJN</span> <span class="lexeme_etcbc">SBR</span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">participle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܢܬܘܢ </div>
# <div class="features"> <span class="word_etcbc">>NTWN</span> <span class="lexeme_etcbc">>NT</span> <span class="sp">pronoun</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܕܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">DCJN></span> <span class="lexeme_etcbc">CJN></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܬܝܬ </div>
# <div class="features"> <span class="word_etcbc">>TJT</span> <span class="lexeme_etcbc">>T></span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܐܪܡܐ </div>
# <div class="features"> <span class="word_etcbc">D>RM></span> <span class="lexeme_etcbc">RM></span> <span class="sp">verb</span> <span class="vs">aphel</span> <span class="vt">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܐܪܥܐ </div>
# <div class="features"> <span class="word_etcbc">B>R&lt;></span> <span class="lexeme_etcbc">>R&lt;></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܡܪ </div>
# <div class="features"> <span class="word_etcbc">>MR</span> <span class="lexeme_etcbc">>MR</span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">participle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܢܐ </div>
# <div class="features"> <span class="word_etcbc">>N></span> <span class="lexeme_etcbc">>N></span> <span class="sp">pronoun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܟܘܢ </div>
# <div class="features"> <span class="word_etcbc">LKWN</span> <span class="lexeme_etcbc">L</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܠܐ </div>
# <div class="features"> <span class="word_etcbc">DL></span> <span class="lexeme_etcbc">L></span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܠܐ </div>
# <div class="features"> <span class="word_etcbc">>L></span> <span class="lexeme_etcbc">>L></span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܦܠܓܘܬܐ </div>
# <div class="features"> <span class="word_etcbc">PLGWT></span> <span class="lexeme_etcbc">PLGWT></span> <span class="sp">noun</span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>6</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/syrnt/blob/master/plain/0.1/Acts.txt" title="show this passage in the SyrNT source" sec="Acts 10:36">Acts 10:36</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܡܠܬܐ </div>
# <div class="features"> <span class="word_etcbc">MLT></span> <span class="lexeme_etcbc">MLT></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܓܝܪ </div>
# <div class="features"> <span class="word_etcbc">GJR</span> <span class="lexeme_etcbc">GJR</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܫܕܪ </div>
# <div class="features"> <span class="word_etcbc">DCDR</span> <span class="lexeme_etcbc">CDR</span> <span class="sp">verb</span> <span class="vs">pael</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܒܢܝ </div>
# <div class="features"> <span class="word_etcbc">LBNJ</span> <span class="lexeme_etcbc">BR></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܝܣܪܝܠ </div>
# <div class="features"> <span class="word_etcbc">>JSRJL</span> <span class="lexeme_etcbc">>JSR>JL</span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܣܒܪ </div>
# <div class="features"> <span class="word_etcbc">WSBR</span> <span class="lexeme_etcbc">SBR</span> <span class="sp">verb</span> <span class="vs">pael</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܢܘܢ </div>
# <div class="features"> <span class="word_etcbc">>NWN</span> <span class="lexeme_etcbc">HW</span> <span class="sp">pronoun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܫܠܡܐ </div>
# <div class="features"> <span class="word_etcbc">CLM></span> <span class="lexeme_etcbc">CLM></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܘܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">WCJN></span> <span class="lexeme_etcbc">CJN></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܝܕ </div>
# <div class="features"> <span class="word_etcbc">BJD</span> <span class="lexeme_etcbc">>JD></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܝܫܘܥ </div>
# <div class="features"> <span class="word_etcbc">JCW&lt;</span> <span class="lexeme_etcbc">JCW&lt;</span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܫܝܚܐ </div>
# <div class="features"> <span class="word_etcbc">MCJX></span> <span class="lexeme_etcbc">MCJX></span> <span class="sp">verb</span> <span class="vs">peal</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܗܢܘ </div>
# <div class="features"> <span class="word_etcbc">HNW</span> <span class="lexeme_etcbc">HNW</span> <span class="sp">pronoun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܪܝܐ </div>
# <div class="features"> <span class="word_etcbc">MRJ></span> <span class="lexeme_etcbc">MRJ></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܟܠ </div>
# <div class="features"> <span class="word_etcbc">DKL</span> <span class="lexeme_etcbc">KL</span> <span class="sp">particle</span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>7</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/syrnt/blob/master/plain/0.1/Acts.txt" title="show this passage in the SyrNT source" sec="Acts 12:20">Acts 12:20</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܘܡܛܠ </div>
# <div class="features"> <span class="word_etcbc">WMVL</span> <span class="lexeme_etcbc">MVL</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܪܓܝܙ </div>
# <div class="features"> <span class="word_etcbc">DRGJZ</span> <span class="lexeme_etcbc">RGZ</span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">participle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܗܘܐ </div>
# <div class="features"> <span class="word_etcbc">HW></span> <span class="lexeme_etcbc">HW></span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܥܠ </div>
# <div class="features"> <span class="word_etcbc">&lt;L</span> <span class="lexeme_etcbc">&lt;L</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܨܘܪܝܐ </div>
# <div class="features"> <span class="word_etcbc">YWRJ></span> <span class="lexeme_etcbc">YWRJ></span> <span class="sp">adjective</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܥܠ </div>
# <div class="features"> <span class="word_etcbc">W&lt;L</span> <span class="lexeme_etcbc">&lt;L</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܨܝܕܢܝܐ </div>
# <div class="features"> <span class="word_etcbc">YJDNJ></span> <span class="lexeme_etcbc">YJDNJ></span> <span class="sp">adjective</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܬܟܢܫܘ </div>
# <div class="features"> <span class="word_etcbc">>TKNCW</span> <span class="lexeme_etcbc">KNC</span> <span class="sp">verb</span> <span class="vs">ethpael</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܐܬܘ </div>
# <div class="features"> <span class="word_etcbc">W>TW</span> <span class="lexeme_etcbc">>T></span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܘܬܗ </div>
# <div class="features"> <span class="word_etcbc">LWTH</span> <span class="lexeme_etcbc">LWT</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܟܚܕܐ </div>
# <div class="features"> <span class="word_etcbc">>KXD></span> <span class="lexeme_etcbc">>KXD></span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܐܦܝܣܘ </div>
# <div class="features"> <span class="word_etcbc">W>PJSW</span> <span class="lexeme_etcbc">PJS</span> <span class="sp">verb</span> <span class="vs">aphel</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܒܠܣܛܘܣ </div>
# <div class="features"> <span class="word_etcbc">LBLSVWS</span> <span class="lexeme_etcbc">BLSVWS</span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܩܝܛܘܢܩܢܗ </div>
# <div class="features"> <span class="word_etcbc">QJVWNQNH</span> <span class="lexeme_etcbc">QJVWNQN></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܡܠܟܐ </div>
# <div class="features"> <span class="word_etcbc">DMLK></span> <span class="lexeme_etcbc">MLK></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܫܐܠܘ </div>
# <div class="features"> <span class="word_etcbc">WC>LW</span> <span class="lexeme_etcbc">C>L</span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܢܗ </div>
# <div class="features"> <span class="word_etcbc">MNH</span> <span class="lexeme_etcbc">MN</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܢܗܘܐ </div>
# <div class="features"> <span class="word_etcbc">DNHW></span> <span class="lexeme_etcbc">HW></span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܗܘܢ </div>
# <div class="features"> <span class="word_etcbc">LHWN</span> <span class="lexeme_etcbc">L</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">CJN></span> <span class="lexeme_etcbc">CJN></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܛܠ </div>
# <div class="features"> <span class="word_etcbc">MVL</span> <span class="lexeme_etcbc">MVL</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܦܘܪܢܣܐ </div>
# <div class="features"> <span class="word_etcbc">DPWRNS></span> <span class="lexeme_etcbc">PWRNS></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܐܬܪܗܘܢ </div>
# <div class="features"> <span class="word_etcbc">D>TRHWN</span> <span class="lexeme_etcbc">>TR></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܢ </div>
# <div class="features"> <span class="word_etcbc">MN</span> <span class="lexeme_etcbc">MN</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܠܟܘܬܗ </div>
# <div class="features"> <span class="word_etcbc">MLKWTH</span> <span class="lexeme_etcbc">MLKWT></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܗܘܐ </div>
# <div class="features"> <span class="word_etcbc">HW></span> <span class="lexeme_etcbc">HW></span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܗܪܘܕܣ </div>
# <div class="features"> <span class="word_etcbc">DHRWDS</span> <span class="lexeme_etcbc">HRWDS</span> <span class="sp">noun</span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>8</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/syrnt/blob/master/plain/0.1/Acts.txt" title="show this passage in the SyrNT source" sec="Acts 24:2">Acts 24:2</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܘܟܕ </div>
# <div class="features"> <span class="word_etcbc">WKD</span> <span class="lexeme_etcbc">KD</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܬܩܪܝ </div>
# <div class="features"> <span class="word_etcbc">>TQRJ</span> <span class="lexeme_etcbc">QR></span> <span class="sp">verb</span> <span class="vs">ethpeal</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܩܦ </div>
# <div class="features"> <span class="word_etcbc">>QP</span> <span class="lexeme_etcbc">NQP</span> <span class="sp">verb</span> <span class="vs">aphel</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܗܘܐ </div>
# <div class="features"> <span class="word_etcbc">HW></span> <span class="lexeme_etcbc">HW></span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܛܪܛܠܘܣ </div>
# <div class="features"> <span class="word_etcbc">VRVLWS</span> <span class="lexeme_etcbc">VRVLWS</span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܩܛܪܓ </div>
# <div class="features"> <span class="word_etcbc">MQVRG</span> <span class="lexeme_etcbc">QVRG</span> <span class="sp">verb</span> <span class="vs">palpel</span> <span class="vt">participle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܗ </div>
# <div class="features"> <span class="word_etcbc">LH</span> <span class="lexeme_etcbc">L</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܐܡܪ </div>
# <div class="features"> <span class="word_etcbc">W>MR</span> <span class="lexeme_etcbc">>MR</span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">participle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܣܘܓܐܐ </div>
# <div class="features"> <span class="word_etcbc">BSWG>></span> <span class="lexeme_etcbc">SWG>></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܕܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">DCJN></span> <span class="lexeme_etcbc">CJN></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܥܡܪܝܢܢ </div>
# <div class="features"> <span class="word_etcbc">&lt;MRJNN</span> <span class="lexeme_etcbc">&lt;MR</span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">participle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܛܠܬܟ </div>
# <div class="features"> <span class="word_etcbc">MVLTK</span> <span class="lexeme_etcbc">MVL</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܬܩܢܬܐ </div>
# <div class="features"> <span class="word_etcbc">WTQNT></span> <span class="lexeme_etcbc">TQN></span> <span class="sp">adjective</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܣܓܝܐܬܐ </div>
# <div class="features"> <span class="word_etcbc">SGJ>T></span> <span class="lexeme_etcbc">SGJ>></span> <span class="sp">adjective</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܗܘܝ </div>
# <div class="features"> <span class="word_etcbc">HWJ</span> <span class="lexeme_etcbc">HW></span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܥܡܐ </div>
# <div class="features"> <span class="word_etcbc">L&lt;M></span> <span class="lexeme_etcbc">&lt;M></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܗܢܐ </div>
# <div class="features"> <span class="word_etcbc">HN></span> <span class="lexeme_etcbc">HN></span> <span class="sp">pronoun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܫܩܠ </div>
# <div class="features"> <span class="word_etcbc">BCQL</span> <span class="lexeme_etcbc">CQL></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܛܥܢܟ </div>
# <div class="features"> <span class="word_etcbc">V&lt;NK</span> <span class="lexeme_etcbc">V&lt;N></span> <span class="sp">noun</span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>9</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/syrnt/blob/master/plain/0.1/Romans.txt" title="show this passage in the SyrNT source" sec="Romans 1:31">Romans 1:31</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܘܕܩܝܡܐ </div>
# <div class="features"> <span class="word_etcbc">WDQJM></span> <span class="lexeme_etcbc">QJM></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܝܬ </div>
# <div class="features"> <span class="word_etcbc">LJT</span> <span class="lexeme_etcbc">LJT</span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܗܘܢ </div>
# <div class="features"> <span class="word_etcbc">LHWN</span> <span class="lexeme_etcbc">L</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܠܐ </div>
# <div class="features"> <span class="word_etcbc">WL></span> <span class="lexeme_etcbc">L></span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܚܘܒܐ </div>
# <div class="features"> <span class="word_etcbc">XWB></span> <span class="lexeme_etcbc">XWB></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܠܐ </div>
# <div class="features"> <span class="word_etcbc">WL></span> <span class="lexeme_etcbc">L></span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">CJN></span> <span class="lexeme_etcbc">CJN></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܠܐ </div>
# <div class="features"> <span class="word_etcbc">WL></span> <span class="lexeme_etcbc">L></span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܪܚܡܐ </div>
# <div class="features"> <span class="word_etcbc">RXM></span> <span class="lexeme_etcbc">RXM></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܝܬ </div>
# <div class="features"> <span class="word_etcbc">>JT</span> <span class="lexeme_etcbc">>JT</span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܗܘܢ </div>
# <div class="features"> <span class="word_etcbc">BHWN</span> <span class="lexeme_etcbc">B</span> <span class="sp">particle</span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>10</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/syrnt/blob/master/plain/0.1/2_Corinthians.txt" title="show this passage in the SyrNT source" sec="2_Corinthians 13:11">2_Corinthians 13:11</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܡܟܝܠ </div>
# <div class="features"> <span class="word_etcbc">MKJL</span> <span class="lexeme_etcbc">MKJL</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܚܝ </div>
# <div class="features"> <span class="word_etcbc">>XJ</span> <span class="lexeme_etcbc">>X></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܚܕܘ </div>
# <div class="features"> <span class="word_etcbc">XDW</span> <span class="lexeme_etcbc">XDJ</span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">imperative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܐܬܓܡܪܘ </div>
# <div class="features"> <span class="word_etcbc">W>TGMRW</span> <span class="lexeme_etcbc">GMR</span> <span class="sp">verb</span> <span class="vs">ethpeal</span> <span class="vt">imperative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܐܬܒܝܐܘ </div>
# <div class="features"> <span class="word_etcbc">W>TBJ>W</span> <span class="lexeme_etcbc">BJ></span> <span class="sp">verb</span> <span class="vs">ethpael</span> <span class="vt">imperative</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܐܘܝܘܬܐ </div>
# <div class="features"> <span class="word_etcbc">W>WJWT></span> <span class="lexeme_etcbc">>WJWT></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܘܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">WCJN></span> <span class="lexeme_etcbc">CJN></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܢܗܘܐ </div>
# <div class="features"> <span class="word_etcbc">NHW></span> <span class="lexeme_etcbc">HW></span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܟܘܢ </div>
# <div class="features"> <span class="word_etcbc">BKWN</span> <span class="lexeme_etcbc">B</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܐܠܗܐ </div>
# <div class="features"> <span class="word_etcbc">W>LH></span> <span class="lexeme_etcbc">>LH></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܚܘܒܐ </div>
# <div class="features"> <span class="word_etcbc">DXWB></span> <span class="lexeme_etcbc">XWB></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܕܫܠܡܘܬܐ </div>
# <div class="features"> <span class="word_etcbc">WDCLMWT></span> <span class="lexeme_etcbc">CLMWT></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܢܗܘܐ </div>
# <div class="features"> <span class="word_etcbc">NHW></span> <span class="lexeme_etcbc">HW></span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܥܡܟܘܢ </div>
# <div class="features"> <span class="word_etcbc">&lt;MKWN</span> <span class="lexeme_etcbc">&lt;M</span> <span class="sp">particle</span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>11</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/syrnt/blob/master/plain/0.1/Ephesians.txt" title="show this passage in the SyrNT source" sec="Ephesians 2:14">Ephesians 2:14</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܗܘܝܘ </div>
# <div class="features"> <span class="word_etcbc">HWJW</span> <span class="lexeme_etcbc">HWJW</span> <span class="sp">pronoun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܓܝܪ </div>
# <div class="features"> <span class="word_etcbc">GJR</span> <span class="lexeme_etcbc">GJR</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܫܝܢܢ </div>
# <div class="features"> <span class="word_etcbc">CJNN</span> <span class="lexeme_etcbc">CJN></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܗܘ </div>
# <div class="features"> <span class="word_etcbc">HW</span> <span class="lexeme_etcbc">HW</span> <span class="sp">pronoun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܥܒܕ </div>
# <div class="features"> <span class="word_etcbc">D&lt;BD</span> <span class="lexeme_etcbc">&lt;BD</span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܬܪܬܝܗܝܢ </div>
# <div class="features"> <span class="word_etcbc">TRTJHJN</span> <span class="lexeme_etcbc">TRJN</span> <span class="sp">numeral</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܚܕܐ </div>
# <div class="features"> <span class="word_etcbc">XD></span> <span class="lexeme_etcbc">XD</span> <span class="sp">numeral</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܫܪܐ </div>
# <div class="features"> <span class="word_etcbc">WCR></span> <span class="lexeme_etcbc">CR></span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܣܝܓܐ </div>
# <div class="features"> <span class="word_etcbc">SJG></span> <span class="lexeme_etcbc">SJG></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܩܐܡ </div>
# <div class="features"> <span class="word_etcbc">DQ>M</span> <span class="lexeme_etcbc">QM</span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">participle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܗܘܐ </div>
# <div class="features"> <span class="word_etcbc">HW></span> <span class="lexeme_etcbc">HW></span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܡܨܥܬܐ </div>
# <div class="features"> <span class="word_etcbc">BMY&lt;T></span> <span class="lexeme_etcbc">MY&lt;T></span> <span class="sp">noun</span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>12</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/syrnt/blob/master/plain/0.1/Ephesians.txt" title="show this passage in the SyrNT source" sec="Ephesians 2:15">Ephesians 2:15</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܘܒܥܠܕܒܒܘܬܐ </div>
# <div class="features"> <span class="word_etcbc">WB&lt;LDBBWT></span> <span class="lexeme_etcbc">B&lt;LDBBWT></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܒܣܪܗ </div>
# <div class="features"> <span class="word_etcbc">BBSRH</span> <span class="lexeme_etcbc">BSR></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܢܡܘܣܐ </div>
# <div class="features"> <span class="word_etcbc">WNMWS></span> <span class="lexeme_etcbc">NMWS></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܦܘܩܕܐ </div>
# <div class="features"> <span class="word_etcbc">DPWQD></span> <span class="lexeme_etcbc">PWQD></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܦܘܩܕܢܘܗܝ </div>
# <div class="features"> <span class="word_etcbc">BPWQDNWHJ</span> <span class="lexeme_etcbc">PWQDN></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܛܠ </div>
# <div class="features"> <span class="word_etcbc">BVL</span> <span class="lexeme_etcbc">BVL</span> <span class="sp">verb</span> <span class="vs">pael</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܠܬܪܝܗܘܢ </div>
# <div class="features"> <span class="word_etcbc">DLTRJHWN</span> <span class="lexeme_etcbc">TRJN</span> <span class="sp">numeral</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܢܒܪܐ </div>
# <div class="features"> <span class="word_etcbc">NBR></span> <span class="lexeme_etcbc">BR></span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܩܢܘܡܗ </div>
# <div class="features"> <span class="word_etcbc">BQNWMH</span> <span class="lexeme_etcbc">QNWM></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܚܕ </div>
# <div class="features"> <span class="word_etcbc">LXD</span> <span class="lexeme_etcbc">XD</span> <span class="sp">numeral</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܪܢܫܐ </div>
# <div class="features"> <span class="word_etcbc">BRNC></span> <span class="lexeme_etcbc">BRNC></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܚܕܬܐ </div>
# <div class="features"> <span class="word_etcbc">XDT></span> <span class="lexeme_etcbc">XDT></span> <span class="sp">adjective</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܥܒܕ </div>
# <div class="features"> <span class="word_etcbc">W&lt;BD</span> <span class="lexeme_etcbc">&lt;BD</span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">perfect</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">CJN></span> <span class="lexeme_etcbc">CJN></span> <span class="sp">noun</span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>13</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/syrnt/blob/master/plain/0.1/1_Thessalonians.txt" title="show this passage in the SyrNT source" sec="1_Thessalonians 5:3">1_Thessalonians 5:3</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܟܕ </div>
# <div class="features"> <span class="word_etcbc">KD</span> <span class="lexeme_etcbc">KD</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܢܐܡܪܘܢ </div>
# <div class="features"> <span class="word_etcbc">N>MRWN</span> <span class="lexeme_etcbc">>MR</span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܫܠܡܐ </div>
# <div class="features"> <span class="word_etcbc">DCLM></span> <span class="lexeme_etcbc">CLM></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܗܘ </div>
# <div class="features"> <span class="word_etcbc">HW</span> <span class="lexeme_etcbc">HW</span> <span class="sp">pronoun</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܘܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">WCJN></span> <span class="lexeme_etcbc">CJN></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܗܝܕܝܢ </div>
# <div class="features"> <span class="word_etcbc">WHJDJN</span> <span class="lexeme_etcbc">HJDJN</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܢܫܠܝܐ </div>
# <div class="features"> <span class="word_etcbc">MNCLJ></span> <span class="lexeme_etcbc">MNCLJ></span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܢܩܘܡ </div>
# <div class="features"> <span class="word_etcbc">NQWM</span> <span class="lexeme_etcbc">QM</span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">imperfect</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܥܠܝܗܘܢ </div>
# <div class="features"> <span class="word_etcbc">&lt;LJHWN</span> <span class="lexeme_etcbc">&lt;L</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܒܕܢܐ </div>
# <div class="features"> <span class="word_etcbc">>BDN></span> <span class="lexeme_etcbc">>BDN></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܝܟ </div>
# <div class="features"> <span class="word_etcbc">>JK</span> <span class="lexeme_etcbc">>JK</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܚܒܠܐ </div>
# <div class="features"> <span class="word_etcbc">XBL></span> <span class="lexeme_etcbc">XBL></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܥܠ </div>
# <div class="features"> <span class="word_etcbc">&lt;L</span> <span class="lexeme_etcbc">&lt;L</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܛܢܬܐ </div>
# <div class="features"> <span class="word_etcbc">BVNT></span> <span class="lexeme_etcbc">BVNT></span> <span class="sp">adjective</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܠܐ </div>
# <div class="features"> <span class="word_etcbc">WL></span> <span class="lexeme_etcbc">L></span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܢܡܕܘܢ </div>
# <div class="features"> <span class="word_etcbc">NMDWN</span> <span class="lexeme_etcbc">MD</span> <span class="sp">verb</span> <span class="vs">aphel</span> <span class="vt">imperfect</span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>14</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/syrnt/blob/master/plain/0.1/James.txt" title="show this passage in the SyrNT source" sec="James 3:18">James 3:18</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܦܐܪܐ </div>
# <div class="features"> <span class="word_etcbc">P>R></span> <span class="lexeme_etcbc">P>R></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܝܢ </div>
# <div class="features"> <span class="word_etcbc">DJN</span> <span class="lexeme_etcbc">DJN</span> <span class="sp">particle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܙܕܝܩܘܬܐ </div>
# <div class="features"> <span class="word_etcbc">DZDJQWT></span> <span class="lexeme_etcbc">ZDJQWT></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܒܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">BCJN></span> <span class="lexeme_etcbc">CJN></span> <span class="sp">noun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܙܕܪܥܝܢ </div>
# <div class="features"> <span class="word_etcbc">MZDR&lt;JN</span> <span class="lexeme_etcbc">ZR&lt;</span> <span class="sp">verb</span> <span class="vs">ethpeal</span> <span class="vt">participle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܐܝܠܝܢ </div>
# <div class="features"> <span class="word_etcbc">L>JLJN</span> <span class="lexeme_etcbc">>JN></span> <span class="sp">pronoun</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܥܒܕܝܢ </div>
# <div class="features"> <span class="word_etcbc">D&lt;BDJN</span> <span class="lexeme_etcbc">&lt;BD</span> <span class="sp">verb</span> <span class="vs">peal</span> <span class="vt">participle</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܫܠܡܐ </div>
# <div class="features"> <span class="word_etcbc">CLM></span> <span class="lexeme_etcbc">CLM></span> <span class="sp">noun</span></div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# For the OT, we do not have the lexeme value, so we try looking for word forms that *match* `CJN>` rather than those that are exactly equal to it.
#
# Note that we have replaced '=' by '~' in the query below

# %%
queryP = '''
word word_etcbc~CJN>
'''

# %%
resultsP = A[P].search(queryP)
# Out:
#   0.46s 130 results

# %%
# We show only 20 results

A[P].show(resultsP, end=20)
# Out:
# <p><b>result</b> <i>1</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Genesis" title="show this passage in the Peshitta source" sec="Genesis 49:24">Genesis 49:24</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܘܗܦ̣ܟܬ </div>
# <div class="features"> <span class="word_etcbc">WHP#KT</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܥܘܫܢܐ </div>
# <div class="features"> <span class="word_etcbc">B&lt;WCN></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܩܫܬܗ. </div>
# <div class="features"> <span class="word_etcbc">QCTH</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܐ̣ܬܒܕܪܘ </div>
# <div class="features"> <span class="word_etcbc">W>#TBDRW</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܪ̈ܥܐ </div>
# <div class="features"> <span class="word_etcbc">DR"&lt;></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܐ̈ܝܕܘܗܝ. </div>
# <div class="features"> <span class="word_etcbc">D>"JDWHJ</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܢ </div>
# <div class="features"> <span class="word_etcbc">MN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐ̈ܝܕܝ </div>
# <div class="features"> <span class="word_etcbc">>"JDJ</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܥܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">&lt;CJN></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܝܥܩܘܒ. </div>
# <div class="features"> <span class="word_etcbc">DJ&lt;QWB</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܡܢ </div>
# <div class="features"> <span class="word_etcbc">WMN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܫܡ </div>
# <div class="features"> <span class="word_etcbc">CM</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܪܥܝܐ </div>
# <div class="features"> <span class="word_etcbc">R&lt;J></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܟܐܦܐ </div>
# <div class="features"> <span class="word_etcbc">DK>P></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܐܝܣܪܝܠ. </div>
# <div class="features"> <span class="word_etcbc">D>JSRJL</span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>2</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Genesis" title="show this passage in the Peshitta source" sec="Genesis 50:9">Genesis 50:9</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܘܣܠܩܘ </div>
# <div class="features"> <span class="word_etcbc">WSLQW</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܥܡܗ </div>
# <div class="features"> <span class="word_etcbc">&lt;MH</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܦ </div>
# <div class="features"> <span class="word_etcbc">>P</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܪ̈ܟܒܬܐ </div>
# <div class="features"> <span class="word_etcbc">MR"KBT></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܦܪ̈ܫܐ  . </div>
# <div class="features"> <span class="word_etcbc">WPR"C></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܗܘܬ </div>
# <div class="features"> <span class="word_etcbc">WHWT</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܫܪܝܬܐ </div>
# <div class="features"> <span class="word_etcbc">MCRJT></span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܕܥܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">D&lt;CJN></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܛܒ. </div>
# <div class="features"> <span class="word_etcbc">VB</span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>3</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Numbers" title="show this passage in the Peshitta source" sec="Numbers 20:20">Numbers 20:20</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܘܐܡܪ </div>
# <div class="features"> <span class="word_etcbc">W>MR</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܕܘܡ </div>
# <div class="features"> <span class="word_etcbc">>DWM</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܐ </div>
# <div class="features"> <span class="word_etcbc">L></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܬܥܒܪܘܢ. </div>
# <div class="features"> <span class="word_etcbc">T&lt;BRWN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܢܦܩ </div>
# <div class="features"> <span class="word_etcbc">WNPQ</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܕܘܡ </div>
# <div class="features"> <span class="word_etcbc">>DWM</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܐܘܪܥܗܘܢ </div>
# <div class="features"> <span class="word_etcbc">L>WR&lt;HWN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܥܡܐ </div>
# <div class="features"> <span class="word_etcbc">B&lt;M></span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܥܫܝܢܐ. </div>
# <div class="features"> <span class="word_etcbc">&lt;CJN></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܒܐܝܕܐ </div>
# <div class="features"> <span class="word_etcbc">WB>JD></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܬܩܝܦܬܐ. </div>
# <div class="features"> <span class="word_etcbc">TQJPT></span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>4</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Deuteronomy" title="show this passage in the Peshitta source" sec="Deuteronomy 26:5">Deuteronomy 26:5</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܘܥܢܝ </div>
# <div class="features"> <span class="word_etcbc">W&lt;NJ</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܐܡܪ </div>
# <div class="features"> <span class="word_etcbc">W>MR</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܩܕܡ </div>
# <div class="features"> <span class="word_etcbc">QDM</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܪܝܐ </div>
# <div class="features"> <span class="word_etcbc">MRJ></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܠܗܟ. </div>
# <div class="features"> <span class="word_etcbc">>LHK</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܐܪܡ </div>
# <div class="features"> <span class="word_etcbc">L>RM</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܬܕܒܪ </div>
# <div class="features"> <span class="word_etcbc">>TDBR</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܒܝ </div>
# <div class="features"> <span class="word_etcbc">>BJ</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܢܚܬ </div>
# <div class="features"> <span class="word_etcbc">WNXT</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܡܨܪܝܢ. </div>
# <div class="features"> <span class="word_etcbc">LMYRJN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܥܡܪ </div>
# <div class="features"> <span class="word_etcbc">W&lt;MR</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܬܡܢ </div>
# <div class="features"> <span class="word_etcbc">TMN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܙܒܢܐ </div>
# <div class="features"> <span class="word_etcbc">ZBN></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܙܥܘܪܐ. </div>
# <div class="features"> <span class="word_etcbc">Z&lt;WR></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܗܘܐ </div>
# <div class="features"> <span class="word_etcbc">WHW></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܬܡܢ </div>
# <div class="features"> <span class="word_etcbc">TMN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܥܡܐ </div>
# <div class="features"> <span class="word_etcbc">L&lt;M></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܪܒܐ </div>
# <div class="features"> <span class="word_etcbc">RB></span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܘܥܫܝܢܐ. </div>
# <div class="features"> <span class="word_etcbc">W&lt;CJN></span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>5</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Job" title="show this passage in the Peshitta source" sec="Job 5:15">Job 5:15</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܦ̇ܪܩ </div>
# <div class="features"> <span class="word_etcbc">P^RQ</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܢ </div>
# <div class="features"> <span class="word_etcbc">MN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܚܪܒܐ </div>
# <div class="features"> <span class="word_etcbc">XRB></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܢ </div>
# <div class="features"> <span class="word_etcbc">MN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܦܘܡܗܘܢ </div>
# <div class="features"> <span class="word_etcbc">PWMHWN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܡܢ </div>
# <div class="features"> <span class="word_etcbc">WMN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܝܕܐ </div>
# <div class="features"> <span class="word_etcbc">>JD></span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܕܥܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">D&lt;CJN></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܡܣ̈ܟܢܐ </div>
# <div class="features"> <span class="word_etcbc">LMS"KN></span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>6</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Job" title="show this passage in the Peshitta source" sec="Job 14:18">Job 14:18</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܫܪܝܪܐܝܬ </div>
# <div class="features"> <span class="word_etcbc">CRJR>JT</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܛܘܪܐ </div>
# <div class="features"> <span class="word_etcbc">VWR></span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܥܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">&lt;CJN></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܢ̇ܦܠ </div>
# <div class="features"> <span class="word_etcbc">N^PL</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܘ </div>
# <div class="features"> <span class="word_etcbc">>W</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܫܩܝܦܐ </div>
# <div class="features"> <span class="word_etcbc">CQJP></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܬܬܙܝܥ </div>
# <div class="features"> <span class="word_etcbc">MTTZJ&lt;</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܢ </div>
# <div class="features"> <span class="word_etcbc">MN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܘܟܬܗ </div>
# <div class="features"> <span class="word_etcbc">DWKTH</span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>7</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Job" title="show this passage in the Peshitta source" sec="Job 24:22">Job 24:22</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܘܩܢܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">WQNJN></span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܕܥܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">D&lt;CJN></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܚܝܠܗ </div>
# <div class="features"> <span class="word_etcbc">BXJLH</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܢܩܘܡ </div>
# <div class="features"> <span class="word_etcbc">NQWM</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܠܐ </div>
# <div class="features"> <span class="word_etcbc">WL></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܢܗܝܡܢ </div>
# <div class="features"> <span class="word_etcbc">NHJMN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܚܙܘܐ </div>
# <div class="features"> <span class="word_etcbc">BXZW></span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>8</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Job" title="show this passage in the Peshitta source" sec="Job 36:5">Job 36:5</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܗܐ </div>
# <div class="features"> <span class="word_etcbc">H></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܠܗܐ </div>
# <div class="features"> <span class="word_etcbc">>LH></span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܥܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">&lt;CJN></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܐ </div>
# <div class="features"> <span class="word_etcbc">L></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܣܠܐ </div>
# <div class="features"> <span class="word_etcbc">MSL></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܐܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">L>JN></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܕܟܐ </div>
# <div class="features"> <span class="word_etcbc">DDK></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܝܟ </div>
# <div class="features"> <span class="word_etcbc">>JK</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܚܠܒܐ </div>
# <div class="features"> <span class="word_etcbc">XLB></span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>9</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Judges" title="show this passage in the Peshitta source" sec="Judges 9:51">Judges 9:51</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܘܡܓܕܠܐ </div>
# <div class="features"> <span class="word_etcbc">WMGDL></span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܥܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">&lt;CJN></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܗܘܐ </div>
# <div class="features"> <span class="word_etcbc">HW></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܓܘܗ̇ </div>
# <div class="features"> <span class="word_etcbc">BGWH^</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܩܪܝܬܐ </div>
# <div class="features"> <span class="word_etcbc">DQRJT></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܥܪܩܘ </div>
# <div class="features"> <span class="word_etcbc">W&lt;RQW</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܬܡܢ </div>
# <div class="features"> <span class="word_etcbc">LTMN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܟܠܗܘܢ </div>
# <div class="features"> <span class="word_etcbc">KLHWN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܓܒܪ̈ܐ </div>
# <div class="features"> <span class="word_etcbc">GBR"></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܢܫ̈ܐ </div>
# <div class="features"> <span class="word_etcbc">WNC"></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܟܠܗܘܢ </div>
# <div class="features"> <span class="word_etcbc">WKLHWN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܪ̈ܝܗ </div>
# <div class="features"> <span class="word_etcbc">MR"JH</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܩܪܝܬܐ </div>
# <div class="features"> <span class="word_etcbc">DQRJT></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܐܚܕܘ </div>
# <div class="features"> <span class="word_etcbc">W>XDW</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܐ̈ܦܝܗܘܢ </div>
# <div class="features"> <span class="word_etcbc">B>"PJHWN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܣܠܩܘ </div>
# <div class="features"> <span class="word_etcbc">WSLQW</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܐܓܪܐ </div>
# <div class="features"> <span class="word_etcbc">L>GR></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܡܓܕܠܐ </div>
# <div class="features"> <span class="word_etcbc">DMGDL></span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>10</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Samuel_1" title="show this passage in the Peshitta source" sec="Samuel_1 4:8">Samuel_1 4:8</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܘܝ </div>
# <div class="features"> <span class="word_etcbc">WJ</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܢ </div>
# <div class="features"> <span class="word_etcbc">LN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܢܘ </div>
# <div class="features"> <span class="word_etcbc">MNW</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܢܦܨܝܢ </div>
# <div class="features"> <span class="word_etcbc">NPYJN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܢ </div>
# <div class="features"> <span class="word_etcbc">MN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐ̈ܝܕܝ </div>
# <div class="features"> <span class="word_etcbc">>"JDJ</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܠܗܐ </div>
# <div class="features"> <span class="word_etcbc">>LH></span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܥܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">&lt;CJN></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܗܢܘ </div>
# <div class="features"> <span class="word_etcbc">HNW</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܠܗܐ </div>
# <div class="features"> <span class="word_etcbc">>LH></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܡܚܐ </div>
# <div class="features"> <span class="word_etcbc">DMX></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܟܠܗ̇ </div>
# <div class="features"> <span class="word_etcbc">LKLH^</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܨܪܝܢ </div>
# <div class="features"> <span class="word_etcbc">MYRJN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܟܘܠ </div>
# <div class="features"> <span class="word_etcbc">BKWL</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܚ̈ܘܢ </div>
# <div class="features"> <span class="word_etcbc">MX"WN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܡܕܒܪܐ </div>
# <div class="features"> <span class="word_etcbc">BMDBR></span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>11</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Samuel_1" title="show this passage in the Peshitta source" sec="Samuel_1 14:52">Samuel_1 14:52</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܘܗܘܐ </div>
# <div class="features"> <span class="word_etcbc">WHW></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܩܪܒܐ </div>
# <div class="features"> <span class="word_etcbc">QRB></span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܥܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">&lt;CJN></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܥܡ </div>
# <div class="features"> <span class="word_etcbc">&lt;M</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܦܠܫ̈ܬܝܐ </div>
# <div class="features"> <span class="word_etcbc">PLC"TJ></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܟܠܗܘܢ </div>
# <div class="features"> <span class="word_etcbc">KLHWN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܝܘܡ̈ܬܗ </div>
# <div class="features"> <span class="word_etcbc">JWM"TH</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܫܐܘܠ </div>
# <div class="features"> <span class="word_etcbc">DC>WL</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܚܙܐ </div>
# <div class="features"> <span class="word_etcbc">WXZ></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܗܘܐ </div>
# <div class="features"> <span class="word_etcbc">HW></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܫܐܘܠ </div>
# <div class="features"> <span class="word_etcbc">C>WL</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܟܠ </div>
# <div class="features"> <span class="word_etcbc">KL</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܓܒܪܐ </div>
# <div class="features"> <span class="word_etcbc">GBR></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܓܢܒܪ </div>
# <div class="features"> <span class="word_etcbc">DGNBR</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܟܠ </div>
# <div class="features"> <span class="word_etcbc">WKL</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܓܒܪܐ </div>
# <div class="features"> <span class="word_etcbc">GBR></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܐܝܬ </div>
# <div class="features"> <span class="word_etcbc">D>JT</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܗ </div>
# <div class="features"> <span class="word_etcbc">BH</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܚܝܠܐ </div>
# <div class="features"> <span class="word_etcbc">XJL></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܟܢܫ </div>
# <div class="features"> <span class="word_etcbc">WKNC</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܗܘܐ </div>
# <div class="features"> <span class="word_etcbc">HW></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܗ </div>
# <div class="features"> <span class="word_etcbc">LH</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܘܬܗ </div>
# <div class="features"> <span class="word_etcbc">LWTH</span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>12</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Samuel_1" title="show this passage in the Peshitta source" sec="Samuel_1 21:8">Samuel_1 21:8</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܘܬܡܢ </div>
# <div class="features"> <span class="word_etcbc">WTMN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܓܒܪܐ </div>
# <div class="features"> <span class="word_etcbc">GBR></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܢ </div>
# <div class="features"> <span class="word_etcbc">MN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܥܒ̈ܕܐ </div>
# <div class="features"> <span class="word_etcbc">&lt;B"D></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܫܐܘܠ </div>
# <div class="features"> <span class="word_etcbc">DC>WL</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܝܘܡܐ </div>
# <div class="features"> <span class="word_etcbc">BJWM></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܗ̇ܘ </div>
# <div class="features"> <span class="word_etcbc">H^W</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܟܠܐ </div>
# <div class="features"> <span class="word_etcbc">KL></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܩܕܡ </div>
# <div class="features"> <span class="word_etcbc">QDM</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܪܝܐ </div>
# <div class="features"> <span class="word_etcbc">MRJ></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܫܡܗ </div>
# <div class="features"> <span class="word_etcbc">WCMH</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܘܐܓ </div>
# <div class="features"> <span class="word_etcbc">DW>G</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܪܘܡܝܐ </div>
# <div class="features"> <span class="word_etcbc">>RWMJ></span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܥܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">&lt;CJN></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܪ̈ܥܘܬܐ </div>
# <div class="features"> <span class="word_etcbc">DR"&lt;WT></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕ </div>
# <div class="features"> <span class="word_etcbc">D</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܫܐܘܠ </div>
# <div class="features"> <span class="word_etcbc">C>WL</span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>13</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Psalms" title="show this passage in the Peshitta source" sec="Psalms 24:8">Psalms 24:8</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܡܢܘ </div>
# <div class="features"> <span class="word_etcbc">MNW</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܗܢܐ </div>
# <div class="features"> <span class="word_etcbc">HN></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܠܟܐ </div>
# <div class="features"> <span class="word_etcbc">MLK></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܐܝܩܪ̈ܐ </div>
# <div class="features"> <span class="word_etcbc">D>JQR"></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܪܝܐ </div>
# <div class="features"> <span class="word_etcbc">MRJ></span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܥܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">&lt;CJN></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܓܢܒܪܐ </div>
# <div class="features"> <span class="word_etcbc">WGNBR></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܪܝܐ </div>
# <div class="features"> <span class="word_etcbc">MRJ></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܓܢܒܪܐ </div>
# <div class="features"> <span class="word_etcbc">GNBR></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܩܪܒܬܢܐ </div>
# <div class="features"> <span class="word_etcbc">WQRBTN></span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>14</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Psalms" title="show this passage in the Peshitta source" sec="Psalms 42:5">Psalms 42:5</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܗܠܝܢ </div>
# <div class="features"> <span class="word_etcbc">HLJN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܬܕܟܪܬ </div>
# <div class="features"> <span class="word_etcbc">>TDKRT</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܐܬܛܪܦܬ </div>
# <div class="features"> <span class="word_etcbc">W>TVRPT</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܢܦܫܝ </div>
# <div class="features"> <span class="word_etcbc">NPCJ</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܛܠ </div>
# <div class="features"> <span class="word_etcbc">MVL</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܐܥܒܪ </div>
# <div class="features"> <span class="word_etcbc">D>&lt;BR</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܣܬܪܟ </div>
# <div class="features"> <span class="word_etcbc">BSTRK</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܥܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">&lt;CJN></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܥܕܡܐ </div>
# <div class="features"> <span class="word_etcbc">&lt;DM></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܒܝܬܗ </div>
# <div class="features"> <span class="word_etcbc">LBJTH</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܐܠܗܐ </div>
# <div class="features"> <span class="word_etcbc">D>LH></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܩܠܐ </div>
# <div class="features"> <span class="word_etcbc">BQL></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܬܫܒܘܚܬܐ </div>
# <div class="features"> <span class="word_etcbc">DTCBWXT></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܕܬܘܕܝܬܐ </div>
# <div class="features"> <span class="word_etcbc">WDTWDJT></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܣ̈ܓܝܐܐ </div>
# <div class="features"> <span class="word_etcbc">S"GJ>></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܚܕܝܢ </div>
# <div class="features"> <span class="word_etcbc">XDJN</span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>15</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Psalms" title="show this passage in the Peshitta source" sec="Psalms 46:2">Psalms 46:2</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܐܠܗܢ </div>
# <div class="features"> <span class="word_etcbc">>LHN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܝܬ </div>
# <div class="features"> <span class="word_etcbc">BJT</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܓܘܣܢ </div>
# <div class="features"> <span class="word_etcbc">GWSN</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܥܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">&lt;CJN></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܡܥܕܪܢܢ </div>
# <div class="features"> <span class="word_etcbc">WM&lt;DRNN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܙܒ̈ܢܐ </div>
# <div class="features"> <span class="word_etcbc">BZB"N></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܐܘܠܨܢܐ. </div>
# <div class="features"> <span class="word_etcbc">D>WLYN></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܫܬܟܚܬ </div>
# <div class="features"> <span class="word_etcbc">>CTKXT</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܢ </div>
# <div class="features"> <span class="word_etcbc">LN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܟܠܙܒܢ </div>
# <div class="features"> <span class="word_etcbc">BKLZBN</span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>16</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Psalms" title="show this passage in the Peshitta source" sec="Psalms 68:34">Psalms 68:34</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܕܪܟܝܒ </div>
# <div class="features"> <span class="word_etcbc">DRKJB</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܒܫ̈ܡܝ </div>
# <div class="features"> <span class="word_etcbc">BC"MJ</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܫܡܝܐ </div>
# <div class="features"> <span class="word_etcbc">CMJ></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܢ </div>
# <div class="features"> <span class="word_etcbc">MN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܕܢܚܐ </div>
# <div class="features"> <span class="word_etcbc">MDNX></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܝܗܒ </div>
# <div class="features"> <span class="word_etcbc">JHB</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܩܠܗ </div>
# <div class="features"> <span class="word_etcbc">QLH</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܩܠܐ </div>
# <div class="features"> <span class="word_etcbc">QL></span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܥܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">&lt;CJN></span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>17</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Psalms" title="show this passage in the Peshitta source" sec="Psalms 71:7">Psalms 71:7</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܘܕܘܡܪܐ </div>
# <div class="features"> <span class="word_etcbc">WDWMR></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܗܘܝܬ </div>
# <div class="features"> <span class="word_etcbc">HWJT</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܣ̈ܓܝܐܐ </div>
# <div class="features"> <span class="word_etcbc">LS"GJ>></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܐܢܬ </div>
# <div class="features"> <span class="word_etcbc">D>NT</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܗܘ </div>
# <div class="features"> <span class="word_etcbc">HW</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܬܘܟܠܢܝ </div>
# <div class="features"> <span class="word_etcbc">TWKLNJ</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܥܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">&lt;CJN></span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>18</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Psalms" title="show this passage in the Peshitta source" sec="Psalms 74:14">Psalms 74:14</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܐܢܬ </div>
# <div class="features"> <span class="word_etcbc">>NT</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܪܨܨܬ </div>
# <div class="features"> <span class="word_etcbc">RYYT</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܪ̈ܝܫܘܗܝ </div>
# <div class="features"> <span class="word_etcbc">R"JCWHJ</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܕܠܘܝܬܢ </div>
# <div class="features"> <span class="word_etcbc">DLWJTN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܝܗܒܬܝܗܝ </div>
# <div class="features"> <span class="word_etcbc">WJHBTJHJ</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܐܟܘܠܬܐ </div>
# <div class="features"> <span class="word_etcbc">M>KWLT></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܠܥܡܐ </div>
# <div class="features"> <span class="word_etcbc">L&lt;M></span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܥܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">&lt;CJN></span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>19</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Psalms" title="show this passage in the Peshitta source" sec="Psalms 76:5">Psalms 76:5</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܢܗܝܪ </div>
# <div class="features"> <span class="word_etcbc">NHJR</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܢܬ </div>
# <div class="features"> <span class="word_etcbc">>NT</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܘܡܫܝܚ </div>
# <div class="features"> <span class="word_etcbc">WMCJX</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܢ </div>
# <div class="features"> <span class="word_etcbc">MN</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܛܘܪܟ </div>
# <div class="features"> <span class="word_etcbc">VWRK</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܥܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">&lt;CJN></span></div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>20</i></p>
# <div class="verse  " >
#
#     <div class="vl">
#         <div class="vrs"><a href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Psalms" title="show this passage in the Peshitta source" sec="Psalms 89:9">Psalms 89:9</a></div>
#
#         <div class="features"></div>
#     </div>
#
# <div class="word  " >
# <div class="sy">ܡܪܝܐ </div>
# <div class="features"> <span class="word_etcbc">MRJ></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܠܗܐ </div>
# <div class="features"> <span class="word_etcbc">>LH></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܚܝܠܬܢܐ </div>
# <div class="features"> <span class="word_etcbc">XJLTN></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܡܢܘ </div>
# <div class="features"> <span class="word_etcbc">MNW</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܐܟܘܬܟ </div>
# <div class="features"> <span class="word_etcbc">>KWTK</span></div>
#
#
# </div>
#
# <div class="word  hl" >
# <div class="sy">ܥܫܝܢܐ </div>
# <div class="features"> <span class="word_etcbc">&lt;CJN></span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܗܝܡܢܘܬܟ </div>
# <div class="features"> <span class="word_etcbc">HJMNWTK</span></div>
#
#
# </div>
#
# <div class="word  " >
# <div class="sy">ܚܕܪ̈ܝܟ </div>
# <div class="features"> <span class="word_etcbc">XDR"JK</span></div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# Here ends the bootcamp session.
#
# Interested? Send [me](mailto:dirk.roorda@dans.knaw.nl) a note.
