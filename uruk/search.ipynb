# %% [markdown]
# <img align="right" src="images/ninologo.png" width="150"/>
# <img align="right" src="images/tf-small.png" width="125"/>
# <img align="right" src="images/dans.png" width="150"/>
#
# # Search
#
# Search is essential to get around in the corpus, and it is convenient as well.
# Whereas the whole point of Text-Fabric is to move around in the corpus programmatically,
# we show that
# [template based search](https://annotation.github.io/text-fabric/Use/Search/#search-templates)
# makes everything a lot more convenient ...
#
# Along with showing how search works, we also point to pretty ways to display your search results.
# The good news is that `search` and `pretty` work well together.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys, os
import collections
from IPython.display import display, Markdown
from tf.app import use

# %%
# A = use('uruk', hoist=globals())
A = use('uruk:clone', checkout="clone", hoist=globals())
# Out:
# Using TF-app in /Users/dirk/github/annotation/app-uruk/code:
# 	repo clone offline under ~/github (local github)
# Using data in /Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0:
# 	repo clone offline under ~/github (local github)
#    |     0.00s No structure info in otext, the structure part of the T-API cannot be used
# <b>Documentation:</b> <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs/" title="provenance of Uruk IV/III: Proto-cuneiform tablets ">URUK</a> <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs/transcription.md" title="How TF features represent ATF">Character table</a> <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="URUK feature documentation">Feature docs</a> <a target="_blank" href="https://github.com/annotation/app-uruk" title="uruk API documentation">uruk API</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/" title="text-fabric-api">Text-Fabric API 7.11.1</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Use/Search/" title="Search Templates Introduction and Reference">Search Reference</a><details open><summary><b>Loaded features</b>:</summary>
# <p><b>Uruk IV/III: Proto-cuneiform tablets </b>: <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0/catalogId.tf">catalogId</a>  <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0/crossref.tf">crossref</a>  <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0/damage.tf">damage</a>  <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0/depth.tf">depth</a>  <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0/excavation.tf">excavation</a>  <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0/fragment.tf">fragment</a>  <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0/fullNumber.tf">fullNumber</a>  <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0/grapheme.tf">grapheme</a>  <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0/identifier.tf">identifier</a>  <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0/modifier.tf">modifier</a>  <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0/modifierFirst.tf">modifierFirst</a>  <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0/modifierInner.tf">modifierInner</a>  <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0/name.tf">name</a>  <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0/number.tf">number</a>  <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0/otype.tf">otype</a>  <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0/period.tf">period</a>  <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0/prime.tf">prime</a>  <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0/remarkable.tf">remarkable</a>  <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0/repeat.tf">repeat</a>  <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0/srcLn.tf">srcLn</a>  <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0/srcLnNum.tf">srcLnNum</a>  <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/master/docs//transcription.md" title="/Users/dirk/github/Nino-cunei/uruk/tf/uruk/1.0/terminal.tf">terminal</a>  <a target="_blank" href="https://github.com/Nino-cunei/uruk/blob/ma ...
# <style>.features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .pnum {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .outerplain {
# }
# .verse {
#     display: flex;
#     flex-flow: row wrap;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     width: 100%;
# }
# .vn {
#   font-size: small !important;
#   padding-right: 1em;
# }
# .vrs {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .meta {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: row nowrap;
# }
# .features,.comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .children {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     border: 0;
#     background-color: #ffffff;
# }
# .children.tablet,.children.face {
#     flex-flow: row nowrap;
# }
# .children.column {
#     align-items: stretch;
#     flex-flow: column nowrap;
# }
# .children.line,.children.case {
#     align-items: stretch;
#     flex-flow: row nowrap;
# }
# .children.caseh,.children.trminalh {
#     flex-flow: row nowrap;
# }
# .children.casev,.children.trminalv {
#     flex-flow: column nowrap;
# }
# .children.trminal {
#     flex-flow: row nowrap;
# }
# .children.cluster {
#     flex-flow: row wrap;
# }
# .children.quad {
#     flex-flow: row wrap;
# }
# .children.sign {
#     flex-flow: column nowrap;
# }
# .contnr {
#     width: fit-content;
# }
# .contnr.tablet,.contnr.face,.contnr.column,
# .contnr.line,.contnr.case,.contnr.trminal,
# .contnr.comment,
# .contnr.cluster,
# .contnr.quad,.contnr.sign {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5em 0.1em 0.1em 0.1em;
#     margin: 0.8em 0.1em 0.1em 0.1em;
#     border-radius: 0.1rem;
#     border-style: solid;
#     border-width: 0.1rem;
#     font-size: small;
# }
# .contnr.tablet,.contnr.face,.contnr.column {
#     border-color: #bb9966;
# }
# .contnr.line,.contnr.case,.contnr.trminal {
#     border-color: #6699bb;
# }
# .contnr.cluster {
#     flex-flow: row wrap;
#     border: 0;
# }
# .contnr.sign,.contnr.quad {
#     border-color: #bbbbbb;
# }
# .contnr.comment {
#     background-color: #eeccbb;
#     border: 0.2em solid #eecc99;
#     border-radius: 0.1rem;
# }
# .contnr.hl {
#     background-color: #ffee66;
# }
# .lbl.tablet,.lbl.face,.lbl.column,
# .lbl.line,.lbl.case,.lbl.trminal,
# .lbl.comment,
# .lbl.cluster,
# .lbl.quad,.lbl.sign {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     font-size: small;
#     color: #0000cc;
#     display: block;
# }
# .lbl.tablet,.lbl.face,.lbl.column {
#     border-color: #bb9966;
#     border-width: 0.1rem;
#     border-radius: 0.1rem;
#     color: #bb8800;
# }
# .lbl.line,.lbl.case,.lbl.trminal {
#     border-color: #6699bb;
#     border-width: 0.1rem;
#     border-radius: 0.1rem;
#     color: #0088bb;
# }
# .lbl.comment {
#     border-color: #eecc99;
#     border-width: 0.1rem;
#     border-radius: 0.1rem;
#     color: #eecc99;
#     background-color: #ffddaa none repeat scroll 0 0;
# }
# .lbl.clusterb,.lbl.clustere {
#     padding:  0.5em 0.1em 0.1em 0.1em;
#     margin: 0.8em 0.1em 0.1em 0.1em;
#     color: #888844;
#     font-size: x-small;
# }
# .lbl.clusterb {
#     border-left: 0.3em solid #cccc99;
#     border-right: 0;
#     border-top: 0;
#     border-bottom: 0;
#     border-radius: 1rem;
# }
# .lbl.clustere {
#     border-left: 0;
#     border-right: 0.3em solid #cccc99;
#     border-top: 0;
#     border-bottom: 0;
#     border-radius: 1rem;
# }
# .lbl.quad {
#     border-color: #bbbbbb;
#     border-width: 0.1rem;
#     border-radius: 0.1rem;
#     font-family: monospace;
#     font-size: medium;
#     color: #444444;
# }
# .lbl.sign {
#     border-color: #dddddd;
#     border-width: 0.1rem;
#     border-radius: 0.1rem;
#     font-family: monospace;
#     font-size: medium;
#     color: #000000;
# }
# .op {
#     padding:  0.5em 0.1em 0.1em 0.1em;
#     margin: 0.8em 0.1em 0.1em 0.1em;
#     font-family: monospace;
#     font-size: x-large;
#     font-weight: bold;
# }
# .name {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .period {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .excavation {
#     font-family: monospace;
#     font-size: medium;
#     font-style: italic;
#     color: #779900;
# }
# .text {
#     font-family: sans-serif;
#     font-size: x-small;
#     color: #000000;
# }
# .srcln {
#     font-family: monospace;
#     font-size: medium;
#     color: #000000;
# }
# .srclnnum {
#     font-family: monospace;
#     font-size: x-small;
#     color: #0000bb;
# }
#
#
# tr.tf, td.tf, th.tf {
#   text-align: left ! important;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlbx {
# 	border-color: var(--hl-dark);
# 	border-width: 0.2rem;
# 	border-style: solid;
# 	border-radius: 0.3rem;
#   padding: 0.2rem;
#   margin: 0.2rem;
# }
#
# span.plain {
#   display: inline-block;
#   white-space: pre-wrap;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>
# <details open><summary><b>API members</b>:</summary>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">C Computed</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Call AllComputeds</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Cs ComputedString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">E Edge</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Eall AllEdges</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Es EdgeString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ensureLoaded</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">TF</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ignored</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">loadLog</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Locality/#locality" title="doc">L Locality</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">cache</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">error</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">indent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">info</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">isSilent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">reset</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">setSilent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">silentOff</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">silentOn</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">warning</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">N Nodes</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKey</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKeyTuple</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">otypeRank</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortNodes</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">F Feature</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fall AllFeatures</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fs FeatureString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Search/#search" title="doc">S Search</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Text/#text" title="doc">T Text</a></details>
# Using data in /Users/dirk/github/Nino-cunei/uruk/sources/cdli/images:
# 	repo clone offline under ~/github (local github)
# Found 2095 ideograph linearts
# Found 2724 tablet linearts
# Found 5495 tablet photos

# %% [markdown]
# # The basics
#
# Here is a very simple query: we look for tablets containing a numeral sign.

# %%
query = '''
tablet
  sign type=numeral
'''

results = A.search(query)
# Out:
#   0.28s 38122 results

# %% [markdown]
# We can display the results in a table (here are the first 5):

# %%
A.table(results, end=5, condenseType="line")
# Out:
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">tablet</th><th class="tf">sign</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006427" title="to CDLI main page for this tablet" sec="P006427">P006427</a></td><td class="tf"><span class="plain outer  " >tablet P006427</span></td><td class="tf"><span class="plain outer  hl" >3(N14)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006428" title="to CDLI main page for this tablet" sec="P006428">P006428</a></td><td class="tf"><span class="plain outer  " >tablet P006428</span></td><td class="tf"><span class="plain outer  hl" >3(N14)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006428" title="to CDLI main page for this tablet" sec="P006428">P006428</a></td><td class="tf"><span class="plain outer  " >tablet P006428</span></td><td class="tf"><span class="plain outer  hl" >1(N14)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006428" title="to CDLI main page for this tablet" sec="P006428">P006428</a></td><td class="tf"><span class="plain outer  " >tablet P006428</span></td><td class="tf"><span class="plain outer  hl" >1(N01)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006428" title="to CDLI main page for this tablet" sec="P006428">P006428</a></td><td class="tf"><span class="plain outer  " >tablet P006428</span></td><td class="tf"><span class="plain outer  hl" >1(N57)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N57).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n57).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td></tr></table>

# %% [markdown]
# We can combine all results that are on the same tablet:

# %%
A.table(results, condensed=True, condenseType='line', end=5)
# Out:
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">line</th><th class="tf">sign</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006427" title="to CDLI main page for this tablet" sec="P006427">P006427</a></td><td class="tf"><span class="plain outer  " >1. <span class="plain hl" >3(N14)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a><span class="plain " >X</span>  <span class="plain " >SANGA~a</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SANGA~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sanga-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a><span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span>  </span></span></td><td class="tf"><span class="plain outer  hl" >3(N14)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006428" title="to CDLI main page for this tablet" sec="P006428">P006428</a></td><td class="tf"><span class="plain outer  " >2. <span class="plain hl" >3(N14)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a><span class="plain " >X</span>  </span></span></td><td class="tf"><span class="plain outer  hl" >3(N14)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006428" title="to CDLI main page for this tablet" sec="P006428">P006428</a></td><td class="tf"><span class="plain outer  " >3. <span class="plain hl" >1(N14)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a><span class="plain " >SUHUR</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SUHUR.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-suhur.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></span></span></td><td class="tf"><span class="plain outer  hl" >1(N14)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006428" title="to CDLI main page for this tablet" sec="P006428">P006428</a></td><td class="tf"><span class="plain outer  " >5. <span class="plain hl" >1(N01)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a><span class="plain " >|<span class="plain " >DUG~b</span>x<span class="plain hl" >1(N57)</span>|</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|DUG~bx1(N57)|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-qdug-bx1(n57)q.jpg" style="display: inline;max-width: 4em; max-height: 6em;"  /></a><span class="plain " >DUG~b</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/DUG~b.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-dug-b.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a><span class="plain hl" >1(N57)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N57).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n57).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></span></span></td><td class="tf"><span class="plain outer  hl" >1(N01)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td><td class="tf"><span class="plain outer  hl" >1(N57)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N57).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n57).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448701" title="to CDLI main page for this tablet" sec="P448701">P448701</a></td><td class="tf"><span class="plain outer  " >1. <span class="plain hl" >1(N46)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N46).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n46).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a><span class="plain hl" >2(N19)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n19).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a><span class="plain hl" >4(N41)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/4(N41).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-4(n41).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></span></span></td><td class="tf"><span class="plain outer  hl" >2(N19)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n19).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td><td class="tf"><span class="plain outer  hl" >4(N41)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/4(N41).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-4(n41).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td><td class="tf"><span class="plain outer  hl" >1(N46)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N46).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n46).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td></tr></table>

# %% [markdown]
# And we can show them inside the face they occur in:

# %%
A.show(results, condenseType='face', end=2)
# Out:
# <p><b>result</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006427" title="to CDLI main page for this tablet" sec="P006427">tablet P006427  <span class="name">Anonymous 006427</span> <span class="period">uruk-iii</span></a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span> <span class="type xft"><span class="f">type=</span>meta</span></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# </div>
# <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006427" title="to CDLI main page for this tablet" sec="P006427">P006427</a>
# <div class="contnr face " >
#     <div class="lbl face"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006427" title="to CDLI main page for this tablet" sec="P006427">face obverse</a> </div>
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>obverse</span></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"> <span class="type xft"><span class="f">type=</span>ellipsis</span></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"> <span class="type xft"><span class="f">type=</span>unknown</span></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"> <span class="type xft"><span class="f">type=</span>unknown</span></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">3(N14)</span><div class="features"> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"> <span class="type xft"><span class="f">type=</span>unknown</span></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SANGA~a</span><div class="features"> <span class="type xft"><span class="f">type=</span>ideograph</span></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SANGA~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sanga-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"> <span class="type xft"><span class="f">type=</span>ellipsis</span></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div></div></div>
# <p><b>result</b> <i>2</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006428" title="to CDLI main page for this tablet" sec="P006428">tablet P006428  <span class="name">Anonymous 006428</span> <span class="period">uruk-iii</span></a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span> <span class="type xft"><span class="f">type=</span>meta</span></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# </div>
# <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006428" title="to CDLI main page for this tablet" sec="P006428">P006428</a>
# <div class="contnr face " >
#     <div class="lbl face"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006428" title="to CDLI main page for this tablet" sec="P006428">face obverse</a> </div>
#     <div class="meta">
#         <div class="features"> <span class="type xft"><span class="f">type=</span>obverse</span></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"> <span class="type xft"><span class="f">type=</span>unknown</span></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"> <span class="type xft"><span class="f">type=</span>unknown</span></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"> <span class="type xft"><span class="f">type=</span>unknown</span></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"> <span class="type xft"><span class="f">type=</span>unknown</span></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"> <span class="type xft"><span class="f">type=</span>unknown</span></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"> <span class="type xft"><span class="f">type=</span>unknown</span></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"> <span class="type xft"><span class="f">type=</span>unknown</span></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"> <span class="type xft"><span class="f">type=</span>unknown</span></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">3 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"> <span class="type xft"><span class="f">type=</span>unknown</span></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"> <span class="type xft"><span class="f">type=</span>unknown</span></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">3(N14)</span><div class="features"> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"> <span class="type xft"><span class="f">type=</span>unknown</span></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N14)</span><div class="features"> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SUHUR</span><div class="features"> <span class="type xft"><span class="f">type=</span>ideograph</span></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SUHUR.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-suhur.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">4 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"> <span class="type xft"><span class="f">type=</span>unknown</span></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"> <span class="type xft"><span class="f">type=</span>unknown</span></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">5 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|DUG~bx1(N57)|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-qdug-bx1(n57)q.jpg" style="display: inline;max-width: 4em; max-height: 6em;"  /></a></div><div class="children quad">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">DUG~b</span><div class="features"> <span c

# %% [markdown]
# The feature *type* is displayed because it occurs in the query.
# We can make the display a bit more compact by suppressing those features:

# %%
A.show(results, condenseType='face', end=2, showFeatures=False)
# Out:
# <p><b>result</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006427" title="to CDLI main page for this tablet" sec="P006427">tablet P006427 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# </div>
# <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006427" title="to CDLI main page for this tablet" sec="P006427">P006427</a>
# <div class="contnr face " >
#     <div class="lbl face"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006427" title="to CDLI main page for this tablet" sec="P006427">face obverse</a> </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">3(N14)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SANGA~a</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SANGA~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sanga-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div></div></div>
# <p><b>result</b> <i>2</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006428" title="to CDLI main page for this tablet" sec="P006428">tablet P006428 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# </div>
# <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006428" title="to CDLI main page for this tablet" sec="P006428">P006428</a>
# <div class="contnr face " >
#     <div class="lbl face"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006428" title="to CDLI main page for this tablet" sec="P006428">face obverse</a> </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">3 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">3(N14)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N14)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SUHUR</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SUHUR.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-suhur.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">4 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">5 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|DUG~bx1(N57)|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-qdug-bx1(n57)q.jpg" style="display: inline;max-width: 4em; max-height: 6em;"  /></a></div><div class="children quad">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">DUG~b</span><div class="features"></div>
#
#     </div>
# </div><div class="op">x</div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N57)</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">6 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">7 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </

# %% [markdown]
# ## Finding a tablet
#
# Suppose we have the *p-number* of a tablet.
# How do we find that tablet?
# Remembering from the feature docs that the p-numbers are stored in the feature
# `catalogId`, we can write a *search template*.

# %%
t = F.otype.s('tablet')[0]
A.plain(t)
# Out:
# <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006427" title="to CDLI main page for this tablet" sec="P006427">P006427</a>&nbsp;<span class="plain outer  " >tablet P006427</span>

# %%
query = '''
tablet catalogId=P005381
'''
results = A.search(query)
A.table(results)
# Out:
#   0.01s 1 result
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">tablet</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P005381" title="to CDLI main page for this tablet" sec="P005381">P005381</a></td><td class="tf"><span class="plain outer  " >tablet P005381</span></td></tr></table>

# %% [markdown]
# The function `A.table()` gives you a tabular overview of the results,
# with a link to the tablet on CDLI.
#
# But we can also get more information by using `A.show()`:

# %%
A.show(results)
# Out:
# <p><b>result</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P005381" title="to CDLI main page for this tablet" sec="P005381">tablet P005381  <span class="name">MSVO 3, 70</span> <span class="period">uruk-iii</span><div class="features"> <span class="catalogid xft"><span class="f">catalogId=</span>P005381</span></div></a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr line " >
#     <div class="lbl line">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1a </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">2(N14)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZE~a</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SZE~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sze-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SAL</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SAL.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sal.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">TUR3~a</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/TUR3~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-tur3-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NUN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nun-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">1b </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N19)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n19).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|GISZ.TE|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-qgisz(d)teq.jpg" style="display: inline;max-width: 4em; max-height: 6em;"  /></a></div><div class="children quad">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GISZ</span><div class="features"></div>
#
#     </div>
# </div><div class="op">.</div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">TE</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N14)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NAR</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NAR.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nar.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NUN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nun-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SIG7</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SIG7.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sig7.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">2(N04)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n04).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">PIRIG~b1</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/PIRIG~b1.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-pirig-b1.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SIG7</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SIG7.jpg" title="to higher resolution lineart on CDLI"><img src

# %% [markdown]
# Several things to note here
#
# * if you want to see the tablet on CDLI, you can click on the tablet header;
# * the display matches the layout on the tablet:
#   * faces and columns are delineated with red lines
#   * lines and cases are delineated with blue lines
#   * cases and subcases alternate their direction of division between horizontal and vertical:
#     lines are horizontally divided into cases, they are vertically divided into subcases, and they
#     in turn are horizontally divided in subsubcases, etc.
#   * quads and signs are delineated with grey lines
#   * clusters are delineated with brown lines (see further on)
#   * lineart is given for top-level signs and quads; those that are part of a bigger quad do not
#     get lineart;
#
# It is possible to switch off the lineart.

# %% [markdown]
# ## More info in the results
# You can show the line numbers that correspond to the ATF source files as well.
# Let us also switch off the lineart.

# %%
query = '''
tablet catalogId=P005381
'''
results = A.search(query)
A.table(results, lineNumbers=True)
A.show(results, lineNumbers=True, lineart=False)
# Out:
#   0.01s 1 result
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">tablet</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P005381" title="to CDLI main page for this tablet" sec="P005381">P005381</a></td><td class="tf"> @&P005381 = MSVO 3, 70 <span class="plain outer  " >tablet P005381</span></td></tr></table>
# <p><b>result</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P005381" title="to CDLI main page for this tablet" sec="P005381">tablet P005381  <span class="name">MSVO 3, 70</span> <span class="period">uruk-iii</span><div class="features"> <span class="catalogid xft"><span class="f">catalogId=</span>P005381</span></div></a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr line " >
#     <div class="lbl line">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1a </div>
#     <div class="meta">
#         <div class="features"> <span class="srclnnum">85116</span></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">2(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZE~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SAL</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">TUR3~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">1b </div>
#     <div class="meta">
#         <div class="features"> <span class="srclnnum">85117</span></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N19)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GISZ</span><div class="features"></div>
#
#     </div>
# </div><div class="op">.</div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">TE</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"> <span class="srclnnum">85118</span></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NAR</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SIG7</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"> <span class="srclnnum">85119</span></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">2(N04)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">PIRIG~b1</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SIG7</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">URI3~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"> <span class="srclnnum">85121</span></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N04)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GISZ</span><div class="features"></div>
#
#     </div>
# </div><div class="op">.</div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">TE</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GAR</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZU2</span><div class="features"></div>
#
#     </div>
# </div><div class="op">.</div>
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">HI</span><div class="features"></div>
#
#     </div>
# </div><div class="op">+</div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N57)</span><div class="features"></div>
#
#     </div>
# </div></div></div><div class="op">+</div>
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">HI</span><div class="features"></div>
#
#     </div>
# </div><div class="op">+</div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N57)</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GI4~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"> <span class="srclnnum">85122</span></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GU7</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="s

# %% [markdown]
# There is a big quad in `obverse:2 line 1`. We want to call up the lineart for it separately.
# First step: make the nodes visible.

# %%
query = '''
tablet catalogId=P005381
'''
results = A.search(query)
A.table(results, withNodes=True)
A.show(results, withNodes=True, lineart=False)
# Out:
#   0.01s 1 result
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">tablet</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P005381" title="to CDLI main page for this tablet" sec="P005381">P005381</a></td><td class="tf"><span class="plain outer  " >tablet P005381</span></td></tr></table>
# <p><b>result</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P005381" title="to CDLI main page for this tablet" sec="P005381">tablet P005381  <span class="name">MSVO 3, 70</span> <span class="period">uruk-iii</span><div class="features"> <span class="catalogid xft"><span class="f">catalogId=</span>P005381</span></div></a> <span class="nd">148166</span></div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta <span class="nd">178162</span></div>
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse <span class="nd">156932</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 <span class="nd">190362</span></div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr line " >
#     <div class="lbl line">1 <span class="nd">254173</span></div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1a <span class="nd">167736</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">106585</span></div>
#     <div class="meta">
#          <span class="srcln">2(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">106586</span></div>
#     <div class="meta">
#          <span class="srcln">SZE~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">106587</span></div>
#     <div class="meta">
#          <span class="srcln">SAL</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">106588</span></div>
#     <div class="meta">
#          <span class="srcln">TUR3~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">106589</span></div>
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">1b <span class="nd">167737</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">106590</span></div>
#     <div class="meta">
#          <span class="srcln">3(N19)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr quad " >
#     <div class="lbl quad"> <span class="nd">143013</span></div>
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">106591</span></div>
#     <div class="meta">
#          <span class="srcln">GISZ</span><div class="features"></div>
#
#     </div>
# </div><div class="op">.</div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">106592</span></div>
#     <div class="meta">
#          <span class="srcln">TE</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 <span class="nd">254174</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">106593</span></div>
#     <div class="meta">
#          <span class="srcln">1(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">106594</span></div>
#     <div class="meta">
#          <span class="srcln">NAR</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">106595</span></div>
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">106596</span></div>
#     <div class="meta">
#          <span class="srcln">SIG7</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 <span class="nd">254175</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">106597</span></div>
#     <div class="meta">
#          <span class="srcln">2(N04)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">106598</span></div>
#     <div class="meta">
#          <span class="srcln">PIRIG~b1</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">106599</span></div>
#     <div class="meta">
#          <span class="srcln">SIG7</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">106600</span></div>
#     <div class="meta">
#          <span class="srcln">URI3~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">106601</span></div>
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">2 <span class="nd">190363</span></div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 <span class="nd">254176</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">106602</span></div>
#     <div class="meta">
#          <span class="srcln">3(N04)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr quad " >
#     <div class="lbl quad"> <span class="nd">143014</span></div>
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">106603</span></div>
#     <div class="meta">
#          <span class="srcln">GISZ</span><div class="features"></div>
#
#     </div>
# </div><div class="op">.</div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">106604</span></div>
#     <div class="meta">
#          <span class="srcln">TE</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">106605</span></div>
#     <div class="meta">
#          <span class="srcln">GAR</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr quad " >
#     <div class="lbl quad"> <span class="nd">143015</span></div>
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">106606</span></div>
#     <div class="meta">
#          <span class="srcln">SZU2</span><div class="features"></div>
#
#     </div>
# </div><div class="op">.</div>
# <div class="contnr quad " >
#     <div class="lbl qu

# %% [markdown]
# We read off the node number of that quad and fetch the lineart.

# %%
A.lineart(143015)
# Out:
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|SZU2.((HI+1(N57))+(HI+1(N57)))|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-qszu2(d)((hi(p)1(n57))(p)(hi(p)1(n57)))q.jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">|SZU2.((HI+1(N57))+(HI+1(N57)))|</a></div></div></div></div>

# %% [markdown]
# ## Search templates
# Let's highlight all numerals on the tablet.
#
# We prefer our results to be condensed per tablet for the next few shows.
#
# We make that the temporary default:

# %%
A.displaySetup(condensed=True)

# %%
query = '''
tablet catalogId=P005381
  sign type=numeral
'''
results = A.search(query)
A.show(results, showFeatures=False)
# Out:
#   0.18s 10 results
# <p><b>tablet</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P005381" title="to CDLI main page for this tablet" sec="P005381">tablet P005381 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr line " >
#     <div class="lbl line">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1a </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">2(N14)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZE~a</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SZE~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sze-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SAL</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SAL.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sal.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">TUR3~a</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/TUR3~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-tur3-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NUN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nun-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">1b </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">3(N19)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n19).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|GISZ.TE|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-qgisz(d)teq.jpg" style="display: inline;max-width: 4em; max-height: 6em;"  /></a></div><div class="children quad">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GISZ</span><div class="features"></div>
#
#     </div>
# </div><div class="op">.</div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">TE</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N14)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NAR</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NAR.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nar.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NUN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nun-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SIG7</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SIG7.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sig7.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">2(N04)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n04).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">PIRIG~b1</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/PIRIG~b1.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-pirig-b1.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SIG7</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SIG7.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sig7.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">URI3~a</span><d

# %% [markdown]
# We can do the same for multiple tablets. But now we highlight the undivided lines,
# just for variation.

# %%
query = f'''
tablet catalogId=P003581|P000311
  line terminal
'''
results = A.search(query)
# Out:
#   0.05s 11 results

# %%
A.table(results, lineart=False)
# Out:
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">tablet</th><th class="tf">line</th><th class="tf">line</th><th class="tf">line</th><th class="tf">line</th><th class="tf">line</th><th class="tf">line</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P000311" title="to CDLI main page for this tablet" sec="P000311">P000311</a></td><td class="tf"><span class="plain outer  " >tablet P000311</span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P000311" title="to CDLI main page for this tablet" sec="P000311">P000311</a></span>&nbsp;<span class="plain outer  hlbx" >1. <span class="plain " >[<span class="plain " >1(N01)</span>]</span><span class="plain " >1(N01)</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >IR~a</span> </span></span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P000311" title="to CDLI main page for this tablet" sec="P000311">P000311</a></span>&nbsp;<span class="plain outer  hlbx" >2. <span class="plain " >[<span class="plain " >1(N01)</span>]</span><span class="plain " >1(N01)</span> <span class="plain " >ERIM2</span> </span></span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P000311" title="to CDLI main page for this tablet" sec="P000311">P000311</a></span>&nbsp;<span class="plain outer  hlbx" >1. <span class="plain " >1(N01)</span> <span class="plain " >NIMGIR</span> <span class="plain " >SIG7</span> </span></span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P000311" title="to CDLI main page for this tablet" sec="P000311">P000311</a></span>&nbsp;<span class="plain outer  hlbx" >2. <span class="plain " >1(N01)</span> <span class="plain " >U2~b</span> <span class="plain " >NAGA~a</span> <span class="plain " >MUSZEN</span> <span class="plain " >ZATU647</span> <span class="plain " >BA</span> </span></span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P000311" title="to CDLI main page for this tablet" sec="P000311">P000311</a></span>&nbsp;<span class="plain outer  hlbx" >3. <span class="plain " ></span> <span class="plain " >1(N01)</span> <span class="plain " >IM~a</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> </span></span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P000311" title="to CDLI main page for this tablet" sec="P000311">P000311</a></span>&nbsp;<span class="plain outer  hlbx" >1. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> </span></span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003581" title="to CDLI main page for this tablet" sec="P003581">P003581</a></td><td class="tf"><span class="plain outer  " >tablet P003581</span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003581" title="to CDLI main page for this tablet" sec="P003581">P003581</a></span>&nbsp;<span class="plain outer  hlbx" >1. <span class="plain " >5(N01)</span> <span class="plain " >U2~a</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> </span></span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003581" title="to CDLI main page for this tablet" sec="P003581">P003581</a></span>&nbsp;<span class="plain outer  hlbx" >2. <span class="plain " >1(N01)</span> <span class="plain " >X</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> </span></span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003581" title="to CDLI main page for this tablet" sec="P003581">P003581</a></span>&nbsp;<span class="plain outer  hlbx" >2. <span class="plain " >1(N14)</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >SUHUR</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> </span></span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003581" title="to CDLI main page for this tablet" sec="P003581">P003581</a></span>&nbsp;<span class="plain outer  hlbx" >1. <span class="plain " >5(N14)</span> <span class="plain " >1(N01)</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >U2~a</span> </span></span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003581" title="to CDLI main page for this tablet" sec="P003581">P003581</a></span>&nbsp;<span class="plain outer  hlbx" >2. <span class="plain " >|<span class="plain " >GI</span>&<span class="plain " >GI</span>|</span> <span class="plain " >GI</span> <span class="plain " >GI</span> <span class="plain " >GU7</span> </span></span></td></tr></table>

# %%
A.show(results, lineart=False, condenseType="tablet")
# Out:
# <p><b>tablet</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P000311" title="to CDLI main page for this tablet" sec="P000311">tablet P000311  <span class="name">CDLI Lexical 000034, ex. 01</span> <span class="period">uruk-iii</span> <span class="excavation">W 20266,065</span><div class="features"> <span class="catalogid xft"><span class="f">catalogId=</span>P000311</span></div></a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">ruling </div>
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1' </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">ruling </div>
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children column">
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">1' </div>
#     <div class="meta">
#         <div class="features"> <span class="terminal xft"><span class="f">terminal=</span>1</span></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">IR~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2' </div>
#     <div class="meta">
#         <div class="features"> <span class="terminal xft"><span class="f">terminal=</span>1</span></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">ERIM2</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">2' </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">ruling </div>
#     <div class="meta">
#         <div class="features"> <span class="text">beginning broken</span></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children column">
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">1' </div>
#     <div class="meta">
#         <div class="features"> <span class="terminal xft"><span class="f">terminal=</span>1</span></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NIMGIR</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SIG7</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2' </div>
#     <div class="meta">
#         <div class="features"> <span class="terminal xft"><span class="f">terminal=</span>1</span></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">U2~b</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NAGA~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">MUSZEN</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">ZATU647</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">BA</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">3' </div>
#     <div class="meta">
#         <div class="features"> <span class="terminal xft"><span class="f">terminal=</span>1</span></div>
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">ruling </div>
#     <div class="meta">
#         <div class="features"> <span class="text">rest broken</span></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">IM~a</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div></div></div>
# <div class="contnr face " >
#     <div class="lbl face">reverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">0 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"> <span class="terminal xft"><span class="f">terminal=</span>1</span></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">N</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div></div></div></div></div>
# <p><b>tablet</b> <i>2</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003581" title="to CDLI main page for this tablet" sec="P003581">tablet P003581  <span class="name">W 20274,083</span> <span class="period">uruk-iii</span> <span class="excavation">W 20274,083</span><div class="features"> <span class="catalogid xft"><span class="f">catalogId=</span>P003581</span></div></a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"> <span class="terminal xft"><span class="f">terminal=</span>1</span></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">5(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">U2~a</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr line " >
#     <div class="lbl line">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1a </div>
#     <div class="meta">
#         <div class="features"> <span class="terminal xft"><span class="f">terminal=</span>1</span></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr case " >
#     <div class="lbl case">1b </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children casev">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1b1 </div>
#     <div class="meta">
#         <div class="features"> <span class="terminal xft"><span class="f">terminal=</span>1</span></div>
#
#     </div>
# <div class="children trminalh"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">1b2 </div>
#     <div class="meta">
#         <div class="features"> <span class="terminal xft"><span class="f">terminal=</span>1</span></div>
#
#     </div>
# <div class="children trminalh">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">I</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">BU3</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div></div></div>
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"> <span class="terminal xft"><span class="f">terminal=</span>1</span></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">3 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr line " >
#     <div class="lbl line">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1a </div>
#     <div class="meta">
#         <div class="features"> <span class="terminal xft"><span class="f">terminal=</span>1</span></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GA~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">AB2</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">1b </div>
#     <div class="meta">
#         <div class="features"> <span class="terminal xft"><span class="f">terminal=</span>1</span></div>
#
#     </div>
# <div class="children trminalv"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GI</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N57)</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"> <span class="terminal xft"><span class="f">terminal=</span>1</span></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N14)</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span clas

# %% [markdown]
# In an other chapter of this tutorial, [steps](steps.ipynb) we encounter a grapheme with a double prime.
# There is only one, and we showed the tablet on which it occurs, without highlighting the grapheme in question.
# Now we can do the highlight:

# %%
results = A.search('''
sign prime=2
''')
# Out:
#   0.15s 1 result

# %%
A.show(results, showFeatures=False)
# Out:
# <p><b>tablet</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P411604" title="to CDLI main page for this tablet" sec="P411604">tablet P411604 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">AN</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/AN.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-an.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NUNUZ~a1</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NUNUZ~a1.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nunuz-a1.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">ZATU788</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/ZATU788.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-zatu788.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N39~a)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N39~a).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n39-a).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">MUD</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/MUD.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-mud.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NA~a</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NA~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-na-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">BU~a</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/BU~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-bu-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N39~a)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N39~a).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n39-a).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">U4</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/U4.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-u4.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KU6~a</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/KU6~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ku6-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">A</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/A.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">4 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N39~a)</span><div class="features"></div>
#
#     </div>
# <div><a target

# %% [markdown]
# ## Search for spatial patterns
# A few words on the construction of search templates.
#
# The idea is that you mimick the things you are looking for
# in your search template.
# Embedded things are mimicked by indentation.
#
# Let's search for a line with a case in it that is not further divided,
# in which there is a numeral and an ideograph.
#
# Here is our first attempt, and we show the first tablet only.
# Note that you can have comments in a search template.
# Lines that start with `#` are ignored.

# %%
query = '''
line
  case terminal=1
% order is not important
    sign type=ideograph
    sign type=numeral
'''
results = A.search(query)
# Out:
#   0.43s 10673 results

# %% [markdown]
# First a glance at the first 3 items in tabular view.

# %%
A.table(results, end=3, lineart=False)
# Out:
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">tablet</th><th class="tf">sign</th><th class="tf">sign</th><th class="tf">sign</th><th class="tf">line</th><th class="tf">sign</th><th class="tf">case</th><th class="tf">sign</th><th class="tf">sign</th><th class="tf">case</th><th class="tf">sign</th><th class="tf">sign</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  " >tablet P448702</span></td><td class="tf"><span class="plain outer  hl" >3(N01)</span> </td><td class="tf"><span class="plain outer  hl" >KASZ~a</span> </td><td class="tf"><span class="plain outer  hl" >GI</span> </td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></span>&nbsp;<span class="plain outer  hlbx" >2. <span class="plain " >[<span class="plain hl" >N</span>]</span><span class="plain hl" >N</span> <span class="plain hl" >2(N14)</span> <span class="plain hl" >3(N01)</span> <span class="plain hl" >KASZ~b</span> <span class="plain hl" >NUN~a</span> <span class="plain hl" >3(N01)</span> <span class="plain hl" >KASZ~a</span> <span class="plain hl" >GI</span> </span></span></td><td class="tf"><span class="plain outer  hl" >3(N01)</span> </td><td class="tf"><span class="plain outer  hlbx" >2b. <span class="plain hl" >3(N01)</span> <span class="plain hl" >KASZ~a</span> <span class="plain hl" >GI</span> </span></td><td class="tf"><span class="plain outer  hl" >N</span> </td><td class="tf"><span class="plain outer  hl" >2(N14)</span> </td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >[<span class="plain hl" >N</span>]</span><span class="plain hl" >N</span> <span class="plain hl" >2(N14)</span> <span class="plain hl" >3(N01)</span> <span class="plain hl" >KASZ~b</span> <span class="plain hl" >NUN~a</span> </span></td><td class="tf"><span class="plain outer  hl" >KASZ~b</span> </td><td class="tf"><span class="plain outer  hl" >NUN~a</span> </td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P471695" title="to CDLI main page for this tablet" sec="P471695">P471695</a></td><td class="tf"><span class="plain outer  " >tablet P471695</span></td><td class="tf"><span class="plain outer  hlbx" >2b1. <span class="plain " >(<span class="plain hl" >3(N57)</span> <span class="plain hl" >PAP~a</span>)a</span><span class="plain hl" >3(N57)</span> <span class="plain hl" >PAP~a</span> </span></td><td class="tf"><span class="plain outer  hl" >1(N01)</span> </td><td class="tf"><span class="plain outer  hl" >ISZ~a</span> </td><td class="tf"><span class="plain outer  hlbx" >1a. <span class="plain hl" >1(N01)</span> <span class="plain hl" >ISZ~a</span> </span></td><td class="tf"><span class="plain outer  hl" >3(N01)</span> </td><td class="tf"><span class="plain outer  hl" >APIN~a</span> </td><td class="tf"><span class="plain outer  hl" >3(N57)</span> </td><td class="tf"><span class="plain outer  hl" >UR4~a</span> </td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P471695" title="to CDLI main page for this tablet" sec="P471695">P471695</a></span>&nbsp;<span class="plain outer  hlbx" >1. <span class="plain hl" >3(N01)</span> <span class="plain hl" >APIN~a</span> <span class="plain hl" >3(N57)</span> <span class="plain hl" >UR4~a</span> <span class="plain " >(<span class="plain " >EN~a</span> <span class="plain " >DU</span> <span class="plain " >ZATU759</span>)a</span><span class="plain " >EN~a</span> <span class="plain " >DU</span> <span class="plain " >ZATU759</span> <span class="plain " >(<span class="plain " >BAN~b</span> <span class="plain " >KASZ~c</span>)a</span><span class="plain " >BAN~b</span> <span class="plain " >KASZ~c</span> <span class="plain " >(<span class="plain " >KI@n</span> <span class="plain " >SAG</span>)a</span><span class="plain " >KI@n</span> <span class="plain " >SAG</span> </span></span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P471695" title="to CDLI main page for this tablet" sec="P471695">P471695</a></span>&nbsp;<span class="plain outer  hlbx" >2. <span class="plain " >1(N14)</span> <span class="plain " >2(N01)</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >(<span class="plain hl" >3(N57)</span> <span class="plain hl" >PAP~a</span>)a</span><span class="plain hl" >3(N57)</span> <span class="plain hl" >PAP~a</span> <span class="plain " ></span> <span class="plain " >(<span class="plain " >SZU</span> <span class="plain " >KI</span> <span class="plain " >X</span>)a</span><span class="plain " >SZU</span> <span class="plain " >KI</span> <span class="plain " >X</span> <span class="plain " >(<span class="plain " >EN~a</span> <span class="plain " >AN</span> <span class="plain " >EZINU~d</span>)a</span><span class="plain " >EN~a</span> <span class="plain " >AN</span> <span class="plain " >EZINU~d</span> <span class="plain " ></span> <span class="plain " ></span> <span class="plain " >(<span class="plain " >IDIGNA</span> <span class="plain " >[<span class="plain " >...</span>]</span>)a</span><span class="plain " >IDIGNA</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> </span></span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P471695" title="to CDLI main page for this tablet" sec="P471695">P471695</a></span>&nbsp;<span class="plain outer  hlbx" >1. <span class="plain hl" >1(N01)</span> <span class="plain hl" >ISZ~a</span> <span class="plain " ></span> <span class="plain " ></span> <span class="plain " >(<span class="plain " >PAP~a</span> <span class="plain " >GIR3~c</span>)a</span><span class="plain " >PAP~a</sp ...
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P482083" title="to CDLI main page for this tablet" sec="P482083">P482083</a></td><td class="tf"><span class="plain outer  " >tablet P482083</span></td><td class="tf"><span class="plain outer  hl" >1(N14)</span> </td><td class="tf"><span class="plain outer  hl" >SZE~a</span> </td><td class="tf"><span class="plain outer  hl" >N</span> </td><td class="tf"><span class="plain outer  hl" >TAR~a</span> </td><td class="tf"><span class="plain outer  hl" >3(N01)</span> </td><td class="tf"><span class="plain outer  hl" >SZE~a</span> </td><td class="tf"><span class="plain outer  hl" >KASZ~b</span> </td><td class="tf"><span class="plain outer  hl" >U4</span> </td><td class="tf"><span class="plain outer  hl" >3(N01)</span> </td><td class="tf"><span class="plain outer  hl" >1(N42~a)</span> </td><td class="tf"><span class="plain outer  hl" >1(N25)</span> </td><td class="tf"><span class="plain outer  hl" >TAR~a</span> </td><td class="tf"><span class="plain outer  hlbx" >1a. <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain hl" >1(N14)</span> <span class="plain " >[<span class="plain " >...</span>]</span><

# %% [markdown]
# Ah, we were still in condensed mode.
#
# For this query the table is more perspicuous in normal mode, so we tell not to condense.

# %%
A.table(results, condensed=False, end=20, lineart=False)
# Out:
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">line</th><th class="tf">case</th><th class="tf">sign</th><th class="tf">sign</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  hlbx" >2. <span class="plain " >[<span class="plain hl" >N</span>]</span><span class="plain hl" >N</span> <span class="plain " >2(N14)</span> <span class="plain " >3(N01)</span> <span class="plain hl" >KASZ~b</span> <span class="plain " >NUN~a</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~a</span> <span class="plain " >GI</span> </span></span></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >[<span class="plain hl" >N</span>]</span><span class="plain hl" >N</span> <span class="plain " >2(N14)</span> <span class="plain " >3(N01)</span> <span class="plain hl" >KASZ~b</span> <span class="plain " >NUN~a</span> </span></td><td class="tf"><span class="plain outer  hl" >KASZ~b</span> </td><td class="tf"><span class="plain outer  hl" >N</span> </td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  hlbx" >2. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain hl" >2(N14)</span> <span class="plain " >3(N01)</span> <span class="plain hl" >KASZ~b</span> <span class="plain " >NUN~a</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~a</span> <span class="plain " >GI</span> </span></span></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain hl" >2(N14)</span> <span class="plain " >3(N01)</span> <span class="plain hl" >KASZ~b</span> <span class="plain " >NUN~a</span> </span></td><td class="tf"><span class="plain outer  hl" >KASZ~b</span> </td><td class="tf"><span class="plain outer  hl" >2(N14)</span> </td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  hlbx" >2. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain " >2(N14)</span> <span class="plain hl" >3(N01)</span> <span class="plain hl" >KASZ~b</span> <span class="plain " >NUN~a</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~a</span> <span class="plain " >GI</span> </span></span></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain " >2(N14)</span> <span class="plain hl" >3(N01)</span> <span class="plain hl" >KASZ~b</span> <span class="plain " >NUN~a</span> </span></td><td class="tf"><span class="plain outer  hl" >KASZ~b</span> </td><td class="tf"><span class="plain outer  hl" >3(N01)</span> </td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  hlbx" >2. <span class="plain " >[<span class="plain hl" >N</span>]</span><span class="plain hl" >N</span> <span class="plain " >2(N14)</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~b</span> <span class="plain hl" >NUN~a</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~a</span> <span class="plain " >GI</span> </span></span></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >[<span class="plain hl" >N</span>]</span><span class="plain hl" >N</span> <span class="plain " >2(N14)</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~b</span> <span class="plain hl" >NUN~a</span> </span></td><td class="tf"><span class="plain outer  hl" >NUN~a</span> </td><td class="tf"><span class="plain outer  hl" >N</span> </td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  hlbx" >2. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain hl" >2(N14)</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~b</span> <span class="plain hl" >NUN~a</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~a</span> <span class="plain " >GI</span> </span></span></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain hl" >2(N14)</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~b</span> <span class="plain hl" >NUN~a</span> </span></td><td class="tf"><span class="plain outer  hl" >NUN~a</span> </td><td class="tf"><span class="plain outer  hl" >2(N14)</span> </td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  hlbx" >2. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain " >2(N14)</span> <span class="plain hl" >3(N01)</span> <span class="plain " >KASZ~b</span> <span class="plain hl" >NUN~a</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~a</span> <span class="plain " >GI</span> </span></span></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain " >2(N14)</span> <span class="plain hl" >3(N01)</span> <span class="plain " >KASZ~b</span> <span class="plain hl" >NUN~a</span> </span></td><td class="tf"><span class="plain outer  hl" >NUN~a</span> </td><td class="tf"><span class="plain outer  hl" >3(N01)</span> </td></tr>
# <tr class="tf"><td class="tf">7</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  hlbx" >2. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain " >2(N14)</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~b</span> <span class="plain " >NUN~a</span> <span class="plain hl" >3(N01)</span> <span class="plain hl" >KASZ~a</span> <span class="plain " >GI</span> </span></span></td><td class="tf"><span class="plain outer  hlbx" >2b. <span class="plain hl" >3(N01)</span> <span class="plain hl" >KASZ~a</span> <span class="plain " >GI</span> </span></td><td class="tf"><span class="plain outer  hl" >KASZ~a</span> </td><td class="tf"><span class="plain outer  hl" >3(N01)</span> </td></tr>
# <tr class="tf"><td class="tf">8</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  hlbx" >2. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain " >2(N14)</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~b</

# %% [markdown]
# Now the results on the first tablet, condensed by line.

# %%
A.show(results, end=1, condenseType="line")
# Out:
# <p><b>line</b> <i>1</i></p>
# <div class="contnr line " >
#     <div class="lbl line"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">line 2</a> </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2a' </div>
#     <div class="meta">
#         <div class="features"> <span class="terminal xft"><span class="f">terminal=</span>1</span></div>
#
#     </div>
# <div class="children trminalv"><div class="lbl clusterb">? </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">N</span><div class="features"> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">2(N14)</span><div class="features"> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">KASZ~b</span><div class="features"> <span class="type xft"><span class="f">type=</span>ideograph</span></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/KASZ~b.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-kasz-b.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"> <span class="type xft"><span class="f">type=</span>ideograph</span></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NUN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-nun-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div></div></div>
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2b' </div>
#     <div class="meta">
#         <div class="features"> <span class="terminal xft"><span class="f">terminal=</span>1</span></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">KASZ~a</span><div class="features"> <span class="type xft"><span class="f">type=</span>ideograph</span></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/KASZ~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-kasz-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">GI</span><div class="features"> <span class="type xft"><span class="f">type=</span>ideograph</span></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/GI.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-gi.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div></div></div></div></div>

# %% [markdown]
# The order between the two signs is not defined by the template,
# despite the fact that the line with the ideograph
# precedes the line with the numeral.
# Results may have the numeral and the ideograph in any order.
#
# In fact, the highlights above represent multiple results.
# If a case has say 2 numerals and 3 ideographs, there are 6 possible
# pairs.
#
# By default, results are shown in *condensed* mode.
# That means that results are shown per tablet, and on the result tablets
# everything that is in some result is being highlighted.
#
# It is also possible to see the uncondensed results.
# That gives you an exact picture of each real result constellation.
#
# In order to illustrate the difference, we focus on one tablet and one case.
# This case has 3 numerals and 2 ideographs, so we expect 6 results.

# %%
query = '''
tablet catalogId=P448702
  line
    case terminal=1 number=2a
      sign type=ideograph
      sign type=numeral
'''
results = A.search(query)
# Out:
#   0.38s 6 results

# %% [markdown]
# We show them condensed (by default), so we expect 1 line with all ideographs and numerals in case `2a'` highlighted.

# %%
A.show(results, lineart=False, condenseType="line")
# Out:
# <p><b>line</b> <i>1</i></p>
# <div class="contnr line " >
#     <div class="lbl line"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">line 2</a> </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2a' </div>
#     <div class="meta">
#         <div class="features"> <span class="number xft"><span class="f">number=</span>2a</span> <span class="terminal xft"><span class="f">terminal=</span>1</span></div>
#
#     </div>
# <div class="children trminalv"><div class="lbl clusterb">? </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">N</span><div class="features"> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">2(N14)</span><div class="features"> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#
#     </div>
# </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#
#     </div>
# </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">KASZ~b</span><div class="features"> <span class="type xft"><span class="f">type=</span>ideograph</span></div>
#
#     </div>
# </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"> <span class="type xft"><span class="f">type=</span>ideograph</span></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2b' </div>
#     <div class="meta">
#         <div class="features"> <span class="number xft"><span class="f">number=</span>2b</span> <span class="terminal xft"><span class="f">terminal=</span>1</span></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"> <span class="type xft"><span class="f">type=</span>numeral</span></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KASZ~a</span><div class="features"> <span class="type xft"><span class="f">type=</span>ideograph</span></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GI</span><div class="features"> <span class="type xft"><span class="f">type=</span>ideograph</span></div>
#
#     </div>
# </div></div></div></div></div>

# %% [markdown]
# Now the same results in uncondensed mode. Expect 6 times the same line with
# different highlighted pairs of signs.
#
# Note that we can apply different highlight colors to different parts of the result.
# The words in the pair are member 4 and 5.
#
# The members that we do not map, will not be highlighted.
# The members that we map to the empty string will be highlighted with the default color.
#
# **NB:** Choose your colors from the
# [CSS specification](https://developer.mozilla.org/en-US/docs/Web/CSS/color_value).

# %%
A.show(results, condensed=False, colorMap={3: '', 4: 'cyan', 5: 'magenta'}, lineart=False, condenseType="line", showFeatures=False)
# Out:
# <p><b>result</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">tablet P448702 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# </div>
# <div class="contnr line " >
#     <div class="lbl line"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">line 2</a> </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2a' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv"><div class="lbl clusterb">? </div>
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="meta">
#          <span class="srcln">N</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">2(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="meta">
#          <span class="srcln">KASZ~b</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2b' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KASZ~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GI</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <p><b>result</b> <i>2</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">tablet P448702 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# </div>
# <div class="contnr line " >
#     <div class="lbl line"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">line 2</a> </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2a' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">N</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="meta">
#          <span class="srcln">2(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="meta">
#          <span class="srcln">KASZ~b</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2b' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KASZ~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GI</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <p><b>result</b> <i>3</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">tablet P448702 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# </div>
# <div class="contnr line " >
#     <div class="lbl line"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">line 2</a> </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2a' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">N</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">2(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="meta">
#          <span class="srcln">KASZ~b</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2b' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KASZ~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GI</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <p><b>result</b> <i>4</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">tablet P448702 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# </div>
# <div class="contnr line " >
#     <div class="lbl line"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">line 2</a> </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2a' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv"><div class="lbl clusterb">? </div>
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="meta">
#          <span class="srcln">N</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">2(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KASZ~b</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2b' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KASZ~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GI</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <p><b>result</b> <i>5</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">tablet P448702 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# </div>
# <div class="contnr line " >
#     <div class="lbl line"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">line 2</a> </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2a' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">N</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="meta">
#          <span class="srcln">2(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KASZ~b</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2b' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KASZ~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GI</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <p><b>result</b> <i>6</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">tablet P448702 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# </div>
# <div class="contnr line " >
#     <div class="lbl line"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">line 2</a> </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2a' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">N</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">2(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KASZ~b</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2b' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KASZ~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GI</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>

# %% [markdown]
# Color mapping works best for uncondensed results. If you condense results, some nodes may occupy
# different positions in different results. It is unpredictable which color will be used
# for such nodes:

# %%
A.show(results, condensed=True, colorMap={3: '', 4: 'cyan', 5: 'magenta'}, lineart=False, condenseType="line", showFeatures=False)
# Out:
# <p><b>line</b> <i>1</i></p>
# <div class="contnr line " >
#     <div class="lbl line"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">line 2</a> </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2a' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv"><div class="lbl clusterb">? </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">N</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="meta">
#          <span class="srcln">2(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">KASZ~b</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2b' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KASZ~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GI</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>

# %% [markdown]
# You can enforce order.
# We modify the template a little to state a
# relational condition, namely that the ideograph follows the numeral.

# %%
query = '''
tablet catalogId=P448702
  line
    case terminal=1 number=2a
      sign type=ideograph
      > sign type=numeral
'''
results = A.search(query)
A.table(results, condensed=False, lineart=False)
# Out:
#   0.37s 6 results
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">tablet</th><th class="tf">line</th><th class="tf">case</th><th class="tf">sign</th><th class="tf">sign</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  " >tablet P448702</span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></span>&nbsp;<span class="plain outer  hlbx" >2. <span class="plain " >[<span class="plain hl" >N</span>]</span><span class="plain hl" >N</span> <span class="plain " >2(N14)</span> <span class="plain " >3(N01)</span> <span class="plain hl" >KASZ~b</span> <span class="plain " >NUN~a</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~a</span> <span class="plain " >GI</span> </span></span></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >[<span class="plain hl" >N</span>]</span><span class="plain hl" >N</span> <span class="plain " >2(N14)</span> <span class="plain " >3(N01)</span> <span class="plain hl" >KASZ~b</span> <span class="plain " >NUN~a</span> </span></td><td class="tf"><span class="plain outer  hl" >KASZ~b</span> </td><td class="tf"><span class="plain outer  hl" >N</span> </td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  " >tablet P448702</span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></span>&nbsp;<span class="plain outer  hlbx" >2. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain hl" >2(N14)</span> <span class="plain " >3(N01)</span> <span class="plain hl" >KASZ~b</span> <span class="plain " >NUN~a</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~a</span> <span class="plain " >GI</span> </span></span></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain hl" >2(N14)</span> <span class="plain " >3(N01)</span> <span class="plain hl" >KASZ~b</span> <span class="plain " >NUN~a</span> </span></td><td class="tf"><span class="plain outer  hl" >KASZ~b</span> </td><td class="tf"><span class="plain outer  hl" >2(N14)</span> </td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  " >tablet P448702</span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></span>&nbsp;<span class="plain outer  hlbx" >2. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain " >2(N14)</span> <span class="plain hl" >3(N01)</span> <span class="plain hl" >KASZ~b</span> <span class="plain " >NUN~a</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~a</span> <span class="plain " >GI</span> </span></span></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain " >2(N14)</span> <span class="plain hl" >3(N01)</span> <span class="plain hl" >KASZ~b</span> <span class="plain " >NUN~a</span> </span></td><td class="tf"><span class="plain outer  hl" >KASZ~b</span> </td><td class="tf"><span class="plain outer  hl" >3(N01)</span> </td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  " >tablet P448702</span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></span>&nbsp;<span class="plain outer  hlbx" >2. <span class="plain " >[<span class="plain hl" >N</span>]</span><span class="plain hl" >N</span> <span class="plain " >2(N14)</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~b</span> <span class="plain hl" >NUN~a</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~a</span> <span class="plain " >GI</span> </span></span></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >[<span class="plain hl" >N</span>]</span><span class="plain hl" >N</span> <span class="plain " >2(N14)</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~b</span> <span class="plain hl" >NUN~a</span> </span></td><td class="tf"><span class="plain outer  hl" >NUN~a</span> </td><td class="tf"><span class="plain outer  hl" >N</span> </td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  " >tablet P448702</span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></span>&nbsp;<span class="plain outer  hlbx" >2. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain hl" >2(N14)</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~b</span> <span class="plain hl" >NUN~a</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~a</span> <span class="plain " >GI</span> </span></span></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain hl" >2(N14)</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~b</span> <span class="plain hl" >NUN~a</span> </span></td><td class="tf"><span class="plain outer  hl" >NUN~a</span> </td><td class="tf"><span class="plain outer  hl" >2(N14)</span> </td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  " >tablet P448702</span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></span>&nbsp;<span class="plain outer  hlbx" >2. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain " >2(N14)</span> <span class="plain hl" >3(N01)</span> <span class="plain " >KASZ~b</span> <span class="plain hl" >NUN~a</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~a</span> <span class="plain " >GI</span> </span></span></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain " >2(N14)</span> <span class="plain hl" >3(N01)</sp

# %% [markdown]
# Still six results.
# No wonder, because the case has first three numerals in a row and then 2 ideographs.
#
# Do you want the ideograph and the numeral to be *adjacent* as well?
# We only have to add 1 character to the template to make it happen.

# %%
query = '''
tablet catalogId=P448702
  line
    case terminal=1 number=2a
      sign type=ideograph
      :> sign type=numeral
'''
results = A.search(query)
# Out:
#   0.36s 1 result

# %%
A.table(results, condensed=False, lineart=False)
# Out:
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">tablet</th><th class="tf">line</th><th class="tf">case</th><th class="tf">sign</th><th class="tf">sign</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  " >tablet P448702</span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></span>&nbsp;<span class="plain outer  hlbx" >2. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain " >2(N14)</span> <span class="plain hl" >3(N01)</span> <span class="plain hl" >KASZ~b</span> <span class="plain " >NUN~a</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~a</span> <span class="plain " >GI</span> </span></span></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain " >2(N14)</span> <span class="plain hl" >3(N01)</span> <span class="plain hl" >KASZ~b</span> <span class="plain " >NUN~a</span> </span></td><td class="tf"><span class="plain outer  hl" >KASZ~b</span> </td><td class="tf"><span class="plain outer  hl" >3(N01)</span> </td></tr></table>

# %%
A.show(results, condensed=False, colorMap={4: 'cyan', 5: 'magenta'}, lineart=False, condenseType="line", showFeatures=False)
# Out:
# <p><b>result</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">tablet P448702 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# </div>
# <div class="contnr line " >
#     <div class="lbl line"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">line 2</a> </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2a' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">N</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">2(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl"  style="background-color: magenta;" >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl"  style="background-color: cyan;" >
#
#     <div class="meta">
#          <span class="srcln">KASZ~b</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2b' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KASZ~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GI</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>

# %% [markdown]
# By now it pays off to study the possibilities of
# [search templates](https://annotation.github.io/text-fabric/Use/Search/#search-templates).
#
# If you want a reminder of all possible spatial relationships between nodes, you can call it up
# here in your notebook:

# %%
S.relationsLegend()
# Out:
#                       = left equal to right (as node)
#                       # left unequal to right (as node)
#                       < left before right (in canonical node ordering)
#                       > left after right (in canonical node ordering)
#                      == left occupies same slots as right
#                      && left has overlapping slots with right
#                      ## left and right do not have the same slot set
#                      || left and right do not have common slots
#                      [[ left embeds right
#                      ]] left embedded in right
#                      << left completely before right
#                      >> left completely after right
#                      =: left and right start at the same slot
#                      := left and right end at the same slot
#                      :: left and right start and end at the same slot
#                      <: left immediately before right
#                      :> left immediately after right
#                     =k: left and right start at k-nearly the same slot
#                     :k= left and right end at k-nearly the same slot
#                     :k: left and right start and end at k-near slots
#                     <k: left k-nearly before right
#                     :k> left k-nearly after right
#                     .f. left.f = right.f
#                   .f=g. left.f = right.g
#                 .f~r~g. left.f matches right.g
#                   .f#g. left.f # right.g
#                   .f>g. left.f > right.g
#                   .f<g. left.f > right.g
#              -comments> edge feature "comments"
#              <comments- edge feature "comments" (opposite direction)
#              <comments> edge feature "comments" (either direction)
#                    -op> edge feature "op" with value specification allowed
#                    <op- edge feature "op" with value specification allowed (opposite direction)
#                    <op> edge feature "op" with value specification allowed (either direction)
#                   -sub> edge feature "sub"
#                   <sub- edge feature "sub" (opposite direction)
#                   <sub> edge feature "sub" (either direction)
# The warp feature "oslots" cannot be used in searches.
# One of the above relations on nodes and/or slots will suit you better.

# %% [markdown]
# ## Comparisons in templates: cases
#
# Cases have a feature depth which indicate their nesting depth within a line.
# It is not the depth *of* that case, but the depth *at* which that case occurs.
#
# Comparison queries are handy to select cases of a certain minimum or maximum depth.

# %% [markdown]
# We'll work a lot with `condensed=False`, and `lineart` likewise, so let's make that the default:

# %%
A.displaySetup(condensed=False, lineart=False)

# %%
query = '''
case depth=3
'''
results = A.search(query)
A.table(results, end=20)
# Out:
#   0.01s 254 results
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">case</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003357" title="to CDLI main page for this tablet" sec="P003357">P003357</a></td><td class="tf"><span class="plain outer  hlbx" >1b1A. <span class="plain " >EN~a</span> <span class="plain " >ZATU759</span> <span class="plain " >DU</span> </span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003357" title="to CDLI main page for this tablet" sec="P003357">P003357</a></td><td class="tf"><span class="plain outer  hlbx" >1b1B. <span class="plain " >3(N57)</span> <span class="plain " >SU~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003537" title="to CDLI main page for this tablet" sec="P003537">P003537</a></td><td class="tf"><span class="plain outer  hlbx" >4b1A. <span class="plain " >3(N57)</span> <span class="plain " >X</span> <span class="plain " >SZA</span> <span class="plain " >U4</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >X</span> </span></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003537" title="to CDLI main page for this tablet" sec="P003537">P003537</a></td><td class="tf"><span class="plain outer  hlbx" >4b1B. <span class="plain " >X</span> <span class="plain " >X</span> </span></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003537" title="to CDLI main page for this tablet" sec="P003537">P003537</a></td><td class="tf"><span class="plain outer  hlbx" >4b2A. <span class="plain " >2(N57)</span> <span class="plain " >GAN~b</span> <span class="plain " >SZU</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> </span></td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003537" title="to CDLI main page for this tablet" sec="P003537">P003537</a></td><td class="tf"><span class="plain outer  hlbx" >4b2B. <span class="plain " >X</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> </span></td></tr>
# <tr class="tf"><td class="tf">7</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003589" title="to CDLI main page for this tablet" sec="P003589">P003589</a></td><td class="tf"><span class="plain outer  hlbx" >3b2A. <span class="plain " >|<span class="plain " >GA~a</span>.<span class="plain " >ZATU753</span>|</span> <span class="plain " >GA~a</span> <span class="plain " >ZATU753</span> </span></td></tr>
# <tr class="tf"><td class="tf">8</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003589" title="to CDLI main page for this tablet" sec="P003589">P003589</a></td><td class="tf"><span class="plain outer  hlbx" >3b2B. <span class="plain " >MUD</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> </span></td></tr>
# <tr class="tf"><td class="tf">9</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003822" title="to CDLI main page for this tablet" sec="P003822">P003822</a></td><td class="tf"><span class="plain outer  hlbx" >1a2A. <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> </span></td></tr>
# <tr class="tf"><td class="tf">10</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003822" title="to CDLI main page for this tablet" sec="P003822">P003822</a></td><td class="tf"><span class="plain outer  hlbx" >1a2B. <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >PAP~a</span> <span class="plain " >SU~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">11</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003822" title="to CDLI main page for this tablet" sec="P003822">P003822</a></td><td class="tf"><span class="plain outer  hlbx" >1b2A. <span class="plain " >(<span class="plain " >KASZ~c#</span> <span class="plain " >|<span class="plain " >SZE~a</span>&<span class="plain " >SZE~a</span>|</span>)a</span><span class="plain " >KASZ~c</span> <span class="plain " >|<span class="plain " >SZE~a</span>&<span class="plain " >SZE~a</span>|</span> <span class="plain " >SZE~a</span> <span class="plain " >SZE~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">12</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003822" title="to CDLI main page for this tablet" sec="P003822">P003822</a></td><td class="tf"><span class="plain outer  hlbx" >1b2B. <span class="plain " >(<span class="plain " >MUD</span>)a</span><span class="plain " >MUD</span> </span></td></tr>
# <tr class="tf"><td class="tf">13</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P004448" title="to CDLI main page for this tablet" sec="P004448">P004448</a></td><td class="tf"><span class="plain outer  hlbx" >1a2A. <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> </span></td></tr>
# <tr class="tf"><td class="tf">14</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P004448" title="to CDLI main page for this tablet" sec="P004448">P004448</a></td><td class="tf"><span class="plain outer  hlbx" >1a2B. <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >X</span> </span></td></tr>
# <tr class="tf"><td class="tf">15</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P004448" title="to CDLI main page for this tablet" sec="P004448">P004448</a></td><td class="tf"><span class="plain outer  hlbx" >1b2A. <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> </span></td></tr>
# <tr class="tf"><td class="tf">16</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P004448" title="to CDLI main page for this tablet" sec="P004448">P004448</a></td><td class="tf"><span class="plain outer  hlbx" >1b2B. <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >AN</span> <span class="plain " >NUN~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">17</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P004448" title="to CDLI main page for this tablet" sec="P004448">P004448</a></td><td class="tf"><span class="plain outer  hlbx" >2a2A. <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >X</span> <span class="plain " >SU~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">18</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P004448" title="to CDLI main page for this tablet" sec="P004448">P004448</a></td><td class="tf"><span class="pl

# %% [markdown]
# Are there deeper cases?

# %%
query = '''
case depth>3
'''
results = A.search(query)
A.table(results, end=20)
# Out:
#   0.01s 119 results
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">case</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P004735" title="to CDLI main page for this tablet" sec="P004735">P004735</a></td><td class="tf"><span class="plain outer  hlbx" >1b1B1. <span class="plain " >(<span class="plain " >NAB</span> <span class="plain " >DI</span> <span class="plain " >|<span class="plain " >BU~a</span>+<span class="plain " >DU6~a</span>|</span>)a</span><span class="plain " >NAB</span> <span class="plain " >DI</span> <span class="plain " >|<span class="plain " >BU~a</span>+<span class="plain " >DU6~a</span>|</span> <span class="plain " >BU~a</span> <span class="plain " >DU6~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P004735" title="to CDLI main page for this tablet" sec="P004735">P004735</a></td><td class="tf"><span class="plain outer  hlbx" >1b1B2. <span class="plain " >(<span class="plain " >ZI~a#?</span> <span class="plain " >AN</span>)a</span><span class="plain " >ZI~a</span> <span class="plain " >AN</span> </span></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P004735" title="to CDLI main page for this tablet" sec="P004735">P004735</a></td><td class="tf"><span class="plain outer  hlbx" >1b1B3. <span class="plain " >(<span class="plain " >ANSZE~e</span> <span class="plain " >7(N57)</span> <span class="plain " >DUR2</span> <span class="plain " >DU</span>)a</span><span class="plain " >ANSZE~e</span> <span class="plain " >7(N57)</span> <span class="plain " >DUR2</span> <span class="plain " >DU</span> </span></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P004735" title="to CDLI main page for this tablet" sec="P004735">P004735</a></td><td class="tf"><span class="plain outer  hlbx" >1b1B4. <span class="plain " >(<span class="plain " >LAL3~a#?</span> <span class="plain " >GAR</span> <span class="plain " >IG~b</span>)a</span><span class="plain " >LAL3~a</span> <span class="plain " >GAR</span> <span class="plain " >IG~b</span> </span></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P004735" title="to CDLI main page for this tablet" sec="P004735">P004735</a></td><td class="tf"><span class="plain outer  hlbx" >2b2B1. <span class="plain " >(<span class="plain " >GI6</span> <span class="plain " >KISZIK~a#</span> <span class="plain " >URI3~a</span>)a</span><span class="plain " >GI6</span> <span class="plain " >KISZIK~a</span> <span class="plain " >URI3~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P004735" title="to CDLI main page for this tablet" sec="P004735">P004735</a></td><td class="tf"><span class="plain outer  hlbx" >2b2B2. <span class="plain " >(<span class="plain " >[<span class="plain " >...</span>]</span>)a</span><span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> </span></td></tr>
# <tr class="tf"><td class="tf">7</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P218054" title="to CDLI main page for this tablet" sec="P218054">P218054</a></td><td class="tf"><span class="plain outer  hlbx" >1a1A1. <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >5(N01)</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >UDU~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">8</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P218054" title="to CDLI main page for this tablet" sec="P218054">P218054</a></td><td class="tf"><span class="plain outer  hlbx" >1a1A2. <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >7(N01)</span> <span class="plain " >MASZ2</span> </span></td></tr>
# <tr class="tf"><td class="tf">9</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P325754" title="to CDLI main page for this tablet" sec="P325754">P325754</a></td><td class="tf"><span class="plain outer  hlbx" >1c2b1. <span class="plain " >1(N01)</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> </span></td></tr>
# <tr class="tf"><td class="tf">10</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P325754" title="to CDLI main page for this tablet" sec="P325754">P325754</a></td><td class="tf"><span class="plain outer  hlbx" >1c2b2. <span class="plain " >1(N14)</span> <span class="plain " >7(N01)</span> <span class="plain " >TUR</span> </span></td></tr>
# <tr class="tf"><td class="tf">11</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P325754" title="to CDLI main page for this tablet" sec="P325754">P325754</a></td><td class="tf"><span class="plain outer  hlbx" >1c2b3. <span class="plain " >2(N14)</span> <span class="plain " >6(N01)</span> <span class="plain " >SUR</span> </span></td></tr>
# <tr class="tf"><td class="tf">12</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P325234" title="to CDLI main page for this tablet" sec="P325234">P325234</a></td><td class="tf"><span class="plain outer  hlbx" >1c5a1. <span class="plain " >8(N01)</span> <span class="plain " >GAR</span> <span class="plain " >U2~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">13</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P325234" title="to CDLI main page for this tablet" sec="P325234">P325234</a></td><td class="tf"><span class="plain outer  hlbx" >1c5a2. <span class="plain " >|<span class="plain " >SZU2</span>.<span class="plain " >E2~b</span>|</span> <span class="plain " >SZU2</span> <span class="plain " >E2~b</span> </span></td></tr>
# <tr class="tf"><td class="tf">14</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P411608" title="to CDLI main page for this tablet" sec="P411608">P411608</a></td><td class="tf"><span class="plain outer  hlbx" >1b2a1. <span class="plain " >1(N01)</span> <span class="plain " >GAL~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">15</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P411608" title="to CDLI main page for this tablet" sec="P411608">P411608</a></td><td class="tf"><span class="plain outer  hlbx" >1b2a2. <span class="plain " >1(N01)</span> <span class="plain " >GA2~a1</span> <span class="plain " >TUR</span> </span></td></tr>
# <tr class="tf"><td class="tf">16</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P411608" title="to CDLI main page for this tablet" sec="P411608">P411608</a></td><td class="tf"><span class="plain outer  hlbx" >1b2b1. <span class="plain " >1(N01)</span> <span class="plain " >|<span class="plain " >U4</span>x<span class="plain " >3(N57)</span>|</span> <span class="plain " >U4</span> <span class="plain " >3(N57)</span> </span></td></tr>
# <tr class="tf"><td class="tf">17</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P411608" title="to CDLI main page for this tablet" sec="P411608">P411608</a></

# %% [markdown]
# Still deeper?

# %%
query = '''
case depth>4
'''
results = A.search(query)
A.table(results, end=20)
# Out:
#   0.01s 0 results
# <table></table>

# %% [markdown]
# As a check: the cases with depth 4 should be exactly the cases with depth > 3:

# %%
query = '''
case depth=4
'''
results = A.search(query)
A.table(results, end=20)
tc4 = len(results)
# Out:
#   0.01s 119 results
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">case</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P004735" title="to CDLI main page for this tablet" sec="P004735">P004735</a></td><td class="tf"><span class="plain outer  hlbx" >1b1B1. <span class="plain " >(<span class="plain " >NAB</span> <span class="plain " >DI</span> <span class="plain " >|<span class="plain " >BU~a</span>+<span class="plain " >DU6~a</span>|</span>)a</span><span class="plain " >NAB</span> <span class="plain " >DI</span> <span class="plain " >|<span class="plain " >BU~a</span>+<span class="plain " >DU6~a</span>|</span> <span class="plain " >BU~a</span> <span class="plain " >DU6~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P004735" title="to CDLI main page for this tablet" sec="P004735">P004735</a></td><td class="tf"><span class="plain outer  hlbx" >1b1B2. <span class="plain " >(<span class="plain " >ZI~a#?</span> <span class="plain " >AN</span>)a</span><span class="plain " >ZI~a</span> <span class="plain " >AN</span> </span></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P004735" title="to CDLI main page for this tablet" sec="P004735">P004735</a></td><td class="tf"><span class="plain outer  hlbx" >1b1B3. <span class="plain " >(<span class="plain " >ANSZE~e</span> <span class="plain " >7(N57)</span> <span class="plain " >DUR2</span> <span class="plain " >DU</span>)a</span><span class="plain " >ANSZE~e</span> <span class="plain " >7(N57)</span> <span class="plain " >DUR2</span> <span class="plain " >DU</span> </span></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P004735" title="to CDLI main page for this tablet" sec="P004735">P004735</a></td><td class="tf"><span class="plain outer  hlbx" >1b1B4. <span class="plain " >(<span class="plain " >LAL3~a#?</span> <span class="plain " >GAR</span> <span class="plain " >IG~b</span>)a</span><span class="plain " >LAL3~a</span> <span class="plain " >GAR</span> <span class="plain " >IG~b</span> </span></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P004735" title="to CDLI main page for this tablet" sec="P004735">P004735</a></td><td class="tf"><span class="plain outer  hlbx" >2b2B1. <span class="plain " >(<span class="plain " >GI6</span> <span class="plain " >KISZIK~a#</span> <span class="plain " >URI3~a</span>)a</span><span class="plain " >GI6</span> <span class="plain " >KISZIK~a</span> <span class="plain " >URI3~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P004735" title="to CDLI main page for this tablet" sec="P004735">P004735</a></td><td class="tf"><span class="plain outer  hlbx" >2b2B2. <span class="plain " >(<span class="plain " >[<span class="plain " >...</span>]</span>)a</span><span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> </span></td></tr>
# <tr class="tf"><td class="tf">7</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P218054" title="to CDLI main page for this tablet" sec="P218054">P218054</a></td><td class="tf"><span class="plain outer  hlbx" >1a1A1. <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >5(N01)</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >UDU~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">8</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P218054" title="to CDLI main page for this tablet" sec="P218054">P218054</a></td><td class="tf"><span class="plain outer  hlbx" >1a1A2. <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >7(N01)</span> <span class="plain " >MASZ2</span> </span></td></tr>
# <tr class="tf"><td class="tf">9</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P325754" title="to CDLI main page for this tablet" sec="P325754">P325754</a></td><td class="tf"><span class="plain outer  hlbx" >1c2b1. <span class="plain " >1(N01)</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> </span></td></tr>
# <tr class="tf"><td class="tf">10</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P325754" title="to CDLI main page for this tablet" sec="P325754">P325754</a></td><td class="tf"><span class="plain outer  hlbx" >1c2b2. <span class="plain " >1(N14)</span> <span class="plain " >7(N01)</span> <span class="plain " >TUR</span> </span></td></tr>
# <tr class="tf"><td class="tf">11</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P325754" title="to CDLI main page for this tablet" sec="P325754">P325754</a></td><td class="tf"><span class="plain outer  hlbx" >1c2b3. <span class="plain " >2(N14)</span> <span class="plain " >6(N01)</span> <span class="plain " >SUR</span> </span></td></tr>
# <tr class="tf"><td class="tf">12</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P325234" title="to CDLI main page for this tablet" sec="P325234">P325234</a></td><td class="tf"><span class="plain outer  hlbx" >1c5a1. <span class="plain " >8(N01)</span> <span class="plain " >GAR</span> <span class="plain " >U2~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">13</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P325234" title="to CDLI main page for this tablet" sec="P325234">P325234</a></td><td class="tf"><span class="plain outer  hlbx" >1c5a2. <span class="plain " >|<span class="plain " >SZU2</span>.<span class="plain " >E2~b</span>|</span> <span class="plain " >SZU2</span> <span class="plain " >E2~b</span> </span></td></tr>
# <tr class="tf"><td class="tf">14</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P411608" title="to CDLI main page for this tablet" sec="P411608">P411608</a></td><td class="tf"><span class="plain outer  hlbx" >1b2a1. <span class="plain " >1(N01)</span> <span class="plain " >GAL~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">15</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P411608" title="to CDLI main page for this tablet" sec="P411608">P411608</a></td><td class="tf"><span class="plain outer  hlbx" >1b2a2. <span class="plain " >1(N01)</span> <span class="plain " >GA2~a1</span> <span class="plain " >TUR</span> </span></td></tr>
# <tr class="tf"><td class="tf">16</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P411608" title="to CDLI main page for this tablet" sec="P411608">P411608</a></td><td class="tf"><span class="plain outer  hlbx" >1b2b1. <span class="plain " >1(N01)</span> <span class="plain " >|<span class="plain " >U4</span>x<span class="plain " >3(N57)</span>|</span> <span class="plain " >U4</span> <span class="plain " >3(N57)</span> </span></td></tr>
# <tr class="tf"><td class="tf">17</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P411608" title="to CDLI main page for this tablet" sec="P411608">P411608</a></

# %% [markdown]
# Terminal cases at depth 1 are top-level divisions of lines that are not themselves divided further.

# %%
query = '''
case depth=1 terminal
'''
results = A.search(query)
A.table(results, end=20)
tc1 = len(results)
# Out:
#   0.03s 5468 results
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">case</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain " >2(N14)</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~b</span> <span class="plain " >NUN~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  hlbx" >2b. <span class="plain " >3(N01)</span> <span class="plain " >KASZ~a</span> <span class="plain " >GI</span> </span></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P471695" title="to CDLI main page for this tablet" sec="P471695">P471695</a></td><td class="tf"><span class="plain outer  hlbx" >1a. <span class="plain " >3(N01)</span> <span class="plain " >APIN~a</span> <span class="plain " >3(N57)</span> <span class="plain " >UR4~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P471695" title="to CDLI main page for this tablet" sec="P471695">P471695</a></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >1(N14)</span> <span class="plain " >2(N01)</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> </span></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P471695" title="to CDLI main page for this tablet" sec="P471695">P471695</a></td><td class="tf"><span class="plain outer  hlbx" >1a. <span class="plain " >1(N01)</span> <span class="plain " >ISZ~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P482083" title="to CDLI main page for this tablet" sec="P482083">P482083</a></td><td class="tf"><span class="plain outer  hlbx" >1a. <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >1(N14)</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >SZE~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">7</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P482083" title="to CDLI main page for this tablet" sec="P482083">P482083</a></td><td class="tf"><span class="plain outer  hlbx" >1b. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain " >TAR~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">8</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P482083" title="to CDLI main page for this tablet" sec="P482083">P482083</a></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >3(N01)</span> <span class="plain " >SZE~a</span> <span class="plain " >KASZ~b</span> <span class="plain " >|<span class="plain " >U4</span>x<span class="plain " >3(N01)</span>|</span> <span class="plain " >U4</span> <span class="plain " >3(N01)</span> </span></td></tr>
# <tr class="tf"><td class="tf">9</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P482083" title="to CDLI main page for this tablet" sec="P482083">P482083</a></td><td class="tf"><span class="plain outer  hlbx" >2b. <span class="plain " ></span> <span class="plain " >1(N42~a)</span> <span class="plain " >1(N25)</span> <span class="plain " >TAR~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">10</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006438" title="to CDLI main page for this tablet" sec="P006438">P006438</a></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >KU6~a</span> <span class="plain " >BU~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">11</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006438" title="to CDLI main page for this tablet" sec="P006438">P006438</a></td><td class="tf"><span class="plain outer  hlbx" >2b. <span class="plain " >|<span class="plain " >AB~a</span>x<span class="plain " >SUKKAL</span>|</span> <span class="plain " >AB~a</span> <span class="plain " >SUKKAL</span> </span></td></tr>
# <tr class="tf"><td class="tf">12</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006438" title="to CDLI main page for this tablet" sec="P006438">P006438</a></td><td class="tf"><span class="plain outer  hlbx" >2c. <span class="plain " >NAM2</span> <span class="plain " >RAD~a</span> <span class="plain " >PA~a</span> <span class="plain " >SZU</span> </span></td></tr>
# <tr class="tf"><td class="tf">13</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006438" title="to CDLI main page for this tablet" sec="P006438">P006438</a></td><td class="tf"><span class="plain outer  hlbx" >2d. <span class="plain " >RAD~a</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> </span></td></tr>
# <tr class="tf"><td class="tf">14</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P000735" title="to CDLI main page for this tablet" sec="P000735">P000735</a></td><td class="tf"><span class="plain outer  hlbx" >1a. <span class="plain " >2(N39~a)</span> <span class="plain " >HI@g~a</span> <span class="plain " >EN~a</span> <span class="plain " >SZIM~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">15</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P000735" title="to CDLI main page for this tablet" sec="P000735">P000735</a></td><td class="tf"><span class="plain outer  hlbx" >1b. <span class="plain " >2(N01)</span> <span class="plain " >1(N24)</span> <span class="plain " >1(N28)</span> <span class="plain " >1(N30~c)</span> <span class="plain " >SZE~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">16</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P000743" title="to CDLI main page for this tablet" sec="P000743">P000743</a></td><td class="tf"><span class="plain outer  hlbx" >1b. <span class="plain " >4(N39~a)</span> <span class="plain " >1(N24)</span> <span class="plain " >1(N28)</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >|<span class="plain " >ZATU714</span>x<span class="plain " >HI@g~a</span>|</span> <span class="plain " >ZATU714</span> <span class="plain " >HI@g~a</span> <span class="plain " >MU</span> </span></td></tr>
# <tr class="tf"><td class="tf">17</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P000759" title="to CDLI main page for this tablet" sec="P000759">P000759</a></td><td class="tf"><span class="plain outer  hlbx" >1b. <span class="plain " >4(N42~a)</span> <span class="plain " >[<span class="plain " >1(N25)</span> <span class="plain " >1(N28~c)</span>]</span><span class="plain " >1(N25)</span> <span class="plain " >1(N28~c)</span> <span c

# %% [markdown]
# Now let us select both the terminal cases of level 1 and 4.
# They are disjunct, so the amounts should add up.

# %%
query = '''
case depth=1|4 terminal
'''
results = A.search(query)
A.table(results, end=20)
tc14 = len(results)
print(f'{tc1} + {tc4} = {tc1 + tc4} = {tc14}')
# Out:
#   0.03s 5587 results
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">case</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain " >2(N14)</span> <span class="plain " >3(N01)</span> <span class="plain " >KASZ~b</span> <span class="plain " >NUN~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  hlbx" >2b. <span class="plain " >3(N01)</span> <span class="plain " >KASZ~a</span> <span class="plain " >GI</span> </span></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P471695" title="to CDLI main page for this tablet" sec="P471695">P471695</a></td><td class="tf"><span class="plain outer  hlbx" >1a. <span class="plain " >3(N01)</span> <span class="plain " >APIN~a</span> <span class="plain " >3(N57)</span> <span class="plain " >UR4~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P471695" title="to CDLI main page for this tablet" sec="P471695">P471695</a></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >1(N14)</span> <span class="plain " >2(N01)</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> </span></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P471695" title="to CDLI main page for this tablet" sec="P471695">P471695</a></td><td class="tf"><span class="plain outer  hlbx" >1a. <span class="plain " >1(N01)</span> <span class="plain " >ISZ~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P482083" title="to CDLI main page for this tablet" sec="P482083">P482083</a></td><td class="tf"><span class="plain outer  hlbx" >1a. <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >1(N14)</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >SZE~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">7</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P482083" title="to CDLI main page for this tablet" sec="P482083">P482083</a></td><td class="tf"><span class="plain outer  hlbx" >1b. <span class="plain " >[<span class="plain " >N</span>]</span><span class="plain " >N</span> <span class="plain " >TAR~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">8</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P482083" title="to CDLI main page for this tablet" sec="P482083">P482083</a></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >3(N01)</span> <span class="plain " >SZE~a</span> <span class="plain " >KASZ~b</span> <span class="plain " >|<span class="plain " >U4</span>x<span class="plain " >3(N01)</span>|</span> <span class="plain " >U4</span> <span class="plain " >3(N01)</span> </span></td></tr>
# <tr class="tf"><td class="tf">9</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P482083" title="to CDLI main page for this tablet" sec="P482083">P482083</a></td><td class="tf"><span class="plain outer  hlbx" >2b. <span class="plain " ></span> <span class="plain " >1(N42~a)</span> <span class="plain " >1(N25)</span> <span class="plain " >TAR~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">10</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006438" title="to CDLI main page for this tablet" sec="P006438">P006438</a></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >KU6~a</span> <span class="plain " >BU~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">11</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006438" title="to CDLI main page for this tablet" sec="P006438">P006438</a></td><td class="tf"><span class="plain outer  hlbx" >2b. <span class="plain " >|<span class="plain " >AB~a</span>x<span class="plain " >SUKKAL</span>|</span> <span class="plain " >AB~a</span> <span class="plain " >SUKKAL</span> </span></td></tr>
# <tr class="tf"><td class="tf">12</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006438" title="to CDLI main page for this tablet" sec="P006438">P006438</a></td><td class="tf"><span class="plain outer  hlbx" >2c. <span class="plain " >NAM2</span> <span class="plain " >RAD~a</span> <span class="plain " >PA~a</span> <span class="plain " >SZU</span> </span></td></tr>
# <tr class="tf"><td class="tf">13</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006438" title="to CDLI main page for this tablet" sec="P006438">P006438</a></td><td class="tf"><span class="plain outer  hlbx" >2d. <span class="plain " >RAD~a</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> </span></td></tr>
# <tr class="tf"><td class="tf">14</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P000735" title="to CDLI main page for this tablet" sec="P000735">P000735</a></td><td class="tf"><span class="plain outer  hlbx" >1a. <span class="plain " >2(N39~a)</span> <span class="plain " >HI@g~a</span> <span class="plain " >EN~a</span> <span class="plain " >SZIM~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">15</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P000735" title="to CDLI main page for this tablet" sec="P000735">P000735</a></td><td class="tf"><span class="plain outer  hlbx" >1b. <span class="plain " >2(N01)</span> <span class="plain " >1(N24)</span> <span class="plain " >1(N28)</span> <span class="plain " >1(N30~c)</span> <span class="plain " >SZE~a</span> </span></td></tr>
# <tr class="tf"><td class="tf">16</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P000743" title="to CDLI main page for this tablet" sec="P000743">P000743</a></td><td class="tf"><span class="plain outer  hlbx" >1b. <span class="plain " >4(N39~a)</span> <span class="plain " >1(N24)</span> <span class="plain " >1(N28)</span> <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >|<span class="plain " >ZATU714</span>x<span class="plain " >HI@g~a</span>|</span> <span class="plain " >ZATU714</span> <span class="plain " >HI@g~a</span> <span class="plain " >MU</span> </span></td></tr>
# <tr class="tf"><td class="tf">17</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P000759" title="to CDLI main page for this tablet" sec="P000759">P000759</a></td><td class="tf"><span class="plain outer  hlbx" >1b. <span class="plain " >4(N42~a)</span> <span class="plain " >[<span class="plain " >1(N25)</span> <span class="plain " >1(N28~c)</span>]</span><span class="plain " >1(N25)</span> <span class="plain " >1(N28~c)</span> <span c
# 5468 + 119 = 5587 = 5587

# %% [markdown]
# ## Relational patterns: quads
#
# Quads are compositions of signs by means of *operators*, such as `.` and `x`.
# The operators are coded as an *edge* feature with values. The `op`-edges are between the signs/quads that are combined,
# and the values of the `op` edges are the names of the operators in question.
#
# Which operators do we have?

# %%
for (op, freq) in E.op.freqList():
    print(f'{op} : {freq:>5}x')
# Out:
# x :  2346x
# . :  1042x
# & :   222x
# + :   200x

# %% [markdown]
# Between how many sign pairs do we have an operator?

# %%
query = '''
sign
-op> sign
'''
results = A.search(query)
# Out:
#   0.21s 3642 results

# %% [markdown]
# Lets specifically ask for the `x` operator:

# %%
query = '''
sign
-op=x> sign
'''
results = A.search(query)
# Out:
#   0.21s 2238 results

# %% [markdown]
# Less than expected?
#
# We must not forget the combinations between quads and between quads and signs.
#
# We write a function that gives all pairs of sign/quads connected by a specific operator.
#
# This is a fine illustration of how you can use programming to compose search templates,
# instead of writing them out yourself.

# %%
def getCombi(op):
    types = ('sign', 'quad')
    allResults = []
    for type1 in types:
        for type2 in types:
            query = f'''
{type1}
-op{op}> {type2}
'''
            results = A.search(query, silent=True)
            print(f'{len(results):>5} {type1} {op} {type2}')
            allResults += results
    print(f'{len(allResults):>5} {op}')

# %% [markdown]
# Now we can count all combinations with `x`:

# %%
getCombi('=x')
# Out:
#  2238 sign =x sign
#   105 sign =x quad
#     3 quad =x sign
#     0 quad =x quad
#  2346 =x

# %%
getCombi('=.')
# Out:
#   985 sign =. sign
#    43 sign =. quad
#    14 quad =. sign
#     0 quad =. quad
#  1042 =.

# %%
getCombi('=&')
# Out:
#   220 sign =& sign
#     1 sign =& quad
#     0 quad =& sign
#     1 quad =& quad
#   222 =&

# %%
getCombi('=+')
# Out:
#   199 sign =+ sign
#     0 sign =+ quad
#     0 quad =+ sign
#     1 quad =+ quad
#   200 =+

# %% [markdown]
# In exact agreement with the results of `E.op.freqList()` above.
# But we are more flexible!
#
# We can ask for more operators at the same time.

# %%
getCombi('=x|+')
# Out:
#  2437 sign =x|+ sign
#   105 sign =x|+ quad
#     3 quad =x|+ sign
#     1 quad =x|+ quad
#  2546 =x|+

# %%
getCombi('~[^a-z]')
# Out:
#  1404 sign ~[^a-z] sign
#    44 sign ~[^a-z] quad
#    14 quad ~[^a-z] sign
#     2 quad ~[^a-z] quad
#  1464 ~[^a-z]

# %% [markdown]
# Finally, we zoom in on the rare cases where the operator is `x` used between a quad and a sign.
# We want to see the show the lines where they occur.

# %%
query = '''
line
  quad
  -op=x> sign
'''
results = A.search(query)
A.show(results, withNodes=True, lineart=True, condenseType="line")
# Out:
#   0.13s 3 results
# <p><b>result</b> <i>1</i></p>
# <div class="contnr trminal " >
#     <div class="lbl trminal"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P002264" title="to CDLI main page for this tablet" sec="P002264">line 1</a> <span class="nd">244724</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? <span class="nd">210220</span></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">67704</span></div>
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#         <span class="nd">210220</span>
#     </div>
#
# <div class="contnr quad " >
#     <div class="lbl quad"> <span class="nd">141950</span></div>
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr quad hl" >
#     <div class="lbl quad"> <span class="nd">141951</span></div>
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">67705</span></div>
#     <div class="meta">
#          <span class="srcln">GI</span><div class="features"></div>
#
#     </div>
# </div><div class="op">&</div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">67706</span></div>
#     <div class="meta">
#          <span class="srcln">GI</span><div class="features"></div>
#
#     </div>
# </div></div></div><div class="op">x</div>
# <div class="contnr sign hl" >
#     <div class="lbl sign"> <span class="nd">67707</span></div>
#     <div class="meta">
#          <span class="srcln">SZE3</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">67708</span></div>
#     <div class="meta">
#          <span class="srcln">UR2</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/UR2.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ur2.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div><div class="lbl clusterb">? <span class="nd">210221</span></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">67709</span></div>
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#         <span class="nd">210221</span>
#     </div>
# </div></div>
# <p><b>result</b> <i>2</i></p>
# <div class="contnr trminal " >
#     <div class="lbl trminal"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P002624" title="to CDLI main page for this tablet" sec="P002624">line 3</a> <span class="nd">255152</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr quad " >
#     <div class="lbl quad"> <span class="nd">143120</span></div>
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr quad hl" >
#     <div class="lbl quad"> <span class="nd">143121</span></div>
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">110687</span></div>
#     <div class="meta">
#          <span class="srcln">GI</span><div class="features"></div>
#
#     </div>
# </div><div class="op">&</div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">110688</span></div>
#     <div class="meta">
#          <span class="srcln">GI</span><div class="features"></div>
#
#     </div>
# </div></div></div><div class="op">x</div>
# <div class="contnr sign hl" >
#     <div class="lbl sign"> <span class="nd">110689</span></div>
#     <div class="meta">
#          <span class="srcln">SZE3</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">110690</span></div>
#     <div class="meta">
#          <span class="srcln">3(N57)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N57).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n57).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div></div></div>
# <p><b>result</b> <i>3</i></p>
# <div class="contnr trminal " >
#     <div class="lbl trminal"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P004659" title="to CDLI main page for this tablet" sec="P004659">line 2</a> <span class="nd">260576</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">131407</span></div>
#     <div class="meta">
#          <span class="srcln">1(N48)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N48).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n48).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">131408</span></div>
#     <div class="meta">
#          <span class="srcln">8(N34)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/8(N34).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-8(n34).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr quad " >
#     <div class="lbl quad"> <span class="nd">143672</span></div>
#     <div class="meta">
#
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|(GI&amp;GI)xGISZ@t|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-q(gi(e)gi)xgisz(a)tq.jpg" style="display: inline;max-width: 4em; max-height: 6em;"  /></a></div><div class="children quad">
# <div class="contnr quad hl" >
#     <div class="lbl quad"> <span class="nd">143673</span></div>
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">131409</span></div>
#     <div class="meta">
#          <span class="srcln">GI</span><div class="features"></div>
#
#     </div>
# </div><div class="op">&</div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">131410</span></div>
#     <div class="meta">
#          <span class="srcln">GI</span><div class="features"></div>
#
#     </div>
# </div></div></div><div class="op">x</div>
# <div class="contnr sign hl" >
#     <div class="lbl sign"> <span class="nd">131411</span></div>
#     <div class="meta">
#          <span class="srcln">GISZ@t</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">131412</span></div>
#     <div class="meta">
#          <span class="srcln">ZATU659</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/ZATU659.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-zatu659.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">131413</span></div>
#     <div class="meta">
#          <span class="srcln">USZ~a</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/USZ~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-usz-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">131414</span></div>
#     <div class="meta">
#          <span class="srcln">GU4</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/GU4.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-gu4.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div></div></div>

# %% [markdown]
# Hint: if you want to see where these lines come from, hover over the line indicator, or click on it.
#
# Alternatively, you can set the condense type to tablet.
# And note that we have set the base type to `quad`, so that the pretty display does not unravel the quads.

# %%
A.show(results, withNodes=True, lineart=True, condenseType="tablet", baseType="quad")
# Out:
# <p><b>result</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P002264" title="to CDLI main page for this tablet" sec="P002264">tablet P002264  <span class="name">IM 023435,19</span> <span class="period">uruk-iii</span> <span class="excavation">W 15771,h</span></a> <span class="nd">146811</span></div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta <span class="nd">176501</span></div>
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse <span class="nd">154869</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 <span class="nd">186837</span></div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">1 <span class="nd">244724</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? <span class="nd">210220</span></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">67704</span></div>
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#         <span class="nd">210220</span>
#     </div>
#
# <div class="contnr quad " >
#     <div class="lbl quad"><span class="plain outer  " >|<span class="plain outer  hl" >(<span class="plain outer  " >GI</span>&<span class="plain outer  " >GI</span>)</span>x<span class="plain outer  hlbx" >SZE3</span>|</span>   <span class="nd">141950</span></div>
#     <div class="meta">
#
#
#     </div>
# </div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">67708</span></div>
#     <div class="meta">
#          <span class="srcln">UR2</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/UR2.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ur2.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div><div class="lbl clusterb">? <span class="nd">210221</span></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">67709</span></div>
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#         <span class="nd">210221</span>
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 <span class="nd">244725</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr quad " >
#     <div class="lbl quad"><span class="plain outer  " >|<span class="plain outer  " >SILA3~a</span>x<span class="plain outer  " >DUG~a</span>|</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|SILA3~axDUG~a|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-qsila3-axdug-aq.jpg" style="display: inline;max-width: 4em; max-height: 6em;"  /></a> <span class="nd">141952</span></div>
#     <div class="meta">
#
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|SILA3~axDUG~a|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-qsila3-axdug-aq.jpg" style="display: inline;max-width: 4em; max-height: 6em;"  /></a></div></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">67712</span></div>
#     <div class="meta">
#          <span class="srcln">MEN~a</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/MEN~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-men-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">67713</span></div>
#     <div class="meta">
#          <span class="srcln">SUKKAL</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SUKKAL.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sukkal.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">67714</span></div>
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">67715</span></div>
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? <span class="nd">210222</span></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">67716</span></div>
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#         <span class="nd">210222</span>
#     </div>
# </div></div></div></div></div></div></div></div>
# <p><b>result</b> <i>2</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P002624" title="to CDLI main page for this tablet" sec="P002624">tablet P002624  <span class="name">W 17480,b</span> <span class="period">uruk-iii</span> <span class="excavation">W 17480,b</span></a> <span class="nd">148296</span></div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta <span class="nd">178317</span></div>
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse <span class="nd">157130</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 <span class="nd">190707</span></div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 <span class="nd">255146</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">110674</span></div>
#     <div class="meta">
#          <span class="srcln">TUM~b</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/TUM~b.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-tum-b.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div><div class="lbl clusterb">? <span class="nd">220130</span></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">110675</span></div>
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#         <span class="nd">220130</span>
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 <span class="nd">255147</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">110676</span></div>
#     <div class="meta">
#          <span class="srcln">SU~a</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SU~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-su-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div><div class="lbl clusterb">? <span class="nd">220131</span></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">110677</span></div>
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#         <span class="nd">220131</span>
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 <span class="nd">255148</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">110678</span></div>
#     <div class="meta">
#          <span class="srcln">PIRIG~b1</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/PIRIG~b1.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-pirig-b1.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">110679</span></div>
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">4 <span class="nd">255149</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">110680</span></div>
#     <div class="meta">
#          <span class="srcln">NA2~a</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/NA2~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-na2-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div><div class="lbl clusterb">? <span class="nd">220132</span></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">110681</span></div>
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#         <span class="nd">220132</span>
#     </div>
# </div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">2 <span class="nd">190708</span></div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 <span class="nd">255150</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">110682</span></div>
#     <div class="meta">
#          <span class="srcln">RU</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/RU.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-ru.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div><div class="lbl clusterb">? <span class="nd">220133</span></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">110683</span></div>
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#         <span class="nd">220133</span>
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 <span class="nd">255151</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr quad " >
#     <div class="lbl quad"><span class="plain outer  " >|<span class="plain outer  " >BU~b</span>.<span class="plain outer  " >NA2~a</span>|</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|BU~b.NA2~a|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-qbu-b(d)na2-aq.jpg" style="display: inline;max-width: 4em; max-height: 6em;"  /></a> <span class="nd">143119</span></div>
#     <div class="meta">
#
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|BU~b.NA2~a|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-qbu-b(d)na2-aq.jpg" style="display: inline;max-width: 4em; max-height: 6em;"  /></a></div></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">110686</span></div>
#     <div class="meta">
#          <span class="srcln">3(N57)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N57).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n57).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div></div></div>
# <p><b>result</b> <i>3</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P004659" title="to CDLI main page for this tablet" sec="P004659">tablet P004659  <span class="name">ATU 7, pl. 091, W 22133</span> <span class="period">uruk-iv</span> <span class="excavation">W 22133</span></a> <span class="nd">149624</span></div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta <span class="nd">179698</span></div>
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse <span class="nd">158867</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 <span class="nd">193298</span></div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 <span class="nd">260575</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">131403</span></div>
#     <div class="meta">
#          <span class="srcln">1(N34)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N34).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n34).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">131404</span></div>
#     <div class="meta">
#          <span class="srcln">3(N14)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n14).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">131405</span></div>
#     <div class="meta">
#          <span class="srcln">2(N01)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N01).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n01).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">131406</span></div>
#     <div class="meta">
#          <span class="srcln">SZE3</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SZE3.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sze3.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div></div></div>
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2 <span class="nd">260576</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">131407</span></div>
#     <div class="meta">
#          <span class="srcln">1(N48)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N48).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n48).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">131408</span></div>
#     <div class="meta">
#          <span class="srcln">8(N34)</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/8(N34).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-8(n34).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr quad " >
#     <div class="lbl quad"><span class="plain outer  " >|<span class="plain outer  hl" >(<span class="plain outer  " >GI</span>&<span class="plain outer  " >GI</span>)</span>x<span class="plain outer  hlbx" >GISZ@t</span>|</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|(GI&amp;GI)xGISZ@t|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-q(gi(e)gi)xgisz(a)tq.jpg" style="display: inline;max-width: 4em; max-height: 6em;"  /></a> <span class="nd">143672</span></div>
#     <div class="meta">
#
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/|(GI&amp;GI)xGISZ@t|.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-q(gi(e)gi)xgisz(a)tq.jpg" style="display: inline;max-width: 4em; max-height: 6em;"  /></a></div></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">131412</span></div>
#     <div class="meta">
#          <span class="srcln">ZATU659</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/ZATU659.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-zatu659.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">131413</span></div>
#     <div class="meta">
#          <span class="srcln">USZ~a</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/USZ~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-usz-a.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">131414</span></div>
#     <div class="meta">
#          <span class="srcln">GU4</span><div class="features"></div>
#
#     </div>
# <div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/GU4.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-gu4.jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></div></div></div></div></div></div></div></div>
# <div class="contnr face " >
#     <div class="lbl face">reverse <span class="nd">158868</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 <span class="nd">193299</span></div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 <span class="nd">260577</span></div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? <span class="nd">225099</span></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">131415</span></div>
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#         <span class="nd">225099</span>
#     </div>
# <div class="lbl clusterb">? <span class="nd">225100</span></div>
# <div class="contnr sign " >
#     <div class="lbl sign"> <span class="nd">131416</span></div>
#     <div class="meta">
#          <span class="srcln">...</span

# %% [markdown]
# ## Regular expressions in templates
# We can use regular expressions in our search templates.
#
# ### Digits in graphemes
# We search for non-numeral signs whose graphemes contains digits.

# %%
A.displaySetup(condensed=True)

# %%
query = '''
sign type=ideograph grapheme~[0-9]
'''
results = A.search(query)
A.table(results, withNodes=True, end=5)
# Out:
#   0.27s 14558 results
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">tablet</th><th class="tf">sign</th><th class="tf">sign</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  " >tablet P448702</span></td><td class="tf"><span class="plain outer  hl" >U4</span> <span class="plain nd">75</span></td><td class="tf"><span class="plain outer  hl" >U4</span> <span class="plain nd">76</span></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448703" title="to CDLI main page for this tablet" sec="P448703">P448703</a></td><td class="tf"><span class="plain outer  " >tablet P448703</span></td><td class="tf"><span class="plain outer  hl" >U4</span> <span class="plain nd">97</span></td><td class="tf"><span class="plain outer  hl" >U4</span> <span class="plain nd">100</span></td><td class="tf"><span class="plain outer  hl" >U4</span> <span class="plain nd">87</span></td><td class="tf"><span class="plain outer  hl" >U4</span> <span class="plain nd">90</span></td><td class="tf"><span class="plain outer  hl" >U4</span> <span class="plain nd">93</span></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P471695" title="to CDLI main page for this tablet" sec="P471695">P471695</a></td><td class="tf"><span class="plain outer  " >tablet P471695</span></td><td class="tf"><span class="plain outer  hl" >ZATU759</span> <span class="plain nd">114</span></td><td class="tf"><span class="plain outer  hl" >GIR3~c</span> <span class="plain nd">140</span></td><td class="tf"><span class="plain outer  hl" >UR4~a</span> <span class="plain nd">111</span></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P482082" title="to CDLI main page for this tablet" sec="P482082">P482082</a></td><td class="tf"><span class="plain outer  " >tablet P482082</span></td><td class="tf"><span class="plain outer  hl" >ZATU694~c</span> <span class="plain nd">155</span></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P482083" title="to CDLI main page for this tablet" sec="P482083">P482083</a></td><td class="tf"><span class="plain outer  " >tablet P482083</span></td><td class="tf"><span class="plain outer  hl" >U4</span> <span class="plain nd">169</span></td></tr></table>

# %% [markdown]
# We can add a bit more context easily:

# %%
query = '''
tablet
  face
    column
      line
        sign type=ideograph grapheme~[0-9]
'''
results = A.search(query)
A.table(results, condensed=False, end=20)
# Out:
#   0.41s 14558 results
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">tablet</th><th class="tf">face</th><th class="tf">column</th><th class="tf">line</th><th class="tf">sign</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  " >tablet P448702</span></td><td class="tf"><span class="plain outer  hlbx" >face obverse</span></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a>&nbsp;<span class="plain outer  hlbx" >column 2</span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></span>&nbsp;<span class="plain outer  hlbx" >1. <span class="plain hl" >U4</span> <span class="plain " >|<span class="plain " >U4</span>x<span class="plain " >1(N01)</span>|</span> <span class="plain " >U4</span> <span class="plain " >1(N01)</span> <span class="plain " >SAG</span> <span class="plain " >SUKUD@h</span> <span class="plain " >NA</span> </span></span></td><td class="tf"><span class="plain outer  hl" >U4</span> </td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></td><td class="tf"><span class="plain outer  " >tablet P448702</span></td><td class="tf"><span class="plain outer  hlbx" >face obverse</span></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a>&nbsp;<span class="plain outer  hlbx" >column 2</span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448702" title="to CDLI main page for this tablet" sec="P448702">P448702</a></span>&nbsp;<span class="plain outer  hlbx" >1. <span class="plain " >U4</span> <span class="plain " >|<span class="plain hl" >U4</span>x<span class="plain " >1(N01)</span>|</span> <span class="plain hl" >U4</span> <span class="plain " >1(N01)</span> <span class="plain " >SAG</span> <span class="plain " >SUKUD@h</span> <span class="plain " >NA</span> </span></span></td><td class="tf"><span class="plain outer  hl" >U4</span> </td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448703" title="to CDLI main page for this tablet" sec="P448703">P448703</a></td><td class="tf"><span class="plain outer  " >tablet P448703</span></td><td class="tf"><span class="plain outer  hlbx" >face obverse</span></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448703" title="to CDLI main page for this tablet" sec="P448703">P448703</a>&nbsp;<span class="plain outer  hlbx" >column 1</span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448703" title="to CDLI main page for this tablet" sec="P448703">P448703</a></span>&nbsp;<span class="plain outer  hlbx" >1. <span class="plain " >|<span class="plain hl" >U4</span>.<span class="plain " >1(N08)</span>|</span> <span class="plain hl" >U4</span> <span class="plain " >1(N08)</span> <span class="plain " >X</span> </span></span></td><td class="tf"><span class="plain outer  hl" >U4</span> </td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448703" title="to CDLI main page for this tablet" sec="P448703">P448703</a></td><td class="tf"><span class="plain outer  " >tablet P448703</span></td><td class="tf"><span class="plain outer  hlbx" >face obverse</span></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448703" title="to CDLI main page for this tablet" sec="P448703">P448703</a>&nbsp;<span class="plain outer  hlbx" >column 1</span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448703" title="to CDLI main page for this tablet" sec="P448703">P448703</a></span>&nbsp;<span class="plain outer  hlbx" >2. <span class="plain " >|<span class="plain hl" >U4</span>.<span class="plain " >1(N08)</span>|</span> <span class="plain hl" >U4</span> <span class="plain " >1(N08)</span> <span class="plain " >GI</span> </span></span></td><td class="tf"><span class="plain outer  hl" >U4</span> </td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448703" title="to CDLI main page for this tablet" sec="P448703">P448703</a></td><td class="tf"><span class="plain outer  " >tablet P448703</span></td><td class="tf"><span class="plain outer  hlbx" >face obverse</span></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448703" title="to CDLI main page for this tablet" sec="P448703">P448703</a>&nbsp;<span class="plain outer  hlbx" >column 1</span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448703" title="to CDLI main page for this tablet" sec="P448703">P448703</a></span>&nbsp;<span class="plain outer  hlbx" >3. <span class="plain " >|<span class="plain hl" >U4</span>.<span class="plain " >1(N08)</span>|</span> <span class="plain hl" >U4</span> <span class="plain " >1(N08)</span> <span class="plain " >|<span class="plain " >GI</span>&<span class="plain " >GI</span>|</span> <span class="plain " >GI</span> <span class="plain " >GI</span> </span></span></td><td class="tf"><span class="plain outer  hl" >U4</span> </td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448703" title="to CDLI main page for this tablet" sec="P448703">P448703</a></td><td class="tf"><span class="plain outer  " >tablet P448703</span></td><td class="tf"><span class="plain outer  hlbx" >face obverse</span></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448703" title="to CDLI main page for this tablet" sec="P448703">P448703</a>&nbsp;<span class="plain outer  hlbx" >column 1</span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448703" title="to CDLI main page for this tablet" sec="P448703">P448703</a></span>&nbsp;<span class="plain outer  hlbx" >4. <span class="plain " >|<span class="plain hl" >U4</span>.<span class="plain " >1(N08)</span>|</span> <span class="plain hl" >U4</span> <span class="plain " >1(N08)</span> <span class="plain " >X</span> </span></span></td><td class="tf"><span class="plain outer  hl" >U4</span> </td></tr>
# <tr class="tf"><td class="tf">7</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448703" title="to CDLI main page for this tablet" sec="P448703">P448703</a></td><td class="tf"><span class="plain outer  " >tablet P448703</span></td><td class="tf"><span class="plain outer  hlbx" >face obverse</span></td><td class="tf"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448703" title="to CDLI main page for this tablet" sec="P448703">P448703</a>&nbsp;<span class="plain outer  hlbx" >column 1</span></td><td class="tf"><span class="vrs ltr"><a href="https://cdli.ucla.edu/s

# %% [markdown]
# ### Pit numbers
#
# The feature `excavation` gives you the number of the pit where a tablet is found.
# The syntax of pit numbers is a bit involved, here are a few possible values:
#
# ```
# W 20497
# W 20335,3
# W 19948,10
# W 20493,26
# W 17890,b
# W 17729,o
# W 15920,b5
# W 17729,aq
# W 19548,a + W 19548,b
# W 17729,cn + W 17729,eq
# W 14337,a + W 14337,b + W 14337,c + W 14337,d + W 14337,e
# Ashm 1928-445b
# ```
#
# Let's assume we are interested in `SZITA~a1` signs occurring in cases of depth 1.
# The following query finds them all:

# %%
query = '''
tablet
  case depth=1
    sign grapheme=SZITA variant=a1
'''
results = A.search(query)
# Out:
#   0.18s 78 results

# %% [markdown]
# Now we want to organize them by excavation number:

# %%
signPerPit = {}

for (tablet, case, sign) in sorted(results):
    pit = F.excavation.v(tablet) or 'no pit information'
    signPerPit.setdefault(pit, []).append(sign)

for pit in sorted(signPerPit):
    print(f'{pit:<30} {len(signPerPit[pit]):>2}')
# Out:
# Ashm 1926,562                   1
# Ashm 1926,567                   1
# Ashm 1926,569                  13
# Ashm 1926,695+737+741           6
# Ashm 1926,716+732               1
# Ashm 1926,739                   1
# W 14731,z                       1
# W 14777,c                       4
# W 15776,i                       1
# W 15785,a2                      1
# W 15833,a01 + W 15833,aa04      1
# W 15897,b5                      1
# W 15897,c26                     1
# W 20274,001                     1
# W 20274,043                     1
# W 20274,095                     2
# W 20274,119                     1
# W 20327,01                      1
# W 20327,03                      1
# W 20511,01                      1
# W 20511,02                      6
# W 21157                         1
# W 21194                         1
# W 21733,1                       3
# W 22100,01                      4
# W 22100,03                      5
# W 22101,1                       1
# W 23950                         1
# W 23973,01                      1
# W 24033,05                      1
# no pit information             13

# %% [markdown]
# We can restrict results to those on tablets found in certain pits by constraining the search template.
# If we are interested in pit `20274` we can use a regular expression that matches all 4 detailed pit numbers
# based on `20274`.
# So, we do not say
#
# ```
# excavation=20274
# ```
# but
#
# ```
# excavation~20274
# ```

# %%
query = '''
tablet excavation~20274
  case depth=1
    sign grapheme=SZITA variant=a1
'''
results = A.search(query)
A.table(results, condensed=False, lineart=False)
# Out:
#   0.19s 5 results
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">tablet</th><th class="tf">case</th><th class="tf">sign</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003617" title="to CDLI main page for this tablet" sec="P003617">P003617</a></td><td class="tf"><span class="plain outer  " >tablet P003617</span></td><td class="tf"><span class="plain outer  hlbx" >2b. <span class="plain hl" >SZITA~a1</span> <span class="plain " >BU~a</span> </span></td><td class="tf"><span class="plain outer  hl" >SZITA~a1</span> </td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003499" title="to CDLI main page for this tablet" sec="P003499">P003499</a></td><td class="tf"><span class="plain outer  " >tablet P003499</span></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >GAL~a</span> <span class="plain hl" >SZITA~a1</span> </span></td><td class="tf"><span class="plain outer  hl" >SZITA~a1</span> </td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003541" title="to CDLI main page for this tablet" sec="P003541">P003541</a></td><td class="tf"><span class="plain outer  " >tablet P003541</span></td><td class="tf"><span class="plain outer  hlbx" >1b. <span class="plain " >GESZTU~b</span> <span class="plain hl" >SZITA~a1</span> <span class="plain " >ZATU686~a</span> </span></td><td class="tf"><span class="plain outer  hl" >SZITA~a1</span> </td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003593" title="to CDLI main page for this tablet" sec="P003593">P003593</a></td><td class="tf"><span class="plain outer  " >tablet P003593</span></td><td class="tf"><span class="plain outer  hlbx" >2a. <span class="plain " >[<span class="plain " >...</span>]</span><span class="plain " >...</span> <span class="plain " >GADA~a</span> <span class="plain hl" >SZITA~a1</span> <span class="plain " >X</span> </span></td><td class="tf"><span class="plain outer  hl" >SZITA~a1</span> </td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003593" title="to CDLI main page for this tablet" sec="P003593">P003593</a></td><td class="tf"><span class="plain outer  " >tablet P003593</span></td><td class="tf"><span class="plain outer  hlbx" >3b. <span class="plain " >GESZTU~b</span> <span class="plain hl" >SZITA~a1</span> <span class="plain " >ZATU686~a</span> </span></td><td class="tf"><span class="plain outer  hl" >SZITA~a1</span> </td></tr></table>

# %% [markdown]
# Or if we want to restrict ourselves to pit numbers with a `W`, we can say:

# %%
query = '''
tablet excavation~W
  case depth=1
    sign grapheme=SZITA variant=a1
'''
results = A.search(query)
# Out:
#   0.19s 42 results

# %% [markdown]
# ## Quantifiers in templates
#
# So far we have seen only very positive templates.
# They express what you want to see in the result.
#
# It is also possible to state conditions about what you do not want to see in the results.

# %% [markdown]
# ### Tablets without case divisions
#
# Let's find all tablets in which all lines are undivided, i.e. lines without cases.

# %%
query = '''
tablet
/without/
  case
/-/
'''

# %% [markdown]
# The expression
#
# ```
# /without/
# template
# /-/
# ```
#
# is a [quantifier](https://annotation.github.io/text-fabric/Use/Search/#quantifiers).
#
# It poses a condition on the preceding line in the template, in this case the `tablet`.
# And the condition is that the template
#
# ```
# tablet
#   case
# ```
#
# does not have results.

# %%
results = A.search(query)
# Out:
#   0.03s 5384 results

# %%
A.show(results, end=2)
# Out:
# <p><b>tablet</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006427" title="to CDLI main page for this tablet" sec="P006427">tablet P006427  <span class="name">Anonymous 006427</span> <span class="period">uruk-iii</span></a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SANGA~a</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div></div></div></div></div>
# <p><b>tablet</b> <i>2</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006428" title="to CDLI main page for this tablet" sec="P006428">tablet P006428  <span class="name">Anonymous 006428</span> <span class="period">uruk-iii</span></a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">3 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SUHUR</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">4 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">5 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">DUG~b</span><div class="features"></div>
#
#     </div>
# </div><div class="op">x</div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N57)</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">6 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">7 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">4 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </

# %% [markdown]
# Now let's find cases without numerals.

# %%
query = '''
case
/without/
  sign type=numeral
/-/
'''
results = A.search(query)
# Out:
#   0.21s 2833 results

# %% [markdown]
# We show a few.

# %%
A.show(results, end=2)
# Out:
# <p><b>tablet</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P471695" title="to CDLI main page for this tablet" sec="P471695">tablet P471695  <span class="name">Anonymous 471695</span> <span class="period">uruk-iii</span></a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr line " >
#     <div class="lbl line">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1a </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">APIN~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N57)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">UR4~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr case hl" >
#     <div class="lbl case">1b </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children casev">
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">1b1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalh"><div class="lbl clusterb">= </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">EN~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">DU</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">ZATU759</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         =
#
#     </div>
# </div></div>
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">1b2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalh"><div class="lbl clusterb">= </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">BAN~b</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KASZ~c</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         =
#
#     </div>
# </div></div>
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">1b3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalh"><div class="lbl clusterb">= </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KI@n</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SAG</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         =
#
#     </div>
# </div></div></div></div></div></div>
# <div class="contnr line " >
#     <div class="lbl line">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal " >
#     <div class="lbl trminal">2a </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">2(N01)</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr case " >
#     <div class="lbl case">2b </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children casev">
# <div class="contnr trminal " >
#     <div class="lbl trminal">2b1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalh"><div class="lbl clusterb">= </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N57)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">PAP~a</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         =
#
#     </div>
# </div></div>
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2b2 </div>
#     <div class="meta">
#         <div class="features"></div>
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">ruling </div>
#     <div class="meta">
#         <div class="features"> <span class="text">n lines broken</span></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children trminalh"><div class="lbl clusterb">= </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZU</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KI</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         =
#
#     </div>
# </div></div>
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2b3' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalh"><div class="lbl clusterb">= </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">EN~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">AN</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">EZINU~d</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         =
#
#     </div>
# </div></div>
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2b4' </div>
#     <div class="meta">
#         <div class="features"></div>
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">ruling </div>
#     <div class="meta">
#         <div class="features"> <span class="text">rest broken</span></div>
#
#     </div>
# <div class="children comment"></div></div>
# <div class="contnr comment " >
#     <div class="lbl comment">ruling </div>
#     <div class="meta">
#         <div class="features"> <span
# <p><b>tablet</b> <i>2</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006438" title="to CDLI main page for this tablet" sec="P006438">tablet P006438  <span class="name">AOST 109</span> <span class="period">uruk-iii</span></a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr line " >
#     <div class="lbl line">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2a </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KU6~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">BU~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2b </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">AB~a</span><div class="features"></div>
#
#     </div>
# </div><div class="op">x</div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SUKKAL</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2c </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NAM2</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">RAD~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">PA~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZU</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal hl" >
#     <div class="lbl trminal">2d </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">RAD~a</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div></div></div>
# <div class="contnr face " >
#     <div class="lbl face">reverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">USZ~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZUBUR</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GAL~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">IM~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZA</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">RAD~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">4 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class

# %% [markdown]
# Now we can use this to get something more sophisticated: the tablets that do not have numerals in their cases. So only undivided lines may contain numerals.
#
# Let's find tablets that do have cases, but just no cases with numerals.

# %%
query = '''
tablet
/where/
  case
/have/
  /without/
    sign type=numeral
  /-/
/-/
/with/
  case
/-/
'''

# %%
results = A.search(query)
# Out:
#   0.02s 53 results

# %%
A.show(results, end=2)
# Out:
# <p><b>tablet</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006438" title="to CDLI main page for this tablet" sec="P006438">tablet P006438  <span class="name">AOST 109</span> <span class="period">uruk-iii</span></a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr line " >
#     <div class="lbl line">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal " >
#     <div class="lbl trminal">2a </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KU6~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">BU~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2b </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">AB~a</span><div class="features"></div>
#
#     </div>
# </div><div class="op">x</div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SUKKAL</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2c </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NAM2</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">RAD~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">PA~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZU</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2d </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">RAD~a</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div></div></div>
# <div class="contnr face " >
#     <div class="lbl face">reverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">USZ~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZUBUR</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GAL~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">IM~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZA</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">RAD~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">4 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl cl
# <p><b>tablet</b> <i>2</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P002044" title="to CDLI main page for this tablet" sec="P002044">tablet P002044  <span class="name">ATU 6, pl. 043, W 14335,x</span> <span class="period">uruk-iii</span> <span class="excavation">W 14335,x</span></a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"> <span class="text">atf: lang qpc</span></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr line " >
#     <div class="lbl line">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1a </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GAL~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">1b </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">PAP~a</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div></div></div></div></div>

# %% [markdown]
# Can we find such tablet which do have numerals on their undivided lines.
#
# We show here a way to use the results of one query in another one:
# *custom sets*.
#
# We put the set of tablets with cases but without numerals in cases in a set called `cntablet`.
#
# We run the query again, but now in shallow mode, so that the result is a set.
#
# By the way: read more about custom sets and shallow mode in the description of
# [`A.search()`](https://annotation.github.io/text-fabric/Api/General/#search-api).

# %%
results = A.search(query, shallow=True)
customSets = dict(cntablet=results)
# Out:
#   0.02s 53 results

# %% [markdown]
# Now we can perform a very simple query for numerals on this set: we want tablets with numerals.
# By restricting ourselves to this set, we now that these numerals must occur on undivided lines.

# %%
query = '''
cntablet
  sign type=numeral
'''
results = A.search(query, sets=customSets)
# Out:
#   0.17s 160 results

# %%
A.show(results, end=2, showFeatures=False)
# Out:
# <p><b>tablet</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006438" title="to CDLI main page for this tablet" sec="P006438">tablet P006438 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr line " >
#     <div class="lbl line">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal " >
#     <div class="lbl trminal">2a </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KU6~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">BU~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2b </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">AB~a</span><div class="features"></div>
#
#     </div>
# </div><div class="op">x</div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SUKKAL</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2c </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NAM2</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">RAD~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">PA~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZU</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2d </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">RAD~a</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div></div></div>
# <div class="contnr face " >
#     <div class="lbl face">reverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">USZ~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZUBUR</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GAL~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">IM~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZA</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">RAD~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">4 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</spa
# <p><b>tablet</b> <i>2</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P002082" title="to CDLI main page for this tablet" sec="P002082">tablet P002082 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">BA</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SUHUR</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SAG</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">2(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">BA</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SUHUR</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SUHUR</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">4 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SUMASZ</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N34)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">ZATU759</span><div class="features"></div>
#
#     </div>
# </div><div class="op">x</div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KU6~a</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">UB</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KU6~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr line " >
#     <div class="lbl line">3 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal " >
#     <div class="lbl trminal">3a </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">EN~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr case " >
#     <div class="lbl case">3b </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children casev">
# <div class="contnr trminal " >
#     <div class="lbl trminal">3b1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalh">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SUHUR</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3b2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalh">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">TUR3~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">DU</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZE3</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div></div></div></div></div></div></div>
# <div class="contnr face " >
#     <div class="lbl face">reverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <

# %% [markdown]
# We could have found these results by one query as well.
# Judge for yourself which method causes the least friction.

# %%
query = '''
tablet
/without/
  case
    sign type=numeral
/-/
/with/
  case
/-/
  sign type=numeral
'''
results = A.search(query)
A.show(results, end=2, showFeatures=False)
# Out:
#   0.16s 160 results
# <p><b>tablet</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006438" title="to CDLI main page for this tablet" sec="P006438">tablet P006438 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr line " >
#     <div class="lbl line">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal " >
#     <div class="lbl trminal">2a </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KU6~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">BU~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2b </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">AB~a</span><div class="features"></div>
#
#     </div>
# </div><div class="op">x</div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SUKKAL</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2c </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NAM2</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">RAD~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">PA~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZU</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2d </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">RAD~a</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div></div></div>
# <div class="contnr face " >
#     <div class="lbl face">reverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">USZ~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZUBUR</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GAL~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">IM~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZA</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">RAD~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">4 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</spa
# <p><b>tablet</b> <i>2</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P002082" title="to CDLI main page for this tablet" sec="P002082">tablet P002082 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">BA</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SUHUR</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SAG</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">2(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">BA</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SUHUR</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SUHUR</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">4 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SUMASZ</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N34)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">ZATU759</span><div class="features"></div>
#
#     </div>
# </div><div class="op">x</div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KU6~a</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">UB</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KU6~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr line " >
#     <div class="lbl line">3 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal " >
#     <div class="lbl trminal">3a </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">EN~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr case " >
#     <div class="lbl case">3b </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children casev">
# <div class="contnr trminal " >
#     <div class="lbl trminal">3b1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalh">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SUHUR</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3b2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalh">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">TUR3~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">DU</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZE3</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div></div></div></div></div></div></div>
# <div class="contnr face " >
#     <div class="lbl face">reverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <

# %% [markdown]
# ## Search and hand-coding
#
# Now we want to find all the ShinPP numerals.

# %%
shinPP = dict(
    N41=0.2,
    N04=1,
    N19=6,
    N46=60,
    N36=180,
    N49=1800,
)

shinPPPat = '|'.join(shinPP)

# %% [markdown]
# We make use of the fact that we can construct our template.

# %%
query = f'''
tablet
  sign grapheme={shinPPPat}
'''
results = A.search(query)
A.table(results, end=20, lineart=True)
# Out:
#   0.17s 1018 results
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">tablet</th><th class="tf">sign</th><th class="tf">sign</th><th class="tf">sign</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448701" title="to CDLI main page for this tablet" sec="P448701">P448701</a></td><td class="tf"><span class="plain outer  " >tablet P448701</span></td><td class="tf"><span class="plain outer  hl" >2(N19)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n19).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td><td class="tf"><span class="plain outer  hl" >4(N41)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/4(N41).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-4(n41).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td><td class="tf"><span class="plain outer  hl" >1(N46)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N46).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n46).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td></tr>
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006005" title="to CDLI main page for this tablet" sec="P006005">P006005</a></td><td class="tf"><span class="plain outer  " >tablet P006005</span></td><td class="tf"><span class="plain outer  hl" >1(N04)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n04).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td></tr>
# <tr class="tf"><td class="tf">3</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P002329" title="to CDLI main page for this tablet" sec="P002329">P002329</a></td><td class="tf"><span class="plain outer  " >tablet P002329</span></td><td class="tf"><span class="plain outer  hl" >2(N19)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n19).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td></tr>
# <tr class="tf"><td class="tf">4</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P002342" title="to CDLI main page for this tablet" sec="P002342">P002342</a></td><td class="tf"><span class="plain outer  " >tablet P002342</span></td><td class="tf"><span class="plain outer  hl" >1(N36)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N36).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n36).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td><td class="tf"><span class="plain outer  hl" >2(N19)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n19).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td></tr>
# <tr class="tf"><td class="tf">5</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P002344" title="to CDLI main page for this tablet" sec="P002344">P002344</a></td><td class="tf"><span class="plain outer  " >tablet P002344</span></td><td class="tf"><span class="plain outer  hl" >1(N04)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n04).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td></tr>
# <tr class="tf"><td class="tf">6</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P002398" title="to CDLI main page for this tablet" sec="P002398">P002398</a></td><td class="tf"><span class="plain outer  " >tablet P002398</span></td><td class="tf"><span class="plain outer  hl" >1(N04)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n04).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td></tr>
# <tr class="tf"><td class="tf">7</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P002622" title="to CDLI main page for this tablet" sec="P002622">P002622</a></td><td class="tf"><span class="plain outer  " >tablet P002622</span></td><td class="tf"><span class="plain outer  hl" >5(N19)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/5(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-5(n19).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td><td class="tf"><span class="plain outer  hl" >1(N46)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N46).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n46).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td><td class="tf"><span class="plain outer  hl" >4(N19)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/4(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-4(n19).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td></tr>
# <tr class="tf"><td class="tf">8</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P002626" title="to CDLI main page for this tablet" sec="P002626">P002626</a></td><td class="tf"><span class="plain outer  " >tablet P002626</span></td><td class="tf"><span class="plain outer  hl" >1(N41)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N41).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n41).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td></tr>
# <tr class="tf"><td class="tf">9</td><td class="tf"> <a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P003330" title="to CDLI main page for this tablet" sec="P003330">P003330</a></td><td class="tf"><span class="plain outer  " >tablet P003330</span></td><td class="tf"><span class="plain outer  hl" >3(N46)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N46).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n46).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td><td class="tf"><span class="plain outer  hl" >2(N49)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N49).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n49).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td><td class="tf"><span class="plain outer  hl" >5(N19)</span>  <a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/5(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-5(n19).jpg" style="display: inline;max-width: 2em; max-height: 4em;"  /></a></td><td class="tf"><span class="plain outer  hl" >2(N04)</span>  <a target="_blank" href="

# %% [markdown]
# Let's see a few tablets in more detail:

# %%
A.show(results, end=5, showFeatures=False)
# Out:
# <p><b>tablet</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P448701" title="to CDLI main page for this tablet" sec="P448701">tablet P448701 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N46)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">2(N19)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">4(N41)</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">AB~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">APIN~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZE~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">DU</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div></div></div>
# <div class="contnr face " >
#     <div class="lbl face">reverse </div>
#     <div class="meta">
#         <div class="features"></div>
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">ruling </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# </div></div></div>
# <p><b>tablet</b> <i>2</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006005" title="to CDLI main page for this tablet" sec="P006005">tablet P006005 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N04)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">PAP~a</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div></div></div></div></div>
# <p><b>tablet</b> <i>3</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P002329" title="to CDLI main page for this tablet" sec="P002329">tablet P002329 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KI</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NUNUZ~a1</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SANGA~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N57)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">BA</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">EN~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">BA</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NAGAR~b</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">4 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZU2</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SAL</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr line " >
#     <div class="lbl line">5 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal " >
#     <div class="lbl trminal">5a </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N14)</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">5b </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">2(N19)</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div></div></div></div></div></div></div>
# <p><b>tablet</b> <i>4</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P002342" title="to CDLI main page for this tablet" sec="P002342">tablet P002342 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N45)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">BU~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">2(N34)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N45)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZE~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">4 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">2(N14)</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">3 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N36)</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">2(N19)</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div></div></div></div></div>
# <p><b>tablet</b> <i>5</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P002344" title="to CDLI main page for this tablet" sec="P002344">tablet P002344 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">A</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">2(N50)</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">UH3~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr line " >
#     <div class="lbl line">3 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal " >
#     <div class="lbl trminal">3a </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr case " >
#     <div class="lbl case">3b </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children casev">
# <div class="contnr trminal " >
#     <div class="lbl trminal">3b1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalh">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZA3~a2</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">E2~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N57)</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3b2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalh">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KALAM~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3b3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalh">
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N57)</span><div class="features"></div>
#
#     </div>
# </div><div class="op">.</div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">PIRIG~b1</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SANGA~a</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</sp

# %% [markdown]
# ### A tablet calculator
#
# Rather than displaying search results, you can also *process* them in your program.
#
# Search results come as tuples of nodes that correspond directly to the elements
# of your search template.
#
# We query for shinPP numerals on the faces of tablets.
# The result of the query is a list of tuples `(t, f, s)` consisting of
# a tablet node, a face node and a node for a sign of a shinPP numeral.
#
# #### Rationale
# This task will require a higher level of programming skills and a deeper knowledge of how
# Python works.
# We include it in this tutorial to get the message across that Text-Fabric is not
# a black box that shields you from your data. Everything you handle in Text-Fabric is
# open to further programming and processing of your own design and choosing.

# %% [markdown]
# #### Data collection

# %%
query = f'''
tablet
    face
        sign type=numeral grapheme={shinPPPat}
'''
results = A.search(query)
# Out:
#   0.18s 1018 results

# %% [markdown]
# We are going to put all these numerals in buckets: for each face on each tablet a separate bucket.

# %%
numerals = {}
pNums = {}
for (tablet, face, sign) in results:
    pNums[F.catalogId.v(tablet)] = tablet
    numerals.setdefault(tablet, {}).setdefault(face, []).append(sign)
print(f'{len(pNums)} tablets')
print('\n'.join(list(pNums)[0:10]))
print('...')
# Out:
# 235 tablets
# P448701
# P006005
# P002329
# P002342
# P002344
# P002398
# P002622
# P002626
# P003330
# P003357
# ...

# %% [markdown]
# #### The calculator
# We define a function that given a tablet, adds the shinPP numerals by its faces.
# We also show the line art and a pretty transcription.
#
# The function is a bit involved.

# %%
# we generate Markdown strings and send them to the notebook formatter

def dm(x): display(Markdown(x))

def calcTablet(pNum): # pNum identifies the tablet in question
    # show a horizontal line in Markdown
    dm('---\n')     
    tablet = pNums.get(pNum, None)  # look up the node for this p-number
    if tablet is None:
        dm(f'**no results for {pNum}**')
        return                      # if not found the tablet has no ShinPP numerals: quit
    
    A.lineart(tablet, withCaption="top", width="200")   # show lineart
    faces = numerals[tablet]                    # get the buckets for the faces
    mySigns = []
    for (face, signs) in faces.items():         # work per face 
        mySigns.extend(signs)
        dm(f'##### {F.type.v(face)}')           # show the name of the face
        distinctSigns = {}                      # collect the distinct numerals
        for s in signs:
            distinctSigns.setdefault(A.atfFromSign(s), []).append(s)
        A.lineart(distinctSigns)      # display the list of signs
        total = 0                               # start adding up
        for (signAtf, signs) in distinctSigns.items():
            value = 0
            for s in signs:
                value += F.repeat.v(s) * shinPP[F.grapheme.v(s)]
            total += value
            amount = len(signs)                 # we report our calculation
            shinPPval = shinPP[F.grapheme.v(signs[0])]
            repeat = F.repeat.v(signs[0])
            print(f'{amount} x {signAtf} = {amount} x {repeat} x {shinPPval} = {value}')
        dm(f'**total** = **{total}**')
    A.prettyTuple([tablet] + mySigns, 1, showFeatures=False) # show pretty transcription

# %% [markdown]
# #### Calculate once

# %%
calcTablet('P006377')
# Out:
# ---
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column-reverse nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/dl/lineart/P006377_l.jpg" title="to higher resolution lineart on CDLI"><span><b>no lineart</b> for tablet <code>P006377</code></span></a></div><div><a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006377" title="to CDLI main page for this item">P006377</a></div></div></div></div>
# ##### obverse
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N46).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n46).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N46)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/5(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-5(n19).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">5(N19)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n04).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">3(N04)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N41).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n41).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N41)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n19).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N19)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n19).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">3(N19)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n04).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI ma ...
# 1 x 1(N46) = 1 x 1 x 60 = 60
# 1 x 5(N19) = 1 x 5 x 6 = 30
# 4 x 3(N04) = 4 x 3 x 1 = 12
# 2 x 1(N41) = 2 x 1 x 0.2 = 0.4
# 8 x 1(N19) = 8 x 1 x 6 = 48
# 2 x 3(N19) = 2 x 3 x 6 = 36
# 5 x 1(N04) = 5 x 1 x 1 = 5
# 3 x 2(N04) = 3 x 2 x 1 = 6
# 3 x 2(N19) = 3 x 2 x 6 = 36
# 1 x 2(N41) = 1 x 2 x 0.2 = 0.4
# 2 x 4(N04) = 2 x 4 x 1 = 8
# 1 x 3(N41) = 1 x 3 x 0.2 = 0.6000000000000001
# 1 x 4(N19) = 1 x 4 x 6 = 24
# **total** = **266.4**
# ##### reverse
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N36).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n36).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N36)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N46).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n46).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N46)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/8(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-8(n19).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">8(N19)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/5(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-5(n04).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">5(N04)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N41).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n41).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">3(N41)</a></div></div></div></div>
# 1 x 1(N36) = 1 x 1 x 180 = 180
# 1 x 1(N46) = 1 x 1 x 60 = 60
# 1 x 8(N19) = 1 x 8 x 6 = 48
# 1 x 5(N04) = 1 x 5 x 1 = 5
# 1 x 3(N41) = 1 x 3 x 0.2 = 0.6000000000000001
# **total** = **293.6**
# <p><b>result</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006377" title="to CDLI main page for this tablet" sec="P006377">tablet P006377 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr line " >
#     <div class="lbl line">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1a </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N46)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">5(N19)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">3(N04)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N41)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">UR5~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">1b </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N19)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">3(N04)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N41)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N24)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">TAR~a</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">3(N04)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SAL</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">TUR3~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N19)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SAL</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">ZATU788</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">AN</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NUNUZ~a1</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">4 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">3(N19)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">U4</span><div class="features"></div>
#
#     </div>
# </div><div class="op">x</div>
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N14)</span><div class="features"></div>
#
#     </div>
# </div><div class="op">.</div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">KASZ~b</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">AB~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">5 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N04)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N57)</span><div class="features"></div>
#
#     </div>
# </div><div class="op">.</div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZUBUR</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">TUR3~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">ME~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">6 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">2(N04)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SANGA~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SANGA~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">ZATU788</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">AN</span><div class=

# %% [markdown]
# #### Calculate ad lib
# Now the first 5 tablets.

# %%
for tablet in sorted(pNums)[0:5]:
    calcTablet(tablet)
# Out:
# ---
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column-reverse nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/dl/lineart/P000266_l.jpg" title="to higher resolution lineart on CDLI"><span><b>no lineart</b> for tablet <code>P000266</code></span></a></div><div><a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P000266" title="to CDLI main page for this item">P000266</a></div></div></div></div>
# ##### obverse
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n04).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N04)</a></div></div></div></div>
# 1 x 1(N04) = 1 x 1 x 1 = 1
# **total** = **1**
# <p><b>result</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P000266" title="to CDLI main page for this tablet" sec="P000266">tablet P000266 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">ruling </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1' </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">ruling </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">IM~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">IM~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3' </div>
#     <div class="meta">
#         <div class="features"></div>
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">ruling </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GAN2</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">2' </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">ruling </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">DU7</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">IM~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">AD~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">BU~a</span><div class="features"></div>
#
#     </div>
# </div><div class="op">+</div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">DU6~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">2(N57)</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">4' </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SAR~c</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">HI</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">5' </div>
#     <div class="meta">
#         <div class="features"></div>
# ---
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column-reverse nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/dl/lineart/P001043_l.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-p001043.jpg" style="display: inline;max-width: 200px;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P001043" title="to CDLI main page for this item">P001043</a></div></div></div></div>
# ##### obverse
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N36).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n36).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N36)</a></div></div></div></div>
# 2 x 1(N36) = 2 x 1 x 180 = 360
# **total** = **360**
# ##### reverse
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N36).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n36).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">3(N36)</a></div></div></div></div>
# 1 x 3(N36) = 1 x 3 x 180 = 540
# **total** = **540**
# <p><b>result</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P001043" title="to CDLI main page for this tablet" sec="P001043">tablet P001043 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N36)</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NESAG2~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">TE</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N36)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GI</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">AL</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div></div></div>
# <div class="contnr face " >
#     <div class="lbl face">reverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">3(N36)</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">AN</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div></div></div></div></div>
# ---
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column-reverse nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/dl/lineart/P001270_l.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-p001270.jpg" style="display: inline;max-width: 200px;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P001270" title="to CDLI main page for this item">P001270</a></div></div></div></div>
# ##### obverse
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/5(N36).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-5(n36).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">5(N36)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N46).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n46).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N46)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N36).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n36).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N36)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N46).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n46).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">2(N46)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n04).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N04)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N19).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n19).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N19)</a></div></div></div><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/2(N36).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-2(n36).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI ma ...
# 1 x 5(N36) = 1 x 5 x 180 = 900
# 4 x 1(N46) = 4 x 1 x 60 = 240
# 2 x 1(N36) = 2 x 1 x 180 = 360
# 1 x 2(N46) = 1 x 2 x 60 = 120
# 1 x 1(N04) = 1 x 1 x 1 = 1
# 1 x 1(N19) = 1 x 1 x 6 = 6
# 2 x 2(N36) = 2 x 2 x 180 = 720
# 1 x 2(N19) = 1 x 2 x 6 = 12
# **total** = **2359**
# <p><b>result</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P001270" title="to CDLI main page for this tablet" sec="P001270">tablet P001270 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">9(N34)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N45)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">7(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">5(N36)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N46)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">2(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N36)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">2(N46)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N04)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr quad " >
#
#     <div class="meta">
#
#
#     </div>
# <div class="children quad">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">DU8~c</span><div class="features"></div>
#
#     </div>
# </div><div class="op">x</div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">HI</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N46)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N19)</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">2(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GI</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">2(N36)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N46)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">2(N19)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">2(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GI</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">2(N36)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N46)</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">4 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N36)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">8(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
# ---
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column-reverse nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/dl/lineart/P002260_l.jpg" title="to higher resolution lineart on CDLI"><span><b>no lineart</b> for tablet <code>P002260</code></span></a></div><div><a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P002260" title="to CDLI main page for this item">P002260</a></div></div></div></div>
# ##### obverse
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N04).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n04).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N04)</a></div></div></div></div>
# 1 x 1(N04) = 1 x 1 x 1 = 1
# **total** = **1**
# <p><b>result</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P002260" title="to CDLI main page for this tablet" sec="P002260">tablet P002260 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">GU</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NUN~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N04)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">NAM2</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">3(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">EN~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">PA~a</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">4 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">2(N01)</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">2(N01)</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">3 </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminal">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N01)</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">4 </div>
#     <div class="meta">
#         <div
# ---
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column-reverse nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/dl/lineart/P002275_l.jpg" title="to higher resolution lineart on CDLI"><span><b>no lineart</b> for tablet <code>P002275</code></span></a></div><div><a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P002275" title="to CDLI main page for this item">P002275</a></div></div></div></div>
# ##### obverse
# <div style="display: flex;flex-flow: row nowrap;justify-content: flex-start;align-items: center;align-content: flex-start;"><div style="padding: 0.5rem;"><div style="display: flex;flex-flow: column nowrap;justify-content: space-between;align-items: center;align-content: space-between;"><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/1(N36).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-1(n36).jpg" style="display: inline;"  /></a></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns.html" title="to CDLI main page for this item">1(N36)</a></div></div></div></div>
# 1 x 1(N36) = 1 x 1 x 180 = 180
# **total** = **180**
# <p><b>result</b> <i>1</i></p>
# <div class="contnr tablet " >
#     <div class="lbl tablet"><a href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P002275" title="to CDLI main page for this tablet" sec="P002275">tablet P002275 </a> </div>
#     <div class="meta">
#
#         <div class="comments">
# <div class="contnr comment " >
#     <div class="lbl comment">meta </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children comment"></div></div></div>
#     </div>
# <div class="children tablet">
# <div class="contnr face " >
#     <div class="lbl face">obverse </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children face">
# <div class="contnr column " >
#     <div class="lbl column">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr line " >
#     <div class="lbl line">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1a </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">X</span><div class="features"></div>
#
#     </div>
# </div></div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">1b </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">2(N45)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZE~a</span><div class="features"></div>
#
#     </div>
# </div></div></div></div></div>
# <div class="contnr line " >
#     <div class="lbl line">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal " >
#     <div class="lbl trminal">2a </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv"><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
#
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">4(N14)</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">2b </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign hl" >
#
#     <div class="meta">
#          <span class="srcln">1(N36)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N45)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">2(N14)</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# <div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div></div></div>
# <div class="contnr column " >
#     <div class="lbl column">2 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children column">
# <div class="contnr line " >
#     <div class="lbl line">1 </div>
#     <div class="meta">
#
#
#     </div>
# <div class="children line">
# <div class="contnr trminal " >
#     <div class="lbl trminal">1a </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">1(N50)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">8(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SANGA~a</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">ZATU753</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div>
# <div class="contnr trminal " >
#     <div class="lbl trminal">1b </div>
#     <div class="meta">
#         <div class="features"></div>
#
#     </div>
# <div class="children trminalv">
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">7(N14)</span><div class="features"></div>
#
#     </div>
# </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">SZE~a</span><div class="features"></div>
#
#     </div>
# </div><div class="lbl clusterb">? </div>
# <div class="contnr sign " >
#
#     <div class="meta">
#          <span class="srcln">...</span><div class="features"></div>
#
#     </div>
# </div>
#     <div class="lbl clustere " >
#         ?
#
#     </div>
# </div></div></div></div></div></div></div></div></div></div>

# %% [markdown]
# ## More ...
#
# The capabilities of search are endless.
# Often it is the quickest way to focus on a phenomenon, quicker than hand coding all the logic
# to retrieve your patterns.
#
# That said, it is not a matter of either-or. You can use coding to craft your templates,
# and you can use coding to process your results.
#
# It's an explosive mix. A later chapter in this tutorial shows
# even more [cases](cases.ipynb).
#
# Have another look at
# [the manual](https://annotation.github.io/text-fabric/Use/Search/).

# %% [markdown]
# # Next
#
# [signs](signs.ipynb)
#
# *Back to the basics ...*
#
# All chapters:
# [start](start.ipynb)
# [imagery](imagery.ipynb)
# [steps](steps.ipynb)
# [search](search.ipynb)
# [signs](signs.ipynb)
# [quads](quads.ipynb)
# [jumps](jumps.ipynb)
# [cases](cases.ipynb)
