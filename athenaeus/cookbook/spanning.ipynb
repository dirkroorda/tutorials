# %% [markdown]
# # A bit of dataset development.
#
# Ernst Boogert is developing a converter that converts many Greek sources from TEI to TF.
# He has to deal with many patterns in the sources, sometimes confusing and conflicting ones.
#
# So a fair bit of trial and error is conducted.
#
# Here we show how a dataset with unhelpful sentence boundaries got improved.
# Some sentence endings had not been detected by the converter,
# causing more than hundred sentences to spill over to the next chapter.
#
# After Ernst gave the message that he had remedied this, we performed a check (this notebook).
#
# **Note in passing how easy it is to load previous versions of the data.**

# %%
from tf.app import use

# %% [markdown]
# # After the improvement
#
# There are no sentences that span chapters anymore.
#
# We test version 1.1 at a moment where the `athenaeus` app is not yet updated GitHub, only locally.
# The app is configured to a specific version of the data.
#
# By means of the specifier `:clone` we ask for the app in its development version in our local
# git repository.

# %%
# A = use('athenaeus', hoist=globals())
A = use('athenaeus:clone', checkout="clone", hoist=globals())
# Out:
# Using TF-app in /Users/dirk/github/annotation/app-athenaeus/code:
# 	repo clone offline under ~/github (local github)
# Using data in /Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.1:
# 	repo clone offline under ~/github (local github)
# <b>Documentation:</b> <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="provenance of The Deipnosophistae by Athenaeus">ATHENAEUS</a> <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="How TF features represent text">Character table</a> <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="ATHENAEUS feature documentation">Feature docs</a> <a target="_blank" href="https://github.com/annotation/app-athenaeus" title="athenaeus API documentation">athenaeus API</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/" title="text-fabric-api">Text-Fabric API 7.11.1</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Use/Search/" title="Search Templates Introduction and Reference">Search Reference</a><details open><summary><b>Loaded features</b>:</summary>
# <p><b>The Deipnosophistae by Athenaeus</b>: <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.1/_book.tf">_book</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.1/_sentence.tf">_sentence</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.1/add.tf">add</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.1/beta_plain.tf">beta_plain</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.1/bibl.tf">bibl</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.1/book.tf">book</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.1/chapter.tf">chapter</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.1/cit.tf">cit</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.1/head.tf">head</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.1/hi.tf">hi</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.1/l.tf">l</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.1/lemma.tf">lemma</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.1/main.tf">main</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.1/norm.tf">norm</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.1/num.tf">num</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.1/orig.tf">orig</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.1/otype.tf">otype</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.1/p.tf">p</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.1/pb.tf">pb</a>  <a target="_blank" href="https://nbviewer.jupyter.org ...
# <style>
# @font-face {
#   font-family: "Gentium";
#   src:
#     local("GentiumPlus-R.ttf"),
#     url("https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true");
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .title {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .hl {
#     background-color: #ffee66;
# }
# .outerplain {
#     direction: rtl;
# }
# .meta {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: row nowrap;
# }
# .features,.comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .verse {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-end;
#     align-items: flex-end;
#     direction: ltr;
#     width: 100%;
# }
# .vn {
#   font-size: small !important;
#   padding-right: 1em;
# }
# .vrs {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: Gentium;
#     font-size: normal;
#     text-decoration: none;
# }
# .children {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     border: 0;
#     background-color: #ffffff;
# }
# .children._book {
#     flex-flow: column nowrap;
# }
# .children.book {
#     flex-flow: column nowrap;
# }
# .children.chapter {
#     align-items: stretch;
#     flex-flow: row wrap;
# }
# .children.p {
#     align-items: stretch;
#     flex-flow: row wrap;
# }
# .children._sentence {
#     align-items: stretch;
#     flex-flow: row wrap;
# }
# .children.word {
#     flex-flow: column nowrap;
# }
# .contnr {
#     width: fit-content;
# }
# .contnr._book,.contnr.book,
# .contnr.chapter,
# .contnr.p,
# .contnr._sentence,
# .contnr.word {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5em 0.1em 0.1em 0.1em;
#     margin: 0.8em 0.1em 0.1em 0.1em;
#     border-radius: 0.2em;
#     border-style: solid;
#     border-width: 0.2em;
#     font-size: small;
# }
# .contnr._book,.contnr.book {
#     border-color: #bb8800;
# }
# .contnr.chapter {
#     flex-flow: row wrap;
#     border-color: #0088bb;
# }
# .contnr.p {
#     flex-flow: row wrap;
#     border-color: #44bbff;
# }
# .contnr._sentence {
#     flex-flow: row wrap;
#     border-color: #44bbff;
# }
# .contnr.word {
#     border-color: #bbbbbb;
# }
# .contnr.hl {
#     background-color: #ffee66;
# }
# .lbl._book,.lbl.book,
# .lbl.chapter,
# .lbl.p,
# .lbl._sentence,
# .lbl.word {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     font-size: small;
#     display: block;
# }
# .lbl._book,.lbl.book {
#     border-color: #bb8800;
#     border-width: 0.3em;
#     border-radius: 0.3em;
#     color: #bb8800;
# }
# .lbl.chapter {
#     border-color: #0088bb;
#     border-width: 0.3em;
#     border-radius: 0.3em;
#     color: #0088bb;
# }
# .lbl.p {
#     border-color: #dddddd;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     color: #0000cc;
# }
# .lbl._sentence {
#     border-color: #dddddd;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     color: #0000cc;
# }
# .lbl.word {
#     border-color: #bbbbbb;
#     border-width: 0.1em;
#     border-radius: 0.1em;
#     font-size: small;
#     color: #000000;
# }
# .text {
#     font-family: sans-serif;
#     font-size: x-small;
#     color: #000000;
# }
# .gap {
#     color: red;
# }
#
# tr.tf, td.tf, th.tf {
#   text-align: left;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlbx {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
#   margin: 0.2rem;
# }
#
# span.plain {
#   display: inline-block;
#   white-space: pre-wrap;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>
# <details open><summary><b>API members</b>:</summary>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">C Computed</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Call AllComputeds</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Cs ComputedString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">E Edge</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Eall AllEdges</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Es EdgeString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ensureLoaded</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">TF</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ignored</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">loadLog</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Locality/#locality" title="doc">L Locality</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">cache</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">error</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">indent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">info</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">isSilent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">reset</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">setSilent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">silentOff</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">silentOn</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">warning</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">N Nodes</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKey</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKeyTuple</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">otypeRank</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortNodes</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">F Feature</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fall AllFeatures</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fs FeatureString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Search/#search" title="doc">S Search</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Text/#text" title="doc">T Text</a></details>

# %% [markdown]
# ### Find sentences across chapters
#
# A sentence that spans multiple chapters is not embedded in any chapter.
# So if we look up the embedders of sentences, restricted to chapters, and we do not find any, we have a chapter spanning sentence.

# %%
def getSpanning():
  spanning = []

  for s in F.otype.s('_sentence'):
    chapters = L.u(s, otype='chapter')
    if not chapters:
      spanning.append((s,)) # we add s as a singleton tuple, so that we can feed all to table() later

  print(len(spanning))
  return spanning

# %%
spanning = getSpanning()
# Out:
# 0

# %% [markdown]
# No spanning sentences. Good!
#
# # Before the improvement
#
# But it has not been always so good.

# %% [markdown]
# We use the newest app, but we override the data version.

# %%
# A = use('athenaeus', version='1.0', hoist=globals())
A = use('athenaeus:clone', checkout="clone", version='1.0', hoist=globals())
# Out:
# Using TF-app in /Users/dirk/github/annotation/app-athenaeus/code:
# 	repo clone offline under ~/github (local github)
# Using data in /Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.0:
# 	repo clone offline under ~/github (local github)
# <b>Documentation:</b> <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="provenance of The Deipnosophistae by Athenaeus">ATHENAEUS</a> <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="How TF features represent text">Character table</a> <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="ATHENAEUS feature documentation">Feature docs</a> <a target="_blank" href="https://github.com/annotation/app-athenaeus" title="athenaeus API documentation">athenaeus API</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/" title="text-fabric-api">Text-Fabric API 7.11.1</a> <a target="_blank" href="https://annotation.github.io/text-fabric/Use/Search/" title="Search Templates Introduction and Reference">Search Reference</a><details open><summary><b>Loaded features</b>:</summary>
# <p><b>The Deipnosophistae by Athenaeus</b>: <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.0/_book.tf">_book</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.0/_sentence.tf">_sentence</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.0/add.tf">add</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.0/beta_plain.tf">beta_plain</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.0/bibl.tf">bibl</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.0/book.tf">book</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.0/chapter.tf">chapter</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.0/cit.tf">cit</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.0/head.tf">head</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.0/hi.tf">hi</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.0/l.tf">l</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.0/lemma.tf">lemma</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.0/main.tf">main</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.0/norm.tf">norm</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.0/num.tf">num</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.0/orig.tf">orig</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.0/otype.tf">otype</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.0/p.tf">p</a>  <a target="_blank" href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="/Users/dirk/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.0/pb.tf">pb</a>  <a target="_blank" href="https://nbviewer.jupyter.org ...
# <style>
# @font-face {
#   font-family: "Gentium";
#   src:
#     local("GentiumPlus-R.ttf"),
#     url("https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true");
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .title {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .hl {
#     background-color: #ffee66;
# }
# .outerplain {
#     direction: rtl;
# }
# .meta {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: row nowrap;
# }
# .features,.comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .verse {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-end;
#     align-items: flex-end;
#     direction: ltr;
#     width: 100%;
# }
# .vn {
#   font-size: small !important;
#   padding-right: 1em;
# }
# .vrs {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: Gentium;
#     font-size: normal;
#     text-decoration: none;
# }
# .children {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     border: 0;
#     background-color: #ffffff;
# }
# .children._book {
#     flex-flow: column nowrap;
# }
# .children.book {
#     flex-flow: column nowrap;
# }
# .children.chapter {
#     align-items: stretch;
#     flex-flow: row wrap;
# }
# .children.p {
#     align-items: stretch;
#     flex-flow: row wrap;
# }
# .children._sentence {
#     align-items: stretch;
#     flex-flow: row wrap;
# }
# .children.word {
#     flex-flow: column nowrap;
# }
# .contnr {
#     width: fit-content;
# }
# .contnr._book,.contnr.book,
# .contnr.chapter,
# .contnr.p,
# .contnr._sentence,
# .contnr.word {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5em 0.1em 0.1em 0.1em;
#     margin: 0.8em 0.1em 0.1em 0.1em;
#     border-radius: 0.2em;
#     border-style: solid;
#     border-width: 0.2em;
#     font-size: small;
# }
# .contnr._book,.contnr.book {
#     border-color: #bb8800;
# }
# .contnr.chapter {
#     flex-flow: row wrap;
#     border-color: #0088bb;
# }
# .contnr.p {
#     flex-flow: row wrap;
#     border-color: #44bbff;
# }
# .contnr._sentence {
#     flex-flow: row wrap;
#     border-color: #44bbff;
# }
# .contnr.word {
#     border-color: #bbbbbb;
# }
# .contnr.hl {
#     background-color: #ffee66;
# }
# .lbl._book,.lbl.book,
# .lbl.chapter,
# .lbl.p,
# .lbl._sentence,
# .lbl.word {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     font-size: small;
#     display: block;
# }
# .lbl._book,.lbl.book {
#     border-color: #bb8800;
#     border-width: 0.3em;
#     border-radius: 0.3em;
#     color: #bb8800;
# }
# .lbl.chapter {
#     border-color: #0088bb;
#     border-width: 0.3em;
#     border-radius: 0.3em;
#     color: #0088bb;
# }
# .lbl.p {
#     border-color: #dddddd;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     color: #0000cc;
# }
# .lbl._sentence {
#     border-color: #dddddd;
#     border-width: 0.2em;
#     border-radius: 0.2em;
#     color: #0000cc;
# }
# .lbl.word {
#     border-color: #bbbbbb;
#     border-width: 0.1em;
#     border-radius: 0.1em;
#     font-size: small;
#     color: #000000;
# }
# .text {
#     font-family: sans-serif;
#     font-size: x-small;
#     color: #000000;
# }
# .gap {
#     color: red;
# }
#
# tr.tf, td.tf, th.tf {
#   text-align: left;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlbx {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
#   margin: 0.2rem;
# }
#
# span.plain {
#   display: inline-block;
#   white-space: pre-wrap;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>
# <details open><summary><b>API members</b>:</summary>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">C Computed</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Call AllComputeds</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Computed/#computed-data" title="doc">Cs ComputedString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">E Edge</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Eall AllEdges</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#edge-features" title="doc">Es EdgeString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ensureLoaded</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">TF</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">ignored</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Fabric/#loading" title="doc">loadLog</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Locality/#locality" title="doc">L Locality</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">cache</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">error</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">indent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">info</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">isSilent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">reset</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">setSilent</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">silentOff</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">silentOn</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Misc/#messaging" title="doc">warning</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">N Nodes</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKey</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortKeyTuple</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">otypeRank</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Nodes/#navigating-nodes" title="doc">sortNodes</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">F Feature</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fall AllFeatures</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Features/#node-features" title="doc">Fs FeatureString</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Search/#search" title="doc">S Search</a><br/>
# <a target="_blank" href="https://annotation.github.io/text-fabric/Api/Text/#text" title="doc">T Text</a></details>

# %%
spanning = getSpanning()
# Out:
# 138

# %%
A.table(spanning)
# Out:
# <table>
# <tr class="tf">
#   <th class="tf">n</th><th class="tf">p</th>
#   <th class="tf">_sentence</th>
# </tr>
#
# <tr class="tf"><td class="tf">1</td><td class="tf"> <a href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="show this passage online" sec="1 3:16">1 3:16</a></td><td class="tf"><span class="vrs ltr"><a href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="show this passage online" sec="1 3:16">1 3:16</a></span><span class="plain outer  " ><span class="plain"><span class="plain " ><span class="txtp">‘ἆρ’  </span></span><span class="plain " ><span class="txtp">οὖν </span></span><span class="plain " ><span class="txtp">ἐθελήσεις </span></span><span class="plain " ><span class="txtp">καὶ </span></span><span class="plain " ><span class="txtp">ἡμῖν </span></span><span class="plain " ><span class="txtp">τῶν </span></span><span class="plain " ><span class="txtp">καλῶν </span></span><span class="plain " ><span class="txtp">ἐπικυλικίων </span></span><span class="plain " ><span class="txtp">λόγων </span></span><span class="plain " ><span class="txtp">μεταδοῦναι— </span></span><span class="plain " ><span class="txtp">τρὶς </span></span><span class="plain " ><span class="txtp">δ’  </span></span><span class="plain " ><span class="txtp">ἀπομαξαμένοισι </span></span><span class="plain " ><span class="txtp">θεοὶ </span></span><span class="plain " ><span class="txtp">διδόασιν </span></span><span class="plain " ><span class="txtp">ἄμεινον, </span></span><span class="plain " ><span class="txtp">ὥς </span></span><span class="plain " ><span class="txtp">πού </span></span><span class="plain " ><span class="txtp">φησιν </span></span><span class="plain " ><span class="txtp">ὁ </span></span><span class="plain " ><span class="txtp">Κυρηναῖος </span></span><span class="plain " ><span class="txtp">ποιητής(  </span></span><span class="plain " ><span class="txtp">)—ʼἢ </span></span><span class="plain " ><span class="txtp">παρ’  </span></span><span class="plain " ><span class="txtp">ἄλλου </span></span><span class="plain " ><span class="txtp">τινὸς </span></span><span class="plain " ><span class="txtp">ἡμᾶς </span></span><span class="plain " ><span class="txtp">ἀναπυνθάνεσθαι </span></span><span class="plain " ><span class="txtp">δεῖ;’ </span></span><span class="plain " ><span class="txtp">εἶτα </span></span><span class="plain " ><span class="txtp">εἰσβάλλει </span></span><span class="plain " ><span class="txtp">μετ’  </span></span><span class="plain " ><span class="txtp">ὀλίγον </span></span><span class="plain " ><span class="txtp">εἰς </span></span><span class="plain " ><span class="txtp">τὸν </span></span><span class="plain " ><span class="txtp">τοῦ </span></span><span class="plain " ><span class="txtp">Λαρηνσίου </span></span><span class="plain " ><span class="txtp">ἔπαινον </span></span><span class="plain " ><span class="txtp">καὶ </span></span><span class="plain " ><span class="txtp">λέγει· </span></span><span class="plain " ><span class="txtp">ὃς </span></span><span class="plain " ><span class="txtp">ὑπὸ </span></span><span class="plain " ><span class="txtp">φιλοτιμίας </span></span><span class="plain " ><span class="txtp">πολλοὺς </span></span><span class="plain " ><span class="txtp">τῶν </span></span><span class="plain " ><span class="txtp">ἀπὸ </span></span><span class="plain " ><span class="txtp">παιδείας </span></span><span class="plain " ><span class="txtp">συναθροίζων </span></span><span class="plain " ><span class="txtp">οὐ </span></span><span class="plain " ><span class="txtp">μόνον </span></span><span class="plain " ><span class="txtp">τοῖς </span></span><span class="plain " ><span class="txtp">ἄλλοις </span></span><span class="plain " ><span class="txtp">ἀλλὰ </span></span><span class="plain " ><span class="txtp">καὶ </span></span><span class="plain " ><span class="txtp">λόγοις </span></span><span class="plain " ><span class="txtp">εἱστία, </span></span><span class="plain " ><span class="txtp">τὰ </span></span><span class="plain " ><span class="txtp ...
# <tr class="tf"><td class="tf">2</td><td class="tf"> <a href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="show this passage online" sec="1 6:39">1 6:39</a></td><td class="tf"><span class="vrs ltr"><a href="https://nbviewer.jupyter.org/github/pthu/patristics/blob/master/docs/transcription.md" title="show this passage online" sec="1 6:39">1 6:39</a></span><span class="plain outer  " ><span class="plain"><span class="plain " ><span class="txtp">‘γυργάθους </span></span><span class="plain " ><span class="txtp">ψηφισμάτων </span></span><span class="plain " ><span class="txtp">φέροντες,’ </span></span><span class="plain " ><span class="txtp">Ἀριστοφάνης </span></span><span class="plain " ><span class="txtp">φησίν( ).  </span></span><span class="plain " ><span class="txtp">ὅτι </span></span><span class="plain " ><span class="txtp">Ἀρχέστρατος </span></span><span class="plain " ><span class="txtp">ὁ </span></span><span class="plain " ><span class="txtp">Συρακούσιος </span></span><span class="plain " ><span class="txtp">ἢ </span></span><span class="plain " ><span class="txtp">Γελῷος </span></span><span class="plain " ><span class="txtp">ἐν </span></span><span class="plain " ><span class="txtp">τῇ </span></span><span class="plain " ><span class="txtp">ὡς </span></span><span class="plain " ><span class="txtp">Χρύσιππος </span></span><span class="plain " ><span class="txtp">ἐπιγράφει </span></span><span class="plain " ><span class="txtp">Γαστρονομίᾳ, </span></span><span class="plain " ><span class="txtp">ὡς </span></span><span class="plain " ><span class="txtp">δὲ </span></span><span class="plain " ><span class="txtp">Λυγκεὺς </span></span><span class="plain " ><span class="txtp">καὶ </span></span><span class="plain " ><span class="txtp"

# %% [markdown]
# We could also have picked the commit hash of the app where it still asks for version `1.0` of the data.
#
# But then we need a previous version of Text-Fabric!

# %%
A = use('athenaeus:5e24f733392baaf28658dc6bef0fb42d04f8d296', hoist=globals())
# Out:
# rate limit is 5000 requests per hour, with 5000 left for this hour
# 	connecting to online GitHub repo annotation/app-athenaeus ... connected
# Using TF-app in /Users/dirk/text-fabric-data/annotation/app-athenaeus/code:
# 	#5e24f733392baaf28658dc6bef0fb42d04f8d296 (requested)
# findAppClass: cannot import name 'prettyPre' from 'tf.applib.display' (/Users/dirk/github/annotation/text-fabric/tf/applib/display.py)
# findAppClass: Api for "athenaeus" not found

# %% [markdown]
# This is the same data as in the previous cells.
