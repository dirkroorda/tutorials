# %% [markdown]
# <img src="images/pthu.png"/>
# <img align="right" src="images/tf-small.png" width="128"/>
# <img align="right" src="images/dans-small.png"/>
#
# # Tutorial
#
# This notebook gets you started with using
# [Text-Fabric](https://annotation.github.io/text-fabric/) for coding in the Greek Literature.
#
# ## About
#
# Ernst Boogert, while at the [PThU](https://www.pthu.nl/en/) has mass-converted Greek Literature from
# high quality libraries such as Perseus to the Text-Fabric format.
#
# He has delivered the outcome to the [greek_literature](https://github.com/pthu/greek_literature) repository on GitHub.
#
# It consists of nearly 1800 works by over 250 authors.
#
# ## Catalog
#
# At first sight, it is not easy to see what is in this repo.
# So we make a catalog and show the results.
#
# In this notebook we show how you can make an inventory by coding some functions in Python.
# We also have written a small library, `catalog.py` that contains catalog functions, so that we can
# easily use the catalog in other notebooks.

# %% [markdown]
# Our catalog functions make use of pretty low-level Text-Fabric stuff.
#
# Do not let this deter you. Later, when we are using Text-Fabric for individual works, we use a much more high-level interface to
# Text-Fabric.
#
# We also use a pretty-printer of Python datastructures: `pprint`.

# %%
import os
import collections
import pprint as pp

from tf.core.timestamp import Timestamp
from tf.core.data import Data, WARP

PP = pp.PrettyPrinter(indent=2)


def pprint(x):
    PP.pprint(x)

# %% [markdown]
# ## Clone the repo
#
# Make sure you have cloned the Greek Literature repository to your computer.
#
# I assume that you have created a directory `github` in your home directory, and under that a directory `pthu`.
#
# <img align="right" src="images/github.png" width="400"/>
#
# ### novice way
#
# If you have never used `git`, use the following procedure:
#
# 1. go to [greek_literature](https://github.com/pthu/greek_literature) and locate the green `code` button.
# 1. click the little triangle and then click `Download ZIP`.
# 1. go to your `Downloads` folder and locate the file `greek_literature-master.zip`
#    (it may take a while before the file has arrived, because it is 450 MB)
# 1. unzip the result, it will be a directory `greek_literature-master`
#    with a size of nearly 2GB and 45,000 files in it.
# 1. move this directory straight under the `github/pthu` directory you have created before
# 1. rename this directory to `greek_literature`
#
# ### expert way
#
# If you are comfortable with `git` and have it already installed on your computer, you can proceed like this:
#
# On the command line, go to the directory `~/github/pthu`, and say
#
# ```
# git clone https://github.com/pthu/greek_literature
# ```
#
# After that you have all works in Greek Literature stored on your computer.

# %% [markdown]
# By means of a few definitions we tell our functions where the data is.

# %%
BASE = os.path.expanduser("~/github")
ORG = "pthu"
REPO = "greek_literature"
REPO_PATH = f"{BASE}/{ORG}/{REPO}"
VERSION = "1.0"

# %% [markdown]
# The next function collects all `tf` directories that can be found somewhere below a base directory.

# %%
def collectTfDirs(path, result):
    """Collect TF directories.
    
    Collect all directories named `tf` that are somewhere below `path` and add
    the path names of those directories to the list `result`.
    
    Note: we strip the initial part that is common to all result paths.
    """
    
    with os.scandir(path) as it:
        for entry in it:
            name = entry.name
            if not name.startswith('.') and entry.is_dir():
                subPath = f"{path}/{name}"
                if name == "tf":
                    result.append(subPath.removeprefix(f"{REPO_PATH}/"))
                else:
                    collectTfDirs(subPath, result)

# %%
tfDirs = []

collectTfDirs(REPO_PATH, tfDirs)

len(tfDirs)
# Out:
# 1779

# %% [markdown]
# Here are a few of the paths that we have found.

# %%
pprint(tfDirs[0:10])
print("")
pprint(tfDirs[100:110])
print("")
pprint(tfDirs[1000:1010])
print("")
pprint(tfDirs[-10:])
# Out:
# [ 'canonical-greekLit/tlg0057/tlg010/perseus-grc1/1/tf',
#   'canonical-greekLit/tlg0059/tlg009/perseus-grc2/1/tf',
#   'canonical-greekLit/tlg0059/tlg036/perseus-grc2/1/tf',
#   'canonical-greekLit/tlg0059/tlg031/perseus-grc2/1/tf',
#   'canonical-greekLit/tlg0059/tlg007/perseus-grc2/1/tf',
#   'canonical-greekLit/tlg0059/tlg001/perseus-grc1/1/tf',
#   'canonical-greekLit/tlg0059/tlg006/perseus-grc2/1/tf',
#   'canonical-greekLit/tlg0059/tlg030/perseus-grc2/1/tf',
#   'canonical-greekLit/tlg0059/tlg008/perseus-grc2/1/tf',
#   'canonical-greekLit/tlg0059/tlg015/perseus-grc2/1/tf']
#
# [ 'canonical-greekLit/tlg0540/tlg023/perseus-grc2/1/tf',
#   'canonical-greekLit/tlg0540/tlg022/perseus-grc2/1/tf',
#   'canonical-greekLit/tlg0540/tlg025/perseus-grc2/1/tf',
#   'canonical-greekLit/tlg0540/tlg013/perseus-grc2/1/tf',
#   'canonical-greekLit/tlg0540/tlg014/perseus-grc2/1/tf',
#   'canonical-greekLit/tlg0540/tlg032/perseus-grc2/1/tf',
#   'canonical-greekLit/tlg0540/tlg003/perseus-grc2/1/tf',
#   'canonical-greekLit/tlg0540/tlg004/perseus-grc2/1/tf',
#   'canonical-greekLit/tlg0540/tlg005/perseus-grc2/1/tf',
#   'canonical-greekLit/tlg0540/tlg002/perseus-grc2/1/tf']
#
# [ 'First1KGreek/tlg0552/tlg013/1st1K-grc1/1/tf',
#   'First1KGreek/tlg0552/tlg003/1st1K-grc1/1/tf',
#   'First1KGreek/tlg0552/tlg004/1st1K-grc1/1/tf',
#   'First1KGreek/tlg0552/tlg005/1st1K-grc1/1/tf',
#   'First1KGreek/tlg0552/tlg002/1st1K-grc1/1/tf',
#   'First1KGreek/tlg0552/tlg011/1st1K-grc1/1/tf',
#   'First1KGreek/tlg0552/tlg010/1st1K-grc1/1/tf',
#   'First1KGreek/tlg1271/tlg001/1st1K-grc1/1/tf',
#   'First1KGreek/tlg1271/tlg002/1st1K-grc1/1/tf',
#   'First1KGreek/tlg0357/tlg001/1st1K-grc2/1/tf']
#
# [ 'First1KGreek/tlg1551/tlg002/opp-grc1/1/tf',
#   'First1KGreek/tlg0645/tlg001/opp-grc1/1/tf',
#   'First1KGreek/tlg0645/tlg003/perseus-grc2/1/tf',
#   'First1KGreek/tlg0645/tlg002/perseus-grc2/1/tf',
#   'First1KGreek/tlg0645/tlg002/opp-grc1/1/tf',
#   'First1KGreek/tlg2115/tlg060/opp-grc1/1/tf',
#   'First1KGreek/tlg2115/tlg060/perseus-grc1/1/tf',
#   'First1KGreek/tlg4024/tlg001/opp-grc2/1/tf',
#   'First1KGreek/tlg4024/tlg002/opp-grc12/1/tf',
#   'First1KGreek/tlg1764/tlg001/1st1K-grc1/1/tf']

# %% [markdown]
# In order to get the authors and titles of the works, we load a single feature of each
# `tf` directory and inspect its metadata.
#
# The feature in question is called `otype`, it is present in all Text-Fabric datasets.
# See [data model](https://annotation.github.io/text-fabric/about/datamodel.html) for more info on this.

# %%
tmObj = Timestamp()
OTYPE = WARP[0]

# %% [markdown]
# The following function gives us the metadata of the `otype` feature.

# %%
def getMeta(tfDir):
    """Load the otype function of a TF dataset and deliver its metadata.
    """
    
    otypePath = f"{REPO_PATH}/{tfDir}/{VERSION}/{OTYPE}.tf"
    dataObj = Data(otypePath, tmObj)
    dataObj.load(metaOnly=True, silent=True)
    return dataObj.metaData

# %% [markdown]
# We print out the metadata of the first, last and an intermediate dataset.
#
# We also print out the number of authors.
# Scroll down to the bottom in order to view it.

# %%
pprint(getMeta(tfDirs[0]))
pprint(getMeta(tfDirs[1000]))
pprint(getMeta(tfDirs[-1]))
# Out:
# { 'author': 'Galen',
#   'availability': 'Available under a Creative Commons Attribution-ShareAlike '
#                   '4.0 International License.',
#   'convertor_author': 'Ernst Boogert',
#   'convertor_date': 'July, 2020',
#   'convertor_execution': 'Ernst Boogert',
#   'convertor_institution': 'Protestant Theological University (PThU), '
#                            'Amsterdam/Groningen, The Netherlands',
#   'convertor_version': '1.0.0',
#   'dateWritten': '2020-12-11T14:43:18Z',
#   'editor': 'A.J. Brock',
#   'filename': 'tlg0057.tlg010.perseus-grc1',
#   'funder': 'National Library of Medicine History of Medicine Division',
#   'placeName': 'Ctesiphon',
#   'principal': 'Gregory Crane',
#   'publicationStmt': 'Cultural Heritage Langauge Technologies, Kansas City '
#                      'Missouri, July 1, 2005.',
#   'respStmt': 'Prepared under the supervision of, Lisa Cerrato, Alison Babeu, '
#               'Bridget Almas, Monica Berti',
#   'sourceDesc': 'On the Natural Faculties, Galen, A.J. Brock, Cambridge, Mass, '
#                 'Harvard University Press, 1916.',
#   'sponsor': 'Perseus Project, Tufts University',
#   'title': 'On the Natural Faculties',
#   'valueType': 'str',
#   'writtenBy': 'Text-Fabric'}
# { 'author': 'Archimedes',
#   'availability': 'Available under a Creative Commons Attribution-ShareAlike '
#                   '4.0 International License.',
#   'convertor_author': 'Ernst Boogert',
#   'convertor_date': 'July, 2020',
#   'convertor_execution': 'Ernst Boogert',
#   'convertor_institution': 'Protestant Theological University (PThU), '
#                            'Amsterdam/Groningen, The Netherlands',
#   'convertor_version': '1.0.0',
#   'dateWritten': '2020-12-11T14:50:19Z',
#   'editor': 'Charles Mugler',
#   'filename': 'tlg0552.tlg013.1st1K-grc1',
#   'funder': 'Harvard Library Arcadia Fund',
#   'principal': 'Gregory Crane',
#   'publicationStmt': 'Harvard College Library, tlg0552.tlg013.1st1K-grc1.xml.',
#   'respStmt': 'Digital Divide Data, Corrected and encoded the text, Gregory '
#               'Crane, Editor-in-Chief, Perseus Digital Library, Matt Munson, '
#               'Project Manager (University of Leipzig), Annette Gessner, '
#               'Project Assistant (University of Leipzig) 2015 - 2017, Thibault '
#               'Clérice, Lead Developer (University of Leipzig) 2015 - 2017, '
#               'Bruce Robertson, Technical Advisor',
#   'sourceDesc': 'Archimède, Charles Mugler, Archimedes, Les Belles Lettres, '
#                 'Paris, 1972, 4, SLUB Dresden.',
#   'sponsor': 'University of Leipzig',
#   'title': 'Fragmenta',
#   'valueType': 'str',
#   'writtenBy': 'Text-Fabric'}
# { 'author': 'Vettius Valens',
#   'availability': 'Available under a Creative Commons Attribution-ShareAlike '
#                   '4.0 International License.',
#   'convertor_author': 'Ernst Boogert',
#   'convertor_date': 'July, 2020',
#   'convertor_execution': 'Ernst Boogert',
#   'convertor_institution': 'Protestant Theological University (PThU), '
#                            'Amsterdam/Groningen, The Netherlands',
#   'convertor_version': '1.0.0',
#   'dateWritten': '2020-12-11T14:50:12Z',
#   'editor': 'Wilhelm Kroll',
#   'filename': 'tlg1764.tlg001.1st1K-grc1',
#   'funder': 'Harvard Library Arcadia Fund',
#   'principal': 'Gregory Crane',
#   'publicationStmt': 'Harvard College Library, tlg1764.tlg001.1st1K-grc1.xml.',
#   'respStmt': 'Digital Divide Data, Corrected and encoded the text, Gregory '
#               'Crane, Editor-in-Chief, Perseus Digital Library, Matt Munson, '
#               'Project Manager (University of Leipzig), Annette Gessner, '
#               'Project Assistant (University of Leipzig) 2015 - 2017, Thibault '
#               'Clérice, Lead Developer (University of Leipzig), Bruce '
#               'Robertson, Technical Advisor',
#   'sourceDesc': 'Anthologiarum libri, Guilelmus Kroll, Vettius Valens, '
#                 'Weidmann, Berlin, 1908, Hathi Trust.',
#   'sponsor': 'Harvard College Library',
#   'title': 'Anthologiarum libri ix',
#   'valueType': 'str',
#   'writtenBy': 'Text-Fabric'}

# %% [markdown]
# We now make a catalog based on author and title of the works.

# %%
def getCatalog(tfDirs):
    """Given a list of TF datasets, make a catalog of them.
    
    The catalog is first by author, then by title.
    """
    
    works = collections.defaultdict(list)
    
    for tfDir in tfDirs:
        meta = getMeta(tfDir)
        author = meta.get("author", "")
        title = meta.get("title", "")
        works[author].append(title)
    
    return works

# %%
works = getCatalog(tfDirs)
pprint(works)
print(f"{len(works)} authors")
# Out:
# defaultdict(<class 'list'>,
#             { '>, Catenae (Novum Testamentum)': [ 'Catena In Epistulam I Ad '
#                                                   'Timotheum'],
#               'Achilles Tatius': [ 'Leucippe et Clitophon',
#                                    'Hymn 9 To Artemis, Machine readable text',
#                                    'Hymn 31 To Helios, Machine readable text',
#                                    'Hymn 7 To Dionysus, Machine readable text',
#                                    'Hymn 1 To Dionysus, Machine readable text',
#                                    'Hymn 6 To Aphrodite, Machine readable text',
#                                    'Hymn 30 To Earth, Machine readable text',
#                                    'Hymn 8 To Ares, Machine readable text',
#                                    'Hymn 15 To Heracles the Lion-Hearted, '
#                                    'Machine readable text',
#                                    'Hymn 12 To Hera, Machine readable text',
#                                    'Hymn 24 To Hestia, Machine readable text',
#                                    'Hymn 23 to Zeus, Machine readable text',
#                                    'Hymn 22 To Poseidon, Machine readable text',
#                                    'Hymn 25 To the Muses and Apollo, Machine '
#                                    'readable text',
#                                    'Hymn 13 To Demeter, Machine readable text',
#                                    'Hymn 14 to the Mother of the Gods, Machine '
#                                    'readable text',
#                                    'Hymn 32 To Selene, Machine readable text',
#                                    'Hymn 3 To Apollo, Machine readable text',
#                                    'Hymn 4 To Hermes, Machine readable text',
#                                    'Hymn 5 To Aphrodite, Machine readable text',
#                                    'Hymn 2 To Demeter, Machine readable text',
#                                    'Hymn 33 To the Dioscuri, Machine readable '
#                                    'text',
#                                    'Hymn 16 To Asclepius, Machine readable '
#                                    'text',
#                                    'Hymn 29 To Hestia, Machine readable text',
#                                    'Hymn 20 To Hephaestus, Machine readable '
#                                    'text',
#                                    'Hymn 27 To Artemis, Machine readable text',
#                                    'Hymn 18 To Hermes, Machine readable text',
#                                    'Hymn 26 To Dionysus, Machine readable text',
#                                    'Hymn 19 to Pan, Machine readable text',
#                                    'Hymn 21 To Apollo, Machine readable text',
#                                    'Hymn 17 To the Dioscuri, Machine readable '
#                                    'text',
#                                    'Hymn 28 To Athena, Machine readable text',
#                                    'Hymn 10 To Aphrodite, Machine readable '
#                                    'text'],
#               'Acta Joannis': ['Acta Joannis', 'Acta Joannis (recenscio)'],
#               'Adamantius': ['Physiognomonica (epitome Matritensis)'],
#               'Adamantius Judaeus': ['Physiognomonica'],
#               'Aelian': [ 'De Natura Animalium',
#                           'Epistulae Rusticae',
#                           'Varia Historia'],
#               'Aelius Theon': ['Progymnasmata'],
#               'Aeneas Tacticus': [ 'Περὶ τοῦ πῶς χρὴ πολιορκουμένους ἀντέχειν',
#                                    'New Testament - 1 Corinthians, Machine '
#                                    'readable text',
#                                    'New Testament - Romans, Machine readable '
#                                    'text',
#                                    'New Testament - 1 John, Machine readable '
#                                    'text',
#                                    'New Testament - 2 Peter, Machine readable '
#                                    'text',
#                                    'New Testament - Luke, Machine readable '
#                                    'text',
#                                    'New Testament - Acts, Machine readable '
#                                    'text',
#                                    'New Testament - 2 Timothy, Machine '
#                                    'readable text',
#                                    'New Testament - Philemon, Machine readable '
#                                    'text',
#                                    'New Testament - 1 Peter, Machine readable '
#                                    'text',
#                                    'New Testament - Titus, Machine readable '
#                                    'text'],
#               'Aeschines': [ 'Against Timarchus',
#                              'Against',
#                              'The Speech on the Embassy'],
#               'Aeschylus': [ 'Eumenides, Machine readable text',
#                              'Suppliant Maidens, Machine readable text',
#                              'Libation Bearers, Machine readable text',
#                              'Prometheus Bound, Machine readable text',
#                              'Seven Against Thebes, Machine readable text',
#                              'Agamemnon, Machine readable text',
#                              'Persians, Machine readable text',
#                              'Eumenides',
#                              'Ἱκέτιδες',
#                              'Χοηφóρoι',
#                              'Προμηθευς δεσμωτης',
#                              'Ἑπτὰ ἐπὶ Θήβας',
#                              'Ἀγαμέμνων',
#                              'Περσαι'],
#               'Aesop': ['Fabulae'],
#               'Agatharchides': [ 'Ex Agatharchidis De Maris Erythraeo Libri '
#                                  'Excerpta'],
#               'Agathemerus': [ 'Geographiae Informatio',
#                                'Geographiae Informatio',
#                                'Geographiae Informatio',
#                                'Geographiae Informatio',
#                                'Geographiae Informatio',
#                                'Geographiae Informatio'],
#               'Agathias Scholasticus': ['Historiae', 'Epigrammata'],
#               'Alcidamas': ['Peri Sophiston', 'Odysseus'],
#               'Alciphron': ['Epistulae'],
#               'Alexander of Aphrodisias': [ 'In Librum De Sensu Commentarium',
#                                             'In Aristotelis Sophisticos '
#                                             'Elenchos Commentarius [Sp.]',
#                                             'De mixtione',
#                                             'In Aristotelis topicorum libros '
#                                             'octo commentaria',
#                                             'In Aristotelis Meteorologicorum '
#                                             'Libros Commentaria',
#                                             'Ἀπορίαι καὶ λύσεις [Sp.]',
#                                             'Quaestiones',
#                                             'Ἠθικὰ προβλήματα [Sp.]',
#                                             'De fato',
#                                             'In Aristotelis metaphysica '
#                                             'commentaria',
#                                             'In Aristotelis analyticorum '
#                                             'priorum librum I commentarium',
#                                             'De anima libri mantissa',
#                                             'De anima'],
#               'Alypius': ['Isagoge musica'],
#               'Ammonius': [ 'In Porphyrii Isagogen Sive Quinque Voces',
#                             'In Aristotelis Librum De Interpretatione '
#                             'Commentarius',
#                             'In Aristotelis Analyticorum Priorum Librum I '
#                             'Commentarium',
#                             'In Aristotelis Categorias Commentarius'],
#               'Ammonius Grammaticus': [ 'De adfinium vocabulorum differentia, '
#                                         'ΠΕΡΙ ΟΜΟΙΩΝ ΚΑΙ ΔΙΑΦΟΡΩΝ ΛΕΞΕΩΝ'],
#               'Andocides': [ 'On the Mysteries',
#                              'On the Peace with',
#                              'Against Alcibiades',
#                              'On His Return'],
#               'Anna Comnena': ['Alexias'],
#               'Annae Comnenae': ['Alexias'],
#               'Anonymi Exegesis In Hesiodi Theogoniam': [ 'Exegesis in Hesiodi '
#                                                           'theogoniam'],
#               'Anonymi In Aristotelis Categorias': ['Paraphrasis categoriarum'],
#               'Anonymi In Aristotelis Ethica Nicomachea': [ 'In ethica '
#                                                             'Nicomachea '
#                                                             'paraphrasis'],
#               'Anonymi In Aristotelis Librum Alterum Analyticorum Posteriorum': [ 'Anonymi '
#                                                                                   'in '
#                                                                                   'analyticorum '
#                                                                                   'posteriorum '
#                                                                                   'librum '
#                                                                                   'alterum '
#                                                                                   'commentarium'],
#               'Anonymi In Aristotelis Sophisticos Elenchos': [ 'In Aristotelis '
#                                                                'sophisticos '
#                                                                'elenchos '
#                                                                'paraphrasis'],
#               'Anonymous': [ 'Geographiae expositio compendiaria',
#                              'IOANNIS ZONARAE EPITOME HISTORIARUM',
#                              'IOANNIS ZONARAE EPITOME HISTORIARUM',
#                              'IOANNIS ZONARAE EPITOME HISTORIARUM',
#                              'Scholia in Dionysium Periegetam',
#                              'GELASIUS KIRCHENGESCHICHTE',
#                              'CORPUS SCRIPTORUM HISTORIAE BYZANTINAE',
#                              'ANNAE COMNENAE',
#                              'ROCLUS DIADOCHUS',
#                              'METHODIUS',
#                              'METHODIUS',
#                              'METHODIUS',
#                              'EPIPHANIUS',
#                              'EPIPHANIUS',
#                              'EPIPHANIUS',
#                              'COMMENTARIA IN ARISTOTELEM GRAECA',
#                              'Anonymi summaria ratio geographiae in sphaera '
#                              'intelligendae',
#                              'THE BOOK OF ISAIAH',
#                              'In Dionysii periegetae orbis descriptionem',
#                              'Martyrium Polycarpi',
#                              'Stadiasmus Magni Maris',
#                              'Anametresis Pontou'],
#               'Anonymus': ['Didache XII Apostolorum'],
#               'Anonymus Londinensis': [ 'EUSEBII CAESARIENSIS OPERA',
#                                         'EUSEBII CAESARIENSIS OPERA',
#                                         'EUSEBIUS WERKE',
#                                         'EUSEBIUS WERKE',
#                                         'EUSEBIUS WERKE',
#                                         'EUSEBIUS WERKE',
#                                         'Commentaria in Aristotelem Graeca',
#                                         'Catenae Graecorum Patrum in Novum '
#                                         'Testamentum',
#                                         'Catenae Graecorum Patrum in Novum '
#                                         'Testamentum',
#                                         'Libanius Opera',
#                                         'Iatrica'],
#               'Antiphon': [ 'Prosecution Of The Stepmother For Poisoning, '
#                             'Machine readable text',
#                             'On the Choreutes, Machine readable text',
#                             'The Second Tetralogy: Prosecution for Accidental '
#                             'Homicide, Machine readable text',
#                             'The Third Tetralogy: Prosecution for Murder Of '
#                             'One Who Pleads Self-Defense, Machine readable '
#                             'text',
#                             'Περὶ τοῦ Ἡρῷδου φόνου, Machine readable text',
#                             'Anonymous Prosecution for Murder, Machine '
#                             'readable text'],
#               'Antisthenes': ['Odysseus, ΟΔΥΣΣΕΥΣ', 'Ajax, Αιας'],
#               'Anubion': ['Fragmenta'],
#               'Apollodorus': [ 'Library, Machine readable text',
#                                'Epitome, Machine readable text'],
#               'Apollonius Rhodius': ['Argonautica'],
#               'Apollonius, Dyscolus': [ 'De pronominibus',
#                                         'De constructione',
#                                         'De adverbiis'],
#               'Appian': [ 'Punic Wars',
#                           'Wars in Spain',
#                           'Sicily and the Other Islands',
#                           'Hannibalic War',
#                           'Illyrian Wars',
#                           'Syrian Wars',
#                           'Mithridatic Wars',
#                           'Italy',
#                           'Samnite History',
#                           'Gallic History',
#                           'Kings',
#                           'Macedonian Affairs',
#                           'The Civil Wars',
#                           'Numidian Affairs'],
#               'Aratus Solensis': ['Phaenomena'],
#               'Archimedes': ['Fragmenta'],
#               'Archimède': [ 'Stomachion',
#                              'Quadratura parabolae',
#                              'De sphaera et cylindro',
#                              'Arenarius',
#                              'De corporibus fluitantibus',
#                              'Problema bovinum',
#                              'De conoidibus et sphaeroidibus',
#                              'De lineis spiralibus',
#                              'De planorum aequilibriis',
#                              'Dimensio circuli',
#                              'Liber assumptorum',
#                              'Ad Eratosthenem methodus'],
#               'Aretaeus': [ 'De causis et signis acutorum morborum',
#                             'De curatione acutorum morborum',
#                             'De curatione diuturnorum morborum',
#                             'De causis et signis diuturnorum morborum'],
#               'Aristarchus of Samos': [ 'De magnitudinibus et distantiis solis '
#                                         'et lunae'],
#               'Aristides, Aelius': [ 'Orationes 54, Machine readable text',
#                                      'Orationes 53, Machine readable text',
#                                      'Orationes 9, Machine readable text',
#                                      'Orationes 36, Machine readable text',
#                                      'Orationes 31, Machine readable text',
#                                      'Orationes 38, Machine readable text',
#                                      'Orationes 7, Machine readable text',
#                                      'Orationes 52, Machine readable text',
#                                      'Orationes 55, Machine readable text',
#                                      'Orationes 1, Machine readable text',
#                                      'Orationes 39, Machine readable text',
#                                      'Orationes 6, Machine readable text',
#                                      'Orationes 30, Machine readable text',
#                                      'Orationes 8, Machine readable text',
#                                      'Orationes 37, Machine readable text',
#                                      'Orationes 15, Machine readable text',
#                                      'Orationes 12, Machine readable text',
#                                      'Orationes 24, Machine readable text',
#                                      'Orationes 23, Machine readable text',
#                                      'Orationes 48, Machine readable text',
#                                      'Orationes 46, Machine readable text',
#                                      'Orationes 41, Machine readable text',
#                                      'Orationes 22, Machine readable text',
#                                      'Orationes 25, Machine readable text',
#                                      'Orationes 13, Machine readable text',
#                                      'Orationes 14, Machine readable text',
#                                      'Orationes 40, Machine readable text',
#                                      'Orationes 47, Machine readable text',
#                                      'Orationes 49, Machine readable text',
#                                      'Orationes 32, Machine readable text',
#                                      'Orationes 35, Machine readable text',
#                                      'Orationes 3, Machine readable text',
#                                      'Orationes 4, Machine readable text',
#                                      'Orationes 50, Machine readable text',
#                                      'Orationes 5, Machine readable text',
#                                      'Orationes 2, Machine readable text',
#                                      'Orationes 34, Machine readable text',
#                                      'Orationes 33, Machine readable text',
#                                      'Ars Rhetorica, Machine readable text',
#                                      'Orationes 51, Machine readable text',
#                                      'Orationes 42, Machine readable text',
#                                      'Orationes 45, Machine readable text',
#                                      'Orationes 11, Machine readable text',
#                                      'Orationes 16, Machine readable text',
#                                      'Orationes 29, Machine readable text',
#                                      'Orationes 20, Machine readable text',
#                                      'Orationes 27, Machine readable text',
#                                      'Orationes 18, Machine readable text',
#                                      'Orationes 44, Machine readable text',
#                                      'Orationes 43, Machine readable text',
#                                      'Orationes 26, Machine readable text',
#                                      'Orationes 19, Machine readable text',
#                                      'Orationes 21, Machine readable text',
#                                      'Orationes 17, Machine readable text',
#                                      'Orationes 28, Machine readable text',
#                                      'Orationes 10, Machine readable text'],
#               'Aristophanes': [ 'Frogs, Machine readable text',
#                                 'Lysistrata, Machine readable text',
#                                 'Lysistrata, Machine readable text',
#                                 'Acharnians, Machine readable text',
#                                 'Birds, Machine readable text',
#                                 'Thesmophoriazusae, Machine readable text',
#                                 'Clouds, Machine readable text',
#                                 'Clouds, Machine readable text',
#                                 'Wasps, Machine readable text',
#                                 'Peace, Machine readable text',
#                                 'Knights, Machine readable text',
#                                 'Plutus, Machine readable text',
#                                 'Ecclesiazusae, Machine readable text',
#                                 'Ecclesiazusae, Machine readable text'],
#               'Aristophanes of Byzantium': ['Historiae Animalium Epitome'],
#               'Aristoteles': [ 'De animalium motione',
#                                'De spiritu',
#                                'De animalium incessu'],
#               'Aristotle': [ 'Eudemian Ethics (Greek). Machine readable text',
#                              'Rhetoric',
#                              'Metaphysics (Greek). Machine readable text',
#                              'Politics (Greek). Machine readable text',
#                              'Athenian Constitution, Machine readable text',
#                              'Ars Poetica',
#                              'Virtues and Vices, Machine readable text',
#                              'Economics (Greek). Machine readable text',
#                              'Nicomachean Ethics, Machine readable text',
#                              'Physica (textus alter)',
#                              'Physica',
#                              'De anima (codicis E fragmenta recensionis a '
#                              'vulgata diversae)',
#                              'Aristotelis Analytica Priora et Posteriora',
#                              'Analytica priora',
#                              'Categoriae',
#                              'De partibus animalium',
#                              'De divinatione per somnum',
#                              'De respiratione',
#                              'De memoria et reminiscentia',
#                              'De sensu et sensibilibus',
#                              'Magna Moralia',
#                              'De generatione et corruptione',
#                              'De generatione et corruptione',
#                              'Historia animalium',
#                              'De sophisticis elenchis',
#                              'Fragmenta Deperditae Partis Primae',
#                              'Res Publica Atheniensium',
#                              'De caelo',
#                              'De anima',
#                              'De anima',
#                              'Ars Poetica',
#                              'De somno et vigilia',
#                              'De insomniis',
#                              'De longitudine et brevitate vitae',
#                              'De iuventute et senectute, De vita et morte',
#                              'Topica',
#                              'Meteorologica',
#                              'Meteorologica',
#                              'De interpretatione'],
#               'Aristoxenus': ['Elementa Harmonica'],
#               'Arrian': [ 'Anabasis',
#                           'Acies Contra Alanos',
#                           'Cynegeticus',
#                           'Periplus Ponti Euxini',
#                           'Tactica',
#                           'Indica'],
#               'Artemidorus': ['Onirocriticon'],
#               'Asclepiodotus': ['Tactica'],
#               'Asclepius': [ 'In Aristotelis Metaphysicorum Libros A-Z '
#                              'Commentaria'],
#               'Aspasius': ['In Ethica Nicomachea paraphrasis'],
#               'Athanasius': [ 'Oratio quarta contra Arianos [Sp.]',
#                               'Oratio III contra Arianos',
#                               'Oratio II contra Arianos',
#                               'Oratio I contra Arianos'],
#               'Athanasius of Alexandria': [ 'De decretis Nicaenae synodi '
#                                             '(Chapters 41 and 42)'],
#               'Athenaeus': [ 'Deipnosophistae',
#                              'The Deipnosophists, Machine readable text'],
#               'Athenagoras': [ '01',
#                                'Supplication pro Christianis',
#                                'Legatio sive Supplicatio pro Christianis',
#                                'De resurrectione',
#                                'De Resurrectione'],
#               'Autolycus': [ 'De Sphaera Quae Movetur',
#                              'De Ortibus et Occasibus'],
#               'Babrius': ['Fabulae Aesopeae', 'Fabulae Aesopeae'],
#               'Bacchius Geron': ['Isagoge'],
#               'Bacchylides': ['Odes (Greek) - Ep', 'Odes (Greek) - Dith'],
#               'Barnabas': ['The Epistle of Barnabas', 'Barnabae epistula'],
#               'Basil, Saint, Bishop of Caesarea': [ 'Epistulae',
#                                                     'To Young Men, On How They '
#                                                     'Might Dervice Profit From '
#                                                     'Pagan Literature'],
#               'Bion of Phlossa': [ 'Epitaphius Adonis',
#                                    'Fragmenta',
#                                    'Epithalamium Achillis et Deidameiae'],
#               'Callimachus': [ 'Hymn to Zeus',
#                                'Hymn to Zeus',
#                                'Epigrams',
#                                'Epigrams, Fragmenta',
#                                'Hymn to Apollo',
#                                'Hymn to Apollo',
#                                'Hymn to Demeter',
#                                'Hymn to Demeter',
#                                'Hymn to Delos',
#                                'Hymn to Delos',
#                                'Hymn to Athena',
#                                'Hymn to Athena',
#                                'Hymn to Artemis',
#                                'Hymn to Artemis'],
#               'Callistratus': ['Statuaram Descriptiones'],
#               'Canticum Euripidis': ['Ex Orestis Stasimo I'],
#               'Carmina Delphis Inventa': ['Carmina Delphis Inventa'],
#               'Cassius Dio Cocceianus': ['Historiae Romanae'],
#               'Cassius Longinus': ['Ars rhetorica', 'Excerpta'],
#               'Catenae (Novum Testamentum)': [ 'Catena In Epistulam Ad Titum',
#                                                'Catena In Epistulam Ad '
#                                                'Hebraeos',
#                                                'Supplementum Et Varietas '
#                                                'Lectionis Ad Catenam In '
#                                                'Evangelium',
#                                                'Prooemium Pseudo-Oecumenii In '
#                                                'Apocalypsin Commentarii',
#                                                'Catena In Matthaeum',
#                                                'Supplementum Et Varietas '
#                                                'Lectionis Ad Catenam In '
#                                                'Evangelium sancti Lucae',
#                                                'Catena In Acta',
#                                                'Catena In Epistulam Ad '
#                                                'Philemonem',
#                                                'Catena In Epistulam I Ad '
#                                                'Corinthios',
#                                                'Catena In Epistulam II Ad '
#                                                'Thessalonicenses',
#                                                'Catena In Epistulam I Ad '
#                                                'Thessalonicenses',
#                                                'Catena In Epistulam Juda',
#                                                'Catena In Epistulam Petri I',
#                                                'Catena In Epistulam Ad '
#                                                'Colossenses',
#                                                'Catena In Epistulam II Ad '
#                                                'Corinthios',
#                                                'Catena In Epistulam Jacobi',
#                                                'Catena In Epistulam II Ad '
#                                                'Timotheum',
#                                                'Supplementum et varietas '
#                                                'lectionis ad commentarium '
#                                                'Chrysostomi in evangelium '
#                                                'sancti Matthaei',
#                                                'Commentarius In Apocalypsin',
#                                                'Catena In Lucam',
#                                                'Catena In Joannem',
#                                                'Catena In Marcum',
#                                                'Commentarius In Apocalypsin',
#                                                'Catena In Epistulam Petri II',
#                                                'Catena In Epistulam Joannis '
#                                                'III',
#                                                'Catena In Epistulam Ad Romanos '
#                                                '(typus Monacensis)',
#                                                'Catena In Epistulam Ad '
#                                                'Ephesios',
#                                                'Catena In Epistulam Joannis II',
#                                                'Catena In Epistulam Joannis I',
#                                                'Catena In Epistulam Ad Galatas',
#                                                'Catena In Epistulam Ad '
#                                                'Philippenses',
#                                                'Catena In Epistulam Ad Romanos '
#                                                '(typus Vaticanus)'],
#               'Chariton': ['De Chaerea et Callirhoe'],
#               'Chronicon Paschale': ['Chronicon Paschale'],
#               'Claudius Ptolemaeus': [ 'Apotelesmatica (= Tetrabiblos)',
#                                        'Syntaxis mathematica',
#                                        'Musica'],
#               'Claudius Ptolemy': ['Tetrabiblos'],
#               'Clemens Romanus': [ 'Epistula I ad Corinthios',
#                                    'Epistula II ad Corinthios'],
#               'Clement of Alexandria': [ 'Protrepticus',
#                                          'Quis Dis Salvetur',
#                                          'Exhortation to Endurance, or to the '
#                                          'Newly Baptized',
#                                          'Stromata (Books I-VI)',
#                                          'Excerpta ex Theodoto',
#                                          'Protrepticus',
#                                          'Quis dives salvetur',
#                                          'Stromata',
#                                          'Eclogae propheticae',
#                                          'Paedagogus'],
#               'Cleomedes': ['De motu circulari corporum caelestium'],
#               'Cleonides': ['Introductio Harmonica'],
#               'Colluthus': [ 'Rape of Helen',
#                              'New Testament - Galatians, Machine readable text',
#                              'New Testament - Matthew, Machine readable text',
#                              'New Testament - 2 Corinthians, Machine readable '
#                              'text',
#                              'New Testament - 1 Timothy, Machine readable text',
#                              'New Testament - Colossians, Machine readable '
#                              'text',
#                              'New Testament - 2 John, Machine readable text',
#                              'New Testament - 3 John, Machine readable text',
#                              'New Testament - 1 Thessalonians, Machine '
#                              'readable text',
#                              'New Testament - 2 Thessalonians, Machine '
#                              'readable text',
#                              'New Testament - John, Machine readable text',
#                              'New Testament - Mark, Machine readable text',
#                              'New Testament - Philippians, Machine readable '
#                              'text',
#                              'New Testament - James, Machine readable text',
#                              'New Testament - Revelation, Machine readable '
#                              'text',
#                              'New Testament - Jude, Machine readable text',
#                              'New Testament - Hebrews, Machine readable text',
#                              'New Testament - Ephesians, Machine readable '
#                              'text'],
#               'Crateuas': ['Fragmenta'],
#               'Cyrillus Alexandrinus': ['In XII Prophetas'],
#               'David the Invincible': [ 'Prolegomena philosophiae',
#                                         'In Porphyrii isagogen commentarium'],
#               'Demades': ['On the Twelve Years'],
#               'Demetrius of Phaleron (Attributed Author)': [ 'Libro de '
#                                                              'Elocutione'],
#               'Demosthenes': [ 'κατὰ Κόνωνος αἰκείας',
#                                'πρὸς Νικόστρατον περὶ ἀνδραπόδων ἀπογραφῆς '
#                                'Ἀρεθουσίου',
#                                'προοίμια δημηγορικά',
#                                'κατὰ Φιλίππου γ΄',
#                                'παραγραφὴ ὑπὲρ Φορμίωνος',
#                                'πρὸς Ὀνήτορα ἐξούλης β΄',
#                                'παραγραφὴ πρὸς Ναυσίμακον καὶ Ξενοπείθην',
#                                'περὶ Ἀλοννήσου',
#                                'Δημοσθένους ἐπιστολαὶ',
#                                'πρὸς Κάλλιππον',
#                                'πρὸς Καλλικλέα περὶ χωρίου βλάβης',
#                                'Ὀλυνθιακὸς α΄',
#                                'πρὸς Βοιωτὸν περὶ τοῦ Ὀνόματος',
#                                'κατὰ Φιλίππου β΄',
#                                'πρὸς Ὀνήτορα ἐξούλης α΄',
#                                'περὶ τῶν ἐν Χερρονήσῳ',
#                                'παραγραφὴ πρὸς Πανταίνετον',
#                                'ὑπὲρ τῆς Ῥοδίων ἐλευθερίας',
#                                'ἐπιστολή [Φιλίππου]',
#                                'κατὰ Τιμοκράτους',
#                                'κατὰ Ἀριστοκράτους',
#                                'κατὰ Ὀλυμπιοδώρου βλάβης',
#                                'κατὰ Στεφάνου ψευδομαρτυριῶν β΄',
#                                'πρὸς Σπουδίαν ὑπὲρ προικός',
#                                'κατὰ Ἀνδροτίωνος παρανόμων',
#                                'κατὰ Ἀριστογείτονος α΄',
#                                'περὶ συντάξεως',
#                                'περὶ τῶν συμμοριῶν',
#                                'πρὸς Βοιωτὸν περὶ προικὸς μητρῴας',
#                                'κατὰ Εὐέργου καὶ Μνησιβούλου ψευδομαρτυριῶν',
#                                'πρὸς Τιμόθεον ὑπὲρ χρέως',
#                                'πρὸς Ζηνόθεμιν παραγραφή',
#                                'πρὸς τὴν Λάκριτον παραγραφὴν',
#                                'Ὀλυνθιακὸς γ΄',
#                                'κατὰ Φιλίππου α΄',
#                                'πρὸς Πολυκλέα περὶ τοῦ ἐπιτριηραρχήματος',
#                                'ἔφεσις πρὸς Εὐβουλίδην',
#                                'ἐρωτικὸς',
#                                'κατὰ Νεαίρας',
#                                'περὶ τῆς εἰρήνης',
#                                'Ὀλυνθιακὸς β΄',
#                                'πρὸς Φορμίωνα ὑπὲρ δανείου',
#                                'πρὸς Ἀπατούριον παραγραφή',
#                                'ἔνδειξις κατὰ Θεοκρίνου',
#                                'ἐπιτάφιος',
#                                'κατὰ Διονυσοδώρου βλάβης',
#                                'περὶ τοῦ Στεφάνου τῆς τριηραρκίας',
#                                'πρὸς Φαίνιππον περὶ ἀντιδόσεως',
#                                'κατὰ Στεφάνου ψευδομαρτυριῶν α΄',
#                                'πρὸς τὴν ἐπιστολήν τὴν Φιλίππου',
#                                'ὑπὲρ Μεγαλοπολιτῶν',
#                                'πρὸς Ἄφοβον ὑπὲρ Φάνου ψευδομαρτυριῶν γ΄',
#                                'περὶ τῆς Ἀτελείας πρὸς Λεπτίνην',
#                                'κατὰ Ἀφόβου ἐπιτροπῆς α΄',
#                                'ὑπὲρ Κτησιφῶντος περὶ τοῦ στεφάνου',
#                                'πρὸς Λεωκάρη περὶ τοῦ Ἀρχιάδου κλήρου',
#                                'πρὸς Μακάρτατον περὶ Ἁγνίου κλήρου',
#                                'κατὰ Ἀριστογείτονος β΄',
#                                'περὶ τῆς παραπρεσβείας',
#                                'κατὰ Μειδίου περὶ τοῦ Κονδύλου',
#                                'περὶ τῶν πρὸς Ἀλέξανδρον συνθηκῶν',
#                                'κατὰ Ἀφόβου β΄',
#                                'κατὰ Φιλίππου δ΄'],
#               'Dexippus': ['In Aristotelis categorias commentarium'],
#               'Didymus Alexandrinus': [ 'Mensuris marmorum',
#                                         'Mensurae marmorum ac lignorum'],
#               'Dinarchus': [ 'Against Philocles',
#                              'Against Demosthenes',
#                              'Against Aristogiton'],
#               'Dio Chrysostom': ['Orationes'],
#               'Diodorus Siculus': [ 'Library (Greek). Machine readable text',
#                                     'Bibliotheca Historica, Books XVIII-XX, '
#                                     'Machine readable text',
#                                     'Bibliotheca Historica, Books I-V, Machine '
#                                     'readable text'],
#               'Diogenes Laertius': ['Lives of Eminent Philosophers'],
#               'Dionysius Calliphontis': [ 'Dionysii Calliphontis filii '
#                                           'Descriptio Graeciae'],
#               'Dionysius Corinthius': ['Fragmenta'],
#               'Dionysius Halicarnassensis': [ 'Libri secundi de antiquis '
#                                               'oratoribus reliquiae',
#                                               'De Demosthenis dictione'],
#               'Dionysius Periegetes': ['Orbis Descriptio'],
#               'Dionysius of Byzantium': ['De Bospori Navigatione'],
#               'Dionysius of Halicarnassus': [ 'De Dinarcho',
#                                               'Libri secundi de antiquis '
#                                               'oratoribus reliquiae',
#                                               'Antiquitates Romanae, Books '
#                                               'I-XX',
#                                               'De Demosthene',
#                                               'Ad Ammaeum',
#                                               'Epistula ad Pompeium Geminum',
#                                               'De Compositione Verborum',
#                                               'De Lysia',
#                                               'De Isocrate',
#                                               'De Isaeo',
#                                               'De antiquis oratoribus',
#                                               'De Thucydidis idiomatibus '
#                                               '(epistula ad Ammaeum)',
#                                               'De Thucydide'],
#               'Diophantus Alexandrinus': [ 'Fragmentum [Sp.] (e cod. Paris. '
#                                            'suppl. gr. 387, fol. 181r)',
#                                            'Fragmentum [Sp.] (e cod. Paris. '
#                                            '453)',
#                                            'Fragmentum [Sp.] (e cod. Paris. '
#                                            'gr. 2448)'],
#               'Dioscurides Pedianus': ['De materia medica'],
#               'Dorotheus of Sidon': ['Fragmenta alia antiqua'],
#               'Elias': [ 'In Porphyrii isagogen',
#                          'Eliae (olim Davidis) in Aristotelis categorias '
#                          'commentarium'],
#               'Epictetus': [ 'Greek Anthology, Volume IV, Machine readable '
#                              'text',
#                              'Ἀρριανοῦ τῶν Ἐπικτήτου Διατριβῶν',
#                              'Fragmenta',
#                              'Ἐγχειρίδιον'],
#               'Epiphanius': [ 'Ancoratus',
#                               'Anacephalaeosis [Sp.]',
#                               'Panarion (Adversus haereses)'],
#               'Epitaphium Sicili': ['Sicili Epitaphium'],
#               'Euclid': [ 'Elements, Machine readable text',
#                           'Data',
#                           'Data (demonstrationes alterae)',
#                           'Sectio canonis [Sp.]',
#                           'Sectio canonis [Sp.]',
#                           'Phaenomena',
#                           'Phaenomena (recensio b)',
#                           'Phaenomena (demonstrationes alterae recensionis b)',
#                           'Fragmenta',
#                           'Epigramma'],
#               'Euclides': [ 'Optica',
#                             'Catoptrica (recensio Theonis?)',
#                             'Opticorum recensio Theonis'],
#               'Eunapius': ['Vitae Sophistarum'],
#               'Euripides': [ 'Ἡρακλῆς, Machine readable text',
#                              'Ἑκάβη, Machine readable text',
#                              'Andromache, Machine readable text',
#                              'Ἱκέτιδες, Machine readable text',
#                              'Φοίνισσαι, Machine readable text',
#                              'Ἠλέκτρα, Machine readable text',
#                              'Ἰφιγένεια ἐν Ταύροις, Machine readable text',
#                              'Ἑλένη, Machine readable text',
#                              'Τρῳάδες, Machine readable text',
#                              'Orestes, Machine readable text',
#                              'Ἰφιγένεια ἐν Αὐλίδι, Machine readable text',
#                              'Ῥῆσος, Machine readable text',
#                              'Βάκχαι',
#                              'Ἴων, Machine readable text'],
#               'Eusebius': [ 'De Ecclesiastica Theologia',
#                             'Praeperatio Evangelica',
#                             'De laudibus Constantini',
#                             'De Martyribus Palaestinae (Recensio Brevior)',
#                             'Demonstratio Evangelica',
#                             'Historia Ecclesiastica',
#                             'Historia Ecclesiastica',
#                             'Onomasticon',
#                             'Vita Constantini',
#                             'Constantini imperatoris oratio ad coetum '
#                             'sanctorum',
#                             'De Theophania (Fragmenta)'],
#               'Eusebius of Caesarea': ['Historia ecclesiastica'],
#               'Eustratius': ['In Aristotelis Ethica Nicomachea I Commentaria'],
#               'Eutocius': [ 'Commentarii in libros de sphaera et cylindro',
#                             'Commentarius in libros de planorum aequilibriis',
#                             'Commentarius in dimensionem circuli'],
#               'Eutropius': ['Breviarium historiae romanae'],
#               'Evagrius, Scholasticus': ['Historia Ecclesiastica'],
#               'Flavius Josephus': [ 'Antiquitates Judaicae, Machine readable '
#                                     'text',
#                                     'Contra Apionem, Machine readable text',
#                                     'De bello Judaico libri vii, Machine '
#                                     'readable text',
#                                     'Josephi vita, Machine readable text'],
#               'Galen': [ 'On the Natural Faculties',
#                          'De tumoribus praeter naturam',
#                          'De marcore',
#                          'De diebus decretoriis',
#                          'De praesagitione ex pulsibus',
#                          'De Humero iis Modis Prolapso quos Hippocrates non '
#                          'Vidit',
#                          'De temperamentis',
#                          'De temperamentis',
#                          'De sanitate tuenda',
#                          'De usu pulsuum',
#                          'De rebus boni malique suci',
#                          'Ars Medica',
#                          'Synopsis librorum suorum de pulsibus',
#                          'De crisibus',
#                          'De comate secundum Hippocratem',
#                          'In Hippocratis Prognosticum',
#                          'De inaequali intemperie',
#                          'Protrepticus',
#                          'Adhortatio ad artes addiscendas',
#                          'De ptisana',
#                          'De constitutione artis medicae ad Patrophilum',
#                          'De atra bile',
#                          'De elementis ex Hippocrate',
#                          'De instrumento odoratus',
#                          'De ossibus ad tirones',
#                          'De optima corporis nostri constitutione',
#                          'An in arteriis sanguis contineatur',
#                          'De typis',
#                          'De praenotione ad Epigenem',
#                          'De compositione medicamentorum per genera',
#                          'De curandi ratione per venae sectionem',
#                          'De substantia facultatum naturalium fragmentum',
#                          'De theriaca ad Pisonem',
#                          'De morborum temporibus',
#                          'De morborum differentiis',
#                          'De foetuum formatione',
#                          'De bono habitu',
#                          'De venarum arteriarumque dissectione',
#                          'De nervorum dissectione',
#                          'De dignotione ex insomniis',
#                          'De antidotis',
#                          'De totius morbi temporibus',
#                          'In Hippocratis De natura hominis',
#                          'De hirudinibus, revulsione, cucurbitula, incisione '
#                          'et scarificatione',
#                          'Adversus eos qui de typis scripserunt vel de '
#                          'circuitibus',
#                          'De compositione medicamentorum secundum locos I-VI',
#                          'De sophismatis seu captionibus penes dictionem',
#                          'De consuetudinibus',
#                          'De musculorum dissectione ad tirones',
#                          'De causis respirationis',
#                          'De placitis Hippocratis et Platonis',
#                          'De venereis (ap. Oribasium)',
#                          'De venereis',
#                          'Quod optimus medicus sit quoque philosophus',
#                          'De sectis ad eos qui introducuntur',
#                          'De plenitudine',
#                          'De locis affectis',
#                          'De venae sectione adversus Erasistratum',
#                          'De causis pulsuum',
#                          'In Hippocratis De articulis',
#                          'In Hippocratis Aphorismos',
#                          'De methodo medendi',
#                          'De differentiis pulsuum',
#                          'De optima doctrina',
#                          'De parvae pilae exercitio',
#                          'De parvae pilae exercitio',
#                          'Ad Glauconem de methodo medendi',
#                          'Adversus Lycum',
#                          'De pulsibus ad tirones',
#                          'Adversus ea quae Juliano in Hippocratis Aphorismos '
#                          'enuntiata sunt',
#                          'De dignoscendis pulsibus',
#                          'De difficultate respirationis',
#                          'De venae sectione adversus Erasistrateos Romae '
#                          'degentes',
# ...
#                             'Comparison of Alcibiades and Coriolanus',
#                             'Machine readable text, Titus Flamininus',
#                             'Themistocles',
#                             'Ποτερον τὰ τῆς ψυχῆς ἢ τὰ τοῦ σώματος πάθη '
#                             'χείρονα',
#                             'De sera numinis vindicta, Machine readable text',
#                             'De communibus notitiis adversus Stoicos, Machine '
#                             'readable text',
#                             'Αἴτια Ἑλληνικά',
#                             'Κεφαλαίων καταγραφή Ἑλληνικά',
#                             'De esu carnium I, Machine readable text',
#                             'De Stoicorum repugnantiis, Machine readable text',
#                             'De genio Socratis, Machine readable text',
#                             'Τὰ παλαιὰ τῶν Λακεδαινίων ἐπιτηδεύματα',
#                             'Τὰ παλαιὰ τῶν Λακεδαινίων ἐπιτηδεύματα',
#                             'Compendium Argumenti Stoicos absurdiora poetis '
#                             'dicere, Machine readable text',
#                             'De fato, Machine readable text',
#                             'Bruta animalia ratione uti, Machine readable text',
#                             'De Se Ipsum Citra Invidiam Laudando, Machine '
#                             'readable text',
#                             "Ὅτι οὐδ' ἡδέως ζῆν ἔστι κατ' Ἐπίκουρον",
#                             'Περὶ ἀδολεσχίας',
#                             'De garrulitate, Machine readable text'],
#               'Polyaenus': ['Strategemata', 'Excerpta Polyaeni'],
#               'Polybius': [ 'Histories',
#                             'Hymn 11 To Athena, Machine readable text'],
#               'Polycarp': ['Epistula ad Philippenses'],
#               'Porphyrius': [ 'In Aristotelis categorias expositio per '
#                               'interrogationem et responsionem',
#                               'Isagoge sive quinque voces',
#                               'De abstinentia',
#                               'Ad Marcellam',
#                               'Vita Pythagorae',
#                               'Historia philosophiae (fragmenta)'],
#               'Porphyry': [ 'Zetemata codicis Vaticani',
#                             'Quaestionum Homericanum ad Iliadem pertinentium '
#                             'reliquiae'],
#               'Proclus': ['Chrestomathy'],
#               'Proclus Diadochus': ['In Platonis Rem Publicam Commentarii'],
#               'Procopius': ['de Bellis', 'Historia Arcana (Anecdota)'],
#               'Ps. Dicaearchus': [ 'Dicaearchi, ut fertur, potius vero '
#                                    'Athenaei Descriptionis Graeciae Fragmenta '
#                                    'tria'],
#               'Pseudo Arrianus': [ 'Anonymi (Arriani, ut fertur) periplus '
#                                    'maris Erythraei'],
#               'Pseudo-Aristotle': ['De spiritu', 'De mundo'],
#               'Pseudo-Arrianus': [ 'Anonymi (Arriani, ut fertur) periplus '
#                                    'ponti Euxini'],
#               'Pseudo-Galen': [ 'Ad Gaurum quomodo animetur fetus',
#                                 'Introductio seu medicus',
#                                 'De theriaca ad Pamphilianum',
#                                 'De fasciis',
#                                 'De remediis parabilibus',
#                                 'De optima secta ad Thrasybulum'],
#               'Pseudo-Hippocrates': ['De septimestri partu'],
#               'Pseudo-Justinus Martyr': ['Epistula ad Diognetum'],
#               'Pseudo-Menander': [ 'Sententiae (corresponds to quotes from '
#                                    'Gregory Nazianzen, Carmen morale XXX) '
#                                    '(Greek)',
#                                    'Sententiae (corresponds to version Men ar '
#                                    'II) (Greek)',
#                                    'Sententiae (corresponds to version Men Ar '
#                                    'I) (Greek)'],
#               'Pseudo-Menander, Gregory Nazianzus': [ 'Sententiae = (Carmen '
#                                                       'morale XXX)'],
#               'Pseudo-Plutarch': [ 'Placita Philosophorum, Machine readable '
#                                    'text',
#                                    'De musica, Machine readable text',
#                                    'De Fluviis'],
#               'Pseudo-Polemon': [ 'Physiognomonica (Epitome Adamantiana)',
#                                   'Physiognomonica'],
#               'Pseudo-Scymnus': ['Scymni Chii, ut fertur, Periegesis'],
#               'Quintus Smyrnaeus': ['Fall of Troy'],
#               'Rufus Soph': ['Ars rhetorica'],
#               'Scholia Euripidem': [ 'Scholia in Euripidis Troiades',
#                                      'Scholia in Euripidis Hippolytum',
#                                      'Scholia in Euripidis Hecubam (scholia '
#                                      'vetera et scholia recentiora Thomae '
#                                      'Magistri, Triclinii, Moschopuli et '
#                                      'anonyma)',
#                                      'Scholia in Euripidis Rhesum',
#                                      'Vitae Euripidis'],
#               'Scholia In Euclidem': [ 'Scholia in Euclidis data et catoptrica '
#                                        '(scholia vetera)',
#                                        'Scholia in Euclidis phaenomena '
#                                        '(scholia vetera)',
#                                        'Scholia in Euclidis optica (scholia '
#                                        'vetera)',
#                                        'Scholia in opticorum recensionem '
#                                        'Theonis (scholia vetera)',
#                                        'Scholia in Euclidis catoptrica '
#                                        '(scholia vetera)',
#                                        'Scholia in Euclidis Data'],
#               'Scholia In Homerum': [ 'Scholia in Odysseam',
#                                       'Scholia in Iliadum',
#                                       'Batrachomyomachia'],
#               'Scholia In Sophoclem': ['Scholia in Sophoclem (scholia vetera)'],
#               'Scylax': ['Periplus Scylacis'],
#               'Seniores Apud Irenaeum': [ 'Commentaria in Aristotelem Graeca',
#                                           'Commentaria in Aristotelem Graeca',
#                                           'Commentaria in Aristotelem Graeca',
#                                           'Commentaria in Aristotelem Graeca',
#                                           'Reliquiae plurium anonymorum',
#                                           'Commentaria in Aristotelem Graeca',
#                                           'Commentaria in Aristotelem Graeca',
#                                           'Commentaria in Aristotelem Graeca',
#                                           'Commentaria in Aristotelem Graeca',
#                                           'Commentaria in Aristotelem Graeca',
#                                           'Commentaria in Aristotelem Graeca',
#                                           'Commentaria in Aristotelem Graeca',
#                                           'Commentaria in Aristotelem Graeca',
#                                           'METHODIUS',
#                                           'DAS BUCH HENOCH',
#                                           'Commentaria in Aristotelem Graeca',
#                                           'Commentaria in Aristotelem Graeca',
#                                           'Commentaria in Aristotelem Graeca'],
#               'Septuaginta': [ 'Susanna (translatio Graeca)',
#                                'Ezechiel',
#                                'Osee',
#                                'Canticum',
#                                'Michaeas',
#                                'Epistula Jeremiae',
#                                'Susanna (Theodotionis versio)',
#                                'Genesis',
#                                'Joel',
#                                'Josue (Cod. Vaticanus + Cod. Alexandrinus)',
#                                'Judices (Cod. Alexandrinus)',
#                                'Amos',
#                                'Paralipomenon I sive Chronicon I',
#                                'Regnorum II (Samuelis II In Textu Masoretico)',
#                                'Machabaeorum ii',
#                                'Machabaeorum i',
#                                'Isaias',
#                                'Isaias',
#                                'Zacharias',
#                                'Jonas',
#                                'Machabaeorum iii',
#                                'Regnorum III (Regum I in textu Masoretico)',
#                                'Regnorum IV (Regum II in textu Masoretico)',
#                                'Abdias',
#                                'Malachias',
#                                'Jeremias',
#                                'Job',
#                                'Psalmi Salomonis',
#                                'Leviticus',
#                                'Numeri',
#                                'Baruch',
#                                'Daniel (Theodotionis versio)',
#                                'Bel et Draco (Theodotionis versio)',
#                                'Deuteronomium',
#                                'Exodus',
#                                'Ecclesiasticus',
#                                'Ecclesiasticus',
#                                'Sapientia Salomonis',
#                                'Bel et Draco (translatio Graeca)',
#                                'Daniel (translatio Graeca)',
#                                'Threni seu Lamentationes',
#                                'Nahum',
#                                'Aggaeus',
#                                'Regnorum I (Samuelis I in textu Masoretico)',
#                                'Paralipomenon II sive Chronicon II',
#                                'Proverbia',
#                                'Judith',
#                                'Psalmi',
#                                'Esdras B',
#                                'Sophonias',
#                                'Habacuc',
#                                'Machabaeorum iv',
#                                'Esther',
#                                'Tobias',
#                                'Esdras A',
#                                'Odae',
#                                'Ruth'],
#               'Sextus Empiricus': [ 'Pyrrhoniae hypotyposes',
#                                     'Adversus mathematicos'],
#               'Simplicius': [ 'In Aristotelis quattuor libros de caelo '
#                               'commentaria',
#                               'In Aristotelis Categorias Commentarium',
#                               'In Aristotelis physicorum libros commentaria',
#                               'In Aristotelis libros de anima commentaria '
#                               '[Sp.?] (fort. auctore Prisciano Lydo)'],
#               'Socrates, Scholasticus': ['Historia Ecclesiastica'],
#               'Sophocles': [ 'Oedipus at Colonus',
#                              'Trachiniae, Machine readable text',
#                              'Philoctetes, Machine readable text',
#                              'Ichneutae',
#                              'Ajax, Machine readable text',
#                              'Oedipus Tyrannus, Machine readable text',
#                              'Electra, Machine readable text',
#                              'Antigone, Machine readable text',
#                              'Ajax, Machine readable text'],
#               'Sophonias': ['In Aristotelis Libros De Anima Paraphrasis'],
#               'Soranus': [ 'Certamen Homeri et Hesiodi',
#                            'Gynaeciorum Libri IV',
#                            'De Fasciis',
#                            'Vita Hippocratis Secundum Soranum',
#                            'De signis Fracturarum'],
#               'Sozomenus, Salaminius Hermias': ['Historia Ecclesiastica'],
#               'Stephanus of Alexandria': [ 'In Aristotelis librum de '
#                                            'interpretatione commentarium'],
#               'Strabo': [ 'Geography',
#                           'Geography (Greek). Machine readable text',
#                           'Strabonis Geographiae Chrestomathia, Geographia. '
#                           'Selections Chrestomathia'],
#               'Suda': ['Suidae lexicon'],
#               'Syntipas': [ 'Ιστορικον Συντιπα του Φιλοσοφου Ωραιοτατον Πανυ',
#                             'Narrationes de Syntipa'],
#               'Syrianus': ['In Aristotelis Metaphysica Commentaria'],
#               'Tatianus': ['Oratio ad Graecos'],
#               'Testamentum Abrahamae': [ 'The Testament of Abraham Recension A',
#                                          'The Testament of Abraham Recension '
#                                          'B'],
#               'Themistius': [ 'Analyticorum Posteriorum Paraphrasis',
#                               'In Aristotelis Physica Paraphrasis',
#                               '(Sophoniae) In Parva Naturalia Commentarium',
#                               'In libros Aristotelis de Anima paraphrasis',
#                               'Quae Fertur In Aristotelis Analyticorum Priorum '
#                               'Librum I'],
#               'Theocritus': ['Idylls', 'Epigrams'],
#               'Theodoret, Bishop of Cyrus': [ 'Historia Ecclesiastica',
#                                               'Historia Religiosa'],
#               'Theodoretus': ['Historia ecclesiastica'],
#               'Theon Smyrnaeus': ['De utilitate mathematicae'],
#               'Theophilus Antiochenus': ['Ad Autolycum', 'Ad Autolycum'],
#               'Theophrastus': [ 'Characters',
#                                 'Enquiry into Plants, Historia plantarum',
#                                 'Concerning Odours',
#                                 'De sensu et sensibilibus',
#                                 'De lapidibus',
#                                 'Enquiry into Plants'],
#               'Theophylactus': ['In Cyrilli In XII Prophetas'],
#               'Thucydides': ['The Peloponnesian War'],
#               'Tryphiodorus': ['The Taking of Ilios'],
#               'Valerius Apsines': [ 'Ars rhetorica',
#                                     'Περὶ τῶν ἐσχηματισμένων προβλημάτων'],
#               'Vettius Valens': ['Anthologiarum libri ix'],
#               'Vitae Aesopi': [ 'Vita Aesopi Pl vel Accursiana (sub auctore '
#                                 'Maximo Planude)(recensio 1)',
#                                 'Vita Aesopi (fort. auctore Aphthonio)',
#                                 'Βιβλίον μυθικὸν τοῦ Αἰσώπου'],
#               'Vitae Pindari Et Varia De Pindaro': [ 'Vita Ambrosiana',
#                                                      'Vita Thomana et '
#                                                      'hypothesis Olympiorum',
#                                                      'Pentathlon et de novem '
#                                                      'lyricis',
#                                                      'Vita metrica'],
#               'Xenophon': [ 'Agesilaus',
#                             'Cyropaedia',
#                             'Hellenica',
#                             'Anabasis',
#                             'Hiero',
#                             'On the Cavalry Commander',
#                             'On the Art of Horsemanship',
#                             'On Hunting',
#                             'Economics',
#                             'Symposium',
#                             'Apology',
#                             'Memorabilia',
#                             'Ways and Means',
#                             'Constitution of the Lacedaemonians'],
#               'Xenophon of Ephesus': ['Ephesiaca'],
#               'Zosimus': ['Historia Nova']})
# 265 authors

# %% [markdown]
# # All steps
#
# By now you have an impression of what to find in the Greek Literature.
# The next step is to pick and choose works and start computing with them in the Text-Fabric way.
#
# * **start** catalogue of Greek Literature
# * **[load](load.ipynb)** load a Greek work
# * (later) ~[display](display.ipynb)~ create pretty displays of your text structures
# * **[compute](compute.ipynb)** compute with text and features
# * (later) ~[search](search.ipynb)~ turbo charge your hand-coding with search templates
# * (later) ~[exportExcel](exportExcel.ipynb)~ make tailor-made spreadsheets out of your results
# * (later) ~[share](share.ipynb)~ draw in other people's data and let them use yours
#
# CC-BY Ernst Boogert, Dirk Roorda
