# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use
from fixture import typeShow

# %% [markdown]
# # Peshitta (OT)

# %%
A = use('peshitta:clone', checkout="clone", hoist=globals())
# Out:
# Using TF-app in ~/github/annotation/app-peshitta/code:
# 	repo clone offline under ~/github (local github)
# Using data in ~/github/etcbc/peshitta/tf/0.1:
# 	repo clone offline under ~/github (local github)
#    |     0.00s Dataset without structure sections in otext:no structure functions in the T-API
# <b>Documentation:</b> <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription.md" title="provenance of Peshitta (Old Testament)">PESHITTA</a> <a target="_blank" href="https://annotation.github.io/text-fabric/writing/syriac.html" title="How TF features represent text">Character table</a> <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#" title="PESHITTA feature documentation">Feature docs</a> <a target="_blank" href="https://github.com/annotation/app-peshitta" title="peshitta API documentation">peshitta API</a> <a target="_blank" href="https://annotation.github.io/text-fabric/cheatsheet.html" title="text-fabric-api">Text-Fabric API 8.3.0</a> <a target="_blank" href="https://annotation.github.io/text-fabric/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><details open><summary><b>Loaded features</b>:</summary>
# <p><b>Peshitta (Old Testament)</b>: <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#book" title="~/github/etcbc/peshitta/tf/0.1/book.tf">book</a>  <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#book@ll" title="~/github/etcbc/peshitta/tf/0.1/book@en.tf">book@ll</a>  <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#chapter" title="~/github/etcbc/peshitta/tf/0.1/chapter.tf">chapter</a>  <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#otype" title="~/github/etcbc/peshitta/tf/0.1/otype.tf">otype</a>  <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#trailer" title="~/github/etcbc/peshitta/tf/0.1/trailer.tf">trailer</a>  <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#trailer_etcbc" title="~/github/etcbc/peshitta/tf/0.1/trailer_etcbc.tf">trailer_etcbc</a>  <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#verse" title="~/github/etcbc/peshitta/tf/0.1/verse.tf">verse</a>  <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#witness" title="~/github/etcbc/peshitta/tf/0.1/witness.tf">witness</a>  <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#word" title="~/github/etcbc/peshitta/tf/0.1/word.tf">word</a>  <a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#word_etcbc" title="~/github/etcbc/peshitta/tf/0.1/word_etcbc.tf">word_etcbc</a>  <b><i><a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#oslots" title="~/github/etcbc/peshitta/tf/0.1/oslots.tf">oslots</a></i></b> </p></details>
# <style>tr.tf, td.tf, th.tf { text-align: left ! important;}@font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: x-large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: x-large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .rtl {
#     direction: rtl ! important;
# }
# span.plain {
#     display: inline-block;
#     white-space: pre-wrap;
#     text-align: start;
# }
# .gr,.gl {
#     white-space: pre-wrap;
#     border-color: var(--border-color-gap);
#     border-width: var(--border-width-gap);
#     border-top-style: none;
#     border-bottom-style: none;
# }
# .gr {
#     border-right-style: solid;
#     border-left-style: dashed;
# }
# .gl {
#     border-right-style: dashed;
#     border-left-style: solid;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 0.1rem;
#     margin: 0.1rem;
#     direction: ltr;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1rem 0rem;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .section {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--section);
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5rem 0.1rem 0.1rem 0.1rem;
#     margin: 0.8rem 0.1rem 0.1rem 0.1rem;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-color3);
#     border-width: var(--border-width3);
#     border-radius: var(--border-width3);
# }
# .contnr.c4,.lbl.c4 {
#     border-color: var(--border-color4);
#     border-width: var(--border-width4);
#     border-radius: var(--border-width4);
# }
# .plain.l,.contnr.l,.contnr.l>.lbl {
#     border-left-style: dotted
# }
# .plain.r,.contnr.r,.contnr.r>.lbl
# <div><a target="_blank" href="https://annotation.github.io/text-fabric/cheatsheet.html" title="doc">names N F E L T S C TF directly usable</a></div>

# %%
A.reuse()
# Out:
# <style>tr.tf, td.tf, th.tf { text-align: left ! important;}@font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: x-large;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: large;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: x-large;
#     direction: ltr;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .rtl {
#     direction: rtl ! important;
# }
# span.plain {
#     display: inline-block;
#     white-space: pre-wrap;
#     text-align: start;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 0.1rem;
#     margin: 0.1rem;
#     direction: ltr;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1rem 0rem;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .psg {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--passage);
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd {
#     font-family: sans-serif;
#     font-size: x-small;
#     color: var(--node);
#     vertical-align: super;
# }
# .verse {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-end;
#     align-items: flex-end;
#     direction: ltr;
#     width: 100%;
# }
# .vn {
#   font-size: small !important;
#   padding-right: 1rem;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.row {
#     flex-flow: row nowrap;
# }
# .children.row.wrap {
#     flex-flow: row wrap;
# }
# .children.col {
#     flex-flow: column nowrap;
# }
# .children.col.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5rem 0.1rem 0.1rem 0.1rem;
#     margin: 0.8rem 0.1rem 0.1rem 0.1rem;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-color3);
#     border-width: var(--border-width3);
#     border-radius: var(--border-width3);
# }
# .contnr.c4,.lbl.c4 {
#     border-color: var(--border-color4);
#     border-width: var(--border-width4);
#     border-radius: var(--border-width4);
# }
# .contnr.l {
#     border-left-style: dotted
# }
# .contnr.r {
#     border-right-style: dotted
# }
# .contnr.lno {
#     border-left-style: none
# }
# .contnr.rno {
#     border-right-style: none
# }
# .lbl {
#     margin-top: -1.2rem;
#     margin-left: 1rem;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3rem;
#     border-style: solid;
#     display: block;
#     color: var(--label)
# }
# .lbl.trm {
#     ba

# %%
typeShow(A, prettyTypes=False, baseTypes=set())
# Out:
# ### book 427228
# <div class="rtl children"><span class="section ltr"><a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Genesis" title="Show this document in the Peshitta repository" sec="Genesis">Genesis</a></span> <span class="plain outer rtl  " ><span class="plain txtu syc rtl"><span class="section"> </span></span></span></div>
# <span class="section ltr"><a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Genesis" title="Show this document in the Peshitta repository" sec="Genesis">Genesis</a></span><div class="rtl children"><div class="contnr c4 trm rtl  " ><div class="lbl c4 trm " ><span class="txtu syc"><span class="section">Genesis</span></span></div></div></div>
# ### chapter 427293
# <div class="rtl children"><span class="section ltr"><a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Genesis" title="Show this document in the Peshitta repository" sec="Genesis 1">Genesis 1</a></span> <span class="plain outer rtl  " ><span class="plain txtu syc rtl"><span class="section"> </span></span></span></div>
# <span class="section ltr"><a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Genesis" title="Show this document in the Peshitta repository" sec="Genesis 1">Genesis 1</a></span><div class="rtl children"><div class="contnr c4 trm rtl  " ><div class="lbl c4 trm " ><span class="txtu syc"><span class="section">Genesis 1</span></span></div></div></div>
# ### verse 428562
# <div class="rtl children"><span class="section ltr"><a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Genesis" title="Show this document in the Peshitta repository" sec="Genesis 1:1">Genesis 1:1</a></span> <span class="plain outer rtl  " ><span class="plain txtu syc rtl"></span><span class="plain  rtl  " ><span class="txtu syc">ܒܪܫܝܬ </span></span><span class="plain  rtl  " ><span class="txtu syc">ܒܪܐ </span></span><span class="plain  rtl  " ><span class="txtu syc">ܐܠܗܐ. </span></span><span class="plain  rtl  " ><span class="txtu syc">ܝܬ </span></span><span class="plain  rtl  " ><span class="txtu syc">ܫܡܝܐ </span></span><span class="plain  rtl  " ><span class="txtu syc">ܘܝܬ </span></span><span class="plain  rtl  " ><span class="txtu syc">ܐܪܥܐ. </span></span></span></div>
# <span class="section ltr"><a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Genesis" title="Show this document in the Peshitta repository" sec="Genesis 1:1">Genesis 1:1</a></span><div class="rtl children"><div class="contnr c3  rtl  " ><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="txtu syc">ܒܪܫܝܬ </span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="txtu syc">ܒܪܐ </span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="txtu syc">ܐܠܗܐ. </span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="txtu syc">ܝܬ </span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="txtu syc">ܫܡܝܐ </span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="txtu syc">ܘܝܬ </span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="txtu syc">ܐܪܥܐ. </span></div></div></div></div></div>
# ### word 1
# <div class="rtl children"><span class="section ltr"><a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Genesis" title="Show this document in the Peshitta repository" sec="Genesis 1:1">Genesis 1:1</a></span> <span class="plain outer rtl  " ><span class="txtu syc">ܒܪܫܝܬ </span></span></div>
# <span class="section ltr"><a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Genesis" title="Show this document in the Peshitta repository" sec="Genesis 1:1">Genesis 1:1</a></span><div class="rtl children"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="txtu syc">ܒܪܫܝܬ </span></div></div></div>

# %%
typeShow(A, standardFeatures=True, prettyTypes=True)
# Out:
# ### book 427228
# <div class="rtl children"><span class="section ltr"><a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Genesis" title="Show this document in the Peshitta repository" sec="Genesis">Genesis</a></span> <span class="plain outer rtl  " ><span class="plain txtu syc rtl"><span class="section"> </span></span></span></div>
# <span class="section ltr"><a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Genesis" title="Show this document in the Peshitta repository" sec="Genesis">Genesis</a></span><div class="rtl children"><div class="contnr c4 trm rtl  " ><div class="lbl c4 trm " ><span class="nd">book</span> <span class="txtu syc"><span class="section">Genesis</span></span></div></div></div>
# ### chapter 427293
# <div class="rtl children"><span class="section ltr"><a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Genesis" title="Show this document in the Peshitta repository" sec="Genesis 1">Genesis 1</a></span> <span class="plain outer rtl  " ><span class="plain txtu syc rtl"><span class="section"> </span></span></span></div>
# <span class="section ltr"><a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Genesis" title="Show this document in the Peshitta repository" sec="Genesis 1">Genesis 1</a></span><div class="rtl children"><div class="contnr c4 trm rtl  " ><div class="lbl c4 trm " ><span class="nd">chapter</span> <span class="txtu syc"><span class="section">Genesis 1</span></span></div></div></div>
# ### verse 428562
# <div class="rtl children"><span class="section ltr"><a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Genesis" title="Show this document in the Peshitta repository" sec="Genesis 1:1">Genesis 1:1</a></span> <span class="plain outer rtl  " ><span class="plain txtu syc rtl"></span><span class="plain  rtl  " ><span class="txtu syc">ܒܪܫܝܬ </span></span><span class="plain  rtl  " ><span class="txtu syc">ܒܪܐ </span></span><span class="plain  rtl  " ><span class="txtu syc">ܐܠܗܐ. </span></span><span class="plain  rtl  " ><span class="txtu syc">ܝܬ </span></span><span class="plain  rtl  " ><span class="txtu syc">ܫܡܝܐ </span></span><span class="plain  rtl  " ><span class="txtu syc">ܘܝܬ </span></span><span class="plain  rtl  " ><span class="txtu syc">ܐܪܥܐ. </span></span></span></div>
# <span class="section ltr"><a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Genesis" title="Show this document in the Peshitta repository" sec="Genesis 1:1">Genesis 1:1</a></span><div class="rtl children"><div class="contnr c3  rtl  " ><div class="lbl c3  " ><span class="nd">verse</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="txtu syc">ܒܪܫܝܬ </span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="txtu syc">ܒܪܐ </span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="txtu syc">ܐܠܗܐ. </span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="txtu syc">ܝܬ </span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="txtu syc">ܫܡܝܐ </span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="txtu syc">ܘܝܬ </span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="txtu syc">ܐܪܥܐ. </span></div></div></div></div></div>
# ### word 1
# <div class="rtl children"><span class="section ltr"><a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Genesis" title="Show this document in the Peshitta repository" sec="Genesis 1:1">Genesis 1:1</a></span> <span class="plain outer rtl  " ><span class="txtu syc">ܒܪܫܝܬ </span></span></div>
# <span class="section ltr"><a target="_blank" href="https://github.com/etcbc/peshitta/blob/master/source/0.1/Genesis" title="Show this document in the Peshitta repository" sec="Genesis 1:1">Genesis 1:1</a></span><div class="rtl children"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="txtu syc">ܒܪܫܝܬ </span></div></div></div>

# %%
A.showContext()
# Out:
# <details ><summary><b>peshitta</b> <i>app context</i></summary>
#
# <details ><summary>1. afterChild</summary>
#
# {}
#
# </details>
# <details ><summary>2. allowedBaseTypes</summary>
#
# ()
#
# </details>
# <details ><summary>3. apiVersion</summary>
#
# `2`
#
# </details>
# <details ><summary>4. appName</summary>
#
# `peshitta`
#
# </details>
# <details ><summary>5. appPath</summary>
#
# `/Users/dirk/github/annotation/app-peshitta/code`
#
# </details>
# <details ><summary>6. baseTypes</summary>
#
#
# 1.  `word`
#
# </details>
# <details ><summary>7. browseContentPretty</summary>
#
# False
#
# </details>
# <details ><summary>8. browseNavLevel</summary>
#
# `2`
#
# </details>
# <details ><summary>9. charText</summary>
#
# `How TF features represent text`
#
# </details>
# <details ><summary>10. charUrl</summary>
#
# `https://annotation.github.io/text-fabric/writing/syriac.html`
#
# </details>
# <details ><summary>11. childType</summary>
#
#
# *   **`book`**:
#     *   `chapter`
# *   **`chapter`**:
#     *   `verse`
# *   **`verse`**:
#     *   `word`
#
# </details>
# <details ><summary>12. commit</summary>
#
# None
#
# </details>
# <details ><summary>13. condenseType</summary>
#
# `verse`
#
# </details>
# <details ><summary>14. condenseTypes</summary>
#
#
# 1.
#     *   `book`
#     *   `6572.723076923077`
#     *   `427228`
#     *   `427292`
# 2.
#     *   `chapter`
#     *   `336.6643026004728`
#     *   `427293`
#     *   `428561`
# 3.
#     *   `verse`
#     *   `13.61636282508924`
#     *   `428562`
#     *   `459937`
# 4.
#     *   `word`
#     *   `1`
#     *   `1`
#     *   `427227`
#
# </details>
# <details ><summary>15. corpus</summary>
#
# `Peshitta (Old Testament)`
#
# </details>
# <details ><summary>16. css</summary>
#
# *empty*
#
# </details>
# <details ><summary>17. dataDisplay</summary>
#
#
# *   **`noneValues`**:
#     *   `none`
#     *   `unknown`
#     *   None
#     *   `NA`
#
# </details>
# <details ><summary>18. defaultClsOrig</summary>
#
# `txtu syc`
#
# </details>
# <details ><summary>19. defaultFormat</summary>
#
# `text-orig-full`
#
# </details>
# <details ><summary>20. descendantType</summary>
#
#
# *   **`book`**:
#     *   `book`
#     *   `chapter`
#     *   `verse`
#     *   `word`
# *   **`chapter`**:
#     *   `chapter`
#     *   `verse`
#     *   `word`
# *   **`verse`**:
#     *   `verse`
#     *   `word`
#
# </details>
# <details ><summary>21. direction</summary>
#
# `rtl`
#
# </details>
# <details ><summary>22. docBase</summary>
#
# `https://github.com/etcbc/peshitta/blob/master/docs`
#
# </details>
# <details ><summary>23. docExt</summary>
#
# `.md`
#
# </details>
# <details ><summary>24. docPage</summary>
#
# `transcription`
#
# </details>
# <details ><summary>25. docRoot</summary>
#
# `https://github.com`
#
# </details>
# <details ><summary>26. docUrl</summary>
#
# `https://github.com/etcbc/peshitta/blob/master/docs/transcription.md`
#
# </details>
# <details ><summary>27. docs</summary>
#
#
# *   **`charText`**: `How TF features represent text`
# *   **`charUrl`**: `https://annotation.github.io/text-fabric/writing/syriac.html`
# *   **`docBase`**: `https://github.com/etcbc/peshitta/blob/master/docs`
# *   **`docExt`**: `.md`
# *   **`docPage`**: `transcription`
# *   **`docRoot`**: `https://github.com`
# *   **`docUrl`**: `https://github.com/etcbc/peshitta/blob/master/docs/transcription.md`
# *   **`featureBase`**: `https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#<feature>`
# *   **`featurePage`**: *empty*
#
# </details>
# <details ><summary>28. doi</summary>
#
# `10.5281/zenodo.1463675`
#
# </details>
# <details ><summary>29. exampleSection</summary>
#
# `Genesis 1:1`
#
# </details>
# <details ><summary>30. exampleSectionHtml</summary>
#
# `<code>Genesis 1:1</code>`
#
# </details>
# <details ><summary>31. excludedFeatures</summary>
#
# set()
#
# </details>
# <details ><summary>32. exclusions</summary>
#
# {}
#
# </details>
# <details ><summary>33. extension</summary>
#
# ` syc`
#
# </details>
# <details ><summary>34. featureBase</summary>
#
# `https://github.com/etcbc/peshitta/blob/master/docs/transcription-0.1.md#<feature>`
#
# </details>
# <details ><summary>35. featurePage</summary>
#
# *empty*
#
# </details>
# <details ><summary>36. features</summary>
#
# {}
#
# </details>
# <details ><summary>37. featuresBare</summary>
#
# {}
#
# </details>
# <details ><summary>38. formatCls</summary>
#
#
# *   **`text-orig-full`**: `txtu syc`
# *   **`text-trans-full`**: `txtt`
#
# </details>
# <details ><summary>39. formatHtml</summary>
#
# set()
#
# </details>
# <details ><summary>40. formatMethod</summary>
#
# {}
#
# </details>
# <details ><summary>41. formatStyle</summary>
#
#
# *   **`normal`**: `txtn`
# *   **`orig`**: `txtu syc`
# *   **`phono`**: `txtp`
# *   **`source`**: `txto`
# *   **`trans`**: `txtt`
#
# </details>
# <details ><summary>42. graphicsRelative</summary>
#
# None
#
# </details>
# <details ><summary>43. hasGraphics</summary>
#
# set()
#
# </details>
# <details ><summary>44. interfaceDefaults</summary>
#
#
# *   **`lineNumbers`**: None
# *   **`plainGaps`**: `True`
# *   **`prettyTypes`**: `True`
# *   **`queryFeatures`**: `True`
# *   **`showGraphics`**: None
# *   **`showHidden`**: None
# *   **`standardFeatures`**: False
# *   **`withNodes`**: False
# *   **`withTypes`**: False
#
# </details>
# <details ><summary>45. isCompatible</summary>
#
# `True`
#
# </details>
# <details ><summary>46. isHidden</summary>
#
# set()
#
# </details>
# <details ><summary>47. labels</summary>
#
#
# *   **`book`**:
#     *   `True`
#     *   ()
# *   **`chapter`**:
#     *   `True`
#     *   ()
# *   **`verse`**:
#     *   *empty*
#     *   ()
# *   **`word`**:
#     *   `True`
#     *   ()
#
# </details>
# <details ><summary>48. language</summary>
#
# `syriac`
#
# </details>
# <details ><summary>49. levelCls</summary>
#
#
# *   **`book`**:
#     *   **`children`**: `children hor wrap`
#     *   **`container`**: `contnr c4`
#     *   **`label`**: `lbl c4`
# *   **`chapter`**:
#     *   **`children`**: `children hor wrap`
#     *   **`container`**: `contnr c4`
#     *   **`label`**: `lbl c4`
# *   **`verse`**:
#     *   **`children`**: `children hor wrap`
#     *   **`container`**: `contnr c3`
#     *   **`label`**: `lbl c3`
# *   **`word`**:
#     *   **`children`**: *empty*
#     *   **`container`**: `contnr c0`
#     *   **`label`**: `lbl c0`
#
# </details>
# <details ><summary>50. levels</summary>
#
#
# *   **`book`**:
#     *   **`flow`**: `hor`
#     *   **`level`**: `4`
#     *   **`stretch`**: `True`
#     *   **`wrap`**: `True`
# *   **`chapter`**:
#     *   **`flow`**: `hor`
#     *   **`level`**: `4`
#     *   **`stretch`**: `True`
#     *   **`wrap`**: `True`
# *   **`verse`**:
#     *   **`flow`**: `hor`
#     *   **`level`**: `3`
#     *   **`stretch`**: `True`
#     *   **`wrap`**: `True`
# *   **`word`**:
#     *   **`flow`**: `ver`
#     *   **`level`**: 0
#     *   **`stretch`**: False
#     *   **`wrap`**: False
#
# </details>
# <details ><summary>51. lexMap</summary>
#
# {}
#
# </details>
# <details ><summary>52. lexTypes</summary>
#
# set()
#
# </details>
# <details ><summary>53. lineNumberFeature</summary>
#
# {}
#
# </details>
# <details ><summary>54. local</summary>
#
# `clone`
#
# </details>
# <details ><summary>55. localDir</summary>
#
# `/Users/dirk/github/etcbc/peshitta/_temp`
#
# </details>
# <details ><summary>56. moduleSpecs</summary>
#
# ()
#
# </details>
# <details ><summary>57. noChildren</summary>
#
# set()
#
# </details>
# <details ><summary>58. noDescendTypes</summary>
#
# set()
#
# </details>
# <details ><summary>59. noneValues</summary>
#
#
# 1.  `none`
# 2.  `unknown`
# 3.  None
# 4.  `NA`
#
# </details>
# <details ><summary>60. org</summary>
#
# `etcbc`
#
# </details>
# <details ><summary>61. plainCustom</summary>
#
# {}
#
# </details>
# <details ><summary>62. prettyCustom</summary>
#
# {}
#
# </details>
# <details ><summary>63. provenanceSpec</summary>
#
#
# *   **`corpus`**: `Peshitta (Old Testament)`
# *   **`doi`**: `10.5281/zenodo.1463675`
# *   **`graphicsRelative`**: None
# *   **`moduleSpecs`**: ()
# *   **`org`**: `etcbc`
# *   **`relative`**: `tf`
# *   **`repo`**: `peshitta`
# *   **`version`**: `0.1`
# *   **`webBase`**: `https://github.com/etcbc/peshitta/blob/master/source`
# *   **`webHint`**: `Show this document in the Peshitta repository`
# *   **`webLang`**: `en`
# *   **`webLexId`**: None
# *   **`webUrl`**: `https://github.com/etcbc/peshitta/blob/master/source/0.1/<1>`
# *   **`webUrlLex`**: None
# *   **`zip`**: None
#
# </details>
# <details ><summary>64. relative</summary>
#
# `tf`
#
# </details>
# <details ><summary>65. release</summary>
#
# None
#
# </details>
# <details ><summary>66. repo</summary>
#
# `peshitta`
#
# </details>
# <details ><summary>67. sectionSep1</summary>
#
# ` `
#
# </details>
# <details ><summary>68. sectionSep2</summary>
#
# `:`
#
# </details>
# <details ><summary>69. showVerseInTuple</summary>
#
# False
#
# </details>
# <details ><summary>70. styles</summary>
#
# {}
#
# </details>
# <details ><summary>71. templates</summary>
#
#
# *   **`book`**:
#     *   `True`
#     *   ()
# *   **`chapter`**:
#     *   `True`
#     *   ()
# *   **`verse`**:
#     *   *empty*
#     *   ()
# *   **`word`**:
#     *   `True`
#     *   ()
#
# </details>
# <details ><summary>72. tfDoc</summary>
#
# `https://annotation.github.io/text-fabric`
#
# </details>
# <details ><summary>73. transform</summary>
#
# {}
#
# </details>
# <details ><summary>74. typeDisplay</summary>
#
# {}
#
# </details>
# <details ><summary>75. urlGh</summary>
#
# `https://github.com`
#
# </details>
# <details ><summary>76. urlNb</summary>
#
# `https://nbviewer.jupyter.org/github`
#
# </details>
# <details ><summary>77. verseTypes</summary>
#
#
# 1.  `verse`
#
# </details>
# <details ><summary>78. version</summary>
#
# `0.1`
#
# </details>
# <details ><summary>79. webBase</summary>
#
# `https://github.com/etcbc/peshitta/blob/master/source`
#
# </details>
# <details ><summary>80. webHint</summary>
#
# `Show this document in the Peshitta repository`
#
# </details>
# <details ><summary>81. webLang</summary>
#
# `en`
#
# </details>
# <details ><summary>82. webLexId</summary>
#
# None
#
# </details>
# <details ><summary>83. webUrl</summary>
#
# `https://github.com/etcbc/peshitta/blob/master/source/0.1/<1>`
#
# </details>
# <details ><summary>84. webUrlLex</summary>
#
# None
#
# </details>
# <details ><summary>85. writing</summary>
#
# `syc`
#
# </details>
# <details ><summary>86. zip</summary>
#
#
# 1.  `peshitta`
#
# </details>
# </details>
