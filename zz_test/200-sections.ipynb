# %%
# %load_ext autoreload
# %autoreload 2

# %%
from fixture import TestApp

# %%
As = TestApp(globals())

# %%
def sections():
    for n in As.select(section=True, structure=True, verse=False, start=True, size=1):
        As.perform('plain', n, withPassage=False, withNodes=True)
        As.perform('plain', n, withPassage=True, withNodes=True)
        As.perform('pretty', n, withPassage=False, withNodes=True)
        As.perform('pretty', n, withPassage=True, withNodes=True)

# %% [markdown]
# ## Run all corpora

# %%
As.testSet()

# %%
As.test(sections)
# Out:
# # athenaeus
# <style>tr.tf, td.tf, th.tf { text-align: left ! important;}@font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: x-large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: x-large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .rtl {
#     direction: rtl ! important;
# }
# span.plain {
#     display: inline-block;
#     white-space: pre-wrap;
#     text-align: start;
# }
# .gr,.gl {
#     white-space: pre-wrap;
#     border-color: var(--border-color-gap);
#     border-width: var(--border-width-gap);
#     border-top-style: none;
#     border-bottom-style: none;
# }
# .gr {
#     border-right-style: solid;
#     border-left-style: dashed;
# }
# .gl {
#     border-right-style: dashed;
#     border-left-style: solid;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 0.1rem;
#     margin: 0.1rem;
#     direction: ltr;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1rem 0rem;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .section {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--section);
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5rem 0.1rem 0.1rem 0.1rem;
#     margin: 0.8rem 0.1rem 0.1rem 0.1rem;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-color3);
#     border-width: var(--border-width3);
#     border-radius: var(--border-width3);
# }
# .contnr.c4,.lbl.c4 {
#     border-color: var(--border-color4);
#     border-width: var(--border-width4);
#     border-radius: var(--border-width4);
# }
# .plain.l,.contnr.l,.contnr.l>.lbl {
#     border-left-style: dotted
# }
# .plain.r,.contnr.r,.contnr.r>.lbl
# ---
#
# *sectional:* **chapter**  `A.plain(285989, withPassage=False, withNodes=True)`
# <div class=" children"><span class="plain outer   " ><span class="nd">285989</span><span class="plain txtu grc "><span class="section">1 1</span></span></span></div>
# ---
#
# *sectional:* **chapter**  `A.plain(285989, withPassage=True, withNodes=True)`
# <div class=" children"><span class="section ltr">1 1</span> <span class="plain outer   " ><span class="nd">285989</span><span class="plain txtu grc "><span class="section"> </span></span></span></div>
# ---
#
# *sectional:* **chapter**  `A.pretty(285989, withPassage=False, withNodes=True)`
# <div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">chapter:285989</span> <span class="txtu grc"><span class="section">1 1</span></span></div></div></div>
# ---
#
# *sectional:* **chapter**  `A.pretty(285989, withPassage=True, withNodes=True)`
# <span class="section ltr">1 1</span><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">chapter:285989</span> <span class="txtu grc"><span class="section">1 1</span></span></div></div></div>
# ---
#
# *sectional:* **book**  `A.plain(285974, withPassage=False, withNodes=True)`
# <div class=" children"><span class="plain outer   " ><span class="nd">285974</span><span class="plain txtu grc "><span class="section">1</span></span></span></div>
# ---
#
# *sectional:* **book**  `A.plain(285974, withPassage=True, withNodes=True)`
# <div class=" children"><span class="section ltr">1</span> <span class="plain outer   " ><span class="nd">285974</span><span class="plain txtu grc "><span class="section"> </span></span></span></div>
# ---
#
# *sectional:* **book**  `A.pretty(285974, withPassage=False, withNodes=True)`
# <div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">book:285974</span> <span class="txtu grc"><span class="section">1</span></span></div></div></div>
# ---
#
# *sectional:* **book**  `A.pretty(285974, withPassage=True, withNodes=True)`
# <span class="section ltr">1</span><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">book:285974</span> <span class="txtu grc"><span class="section">1</span></span></div></div></div>
# ---
#
# *structure:* **_book**  `A.plain(265147, withPassage=False, withNodes=True)`
# <div class=" children"><span class="plain outer   " ><span class="nd">265147</span><span class="plain txtu grc "><span class="structure"><span class="nd">_book</span> Deipnosophistae</span></span></span></div>
# ---
#
# *structure:* **_book**  `A.plain(265147, withPassage=True, withNodes=True)`
# <div class=" children"><span class="section ltr">1 1:1</span> <span class="plain outer   " ><span class="nd">265147</span><span class="plain txtu grc "><span class="structure"><span class="nd">_book</span> Deipnosophistae</span></span></span></div>
# ---
#
# *structure:* **_book**  `A.pretty(265147, withPassage=False, withNodes=True)`
# <div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">_book:265147</span> <span class="txtu grc"><span class="structure"><span class="nd">_book</span> Deipnosophistae</span></span></div></div></div>
# ---
#
# *structure:* **_book**  `A.pretty(265147, withPassage=True, withNodes=True)`
# <span class="section ltr">1 1:1</span><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">_book:265147</span> <span class="txtu grc"><span class="structure"><span class="nd">_book</span> Deipnosophistae</span></span></div></div></div>
# # banks
# <style>tr.tf, td.tf, th.tf { text-align: left ! important;}@font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: x-large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: x-large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .rtl {
#     direction: rtl ! important;
# }
# span.plain {
#     display: inline-block;
#     white-space: pre-wrap;
#     text-align: start;
# }
# .gr,.gl {
#     white-space: pre-wrap;
#     border-color: var(--border-color-gap);
#     border-width: var(--border-width-gap);
#     border-top-style: none;
#     border-bottom-style: none;
# }
# .gr {
#     border-right-style: solid;
#     border-left-style: dashed;
# }
# .gl {
#     border-right-style: dashed;
#     border-left-style: solid;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 0.1rem;
#     margin: 0.1rem;
#     direction: ltr;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1rem 0rem;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .section {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--section);
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5rem 0.1rem 0.1rem 0.1rem;
#     margin: 0.8rem 0.1rem 0.1rem 0.1rem;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-color3);
#     border-width: var(--border-width3);
#     border-radius: var(--border-width3);
# }
# .contnr.c4,.lbl.c4 {
#     border-color: var(--border-color4);
#     border-width: var(--border-width4);
#     border-radius: var(--border-width4);
# }
# .plain.l,.contnr.l,.contnr.l>.lbl {
#     border-left-style: dotted
# }
# .plain.r,.contnr.r,.contnr.r>.lbl
# ---
#
# *sectional:* **chapter**  `A.plain(101, withPassage=False, withNodes=True)`
# <div class=" children"><span class="plain outer   " ><span class="nd">101</span><span class="plain txtu "><span class="section">Consider Phlebas 1</span></span></span></div>
# ---
#
# *sectional:* **chapter**  `A.plain(101, withPassage=True, withNodes=True)`
# <div class=" children"><span class="section ltr">Consider Phlebas 1</span> <span class="plain outer   " ><span class="nd">101</span><span class="plain txtu "><span class="section"> </span></span></span></div>
# ---
#
# *sectional:* **chapter**  `A.pretty(101, withPassage=False, withNodes=True)`
# <div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">chapter:101</span> <span class="txtu"><span class="section">Consider Phlebas 1</span></span></div></div></div>
# ---
#
# *sectional:* **chapter**  `A.pretty(101, withPassage=True, withNodes=True)`
# <span class="section ltr">Consider Phlebas 1</span><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">chapter:101</span> <span class="txtu"><span class="section">Consider Phlebas 1</span></span></div></div></div>
# ---
#
# *sectional:* **book**  `A.plain(100, withPassage=False, withNodes=True)`
# <div class=" children"><span class="plain outer   " ><span class="nd">100</span><span class="plain txtu "><span class="section">Consider Phlebas</span></span></span></div>
# ---
#
# *sectional:* **book**  `A.plain(100, withPassage=True, withNodes=True)`
# <div class=" children"><span class="section ltr">Consider Phlebas</span> <span class="plain outer   " ><span class="nd">100</span><span class="plain txtu "><span class="section"> </span></span></span></div>
# ---
#
# *sectional:* **book**  `A.pretty(100, withPassage=False, withNodes=True)`
# <div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">book:100</span> <span class="txtu"><span class="section">Consider Phlebas</span></span></div></div></div>
# ---
#
# *sectional:* **book**  `A.pretty(100, withPassage=True, withNodes=True)`
# <span class="section ltr">Consider Phlebas</span><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">book:100</span> <span class="txtu"><span class="section">Consider Phlebas</span></span></div></div></div>
# # bhsa
# <style>tr.tf, td.tf, th.tf { text-align: left ! important;}@font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: x-large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: x-large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .rtl {
#     direction: rtl ! important;
# }
# span.plain {
#     display: inline-block;
#     white-space: pre-wrap;
#     text-align: start;
# }
# .gr,.gl {
#     white-space: pre-wrap;
#     border-color: var(--border-color-gap);
#     border-width: var(--border-width-gap);
#     border-top-style: none;
#     border-bottom-style: none;
# }
# .gr {
#     border-right-style: solid;
#     border-left-style: dashed;
# }
# .gl {
#     border-right-style: dashed;
#     border-left-style: solid;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 0.1rem;
#     margin: 0.1rem;
#     direction: ltr;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1rem 0rem;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .section {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--section);
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5rem 0.1rem 0.1rem 0.1rem;
#     margin: 0.8rem 0.1rem 0.1rem 0.1rem;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-color3);
#     border-width: var(--border-width3);
#     border-radius: var(--border-width3);
# }
# .contnr.c4,.lbl.c4 {
#     border-color: var(--border-color4);
#     border-width: var(--border-width4);
#     border-radius: var(--border-width4);
# }
# .plain.l,.contnr.l,.contnr.l>.lbl {
#     border-left-style: dotted
# }
# .plain.r,.contnr.r,.contnr.r>.lbl
# ---
#
# *section:* **chapter**  `A.plain(426624, withPassage=False, withNodes=True)`
# <div class="rtl children"><span class="plain outer rtl  " ><span class="nd">426624</span><span class="plain txtu hbo rtl"><span class="section">Genesis 1</span></span></span></div>
# ---
#
# *section:* **chapter**  `A.plain(426624, withPassage=True, withNodes=True)`
# <div class="rtl children"><span class="section ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 1">Genesis 1</a></span> <span class="plain outer rtl  " ><span class="nd">426624</span><span class="plain txtu hbo rtl"><span class="section"> </span></span></span></div>
# ---
#
# *section:* **chapter**  `A.pretty(426624, withPassage=False, withNodes=True)`
# <div class="rtl children"><div class="contnr c4 trm rtl  " ><div class="lbl c4 trm " ><span class="nd">chapter:426624</span> <span class="txtu hbo"><span class="section">Genesis 1</span></span></div></div></div>
# ---
#
# *section:* **chapter**  `A.pretty(426624, withPassage=True, withNodes=True)`
# <span class="section ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 1">Genesis 1</a></span><div class="rtl children"><div class="contnr c4 trm rtl  " ><div class="lbl c4 trm " ><span class="nd">chapter:426624</span> <span class="txtu hbo"><span class="section">Genesis 1</span></span></div></div></div>
# ---
#
# *section:* **book**  `A.plain(426585, withPassage=False, withNodes=True)`
# <div class="rtl children"><span class="plain outer rtl  " ><span class="nd">426585</span><span class="plain txtu hbo rtl"><span class="section">Genesis</span></span></span></div>
# ---
#
# *section:* **book**  `A.plain(426585, withPassage=True, withNodes=True)`
# <div class="rtl children"><span class="section ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis">Genesis</a></span> <span class="plain outer rtl  " ><span class="nd">426585</span><span class="plain txtu hbo rtl"><span class="section"> </span></span></span></div>
# ---
#
# *section:* **book**  `A.pretty(426585, withPassage=False, withNodes=True)`
# <div class="rtl children"><div class="contnr c4 trm rtl  " ><div class="lbl c4 trm " ><span class="nd">book:426585</span> <span class="txtu hbo"><span class="section">Genesis</span></span></div></div></div>
# ---
#
# *section:* **book**  `A.pretty(426585, withPassage=True, withNodes=True)`
# <span class="section ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis">Genesis</a></span><div class="rtl children"><div class="contnr c4 trm rtl  " ><div class="lbl c4 trm " ><span class="nd">book:426585</span> <span class="txtu hbo"><span class="section">Genesis</span></span></div></div></div>
# # dss
# <style>tr.tf, td.tf, th.tf { text-align: left ! important;}@font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: x-large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: x-large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .rtl {
#     direction: rtl ! important;
# }
# span.plain {
#     display: inline-block;
#     white-space: pre-wrap;
#     text-align: start;
# }
# .gr,.gl {
#     white-space: pre-wrap;
#     border-color: var(--border-color-gap);
#     border-width: var(--border-width-gap);
#     border-top-style: none;
#     border-bottom-style: none;
# }
# .gr {
#     border-right-style: solid;
#     border-left-style: dashed;
# }
# .gl {
#     border-right-style: dashed;
#     border-left-style: solid;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 0.1rem;
#     margin: 0.1rem;
#     direction: ltr;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1rem 0rem;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .section {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--section);
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5rem 0.1rem 0.1rem 0.1rem;
#     margin: 0.8rem 0.1rem 0.1rem 0.1rem;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-color3);
#     border-width: var(--border-width3);
#     border-radius: var(--border-width3);
# }
# .contnr.c4,.lbl.c4 {
#     border-color: var(--border-color4);
#     border-width: var(--border-width4);
#     border-radius: var(--border-width4);
# }
# .plain.l,.contnr.l,.contnr.l>.lbl {
#     border-left-style: dotted
# }
# .plain.r,.contnr.r,.contnr.r>.lbl
# ---
#
# *section:* **fragment**  `A.plain(1531341, withPassage=False, withNodes=True)`
# <div class="rtl children"><span class="plain outer rtl  " ><span class="nd">1531341</span><span class="plain txtu hbo rtl"><span class="section">CD 1</span></span></span></div>
# ---
#
# *section:* **fragment**  `A.plain(1531341, withPassage=True, withNodes=True)`
# <div class="rtl children"><span class="section ltr"><a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="Show this scroll in the Leon Levy library" sec="CD 1">CD 1</a></span> <span class="plain outer rtl  " ><span class="nd">1531341</span><span class="plain txtu hbo rtl"><span class="section"> </span></span></span></div>
# ---
#
# *section:* **fragment**  `A.pretty(1531341, withPassage=False, withNodes=True)`
# <div class="rtl children"><div class="contnr c4 trm rtl  " ><div class="lbl c4 trm " ><span class="nd">fragment:1531341</span> <span class="txtu hbo"><span class="section">CD 1</span></span></div></div></div>
# ---
#
# *section:* **fragment**  `A.pretty(1531341, withPassage=True, withNodes=True)`
# <span class="section ltr"><a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="Show this scroll in the Leon Levy library" sec="CD 1">CD 1</a></span><div class="rtl children"><div class="contnr c4 trm rtl  " ><div class="lbl c4 trm " ><span class="nd">fragment:1531341</span> <span class="txtu hbo"><span class="section">CD 1</span></span></div></div></div>
# ---
#
# *section:* **scroll**  `A.plain(1605868, withPassage=False, withNodes=True)`
# <div class="rtl children"><span class="plain outer rtl  " ><span class="nd">1605868</span><span class="plain txtu hbo rtl"><span class="section">CD</span></span></span></div>
# ---
#
# *section:* **scroll**  `A.plain(1605868, withPassage=True, withNodes=True)`
# <div class="rtl children"><span class="section ltr"><a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="Show this scroll in the Leon Levy library" sec="CD">CD</a></span> <span class="plain outer rtl  " ><span class="nd">1605868</span><span class="plain txtu hbo rtl"><span class="section"> </span></span></span></div>
# ---
#
# *section:* **scroll**  `A.pretty(1605868, withPassage=False, withNodes=True)`
# <div class="rtl children"><div class="contnr c4 trm rtl  " ><div class="lbl c4 trm " ><span class="nd">scroll:1605868</span> <span class="txtu hbo"><span class="section">CD</span></span></div></div></div>
# ---
#
# *section:* **scroll**  `A.pretty(1605868, withPassage=True, withNodes=True)`
# <span class="section ltr"><a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="Show this scroll in the Leon Levy library" sec="CD">CD</a></span><div class="rtl children"><div class="contnr c4 trm rtl  " ><div class="lbl c4 trm " ><span class="nd">scroll:1605868</span> <span class="txtu hbo"><span class="section">CD</span></span></div></div></div>
# # nena
# <style>tr.tf, td.tf, th.tf { text-align: left ! important;}@font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: x-large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
# ...
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-color3);
#     border-width: var(--border-width3);
#     border-radius: var(--border-width3);
# }
# .contnr.c4,.lbl.c4 {
#     border-color: var(--border-color4);
#     border-width: var(--border-width4);
#     border-radius: var(--border-width4);
# }
# .plain.l,.contnr.l,.contnr.l>.lbl {
#     border-left-style: dotted
# }
# .plain.r,.contnr.r,.contnr.r>.lbl
# ---
#
# *section:* **column**  `A.plain(180450, withPassage=False, withNodes=True)`
# <div class=" children"><span class="plain outer   " ><span class="nd">180450</span><span class="plain txtu "><span class="section">P006427 obverse:1</span></span><span class="plain    " ><span class="plain txtu "></span><span class="plain    " ><span class="plain " >[<span class="plain " >...</span>]</span> </span><span class="plain    " ><span class="plain " >X</span> </span><span class="plain    " ><span class="plain " >X</span> </span></span></span></div>
# ---
#
# *section:* **column**  `A.plain(180450, withPassage=True, withNodes=True)`
# <div class=" children"><span class="section ltr"><a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006427" title="to CDLI main page for this tablet" sec="P006427 obverse:1">P006427 obverse:1</a></span> <span class="plain outer   " ><span class="nd">180450</span><span class="plain txtu "><span class="section"> </span></span><span class="plain    " ><span class="plain txtu "></span><span class="plain    " ><span class="plain " >[<span class="plain " >...</span>]</span> </span><span class="plain    " ><span class="plain " >X</span> </span><span class="plain    " ><span class="plain " >X</span> </span></span></span></div>
# ---
#
# *section:* **column**  `A.pretty(180450, withPassage=False, withNodes=True)`
# <div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">column:180450</span> <span class="txtu"><span title="number">1</span><span title="prime"></span></span></div><div class="children ver  "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">line:227226</span> <span class="txtu"><span title="number">1</span></span></div><div class="children hor  "><div class="contnr c1 cluster trm   " ><div class="lbl c1 clusterb trm " ><span class="nd">cluster:194473</span> <span class="txtu"><span title="type">?</span></span></div></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">2</span> <span class="txtu"><span title="atf">...</span></span></div></div></div><div class="contnr c1 cluster {}   " ><div class="lbl c1 clustere trm " ><span class="nd">cluster:194473</span> <span class="txtu"><span title="type">?</span></span></div> </div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">3</span> <span class="txtu"><span title="atf">X</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">4</span> <span class="txtu"><span title="atf">X</span></span></div></div></div></div></div></div></div>
# ---
#
# *section:* **column**  `A.pretty(180450, withPassage=True, withNodes=True)`
# <span class="section ltr"><a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006427" title="to CDLI main page for this tablet" sec="P006427 obverse:1">P006427 obverse:1</a></span><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">column:180450</span> <span class="txtu"><span title="number">1</span><span title="prime"></span></span></div><div class="children ver  "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">line:227226</span> <span class="txtu"><span title="number">1</span></span></div><div class="children hor  "><div class="contnr c1 cluster trm   " ><div class="lbl c1 clusterb trm " ><span class="nd">cluster:194473</span> <span class="txtu"><span title="type">?</span></span></div></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">2</span> <span class="txtu"><span title="atf">...</span></span></div></div></div><div class="contnr c1 cluster {}   " ><div class="lbl c1 clustere trm " ><span class="nd">cluster:194473</span> <span class="txtu"><span title="type">?</span></span></div> </div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">3</span> <span class="txtu"><span title="atf">X</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">4</span> <span class="txtu"><span title="atf">X</span></span></div></div></div></div></div></div></div>
# ---
#
# *section:* **tablet**  `A.plain(143889, withPassage=False, withNodes=True)`
# <div class=" children"><span class="plain outer   " ><span class="nd">143889</span><span class="plain txtu "><span class="section">P006427</span></span><span class="plain    " ><span class="plain txtu "></span><span class="plain    " ><span class="plain " ></span> </span></span><span class="plain    " ><span class="plain txtu "><span title="type">obverse</span></span><span class="plain    " ><span class="plain txtu "><span class="section">P006427 obverse:1</span></span><span class="plain    " ><span class="plain txtu "></span><span class="plain    " ><span class="plain " >[<span class="plain " >...</span>]</span> </span><span class="plain    " ><span class="plain " >X</span> </span><span class="plain    " ><span class="plain " >X</span> </span></span></span><span class="plain    " ><span class="plain txtu "><span class="section">P006427 obverse:2</span></span><span class="plain    " ><span class="plain txtu "></span><span class="plain    " ><span class="plain " >3(N14)</span> </span><span class="plain    " ><span class="plain " >X</span> </span><span class="plain    " ><span class="plain " >SANGA~a</span> </span><span class="plain    " ><span class="plain " >[<span class="plain " >...</span>]</span> </span></span></span></span></span></div>
# ---
#
# *section:* **tablet**  `A.plain(143889, withPassage=True, withNodes=True)`
# <div class=" children"><span class="section ltr"><a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006427" title="to CDLI main page for this tablet" sec="P006427">P006427</a></span> <span class="plain outer   " ><span class="nd">143889</span><span class="plain txtu "><span class="section"> </span></span><span class="plain    " ><span class="plain txtu "></span><span class="plain    " ><span class="plain " ></span> </span></span><span class="plain    " ><span class="plain txtu "><span title="type">obverse</span></span><span class="plain    " ><span class="plain txtu "><span class="section">P006427 obverse:1</span></span><span class="plain    " ><span class="plain txtu "></span><span class="plain    " ><span class="plain " >[<span class="plain " >...</span>]</span> </span><span class="plain    " ><span class="plain " >X</span> </span><span class="plain    " ><span class="plain " >X</span> </span></span></span><span class="plain    " ><span class="plain txtu "><span class="section">P006427 obverse:2</span></span><span class="plain    " ><span class="plain txtu "></span><span class="plain    " ><span class="plain " >3(N14)</span> </span><span class="plain    " ><span class="plain " >X</span> </span><span class="plain    " ><span class="plain " >SANGA~a</span> </span><span class="plain    " ><span class="plain " >[<span class="plain " >...</span>]</span> </span></span></span></span></span></div>
# ---
#
# *section:* **tablet**  `A.pretty(143889, withPassage=False, withNodes=True)`
# <div class=" children"><div class="contnr c4    " ><div class="lbl c4  " ><span class="nd">tablet:143889</span> <span class="txtu"><span class="section">P006427</span></span></div><div class='features'><span class="name " title="name">Anonymous 006427</span><span class="period " title="period">uruk-iii</span></div><div class="children ver  "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">comment:169360</span> <span class="txtu"><span class="plain    " ><span class="plain txtu "></span><span class="plain    " ><span class="plain " ></span> </span></span></span></div><div class='features'><span class="text " title="text">atf: lang qpc</span></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">face:150253</span> <span class="txtu"><span title="type">obverse</span></span></div><div class="children hor  "><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">column:180450</span> <span class="txtu"><span title="number">1</span><span title="prime"></span></span></div><div class="children ver  "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">line:227226</span> <span class="txtu"><span title="number">1</span></span></div><div class="children hor  "><div class="contnr c1 cluster trm   " ><div class="lbl c1 clusterb trm " ><span class="nd">cluster:194473</span> <span class="txtu"><span title="type">?</span></span></div></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">2</span> <span class="txtu"><span title="atf">...</span></span></div></div></div><div class="contnr c1 cluster {}   " ><div class="lbl c1 clustere trm " ><span class="nd">cluster:194473</span> <span class="txtu"><span title="type">?</span></span></div> </div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">3</span> <span class="txtu"><span title="atf">X</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">4</span> <span class="txtu"><span title="atf">X</span></span></div></div></div></div></div></div><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">column:180451</span> <span class="txtu"><span title="number">2</span><span title="prime"></span></span></div><div class="children ver  "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">line:227227</span> <span class="txtu"><span title="number">1</span></span></div><div class="children hor  "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">5</span> <span class="txtu"><span title="atf">3(N14)</span></span></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n14).jpg" style="display: inline;max-width: 2em; max-height: 6em;"  /></a></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">6</span> <span class="txtu"><span title="atf">X</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">7</span> <span class="txtu"><span title="atf">SANGA~a?</span></span></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SANGA~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sanga-a.jpg" style="display: inline;max-width: 2em; max-height: 6em;"  /></a></div></div><div class="contnr c1 cluster trm   " ><div class="lbl c1 clusterb trm " ><span class="nd">cluster:194474</span> <span class="txtu"><span title="type">?</span></span></div></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">8</span> <span class="txtu"><span title="atf">...</span></span></div></div></div><div class="contnr c1 cluster {}   " ><div class="lbl c1 clustere trm " ><span class="nd">cluster:194474</span> <span class="txtu"><span title="type">?</span></span></div> ...
# ---
#
# *section:* **tablet**  `A.pretty(143889, withPassage=True, withNodes=True)`
# <span class="section ltr"><a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006427" title="to CDLI main page for this tablet" sec="P006427">P006427</a></span><div class=" children"><div class="contnr c4    " ><div class="lbl c4  " ><span class="nd">tablet:143889</span> <span class="txtu"><span class="section">P006427</span></span></div><div class='features'><span class="name " title="name">Anonymous 006427</span><span class="period " title="period">uruk-iii</span></div><div class="children ver  "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">comment:169360</span> <span class="txtu"><span class="plain    " ><span class="plain txtu "></span><span class="plain    " ><span class="plain " ></span> </span></span></span></div><div class='features'><span class="text " title="text">atf: lang qpc</span></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">face:150253</span> <span class="txtu"><span title="type">obverse</span></span></div><div class="children hor  "><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">column:180450</span> <span class="txtu"><span title="number">1</span><span title="prime"></span></span></div><div class="children ver  "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">line:227226</span> <span class="txtu"><span title="number">1</span></span></div><div class="children hor  "><div class="contnr c1 cluster trm   " ><div class="lbl c1 clusterb trm " ><span class="nd">cluster:194473</span> <span class="txtu"><span title="type">?</span></span></div></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">2</span> <span class="txtu"><span title="atf">...</span></span></div></div></div><div class="contnr c1 cluster {}   " ><div class="lbl c1 clustere trm " ><span class="nd">cluster:194473</span> <span class="txtu"><span title="type">?</span></span></div> </div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">3</span> <span class="txtu"><span title="atf">X</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">4</span> <span class="txtu"><span title="atf">X</span></span></div></div></div></div></div></div><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">column:180451</span> <span class="txtu"><span title="number">2</span><span title="prime"></span></span></div><div class="children ver  "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">line:227227</span> <span class="txtu"><span title="number">1</span></span></div><div class="children hor  "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">5</span> <span class="txtu"><span title="atf">3(N14)</span></span></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/3(N14).jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-3(n14).jpg" style="display: inline;max-width: 2em; max-height: 6em;"  /></a></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">6</span> <span class="txtu"><span title="atf">X</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">7</span> <span class="txtu"><span title="atf">SANGA~a?</span></span></div><div><a target="_blank" href="https://cdli.ucla.edu/tools/SignLists/protocuneiform/archsigns/SANGA~a.jpg" title="to higher resolution lineart on CDLI"><img src="cdli-imagery/lineart-sanga-a.jpg" style="display: inline;max-width: 2em; max-height: 6em;"  /></a></div></div><div class="contnr c1 cluster trm   " ><div class="lbl c1 clusterb trm " ><span class="nd">cluster:194474</span> <span class="txtu"><span title="type">?</span></span></div></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">8</span> <span class="txtu"><span title=" ...

# %% [markdown]
# ## Run specific corpora

# %%
As.testSet("banks")

# %%
As.test(sections, refresh=True)
# Out:
# # banks
#  1m 01s All features loaded/computed - for details use loadLog()
# <style>tr.tf, td.tf, th.tf { text-align: left ! important;}@font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: x-large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: x-large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .rtl {
#     direction: rtl ! important;
# }
# span.plain {
#     display: inline-block;
#     white-space: pre-wrap;
#     text-align: start;
# }
# .gr,.gl {
#     white-space: pre-wrap;
#     border-color: var(--border-color-gap);
#     border-width: var(--border-width-gap);
#     border-top-style: none;
#     border-bottom-style: none;
# }
# .gr {
#     border-right-style: solid;
#     border-left-style: dashed;
# }
# .gl {
#     border-right-style: dashed;
#     border-left-style: solid;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 0.1rem;
#     margin: 0.1rem;
#     direction: ltr;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1rem 0rem;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .section {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--section);
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5rem 0.1rem 0.1rem 0.1rem;
#     margin: 0.8rem 0.1rem 0.1rem 0.1rem;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-color3);
#     border-width: var(--border-width3);
#     border-radius: var(--border-width3);
# }
# .contnr.c4,.lbl.c4 {
#     border-color: var(--border-color4);
#     border-width: var(--border-width4);
#     border-radius: var(--border-width4);
# }
# .plain.l,.contnr.l,.contnr.l>.lbl {
#     border-left-style: dotted
# }
# .plain.r,.contnr.r,.contnr.r>.lbl
# ---
#
# *sectional:* **chapter**  `A.plain(101, withPassage=False, withNodes=True)`
# <div class=" children"><span class="plain outer   " ><span class="nd">101</span><span class="plain txtu "><span class="section">Consider Phlebas 1</span></span></span></div>
# ---
#
# *sectional:* **chapter**  `A.plain(101, withPassage=True, withNodes=True)`
# <div class=" children"><span class="section ltr">Consider Phlebas 1</span> <span class="plain outer   " ><span class="nd">101</span><span class="plain txtu "><span class="section"> </span></span></span></div>
# ---
#
# *sectional:* **chapter**  `A.pretty(101, withPassage=False, withNodes=True)`
# <div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">chapter:101</span> <span class="txtu"><span class="section">Consider Phlebas 1</span></span></div></div></div>
# ---
#
# *sectional:* **chapter**  `A.pretty(101, withPassage=True, withNodes=True)`
# <span class="section ltr">Consider Phlebas 1</span><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">chapter:101</span> <span class="txtu"><span class="section">Consider Phlebas 1</span></span></div></div></div>
# ---
#
# *sectional:* **book**  `A.plain(100, withPassage=False, withNodes=True)`
# <div class=" children"><span class="plain outer   " ><span class="nd">100</span><span class="plain txtu "><span class="section">Consider Phlebas</span></span></span></div>
# ---
#
# *sectional:* **book**  `A.plain(100, withPassage=True, withNodes=True)`
# <div class=" children"><span class="section ltr">Consider Phlebas</span> <span class="plain outer   " ><span class="nd">100</span><span class="plain txtu "><span class="section"> </span></span></span></div>
# ---
#
# *sectional:* **book**  `A.pretty(100, withPassage=False, withNodes=True)`
# <div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">book:100</span> <span class="txtu"><span class="section">Consider Phlebas</span></span></div></div></div>
# ---
#
# *sectional:* **book**  `A.pretty(100, withPassage=True, withNodes=True)`
# <span class="section ltr">Consider Phlebas</span><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">book:100</span> <span class="txtu"><span class="section">Consider Phlebas</span></span></div></div></div>
