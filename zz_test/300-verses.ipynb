# %%
# %load_ext autoreload
# %autoreload 2

# %%
from fixture import TestApp

# %%
As = TestApp(globals())

# %%
def verses():
    for n in As.select(verse=True, start=True, size=1):
        As.perform('plain', n, withPassage=False, withNodes=True)
        As.perform('plain', n, withPassage=True, withNodes=True)
        As.perform('pretty', n, withPassage=False, withNodes=True)
        As.perform('pretty', n, withPassage=True, withNodes=True)

# %% [markdown]
# ## Run all corpora

# %%
As.testSet()

# %%
As.test(verses)
# Out:
# # athenaeus
# <style>tr.tf, td.tf, th.tf { text-align: left ! important;}@font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: x-large;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: large;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: x-large;
#     direction: ltr;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .rtl {
#     direction: rtl ! important;
# }
# span.plain {
#     display: inline-block;
#     white-space: pre-wrap;
#     text-align: start;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 0.1rem;
#     margin: 0.1rem;
#     direction: ltr;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1rem 0rem;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .psg {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--passage);
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd {
#     font-family: sans-serif;
#     font-size: x-small;
#     color: var(--node);
#     vertical-align: super;
# }
# .verse {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-end;
#     align-items: flex-end;
#     direction: ltr;
#     width: 100%;
# }
# .vn {
#   font-size: small !important;
#   padding-right: 1rem;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.row {
#     flex-flow: row nowrap;
# }
# .children.row.wrap {
#     flex-flow: row wrap;
# }
# .children.col {
#     flex-flow: column nowrap;
# }
# .children.col.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5rem 0.1rem 0.1rem 0.1rem;
#     margin: 0.8rem 0.1rem 0.1rem 0.1rem;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-color3);
#     border-width: var(--border-width3);
#     border-radius: var(--border-width3);
# }
# .contnr.c4,.lbl.c4 {
#     border-color: var(--border-color4);
#     border-width: var(--border-width4);
#     border-radius: var(--border-width4);
# }
# .contnr.l {
#     border-left-style: dotted
# }
# .contnr.r {
#     border-right-style: dotted
# }
# .contnr.lno {
#     border-left-style: none
# }
# .contnr.rno {
#     border-right-style: none
# }
# .lbl {
#     margin-top: -1.2rem;
#     margin-left: 1rem;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3rem;
#     border-style: solid;
#     display: block;
#     color: var(--label)
# }
# .lbl.trm {
#     ba
# ---
#
# *verse:* **_sentence** `A.plain(265148, withPassage=False, withNodes=True)`
# <span class="plain outer   " ><span class="nd">265148</span><span class="plain ">1 1:1</span><span class="plain    " ><span class="txtu grc">Ἀθήναιος </span></span><span class="plain    " ><span class="txtu grc">μὲν </span></span><span class="plain    " ><span class="txtu grc">ὁ </span></span><span class="plain    " ><span class="txtu grc">τῆς </span></span><span class="plain    " ><span class="txtu grc">βίβλου </span></span><span class="plain    " ><span class="txtu grc">πατήρ· </span></span><span class="plain    " ><span class="txtu grc">ποιεῖται </span></span><span class="plain    " ><span class="txtu grc">δὲ </span></span><span class="plain    " ><span class="txtu grc">τὸν </span></span><span class="plain    " ><span class="txtu grc">λόγον </span></span><span class="plain    " ><span class="txtu grc">πρὸς </span></span><span class="plain    " ><span class="txtu grc">Τιμοκράτην· </span></span><span class="plain    " ><span class="txtu grc">Δειπνοσοφιστὴς </span></span><span class="plain    " ><span class="txtu grc">δὲ </span></span><span class="plain    " ><span class="txtu grc">ταύτῃ </span></span><span class="plain    " ><span class="txtu grc">τὸ </span></span><span class="plain    " ><span class="txtu grc">ὄνομα. </span></span></span>
# ---
#
# *verse:* **_sentence** `A.plain(265148, withPassage=True, withNodes=True)`
# <span class="psg ltr">1 1:1 </span><span class="plain outer   " ><span class="nd">265148</span><span class="plain ">1 1:1</span><span class="plain    " ><span class="txtu grc">Ἀθήναιος </span></span><span class="plain    " ><span class="txtu grc">μὲν </span></span><span class="plain    " ><span class="txtu grc">ὁ </span></span><span class="plain    " ><span class="txtu grc">τῆς </span></span><span class="plain    " ><span class="txtu grc">βίβλου </span></span><span class="plain    " ><span class="txtu grc">πατήρ· </span></span><span class="plain    " ><span class="txtu grc">ποιεῖται </span></span><span class="plain    " ><span class="txtu grc">δὲ </span></span><span class="plain    " ><span class="txtu grc">τὸν </span></span><span class="plain    " ><span class="txtu grc">λόγον </span></span><span class="plain    " ><span class="txtu grc">πρὸς </span></span><span class="plain    " ><span class="txtu grc">Τιμοκράτην· </span></span><span class="plain    " ><span class="txtu grc">Δειπνοσοφιστὴς </span></span><span class="plain    " ><span class="txtu grc">δὲ </span></span><span class="plain    " ><span class="txtu grc">ταύτῃ </span></span><span class="plain    " ><span class="txtu grc">τὸ </span></span><span class="plain    " ><span class="txtu grc">ὄνομα. </span></span></span>
# ---
#
# *verse:* **_sentence** `A.pretty(265148, withPassage=False, withNodes=True)`
# <div class="contnr c3    " ><div class="lbl c3  "><span class="nd">_sentence:265148</span> <span class="txtu grc">1 1:1</span></div> <div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">1</span> <span class="txtu grc">Ἀθήναιος </span></div> <div class='features'><span class="beta_plain ">aqhnaios</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">2</span> <span class="txtu grc">μὲν </span></div> <div class='features'><span class="beta_plain ">me</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">3</span> <span class="txtu grc">ὁ </span></div> <div class='features'><span class="beta_plain ">o</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">4</span> <span class="txtu grc">τῆς </span></div> <div class='features'><span class="beta_plain ">ths</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">5</span> <span class="txtu grc">βίβλου </span></div> <div class='features'><span class="beta_plain ">biblou</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">6</span> <span class="txtu grc">πατήρ· </span></div> <div class='features'><span class="beta_plain ">pathr</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">7</span> <span class="txtu grc">ποιεῖται </span></div> <div class='features'><span class="beta_plain ">poieitai</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">8</span> <span class="txtu grc">δὲ </span></div> <div class='features'><span class="beta_plain ">de</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">9</span> <span class="txtu grc">τὸν </span></div> <div class='features'><span class="beta_plain ">ton</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">10</span> <span class="txtu grc">λόγον </span></div> <div class='features'><span class="beta_plain ">logon</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">11</span> <span class="txtu grc">πρὸς </span></div> <div class='features'><span class="beta_plain ">pros</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">12</span> <span class="txtu grc">Τιμοκράτην· </span></div> <div class='features'><span class="beta_plain ">timokrathn</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">13</span> <span class="txtu grc">Δειπνοσοφιστὴς </span></div> <div class='features'><span class="beta_plain ">deipnos1ofis1ths</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">14</span> <span class="txtu grc">δὲ </span></div> <div class='features'><span class="beta_plain ">de</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">15</span> <span class="txtu grc">ταύτῃ </span></div> <div class='features'><span class="beta_plain ">tauth</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">16</span> <span class="txtu grc">τὸ </span></div> <div class='features'><span class="beta_plain ">to</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">17</span> <span class="txtu grc">ὄνομα. </span></div> <div class='features'><span class="beta_plain ">onoma</span></div></div></div></div>
# ---
#
# *verse:* **_sentence** `A.pretty(265148, withPassage=True, withNodes=True)`
# <span class="psg ltr">1 1:1 </span><div class="contnr c3    " ><div class="lbl c3  "><span class="nd">_sentence:265148</span> <span class="txtu grc">1 1:1</span></div> <div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">1</span> <span class="txtu grc">Ἀθήναιος </span></div> <div class='features'><span class="beta_plain ">aqhnaios</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">2</span> <span class="txtu grc">μὲν </span></div> <div class='features'><span class="beta_plain ">me</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">3</span> <span class="txtu grc">ὁ </span></div> <div class='features'><span class="beta_plain ">o</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">4</span> <span class="txtu grc">τῆς </span></div> <div class='features'><span class="beta_plain ">ths</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">5</span> <span class="txtu grc">βίβλου </span></div> <div class='features'><span class="beta_plain ">biblou</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">6</span> <span class="txtu grc">πατήρ· </span></div> <div class='features'><span class="beta_plain ">pathr</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">7</span> <span class="txtu grc">ποιεῖται </span></div> <div class='features'><span class="beta_plain ">poieitai</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">8</span> <span class="txtu grc">δὲ </span></div> <div class='features'><span class="beta_plain ">de</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">9</span> <span class="txtu grc">τὸν </span></div> <div class='features'><span class="beta_plain ">ton</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">10</span> <span class="txtu grc">λόγον </span></div> <div class='features'><span class="beta_plain ">logon</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">11</span> <span class="txtu grc">πρὸς </span></div> <div class='features'><span class="beta_plain ">pros</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">12</span> <span class="txtu grc">Τιμοκράτην· </span></div> <div class='features'><span class="beta_plain ">timokrathn</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">13</span> <span class="txtu grc">Δειπνοσοφιστὴς </span></div> <div class='features'><span class="beta_plain ">deipnos1ofis1ths</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">14</span> <span class="txtu grc">δὲ </span></div> <div class='features'><span class="beta_plain ">de</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">15</span> <span class="txtu grc">ταύτῃ </span></div> <div class='features'><span class="beta_plain ">tauth</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">16</span> <span class="txtu grc">τὸ </span></div> <div class='features'><span class="beta_plain ">to</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">17</span> <span class="txtu grc">ὄνομα. </span></div> <div class='features'><span class="beta_plain ">onoma</span></div></div></div></div>
# # banks
# <style>tr.tf, td.tf, th.tf { text-align: left ! important;}@font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: x-large;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: large;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: x-large;
#     direction: ltr;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .rtl {
#     direction: rtl ! important;
# }
# span.plain {
#     display: inline-block;
#     white-space: pre-wrap;
#     text-align: start;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 0.1rem;
#     margin: 0.1rem;
#     direction: ltr;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1rem 0rem;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .psg {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--passage);
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd {
#     font-family: sans-serif;
#     font-size: x-small;
#     color: var(--node);
#     vertical-align: super;
# }
# .verse {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-end;
#     align-items: flex-end;
#     direction: ltr;
#     width: 100%;
# }
# .vn {
#   font-size: small !important;
#   padding-right: 1rem;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.row {
#     flex-flow: row nowrap;
# }
# .children.row.wrap {
#     flex-flow: row wrap;
# }
# .children.col {
#     flex-flow: column nowrap;
# }
# .children.col.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5rem 0.1rem 0.1rem 0.1rem;
#     margin: 0.8rem 0.1rem 0.1rem 0.1rem;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-color3);
#     border-width: var(--border-width3);
#     border-radius: var(--border-width3);
# }
# .contnr.c4,.lbl.c4 {
#     border-color: var(--border-color4);
#     border-width: var(--border-width4);
#     border-radius: var(--border-width4);
# }
# .contnr.l {
#     border-left-style: dotted
# }
# .contnr.r {
#     border-right-style: dotted
# }
# .contnr.lno {
#     border-left-style: none
# }
# .contnr.rno {
#     border-right-style: none
# }
# .lbl {
#     margin-top: -1.2rem;
#     margin-left: 1rem;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3rem;
#     border-style: solid;
#     display: block;
#     color: var(--label)
# }
# .lbl.trm {
#     ba
# ---
#
# *verse:* **line** `A.plain(103, withPassage=False, withNodes=True)`
# <span class="plain outer   " ><span class="nd">103</span><span class="plain "><span class="nd">book</span> Consider Phlebas, <span class="nd">chapter</span> 1, <span class="nd">sentence</span> 1, <span class="nd">line</span> 1</span><span class="plain    " ><span class="txtu">Everything </span></span><span class="plain    " ><span class="txtu">about </span></span><span class="plain    " ><span class="txtu">us, </span></span></span>
# ---
#
# *verse:* **line** `A.plain(103, withPassage=True, withNodes=True)`
# <span class="psg ltr">Consider Phlebas 1:1 </span><span class="plain outer   " ><span class="nd">103</span><span class="plain "><span class="nd">book</span> Consider Phlebas, <span class="nd">chapter</span> 1, <span class="nd">sentence</span> 1, <span class="nd">line</span> 1</span><span class="plain    " ><span class="txtu">Everything </span></span><span class="plain    " ><span class="txtu">about </span></span><span class="plain    " ><span class="txtu">us, </span></span></span>
# ---
#
# *verse:* **line** `A.pretty(103, withPassage=False, withNodes=True)`
# <div class="children row wrap "><div class="contnr c3    r " ><div class="lbl c3  "><span class="nd">line:103</span> <span class="txtn">1</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>,</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">1</span> <span class="txtu">Everything </span></div> </div></div></div><div class="contnr c3    l r " ><div class="lbl c3  "><span class="nd">line:103</span> <span class="txtn">1</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>,</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">2</span> <span class="txtu">about </span></div> </div></div></div><div class="contnr c3    l " ><div class="lbl c3  "><span class="nd">line:103</span> <span class="txtn">1</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>,</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">3</span> <span class="txtu">us, </span></div> </div></div></div></div>
# ---
#
# *verse:* **line** `A.pretty(103, withPassage=True, withNodes=True)`
# <span class="psg ltr">Consider Phlebas 1:1 </span><div class="children row wrap "><div class="contnr c3    r " ><div class="lbl c3  "><span class="nd">line:103</span> <span class="txtn">1</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>,</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">1</span> <span class="txtu">Everything </span></div> </div></div></div><div class="contnr c3    l r " ><div class="lbl c3  "><span class="nd">line:103</span> <span class="txtn">1</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>,</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">2</span> <span class="txtu">about </span></div> </div></div></div><div class="contnr c3    l " ><div class="lbl c3  "><span class="nd">line:103</span> <span class="txtn">1</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>,</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">3</span> <span class="txtu">us, </span></div> </div></div></div></div>
# ---
#
# *verse:* **sentence** `A.plain(115, withPassage=False, withNodes=True)`
# <span class="plain outer   " ><span class="nd">115</span><span class="plain ">Consider Phlebas 1:1</span><span class="plain    " ><span class="txtu">Everything </span></span><span class="plain    " ><span class="txtu">about </span></span><span class="plain    " ><span class="txtu">us, </span></span><span class="plain    " ><span class="txtu">everything </span></span><span class="plain    " ><span class="txtu">around </span></span><span class="plain    " ><span class="txtu">us, </span></span><span class="plain    " ><span class="txtu">everything </span></span><span class="plain    " ><span class="txtu">we </span></span><span class="plain    " ><span class="txtu">know </span></span><span class="plain    " ><span class="txtu">and </span></span><span class="plain    " ><span class="txtu">can </span></span><span class="plain    " ><span class="txtu">know </span></span><span class="plain    " ><span class="txtu">of </span></span><span class="plain    " ><span class="txtu">is </span></span><span class="plain    " ><span class="txtu">composed </span></span><span class="plain    " ><span class="txtu">ultimately </span></span><span class="plain    " ><span class="txtu">of </span></span><span class="plain    " ><span class="txtu">patterns </span></span><span class="plain    " ><span class="txtu">of </span></span><span class="plain    " ><span class="txtu">nothing; </span></span><span class="plain    " ><span class="txtu">that’s </span></span><span class="plain    " ><span class="txtu">the </span></span><span class="plain    " ><span class="txtu">bottom </span></span><span class="plain    " ><span class="txtu">line, </span></span><span class="plain    " ><span class="txtu">the </span></span><span class="plain    " ><span class="txtu">final </span></span><span class="plain    " ><span class="txtu">truth. </span></span></span>
# ---
#
# *verse:* **sentence** `A.plain(115, withPassage=True, withNodes=True)`
# <span class="psg ltr">Consider Phlebas 1:1 </span><span class="plain outer   " ><span class="nd">115</span><span class="plain ">Consider Phlebas 1:1</span><span class="plain    " ><span class="txtu">Everything </span></span><span class="plain    " ><span class="txtu">about </span></span><span class="plain    " ><span class="txtu">us, </span></span><span class="plain    " ><span class="txtu">everything </span></span><span class="plain    " ><span class="txtu">around </span></span><span class="plain    " ><span class="txtu">us, </span></span><span class="plain    " ><span class="txtu">everything </span></span><span class="plain    " ><span class="txtu">we </span></span><span class="plain    " ><span class="txtu">know </span></span><span class="plain    " ><span class="txtu">and </span></span><span class="plain    " ><span class="txtu">can </span></span><span class="plain    " ><span class="txtu">know </span></span><span class="plain    " ><span class="txtu">of </span></span><span class="plain    " ><span class="txtu">is </span></span><span class="plain    " ><span class="txtu">composed </span></span><span class="plain    " ><span class="txtu">ultimately </span></span><span class="plain    " ><span class="txtu">of </span></span><span class="plain    " ><span class="txtu">patterns </span></span><span class="plain    " ><span class="txtu">of </span></span><span class="plain    " ><span class="txtu">nothing; </span></span><span class="plain    " ><span class="txtu">that’s </span></span><span class="plain    " ><span class="txtu">the </span></span><span class="plain    " ><span class="txtu">bottom </span></span><span class="plain    " ><span class="txtu">line, </span></span><span class="plain    " ><span class="txtu">the </span></span><span class="plain    " ><span class="txtu">final </span></span><span class="plain    " ><span class="txtu">truth. </span></span></span>
# ---
#
# *verse:* **sentence** `A.pretty(115, withPassage=False, withNodes=True)`
# <div class="contnr c3    " ><div class="lbl c3  "><span class="nd">sentence:115</span> <span class="txtu">Consider Phlebas 1:1</span></div> <div class="children row wrap "><div class="contnr c3    r " ><div class="lbl c3  "><span class="nd">line:103</span> <span class="txtn">1</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>,</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">1</span> <span class="txtu">Everything </span></div> </div></div></div><div class="contnr c3    l r " ><div class="lbl c3  "><span class="nd">line:103</span> <span class="txtn">1</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>,</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">2</span> <span class="txtu">about </span></div> </div></div></div><div class="contnr c3    l " ><div class="lbl c3  "><span class="nd">line:103</span> <span class="txtn">1</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>,</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">3</span> <span class="txtu">us, </span></div> </div></div></div><div class="contnr c3    r " ><div class="lbl c3  "><span class="nd">line:104</span> <span class="txtn">2</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>,</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">4</span> <span class="txtu">everything </span></div> </div></div></div><div class="contnr c3    l r " ><div class="lbl c3  "><span class="nd">line:104</span> <span class="txtn">2</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>,</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">5</span> <span class="txtu">around </span></div> </div></div></div><div class="contnr c3    l " ><div class="lbl c3  "><span class="nd">line:104</span> <span class="txtn">2</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>,</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">6</span> <span class="txtu">us, </span></div> </div></div></div><div class="contnr c3    r " ><div class="lbl c3  "><span class="nd">line:105</span> <span class="txtn">3</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>;</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">7</span> <span class="txtu">everything </span></div> </div></div></div><div class="contnr c3    l r " ><div class="lbl c3  "><span class="nd">line:105</span> <span class="txtn">3</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>;</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">8</span> <span class="txtu">we </span></div> </div></div></div><div class="contnr c3    l r " ><div class="lbl c3  "><span class="nd">line:105</span> <span class="txtn">3</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>;</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">9</span> <span class="txtu">know </span></div> </div></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">10</span> <span class="txtu">and </span></div> <div class='features'><span class="gap "><span class="f">gap=</span>1</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">11</span> <span class="txtu">can </span></div> <div class ...
# ---
#
# *verse:* **sentence** `A.pretty(115, withPassage=True, withNodes=True)`
# <span class="psg ltr">Consider Phlebas 1:1 </span><div class="contnr c3    " ><div class="lbl c3  "><span class="nd">sentence:115</span> <span class="txtu">Consider Phlebas 1:1</span></div> <div class="children row wrap "><div class="contnr c3    r " ><div class="lbl c3  "><span class="nd">line:103</span> <span class="txtn">1</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>,</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">1</span> <span class="txtu">Everything </span></div> </div></div></div><div class="contnr c3    l r " ><div class="lbl c3  "><span class="nd">line:103</span> <span class="txtn">1</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>,</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">2</span> <span class="txtu">about </span></div> </div></div></div><div class="contnr c3    l " ><div class="lbl c3  "><span class="nd">line:103</span> <span class="txtn">1</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>,</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">3</span> <span class="txtu">us, </span></div> </div></div></div><div class="contnr c3    r " ><div class="lbl c3  "><span class="nd">line:104</span> <span class="txtn">2</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>,</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">4</span> <span class="txtu">everything </span></div> </div></div></div><div class="contnr c3    l r " ><div class="lbl c3  "><span class="nd">line:104</span> <span class="txtn">2</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>,</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">5</span> <span class="txtu">around </span></div> </div></div></div><div class="contnr c3    l " ><div class="lbl c3  "><span class="nd">line:104</span> <span class="txtn">2</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>,</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">6</span> <span class="txtu">us, </span></div> </div></div></div><div class="contnr c3    r " ><div class="lbl c3  "><span class="nd">line:105</span> <span class="txtn">3</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>;</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">7</span> <span class="txtu">everything </span></div> </div></div></div><div class="contnr c3    l r " ><div class="lbl c3  "><span class="nd">line:105</span> <span class="txtn">3</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>;</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">8</span> <span class="txtu">we </span></div> </div></div></div><div class="contnr c3    l r " ><div class="lbl c3  "><span class="nd">line:105</span> <span class="txtn">3</span></div> <div class='features'><span class="terminator "><span class="f">terminator=</span>;</span></div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">9</span> <span class="txtu">know </span></div> </div></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">10</span> <span class="txtu">and </span></div> <div class='features'><span class="gap "><span class="f">gap=</span>1</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">11</spa ...
# # bhsa
# <style>tr.tf, td.tf, th.tf { text-align: left ! important;}@font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: x-large;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: large;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: x-large;
#     direction: ltr;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .rtl {
#     direction: rtl ! important;
# }
# span.plain {
#     display: inline-block;
#     white-space: pre-wrap;
#     text-align: start;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 0.1rem;
#     margin: 0.1rem;
#     direction: ltr;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1rem 0rem;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .psg {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--passage);
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd {
#     font-family: sans-serif;
#     font-size: x-small;
#     color: var(--node);
#     vertical-align: super;
# }
# .verse {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-end;
#     align-items: flex-end;
#     direction: ltr;
#     width: 100%;
# }
# .vn {
#   font-size: small !important;
#   padding-right: 1rem;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.row {
#     flex-flow: row nowrap;
# }
# .children.row.wrap {
#     flex-flow: row wrap;
# }
# .children.col {
#     flex-flow: column nowrap;
# }
# .children.col.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
# ...
# ---
#
# *verse:* **verse** `A.plain(112966, withPassage=True, withNodes=True)`
# <span class="psg ltr">Matthew 1:1 </span><span class="plain outer rtl  " ><span class="nd">112966</span><span class="plain rtl">Matthew 1:1</span><span class="plain  rtl  " ><span class="txtu syc">ܟܬܒܐ </span></span><span class="plain  rtl  " ><span class="txtu syc">ܕܝܠܝܕܘܬܗ </span></span><span class="plain  rtl  " ><span class="txtu syc">ܕܝܫܘܥ </span></span><span class="plain  rtl  " ><span class="txtu syc">ܡܫܝܚܐ </span></span><span class="plain  rtl  " ><span class="txtu syc">ܒܪܗ </span></span><span class="plain  rtl  " ><span class="txtu syc">ܕܕܘܝܕ </span></span><span class="plain  rtl  " ><span class="txtu syc">ܒܪܗ </span></span><span class="plain  rtl  " ><span class="txtu syc">ܕܐܒܪܗܡ </span></span></span>
# ---
#
# *verse:* **verse** `A.pretty(112966, withPassage=False, withNodes=True)`
# <div class="contnr c3  rtl  " ><div class="lbl c3  "><span class="nd">verse:112966</span> <span class="txtu syc">Matthew 1:1</span></div> <div class="children row wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm "><span class="nd">1</span> <span class="txtu syc">ܟܬܒܐ </span></div> <div class='features'><span class="sp ">noun</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm "><span class="nd">2</span> <span class="txtu syc">ܕܝܠܝܕܘܬܗ </span></div> <div class='features'><span class="sp ">noun</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm "><span class="nd">3</span> <span class="txtu syc">ܕܝܫܘܥ </span></div> <div class='features'><span class="sp ">noun</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm "><span class="nd">4</span> <span class="txtu syc">ܡܫܝܚܐ </span></div> <div class='features'><span class="sp ">verb</span><span class="vs "><span class="f">vs=</span>peal</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm "><span class="nd">5</span> <span class="txtu syc">ܒܪܗ </span></div> <div class='features'><span class="sp ">noun</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm "><span class="nd">6</span> <span class="txtu syc">ܕܕܘܝܕ </span></div> <div class='features'><span class="sp ">noun</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm "><span class="nd">7</span> <span class="txtu syc">ܒܪܗ </span></div> <div class='features'><span class="sp ">noun</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm "><span class="nd">8</span> <span class="txtu syc">ܕܐܒܪܗܡ </span></div> <div class='features'><span class="sp ">noun</span></div></div></div></div>
# ---
#
# *verse:* **verse** `A.pretty(112966, withPassage=True, withNodes=True)`
# <span class="psg ltr">Matthew 1:1 </span><div class="contnr c3  rtl  " ><div class="lbl c3  "><span class="nd">verse:112966</span> <span class="txtu syc">Matthew 1:1</span></div> <div class="children row wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm "><span class="nd">1</span> <span class="txtu syc">ܟܬܒܐ </span></div> <div class='features'><span class="sp ">noun</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm "><span class="nd">2</span> <span class="txtu syc">ܕܝܠܝܕܘܬܗ </span></div> <div class='features'><span class="sp ">noun</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm "><span class="nd">3</span> <span class="txtu syc">ܕܝܫܘܥ </span></div> <div class='features'><span class="sp ">noun</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm "><span class="nd">4</span> <span class="txtu syc">ܡܫܝܚܐ </span></div> <div class='features'><span class="sp ">verb</span><span class="vs "><span class="f">vs=</span>peal</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm "><span class="nd">5</span> <span class="txtu syc">ܒܪܗ </span></div> <div class='features'><span class="sp ">noun</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm "><span class="nd">6</span> <span class="txtu syc">ܕܕܘܝܕ </span></div> <div class='features'><span class="sp ">noun</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm "><span class="nd">7</span> <span class="txtu syc">ܒܪܗ </span></div> <div class='features'><span class="sp ">noun</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm "><span class="nd">8</span> <span class="txtu syc">ܕܐܒܪܗܡ </span></div> <div class='features'><span class="sp ">noun</span></div></div></div></div>
# # uruk
# <style>tr.tf, td.tf, th.tf { text-align: left ! important;}@font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: x-large;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: large;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: x-large;
#     direction: ltr;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .rtl {
#     direction: rtl ! important;
# }
# span.plain {
#     display: inline-block;
#     white-space: pre-wrap;
#     text-align: start;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 0.1rem;
#     margin: 0.1rem;
#     direction: ltr;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1rem 0rem;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .psg {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--passage);
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd {
#     font-family: sans-serif;
#     font-size: x-small;
#     color: var(--node);
#     vertical-align: super;
# }
# .verse {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-end;
#     align-items: flex-end;
#     direction: ltr;
#     width: 100%;
# }
# .vn {
#   font-size: small !important;
#   padding-right: 1rem;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.row {
#     flex-flow: row nowrap;
# }
# .children.row.wrap {
#     flex-flow: row wrap;
# }
# .children.col {
#     flex-flow: column nowrap;
# }
# .children.col.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5rem 0.1rem 0.1rem 0.1rem;
#     margin: 0.8rem 0.1rem 0.1rem 0.1rem;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-color3);
#     border-width: var(--border-width3);
#     border-radius: var(--border-width3);
# }
# .contnr.c4,.lbl.c4 {
#     border-color: var(--border-color4);
#     border-width: var(--border-width4);
#     border-radius: var(--border-width4);
# }
# .contnr.l {
#     border-left-style: dotted
# }
# .contnr.r {
#     border-right-style: dotted
# }
# .contnr.lno {
#     border-left-style: none
# }
# .contnr.rno {
#     border-right-style: none
# }
# .lbl {
#     margin-top: -1.2rem;
#     margin-left: 1rem;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3rem;
#     border-style: solid;
#     display: block;
#     color: var(--label)
# }
# .lbl.trm {
#     ba
# ---
#
# *verse:* **line** `A.plain(227226, withPassage=False, withNodes=True)`
# <span class="plain outer   " ><span class="nd">227226</span><span class="plain ">P006427 obverse:1:1</span><span class="plain    " ><span class="plain " >[<span class="plain " >...</span>]</span></span><span class="plain    " ><span class="plain " >X</span>  </span><span class="plain    " ><span class="plain " >X</span>  </span></span>
# ---
#
# *verse:* **line** `A.plain(227226, withPassage=True, withNodes=True)`
# <span class="psg ltr">P006427 obverse:1:1 </span><span class="plain outer   " ><span class="nd">227226</span><span class="plain ">P006427 obverse:1:1</span><span class="plain    " ><span class="plain " >[<span class="plain " >...</span>]</span></span><span class="plain    " ><span class="plain " >X</span>  </span><span class="plain    " ><span class="plain " >X</span>  </span></span>
# ---
#
# *verse:* **line** `A.pretty(227226, withPassage=False, withNodes=True)`
# <div class="contnr c2    " ><div class="lbl c2  "><span class="nd">line:227226</span> <span class="txtn">1</span></div> <div class="children row  "><div class="contnr c1 cluster trm   " ><div class="lbl c1 clusterb trm "><span class="nd">cluster:194473</span> <span class="txtn">?</span></div> </div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">2</span> <span class="txtn">...</span></div> </div></div><div class="contnr c1 cluster {}   " ><div class="lbl c1 clustere trm "><span class="nd">cluster:194473</span> <span class="txtn">?</span></div> </div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">3</span> <span class="txtn">X</span></div> </div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">4</span> <span class="txtn">X</span></div> </div></div></div>
# ---
#
# *verse:* **line** `A.pretty(227226, withPassage=True, withNodes=True)`
# <span class="psg ltr">P006427 obverse:1:1 </span><div class="contnr c2    " ><div class="lbl c2  "><span class="nd">line:227226</span> <span class="txtn">1</span></div> <div class="children row  "><div class="contnr c1 cluster trm   " ><div class="lbl c1 clusterb trm "><span class="nd">cluster:194473</span> <span class="txtn">?</span></div> </div><div class="children row wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">2</span> <span class="txtn">...</span></div> </div></div><div class="contnr c1 cluster {}   " ><div class="lbl c1 clustere trm "><span class="nd">cluster:194473</span> <span class="txtn">?</span></div> </div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">3</span> <span class="txtn">X</span></div> </div><div class="contnr c0 trm   " ><div class="lbl c0 trm "><span class="nd">4</span> <span class="txtn">X</span></div> </div></div></div>

# %% [markdown]
# ## Run specific corpora

# %%
As.testSet("dss")

# %%
As.test(verses, refresh=True)
# Out:
# # dss
# <style>tr.tf, td.tf, th.tf { text-align: left ! important;}@font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: large;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: x-large;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: large;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: x-large;
#     direction: ltr;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .rtl {
#     direction: rtl ! important;
# }
# span.plain {
#     display: inline-block;
#     white-space: pre-wrap;
#     text-align: start;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 0.1rem;
#     margin: 0.1rem;
#     direction: ltr;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1rem 0rem;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .section {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--section);
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd {
#     font-family: sans-serif;
#     font-size: x-small;
#     color: var(--node);
#     vertical-align: super;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.row {
#     flex-flow: row nowrap;
# }
# .children.row.wrap {
#     flex-flow: row wrap;
# }
# .children.col {
#     flex-flow: column nowrap;
# }
# .children.col.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5rem 0.1rem 0.1rem 0.1rem;
#     margin: 0.8rem 0.1rem 0.1rem 0.1rem;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-color3);
#     border-width: var(--border-width3);
#     border-radius: var(--border-width3);
# }
# .contnr.c4,.lbl.c4 {
#     border-color: var(--border-color4);
#     border-width: var(--border-width4);
#     border-radius: var(--border-width4);
# }
# .contnr.l {
#     border-left-style: dotted
# }
# .contnr.r {
#     border-right-style: dotted
# }
# .contnr.lno {
#     border-left-style: none
# }
# .contnr.rno {
#     border-right-style: none
# }
# .lbl {
#     margin-top: -1.2rem;
#     margin-left: 1rem;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3rem;
#     border-style: solid;
#     display: block;
#     color: var(--label)
# }
# .lbl.trm {
#     background-attachment: local;
#     margin-top: 0.1rem;
#     margin-left: 0.1rem;
#     padding: 0.1rem 0.1rem;
#     border-style: none;
# }
# .lbl.cnul {
#     font-size: xx-small;
# ---
#
# *verse:* **line** `A.plain(1552973, withPassage=False, withNodes=True)`
# <span class="plain outer rtl  " ><span class="nd">1552973</span><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">ו</span></span></span><span class="plain  rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">ע</span></span><span class="plain  rtl  " ><span class="txtu hbo">ת</span></span><span class="plain  rtl  " ><span class="txtu hbo">ה </span></span></span><span class="plain  rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">ש</span></span><span class="plain  rtl  " ><span class="txtu hbo">מ</span></span><span class="plain  rtl  " ><span class="txtu hbo">ע</span></span><span class="plain  rtl  " ><span class="txtu hbo">ו </span></span></span><span class="plain  rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">כ</span></span><span class="plain  rtl  " ><span class="txtu hbo">ל </span></span></span><span class="plain  rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">י</span></span><span class="plain  rtl  " ><span class="txtu hbo">ו</span></span><span class="plain  rtl  " ><span class="txtu hbo">ד</span></span><span class="plain  rtl  " ><span class="txtu hbo">ע</span></span><span class="plain  rtl  " ><span class="txtu hbo">י </span></span></span><span class="plain  rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">צ</span></span><span class="plain  rtl  " ><span class="txtu hbo">ד</span></span><span class="plain  rtl  " ><span class="txtu hbo">ק </span></span></span><span class="plain  rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">ו</span></span></span><span class="plain  rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">ב</span></span><span class="plain  rtl  " ><span class="txtu hbo">י</span></span><span class="plain  rtl  " ><span class="txtu hbo">נ</span></span><span class="plain  rtl  " ><span class="txtu hbo">ו </span></span></span><span class="plain  rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">ב</span></span></span><span class="plain  rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">מ</span></span><span class="plain  rtl  " ><span class="txtu hbo">ע</span></span><span class="plain  rtl  " ><span class="txtu hbo">ש</span></span><span class="plain  rtl  " ><span class="txtu hbo">י </span></span></span></span>
# ---
#
# *verse:* **line** `A.plain(1552973, withPassage=True, withNodes=True)`
# <span class="section ltr">CD 1:1 </span><span class="plain outer rtl  " ><span class="nd">1552973</span><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">ו</span></span></span><span class="plain  rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">ע</span></span><span class="plain  rtl  " ><span class="txtu hbo">ת</span></span><span class="plain  rtl  " ><span class="txtu hbo">ה </span></span></span><span class="plain  rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">ש</span></span><span class="plain  rtl  " ><span class="txtu hbo">מ</span></span><span class="plain  rtl  " ><span class="txtu hbo">ע</span></span><span class="plain  rtl  " ><span class="txtu hbo">ו </span></span></span><span class="plain  rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">כ</span></span><span class="plain  rtl  " ><span class="txtu hbo">ל </span></span></span><span class="plain  rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">י</span></span><span class="plain  rtl  " ><span class="txtu hbo">ו</span></span><span class="plain  rtl  " ><span class="txtu hbo">ד</span></span><span class="plain  rtl  " ><span class="txtu hbo">ע</span></span><span class="plain  rtl  " ><span class="txtu hbo">י </span></span></span><span class="plain  rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">צ</span></span><span class="plain  rtl  " ><span class="txtu hbo">ד</span></span><span class="plain  rtl  " ><span class="txtu hbo">ק </span></span></span><span class="plain  rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">ו</span></span></span><span class="plain  rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">ב</span></span><span class="plain  rtl  " ><span class="txtu hbo">י</span></span><span class="plain  rtl  " ><span class="txtu hbo">נ</span></span><span class="plain  rtl  " ><span class="txtu hbo">ו </span></span></span><span class="plain  rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">ב</span></span></span><span class="plain  rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">מ</span></span><span class="plain  rtl  " ><span class="txtu hbo">ע</span></span><span class="plain  rtl  " ><span class="txtu hbo">ש</span></span><span class="plain  rtl  " ><span class="txtu hbo">י </span></span></span></span>
# ---
#
# *verse:* **line** `A.pretty(1552973, withPassage=False, withNodes=True)`
# <div class="contnr c3  rtl  " ><div class="lbl c3  "><span class="nd">line:1552973</span> </div> <div class="children row wrap rtl"><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm "><span class="nd">word:1606869</span> <span class="txtu hbo"><span class="plain outer rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">ו</span></span></span></span></div> <div class='features'><span class="sp ">ptcl</span><span class="lex "><span class="f">lex=</span>וְ</span><span class="cl "><span class="f">cl=</span>conj</span></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm "><span class="nd">word:1606870</span> <span class="txtu hbo"><span class="plain outer rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">ע</span></span><span class="plain  rtl  " ><span class="txtu hbo">ת</span></span><span class="plain  rtl  " ><span class="txtu hbo">ה </span></span></span></span></div> <div class='features'><span class="sp ">ptcl</span><span class="lex "><span class="f">lex=</span>עַתָּה</span><span class="cl "><span class="f">cl=</span>advb</span></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm "><span class="nd">word:1606871</span> <span class="txtu hbo"><span class="plain outer rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">ש</span></span><span class="plain  rtl  " ><span class="txtu hbo">מ</span></span><span class="plain  rtl  " ><span class="txtu hbo">ע</span></span><span class="plain  rtl  " ><span class="txtu hbo">ו </span></span></span></span></div> <div class='features'><span class="sp ">verb</span><span class="lex "><span class="f">lex=</span>שׁמע</span><span class="gn "><span class="f">gn=</span>m</span><span class="nu "><span class="f">nu=</span>p</span><span class="vs "><span class="f">vs=</span>qal</span><span class="vt "><span class="f">vt=</span>impv</span></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm "><span class="nd">word:1606872</span> <span class="txtu hbo"><span class="plain outer rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">כ</span></span><span class="plain  rtl  " ><span class="txtu hbo">ל </span></span></span></span></div> <div class='features'><span class="sp ">subs</span><span class="lex "><span class="f">lex=</span>כֹּל</span><span class="cl "><span class="f">cl=</span>cmn</span><span class="gn "><span class="f">gn=</span>m</span><span class="nu "><span class="f">nu=</span>s</span><span class="st "><span class="f">st=</span>c</span></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm "><span class="nd">word:1606873</span> <span class="txtu hbo"><span class="plain outer rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">י</span></span><span class="plain  rtl  " ><span class="txtu hbo">ו</span></span><span class="plain  rtl  " ><span class="txtu hbo">ד</span></span><span class="plain  rtl  " ><span class="txtu hbo">ע</span></span><span class="plain  rtl  " ><span class="txtu hbo">י </span></span></span></span></div> <div class='features'><span class="sp ">verb</span><span class="lex "><span class="f">lex=</span>ידע</span><span class="gn "><span class="f">gn=</span>m</span><span class="nu "><span class="f">nu=</span>p</span><span class="st "><span class="f">st=</span>c</span><span class="vs "><span class="f">vs=</span>qal</span><span class="vt "><span class="f">vt=</span>ptca</span></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm "><span class="nd">word:1606874</span> <span class="txtu hbo"><span class="plain outer rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">צ</span></span><span class="plain  rtl  " ><span class="txtu hbo">ד</span></span><span class="plain  rtl  " ><span class="txtu hbo">ק </span></span></span></span></div>  ...
# ---
#
# *verse:* **line** `A.pretty(1552973, withPassage=True, withNodes=True)`
# <span class="section ltr">CD 1:1 </span><div class="contnr c3  rtl  " ><div class="lbl c3  "><span class="nd">line:1552973</span> </div> <div class="children row wrap rtl"><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm "><span class="nd">word:1606869</span> <span class="txtu hbo"><span class="plain outer rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">ו</span></span></span></span></div> <div class='features'><span class="sp ">ptcl</span><span class="lex "><span class="f">lex=</span>וְ</span><span class="cl "><span class="f">cl=</span>conj</span></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm "><span class="nd">word:1606870</span> <span class="txtu hbo"><span class="plain outer rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">ע</span></span><span class="plain  rtl  " ><span class="txtu hbo">ת</span></span><span class="plain  rtl  " ><span class="txtu hbo">ה </span></span></span></span></div> <div class='features'><span class="sp ">ptcl</span><span class="lex "><span class="f">lex=</span>עַתָּה</span><span class="cl "><span class="f">cl=</span>advb</span></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm "><span class="nd">word:1606871</span> <span class="txtu hbo"><span class="plain outer rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">ש</span></span><span class="plain  rtl  " ><span class="txtu hbo">מ</span></span><span class="plain  rtl  " ><span class="txtu hbo">ע</span></span><span class="plain  rtl  " ><span class="txtu hbo">ו </span></span></span></span></div> <div class='features'><span class="sp ">verb</span><span class="lex "><span class="f">lex=</span>שׁמע</span><span class="gn "><span class="f">gn=</span>m</span><span class="nu "><span class="f">nu=</span>p</span><span class="vs "><span class="f">vs=</span>qal</span><span class="vt "><span class="f">vt=</span>impv</span></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm "><span class="nd">word:1606872</span> <span class="txtu hbo"><span class="plain outer rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">כ</span></span><span class="plain  rtl  " ><span class="txtu hbo">ל </span></span></span></span></div> <div class='features'><span class="sp ">subs</span><span class="lex "><span class="f">lex=</span>כֹּל</span><span class="cl "><span class="f">cl=</span>cmn</span><span class="gn "><span class="f">gn=</span>m</span><span class="nu "><span class="f">nu=</span>s</span><span class="st "><span class="f">st=</span>c</span></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm "><span class="nd">word:1606873</span> <span class="txtu hbo"><span class="plain outer rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">י</span></span><span class="plain  rtl  " ><span class="txtu hbo">ו</span></span><span class="plain  rtl  " ><span class="txtu hbo">ד</span></span><span class="plain  rtl  " ><span class="txtu hbo">ע</span></span><span class="plain  rtl  " ><span class="txtu hbo">י </span></span></span></span></div> <div class='features'><span class="sp ">verb</span><span class="lex "><span class="f">lex=</span>ידע</span><span class="gn "><span class="f">gn=</span>m</span><span class="nu "><span class="f">nu=</span>p</span><span class="st "><span class="f">st=</span>c</span><span class="vs "><span class="f">vs=</span>qal</span><span class="vt "><span class="f">vt=</span>ptca</span></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm "><span class="nd">word:1606874</span> <span class="txtu hbo"><span class="plain outer rtl  " ><span class="plain txtu hbo rtl"></span><span class="plain  rtl  " ><span class="txtu hbo">צ</span></span><span class="plain  rtl  " ><span class="txtu hbo">ד</span></span><span class="plain  rtl  " ><span class="txtu hb ...
