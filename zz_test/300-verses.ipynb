# %%
# %load_ext autoreload
# %autoreload 2

# %%
from fixture import TestApp

# %%
As = TestApp(globals())

# %%
def verses():
    for n in As.select(verse=True, start=True, size=1):
        As.perform("plain", n, withPassage=False, withNodes=True)
        As.perform("plain", n, withPassage=True, withNodes=True)
        As.perform("pretty", n, withPassage=False, withNodes=True)
        As.perform("pretty", n, withPassage=True, withNodes=True)

# %% [markdown]
# ## Run all corpora

# %%
As.testSet()

# %%
As.test(verses)
# Out:
# # athenaeus
# <b title="local github">TF-app:</b> <span title="repo clone offline under ~/github">~/github/annotation/app-athenaeus/code</span>
# <b title="local github">data:</b> <span title="repo clone offline under ~/github">~/github/pthu/athenaeus/Athenaeus/Deipnosophistae/tf/1.1</span>
# <style>tr.tf, td.tf, th.tf { text-align: left ! important;}@font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .rtl {
#     direction: rtl ! important;
# }
# span.plain {
#     display: inline-block;
#     white-space: pre-wrap;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 0.1rem;
#     margin: 0.1rem;
#     direction: ltr;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1rem 0rem;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .section {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--section);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5rem 0.1rem 0.1rem 0.1rem;
#     margin: 0.8rem 0.1rem 0.1rem 0.1rem;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-color3);
#     border-width: var(--border-width3);
#     border-radius: var(--border-width3);
# }
# .contnr.c4,.lbl.c4 {
#     border-color: var(--border-color4);
#     border-width: var(--border-width4);
#     border-radius: var(--border-width4);
# }
# .plain.l,.contnr.l,.contnr.l>.lbl {
#     border-left-style: dotted
# }
# .plain.r,.contnr.r,.contnr.r>.lbl {
#     border-right-style: dotted
# }
# .plain.lno,.contnr.lno,.contnr.lno>.lbl {
#     border-left-style: none
# }
# .plain.rno,.contnr.rno,.contnr.rno>.lbl {
#     border-right-style: none
# }
# .pl
# ---
#
# *verse:* **_sentence**  `A.plain(265148, withPassage=False, withNodes=True)`
# <div class=""><span class="plain   " ><span class="nd">265148</span><span class="txtu grc">Ἀθήναιος </span><span class="txtu grc">μὲν </span><span class="txtu grc">ὁ </span><span class="txtu grc">τῆς </span><span class="txtu grc">βίβλου </span><span class="txtu grc">πατήρ· </span><span class="txtu grc">ποιεῖται </span><span class="txtu grc">δὲ </span><span class="txtu grc">τὸν </span><span class="txtu grc">λόγον </span><span class="txtu grc">πρὸς </span><span class="txtu grc">Τιμοκράτην· </span><span class="txtu grc">Δειπνοσοφιστὴς </span><span class="txtu grc">δὲ </span><span class="txtu grc">ταύτῃ </span><span class="txtu grc">τὸ </span><span class="txtu grc">ὄνομα. </span></span></div>
# ---
#
# *verse:* **_sentence**  `A.plain(265148, withPassage=True, withNodes=True)`
# <div class=""><span class="section ">1 1:1</span>  <span class="plain   " ><span class="nd">265148</span><span class="txtu grc">Ἀθήναιος </span><span class="txtu grc">μὲν </span><span class="txtu grc">ὁ </span><span class="txtu grc">τῆς </span><span class="txtu grc">βίβλου </span><span class="txtu grc">πατήρ· </span><span class="txtu grc">ποιεῖται </span><span class="txtu grc">δὲ </span><span class="txtu grc">τὸν </span><span class="txtu grc">λόγον </span><span class="txtu grc">πρὸς </span><span class="txtu grc">Τιμοκράτην· </span><span class="txtu grc">Δειπνοσοφιστὴς </span><span class="txtu grc">δὲ </span><span class="txtu grc">ταύτῃ </span><span class="txtu grc">τὸ </span><span class="txtu grc">ὄνομα. </span></span></div>
# ---
#
# *verse:* **_sentence**  `A.pretty(265148, withPassage=False, withNodes=True)`
# <div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">_sentence:265148</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1</span> <span class="txtu grc">Ἀθήναιος </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">2</span> <span class="txtu grc">μὲν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">3</span> <span class="txtu grc">ὁ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">4</span> <span class="txtu grc">τῆς </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">5</span> <span class="txtu grc">βίβλου </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">6</span> <span class="txtu grc">πατήρ· </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">7</span> <span class="txtu grc">ποιεῖται </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">8</span> <span class="txtu grc">δὲ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">9</span> <span class="txtu grc">τὸν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">10</span> <span class="txtu grc">λόγον </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">11</span> <span class="txtu grc">πρὸς </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">12</span> <span class="txtu grc">Τιμοκράτην· </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">13</span> <span class="txtu grc">Δειπνοσοφιστὴς </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">14</span> <span class="txtu grc">δὲ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">15</span> <span class="txtu grc">ταύτῃ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">16</span> <span class="txtu grc">τὸ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">17</span> <span class="txtu grc">ὄνομα. </span></div></div></div></div></div>
# ---
#
# *verse:* **_sentence**  `A.pretty(265148, withPassage=True, withNodes=True)`
# <div class="section ">1 1:1</div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">_sentence:265148</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1</span> <span class="txtu grc">Ἀθήναιος </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">2</span> <span class="txtu grc">μὲν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">3</span> <span class="txtu grc">ὁ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">4</span> <span class="txtu grc">τῆς </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">5</span> <span class="txtu grc">βίβλου </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">6</span> <span class="txtu grc">πατήρ· </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">7</span> <span class="txtu grc">ποιεῖται </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">8</span> <span class="txtu grc">δὲ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">9</span> <span class="txtu grc">τὸν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">10</span> <span class="txtu grc">λόγον </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">11</span> <span class="txtu grc">πρὸς </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">12</span> <span class="txtu grc">Τιμοκράτην· </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">13</span> <span class="txtu grc">Δειπνοσοφιστὴς </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">14</span> <span class="txtu grc">δὲ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">15</span> <span class="txtu grc">ταύτῃ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">16</span> <span class="txtu grc">τὸ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">17</span> <span class="txtu grc">ὄνομα. </span></div></div></div></div></div>
# # banks
# <b title="local github">TF-app:</b> <span title="repo clone offline under ~/github">~/github/annotation/app-banks/code</span>
# <b title="local github">data:</b> <span title="repo clone offline under ~/github">~/github/annotation/banks/tf/0.2</span>
# <style>tr.tf, td.tf, th.tf { text-align: left ! important;}@font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .rtl {
#     direction: rtl ! important;
# }
# span.plain {
#     display: inline-block;
#     white-space: pre-wrap;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 0.1rem;
#     margin: 0.1rem;
#     direction: ltr;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1rem 0rem;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .section {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--section);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5rem 0.1rem 0.1rem 0.1rem;
#     margin: 0.8rem 0.1rem 0.1rem 0.1rem;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-color3);
#     border-width: var(--border-width3);
#     border-radius: var(--border-width3);
# }
# .contnr.c4,.lbl.c4 {
#     border-color: var(--border-color4);
#     border-width: var(--border-width4);
#     border-radius: var(--border-width4);
# }
# .plain.l,.contnr.l,.contnr.l>.lbl {
#     border-left-style: dotted
# }
# .plain.r,.contnr.r,.contnr.r>.lbl {
#     border-right-style: dotted
# }
# .plain.lno,.contnr.lno,.contnr.lno>.lbl {
#     border-left-style: none
# }
# .plain.rno,.contnr.rno,.contnr.rno>.lbl {
#     border-right-style: none
# }
# .pl
# ---
#
# *verse:* **line**  `A.plain(103, withPassage=False, withNodes=True)`
# <div class=""><span class="plain   " ><span class="nd">103</span><span class="txtu">Everything </span><span class="txtu">about </span><span class="txtu">us, </span></span></div>
# ---
#
# *verse:* **line**  `A.plain(103, withPassage=True, withNodes=True)`
# <div class=""><span class="section ">Consider Phlebas 1:1</span>  <span class="plain   " ><span class="nd">103</span><span class="txtu">Everything </span><span class="txtu">about </span><span class="txtu">us, </span></span></div>
# ---
#
# *verse:* **line**  `A.pretty(103, withPassage=False, withNodes=True)`
# <div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">line:103</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1</span> <span class="txtu">Everything </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">2</span> <span class="txtu">about </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">3</span> <span class="txtu">us, </span></div></div></div></div></div>
# ---
#
# *verse:* **line**  `A.pretty(103, withPassage=True, withNodes=True)`
# <div class="section ">Consider Phlebas 1:1</div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">line:103</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1</span> <span class="txtu">Everything </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">2</span> <span class="txtu">about </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">3</span> <span class="txtu">us, </span></div></div></div></div></div>
# ---
#
# *verse:* **sentence**  `A.plain(115, withPassage=False, withNodes=True)`
# <div class=""><span class="plain   " ><span class="nd">115</span><span class="txtu">Everything </span><span class="txtu">about </span><span class="txtu">us, </span><span class="txtu">everything </span><span class="txtu">around </span><span class="txtu">us, </span><span class="plain  r " ><span class="txtu">everything </span><span class="txtu">we </span><span class="txtu">know </span></span><span class="txtu">and </span><span class="txtu">can </span><span class="txtu">know </span><span class="txtu">of </span><span class="plain  l " ><span class="txtu">is </span><span class="txtu">composed </span><span class="txtu">ultimately </span><span class="txtu">of </span><span class="txtu">patterns </span><span class="txtu">of </span><span class="txtu">nothing; </span></span><span class="txtu">that’s </span><span class="txtu">the </span><span class="txtu">bottom </span><span class="txtu">line, </span><span class="txtu">the </span><span class="txtu">final </span><span class="txtu">truth. </span></span></div>
# ---
#
# *verse:* **sentence**  `A.plain(115, withPassage=True, withNodes=True)`
# <div class=""><span class="section ">Consider Phlebas 1:1</span>  <span class="plain   " ><span class="nd">115</span><span class="txtu">Everything </span><span class="txtu">about </span><span class="txtu">us, </span><span class="txtu">everything </span><span class="txtu">around </span><span class="txtu">us, </span><span class="plain  r " ><span class="txtu">everything </span><span class="txtu">we </span><span class="txtu">know </span></span><span class="txtu">and </span><span class="txtu">can </span><span class="txtu">know </span><span class="txtu">of </span><span class="plain  l " ><span class="txtu">is </span><span class="txtu">composed </span><span class="txtu">ultimately </span><span class="txtu">of </span><span class="txtu">patterns </span><span class="txtu">of </span><span class="txtu">nothing; </span></span><span class="txtu">that’s </span><span class="txtu">the </span><span class="txtu">bottom </span><span class="txtu">line, </span><span class="txtu">the </span><span class="txtu">final </span><span class="txtu">truth. </span></span></div>
# ---
#
# *verse:* **sentence**  `A.pretty(115, withPassage=False, withNodes=True)`
# <div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">sentence:115</span></div><div class="children hor wrap "><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">line:103</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1</span> <span class="txtu">Everything </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">2</span> <span class="txtu">about </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">3</span> <span class="txtu">us, </span></div></div></div></div><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">line:104</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">4</span> <span class="txtu">everything </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">5</span> <span class="txtu">around </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">6</span> <span class="txtu">us, </span></div></div></div></div><div class="contnr c3   r " ><div class="lbl c3  " ><span class="nd">line:105</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">7</span> <span class="txtu">everything </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">8</span> <span class="txtu">we </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">9</span> <span class="txtu">know </span></div></div></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">10</span> <span class="txtu">and </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">11</span> <span class="txtu">can </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">12</span> <span class="txtu">know </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">13</span> <span class="txtu">of </span></div></div><div class="contnr c3   l " ><div class="lbl c3  " ><span class="nd">line:105</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">14</span> <span class="txtu">is </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">15</span> <span class="txtu">composed </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">16</span> <span class="txtu">ultimately </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">17</span> <span class="txtu">of </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">18</span> <span class="txtu">patterns </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">19</span> <span class="txtu">of </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">20</span> <span class="txtu">nothing; </span></div></div></div></div><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">line:106</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">21</span> <span class="txtu">that’s </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">22</span> <span class="txtu">the </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">23</span> <span class="txtu">bottom </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">24</span> <span class="txtu">line, </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">25</span> <span class="txtu">the </span></div></div><di ...
# ---
#
# *verse:* **sentence**  `A.pretty(115, withPassage=True, withNodes=True)`
# <div class="section ">Consider Phlebas 1:1</div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">sentence:115</span></div><div class="children hor wrap "><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">line:103</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1</span> <span class="txtu">Everything </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">2</span> <span class="txtu">about </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">3</span> <span class="txtu">us, </span></div></div></div></div><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">line:104</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">4</span> <span class="txtu">everything </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">5</span> <span class="txtu">around </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">6</span> <span class="txtu">us, </span></div></div></div></div><div class="contnr c3   r " ><div class="lbl c3  " ><span class="nd">line:105</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">7</span> <span class="txtu">everything </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">8</span> <span class="txtu">we </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">9</span> <span class="txtu">know </span></div></div></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">10</span> <span class="txtu">and </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">11</span> <span class="txtu">can </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">12</span> <span class="txtu">know </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">13</span> <span class="txtu">of </span></div></div><div class="contnr c3   l " ><div class="lbl c3  " ><span class="nd">line:105</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">14</span> <span class="txtu">is </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">15</span> <span class="txtu">composed </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">16</span> <span class="txtu">ultimately </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">17</span> <span class="txtu">of </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">18</span> <span class="txtu">patterns </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">19</span> <span class="txtu">of </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">20</span> <span class="txtu">nothing; </span></div></div></div></div><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">line:106</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">21</span> <span class="txtu">that’s </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">22</span> <span class="txtu">the </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">23</span> <span class="txtu">bottom </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">24</span> <span class="txtu">line, </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">25</spa ...
# # bhsa
# <b title="local github">TF-app:</b> <span title="repo clone offline under ~/github">~/github/annotation/app-bhsa/code</span>
# <b title="local github">data:</b> <span title="repo clone offline under ~/github">~/github/etcbc/bhsa/tf/c</span>
# <b title="local github">data:</b> <span title="repo clone offline under ~/github">~/github/etcbc/phono/tf/c</span>
# <b title="local github">data:</b> <span title="repo clone offline under ~/github">~/github/etcbc/parallels/tf/c</span>
# <style>tr.tf, td.tf, th.tf { text-align: left ! important;}@font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .rtl {
#     direction: rtl ! important;
# }
# span.plain {
#     display: inline-block;
#     white-space: pre-wrap;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 0.1rem;
#     margin: 0.1rem;
#     direction: ltr;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1rem 0rem;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .section {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--section);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5rem 0.1rem 0.1rem 0.1rem;
#     margin: 0.8rem 0.1rem 0.1rem 0.1rem;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-color3);
#     border-width: var(--border-width3);
#     border-radius: var(--border-width3);
# }
# .contnr.c4,.lbl.c4 {
#     border-color: var(--border-color4);
#     border-width: var(--border-width4);
#     border-radius: var(--border-width4);
# }
# .plain.l,.contnr.l,.contnr.l>.lbl {
#     border-left-style: dotted
# }
# .plain.r,.contnr.r,.contnr.r>.lbl {
#     border-right-style: dotted
# }
# .plain.lno,.contnr.lno,.contnr.lno>.lbl {
#     border-left-style: none
# }
# .plain.rno,.contnr.rno,.contnr.rno>.lbl {
#     border-right-style: none
# }
# .pl
# ---
#
# *verse:* **half_verse**  `A.plain(606362, withPassage=False, withNodes=True)`
# <div class="rtl"><span class="plain rtl  " ><span class="nd">606362</span><span class="txtu hbo">בְּ</span><span class="txtu hbo">רֵאשִׁ֖ית </span><span class="txtu hbo">בָּרָ֣א </span><span class="txtu hbo">אֱלֹהִ֑ים </span></span></div>
# ---
#
# *verse:* **half_verse**  `A.plain(606362, withPassage=True, withNodes=True)`
# <div class="rtl"><span class="section rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 1:1">Genesis 1:1</a></span>  <span class="plain rtl  " ><span class="nd">606362</span><span class="txtu hbo">בְּ</span><span class="txtu hbo">רֵאשִׁ֖ית </span><span class="txtu hbo">בָּרָ֣א </span><span class="txtu hbo">אֱלֹהִ֑ים </span></span></div>
# ---
#
# *verse:* **half_verse**  `A.pretty(606362, withPassage=False, withNodes=True)`
# <div class="rtl children"><div class="contnr c3  rtl  " ><div class="lbl c3  " ><span class="nd">half_verse:606362</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl lno " ><div class="lbl c2  " ><span class="nd">sentence:1172290</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl lno " ><div class="lbl c2  " ><span class="nd">clause:427553</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:651542</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="Show this on SHEBANQ"><span class="txtu hbo">בְּ</span></a></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">2</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1RACJTn" title="Show this on SHEBANQ"><span class="txtu hbo">רֵאשִׁ֖ית </span></a></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:651543</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">3</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1BRAv" title="Show this on SHEBANQ"><span class="txtu hbo">בָּרָ֣א </span></a></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:651544</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">4</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1ALHJMn" title="Show this on SHEBANQ"><span class="txtu hbo">אֱלֹהִ֑ים </span></a></div></div></div></div></div></div></div></div></div></div></div>
# ---
#
# *verse:* **half_verse**  `A.pretty(606362, withPassage=True, withNodes=True)`
# ...
# ---
#
# *verse:* **verse**  `A.pretty(112966, withPassage=True, withNodes=True)`
# <div class="section rtl"><a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/plain/0.1/Matthew.txt" title="show this passage in the SyrNT repository" sec="Matthew 1:1">Matthew 1:1</a></div><div class="rtl children"><div class="contnr c3  rtl  " ><div class="lbl c3  " ><span class="nd">verse:112966</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1</span> <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/plain" title="show this passage in the SyrNT repository"><span class="txtu syc">ܟܬܒܐ </span></a></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">2</span> <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/plain" title="show this passage in the SyrNT repository"><span class="txtu syc">ܕܝܠܝܕܘܬܗ </span></a></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">3</span> <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/plain" title="show this passage in the SyrNT repository"><span class="txtu syc">ܕܝܫܘܥ </span></a></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">4</span> <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/plain" title="show this passage in the SyrNT repository"><span class="txtu syc">ܡܫܝܚܐ </span></a></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">5</span> <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/plain" title="show this passage in the SyrNT repository"><span class="txtu syc">ܒܪܗ </span></a></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">6</span> <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/plain" title="show this passage in the SyrNT repository"><span class="txtu syc">ܕܕܘܝܕ </span></a></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">7</span> <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/plain" title="show this passage in the SyrNT repository"><span class="txtu syc">ܒܪܗ </span></a></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">8</span> <a target="_blank" href="https://github.com/etcbc/syrnt/blob/master/plain" title="show this passage in the SyrNT repository"><span class="txtu syc">ܕܐܒܪܗܡ </span></a></div></div></div></div></div>
# # uruk
# <b title="local github">TF-app:</b> <span title="repo clone offline under ~/github">~/github/annotation/app-uruk/code</span>
# <b title="local github">data:</b> <span title="repo clone offline under ~/github">~/github/Nino-cunei/uruk/tf/uruk/1.0</span>
# <style>tr.tf, td.tf, th.tf { text-align: left ! important;}@font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .rtl {
#     direction: rtl ! important;
# }
# span.plain {
#     display: inline-block;
#     white-space: pre-wrap;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 0.1rem;
#     margin: 0.1rem;
#     direction: ltr;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1rem 0rem;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .section {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--section);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5rem 0.1rem 0.1rem 0.1rem;
#     margin: 0.8rem 0.1rem 0.1rem 0.1rem;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-color3);
#     border-width: var(--border-width3);
#     border-radius: var(--border-width3);
# }
# .contnr.c4,.lbl.c4 {
#     border-color: var(--border-color4);
#     border-width: var(--border-width4);
#     border-radius: var(--border-width4);
# }
# .plain.l,.contnr.l,.contnr.l>.lbl {
#     border-left-style: dotted
# }
# .plain.r,.contnr.r,.contnr.r>.lbl {
#     border-right-style: dotted
# }
# .plain.lno,.contnr.lno,.contnr.lno>.lbl {
#     border-left-style: none
# }
# .plain.rno,.contnr.rno,.contnr.rno>.lbl {
#     border-right-style: none
# }
# .pl
# <b title="local github">data:</b> <span title="repo clone offline under ~/github">~/github/Nino-cunei/uruk/sources/cdli/images</span>
# ---
#
# *verse:* **line**  `A.plain(227226, withPassage=False, withNodes=True)`
# <div class=""><span class="plain   " ><span class="nd">227226</span><span class="plain " >[<span class="plain " >...</span>]</span> <span class="plain " >X</span> <span class="plain " >X</span> </span></div>
# ---
#
# *verse:* **line**  `A.plain(227226, withPassage=True, withNodes=True)`
# <div class=""><span class="section "><a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006427" title="to CDLI main page for this tablet" sec="P006427 obverse:1:1">P006427 obverse:1:1</a></span>  <span class="plain   " ><span class="nd">227226</span><span class="plain " >[<span class="plain " >...</span>]</span> <span class="plain " >X</span> <span class="plain " >X</span> </span></div>
# ---
#
# *verse:* **line**  `A.pretty(227226, withPassage=False, withNodes=True)`
# <div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">line:227226</span> <span class="txtu"><span title="number">1</span></span></div><div class="children hor  "><div class="contnr c1 cluster trm   " ><div class="lbl c1 clusterb trm " ><span class="nd">cluster:194473</span> <span class="txtu"><span title="type">?</span></span></div></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">2</span> <span class="txtu"><span title="atf">...</span></span></div></div></div><div class="contnr c1 cluster {}   " ><div class="lbl c1 clustere trm " ><span class="nd">cluster:194473</span> <span class="txtu"><span title="type">?</span></span></div> </div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">3</span> <span class="txtu"><span title="atf">X</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">4</span> <span class="txtu"><span title="atf">X</span></span></div></div></div></div></div>
# ---
#
# *verse:* **line**  `A.pretty(227226, withPassage=True, withNodes=True)`
# <div class="section "><a target="_blank" href="https://cdli.ucla.edu/search/search_results.php?SearchMode=Text&amp;ObjectID=P006427" title="to CDLI main page for this tablet" sec="P006427 obverse:1:1">P006427 obverse:1:1</a></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">line:227226</span> <span class="txtu"><span title="number">1</span></span></div><div class="children hor  "><div class="contnr c1 cluster trm   " ><div class="lbl c1 clusterb trm " ><span class="nd">cluster:194473</span> <span class="txtu"><span title="type">?</span></span></div></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">2</span> <span class="txtu"><span title="atf">...</span></span></div></div></div><div class="contnr c1 cluster {}   " ><div class="lbl c1 clustere trm " ><span class="nd">cluster:194473</span> <span class="txtu"><span title="type">?</span></span></div> </div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">3</span> <span class="txtu"><span title="atf">X</span></span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">4</span> <span class="txtu"><span title="atf">X</span></span></div></div></div></div></div>

# %% [markdown]
# ## Run specific corpora

# %%
As.testSet("dss")

# %%
As.test(verses, refresh=True)
# Out:
# # dss
#     10s All features loaded/computed - for details use loadLog()
# <style>tr.tf, td.tf, th.tf { text-align: left ! important;}@font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .rtl {
#     direction: rtl ! important;
# }
# span.plain {
#     display: inline-block;
#     white-space: pre-wrap;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 0.1rem;
#     margin: 0.1rem;
#     direction: ltr;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1rem 0rem;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .section {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--section);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  0.5rem 0.1rem 0.1rem 0.1rem;
#     margin: 0.8rem 0.1rem 0.1rem 0.1rem;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-color3);
#     border-width: var(--border-width3);
#     border-radius: var(--border-width3);
# }
# .contnr.c4,.lbl.c4 {
#     border-color: var(--border-color4);
#     border-width: var(--border-width4);
#     border-radius: var(--border-width4);
# }
# .plain.l,.contnr.l,.contnr.l>.lbl {
#     border-left-style: dotted
# }
# .plain.r,.contnr.r,.contnr.r>.lbl {
#     border-right-style: dotted
# }
# .plain.lno,.contnr.lno,.contnr.lno>.lbl {
#     border-left-style: none
# }
# .plain.rno,.contnr.rno,.contnr.rno>.lbl {
#     border-right-style: none
# }
# .pl
# ---
#
# *verse:* **line**  `A.plain(1552973, withPassage=False, withNodes=True)`
# <div class="rtl"><span class="plain rtl  " ><span class="nd">1552973</span><span class="txtu hbo">  </span><span class="txtu hbo">ו</span><span class="txtu hbo">ע</span><span class="txtu hbo">ת</span><span class="txtu hbo">ה </span><span class="txtu hbo">ש</span><span class="txtu hbo">מ</span><span class="txtu hbo">ע</span><span class="txtu hbo">ו </span><span class="txtu hbo">כ</span><span class="txtu hbo">ל </span><span class="txtu hbo">י</span><span class="txtu hbo">ו</span><span class="txtu hbo">ד</span><span class="txtu hbo">ע</span><span class="txtu hbo">י </span><span class="txtu hbo">צ</span><span class="txtu hbo">ד</span><span class="txtu hbo">ק </span><span class="txtu hbo">ו</span><span class="txtu hbo">ב</span><span class="txtu hbo">י</span><span class="txtu hbo">נ</span><span class="txtu hbo">ו </span><span class="txtu hbo">ב</span><span class="txtu hbo">מ</span><span class="txtu hbo">ע</span><span class="txtu hbo">ש</span><span class="txtu hbo">י </span></span></div>
# ---
#
# *verse:* **line**  `A.plain(1552973, withPassage=True, withNodes=True)`
# <div class="rtl"><span class="section rtl"><a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="Show this scroll in the Leon Levy library" sec="CD 1:1">CD 1:1</a></span>  <span class="plain rtl  " ><span class="nd">1552973</span><span class="txtu hbo">  </span><span class="txtu hbo">ו</span><span class="txtu hbo">ע</span><span class="txtu hbo">ת</span><span class="txtu hbo">ה </span><span class="txtu hbo">ש</span><span class="txtu hbo">מ</span><span class="txtu hbo">ע</span><span class="txtu hbo">ו </span><span class="txtu hbo">כ</span><span class="txtu hbo">ל </span><span class="txtu hbo">י</span><span class="txtu hbo">ו</span><span class="txtu hbo">ד</span><span class="txtu hbo">ע</span><span class="txtu hbo">י </span><span class="txtu hbo">צ</span><span class="txtu hbo">ד</span><span class="txtu hbo">ק </span><span class="txtu hbo">ו</span><span class="txtu hbo">ב</span><span class="txtu hbo">י</span><span class="txtu hbo">נ</span><span class="txtu hbo">ו </span><span class="txtu hbo">ב</span><span class="txtu hbo">מ</span><span class="txtu hbo">ע</span><span class="txtu hbo">ש</span><span class="txtu hbo">י </span></span></div>
# ---
#
# *verse:* **line**  `A.pretty(1552973, withPassage=False, withNodes=True)`
# <div class="rtl children"><div class="contnr c3  rtl  " ><div class="lbl c3  " ><span class="nd">line:1552973</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">cluster:1430242</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1</span> <span class="txtu hbo">  </span></div></div></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm " ><span class="nd">word:1606869</span> <a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive" title="Show this scroll in the Leon Levy library"><span class="txtu hbo"><span class="txtu hbo">ו</span></span></a></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm " ><span class="nd">word:1606870</span> <a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive" title="Show this scroll in the Leon Levy library"><span class="txtu hbo"><span class="txtu hbo">ע</span><span class="txtu hbo">ת</span><span class="txtu hbo">ה </span></span></a></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm " ><span class="nd">word:1606871</span> <a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive" title="Show this scroll in the Leon Levy library"><span class="txtu hbo"><span class="txtu hbo">ש</span><span class="txtu hbo">מ</span><span class="txtu hbo">ע</span><span class="txtu hbo">ו </span></span></a></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm " ><span class="nd">word:1606872</span> <a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive" title="Show this scroll in the Leon Levy library"><span class="txtu hbo"><span class="txtu hbo">כ</span><span class="txtu hbo">ל </span></span></a></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm " ><span class="nd">word:1606873</span> <a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive" title="Show this scroll in the Leon Levy library"><span class="txtu hbo"><span class="txtu hbo">י</span><span class="txtu hbo">ו</span><span class="txtu hbo">ד</span><span class="txtu hbo">ע</span><span class="txtu hbo">י </span></span></a></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm " ><span class="nd">word:1606874</span> <a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive" title="Show this scroll in the Leon Levy library"><span class="txtu hbo"><span class="txtu hbo">צ</span><span class="txtu hbo">ד</span><span class="txtu hbo">ק </span></span></a></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm " ><span class="nd">word:1606875</span> <a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive" title="Show this scroll in the Leon Levy library"><span class="txtu hbo"><span class="txtu hbo">ו</span></span></a></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm " ><span class="nd">word:1606876</span> <a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive" title="Show this scroll in the Leon Levy library"><span class="txtu hbo"><span class="txtu hbo">ב</span><span class="txtu hbo">י</span><span class="txtu hbo">נ</span><span class="txtu hbo">ו </span></span></a></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm " ><span class="nd">word:1606877</span> <a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive" title="Show this scroll in the Leon Levy library"><span class="txtu hbo"><span class="txtu hbo">ב</span></span></a></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm " ><span class="nd">word:1606878</span> <a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive" title="Show this scroll in the Leon Levy library"><span class="txtu hbo"><span class="txtu hbo">מ</span><span class="txtu hbo">ע</span><span class="txtu hbo">ש</span><span class="txtu ...
# ---
#
# *verse:* **line**  `A.pretty(1552973, withPassage=True, withNodes=True)`
# <div class="section rtl"><a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive/search#q='CD'" title="Show this scroll in the Leon Levy library" sec="CD 1:1">CD 1:1</a></div><div class="rtl children"><div class="contnr c3  rtl  " ><div class="lbl c3  " ><span class="nd">line:1552973</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">cluster:1430242</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1</span> <span class="txtu hbo">  </span></div></div></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm " ><span class="nd">word:1606869</span> <a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive" title="Show this scroll in the Leon Levy library"><span class="txtu hbo"><span class="txtu hbo">ו</span></span></a></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm " ><span class="nd">word:1606870</span> <a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive" title="Show this scroll in the Leon Levy library"><span class="txtu hbo"><span class="txtu hbo">ע</span><span class="txtu hbo">ת</span><span class="txtu hbo">ה </span></span></a></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm " ><span class="nd">word:1606871</span> <a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive" title="Show this scroll in the Leon Levy library"><span class="txtu hbo"><span class="txtu hbo">ש</span><span class="txtu hbo">מ</span><span class="txtu hbo">ע</span><span class="txtu hbo">ו </span></span></a></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm " ><span class="nd">word:1606872</span> <a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive" title="Show this scroll in the Leon Levy library"><span class="txtu hbo"><span class="txtu hbo">כ</span><span class="txtu hbo">ל </span></span></a></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm " ><span class="nd">word:1606873</span> <a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive" title="Show this scroll in the Leon Levy library"><span class="txtu hbo"><span class="txtu hbo">י</span><span class="txtu hbo">ו</span><span class="txtu hbo">ד</span><span class="txtu hbo">ע</span><span class="txtu hbo">י </span></span></a></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm " ><span class="nd">word:1606874</span> <a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive" title="Show this scroll in the Leon Levy library"><span class="txtu hbo"><span class="txtu hbo">צ</span><span class="txtu hbo">ד</span><span class="txtu hbo">ק </span></span></a></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm " ><span class="nd">word:1606875</span> <a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive" title="Show this scroll in the Leon Levy library"><span class="txtu hbo"><span class="txtu hbo">ו</span></span></a></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm " ><span class="nd">word:1606876</span> <a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive" title="Show this scroll in the Leon Levy library"><span class="txtu hbo"><span class="txtu hbo">ב</span><span class="txtu hbo">י</span><span class="txtu hbo">נ</span><span class="txtu hbo">ו </span></span></a></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm " ><span class="nd">word:1606877</span> <a target="_blank" href="https://www.deadseascrolls.org.il/explore-the-archive" title="Show this scroll in the Leon Levy library"><span class="txtu hbo"><span class="txtu hbo">ב</span></span></a></div></div><div class="contnr c1 trm rtl  " ><div class="lbl c1 trm " ><span class="nd">word:1606878</span> <a target="_blank" href="https://www.deadseascrolls.org.il/explor ...
